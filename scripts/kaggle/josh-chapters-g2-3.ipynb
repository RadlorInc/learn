# %% [markdown]
# # Radlic voice — Grade 2 (part 3 of 4) story chapters in Josh
#
# Renders every line the Grade 2 (part 3 of 4) story chapters can say that has no clip yet — **1500 lines, 71,702 characters** (the lines are
# written into this notebook). Style A (Chatterbox Turbo) for all of them. Rules: `docs/new-flow/voice.md`.
#
# **Before Run All:** Settings → Accelerator → **GPU T4 x2** (or P100), Internet **On**. At the end, download
# `radlic-voice-josh-chapters-g2-3.zip` from the Output panel and hand it back. If the session stops early, Run All
# again in the same session: lines already rendered are skipped.

# %%
import os, sys, subprocess, pathlib, shutil, json
VOICE = 'nzFihrBIvB34imQBuxub'   # Josh
WORK = pathlib.Path('/kaggle/working' if os.path.isdir('/kaggle/working') else '/content')
REPO = WORK / 'learn-main'
if not REPO.exists():
    subprocess.run(['git', 'clone', '--depth', '1', '--branch', 'main', 'https://github.com/RadlorInc/learn.git', str(REPO)], check=True)
LINES = [{"key": "lrluti", "text": "That makes fifteen. I asked for three.", "style": "A"}, {"key": "pllcu3", "text": "That makes sixteen. I asked for three.", "style": "A"}, {"key": "jltqe2", "text": "That makes seventeen. I asked for three.", "style": "A"}, {"key": "1wh3lo4", "text": "That makes eighteen. I asked for three.", "style": "A"}, {"key": "1x7msp1", "text": "That makes forty-six. Count my coins again.", "style": "A"}, {"key": "19zzf8z", "text": "That makes thirty-one. I asked for forty-six.", "style": "A"}, {"key": "1d5vqz1", "text": "That makes thirty-two. I asked for forty-six.", "style": "A"}, {"key": "13lrdon", "text": "That makes thirty-three. I asked for forty-six.", "style": "A"}, {"key": "1qpahnf", "text": "That makes thirty-four. I asked for forty-six.", "style": "A"}, {"key": "1lepb27", "text": "That makes thirty-five. I asked for forty-six.", "style": "A"}, {"key": "5xo8hj", "text": "That makes thirty-six. I asked for forty-six.", "style": "A"}, {"key": "bq259m", "text": "That makes thirty-seven. I asked for forty-six.", "style": "A"}, {"key": "kl7fd8", "text": "That makes thirty-eight. I asked for forty-six.", "style": "A"}, {"key": "1m4qgdb", "text": "That makes thirty-nine. I asked for forty-six.", "style": "A"}, {"key": "1d2go2o", "text": "That makes forty. I asked for forty-six.", "style": "A"}, {"key": "123pjsp", "text": "That makes forty-one. I asked for forty-six.", "style": "A"}, {"key": "jg5m8b", "text": "That makes forty-two. I asked for forty-six.", "style": "A"}, {"key": "gwlxap", "text": "That makes forty-three. I asked for forty-six.", "style": "A"}, {"key": "92jix5", "text": "That makes forty-four. I asked for forty-six.", "style": "A"}, {"key": "lmd4a9", "text": "That makes forty-five. I asked for forty-six.", "style": "A"}, {"key": "16i98ek", "text": "That makes forty-seven. I asked for forty-six.", "style": "A"}, {"key": "1qd3dt2", "text": "That makes forty-eight. I asked for forty-six.", "style": "A"}, {"key": "1ephdvl", "text": "That makes forty-nine. I asked for forty-six.", "style": "A"}, {"key": "kvwh3y", "text": "That makes fifty. I asked for forty-six.", "style": "A"}, {"key": "10jta9b", "text": "That makes fifty-one. I asked for forty-six.", "style": "A"}, {"key": "tw8sfd", "text": "That makes fifty-two. I asked for forty-six.", "style": "A"}, {"key": "yree9f", "text": "That makes fifty-three. I asked for forty-six.", "style": "A"}, {"key": "1ngusnj", "text": "That makes fifty-four. I asked for forty-six.", "style": "A"}, {"key": "whz5yr", "text": "That makes fifty-five. I asked for forty-six.", "style": "A"}, {"key": "p8k3a3", "text": "That makes fifty-six. I asked for forty-six.", "style": "A"}, {"key": "mtdqny", "text": "That makes fifty-seven. I asked for forty-six.", "style": "A"}, {"key": "yx8t48", "text": "That makes fifty-eight. I asked for forty-six.", "style": "A"}, {"key": "1hwswdf", "text": "That makes fifty-nine. I asked for forty-six.", "style": "A"}, {"key": "1bw8xlf", "text": "That makes sixty. I asked for forty-six.", "style": "A"}, {"key": "av2o8u", "text": "That makes sixty-one. I asked for forty-six.", "style": "A"}, {"key": "10ggfna", "text": "That makes two. I asked for seventeen.", "style": "A"}, {"key": "1tgma6k", "text": "That makes three. I asked for seventeen.", "style": "A"}, {"key": "1fr76ma", "text": "That makes four. I asked for seventeen.", "style": "A"}, {"key": "nsf9f6", "text": "That makes five. I asked for seventeen.", "style": "A"}, {"key": "1o9rh50", "text": "That makes six. I asked for seventeen.", "style": "A"}, {"key": "knsnx", "text": "That makes seven. I asked for seventeen.", "style": "A"}, {"key": "1ftr82r", "text": "That makes eight. I asked for seventeen.", "style": "A"}, {"key": "8wrj6a", "text": "That makes nine. I asked for seventeen.", "style": "A"}, {"key": "l2p4h3", "text": "That makes ten. I asked for seventeen.", "style": "A"}, {"key": "17wm983", "text": "That makes eleven. I asked for seventeen.", "style": "A"}, {"key": "1hsy02v", "text": "That makes twelve. I asked for seventeen.", "style": "A"}, {"key": "ah25gl", "text": "That makes thirteen. I asked for seventeen.", "style": "A"}, {"key": "107t6xq", "text": "That makes fourteen. I asked for seventeen.", "style": "A"}, {"key": "5dfn21", "text": "That makes fifteen. I asked for seventeen.", "style": "A"}, {"key": "fyo4dg", "text": "That makes sixteen. I asked for seventeen.", "style": "A"}, {"key": "1aoisyr", "text": "That makes eighteen. I asked for seventeen.", "style": "A"}, {"key": "7nmmku", "text": "That makes nineteen. I asked for seventeen.", "style": "A"}, {"key": "xkcicr", "text": "That makes twenty. I asked for seventeen.", "style": "A"}, {"key": "d3i6nu", "text": "That makes twenty-one. I asked for seventeen.", "style": "A"}, {"key": "ou4m28", "text": "That makes twenty-two. I asked for seventeen.", "style": "A"}, {"key": "1lq2x6y", "text": "That makes twenty-three. I asked for seventeen.", "style": "A"}, {"key": "12jpnkk", "text": "That makes twenty-four. I asked for seventeen.", "style": "A"}, {"key": "88fsfs", "text": "That makes twenty-five. I asked for seventeen.", "style": "A"}, {"key": "1yrg0fe", "text": "That makes twenty-six. I asked for seventeen.", "style": "A"}, {"key": "92yupf", "text": "That makes twenty-seven. I asked for seventeen.", "style": "A"}, {"key": "cortnt", "text": "That makes twenty-eight. I asked for seventeen.", "style": "A"}, {"key": "cn57l4", "text": "That makes twenty-nine. I asked for seventeen.", "style": "A"}, {"key": "yryiuq", "text": "That makes thirty. I asked for seventeen.", "style": "A"}, {"key": "e2473z", "text": "That makes thirty-one. I asked for seventeen.", "style": "A"}, {"key": "uafgyp", "text": "That makes thirty-two. I asked for seventeen.", "style": "A"}, {"key": "1woihz5", "text": "That makes one. I asked for four.", "style": "A"}, {"key": "1npawtr", "text": "That makes two. I asked for four.", "style": "A"}, {"key": "7g21it", "text": "That makes three. I asked for four.", "style": "A"}, {"key": "a2i9nv", "text": "That makes five. I asked for four.", "style": "A"}, {"key": "1ba4ax9", "text": "That makes six. I asked for four.", "style": "A"}, {"key": "eia5ye", "text": "That makes seven. I asked for four.", "style": "A"}, {"key": "1vdqt90", "text": "That makes eight. I asked for four.", "style": "A"}, {"key": "1qhan2j", "text": "That makes nine. I asked for four.", "style": "A"}, {"key": "15wix94", "text": "That makes ten. I asked for four.", "style": "A"}, {"key": "1wkfk84", "text": "That makes eleven. I asked for four.", "style": "A"}, {"key": "1uh4lw8", "text": "That makes twelve. I asked for four.", "style": "A"}, {"key": "5au9bi", "text": "That makes thirteen. I asked for four.", "style": "A"}, {"key": "pfmydz", "text": "That makes fourteen. I asked for four.", "style": "A"}, {"key": "1fh818y", "text": "That makes fifteen. I asked for four.", "style": "A"}, {"key": "j4csml", "text": "That makes sixteen. I asked for four.", "style": "A"}, {"key": "opoyxq", "text": "That makes seventeen. I asked for four.", "style": "A"}, {"key": "og90yc", "text": "That makes eighteen. I asked for four.", "style": "A"}, {"key": "17zr613", "text": "That makes nineteen. I asked for four.", "style": "A"}, {"key": "1dm6zb2", "text": "That makes one. I asked for twelve.", "style": "A"}, {"key": "l6lmiw", "text": "That makes two. I asked for twelve.", "style": "A"}, {"key": "1ukcd3u", "text": "That makes three. I asked for twelve.", "style": "A"}, {"key": "prgeak", "text": "That makes four. I asked for twelve.", "style": "A"}, {"key": "1tcqr3g", "text": "That makes five. I asked for twelve.", "style": "A"}, {"key": "6ngwfm", "text": "That makes six. I asked for twelve.", "style": "A"}, {"key": "nb97q9", "text": "That makes seven. I asked for twelve.", "style": "A"}, {"key": "1op9hpv", "text": "That makes eight. I asked for twelve.", "style": "A"}, {"key": "1yawaoc", "text": "That makes nine. I asked for twelve.", "style": "A"}, {"key": "1bpv0f3", "text": "That makes ten. I asked for twelve.", "style": "A"}, {"key": "1e1yqr", "text": "That makes eleven. I asked for twelve.", "style": "A"}, {"key": "11y4cqx", "text": "That makes thirteen. I asked for twelve.", "style": "A"}, {"key": "tjfhps", "text": "That makes fourteen. I asked for twelve.", "style": "A"}, {"key": "1dq0dqt", "text": "That makes fifteen. I asked for twelve.", "style": "A"}, {"key": "dxmkeq", "text": "That makes sixteen. I asked for twelve.", "style": "A"}, {"key": "wgcb2x", "text": "That makes seventeen. I asked for twelve.", "style": "A"}, {"key": "un7kvn", "text": "That makes eighteen. I asked for twelve.", "style": "A"}, {"key": "1aiys3k", "text": "That makes nineteen. I asked for twelve.", "style": "A"}, {"key": "rvfqyj", "text": "That makes twenty. I asked for twelve.", "style": "A"}, {"key": "141h9as", "text": "That makes twenty-one. I asked for twelve.", "style": "A"}, {"key": "fbfcp2", "text": "That makes twenty-two. I asked for twelve.", "style": "A"}, {"key": "1qldfes", "text": "That makes twenty-three. I asked for twelve.", "style": "A"}, {"key": "pnsndu", "text": "That makes twenty-four. I asked for twelve.", "style": "A"}, {"key": "rahlxq", "text": "That makes twenty-five. I asked for twelve.", "style": "A"}, {"key": "p78pw", "text": "That makes twenty-six. I asked for twelve.", "style": "A"}, {"key": "1auztv", "text": "That makes twenty-seven. I asked for twelve.", "style": "A"}, {"key": "17j542t", "text": "That makes six. I asked for twenty-one.", "style": "A"}, {"key": "kgk68u", "text": "That makes seven. I asked for twenty-one.", "style": "A"}, {"key": "1gm31ao", "text": "That makes eight. I asked for twenty-one.", "style": "A"}, {"key": "666txj", "text": "That makes nine. I asked for twenty-one.", "style": "A"}, {"key": "akwz3o", "text": "That makes ten. I asked for twenty-one.", "style": "A"}, {"key": "zh8mzk", "text": "That makes eleven. I asked for twenty-one.", "style": "A"}, {"key": "1nogmgk", "text": "That makes twelve. I asked for twenty-one.", "style": "A"}, {"key": "i7w7mu", "text": "That makes thirteen. I asked for twenty-one.", "style": "A"}, {"key": "520qwz", "text": "That makes fourteen. I asked for twenty-one.", "style": "A"}, {"key": "caxw3e", "text": "That makes fifteen. I asked for twenty-one.", "style": "A"}, {"key": "y4sqo5", "text": "That makes sixteen. I asked for twenty-one.", "style": "A"}, {"key": "1y963di", "text": "That makes seventeen. I asked for twenty-one.", "style": "A"}, {"key": "3ejftc", "text": "That makes eighteen. I asked for twenty-one.", "style": "A"}, {"key": "18uqdo3", "text": "That makes nineteen. I asked for twenty-one.", "style": "A"}, {"key": "1i1h1tk", "text": "That makes twenty. I asked for twenty-one.", "style": "A"}, {"key": "10790wh", "text": "That makes twenty-two. I asked for twenty-one.", "style": "A"}, {"key": "1qql0sf", "text": "That makes twenty-three. I asked for twenty-one.", "style": "A"}, {"key": "15g2k8l", "text": "That makes twenty-four. I asked for twenty-one.", "style": "A"}, {"key": "16gl8ux", "text": "That makes twenty-five. I asked for twenty-one.", "style": "A"}, {"key": "1ghrn1b", "text": "That makes twenty-six. I asked for twenty-one.", "style": "A"}, {"key": "l1hr4w", "text": "That makes twenty-seven. I asked for twenty-one.", "style": "A"}, {"key": "1ibit2i", "text": "That makes twenty-eight. I asked for twenty-one.", "style": "A"}, {"key": "hfav2h", "text": "That makes twenty-nine. I asked for twenty-one.", "style": "A"}, {"key": "gzinmv", "text": "That makes thirty. I asked for twenty-one.", "style": "A"}, {"key": "g4jdak", "text": "That makes thirty-one. I asked for twenty-one.", "style": "A"}, {"key": "100h3mq", "text": "That makes thirty-two. I asked for twenty-one.", "style": "A"}, {"key": "1xqvtkg", "text": "That makes thirty-three. I asked for twenty-one.", "style": "A"}, {"key": "ql5jhg", "text": "That makes thirty-four. I asked for twenty-one.", "style": "A"}, {"key": "1ru3lko", "text": "That makes thirty-five. I asked for twenty-one.", "style": "A"}, {"key": "wmwp9c", "text": "That makes thirty-six. I asked for twenty-one.", "style": "A"}, {"key": "cyt7z8", "text": "That makes ten. I asked for twenty-five.", "style": "A"}, {"key": "6v7cxk", "text": "That makes eleven. I asked for twenty-five.", "style": "A"}, {"key": "1h2gg4k", "text": "That makes twelve. I asked for twenty-five.", "style": "A"}, {"key": "1qxm3aa", "text": "That makes thirteen. I asked for twenty-five.", "style": "A"}, {"key": "yc4jwx", "text": "That makes fourteen. I asked for twenty-five.", "style": "A"}, {"key": "1fdyb9q", "text": "That makes fifteen. I asked for twenty-five.", "style": "A"}, {"key": "zc14dz", "text": "That makes sixteen. I asked for twenty-five.", "style": "A"}, {"key": "1u4l47m", "text": "That makes seventeen. I asked for twenty-five.", "style": "A"}, {"key": "1sxhm08", "text": "That makes eighteen. I asked for twenty-five.", "style": "A"}, {"key": "1o970w1", "text": "That makes nineteen. I asked for twenty-five.", "style": "A"}, {"key": "a3570w", "text": "That makes twenty. I asked for twenty-five.", "style": "A"}, {"key": "11qje8l", "text": "That makes twenty-one. I asked for twenty-five.", "style": "A"}, {"key": "7s7umz", "text": "That makes twenty-two. I asked for twenty-five.", "style": "A"}, {"key": "1obx2cl", "text": "That makes twenty-three. I asked for twenty-five.", "style": "A"}, {"key": "r4llyf", "text": "That makes twenty-four. I asked for twenty-five.", "style": "A"}, {"key": "zj64sl", "text": "That makes twenty-six. I asked for twenty-five.", "style": "A"}, {"key": "nio588", "text": "That makes twenty-seven. I asked for twenty-five.", "style": "A"}, {"key": "aw7b26", "text": "That makes twenty-eight. I asked for twenty-five.", "style": "A"}, {"key": "1ovnecz", "text": "That makes twenty-nine. I asked for twenty-five.", "style": "A"}, {"key": "e585fx", "text": "That makes thirty. I asked for twenty-five.", "style": "A"}, {"key": "15exg4c", "text": "That makes thirty-one. I asked for twenty-five.", "style": "A"}, {"key": "1pd1f3q", "text": "That makes thirty-two. I asked for twenty-five.", "style": "A"}, {"key": "10tkmo8", "text": "That makes thirty-three. I asked for twenty-five.", "style": "A"}, {"key": "a04huc", "text": "That makes thirty-four. I asked for twenty-five.", "style": "A"}, {"key": "fbt9w0", "text": "That makes thirty-five. I asked for twenty-five.", "style": "A"}, {"key": "xbxozc", "text": "That makes thirty-six. I asked for twenty-five.", "style": "A"}, {"key": "1ws6ws5", "text": "That makes thirty-seven. I asked for twenty-five.", "style": "A"}, {"key": "z7ayxj", "text": "That makes thirty-eight. I asked for twenty-five.", "style": "A"}, {"key": "7hrx80", "text": "That makes thirty-nine. I asked for twenty-five.", "style": "A"}, {"key": "16moc9f", "text": "That makes forty. I asked for twenty-five.", "style": "A"}, {"key": "8q1n6t", "text": "That makes fifty-six. I asked for seventy-one.", "style": "A"}, {"key": "1ccxdrc", "text": "That makes fifty-seven. I asked for seventy-one.", "style": "A"}, {"key": "twokam", "text": "That makes fifty-eight. I asked for seventy-one.", "style": "A"}, {"key": "hkjgtp", "text": "That makes fifty-nine. I asked for seventy-one.", "style": "A"}, {"key": "38zmpp", "text": "That makes sixty. I asked for seventy-one.", "style": "A"}, {"key": "1ev1l9k", "text": "That makes sixty-one. I asked for seventy-one.", "style": "A"}, {"key": "13j9jhm", "text": "That makes sixty-two. I asked for seventy-one.", "style": "A"}, {"key": "1vbq0zs", "text": "That makes sixty-three. I asked for seventy-one.", "style": "A"}, {"key": "1j8oxy6", "text": "That makes sixty-four. I asked for seventy-one.", "style": "A"}, {"key": "kfznzu", "text": "That makes sixty-five. I asked for seventy-one.", "style": "A"}, {"key": "784m00", "text": "That makes sixty-six. I asked for seventy-one.", "style": "A"}, {"key": "4j5999", "text": "That makes sixty-seven. I asked for seventy-one.", "style": "A"}, {"key": "1qeu8uv", "text": "That makes sixty-eight. I asked for seventy-one.", "style": "A"}, {"key": "1car52y", "text": "That makes sixty-nine. I asked for seventy-one.", "style": "A"}, {"key": "10f05qc", "text": "That makes seventy. I asked for seventy-one.", "style": "A"}, {"key": "xpcxlf", "text": "That makes seventy-two. I asked for seventy-one.", "style": "A"}, {"key": "1723bih", "text": "That makes seventy-three. I asked for seventy-one.", "style": "A"}, {"key": "ovky5x", "text": "That makes seventy-four. I asked for seventy-one.", "style": "A"}, {"key": "12h8k9t", "text": "That makes seventy-five. I asked for seventy-one.", "style": "A"}, {"key": "44ulqx", "text": "That makes seventy-six. I asked for seventy-one.", "style": "A"}, {"key": "1hobaqk", "text": "That makes seventy-seven. I asked for seventy-one.", "style": "A"}, {"key": "63bypm", "text": "That makes seventy-eight. I asked for seventy-one.", "style": "A"}, {"key": "d3y3mp", "text": "That makes seventy-nine. I asked for seventy-one.", "style": "A"}, {"key": "79qma2", "text": "That makes eighty. I asked for seventy-one.", "style": "A"}, {"key": "12imy4r", "text": "That makes eighty-one. I asked for seventy-one.", "style": "A"}, {"key": "1a9n9cp", "text": "That makes eighty-two. I asked for seventy-one.", "style": "A"}, {"key": "19z73sj", "text": "That makes eighty-three. I asked for seventy-one.", "style": "A"}, {"key": "1pxykfn", "text": "That makes eighty-four. I asked for seventy-one.", "style": "A"}, {"key": "1ihi7zv", "text": "That makes eighty-five. I asked for seventy-one.", "style": "A"}, {"key": "o4moub", "text": "That makes eighty-six. I asked for seventy-one.", "style": "A"}, {"key": "12fptvz", "text": "That makes one. I asked for sixteen.", "style": "A"}, {"key": "1fbgclh", "text": "That makes two. I asked for sixteen.", "style": "A"}, {"key": "1canzcz", "text": "That makes three. I asked for sixteen.", "style": "A"}, {"key": "1p34ck1", "text": "That makes four. I asked for sixteen.", "style": "A"}, {"key": "ikeip", "text": "That makes five. I asked for sixteen.", "style": "A"}, {"key": "1xxhft7", "text": "That makes six. I asked for sixteen.", "style": "A"}, {"key": "1jpgnpq", "text": "That makes seven. I asked for sixteen.", "style": "A"}, {"key": "l3zcfg", "text": "That makes eight. I asked for sixteen.", "style": "A"}, {"key": "1eq27kx", "text": "That makes nine. I asked for sixteen.", "style": "A"}, {"key": "19yuids", "text": "That makes ten. I asked for sixteen.", "style": "A"}, {"key": "17xpxa4", "text": "That makes eleven. I asked for sixteen.", "style": "A"}, {"key": "1dk0d5c", "text": "That makes twelve. I asked for sixteen.", "style": "A"}, {"key": "17xls06", "text": "That makes thirteen. I asked for sixteen.", "style": "A"}, {"key": "1h3ejp9", "text": "That makes fourteen. I asked for sixteen.", "style": "A"}, {"key": "mbva8a", "text": "That makes fifteen. I asked for sixteen.", "style": "A"}, {"key": "1ky55py", "text": "That makes seventeen. I asked for sixteen.", "style": "A"}, {"key": "iwa2wc", "text": "That makes eighteen. I asked for sixteen.", "style": "A"}, {"key": "1ei0sh9", "text": "That makes nineteen. I asked for sixteen.", "style": "A"}, {"key": "1ejow4k", "text": "That makes twenty. I asked for sixteen.", "style": "A"}, {"key": "12yas9l", "text": "That makes twenty-one. I asked for sixteen.", "style": "A"}, {"key": "1afac93", "text": "That makes twenty-two. I asked for sixteen.", "style": "A"}, {"key": "1junz1l", "text": "That makes twenty-three. I asked for sixteen.", "style": "A"}, {"key": "1nfhy6z", "text": "That makes twenty-four. I asked for sixteen.", "style": "A"}, {"key": "ibb64f", "text": "That makes twenty-five. I asked for sixteen.", "style": "A"}, {"key": "1byale1", "text": "That makes twenty-six. I asked for sixteen.", "style": "A"}, {"key": "u8q5q4", "text": "That makes twenty-seven. I asked for sixteen.", "style": "A"}, {"key": "1gwg0l6", "text": "That makes twenty-eight. I asked for sixteen.", "style": "A"}, {"key": "1boswof", "text": "That makes twenty-nine. I asked for sixteen.", "style": "A"}, {"key": "1re7sx", "text": "That makes thirty. I asked for sixteen.", "style": "A"}, {"key": "1ybazvc", "text": "That makes thirty-one. I asked for sixteen.", "style": "A"}, {"key": "1mzj4uy", "text": "That is thirteen, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "vfq1de", "text": "That is thirteen, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1wqbkdl", "text": "That is thirteen, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "12gieuf", "text": "That is thirteen, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1vjr9n9", "text": "That makes one. I asked for two.", "style": "A"}, {"key": "ls61rl", "text": "That makes three. I asked for two.", "style": "A"}, {"key": "bqt30f", "text": "That makes four. I asked for two.", "style": "A"}, {"key": "1sgtgy7", "text": "That makes five. I asked for two.", "style": "A"}, {"key": "n1x721", "text": "That makes six. I asked for two.", "style": "A"}, {"key": "f4g8t8", "text": "That makes seven. I asked for two.", "style": "A"}, {"key": "l49agq", "text": "That makes eight. I asked for two.", "style": "A"}, {"key": "15wq0z3", "text": "That makes nine. I asked for two.", "style": "A"}, {"key": "4erefa", "text": "That makes ten. I asked for two.", "style": "A"}, {"key": "zxnyp6", "text": "That makes eleven. I asked for two.", "style": "A"}, {"key": "1eapfba", "text": "That makes twelve. I asked for two.", "style": "A"}, {"key": "koa2qc", "text": "That makes thirteen. I asked for two.", "style": "A"}, {"key": "14yagsj", "text": "That makes fourteen. I asked for two.", "style": "A"}, {"key": "655pmo", "text": "That makes fifteen. I asked for two.", "style": "A"}, {"key": "l5lt7d", "text": "That makes sixteen. I asked for two.", "style": "A"}, {"key": "1iioqqs", "text": "That makes seventeen. I asked for two.", "style": "A"}, {"key": "10wjtoq", "text": "That makes sixteen. I asked for thirty-one.", "style": "A"}, {"key": "lsbnzt", "text": "That makes seventeen. I asked for thirty-one.", "style": "A"}, {"key": "5p3eqf", "text": "That makes eighteen. I asked for thirty-one.", "style": "A"}, {"key": "14n47ss", "text": "That makes nineteen. I asked for thirty-one.", "style": "A"}, {"key": "eaab73", "text": "That makes twenty. I asked for thirty-one.", "style": "A"}, {"key": "xf2iww", "text": "That makes twenty-one. I asked for thirty-one.", "style": "A"}, {"key": "1lwxrni", "text": "That makes twenty-two. I asked for thirty-one.", "style": "A"}, {"key": "1a3wwg", "text": "That makes twenty-three. I asked for thirty-one.", "style": "A"}, {"key": "18a67wa", "text": "That makes twenty-four. I asked for thirty-one.", "style": "A"}, {"key": "8utc5y", "text": "That makes twenty-five. I asked for thirty-one.", "style": "A"}, {"key": "128mkc0", "text": "That makes twenty-six. I asked for thirty-one.", "style": "A"}, {"key": "1mw0xgn", "text": "That makes twenty-seven. I asked for thirty-one.", "style": "A"}, {"key": "7pstnp", "text": "That makes twenty-eight. I asked for thirty-one.", "style": "A"}, {"key": "tkpop2", "text": "That makes twenty-nine. I asked for thirty-one.", "style": "A"}, {"key": "egpze0", "text": "That makes thirty. I asked for thirty-one.", "style": "A"}, {"key": "1lc1cbx", "text": "That makes thirty-two. I asked for thirty-one.", "style": "A"}, {"key": "wc0y9j", "text": "That makes thirty-three. I asked for thirty-one.", "style": "A"}, {"key": "17xoiyr", "text": "That makes thirty-four. I asked for thirty-one.", "style": "A"}, {"key": "o2wuy7", "text": "That makes thirty-five. I asked for thirty-one.", "style": "A"}, {"key": "1rnjfl3", "text": "That makes thirty-six. I asked for thirty-one.", "style": "A"}, {"key": "1gro8o0", "text": "That makes thirty-seven. I asked for thirty-one.", "style": "A"}, {"key": "e7263u", "text": "That makes thirty-eight. I asked for thirty-one.", "style": "A"}, {"key": "7domdr", "text": "That makes thirty-nine. I asked for thirty-one.", "style": "A"}, {"key": "mfqk12", "text": "That makes forty. I asked for thirty-one.", "style": "A"}, {"key": "1lmmeld", "text": "That makes forty-one. I asked for thirty-one.", "style": "A"}, {"key": "c20uur", "text": "That makes forty-two. I asked for thirty-one.", "style": "A"}, {"key": "1xz59p5", "text": "That makes forty-three. I asked for thirty-one.", "style": "A"}, {"key": "w4mzn5", "text": "That makes forty-four. I asked for thirty-one.", "style": "A"}, {"key": "5iv6ux", "text": "That makes forty-five. I asked for thirty-one.", "style": "A"}, {"key": "12sw85t", "text": "That makes forty-six. I asked for thirty-one.", "style": "A"}, {"key": "yedhyp", "text": "That makes twenty-two. I asked for thirty-seven.", "style": "A"}, {"key": "1n5c1sf", "text": "That makes twenty-three. I asked for thirty-seven.", "style": "A"}, {"key": "phs5s5", "text": "That makes twenty-four. I asked for thirty-seven.", "style": "A"}, {"key": "yx6zjt", "text": "That makes twenty-five. I asked for thirty-seven.", "style": "A"}, {"key": "gi8er3", "text": "That makes twenty-six. I asked for thirty-seven.", "style": "A"}, {"key": "1n742kc", "text": "That makes twenty-seven. I asked for thirty-seven.", "style": "A"}, {"key": "nqy5qm", "text": "That makes twenty-eight. I asked for thirty-seven.", "style": "A"}, {"key": "awxctl", "text": "That makes twenty-nine. I asked for thirty-seven.", "style": "A"}, {"key": "1g3qqs7", "text": "That makes thirty. I asked for thirty-seven.", "style": "A"}, {"key": "18m3boo", "text": "That makes thirty-one. I asked for thirty-seven.", "style": "A"}, {"key": "1r5brnq", "text": "That makes thirty-two. I asked for thirty-seven.", "style": "A"}, {"key": "ls81vw", "text": "That makes thirty-three. I asked for thirty-seven.", "style": "A"}, {"key": "bu4734", "text": "That makes thirty-four. I asked for thirty-seven.", "style": "A"}, {"key": "1t1dbmc", "text": "That makes thirty-five. I asked for thirty-seven.", "style": "A"}, {"key": "dvg56k", "text": "That makes thirty-six. I asked for thirty-seven.", "style": "A"}, {"key": "gm2rat", "text": "That makes thirty-eight. I asked for thirty-seven.", "style": "A"}, {"key": "16w6p84", "text": "That makes thirty-nine. I asked for thirty-seven.", "style": "A"}, {"key": "6bzlmx", "text": "That makes forty. I asked for thirty-seven.", "style": "A"}, {"key": "msbw6a", "text": "That makes forty-one. I asked for thirty-seven.", "style": "A"}, {"key": "18a9eq8", "text": "That makes forty-two. I asked for thirty-seven.", "style": "A"}, {"key": "1evp90q", "text": "That makes forty-three. I asked for thirty-seven.", "style": "A"}, {"key": "1ukj9gy", "text": "That makes forty-four. I asked for thirty-seven.", "style": "A"}, {"key": "1xarnyi", "text": "That makes forty-five. I asked for thirty-seven.", "style": "A"}, {"key": "1el4hw2", "text": "That makes forty-six. I asked for thirty-seven.", "style": "A"}, {"key": "1e05cs5", "text": "That makes forty-seven. I asked for thirty-seven.", "style": "A"}, {"key": "u6ytcb", "text": "That makes forty-eight. I asked for thirty-seven.", "style": "A"}, {"key": "dv7hsq", "text": "That makes forty-nine. I asked for thirty-seven.", "style": "A"}, {"key": "1thmiqb", "text": "That makes fifty. I asked for thirty-seven.", "style": "A"}, {"key": "17ewd8k", "text": "That makes fifty-one. I asked for thirty-seven.", "style": "A"}, {"key": "pd10r6", "text": "That makes fifty-two. I asked for thirty-seven.", "style": "A"}, {"key": "970b3p", "text": "That is thirty-seven, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "ib1m0r", "text": "That is thirty-seven, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "rwbrno", "text": "That is thirty-seven, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "umo4ke", "text": "That is thirty-seven, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "hxn56s", "text": "That is forty-one, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "txw7cs", "text": "That is forty-one, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "v1xe43", "text": "That is forty-one, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "aaclpt", "text": "That is forty-one, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "16f7yj", "text": "That makes twelve. I asked for twenty-seven.", "style": "A"}, {"key": "vpbzt5", "text": "That makes thirteen. I asked for twenty-seven.", "style": "A"}, {"key": "1wdzork", "text": "That makes fourteen. I asked for twenty-seven.", "style": "A"}, {"key": "1siqr2d", "text": "That makes fifteen. I asked for twenty-seven.", "style": "A"}, {"key": "19a2y6", "text": "That makes sixteen. I asked for twenty-seven.", "style": "A"}, {"key": "1yu0x15", "text": "That makes seventeen. I asked for twenty-seven.", "style": "A"}, {"key": "d42nbj", "text": "That makes eighteen. I asked for twenty-seven.", "style": "A"}, {"key": "153k5lc", "text": "That makes nineteen. I asked for twenty-seven.", "style": "A"}, {"key": "j6cpd3", "text": "That makes twenty. I asked for twenty-seven.", "style": "A"}, {"key": "pf7qhg", "text": "That makes twenty-one. I asked for twenty-seven.", "style": "A"}, {"key": "79yo0i", "text": "That makes twenty-two. I asked for twenty-seven.", "style": "A"}, {"key": "m73m78", "text": "That makes twenty-three. I asked for twenty-seven.", "style": "A"}, {"key": "9wbc66", "text": "That makes twenty-four. I asked for twenty-seven.", "style": "A"}, {"key": "licxpm", "text": "That makes twenty-five. I asked for twenty-seven.", "style": "A"}, {"key": "1b73lqc", "text": "That makes twenty-six. I asked for twenty-seven.", "style": "A"}, {"key": "1shxjhx", "text": "That makes twenty-eight. I asked for twenty-seven.", "style": "A"}, {"key": "p93ffe", "text": "That makes twenty-nine. I asked for twenty-seven.", "style": "A"}, {"key": "14qbkqk", "text": "That makes thirty. I asked for twenty-seven.", "style": "A"}, {"key": "pt33bn", "text": "That makes thirty-one. I asked for twenty-seven.", "style": "A"}, {"key": "2m9lp", "text": "That makes thirty-two. I asked for twenty-seven.", "style": "A"}, {"key": "1sil4fj", "text": "That makes thirty-three. I asked for twenty-seven.", "style": "A"}, {"key": "1akr2rf", "text": "That makes thirty-four. I asked for twenty-seven.", "style": "A"}, {"key": "zt35d3", "text": "That makes thirty-five. I asked for twenty-seven.", "style": "A"}, {"key": "j570kf", "text": "That makes thirty-six. I asked for twenty-seven.", "style": "A"}, {"key": "13kq25w", "text": "That makes thirty-seven. I asked for twenty-seven.", "style": "A"}, {"key": "9z20ge", "text": "That makes thirty-eight. I asked for twenty-seven.", "style": "A"}, {"key": "1u2ed8n", "text": "That makes thirty-nine. I asked for twenty-seven.", "style": "A"}, {"key": "1991pmi", "text": "That makes forty. I asked for twenty-seven.", "style": "A"}, {"key": "gayy0x", "text": "That makes forty-one. I asked for twenty-seven.", "style": "A"}, {"key": "j7f8ob", "text": "That makes forty-two. I asked for twenty-seven.", "style": "A"}, {"key": "i9heca", "text": "That is twenty-seven, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "h58l7q", "text": "That is twenty-seven, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1nh3wdq", "text": "That is twenty-seven, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1cx0slf", "text": "That is twenty-seven, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "qvwu79", "text": "That is twenty-seven, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1399kam", "text": "That makes sixty-two. Count my coins again.", "style": "A"}, {"key": "lbvwcc", "text": "That makes sixty-three. Count my coins again.", "style": "A"}, {"key": "65mlqi", "text": "That makes sixty-four. Count my coins again.", "style": "A"}, {"key": "js3dta", "text": "That makes sixty-five. Count my coins again.", "style": "A"}, {"key": "cq52es", "text": "That makes sixty-six. Count my coins again.", "style": "A"}, {"key": "1bfgdt2", "text": "That makes forty. I asked for fifty-five.", "style": "A"}, {"key": "1hvsmjh", "text": "That makes forty-one. I asked for fifty-five.", "style": "A"}, {"key": "zgbm77", "text": "That makes forty-two. I asked for fifty-five.", "style": "A"}, {"key": "1jcr0yd", "text": "That makes forty-three. I asked for fifty-five.", "style": "A"}, {"key": "1jqtaj1", "text": "That makes forty-four. I asked for fifty-five.", "style": "A"}, {"key": "1880ib9", "text": "That makes forty-five. I asked for fifty-five.", "style": "A"}, {"key": "l0vib1", "text": "That makes forty-six. I asked for fifty-five.", "style": "A"}, {"key": "vle5bm", "text": "That makes forty-seven. I asked for fifty-five.", "style": "A"}, {"key": "14omwc8", "text": "That makes forty-eight. I asked for fifty-five.", "style": "A"}, {"key": "8l6nfp", "text": "That makes forty-nine. I asked for fifty-five.", "style": "A"}, {"key": "1sgho34", "text": "That makes fifty. I asked for fifty-five.", "style": "A"}, {"key": "1tsnrbr", "text": "That makes fifty-one. I asked for fifty-five.", "style": "A"}, {"key": "2m9zal", "text": "That makes fifty-two. I asked for fifty-five.", "style": "A"}, {"key": "12o0b", "text": "That makes fifty-three. I asked for fifty-five.", "style": "A"}, {"key": "2ivd9z", "text": "That makes fifty-four. I asked for fifty-five.", "style": "A"}, {"key": "wzolg3", "text": "That makes fifty-six. I asked for fifty-five.", "style": "A"}, {"key": "1vsx1sg", "text": "That makes fifty-seven. I asked for fifty-five.", "style": "A"}, {"key": "47ymb2", "text": "That makes fifty-eight. I asked for fifty-five.", "style": "A"}, {"key": "13iukd7", "text": "That makes fifty-nine. I asked for fifty-five.", "style": "A"}, {"key": "1yus44r", "text": "That makes sixty. I asked for fifty-five.", "style": "A"}, {"key": "9tkmz4", "text": "That makes sixty-one. I asked for fifty-five.", "style": "A"}, {"key": "1stz5de", "text": "That makes sixty-two. I asked for fifty-five.", "style": "A"}, {"key": "1wknt9s", "text": "That makes sixty-three. I asked for fifty-five.", "style": "A"}, {"key": "6qv6dq", "text": "That makes sixty-four. I asked for fifty-five.", "style": "A"}, {"key": "1tzqe0y", "text": "That makes sixty-five. I asked for fifty-five.", "style": "A"}, {"key": "1g6cpzc", "text": "That makes sixty-six. I asked for fifty-five.", "style": "A"}, {"key": "177n4y3", "text": "That makes sixty-seven. I asked for fifty-five.", "style": "A"}, {"key": "11299z1", "text": "That makes sixty-eight. I asked for fifty-five.", "style": "A"}, {"key": "1yk69u", "text": "That makes sixty-nine. I asked for fifty-five.", "style": "A"}, {"key": "1pi6gqs", "text": "That makes seventy. I asked for fifty-five.", "style": "A"}, {"key": "dprkvn", "text": "That is twenty-two, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "zurt9d", "text": "That is twenty-two, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "14xxfju", "text": "That is twenty-two, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "n63quk", "text": "That is twenty-two, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1m0yog0", "text": "That makes one. I asked for seven.", "style": "A"}, {"key": "1lx2slm", "text": "That makes two. I asked for seven.", "style": "A"}, {"key": "192g0hw", "text": "That makes three. I asked for seven.", "style": "A"}, {"key": "fr5dbq", "text": "That makes four. I asked for seven.", "style": "A"}, {"key": "h0fmrq", "text": "That makes five. I asked for seven.", "style": "A"}, {"key": "fu0b8s", "text": "That makes six. I asked for seven.", "style": "A"}, {"key": "3hqitv", "text": "That makes eight. I asked for seven.", "style": "A"}, {"key": "z1c63q", "text": "That makes nine. I asked for seven.", "style": "A"}, {"key": "vdhfuf", "text": "That makes ten. I asked for seven.", "style": "A"}, {"key": "wc35oj", "text": "That makes eleven. I asked for seven.", "style": "A"}, {"key": "1opknzr", "text": "That makes twelve. I asked for seven.", "style": "A"}, {"key": "12dfqfd", "text": "That makes thirteen. I asked for seven.", "style": "A"}, {"key": "1u7by3m", "text": "That makes fourteen. I asked for seven.", "style": "A"}, {"key": "s8ik8d", "text": "That makes fifteen. I asked for seven.", "style": "A"}, {"key": "1ytkwb0", "text": "That makes sixteen. I asked for seven.", "style": "A"}, {"key": "xfijtl", "text": "That makes seventeen. I asked for seven.", "style": "A"}, {"key": "1xlo6dv", "text": "That makes eighteen. I asked for seven.", "style": "A"}, {"key": "1opiwxe", "text": "That makes nineteen. I asked for seven.", "style": "A"}, {"key": "upayvf", "text": "That makes twenty. I asked for seven.", "style": "A"}, {"key": "1q7scpq", "text": "That makes twenty-one. I asked for seven.", "style": "A"}, {"key": "qjn5rs", "text": "That makes twenty-two. I asked for seven.", "style": "A"}, {"key": "tq0y8w", "text": "That makes seventy. Count my coins again.", "style": "A"}, {"key": "8ig8yz", "text": "That makes seventy-one. Count my coins again.", "style": "A"}, {"key": "q76ifd", "text": "That makes seventy-two. Count my coins again.", "style": "A"}, {"key": "2u06vj", "text": "That makes seventy-three. Count my coins again.", "style": "A"}, {"key": "wsdbg3", "text": "That makes seventy-four. Count my coins again.", "style": "A"}, {"key": "ryjddz", "text": "That makes seventy-five. Count my coins again.", "style": "A"}, {"key": "6epzjz", "text": "That makes seventy-six. Count my coins again.", "style": "A"}, {"key": "14k1cmw", "text": "That makes seventy-seven. Count my coins again.", "style": "A"}, {"key": "1l8ziwe", "text": "That makes seventy-eight. Count my coins again.", "style": "A"}, {"key": "12qscp3", "text": "That makes seventy-nine. Count my coins again.", "style": "A"}, {"key": "48xjz2", "text": "That makes eighty. Count my coins again.", "style": "A"}, {"key": "d4vn8h", "text": "That makes eighty-one. Count my coins again.", "style": "A"}, {"key": "1wjuym7", "text": "That makes eighty-two. Count my coins again.", "style": "A"}, {"key": "hbxh2h", "text": "That makes eighty-three. Count my coins again.", "style": "A"}, {"key": "kb7ycp", "text": "That makes eighty-four. Count my coins again.", "style": "A"}, {"key": "wkqndl", "text": "That makes eighty-six. Count my coins again.", "style": "A"}, {"key": "1wb0e4i", "text": "That makes eighty-seven. Count my coins again.", "style": "A"}, {"key": "gxoe74", "text": "That makes eighty-eight. Count my coins again.", "style": "A"}, {"key": "xhox9d", "text": "That makes eighty-nine. Count my coins again.", "style": "A"}, {"key": "kns5qd", "text": "That makes ninety. Count my coins again.", "style": "A"}, {"key": "1hinugm", "text": "That makes ninety-one. Count my coins again.", "style": "A"}, {"key": "shhhrc", "text": "That makes ninety-two. Count my coins again.", "style": "A"}, {"key": "19aua96", "text": "That makes ninety-three. Count my coins again.", "style": "A"}, {"key": "292n7w", "text": "That makes ninety-four. Count my coins again.", "style": "A"}, {"key": "nc3yn0", "text": "That makes ninety-five. Count my coins again.", "style": "A"}, {"key": "f2rb0a", "text": "That makes ninety-six. Count my coins again.", "style": "A"}, {"key": "pt8ta9", "text": "That makes ninety-seven. Count my coins again.", "style": "A"}, {"key": "m5mhcj", "text": "That makes ninety-eight. Count my coins again.", "style": "A"}, {"key": "1gjrypo", "text": "That makes ninety-nine. Count my coins again.", "style": "A"}, {"key": "1soxv6m", "text": "That makes one hundred. Count my coins again.", "style": "A"}, {"key": "ppde3", "text": "That makes forty-one. I asked for fifty-six.", "style": "A"}, {"key": "yq7zjd", "text": "That makes forty-two. I asked for fifty-six.", "style": "A"}, {"key": "1wzslf", "text": "That makes forty-three. I asked for fifty-six.", "style": "A"}, {"key": "lcluyj", "text": "That makes forty-four. I asked for fifty-six.", "style": "A"}, {"key": "1yh3qg3", "text": "That makes forty-five. I asked for fifty-six.", "style": "A"}, {"key": "1g1feu3", "text": "That makes forty-six. I asked for fifty-six.", "style": "A"}, {"key": "bau45m", "text": "That makes forty-seven. I asked for fifty-six.", "style": "A"}, {"key": "nz091s", "text": "That makes forty-eight. I asked for fifty-six.", "style": "A"}, {"key": "19fg9ar", "text": "That makes forty-nine. I asked for fifty-six.", "style": "A"}, {"key": "1298sdk", "text": "That makes fifty. I asked for fifty-six.", "style": "A"}, {"key": "1fjfeyl", "text": "That makes fifty-one. I asked for fifty-six.", "style": "A"}, {"key": "1ukrbv", "text": "That makes fifty-two. I asked for fifty-six.", "style": "A"}, {"key": "19fjh1t", "text": "That makes fifty-three. I asked for fifty-six.", "style": "A"}, {"key": "am46hp", "text": "That makes fifty-four. I asked for fifty-six.", "style": "A"}, {"key": "vkwnkh", "text": "That makes fifty-five. I asked for fifty-six.", "style": "A"}, {"key": "1bon8w8", "text": "That makes fifty-seven. I asked for fifty-six.", "style": "A"}, {"key": "1gir9o6", "text": "That makes fifty-eight. I asked for fifty-six.", "style": "A"}, {"key": "kyo9i9", "text": "That makes fifty-nine. I asked for fifty-six.", "style": "A"}, {"key": "arwd81", "text": "That makes sixty. I asked for fifty-six.", "style": "A"}, {"key": "zqc6h4", "text": "That makes sixty-one. I asked for fifty-six.", "style": "A"}, {"key": "o5tyiy", "text": "That makes sixty-two. I asked for fifty-six.", "style": "A"}, {"key": "6kk9rc", "text": "That makes sixty-three. I asked for fifty-six.", "style": "A"}, {"key": "1ppq53q", "text": "That makes sixty-four. I asked for fifty-six.", "style": "A"}, {"key": "1wjx7x6", "text": "That makes sixty-five. I asked for fifty-six.", "style": "A"}, {"key": "iq8cio", "text": "That makes sixty-six. I asked for fifty-six.", "style": "A"}, {"key": "11gg4pd", "text": "That makes sixty-seven. I asked for fifty-six.", "style": "A"}, {"key": "4xa2sr", "text": "That makes sixty-eight. I asked for fifty-six.", "style": "A"}, {"key": "1g4tt3u", "text": "That makes sixty-nine. I asked for fifty-six.", "style": "A"}, {"key": "126veb0", "text": "That makes seventy. I asked for fifty-six.", "style": "A"}, {"key": "f9po5d", "text": "That makes seventy-one. I asked for fifty-six.", "style": "A"}, {"key": "16etjq1", "text": "That is sixteen, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "f7w9l1", "text": "That is sixteen, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "8fckin", "text": "That is sixteen, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "vvvzp6", "text": "That is sixteen, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "j63620", "text": "That is sixteen, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "zjcq7s", "text": "That is forty-five, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "118zmcg", "text": "That is forty-five, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "vjsft4", "text": "That is forty-five, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1of8r4t", "text": "That is forty-five, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "r0hof", "text": "That is forty-five, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "xzcr7i", "text": "That makes one. I asked for ten.", "style": "A"}, {"key": "2ozj1k", "text": "That makes two. I asked for ten.", "style": "A"}, {"key": "xegxju", "text": "That makes three. I asked for ten.", "style": "A"}, {"key": "gxtq8s", "text": "That makes four. I asked for ten.", "style": "A"}, {"key": "8qbu18", "text": "That makes five. I asked for ten.", "style": "A"}, {"key": "1y0lbmq", "text": "That makes six. I asked for ten.", "style": "A"}, {"key": "133s87n", "text": "That makes seven. I asked for ten.", "style": "A"}, {"key": "o6kml9", "text": "That makes eight. I asked for ten.", "style": "A"}, {"key": "1kilb8s", "text": "That makes nine. I asked for ten.", "style": "A"}, {"key": "d2gp2l", "text": "That makes eleven. I asked for ten.", "style": "A"}, {"key": "zlq71l", "text": "That makes twelve. I asked for ten.", "style": "A"}, {"key": "11993kb", "text": "That makes thirteen. I asked for ten.", "style": "A"}, {"key": "1rwlof4", "text": "That makes fourteen. I asked for ten.", "style": "A"}, {"key": "utwxvb", "text": "That makes fifteen. I asked for ten.", "style": "A"}, {"key": "1w49xs2", "text": "That makes sixteen. I asked for ten.", "style": "A"}, {"key": "1pcfk57", "text": "That makes seventeen. I asked for ten.", "style": "A"}, {"key": "1awfuu5", "text": "That makes eighteen. I asked for ten.", "style": "A"}, {"key": "n8d4pc", "text": "That makes nineteen. I asked for ten.", "style": "A"}, {"key": "twkovp", "text": "That makes twenty. I asked for ten.", "style": "A"}, {"key": "1ncmmbo", "text": "That makes twenty-one. I asked for ten.", "style": "A"}, {"key": "jeg8ae", "text": "That makes twenty-two. I asked for ten.", "style": "A"}, {"key": "t0pi8k", "text": "That makes twenty-three. I asked for ten.", "style": "A"}, {"key": "k2cjg2", "text": "That makes twenty-four. I asked for ten.", "style": "A"}, {"key": "64hgq6", "text": "That makes twenty-five. I asked for ten.", "style": "A"}, {"key": "15g34vs", "text": "That makes sixty-one. I asked for seventy-six.", "style": "A"}, {"key": "1v1jznq", "text": "That makes sixty-two. I asked for seventy-six.", "style": "A"}, {"key": "1s8q1aw", "text": "That makes sixty-three. I asked for seventy-six.", "style": "A"}, {"key": "1nj7kaa", "text": "That makes sixty-four. I asked for seventy-six.", "style": "A"}, {"key": "w5pweu", "text": "That makes sixty-five. I asked for seventy-six.", "style": "A"}, {"key": "slfb2o", "text": "That makes sixty-six. I asked for seventy-six.", "style": "A"}, {"key": "1lzst9x", "text": "That makes sixty-seven. I asked for seventy-six.", "style": "A"}, {"key": "1d7cajv", "text": "That makes sixty-eight. I asked for seventy-six.", "style": "A"}, {"key": "1gb0n86", "text": "That makes sixty-nine. I asked for seventy-six.", "style": "A"}, {"key": "ew36qk", "text": "That makes seventy. I asked for seventy-six.", "style": "A"}, {"key": "hhxmud", "text": "That makes seventy-one. I asked for seventy-six.", "style": "A"}, {"key": "y9w78f", "text": "That makes seventy-two. I asked for seventy-six.", "style": "A"}, {"key": "fa6oft", "text": "That makes seventy-three. I asked for seventy-six.", "style": "A"}, {"key": "cberv1", "text": "That makes seventy-four. I asked for seventy-six.", "style": "A"}, {"key": "gt3kfl", "text": "That makes seventy-five. I asked for seventy-six.", "style": "A"}, {"key": "s6pf8", "text": "That makes seventy-seven. I asked for seventy-six.", "style": "A"}, {"key": "a3lguu", "text": "That makes seventy-eight. I asked for seventy-six.", "style": "A"}, {"key": "1r5oak1", "text": "That makes seventy-nine. I asked for seventy-six.", "style": "A"}, {"key": "ys12g6", "text": "That makes eighty. I asked for seventy-six.", "style": "A"}, {"key": "4wzxqv", "text": "That makes eighty-one. I asked for seventy-six.", "style": "A"}, {"key": "1d1sya1", "text": "That makes eighty-two. I asked for seventy-six.", "style": "A"}, {"key": "1b8hi7z", "text": "That makes eighty-three. I asked for seventy-six.", "style": "A"}, {"key": "1r78yv3", "text": "That makes eighty-four. I asked for seventy-six.", "style": "A"}, {"key": "1xddsef", "text": "That makes eighty-five. I asked for seventy-six.", "style": "A"}, {"key": "156hb0v", "text": "That makes eighty-six. I asked for seventy-six.", "style": "A"}, {"key": "hz37wq", "text": "That makes eighty-seven. I asked for seventy-six.", "style": "A"}, {"key": "1l4768s", "text": "That makes eighty-eight. I asked for seventy-six.", "style": "A"}, {"key": "w0jo9j", "text": "That makes eighty-nine. I asked for seventy-six.", "style": "A"}, {"key": "9nglzv", "text": "That makes ninety. I asked for seventy-six.", "style": "A"}, {"key": "7gg2ji", "text": "That makes ninety-one. I asked for seventy-six.", "style": "A"}, {"key": "1mzlmqu", "text": "That makes twenty-six. I asked for forty-one.", "style": "A"}, {"key": "r94t4b", "text": "That makes twenty-seven. I asked for forty-one.", "style": "A"}, {"key": "1wnjn9p", "text": "That makes twenty-eight. I asked for forty-one.", "style": "A"}, {"key": "5ekqds", "text": "That makes twenty-nine. I asked for forty-one.", "style": "A"}, {"key": "1y4n6zi", "text": "That makes thirty. I asked for forty-one.", "style": "A"}, {"key": "t8dx9b", "text": "That makes thirty-one. I asked for forty-one.", "style": "A"}, {"key": "1pq1x9x", "text": "That makes thirty-two. I asked for forty-one.", "style": "A"}, {"key": "opvta3", "text": "That makes thirty-three. I asked for forty-one.", "style": "A"}, {"key": "1nfh3ev", "text": "That makes thirty-four. I asked for forty-one.", "style": "A"}, {"key": "1ku61f7", "text": "That makes thirty-five. I asked for forty-one.", "style": "A"}, {"key": "12uk42z", "text": "That makes thirty-six. I asked for forty-one.", "style": "A"}, {"key": "mg8uxi", "text": "That makes thirty-seven. I asked for forty-one.", "style": "A"}, {"key": "1gtcr3o", "text": "That makes thirty-eight. I asked for forty-one.", "style": "A"}, {"key": "1lk76qb", "text": "That makes thirty-nine. I asked for forty-one.", "style": "A"}, {"key": "18mu4s0", "text": "That makes forty. I asked for forty-one.", "style": "A"}, {"key": "1w66hpz", "text": "That makes forty-two. I asked for forty-one.", "style": "A"}, {"key": "11vzsch", "text": "That makes forty-three. I asked for forty-one.", "style": "A"}, {"key": "6adtzt", "text": "That makes forty-four. I asked for forty-one.", "style": "A"}, {"key": "16lqzc1", "text": "That makes forty-five. I asked for forty-one.", "style": "A"}, {"key": "69tp15", "text": "That makes forty-six. I asked for forty-one.", "style": "A"}, {"key": "3pai5w", "text": "That makes forty-seven. I asked for forty-one.", "style": "A"}, {"key": "yusxmy", "text": "That makes forty-eight. I asked for forty-one.", "style": "A"}, {"key": "j2g9yp", "text": "That makes forty-nine. I asked for forty-one.", "style": "A"}, {"key": "o22igy", "text": "That makes fifty. I asked for forty-one.", "style": "A"}, {"key": "jhyo2r", "text": "That makes fifty-one. I asked for forty-one.", "style": "A"}, {"key": "r433i1", "text": "That makes fifty-two. I asked for forty-one.", "style": "A"}, {"key": "aac5zz", "text": "That makes fifty-three. I asked for forty-one.", "style": "A"}, {"key": "16f06gz", "text": "That makes fifty-four. I asked for forty-one.", "style": "A"}, {"key": "fqdnz3", "text": "That makes fifty-five. I asked for forty-one.", "style": "A"}, {"key": "mnhttz", "text": "That makes fifty-six. I asked for forty-one.", "style": "A"}, {"key": "c3kdej", "text": "That makes sixty-seven. Count my coins again.", "style": "A"}, {"key": "zsp0dx", "text": "That makes sixty-eight. Count my coins again.", "style": "A"}, {"key": "13fj5gu", "text": "That makes sixty-nine. Count my coins again.", "style": "A"}, {"key": "6o22bj", "text": "That is sixty-one, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "187a7zx", "text": "That is sixty-one, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "9iw4nq", "text": "That is sixty-one, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "8bdhg0", "text": "That is sixty-one, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1j513cl", "text": "That makes sixty-two. I asked for seventy-seven.", "style": "A"}, {"key": "1ghy8fr", "text": "That makes sixty-three. I asked for seventy-seven.", "style": "A"}, {"key": "b8br69", "text": "That makes sixty-four. I asked for seventy-seven.", "style": "A"}, {"key": "hi3091", "text": "That makes sixty-five. I asked for seventy-seven.", "style": "A"}, {"key": "akr8yn", "text": "That makes sixty-six. I asked for seventy-seven.", "style": "A"}, {"key": "p72ph2", "text": "That makes sixty-seven. I asked for seventy-seven.", "style": "A"}, {"key": "zx76gc", "text": "That makes sixty-eight. I asked for seventy-seven.", "style": "A"}, {"key": "6ian9h", "text": "That makes sixty-nine. I asked for seventy-seven.", "style": "A"}, {"key": "1bbni3f", "text": "That makes seventy. I asked for seventy-seven.", "style": "A"}, {"key": "ftjm92", "text": "That makes seventy-one. I asked for seventy-seven.", "style": "A"}, {"key": "atn44w", "text": "That makes seventy-two. I asked for seventy-seven.", "style": "A"}, {"key": "1yrxd7e", "text": "That makes seventy-three. I asked for seventy-seven.", "style": "A"}, {"key": "11d4yfy", "text": "That makes seventy-four. I asked for seventy-seven.", "style": "A"}, {"key": "wfzco2", "text": "That makes seventy-five. I asked for seventy-seven.", "style": "A"}, {"key": "p94nje", "text": "That makes seventy-six. I asked for seventy-seven.", "style": "A"}, {"key": "16n7ozp", "text": "That makes seventy-eight. I asked for seventy-seven.", "style": "A"}, {"key": "ciz6zm", "text": "That makes seventy-nine. I asked for seventy-seven.", "style": "A"}, {"key": "1ht5atx", "text": "That makes eighty. I asked for seventy-seven.", "style": "A"}, {"key": "7zipk", "text": "That makes eighty-one. I asked for seventy-seven.", "style": "A"}, {"key": "6ah4mi", "text": "That makes eighty-two. I asked for seventy-seven.", "style": "A"}, {"key": "199ipw0", "text": "That makes eighty-three. I asked for seventy-seven.", "style": "A"}, {"key": "or0ntc", "text": "That makes eighty-four. I asked for seventy-seven.", "style": "A"}, {"key": "q1nvvs", "text": "That makes eighty-five. I asked for seventy-seven.", "style": "A"}, {"key": "p13z8g", "text": "That makes eighty-six. I asked for seventy-seven.", "style": "A"}, {"key": "tm3t5l", "text": "That makes eighty-seven. I asked for seventy-seven.", "style": "A"}, {"key": "1tuq7yz", "text": "That makes eighty-eight. I asked for seventy-seven.", "style": "A"}, {"key": "1ao9gmw", "text": "That makes eighty-nine. I asked for seventy-seven.", "style": "A"}, {"key": "1w5kmfw", "text": "That makes ninety. I asked for seventy-seven.", "style": "A"}, {"key": "1nndo71", "text": "That makes ninety-one. I asked for seventy-seven.", "style": "A"}, {"key": "1ug42r7", "text": "That makes ninety-two. I asked for seventy-seven.", "style": "A"}, {"key": "rs56qk", "text": "That makes seven. I asked for twenty-two.", "style": "A"}, {"key": "1nz4r7i", "text": "That makes eight. I asked for twenty-two.", "style": "A"}, {"key": "whlhnt", "text": "That makes nine. I asked for twenty-two.", "style": "A"}, {"key": "p92vaq", "text": "That makes ten. I asked for twenty-two.", "style": "A"}, {"key": "13jh6by", "text": "That makes eleven. I asked for twenty-two.", "style": "A"}, {"key": "3bigoi", "text": "That makes twelve. I asked for twenty-two.", "style": "A"}, {"key": "i9po0k", "text": "That makes thirteen. I asked for twenty-two.", "style": "A"}, {"key": "1gnyfp1", "text": "That makes fourteen. I asked for twenty-two.", "style": "A"}, {"key": "gneriw", "text": "That makes fifteen. I asked for twenty-two.", "style": "A"}, {"key": "1k4gfdj", "text": "That makes sixteen. I asked for twenty-two.", "style": "A"}, {"key": "1oo7whw", "text": "That makes seventeen. I asked for twenty-two.", "style": "A"}, {"key": "arl5q6", "text": "That makes eighteen. I asked for twenty-two.", "style": "A"}, {"key": "66v1t1", "text": "That makes nineteen. I asked for twenty-two.", "style": "A"}, {"key": "mgj1x2", "text": "That makes twenty. I asked for twenty-two.", "style": "A"}, {"key": "no2s8x", "text": "That makes twenty-one. I asked for twenty-two.", "style": "A"}, {"key": "1oq4dg1", "text": "That makes twenty-three. I asked for twenty-two.", "style": "A"}, {"key": "zcwwhz", "text": "That makes twenty-four. I asked for twenty-two.", "style": "A"}, {"key": "zvycej", "text": "That makes twenty-five. I asked for twenty-two.", "style": "A"}, {"key": "eys2i9", "text": "That makes twenty-six. I asked for twenty-two.", "style": "A"}, {"key": "irrtse", "text": "That makes twenty-seven. I asked for twenty-two.", "style": "A"}, {"key": "d3k3pk", "text": "That makes twenty-eight. I asked for twenty-two.", "style": "A"}, {"key": "1pifeez", "text": "That makes twenty-nine. I asked for twenty-two.", "style": "A"}, {"key": "e4cuvd", "text": "That makes thirty. I asked for twenty-two.", "style": "A"}, {"key": "1kix8fu", "text": "That makes thirty-one. I asked for twenty-two.", "style": "A"}, {"key": "5uldkg", "text": "That makes thirty-two. I asked for twenty-two.", "style": "A"}, {"key": "1cm47ry", "text": "That makes thirty-three. I asked for twenty-two.", "style": "A"}, {"key": "w8lov6", "text": "That makes thirty-four. I asked for twenty-two.", "style": "A"}, {"key": "w95lo6", "text": "That makes thirty-five. I asked for twenty-two.", "style": "A"}, {"key": "10p58lq", "text": "That makes thirty-six. I asked for twenty-two.", "style": "A"}, {"key": "4g8yld", "text": "That makes thirty-seven. I asked for twenty-two.", "style": "A"}, {"key": "1kujc28", "text": "That makes eleven. I asked for twenty-six.", "style": "A"}, {"key": "rgbaq4", "text": "That makes twelve. I asked for twenty-six.", "style": "A"}, {"key": "pdt4l6", "text": "That makes thirteen. I asked for twenty-six.", "style": "A"}, {"key": "m3vd3j", "text": "That makes fourteen. I asked for twenty-six.", "style": "A"}, {"key": "o0o4ie", "text": "That makes fifteen. I asked for twenty-six.", "style": "A"}, {"key": "lj9y71", "text": "That makes sixteen. I asked for twenty-six.", "style": "A"}, {"key": "1nizdpm", "text": "That makes seventeen. I asked for twenty-six.", "style": "A"}, {"key": "16nxri8", "text": "That makes eighteen. I asked for twenty-six.", "style": "A"}, {"key": "19f9nb3", "text": "That makes nineteen. I asked for twenty-six.", "style": "A"}, {"key": "1h3d360", "text": "That makes twenty. I asked for twenty-six.", "style": "A"}, {"key": "1ye3077", "text": "That makes twenty-one. I asked for twenty-six.", "style": "A"}, {"key": "wbr7mp", "text": "That makes twenty-two. I asked for twenty-six.", "style": "A"}, {"key": "18ocis3", "text": "That makes twenty-three. I asked for twenty-six.", "style": "A"}, {"key": "svwdxp", "text": "That makes twenty-four. I asked for twenty-six.", "style": "A"}, {"key": "198qxs9", "text": "That makes twenty-five. I asked for twenty-six.", "style": "A"}, {"key": "16esg7k", "text": "That makes twenty-seven. I asked for twenty-six.", "style": "A"}, {"key": "asp79i", "text": "That makes twenty-eight. I asked for twenty-six.", "style": "A"}, {"key": "1pd9erd", "text": "That makes twenty-nine. I asked for twenty-six.", "style": "A"}, {"key": "1j361vf", "text": "That makes thirty. I asked for twenty-six.", "style": "A"}, {"key": "1lrjrz8", "text": "That makes thirty-one. I asked for twenty-six.", "style": "A"}, {"key": "p4ubzy", "text": "That makes thirty-two. I asked for twenty-six.", "style": "A"}, {"key": "2gn63k", "text": "That makes thirty-three. I asked for twenty-six.", "style": "A"}, {"key": "crparg", "text": "That makes thirty-four. I asked for twenty-six.", "style": "A"}, {"key": "1qvzmx4", "text": "That makes thirty-five. I asked for twenty-six.", "style": "A"}, {"key": "1i07ec0", "text": "That makes thirty-six. I asked for twenty-six.", "style": "A"}, {"key": "1ehi1r7", "text": "That makes thirty-seven. I asked for twenty-six.", "style": "A"}, {"key": "mv5nlp", "text": "That makes thirty-eight. I asked for twenty-six.", "style": "A"}, {"key": "ssy2co", "text": "That makes thirty-nine. I asked for twenty-six.", "style": "A"}, {"key": "1ng68p", "text": "That makes forty. I asked for twenty-six.", "style": "A"}, {"key": "cvyzfm", "text": "That makes forty-one. I asked for twenty-six.", "style": "A"}, {"key": "r0qs9d", "text": "That is thirty, but with three coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "kndol3", "text": "That is thirty, but with four coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1nn3otf", "text": "That is thirty, but with five coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1t88jl5", "text": "That is thirty, but with six coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1e98mi8", "text": "That is thirty, but with seven coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "bnlepe", "text": "That is thirty, but with eight coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "9u7d7t", "text": "That is twenty-one, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "2f8i0l", "text": "That is twenty-one, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "ja3gb3", "text": "That is twenty-one, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1iq81re", "text": "That is twenty-one, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "wcimyg", "text": "That is twenty-one, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1pt2tgw", "text": "That makes twenty-one. I asked for thirty-six.", "style": "A"}, {"key": "qoxgsy", "text": "That makes twenty-two. I asked for thirty-six.", "style": "A"}, {"key": "14ji8lc", "text": "That makes twenty-three. I asked for thirty-six.", "style": "A"}, {"key": "1cafq1i", "text": "That makes twenty-four. I asked for thirty-six.", "style": "A"}, {"key": "1wgzjoq", "text": "That makes twenty-five. I asked for thirty-six.", "style": "A"}, {"key": "15zhyu8", "text": "That makes twenty-six. I asked for thirty-six.", "style": "A"}, {"key": "qnbeij", "text": "That makes twenty-seven. I asked for thirty-six.", "style": "A"}, {"key": "1n4ohod", "text": "That makes twenty-eight. I asked for thirty-six.", "style": "A"}, {"key": "10qmlne", "text": "That makes twenty-nine. I asked for thirty-six.", "style": "A"}, {"key": "51rj08", "text": "That makes thirty. I asked for thirty-six.", "style": "A"}, {"key": "17ucukn", "text": "That makes thirty-one. I asked for thirty-six.", "style": "A"}, {"key": "6hee9x", "text": "That makes thirty-two. I asked for thirty-six.", "style": "A"}, {"key": "1in44qz", "text": "That makes thirty-three. I asked for thirty-six.", "style": "A"}, {"key": "1ozj55b", "text": "That makes thirty-four. I asked for thirty-six.", "style": "A"}, {"key": "pu5q0z", "text": "That makes thirty-five. I asked for thirty-six.", "style": "A"}, {"key": "33uvrk", "text": "That makes thirty-seven. I asked for thirty-six.", "style": "A"}, {"key": "15pcm9y", "text": "That makes thirty-eight. I asked for thirty-six.", "style": "A"}, {"key": "17yrhgj", "text": "That makes thirty-nine. I asked for thirty-six.", "style": "A"}, {"key": "lw6qpm", "text": "That makes forty. I asked for thirty-six.", "style": "A"}, {"key": "10n8jjl", "text": "That makes forty-one. I asked for thirty-six.", "style": "A"}, {"key": "cmk4hr", "text": "That makes forty-two. I asked for thirty-six.", "style": "A"}, {"key": "8qwi4p", "text": "That makes forty-three. I asked for thirty-six.", "style": "A"}, {"key": "1rro3k1", "text": "That makes forty-four. I asked for thirty-six.", "style": "A"}, {"key": "8b0vs9", "text": "That makes forty-five. I asked for thirty-six.", "style": "A"}, {"key": "yxeew1", "text": "That makes forty-six. I asked for thirty-six.", "style": "A"}, {"key": "c6t9fq", "text": "That makes forty-seven. I asked for thirty-six.", "style": "A"}, {"key": "1a83a4s", "text": "That makes forty-eight. I asked for thirty-six.", "style": "A"}, {"key": "1tuxdyx", "text": "That makes forty-nine. I asked for thirty-six.", "style": "A"}, {"key": "ofgv8k", "text": "That makes fifty. I asked for thirty-six.", "style": "A"}, {"key": "1fvklir", "text": "That makes fifty-one. I asked for thirty-six.", "style": "A"}, {"key": "1bmwvvo", "text": "That is fifty-one, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1exyq18", "text": "That is fifty-one, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "866rz8", "text": "That is fifty-one, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "ffo6yx", "text": "That is fifty-one, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "n4weqb", "text": "That is fifty-one, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "t8szs8", "text": "That is eleven, but with three coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1riadrg", "text": "That is eleven, but with four coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "odeuhk", "text": "That is eleven, but with five coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1yytaqo", "text": "That is eleven, but with six coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "18f3409", "text": "That is eleven, but with seven coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "gc32vz", "text": "That is eleven, but with eight coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "qeuzyi", "text": "That is fifty-six, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "12m8llu", "text": "That is fifty-six, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "6g40ux", "text": "That is fifty-six, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "5n76pj", "text": "That is fifty-six, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1nu2sa5", "text": "That makes thirty-six. I asked for fifty-one.", "style": "A"}, {"key": "5v76kc", "text": "That makes thirty-seven. I asked for fifty-one.", "style": "A"}, {"key": "5svj92", "text": "That makes thirty-eight. I asked for fifty-one.", "style": "A"}, {"key": "5mku2d", "text": "That makes thirty-nine. I asked for fifty-one.", "style": "A"}, {"key": "1axsqs2", "text": "That makes forty. I asked for fifty-one.", "style": "A"}, {"key": "1dfq8vr", "text": "That makes forty-one. I asked for fifty-one.", "style": "A"}, {"key": "oxcp4p", "text": "That makes forty-two. I asked for fifty-one.", "style": "A"}, {"key": "5qxin", "text": "That makes forty-three. I asked for fifty-one.", "style": "A"}, {"key": "1ia2ip3", "text": "That makes forty-four. I asked for fifty-one.", "style": "A"}, {"key": "xw0vdb", "text": "That makes forty-five. I asked for fifty-one.", "style": "A"}, {"key": "1crm0lj", "text": "That makes forty-six. I asked for fifty-one.", "style": "A"}, {"key": "1ljlyly", "text": "That makes forty-seven. I asked for fifty-one.", "style": "A"}, {"key": "2lpjz4", "text": "That makes forty-eight. I asked for fifty-one.", "style": "A"}, {"key": "1rhorb3", "text": "That makes forty-nine. I asked for fifty-one.", "style": "A"}, {"key": "aph7q0", "text": "That makes fifty. I asked for fifty-one.", "style": "A"}, {"key": "1xlvf2f", "text": "That makes fifty-two. I asked for fifty-one.", "style": "A"}, {"key": "1uexc3l", "text": "That makes fifty-three. I asked for fifty-one.", "style": "A"}, {"key": "n7myyt", "text": "That makes fifty-four. I asked for fifty-one.", "style": "A"}, {"key": "1gkaim9", "text": "That makes fifty-five. I asked for fifty-one.", "style": "A"}, {"key": "12x3rl5", "text": "That makes fifty-six. I asked for fifty-one.", "style": "A"}, {"key": "1cmr7js", "text": "That makes fifty-seven. I asked for fifty-one.", "style": "A"}, {"key": "14t1196", "text": "That makes fifty-eight. I asked for fifty-one.", "style": "A"}, {"key": "h4pci9", "text": "That makes fifty-nine. I asked for fifty-one.", "style": "A"}, {"key": "vra89t", "text": "That makes sixty. I asked for fifty-one.", "style": "A"}, {"key": "10og54o", "text": "That makes sixty-one. I asked for fifty-one.", "style": "A"}, {"key": "1yelsza", "text": "That makes sixty-two. I asked for fifty-one.", "style": "A"}, {"key": "17175lk", "text": "That makes sixty-three. I asked for fifty-one.", "style": "A"}, {"key": "1dzzwoq", "text": "That makes sixty-four. I asked for fifty-one.", "style": "A"}, {"key": "1pe0ayu", "text": "That makes sixty-five. I asked for fifty-one.", "style": "A"}, {"key": "ealt80", "text": "That makes sixty-six. I asked for fifty-one.", "style": "A"}, {"key": "grc9wu", "text": "That is fifty-five, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1pkgiju", "text": "That is fifty-five, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1p2qkf6", "text": "That is fifty-five, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "17ex23r", "text": "That is fifty-five, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "m27zl", "text": "That is fifty-five, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1ee1pwt", "text": "That makes fifty. I asked for sixty-five.", "style": "A"}, {"key": "1nub8z2", "text": "That makes fifty-one. I asked for sixty-five.", "style": "A"}, {"key": "f6o6ds", "text": "That makes fifty-two. I asked for sixty-five.", "style": "A"}, {"key": "x7wrxe", "text": "That makes fifty-three. I asked for sixty-five.", "style": "A"}, {"key": "bg5xxq", "text": "That makes fifty-four. I asked for sixty-five.", "style": "A"}, {"key": "1onav8i", "text": "That makes fifty-five. I asked for sixty-five.", "style": "A"}, {"key": "1fowni2", "text": "That makes fifty-six. I asked for sixty-five.", "style": "A"}, {"key": "1iv2d8t", "text": "That makes fifty-seven. I asked for sixty-five.", "style": "A"}, {"key": "1557d3r", "text": "That makes fifty-eight. I asked for sixty-five.", "style": "A"}, {"key": "1bafxf6", "text": "That makes fifty-nine. I asked for sixty-five.", "style": "A"}, {"key": "17ww8n6", "text": "That makes sixty. I asked for sixty-five.", "style": "A"}, {"key": "1vwu0el", "text": "That makes sixty-one. I asked for sixty-five.", "style": "A"}, {"key": "10assyj", "text": "That makes sixty-two. I asked for sixty-five.", "style": "A"}, {"key": "1uug7cd", "text": "That makes sixty-three. I asked for sixty-five.", "style": "A"}, {"key": "1rijt13", "text": "That makes sixty-four. I asked for sixty-five.", "style": "A"}, {"key": "1ftht85", "text": "That makes sixty-six. I asked for sixty-five.", "style": "A"}, {"key": "1d71usi", "text": "That makes sixty-seven. I asked for sixty-five.", "style": "A"}, {"key": "8szw80", "text": "That makes sixty-eight. I asked for sixty-five.", "style": "A"}, {"key": "1trzv57", "text": "That makes sixty-nine. I asked for sixty-five.", "style": "A"}, {"key": "vmpb41", "text": "That makes seventy. I asked for sixty-five.", "style": "A"}, {"key": "u7gx1u", "text": "That makes seventy-one. I asked for sixty-five.", "style": "A"}, {"key": "1d2vuuc", "text": "That makes seventy-two. I asked for sixty-five.", "style": "A"}, {"key": "u7jg06", "text": "That makes seventy-three. I asked for sixty-five.", "style": "A"}, {"key": "1z0wqfe", "text": "That makes seventy-four. I asked for sixty-five.", "style": "A"}, {"key": "1s4nm4u", "text": "That makes seventy-five. I asked for sixty-five.", "style": "A"}, {"key": "1x6twgm", "text": "That makes seventy-six. I asked for sixty-five.", "style": "A"}, {"key": "1i8bhih", "text": "That makes seventy-seven. I asked for sixty-five.", "style": "A"}, {"key": "tw5gtn", "text": "That makes seventy-eight. I asked for sixty-five.", "style": "A"}, {"key": "7uw6q6", "text": "That makes seventy-nine. I asked for sixty-five.", "style": "A"}, {"key": "12q2qnv", "text": "That makes eighty. I asked for sixty-five.", "style": "A"}, {"key": "1v2b4gj", "text": "That makes twenty-five. I asked for forty.", "style": "A"}, {"key": "xw91f5", "text": "That makes twenty-six. I asked for forty.", "style": "A"}, {"key": "d7pr10", "text": "That makes twenty-seven. I asked for forty.", "style": "A"}, {"key": "s2b8xy", "text": "That makes twenty-eight. I asked for forty.", "style": "A"}, {"key": "1i34a83", "text": "That makes twenty-nine. I asked for forty.", "style": "A"}, {"key": "1hty1eh", "text": "That makes thirty. I asked for forty.", "style": "A"}, {"key": "i4aprc", "text": "That makes thirty-one. I asked for forty.", "style": "A"}, {"key": "15tu4m6", "text": "That makes thirty-two. I asked for forty.", "style": "A"}, {"key": "k3r55w", "text": "That makes thirty-three. I asked for forty.", "style": "A"}, {"key": "1pv258g", "text": "That makes thirty-four. I asked for forty.", "style": "A"}, {"key": "s7w6i4", "text": "That makes thirty-five. I asked for forty.", "style": "A"}, {"key": "r7qh1w", "text": "That makes thirty-six. I asked for forty.", "style": "A"}, {"key": "15by9pd", "text": "That makes thirty-seven. I asked for forty.", "style": "A"}, {"key": "nyjkdz", "text": "That makes thirty-eight. I asked for forty.", "style": "A"}, {"key": "1hb0zrg", "text": "That makes thirty-nine. I asked for forty.", "style": "A"}, {"key": "18j3uf6", "text": "That makes forty-one. I asked for forty.", "style": "A"}, {"key": "1m13kmo", "text": "That makes forty-two. I asked for forty.", "style": "A"}, {"key": "1tie0kq", "text": "That makes forty-three. I asked for forty.", "style": "A"}, {"key": "199heqa", "text": "That makes forty-four. I asked for forty.", "style": "A"}, {"key": "9w9bt6", "text": "That makes forty-five. I asked for forty.", "style": "A"}, {"key": "1omznsi", "text": "That makes forty-six. I asked for forty.", "style": "A"}, {"key": "lmnd87", "text": "That makes forty-seven. I asked for forty.", "style": "A"}, {"key": "1v9amb9", "text": "That makes forty-eight. I asked for forty.", "style": "A"}, {"key": "1f1sy8q", "text": "That makes forty-nine. I asked for forty.", "style": "A"}, {"key": "85zu8t", "text": "That makes fifty. I asked for forty.", "style": "A"}, {"key": "1alsckc", "text": "That makes fifty-one. I asked for forty.", "style": "A"}, {"key": "mujt82", "text": "That makes fifty-two. I asked for forty.", "style": "A"}, {"key": "11x15bc", "text": "That makes fifty-three. I asked for forty.", "style": "A"}, {"key": "1xs8br0", "text": "That makes fifty-four. I asked for forty.", "style": "A"}, {"key": "iruei0", "text": "That makes fifty-five. I asked for forty.", "style": "A"}, {"key": "cqv61h", "text": "That is forty, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "9y6rw1", "text": "That is forty, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "8ywgvv", "text": "That is forty, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "lzdgli", "text": "That is forty, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "et0nws", "text": "That is forty, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "10jgz3m", "text": "That makes seventy. I asked for eighty-five.", "style": "A"}, {"key": "u38ebv", "text": "That makes seventy-one. I asked for eighty-five.", "style": "A"}, {"key": "16ckpp5", "text": "That makes seventy-two. I asked for eighty-five.", "style": "A"}, {"key": "cchptz", "text": "That makes seventy-three. I asked for eighty-five.", "style": "A"}, {"key": "aj3usz", "text": "That makes seventy-four. I asked for eighty-five.", "style": "A"}, {"key": "13ojunz", "text": "That makes seventy-five. I asked for eighty-five.", "style": "A"}, {"key": "1fa80qf", "text": "That makes seventy-six. I asked for eighty-five.", "style": "A"}, {"key": "10n1vsa", "text": "That makes seventy-seven. I asked for eighty-five.", "style": "A"}, {"key": "15ial7k", "text": "That makes seventy-eight. I asked for eighty-five.", "style": "A"}, {"key": "bmap8f", "text": "That makes seventy-nine. I asked for eighty-five.", "style": "A"}, {"key": "1289x8w", "text": "That makes eighty. I asked for eighty-five.", "style": "A"}, {"key": "1tac4pd", "text": "That makes eighty-one. I asked for eighty-five.", "style": "A"}, {"key": "mdwmd3", "text": "That makes eighty-two. I asked for eighty-five.", "style": "A"}, {"key": "1hnlud5", "text": "That makes eighty-three. I asked for eighty-five.", "style": "A"}, {"key": "1xmdb09", "text": "That makes eighty-four. I asked for eighty-five.", "style": "A"}, {"key": "a0bz55", "text": "That makes eighty-six. I asked for eighty-five.", "style": "A"}, {"key": "13dt3xo", "text": "That makes eighty-seven. I asked for eighty-five.", "style": "A"}, {"key": "7qgwmq", "text": "That makes eighty-eight. I asked for eighty-five.", "style": "A"}, {"key": "lcrt8x", "text": "That makes eighty-nine. I asked for eighty-five.", "style": "A"}, {"key": "1yqeknx", "text": "That makes ninety. I asked for eighty-five.", "style": "A"}, {"key": "pnnt6w", "text": "That makes ninety-one. I asked for eighty-five.", "style": "A"}, {"key": "1sd5knu", "text": "That makes ninety-two. I asked for eighty-five.", "style": "A"}, {"key": "uqx0j8", "text": "That makes ninety-three. I asked for eighty-five.", "style": "A"}, {"key": "1rqq4ee", "text": "That makes ninety-four. I asked for eighty-five.", "style": "A"}, {"key": "1db8n12", "text": "That makes ninety-five. I asked for eighty-five.", "style": "A"}, {"key": "fwjszo", "text": "That makes ninety-six. I asked for eighty-five.", "style": "A"}, {"key": "182i0tt", "text": "That makes ninety-seven. I asked for eighty-five.", "style": "A"}, {"key": "1iis4sz", "text": "That makes ninety-eight. I asked for eighty-five.", "style": "A"}, {"key": "1ak00s6", "text": "That makes ninety-nine. I asked for eighty-five.", "style": "A"}, {"key": "l40yxc", "text": "That makes one hundred. I asked for eighty-five.", "style": "A"}, {"key": "owtfy8", "text": "That is eighty-five, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "e3kbu0", "text": "That is eighty-five, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1ojsya7", "text": "That is eighty-five, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1n1jk5h", "text": "That is eighty-five, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1ec4fry", "text": "That is thirty-five, but with three coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "2e1i4e", "text": "That is thirty-five, but with four coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1elek1y", "text": "That is thirty-five, but with five coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1lnu6vi", "text": "That is thirty-five, but with six coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1fb237j", "text": "That is thirty-five, but with seven coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "130b9d9", "text": "That is thirty-five, but with eight coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1wa1jtv", "text": "That makes forty-five. I asked for sixty.", "style": "A"}, {"key": "11626e3", "text": "That makes forty-six. I asked for sixty.", "style": "A"}, {"key": "h3p5oa", "text": "That makes forty-seven. I asked for sixty.", "style": "A"}, {"key": "2kv51k", "text": "That makes forty-eight. I asked for sixty.", "style": "A"}, {"key": "1b3v32r", "text": "That makes forty-nine. I asked for sixty.", "style": "A"}, {"key": "wb8c1s", "text": "That makes fifty. I asked for sixty.", "style": "A"}, {"key": "9c0mh1", "text": "That makes fifty-one. I asked for sixty.", "style": "A"}, {"key": "1yeqdsr", "text": "That makes fifty-two. I asked for sixty.", "style": "A"}, {"key": "6m2zu9", "text": "That makes fifty-three. I asked for sixty.", "style": "A"}, {"key": "1kfu59h", "text": "That makes fifty-four. I asked for sixty.", "style": "A"}, {"key": "1a81l0x", "text": "That makes fifty-five. I asked for sixty.", "style": "A"}, {"key": "1yfbfcp", "text": "That makes fifty-six. I asked for sixty.", "style": "A"}, {"key": "tqp9k0", "text": "That makes fifty-seven. I asked for sixty.", "style": "A"}, {"key": "zjdslq", "text": "That makes fifty-eight. I asked for sixty.", "style": "A"}, {"key": "s0la81", "text": "That makes fifty-nine. I asked for sixty.", "style": "A"}, {"key": "1y0f15s", "text": "That makes sixty-one. I asked for sixty.", "style": "A"}, {"key": "wft18a", "text": "That makes sixty-two. I asked for sixty.", "style": "A"}, {"key": "1d8f48w", "text": "That makes sixty-three. I asked for sixty.", "style": "A"}, {"key": "12u9m6", "text": "That makes sixty-four. I asked for sixty.", "style": "A"}, {"key": "1aebtu2", "text": "That makes sixty-five. I asked for sixty.", "style": "A"}, {"key": "1wslco", "text": "That makes sixty-six. I asked for sixty.", "style": "A"}, {"key": "1eba4oh", "text": "That makes sixty-seven. I asked for sixty.", "style": "A"}, {"key": "1k5jyqz", "text": "That makes sixty-eight. I asked for sixty.", "style": "A"}, {"key": "1dv30qy", "text": "That makes sixty-nine. I asked for sixty.", "style": "A"}, {"key": "l89vvw", "text": "That makes seventy. I asked for sixty.", "style": "A"}, {"key": "4arba9", "text": "That makes seventy-one. I asked for sixty.", "style": "A"}, {"key": "3lc307", "text": "That makes seventy-two. I asked for sixty.", "style": "A"}, {"key": "1x3p6q5", "text": "That makes seventy-three. I asked for sixty.", "style": "A"}, {"key": "10knfbd", "text": "That makes seventy-four. I asked for sixty.", "style": "A"}, {"key": "zzkyn9", "text": "That makes seventy-five. I asked for sixty.", "style": "A"}, {"key": "193yv08", "text": "That makes forty-six. I asked for sixty-one.", "style": "A"}, {"key": "1e3651t", "text": "That makes forty-seven. I asked for sixty-one.", "style": "A"}, {"key": "o8hben", "text": "That makes forty-eight. I asked for sixty-one.", "style": "A"}, {"key": "1rcrwps", "text": "That makes forty-nine. I asked for sixty-one.", "style": "A"}, {"key": "5nnurr", "text": "That makes fifty. I asked for sixty-one.", "style": "A"}, {"key": "b0xjdm", "text": "That makes fifty-one. I asked for sixty-one.", "style": "A"}, {"key": "1ty89h4", "text": "That makes fifty-two. I asked for sixty-one.", "style": "A"}, {"key": "13etqli", "text": "That makes fifty-three. I asked for sixty-one.", "style": "A"}, {"key": "150t9a2", "text": "That makes fifty-four. I asked for sixty-one.", "style": "A"}, {"key": "1wvxlpi", "text": "That makes fifty-five. I asked for sixty-one.", "style": "A"}, {"key": "fwphtq", "text": "That makes fifty-six. I asked for sixty-one.", "style": "A"}, {"key": "89w947", "text": "That makes fifty-seven. I asked for sixty-one.", "style": "A"}, {"key": "1pr5wdh", "text": "That makes fifty-eight. I asked for sixty-one.", "style": "A"}, {"key": "1j108vq", "text": "That makes fifty-nine. I asked for sixty-one.", "style": "A"}, {"key": "gce7ye", "text": "That makes sixty. I asked for sixty-one.", "style": "A"}, {"key": "1qy5zf5", "text": "That makes sixty-two. I asked for sixty-one.", "style": "A"}, {"key": "qe67gn", "text": "That makes sixty-three. I asked for sixty-one.", "style": "A"}, {"key": "8zfl1h", "text": "That makes sixty-four. I asked for sixty-one.", "style": "A"}, {"key": "2rn4pt", "text": "That makes sixty-five. I asked for sixty-one.", "style": "A"}, {"key": "1o2yp8v", "text": "That makes sixty-six. I asked for sixty-one.", "style": "A"}, {"key": "3qd0va", "text": "That makes sixty-seven. I asked for sixty-one.", "style": "A"}, {"key": "1x2l85k", "text": "That makes sixty-eight. I asked for sixty-one.", "style": "A"}, {"key": "i32tb5", "text": "That makes sixty-nine. I asked for sixty-one.", "style": "A"}, {"key": "yc94vn", "text": "That makes seventy. I asked for sixty-one.", "style": "A"}, {"key": "1y7ikwm", "text": "That makes seventy-one. I asked for sixty-one.", "style": "A"}, {"key": "1uc4xdg", "text": "That makes seventy-two. I asked for sixty-one.", "style": "A"}, {"key": "1md15de", "text": "That makes seventy-three. I asked for sixty-one.", "style": "A"}, {"key": "2m4w0e", "text": "That makes seventy-four. I asked for sixty-one.", "style": "A"}, {"key": "zqfncq", "text": "That makes seventy-five. I asked for sixty-one.", "style": "A"}, {"key": "8nhlky", "text": "That makes seventy-six. I asked for sixty-one.", "style": "A"}, {"key": "1wc07ld", "text": "That makes eighty-five. Count my coins again.", "style": "A"}, {"key": "e7duiw", "text": "That makes eight. I asked for twenty-three.", "style": "A"}, {"key": "zo0zt7", "text": "That makes nine. I asked for twenty-three.", "style": "A"}, {"key": "eo734c", "text": "That makes ten. I asked for twenty-three.", "style": "A"}, {"key": "1dqnu3c", "text": "That makes eleven. I asked for twenty-three.", "style": "A"}, {"key": "1fgmufg", "text": "That makes twelve. I asked for twenty-three.", "style": "A"}, {"key": "9yy7d6", "text": "That makes thirteen. I asked for twenty-three.", "style": "A"}, {"key": "jq8mmf", "text": "That makes fourteen. I asked for twenty-three.", "style": "A"}, {"key": "h7fo4e", "text": "That makes fifteen. I asked for twenty-three.", "style": "A"}, {"key": "zd54gl", "text": "That makes sixteen. I asked for twenty-three.", "style": "A"}, {"key": "1pku3ay", "text": "That makes seventeen. I asked for twenty-three.", "style": "A"}, {"key": "1fdtufc", "text": "That makes eighteen. I asked for twenty-three.", "style": "A"}, {"key": "ondmrb", "text": "That makes nineteen. I asked for twenty-three.", "style": "A"}, {"key": "1opm0xs", "text": "That makes twenty. I asked for twenty-three.", "style": "A"}, {"key": "1pvzgar", "text": "That makes twenty-one. I asked for twenty-three.", "style": "A"}, {"key": "1bioc8h", "text": "That makes twenty-two. I asked for twenty-three.", "style": "A"}, {"key": "186c22t", "text": "That makes twenty-four. I asked for twenty-three.", "style": "A"}, {"key": "1ay8ecp", "text": "That makes twenty-five. I asked for twenty-three.", "style": "A"}, {"key": "pav19v", "text": "That makes twenty-six. I asked for twenty-three.", "style": "A"}, {"key": "1sqh8ig", "text": "That makes twenty-seven. I asked for twenty-three.", "style": "A"}, {"key": "1gqrsr2", "text": "That makes twenty-eight. I asked for twenty-three.", "style": "A"}, {"key": "1azeye1", "text": "That makes twenty-nine. I asked for twenty-three.", "style": "A"}, {"key": "1oxiru3", "text": "That makes thirty. I asked for twenty-three.", "style": "A"}, {"key": "iqi9bo", "text": "That makes thirty-one. I asked for twenty-three.", "style": "A"}, {"key": "uj2z1y", "text": "That makes thirty-two. I asked for twenty-three.", "style": "A"}, {"key": "1kdfbs8", "text": "That makes thirty-three. I asked for twenty-three.", "style": "A"}, {"key": "1otubng", "text": "That makes thirty-four. I asked for twenty-three.", "style": "A"}, {"key": "6b8eyo", "text": "That makes thirty-five. I asked for twenty-three.", "style": "A"}, {"key": "ow0gpk", "text": "That makes thirty-six. I asked for twenty-three.", "style": "A"}, {"key": "1r2rx7n", "text": "That makes thirty-seven. I asked for twenty-three.", "style": "A"}, {"key": "1oarnp1", "text": "That makes thirty-eight. I asked for twenty-three.", "style": "A"}, {"key": "3iho2i", "text": "That makes thirty. I asked for forty-five.", "style": "A"}, {"key": "1qpuzgl", "text": "That makes thirty-one. I asked for forty-five.", "style": "A"}, {"key": "1sn1j53", "text": "That makes thirty-two. I asked for forty-five.", "style": "A"}, {"key": "eewc09", "text": "That makes thirty-three. I asked for forty-five.", "style": "A"}, {"key": "1kb0q5p", "text": "That makes thirty-four. I asked for forty-five.", "style": "A"}, {"key": "1ntu729", "text": "That makes thirty-five. I asked for forty-five.", "style": "A"}, {"key": "jk8bcp", "text": "That makes thirty-six. I asked for forty-five.", "style": "A"}, {"key": "1eq2geq", "text": "That makes thirty-seven. I asked for forty-five.", "style": "A"}, {"key": "liyiw4", "text": "That makes thirty-eight. I asked for forty-five.", "style": "A"}, {"key": "mq1x7l", "text": "That makes thirty-nine. I asked for forty-five.", "style": "A"}, {"key": "q9km4o", "text": "That makes forty. I asked for forty-five.", "style": "A"}, {"key": "pin01f", "text": "That makes forty-one. I asked for forty-five.", "style": "A"}, {"key": "1ww0wkd", "text": "That makes forty-two. I asked for forty-five.", "style": "A"}, {"key": "pkkwb", "text": "That makes forty-three. I asked for forty-five.", "style": "A"}, {"key": "1a9pmo3", "text": "That makes forty-four. I asked for forty-five.", "style": "A"}, {"key": "109lcdf", "text": "That makes forty-six. I asked for forty-five.", "style": "A"}, {"key": "1mtv3hg", "text": "That makes forty-seven. I asked for forty-five.", "style": "A"}, {"key": "16ag2u6", "text": "That makes forty-eight. I asked for forty-five.", "style": "A"}, {"key": "1ivfncr", "text": "That makes forty-nine. I asked for forty-five.", "style": "A"}, {"key": "1q7l9ue", "text": "That makes fifty. I asked for forty-five.", "style": "A"}, {"key": "1kk69v5", "text": "That makes fifty-one. I asked for forty-five.", "style": "A"}, {"key": "huztcz", "text": "That makes fifty-two. I asked for forty-five.", "style": "A"}, {"key": "2qviyt", "text": "That makes fifty-three. I asked for forty-five.", "style": "A"}, {"key": "1vng30x", "text": "That makes fifty-four. I asked for forty-five.", "style": "A"}, {"key": "khj85h", "text": "That makes fifty-five. I asked for forty-five.", "style": "A"}, {"key": "1euws31", "text": "That makes fifty-six. I asked for forty-five.", "style": "A"}, {"key": "1egrbg6", "text": "That makes fifty-seven. I asked for forty-five.", "style": "A"}, {"key": "1mk7oj4", "text": "That makes fifty-eight. I asked for forty-five.", "style": "A"}, {"key": "1ryyl11", "text": "That makes fifty-nine. I asked for forty-five.", "style": "A"}, {"key": "86lv6t", "text": "That makes sixty. I asked for forty-five.", "style": "A"}, {"key": "nhs0oq", "text": "That makes sixty-six. I asked for eighty-one.", "style": "A"}, {"key": "1wlpar5", "text": "That makes sixty-seven. I asked for eighty-one.", "style": "A"}, {"key": "8m952f", "text": "That makes sixty-eight. I asked for eighty-one.", "style": "A"}, {"key": "1sbm64o", "text": "That makes sixty-nine. I asked for eighty-one.", "style": "A"}, {"key": "855jg6", "text": "That makes seventy. I asked for eighty-one.", "style": "A"}, {"key": "1oxqk1t", "text": "That makes seventy-one. I asked for eighty-one.", "style": "A"}, {"key": "ktb8i3", "text": "That makes seventy-two. I asked for eighty-one.", "style": "A"}, {"key": "1x1ozdh", "text": "That makes seventy-three. I asked for eighty-one.", "style": "A"}, {"key": "lahzbd", "text": "That makes seventy-four. I asked for eighty-one.", "style": "A"}, {"key": "1g71a5p", "text": "That makes seventy-five. I asked for eighty-one.", "style": "A"}, {"key": "1ifeedh", "text": "That makes seventy-six. I asked for eighty-one.", "style": "A"}, {"key": "1pad17y", "text": "That makes seventy-seven. I asked for eighty-one.", "style": "A"}, {"key": "sfrrt4", "text": "That makes seventy-eight. I asked for eighty-one.", "style": "A"}, {"key": "m6dbh", "text": "That makes seventy-nine. I asked for eighty-one.", "style": "A"}, {"key": "ttyuk8", "text": "That makes eighty. I asked for eighty-one.", "style": "A"}, {"key": "o4m8xx", "text": "That makes eighty-two. I asked for eighty-one.", "style": "A"}, {"key": "19jjrjf", "text": "That makes eighty-three. I asked for eighty-one.", "style": "A"}, {"key": "1xwm0x7", "text": "That makes eighty-four. I asked for eighty-one.", "style": "A"}, {"key": "eq5wur", "text": "That makes eighty-five. I asked for eighty-one.", "style": "A"}, {"key": "ppxej", "text": "That makes eighty-six. I asked for eighty-one.", "style": "A"}, {"key": "1nh43mk", "text": "That makes eighty-seven. I asked for eighty-one.", "style": "A"}, {"key": "a3jtbq", "text": "That makes eighty-eight. I asked for eighty-one.", "style": "A"}, {"key": "7504eb", "text": "That makes eighty-nine. I asked for eighty-one.", "style": "A"}, {"key": "1oemwl3", "text": "That makes ninety. I asked for eighty-one.", "style": "A"}, {"key": "diutkg", "text": "That makes ninety-one. I asked for eighty-one.", "style": "A"}, {"key": "1qw1h3y", "text": "That makes ninety-two. I asked for eighty-one.", "style": "A"}, {"key": "6myo04", "text": "That makes ninety-three. I asked for eighty-one.", "style": "A"}, {"key": "1hc0lte", "text": "That makes ninety-four. I asked for eighty-one.", "style": "A"}, {"key": "1e0u076", "text": "That makes ninety-five. I asked for eighty-one.", "style": "A"}, {"key": "j5bx0", "text": "That makes ninety-six. I asked for eighty-one.", "style": "A"}, {"key": "7oktka", "text": "That makes one. I asked for eight.", "style": "A"}, {"key": "6s907w", "text": "That makes two. I asked for eight.", "style": "A"}, {"key": "1unomja", "text": "That makes three. I asked for eight.", "style": "A"}, {"key": "ce68zk", "text": "That makes four. I asked for eight.", "style": "A"}, {"key": "15knf74", "text": "That makes five. I asked for eight.", "style": "A"}, {"key": "yhwyry", "text": "That makes six. I asked for eight.", "style": "A"}, {"key": "122pl3", "text": "That makes seven. I asked for eight.", "style": "A"}, {"key": "15oii34", "text": "That makes nine. I asked for eight.", "style": "A"}, {"key": "114cx9p", "text": "That makes ten. I asked for eight.", "style": "A"}, {"key": "tl6ztt", "text": "That makes eleven. I asked for eight.", "style": "A"}, {"key": "1ugg5f1", "text": "That makes twelve. I asked for eight.", "style": "A"}, {"key": "16fscbz", "text": "That makes thirteen. I asked for eight.", "style": "A"}, {"key": "cnsc84", "text": "That makes fourteen. I asked for eight.", "style": "A"}, {"key": "1a02jnv", "text": "That makes fifteen. I asked for eight.", "style": "A"}, {"key": "66ervy", "text": "That makes sixteen. I asked for eight.", "style": "A"}, {"key": "nl7k0v", "text": "That makes seventeen. I asked for eight.", "style": "A"}, {"key": "8fw2j5", "text": "That makes eighteen. I asked for eight.", "style": "A"}, {"key": "1to4c2c", "text": "That makes nineteen. I asked for eight.", "style": "A"}, {"key": "1n2qvax", "text": "That makes twenty. I asked for eight.", "style": "A"}, {"key": "16d9upk", "text": "That makes twenty-one. I asked for eight.", "style": "A"}, {"key": "gl5slu", "text": "That makes twenty-two. I asked for eight.", "style": "A"}, {"key": "1k9jglk", "text": "That makes twenty-three. I asked for eight.", "style": "A"}, {"key": "1kccse6", "text": "That makes thirty-five. I asked for fifty.", "style": "A"}, {"key": "6ua6xy", "text": "That makes thirty-six. I asked for fifty.", "style": "A"}, {"key": "4c4vov", "text": "That makes thirty-seven. I asked for fifty.", "style": "A"}, {"key": "1kf0zb5", "text": "That makes thirty-eight. I asked for fifty.", "style": "A"}, {"key": "qmad0e", "text": "That makes thirty-nine. I asked for fifty.", "style": "A"}, {"key": "5uv5rh", "text": "That makes forty. I asked for fifty.", "style": "A"}, {"key": "1jz5ii8", "text": "That makes forty-one. I asked for fifty.", "style": "A"}, {"key": "2qwpgy", "text": "That makes forty-two. I asked for fifty.", "style": "A"}, {"key": "1kmuebc", "text": "That makes forty-three. I asked for fifty.", "style": "A"}, {"key": "1rs004g", "text": "That makes forty-four. I asked for fifty.", "style": "A"}, {"key": "1scd194", "text": "That makes forty-five. I asked for fifty.", "style": "A"}, {"key": "13olq8", "text": "That makes forty-six. I asked for fifty.", "style": "A"}, {"key": "1of38u9", "text": "That makes forty-seven. I asked for fifty.", "style": "A"}, {"key": "k33z9v", "text": "That makes forty-eight. I asked for fifty.", "style": "A"}, {"key": "6pfj0o", "text": "That makes forty-nine. I asked for fifty.", "style": "A"}, {"key": "1jhbytq", "text": "That makes fifty-one. I asked for fifty.", "style": "A"}, {"key": "ycct4w", "text": "That makes fifty-two. I asked for fifty.", "style": "A"}, {"key": "a0wht6", "text": "That makes fifty-three. I asked for fifty.", "style": "A"}, {"key": "fc4mb2", "text": "That makes fifty-four. I asked for fifty.", "style": "A"}, {"key": "1pwtsyy", "text": "That makes fifty-five. I asked for fifty.", "style": "A"}, {"key": "169pfj6", "text": "That makes fifty-six. I asked for fifty.", "style": "A"}, {"key": "1jc5gm3", "text": "That makes fifty-seven. I asked for fifty.", "style": "A"}, {"key": "i8bgxx", "text": "That makes fifty-eight. I asked for fifty.", "style": "A"}, {"key": "bxoinu", "text": "That makes fifty-nine. I asked for fifty.", "style": "A"}, {"key": "n0gjyi", "text": "That makes sixty. I asked for fifty.", "style": "A"}, {"key": "okr68r", "text": "That makes sixty-one. I asked for fifty.", "style": "A"}, {"key": "4q32f5", "text": "That makes sixty-two. I asked for fifty.", "style": "A"}, {"key": "1ac1zln", "text": "That makes sixty-three. I asked for fifty.", "style": "A"}, {"key": "70ecrp", "text": "That makes sixty-four. I asked for fifty.", "style": "A"}, {"key": "dw8c29", "text": "That makes sixty-five. I asked for fifty.", "style": "A"}, {"key": "1s3vv8b", "text": "That is fifty, but with three coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "bozz2l", "text": "That is fifty, but with four coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "czqxel", "text": "That is fifty, but with five coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1skmekj", "text": "That is fifty, but with six coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "103m4s2", "text": "That is fifty, but with seven coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "f56uek", "text": "That is fifty, but with eight coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1dauyzf", "text": "That makes eighteen. I asked for thirty-three.", "style": "A"}, {"key": "1s89e78", "text": "That makes nineteen. I asked for thirty-three.", "style": "A"}, {"key": "1bz8t8j", "text": "That makes twenty. I asked for thirty-three.", "style": "A"}, {"key": "uov7ug", "text": "That makes twenty-one. I asked for thirty-three.", "style": "A"}, {"key": "1ovv7ua", "text": "That makes twenty-two. I asked for thirty-three.", "style": "A"}, {"key": "qdz6x4", "text": "That makes twenty-three. I asked for thirty-three.", "style": "A"}, {"key": "16vmo4e", "text": "That makes twenty-four. I asked for thirty-three.", "style": "A"}, {"key": "ker1bu", "text": "That makes twenty-five. I asked for thirty-three.", "style": "A"}, {"key": "8d2m3s", "text": "That makes twenty-six. I asked for thirty-three.", "style": "A"}, {"key": "1pstsx7", "text": "That makes twenty-seven. I asked for thirty-three.", "style": "A"}, {"key": "mc82gl", "text": "That makes twenty-eight. I asked for thirty-three.", "style": "A"}, {"key": "ccwcx6", "text": "That makes twenty-nine. I asked for thirty-three.", "style": "A"}, {"key": "14bk5rk", "text": "That makes thirty. I asked for thirty-three.", "style": "A"}, {"key": "1fyworz", "text": "That makes thirty-one. I asked for thirty-three.", "style": "A"}, {"key": "7n9ki5", "text": "That makes thirty-two. I asked for thirty-three.", "style": "A"}, {"key": "2kkj7r", "text": "That makes thirty-four. I asked for thirty-three.", "style": "A"}, {"key": "1slz98j", "text": "That makes thirty-five. I asked for thirty-three.", "style": "A"}, {"key": "y2nca3", "text": "That makes thirty-six. I asked for thirty-three.", "style": "A"}, {"key": "6pzixk", "text": "That makes thirty-seven. I asked for thirty-three.", "style": "A"}, {"key": "oucgsu", "text": "That makes thirty-eight. I asked for thirty-three.", "style": "A"}, {"key": "1o2a3kz", "text": "That makes thirty-nine. I asked for thirty-three.", "style": "A"}, {"key": "1kbgzyi", "text": "That makes forty. I asked for thirty-three.", "style": "A"}, {"key": "14vwflt", "text": "That makes forty-one. I asked for thirty-three.", "style": "A"}, {"key": "ru2vw7", "text": "That makes forty-two. I asked for thirty-three.", "style": "A"}, {"key": "5z7sh5", "text": "That makes forty-three. I asked for thirty-three.", "style": "A"}, {"key": "s2o5g1", "text": "That makes forty-four. I asked for thirty-three.", "style": "A"}, {"key": "ct77nt", "text": "That makes forty-five. I asked for thirty-three.", "style": "A"}, {"key": "jsq44x", "text": "That makes forty-six. I asked for thirty-three.", "style": "A"}, {"key": "128zm1a", "text": "That makes forty-seven. I asked for thirty-three.", "style": "A"}, {"key": "9g2du4", "text": "That makes forty-eight. I asked for thirty-three.", "style": "A"}, {"key": "wfbewi", "text": "That is thirty-six, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1mgxuxq", "text": "That is thirty-six, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1ljqr6u", "text": "That is thirty-six, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1nzaq8b", "text": "That is thirty-six, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "mpkmgt", "text": "That is thirty-six, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1rmi0ty", "text": "That makes three. I asked for eighteen.", "style": "A"}, {"key": "16maozs", "text": "That makes four. I asked for eighteen.", "style": "A"}, {"key": "12fez14", "text": "That makes five. I asked for eighteen.", "style": "A"}, {"key": "1s6u6by", "text": "That makes six. I asked for eighteen.", "style": "A"}, {"key": "1amwfhp", "text": "That makes seven. I asked for eighteen.", "style": "A"}, {"key": "1p0vb9z", "text": "That makes eight. I asked for eighteen.", "style": "A"}, {"key": "19w90hk", "text": "That makes nine. I asked for eighteen.", "style": "A"}, {"key": "1jzqoj7", "text": "That makes ten. I asked for eighteen.", "style": "A"}, {"key": "1mgww7", "text": "That makes eleven. I asked for eighteen.", "style": "A"}, {"key": "a8wxir", "text": "That makes twelve. I asked for eighteen.", "style": "A"}, {"key": "lys1dh", "text": "That makes thirteen. I asked for eighteen.", "style": "A"}, {"key": "581vl8", "text": "That makes fourteen. I asked for eighteen.", "style": "A"}, {"key": "wh0g0x", "text": "That makes fifteen. I asked for eighteen.", "style": "A"}, {"key": "7nfb8u", "text": "That makes sixteen. I asked for eighteen.", "style": "A"}, {"key": "1uxwl1h", "text": "That makes seventeen. I asked for eighteen.", "style": "A"}, {"key": "1l9qkho", "text": "That makes nineteen. I asked for eighteen.", "style": "A"}, {"key": "17r64an", "text": "That makes twenty. I asked for eighteen.", "style": "A"}, {"key": "1sulfgg", "text": "That makes twenty-one. I asked for eighteen.", "style": "A"}, {"key": "js8dle", "text": "That makes twenty-two. I asked for eighteen.", "style": "A"}, {"key": "am9ib4", "text": "That makes twenty-three. I asked for eighteen.", "style": "A"}, {"key": "tzeum6", "text": "That makes twenty-four. I asked for eighteen.", "style": "A"}, {"key": "esqjga", "text": "That makes twenty-five. I asked for eighteen.", "style": "A"}, {"key": "ioxfyo", "text": "That makes twenty-six. I asked for eighteen.", "style": "A"}, {"key": "tsbio7", "text": "That makes twenty-seven. I asked for eighteen.", "style": "A"}, {"key": "1b48l4h", "text": "That makes twenty-eight. I asked for eighteen.", "style": "A"}, {"key": "1rbx18q", "text": "That makes twenty-nine. I asked for eighteen.", "style": "A"}, {"key": "7itdnc", "text": "That makes thirty. I asked for eighteen.", "style": "A"}, {"key": "k81dbf", "text": "That makes thirty-one. I asked for eighteen.", "style": "A"}, {"key": "n23gyx", "text": "That makes thirty-two. I asked for eighteen.", "style": "A"}, {"key": "1xftzzr", "text": "That makes thirty-three. I asked for eighteen.", "style": "A"}, {"key": "zrolpr", "text": "That makes thirteen. I asked for twenty-eight.", "style": "A"}, {"key": "qfw2ru", "text": "That makes fourteen. I asked for twenty-eight.", "style": "A"}, {"key": "1grzxgz", "text": "That makes fifteen. I asked for twenty-eight.", "style": "A"}, {"key": "w9sy94", "text": "That makes sixteen. I asked for twenty-eight.", "style": "A"}, {"key": "1qdcs8v", "text": "That makes seventeen. I asked for twenty-eight.", "style": "A"}, {"key": "1hivmad", "text": "That makes eighteen. I asked for twenty-eight.", "style": "A"}, {"key": "1m4i5ei", "text": "That makes nineteen. I asked for twenty-eight.", "style": "A"}, {"key": "1xat8d", "text": "That makes twenty. I asked for twenty-eight.", "style": "A"}, {"key": "1wfnvie", "text": "That makes twenty-one. I asked for twenty-eight.", "style": "A"}, {"key": "11jia5w", "text": "That makes twenty-two. I asked for twenty-eight.", "style": "A"}, {"key": "s98rau", "text": "That makes twenty-three. I asked for twenty-eight.", "style": "A"}, {"key": "1p2ww54", "text": "That makes twenty-four. I asked for twenty-eight.", "style": "A"}, {"key": "5w22ik", "text": "That makes twenty-five. I asked for twenty-eight.", "style": "A"}, {"key": "apy0k6", "text": "That makes twenty-six. I asked for twenty-eight.", "style": "A"}, {"key": "13xxkhx", "text": "That makes twenty-seven. I asked for twenty-eight.", "style": "A"}, {"key": "1qcxy18", "text": "That makes twenty-nine. I asked for twenty-eight.", "style": "A"}, {"key": "1an7p8e", "text": "That makes thirty. I asked for twenty-eight.", "style": "A"}, {"key": "adgufl", "text": "That makes thirty-one. I asked for twenty-eight.", "style": "A"}, {"key": "x0i463", "text": "That makes thirty-two. I asked for twenty-eight.", "style": "A"}, {"key": "apx8vp", "text": "That makes thirty-three. I asked for twenty-eight.", "style": "A"}, {"key": "75sbrd", "text": "That makes thirty-four. I asked for twenty-eight.", "style": "A"}, {"key": "ik198d", "text": "That makes thirty-five. I asked for twenty-eight.", "style": "A"}, {"key": "y8f2h1", "text": "That makes thirty-six. I asked for twenty-eight.", "style": "A"}, {"key": "a6fa7a", "text": "That makes thirty-seven. I asked for twenty-eight.", "style": "A"}, {"key": "bh9miw", "text": "That makes thirty-eight. I asked for twenty-eight.", "style": "A"}, {"key": "1pjr4t", "text": "That makes thirty-nine. I asked for twenty-eight.", "style": "A"}, {"key": "m868to", "text": "That makes forty. I asked for twenty-eight.", "style": "A"}, {"key": "w3e1qv", "text": "That makes forty-one. I asked for twenty-eight.", "style": "A"}, {"key": "10oja55", "text": "That makes forty-two. I asked for twenty-eight.", "style": "A"}, {"key": "4jswv", "text": "That makes forty-three. I asked for twenty-eight.", "style": "A"}, {"key": "ixu0ix", "text": "That is twenty-six, but with three coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "zks4n3", "text": "That is twenty-six, but with four coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "o7y3hn", "text": "That is twenty-six, but with five coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1p1i85t", "text": "That is twenty-six, but with six coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1m7po7c", "text": "That is twenty-six, but with seven coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "158t5mi", "text": "That is twenty-six, but with eight coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1ipekk8", "text": "That is sixty, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "n3a7cw", "text": "That is sixty, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "263m20", "text": "That is sixty, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "13r6q7x", "text": "That is sixty, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1wpl9pb", "text": "That is sixty, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "jrga0d", "text": "That makes twenty-seven. I asked for forty-two.", "style": "A"}, {"key": "1b97ga7", "text": "That makes twenty-eight. I asked for forty-two.", "style": "A"}, {"key": "crmgam", "text": "That makes twenty-nine. I asked for forty-two.", "style": "A"}, {"key": "6f45i4", "text": "That makes thirty. I asked for forty-two.", "style": "A"}, {"key": "1qqiepd", "text": "That makes thirty-one. I asked for forty-two.", "style": "A"}, {"key": "1kbnebr", "text": "That makes thirty-two. I asked for forty-two.", "style": "A"}, {"key": "1jj054t", "text": "That makes thirty-three. I asked for forty-two.", "style": "A"}, {"key": "eprp61", "text": "That makes thirty-four. I asked for forty-two.", "style": "A"}, {"key": "i6apk5", "text": "That makes thirty-five. I asked for forty-two.", "style": "A"}, {"key": "vcvkz1", "text": "That makes thirty-six. I asked for forty-two.", "style": "A"}, {"key": "cvao1w", "text": "That makes thirty-seven. I asked for forty-two.", "style": "A"}, {"key": "1vhinaq", "text": "That makes thirty-eight. I asked for forty-two.", "style": "A"}, {"key": "px1gcl", "text": "That makes thirty-nine. I asked for forty-two.", "style": "A"}, {"key": "h642am", "text": "That makes forty. I asked for forty-two.", "style": "A"}, {"key": "128vjgb", "text": "That makes forty-one. I asked for forty-two.", "style": "A"}, {"key": "b7gy03", "text": "That makes forty-three. I asked for forty-two.", "style": "A"}, {"key": "1yquzij", "text": "That makes forty-four. I asked for forty-two.", "style": "A"}, {"key": "1ffr26b", "text": "That makes forty-five. I asked for forty-two.", "style": "A"}, {"key": "61599n", "text": "That makes forty-six. I asked for forty-two.", "style": "A"}, {"key": "idgecy", "text": "That makes forty-seven. I asked for forty-two.", "style": "A"}, {"key": "t5fd2g", "text": "That makes forty-eight. I asked for forty-two.", "style": "A"}, {"key": "1jd7ssz", "text": "That makes forty-nine. I asked for forty-two.", "style": "A"}, {"key": "1lniog", "text": "That makes fifty. I asked for forty-two.", "style": "A"}, {"key": "1v3wcut", "text": "That makes fifty-one. I asked for forty-two.", "style": "A"}, {"key": "qvenqj", "text": "That makes fifty-two. I asked for forty-two.", "style": "A"}, {"key": "17sgng1", "text": "That makes fifty-three. I asked for forty-two.", "style": "A"}, {"key": "iztt9x", "text": "That makes fifty-four. I asked for forty-two.", "style": "A"}, {"key": "1d8i5f5", "text": "That makes fifty-five. I asked for forty-two.", "style": "A"}, {"key": "1jzm31l", "text": "That makes fifty-six. I asked for forty-two.", "style": "A"}, {"key": "3j4s8g", "text": "That makes fifty-seven. I asked for forty-two.", "style": "A"}, {"key": "1iz8xcq", "text": "That makes thirty-eight. I asked for fifty-three.", "style": "A"}, {"key": "1ava211", "text": "That makes thirty-nine. I asked for fifty-three.", "style": "A"}, {"key": "vmqply", "text": "That makes forty. I asked for fifty-three.", "style": "A"}, {"key": "14xaaez", "text": "That makes forty-one. I asked for fifty-three.", "style": "A"}, {"key": "865sg9", "text": "That makes forty-two. I asked for fifty-three.", "style": "A"}, {"key": "45311f", "text": "That makes forty-three. I asked for fifty-three.", "style": "A"}, {"key": "1qalrhn", "text": "That makes forty-four. I asked for fifty-three.", "style": "A"}, {"key": "11aqu5f", "text": "That makes forty-five. I asked for fifty-three.", "style": "A"}, {"key": "d53v7v", "text": "That makes forty-six. I asked for fifty-three.", "style": "A"}, {"key": "4ytct6", "text": "That makes forty-seven. I asked for fifty-three.", "style": "A"}, {"key": "149zk0o", "text": "That makes forty-eight. I asked for fifty-three.", "style": "A"}, {"key": "1jqhaj7", "text": "That makes forty-nine. I asked for fifty-three.", "style": "A"}, {"key": "17ou5r4", "text": "That makes fifty. I asked for fifty-three.", "style": "A"}, {"key": "oue92t", "text": "That makes fifty-one. I asked for fifty-three.", "style": "A"}, {"key": "igdrnv", "text": "That makes fifty-two. I asked for fifty-three.", "style": "A"}, {"key": "1o78v2t", "text": "That makes fifty-four. I asked for fifty-three.", "style": "A"}, {"key": "156oi5d", "text": "That makes fifty-five. I asked for fifty-three.", "style": "A"}, {"key": "1ar5ge1", "text": "That makes fifty-six. I asked for fifty-three.", "style": "A"}, {"key": "1lm1ghs", "text": "That makes fifty-seven. I asked for fifty-three.", "style": "A"}, {"key": "j4hx6m", "text": "That makes fifty-eight. I asked for fifty-three.", "style": "A"}, {"key": "1gkid2p", "text": "That makes fifty-nine. I asked for fifty-three.", "style": "A"}, {"key": "1m31ts1", "text": "That makes sixty. I asked for fifty-three.", "style": "A"}, {"key": "1o45o00", "text": "That makes sixty-one. I asked for fifty-three.", "style": "A"}, {"key": "aq6kd6", "text": "That makes sixty-two. I asked for fifty-three.", "style": "A"}, {"key": "1f94huo", "text": "That makes sixty-three. I asked for fifty-three.", "style": "A"}, {"key": "x3dun2", "text": "That makes sixty-four. I asked for fifty-three.", "style": "A"}, {"key": "1ijfze", "text": "That makes sixty-five. I asked for fifty-three.", "style": "A"}, {"key": "z28f8o", "text": "That makes sixty-six. I asked for fifty-three.", "style": "A"}, {"key": "7rk2g1", "text": "That makes sixty-seven. I asked for fifty-three.", "style": "A"}, {"key": "bvpnff", "text": "That makes sixty-eight. I asked for fifty-three.", "style": "A"}, {"key": "16g4hpk", "text": "That is seventeen, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1rvcd74", "text": "That is seventeen, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1ksz1d3", "text": "That is seventeen, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1v0yju5", "text": "That is seventeen, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "13r19t7", "text": "That makes sixty-five. I asked for eighty.", "style": "A"}, {"key": "1cei57p", "text": "That makes sixty-six. I asked for eighty.", "style": "A"}, {"key": "1y3tau2", "text": "That makes sixty-seven. I asked for eighty.", "style": "A"}, {"key": "1roacbk", "text": "That makes sixty-eight. I asked for eighty.", "style": "A"}, {"key": "r6fru3", "text": "That makes sixty-nine. I asked for eighty.", "style": "A"}, {"key": "nrgw1t", "text": "That makes seventy. I asked for eighty.", "style": "A"}, {"key": "1jrzb1m", "text": "That makes seventy-one. I asked for eighty.", "style": "A"}, {"key": "cx81h0", "text": "That makes seventy-two. I asked for eighty.", "style": "A"}, {"key": "1fwn2ny", "text": "That makes seventy-three. I asked for eighty.", "style": "A"}, {"key": "455uki", "text": "That makes seventy-four. I asked for eighty.", "style": "A"}, {"key": "vb22zq", "text": "That makes seventy-five. I asked for eighty.", "style": "A"}, {"key": "k31gu", "text": "That makes seventy-six. I asked for eighty.", "style": "A"}, {"key": "shatd5", "text": "That makes seventy-seven. I asked for eighty.", "style": "A"}, {"key": "pmi0mj", "text": "That makes seventy-eight. I asked for eighty.", "style": "A"}, {"key": "1uxump2", "text": "That makes seventy-nine. I asked for eighty.", "style": "A"}, {"key": "32xdks", "text": "That makes eighty-one. I asked for eighty.", "style": "A"}, {"key": "dugjou", "text": "That makes eighty-two. I asked for eighty.", "style": "A"}, {"key": "o1qd04", "text": "That makes eighty-three. I asked for eighty.", "style": "A"}, {"key": "s0lob8", "text": "That makes eighty-four. I asked for eighty.", "style": "A"}, {"key": "1sp8ci4", "text": "That makes eighty-five. I asked for eighty.", "style": "A"}, {"key": "adc5hg", "text": "That makes eighty-six. I asked for eighty.", "style": "A"}, {"key": "y9ek0f", "text": "That makes eighty-seven. I asked for eighty.", "style": "A"}, {"key": "13okwch", "text": "That makes eighty-eight. I asked for eighty.", "style": "A"}, {"key": "bcafi4", "text": "That makes eighty-nine. I asked for eighty.", "style": "A"}, {"key": "1q9mrjk", "text": "That makes ninety. I asked for eighty.", "style": "A"}, {"key": "x3uder", "text": "That makes ninety-one. I asked for eighty.", "style": "A"}, {"key": "g4mjfd", "text": "That makes ninety-two. I asked for eighty.", "style": "A"}, {"key": "18xkvk7", "text": "That makes ninety-three. I asked for eighty.", "style": "A"}, {"key": "gcrebx", "text": "That makes ninety-four. I asked for eighty.", "style": "A"}, {"key": "1s7nmn1", "text": "That makes ninety-five. I asked for eighty.", "style": "A"}, {"key": "sjifr3", "text": "That is eighty, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "12sjbwd", "text": "That is eighty, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1wik4nq", "text": "That is eighty, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "yxgntc", "text": "That is eighty, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1ila4if", "text": "That is seventy, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "45pnud", "text": "That is seventy, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "7w6cfy", "text": "That is seventy, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "uaqmq0", "text": "That is seventy, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "nsiuwa", "text": "That is twelve, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "15umkra", "text": "That is twelve, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "h67h3y", "text": "That is twelve, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "avrwxf", "text": "That is twelve, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1h3uuut", "text": "That is twelve, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1j6csyy", "text": "That is thirty-one, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "cxndqu", "text": "That is thirty-one, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "57mazi", "text": "That is thirty-one, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "xee9f7", "text": "That is thirty-one, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1pwqr9", "text": "That is thirty-one, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "m8ed0r", "text": "That makes seventeen. I asked for thirty-two.", "style": "A"}, {"key": "ut8ard", "text": "That makes eighteen. I asked for thirty-two.", "style": "A"}, {"key": "1iw2gyy", "text": "That makes nineteen. I asked for thirty-two.", "style": "A"}, {"key": "xbxetd", "text": "That makes twenty. I asked for thirty-two.", "style": "A"}, {"key": "126271q", "text": "That makes twenty-one. I asked for thirty-two.", "style": "A"}, {"key": "1m7t6nw", "text": "That makes twenty-two. I asked for thirty-two.", "style": "A"}, {"key": "8n5mta", "text": "That makes twenty-three. I asked for thirty-two.", "style": "A"}, {"key": "14x6d20", "text": "That makes twenty-four. I asked for thirty-two.", "style": "A"}, {"key": "1yaz79g", "text": "That makes twenty-five. I asked for thirty-two.", "style": "A"}, {"key": "h3uyji", "text": "That makes twenty-six. I asked for thirty-two.", "style": "A"}, {"key": "1dowo09", "text": "That makes twenty-seven. I asked for thirty-two.", "style": "A"}, {"key": "1m79u2f", "text": "That makes twenty-eight. I asked for thirty-two.", "style": "A"}, {"key": "nakodw", "text": "That makes twenty-nine. I asked for thirty-two.", "style": "A"}, {"key": "2cvkdi", "text": "That makes thirty. I asked for thirty-two.", "style": "A"}, {"key": "1gqw0jh", "text": "That makes thirty-one. I asked for thirty-two.", "style": "A"}, {"key": "lxmx3t", "text": "That makes thirty-three. I asked for thirty-two.", "style": "A"}, {"key": "ct1fhx", "text": "That makes thirty-four. I asked for thirty-two.", "style": "A"}, {"key": "174jykh", "text": "That makes thirty-five. I asked for thirty-two.", "style": "A"}, {"key": "1osdmtl", "text": "That makes thirty-six. I asked for thirty-two.", "style": "A"}, {"key": "1ktws0e", "text": "That makes thirty-seven. I asked for thirty-two.", "style": "A"}, {"key": "18oynig", "text": "That makes thirty-eight. I asked for thirty-two.", "style": "A"}, {"key": "1w9vbhd", "text": "That makes thirty-nine. I asked for thirty-two.", "style": "A"}, {"key": "fguexg", "text": "That makes forty. I asked for thirty-two.", "style": "A"}, {"key": "1ugmhfn", "text": "That makes forty-one. I asked for thirty-two.", "style": "A"}, {"key": "18f9kyt", "text": "That makes forty-two. I asked for thirty-two.", "style": "A"}, {"key": "1yf7yq3", "text": "That makes forty-three. I asked for thirty-two.", "style": "A"}, {"key": "1wfeihf", "text": "That makes forty-four. I asked for thirty-two.", "style": "A"}, {"key": "5a6r3f", "text": "That makes forty-five. I asked for thirty-two.", "style": "A"}, {"key": "12wdp0z", "text": "That makes forty-six. I asked for thirty-two.", "style": "A"}, {"key": "eho5vs", "text": "That makes forty-seven. I asked for thirty-two.", "style": "A"}, {"key": "19fwgsa", "text": "That is thirty-two, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "11y78r6", "text": "That is thirty-two, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "38nseh", "text": "That is thirty-two, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1uhrhhj", "text": "That is thirty-two, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "xsaa72", "text": "That makes thirty-two. I asked for forty-seven.", "style": "A"}, {"key": "1jor0h4", "text": "That makes thirty-three. I asked for forty-seven.", "style": "A"}, {"key": "mxa23g", "text": "That makes thirty-four. I asked for forty-seven.", "style": "A"}, {"key": "b96d74", "text": "That makes thirty-five. I asked for forty-seven.", "style": "A"}, {"key": "jv4iqg", "text": "That makes thirty-six. I asked for forty-seven.", "style": "A"}, {"key": "16zx8hl", "text": "That makes thirty-seven. I asked for forty-seven.", "style": "A"}, {"key": "13yi0zv", "text": "That makes thirty-eight. I asked for forty-seven.", "style": "A"}, {"key": "106ej5c", "text": "That makes thirty-nine. I asked for forty-seven.", "style": "A"}, {"key": "vvy773", "text": "That makes forty. I asked for forty-seven.", "style": "A"}, {"key": "gaq44a", "text": "That makes forty-one. I asked for forty-seven.", "style": "A"}, {"key": "jzl83w", "text": "That makes forty-two. I asked for forty-seven.", "style": "A"}, {"key": "1e5v8ci", "text": "That makes forty-three. I asked for forty-seven.", "style": "A"}, {"key": "1hkua3u", "text": "That makes forty-four. I asked for forty-seven.", "style": "A"}, {"key": "3l5qxu", "text": "That makes forty-five. I asked for forty-seven.", "style": "A"}, {"key": "cqfwy2", "text": "That makes forty-six. I asked for forty-seven.", "style": "A"}, {"key": "1s82plh", "text": "That makes forty-eight. I asked for forty-seven.", "style": "A"}, {"key": "ahwhf6", "text": "That makes forty-nine. I asked for forty-seven.", "style": "A"}, {"key": "nyfji5", "text": "That makes fifty. I asked for forty-seven.", "style": "A"}, {"key": "164fuf4", "text": "That makes fifty-one. I asked for forty-seven.", "style": "A"}, {"key": "i1pte2", "text": "That makes fifty-two. I asked for forty-seven.", "style": "A"}, {"key": "1a7bgsk", "text": "That makes fifty-three. I asked for forty-seven.", "style": "A"}, {"key": "xr8880", "text": "That makes fifty-four. I asked for forty-seven.", "style": "A"}, {"key": "yadp1g", "text": "That makes fifty-five. I asked for forty-seven.", "style": "A"}, {"key": "19kw0d8", "text": "That makes fifty-six. I asked for forty-seven.", "style": "A"}, {"key": "cmirdp", "text": "That makes fifty-seven. I asked for forty-seven.", "style": "A"}, {"key": "1be55s7", "text": "That makes fifty-eight. I asked for forty-seven.", "style": "A"}, {"key": "1hp3zzo", "text": "That makes fifty-nine. I asked for forty-seven.", "style": "A"}, {"key": "vw2p7o", "text": "That makes sixty. I asked for forty-seven.", "style": "A"}, {"key": "f4myvx", "text": "That makes sixty-one. I asked for forty-seven.", "style": "A"}, {"key": "dq2n9n", "text": "That makes sixty-two. I asked for forty-seven.", "style": "A"}, {"key": "m1wn06", "text": "That makes fifty-one. I asked for sixty-six.", "style": "A"}, {"key": "1t04atk", "text": "That makes fifty-two. I asked for sixty-six.", "style": "A"}, {"key": "12v9xa2", "text": "That makes fifty-three. I asked for sixty-six.", "style": "A"}, {"key": "1gqjhp2", "text": "That makes fifty-four. I asked for sixty-six.", "style": "A"}, {"key": "50qgoq", "text": "That makes fifty-five. I asked for sixty-six.", "style": "A"}, {"key": "1jpt8ya", "text": "That makes fifty-six. I asked for sixty-six.", "style": "A"}, {"key": "1adjncr", "text": "That makes fifty-seven. I asked for sixty-six.", "style": "A"}, {"key": "164xif1", "text": "That makes fifty-eight. I asked for sixty-six.", "style": "A"}, {"key": "8s8efe", "text": "That makes fifty-nine. I asked for sixty-six.", "style": "A"}, {"key": "nib4wq", "text": "That makes sixty. I asked for sixty-six.", "style": "A"}, {"key": "yf8kxn", "text": "That makes sixty-one. I asked for sixty-six.", "style": "A"}, {"key": "1us4wf5", "text": "That makes sixty-two. I asked for sixty-six.", "style": "A"}, {"key": "sz8gwr", "text": "That makes sixty-three. I asked for sixty-six.", "style": "A"}, {"key": "1w3rzbx", "text": "That makes sixty-four. I asked for sixty-six.", "style": "A"}, {"key": "1g4m6up", "text": "That makes sixty-five. I asked for sixty-six.", "style": "A"}, {"key": "aw9xtm", "text": "That makes sixty-seven. I asked for sixty-six.", "style": "A"}, {"key": "1tzl8go", "text": "That makes sixty-eight. I asked for sixty-six.", "style": "A"}, {"key": "1w4t08h", "text": "That makes sixty-nine. I asked for sixty-six.", "style": "A"}, {"key": "zljjb3", "text": "That makes seventy. I asked for sixty-six.", "style": "A"}, {"key": "1mskqga", "text": "That makes seventy-one. I asked for sixty-six.", "style": "A"}, {"key": "y3zln0", "text": "That makes seventy-two. I asked for sixty-six.", "style": "A"}, {"key": "1tw3gr2", "text": "That makes seventy-three. I asked for sixty-six.", "style": "A"}, {"key": "1mqc3oi", "text": "That makes seventy-four. I asked for sixty-six.", "style": "A"}, {"key": "13qp5hy", "text": "That makes seventy-five. I asked for sixty-six.", "style": "A"}, {"key": "5hbk7y", "text": "That makes seventy-six. I asked for sixty-six.", "style": "A"}, {"key": "vrvzfr", "text": "That makes seventy-seven. I asked for sixty-six.", "style": "A"}, {"key": "3plrw1", "text": "That makes seventy-eight. I asked for sixty-six.", "style": "A"}, {"key": "ktqo2e", "text": "That makes seventy-nine. I asked for sixty-six.", "style": "A"}, {"key": "c5m60x", "text": "That makes eighty. I asked for sixty-six.", "style": "A"}, {"key": "1cj0vp0", "text": "That makes eighty-one. I asked for sixty-six.", "style": "A"}, {"key": "1noo312", "text": "That makes fifty-five. I asked for seventy.", "style": "A"}, {"key": "kgkcjy", "text": "That makes fifty-six. I asked for seventy.", "style": "A"}, {"key": "1kg44qz", "text": "That makes fifty-seven. I asked for seventy.", "style": "A"}, {"key": "1mb1fsp", "text": "That makes fifty-eight. I asked for seventy.", "style": "A"}, {"key": "1p5k19i", "text": "That makes fifty-nine. I asked for seventy.", "style": "A"}, {"key": "5jsbna", "text": "That makes sixty. I asked for seventy.", "style": "A"}, {"key": "5xgsnf", "text": "That makes sixty-one. I asked for seventy.", "style": "A"}, {"key": "1daon85", "text": "That makes sixty-two. I asked for seventy.", "style": "A"}, {"key": "1ip45uz", "text": "That makes sixty-three. I asked for seventy.", "style": "A"}, {"key": "1o1xg49", "text": "That makes sixty-four. I asked for seventy.", "style": "A"}, {"key": "1kxfg2t", "text": "That makes sixty-five. I asked for seventy.", "style": "A"}, {"key": "zygtar", "text": "That makes sixty-six. I asked for seventy.", "style": "A"}, {"key": "jo6ok6", "text": "That makes sixty-seven. I asked for seventy.", "style": "A"}, {"key": "mzu2mo", "text": "That makes sixty-eight. I asked for seventy.", "style": "A"}, {"key": "1g3hhid", "text": "That makes sixty-nine. I asked for seventy.", "style": "A"}, {"key": "1p7jy2u", "text": "That makes seventy-one. I asked for seventy.", "style": "A"}, {"key": "qp5ux8", "text": "That makes seventy-two. I asked for seventy.", "style": "A"}, {"key": "1n89d6q", "text": "That makes seventy-three. I asked for seventy.", "style": "A"}, {"key": "1n72ljy", "text": "That makes seventy-four. I asked for seventy.", "style": "A"}, {"key": "qguthm", "text": "That makes seventy-five. I asked for seventy.", "style": "A"}, {"key": "qubcya", "text": "That makes seventy-six. I asked for seventy.", "style": "A"}, {"key": "136gyrz", "text": "That makes seventy-seven. I asked for seventy.", "style": "A"}, {"key": "1t6mdph", "text": "That makes seventy-eight. I asked for seventy.", "style": "A"}, {"key": "1gfmt1m", "text": "That makes seventy-nine. I asked for seventy.", "style": "A"}, {"key": "kdka5x", "text": "That makes eighty. I asked for seventy.", "style": "A"}, {"key": "67j6d0", "text": "That makes eighty-one. I asked for seventy.", "style": "A"}, {"key": "j5i7de", "text": "That makes eighty-two. I asked for seventy.", "style": "A"}, {"key": "1vg3kj0", "text": "That makes eighty-three. I asked for seventy.", "style": "A"}, {"key": "x31wh8", "text": "That makes eighty-four. I asked for seventy.", "style": "A"}, {"key": "g2jftw", "text": "That makes eighty-five. I asked for seventy.", "style": "A"}, {"key": "k45fqi", "text": "That makes thirty-seven. I asked for fifty-two.", "style": "A"}, {"key": "v1p4ro", "text": "That makes thirty-eight. I asked for fifty-two.", "style": "A"}, {"key": "86b47", "text": "That makes thirty-nine. I asked for fifty-two.", "style": "A"}, {"key": "poniow", "text": "That makes forty. I asked for fifty-two.", "style": "A"}, {"key": "131c7q1", "text": "That makes forty-one. I asked for fifty-two.", "style": "A"}, {"key": "pdfe5n", "text": "That makes forty-two. I asked for fifty-two.", "style": "A"}, {"key": "j7e14x", "text": "That makes forty-three. I asked for fifty-two.", "style": "A"}, {"key": "1fewpxl", "text": "That makes forty-four. I asked for fifty-two.", "style": "A"}, {"key": "nr3iht", "text": "That makes forty-five. I asked for fifty-two.", "style": "A"}, {"key": "41wmcp", "text": "That makes forty-six. I asked for fifty-two.", "style": "A"}, {"key": "cg2mxw", "text": "That makes forty-seven. I asked for fifty-two.", "style": "A"}, {"key": "6ny3bi", "text": "That makes forty-eight. I asked for fifty-two.", "style": "A"}, {"key": "1ph83yp", "text": "That makes forty-nine. I asked for fifty-two.", "style": "A"}, {"key": "174xoba", "text": "That makes fifty. I asked for fifty-two.", "style": "A"}, {"key": "1em0rcn", "text": "That makes fifty-one. I asked for fifty-two.", "style": "A"}, {"key": "13qehr7", "text": "That makes fifty-three. I asked for fifty-two.", "style": "A"}, {"key": "197ano7", "text": "That makes fifty-four. I asked for fifty-two.", "style": "A"}, {"key": "pvro9v", "text": "That makes fifty-five. I asked for fifty-two.", "style": "A"}, {"key": "bad463", "text": "That makes fifty-six. I asked for fifty-two.", "style": "A"}, {"key": "h1t7na", "text": "That makes fifty-seven. I asked for fifty-two.", "style": "A"}, {"key": "195hwoo", "text": "That makes fifty-eight. I asked for fifty-two.", "style": "A"}, {"key": "oxnjn7", "text": "That makes fifty-nine. I asked for fifty-two.", "style": "A"}, {"key": "14lab43", "text": "That makes sixty. I asked for fifty-two.", "style": "A"}, {"key": "53i586", "text": "That makes sixty-one. I asked for fifty-two.", "style": "A"}, {"key": "pb2hb8", "text": "That makes sixty-two. I asked for fifty-two.", "style": "A"}, {"key": "4fjk7q", "text": "That makes sixty-three. I asked for fifty-two.", "style": "A"}, {"key": "1icgs48", "text": "That makes sixty-four. I asked for fifty-two.", "style": "A"}, {"key": "1pftrck", "text": "That makes sixty-five. I asked for fifty-two.", "style": "A"}, {"key": "1luzspq", "text": "That makes sixty-six. I asked for fifty-two.", "style": "A"}, {"key": "vrb5er", "text": "That makes sixty-seven. I asked for fifty-two.", "style": "A"}, {"key": "sj0ys5", "text": "That makes twenty-three. I asked for thirty-eight.", "style": "A"}, {"key": "12d8eer", "text": "That makes twenty-four. I asked for thirty-eight.", "style": "A"}, {"key": "1nwpzr3", "text": "That makes twenty-five. I asked for thirty-eight.", "style": "A"}, {"key": "xqol6d", "text": "That makes twenty-six. I asked for thirty-eight.", "style": "A"}, {"key": "156k9mm", "text": "That makes twenty-seven. I asked for thirty-eight.", "style": "A"}, {"key": "18ju39k", "text": "That makes twenty-eight. I asked for thirty-eight.", "style": "A"}, {"key": "ez9yq7", "text": "That makes twenty-nine. I asked for thirty-eight.", "style": "A"}, {"key": "1inovwt", "text": "That makes thirty. I asked for thirty-eight.", "style": "A"}, {"key": "9timhu", "text": "That makes thirty-one. I asked for thirty-eight.", "style": "A"}, {"key": "15zdp4g", "text": "That makes thirty-two. I asked for thirty-eight.", "style": "A"}, {"key": "s65zfy", "text": "That makes thirty-three. I asked for thirty-eight.", "style": "A"}, {"key": "8lgukq", "text": "That makes thirty-four. I asked for thirty-eight.", "style": "A"}, {"key": "4jmh2", "text": "That makes thirty-five. I asked for thirty-eight.", "style": "A"}, {"key": "jsc9oe", "text": "That makes thirty-six. I asked for thirty-eight.", "style": "A"}, {"key": "g2e4p1", "text": "That makes thirty-seven. I asked for thirty-eight.", "style": "A"}, {"key": "v3de06", "text": "That makes thirty-nine. I asked for thirty-eight.", "style": "A"}, {"key": "rztoa7", "text": "That makes forty. I asked for thirty-eight.", "style": "A"}, {"key": "149wc9w", "text": "That makes forty-one. I asked for thirty-eight.", "style": "A"}, {"key": "1pb7eje", "text": "That makes forty-two. I asked for thirty-eight.", "style": "A"}, {"key": "z9edto", "text": "That makes forty-three. I asked for thirty-eight.", "style": "A"}, {"key": "i0mms", "text": "That makes forty-four. I asked for thirty-eight.", "style": "A"}, {"key": "p6nh24", "text": "That makes forty-five. I asked for thirty-eight.", "style": "A"}, {"key": "9tk22c", "text": "That makes forty-six. I asked for thirty-eight.", "style": "A"}, {"key": "eui9kz", "text": "That makes forty-seven. I asked for thirty-eight.", "style": "A"}, {"key": "1mkeprt", "text": "That makes forty-eight. I asked for thirty-eight.", "style": "A"}, {"key": "1ez20ek", "text": "That makes forty-nine. I asked for thirty-eight.", "style": "A"}, {"key": "4buevl", "text": "That makes fifty. I asked for thirty-eight.", "style": "A"}, {"key": "1t04z9y", "text": "That makes fifty-one. I asked for thirty-eight.", "style": "A"}, {"key": "1jmkmwk", "text": "That makes fifty-two. I asked for thirty-eight.", "style": "A"}, {"key": "188bn6q", "text": "That makes fifty-three. I asked for thirty-eight.", "style": "A"}, {"key": "1lhu78v", "text": "That is sixty-five, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1cpepnx", "text": "That is sixty-five, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1d0xi2u", "text": "That is sixty-five, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "o18pcw", "text": "That is sixty-five, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "sk1pms", "text": "That is fifteen, but with three coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "fjz0cw", "text": "That is fifteen, but with four coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1lsq3yk", "text": "That is fifteen, but with five coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "v0nun8", "text": "That is fifteen, but with six coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "oyqfil", "text": "That is fifteen, but with seven coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1m5b51n", "text": "That is fifteen, but with eight coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1bujda5", "text": "That makes seventy-five. I asked for ninety.", "style": "A"}, {"key": "n3h5dh", "text": "That makes seventy-six. I asked for ninety.", "style": "A"}, {"key": "14iqv26", "text": "That makes seventy-seven. I asked for ninety.", "style": "A"}, {"key": "15t6mac", "text": "That makes seventy-eight. I asked for ninety.", "style": "A"}, {"key": "cg7v0d", "text": "That makes seventy-nine. I asked for ninety.", "style": "A"}, {"key": "1kteres", "text": "That makes eighty. I asked for ninety.", "style": "A"}, {"key": "ri6cpz", "text": "That makes eighty-one. I asked for ninety.", "style": "A"}, {"key": "10dunlh", "text": "That makes eighty-two. I asked for ninety.", "style": "A"}, {"key": "1tcnb7z", "text": "That makes eighty-three. I asked for ninety.", "style": "A"}, {"key": "1xbimj3", "text": "That makes eighty-four. I asked for ninety.", "style": "A"}, {"key": "1rm965z", "text": "That makes eighty-five. I asked for ninety.", "style": "A"}, {"key": "ijya67", "text": "That makes eighty-six. I asked for ninety.", "style": "A"}, {"key": "1g5i25c", "text": "That makes eighty-seven. I asked for ninety.", "style": "A"}, {"key": "msevja", "text": "That makes eighty-eight. I asked for ninety.", "style": "A"}, {"key": "zrjenb", "text": "That makes eighty-nine. I asked for ninety.", "style": "A"}, {"key": "5svbwc", "text": "That makes ninety-one. I asked for ninety.", "style": "A"}, {"key": "1gm57ji", "text": "That makes ninety-two. I asked for ninety.", "style": "A"}, {"key": "3da0mg", "text": "That makes ninety-three. I asked for ninety.", "style": "A"}, {"key": "1c3922", "text": "That makes ninety-four. I asked for ninety.", "style": "A"}, {"key": "n3e9be", "text": "That makes ninety-five. I asked for ninety.", "style": "A"}]
todo = [r for r in LINES if not (REPO / 'public/audio' / VOICE / f"{r['key']}.mp3").exists()]
json.dump(todo, open(WORK / 'todo.json', 'w'))
print(len(todo), 'lines to render')
assert 0 < len(todo) <= 1500, 'nothing to render — every line already has a clip on main'

# %%
# Chatterbox pins torch 2.6, which breaks Kaggle's own torchvision — so it gets its own venv (uv: Kaggle's python has no ensurepip).
VENV = WORK / 'venv'; PY = VENV / 'bin' / 'python'; READY = VENV / '.ready'
if not READY.exists():
    shutil.rmtree(VENV, ignore_errors=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'uv'], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'venv', str(VENV), '--python', sys.executable], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'pip', 'install', '--python', str(PY), 'setuptools<81', 'chatterbox-tts', 'imageio-ffmpeg'], check=True)
    READY.touch()
print(subprocess.run([str(PY), '-c', "import torch; print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NONE — set the accelerator')"], capture_output=True, text=True).stdout)

# %%
OUT = WORK / 'out' / VOICE
cmd = [str(PY), str(REPO / 'scripts/chatterbox-render.py'), '--voice', VOICE, '--corpus', str(WORK / 'todo.json'), '--out', str(OUT)]
proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in proc.stdout:
    if 'it/s]' in line or not line.strip(): continue   # drop the progress bars
    print(line.rstrip()[:160], flush=True)
print('exit code', proc.wait())

# %%
keys = {r['key'] for r in todo}
clips = sorted(c for c in OUT.glob('*.mp3') if c.stem in keys)
missing = [k for k in keys if not (OUT / f'{k}.mp3').exists()]
stage = WORK / 'stage'; shutil.rmtree(stage, ignore_errors=True); (stage / VOICE).mkdir(parents=True)
for c in clips: shutil.copy2(c, stage / VOICE / c.name)
shutil.make_archive(str(WORK / 'radlic-voice-josh-chapters-g2-3'), 'zip', stage)
print(f'{len(clips)} of {len(todo)} clips in radlic-voice-josh-chapters-g2-3.zip' + (f' — MISSING {len(missing)}: {missing}' if missing else ' — complete'))
