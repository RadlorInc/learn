# %% [markdown]
# # Radlic voice — Grade 1 (part 2 of 3) story chapters in Josh
#
# Renders every line the Grade 1 (part 2 of 3) story chapters can say that has no clip yet — **1500 lines, 73,449 characters** (the lines are
# written into this notebook). Style A (Chatterbox Turbo) for all of them. Rules: `docs/new-flow/voice.md`.
#
# **Before Run All:** Settings → Accelerator → **GPU T4 x2** (or P100), Internet **On**. At the end, download
# `radlic-voice-josh-chapters-g1-2.zip` from the Output panel and hand it back. If the session stops early, Run All
# again in the same session: lines already rendered are skipped.

# %%
import os, sys, subprocess, pathlib, shutil, json
VOICE = 'nzFihrBIvB34imQBuxub'   # Josh
WORK = pathlib.Path('/kaggle/working' if os.path.isdir('/kaggle/working') else '/content')
REPO = WORK / 'learn-main'
if not REPO.exists():
    subprocess.run(['git', 'clone', '--depth', '1', '--branch', 'main', 'https://github.com/RadlorInc/learn.git', str(REPO)], check=True)
LINES = [{"key": "1b4slq1", "text": "You have 13 sharks. Then 12 swim away!", "style": "A"}, {"key": "eg3vz7", "text": "You have 12 squirrels. Pat has 2 squirrels. How many more do you have?", "style": "A"}, {"key": "smqu58", "text": "You have 1 bee. Then you meet 6 more!", "style": "A"}, {"key": "o7rexi", "text": "You have 9 lambs. Then 8 wander off!", "style": "A"}, {"key": "1oypstv", "text": "You have 1 ladybug. Then you meet 5 more!", "style": "A"}, {"key": "1ozbm3b", "text": "You have 9 chicks. Then you spot 1 more!", "style": "A"}, {"key": "15o6u7i", "text": "You have 7 ducklings. Then you spot 5 more!", "style": "A"}, {"key": "1uxjsoa", "text": "You have 5 rabbits. Then 4 wander off!", "style": "A"}, {"key": "1azykcw", "text": "You have 10 butterflies. Then 2 flutter away!", "style": "A"}, {"key": "q5sp3p", "text": "You have 10 sharks. Then 2 swim away!", "style": "A"}, {"key": "eldcv3", "text": "You have 2 squirrels. Then you spot 3 more!", "style": "A"}, {"key": "81fkux", "text": "You have 2 bees. Then you meet 5 more!", "style": "A"}, {"key": "15ajrhi", "text": "You have 12 ladybugs. Then 11 flutter away!", "style": "A"}, {"key": "1hvorni", "text": "You have 12 chicks. Pat has 9 chicks. How many more do you have?", "style": "A"}, {"key": "1hvhob4", "text": "You have 9 rabbits. Then 6 wander off!", "style": "A"}, {"key": "16wovyo", "text": "You have 9 butterflies. Bo has 7 butterflies. How many more do you have?", "style": "A"}, {"key": "mjhsd2", "text": "You have 3 sharks. Then you meet 2 more!", "style": "A"}, {"key": "1saeii9", "text": "You have 6 squirrels. Then 5 wander off!", "style": "A"}, {"key": "ack6r9", "text": "You have 4 bees. Bo has 3 bees. How many more do you have?", "style": "A"}, {"key": "a18gxk", "text": "You have 7 lambs. Then 4 wander off!", "style": "A"}, {"key": "1ozqp43", "text": "You have 10 ladybugs. Bo has 8 ladybugs. How many more do you have?", "style": "A"}, {"key": "14llusw", "text": "You have 12 ducklings. Then 3 wander off!", "style": "A"}, {"key": "8m2m94", "text": "You have 3 rabbits. Then you spot 8 more!", "style": "A"}, {"key": "bbmeay", "text": "You have 4 butterflies. Then you meet 4 more!", "style": "A"}, {"key": "3u7pc8", "text": "You have 12 squirrels. Then you spot 3 more!", "style": "A"}, {"key": "1caxaza", "text": "You have 10 turtles. Then you meet 1 more!", "style": "A"}, {"key": "miwkmn", "text": "You have 8 lambs. Pat has 7 lambs. How many more do you have?", "style": "A"}, {"key": "1hocjcf", "text": "You have 9 ladybugs. Then 7 flutter away!", "style": "A"}, {"key": "1kn4e99", "text": "You have 9 chicks. Then you spot 3 more!", "style": "A"}, {"key": "d28vki", "text": "You have 16 ducklings. Then 9 wander off!", "style": "A"}, {"key": "zl67ry", "text": "You have 4 rabbits. Then 1 wander off!", "style": "A"}, {"key": "17i15xu", "text": "You have 2 butterflies. Then you meet 11 more!", "style": "A"}, {"key": "al9wns", "text": "You have 8 sharks. Finn has 1 shark. How many more do you have?", "style": "A"}, {"key": "zwfyhu", "text": "You have 6 squirrels. Then 4 wander off!", "style": "A"}, {"key": "7bqmgb", "text": "You have 13 bees. Then 11 flutter away!", "style": "A"}, {"key": "1jn7dc", "text": "You have 4 turtles. Finn has 1 turtle. How many more do you have?", "style": "A"}, {"key": "34app3", "text": "You have 3 lambs. Then 1 wander off!", "style": "A"}, {"key": "1vfqbz6", "text": "You have 5 ladybugs. Then you meet 5 more!", "style": "A"}, {"key": "1l0mmc8", "text": "You have 5 chicks. Pat has 3 chicks. How many more do you have?", "style": "A"}, {"key": "dkdq60", "text": "You have 9 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "1palktu", "text": "You have 8 butterflies. Then 3 flutter away!", "style": "A"}, {"key": "g6quog", "text": "You have 5 sharks. Then 1 swim away!", "style": "A"}, {"key": "i7lo8i", "text": "You have 14 bees. Then you meet 1 more!", "style": "A"}, {"key": "1j82dew", "text": "You have 9 turtles. Then 4 swim away!", "style": "A"}, {"key": "jp968r", "text": "You have 11 lambs. Then 4 wander off!", "style": "A"}, {"key": "1eeyv8g", "text": "You have 11 ladybugs. Then you meet 4 more!", "style": "A"}, {"key": "c03fpd", "text": "You have 9 rabbits. Then 1 wander off!", "style": "A"}, {"key": "19lerbo", "text": "You have 8 sharks. Then 2 swim away!", "style": "A"}, {"key": "1i35uzt", "text": "You have 4 squirrels. Pat has 3 squirrels. How many more do you have?", "style": "A"}, {"key": "10exd1q", "text": "You have 12 turtles. Then 6 swim away!", "style": "A"}, {"key": "86unt5", "text": "You have 6 lambs. Pat has 3 lambs. How many more do you have?", "style": "A"}, {"key": "gfubtw", "text": "You have 4 ladybugs. Then 1 flutter away!", "style": "A"}, {"key": "rgp7xj", "text": "You have 6 ducklings. Pat has 3 ducklings. How many more do you have?", "style": "A"}, {"key": "1fcqg2b", "text": "You have 11 butterflies. Then you meet 1 more!", "style": "A"}, {"key": "s5hf6g", "text": "You have 6 sharks. Finn has 4 sharks. How many more do you have?", "style": "A"}, {"key": "bpk5oa", "text": "You have 2 squirrels. Then you spot 4 more!", "style": "A"}, {"key": "13998gt", "text": "You have 1 bee. Then you meet 9 more!", "style": "A"}, {"key": "1nog8y2", "text": "You have 1 ladybug. Then you meet 6 more!", "style": "A"}, {"key": "1xsy58a", "text": "You have 1 chick. Then you spot 10 more!", "style": "A"}, {"key": "1kxya55", "text": "You have 9 ducklings. Then 4 wander off!", "style": "A"}, {"key": "1tt9mt", "text": "You have 6 rabbits. Then 2 wander off!", "style": "A"}, {"key": "6r0gwz", "text": "You have 13 butterflies. Then you meet 3 more!", "style": "A"}, {"key": "1l9b6mf", "text": "You have 4 squirrels. Then you spot 9 more!", "style": "A"}, {"key": "z2pdzx", "text": "You have 2 turtles. Then you meet 7 more!", "style": "A"}, {"key": "8y809q", "text": "You have 6 lambs. Then you spot 1 more!", "style": "A"}, {"key": "g1883t", "text": "You have 5 ladybugs. Bo has 1 ladybug. How many more do you have?", "style": "A"}, {"key": "1s3hfew", "text": "You have 6 chicks. Then you spot 3 more!", "style": "A"}, {"key": "a9xv2o", "text": "You have 11 rabbits. Pat has 4 rabbits. How many more do you have?", "style": "A"}, {"key": "151lqwl", "text": "You have 5 butterflies. Then 3 flutter away!", "style": "A"}, {"key": "1jcu9y2", "text": "You have 11 sharks. Then 6 swim away!", "style": "A"}, {"key": "1e5lk45", "text": "You have 1 squirrel. Then you spot 5 more!", "style": "A"}, {"key": "n5sad6", "text": "You have 5 bees. Then 2 flutter away!", "style": "A"}, {"key": "2kfss6", "text": "You have 9 turtles. Then 6 swim away!", "style": "A"}, {"key": "nvh4ly", "text": "You have 9 lambs. Pat has 3 lambs. How many more do you have?", "style": "A"}, {"key": "mcjx7v", "text": "You have 3 ladybugs. Then 1 flutter away!", "style": "A"}, {"key": "1mldhyc", "text": "You have 12 chicks. Then 11 wander off!", "style": "A"}, {"key": "xyk1da", "text": "You have 12 ducklings. Then you spot 3 more!", "style": "A"}, {"key": "1ilw6jg", "text": "You have 8 rabbits. Then 3 wander off!", "style": "A"}, {"key": "59bcbx", "text": "You have 5 sharks. Then you meet 1 more!", "style": "A"}, {"key": "15j2osc", "text": "You have 2 squirrels. Then you spot 6 more!", "style": "A"}, {"key": "14vjz2x", "text": "You have 8 bees. Then 4 flutter away!", "style": "A"}, {"key": "110q8mz", "text": "You have 16 turtles. Then 7 swim away!", "style": "A"}, {"key": "60ucq9", "text": "You have 5 ladybugs. Then 1 flutter away!", "style": "A"}, {"key": "1cbhpv9", "text": "You have 12 chicks. Then you spot 3 more!", "style": "A"}, {"key": "13af0kz", "text": "You have 4 ducklings. Then 3 wander off!", "style": "A"}, {"key": "9g2eo7", "text": "You have 5 rabbits. Then 3 wander off!", "style": "A"}, {"key": "1o4fppr", "text": "You have 11 butterflies. Bo has 9 butterflies. How many more do you have?", "style": "A"}, {"key": "93pj7l", "text": "You have 6 sharks. Then you meet 2 more!", "style": "A"}, {"key": "1tigshx", "text": "You have 11 squirrels. Then 10 wander off!", "style": "A"}, {"key": "u1d6mi", "text": "You have 9 bees. Then 6 flutter away!", "style": "A"}, {"key": "6g98ge", "text": "You have 7 turtles. Then 4 swim away!", "style": "A"}, {"key": "1r09m0j", "text": "You have 7 lambs. Then you spot 5 more!", "style": "A"}, {"key": "1m7vebg", "text": "You have 1 chick. Then you spot 7 more!", "style": "A"}, {"key": "1eagmj1", "text": "You have 6 ducklings. Then 3 wander off!", "style": "A"}, {"key": "ngqo0y", "text": "You have 8 rabbits. Pat has 4 rabbits. How many more do you have?", "style": "A"}, {"key": "160fgt2", "text": "You have 1 shark. Then you meet 9 more!", "style": "A"}, {"key": "q5xle9", "text": "You have 7 squirrels. Pat has 2 squirrels. How many more do you have?", "style": "A"}, {"key": "1qj2jfz", "text": "You have 8 turtles. Then 6 swim away!", "style": "A"}, {"key": "1tj9wz8", "text": "You have 9 lambs. Pat has 5 lambs. How many more do you have?", "style": "A"}, {"key": "umnhqx", "text": "You have 6 ladybugs. Then 4 flutter away!", "style": "A"}, {"key": "1uif4ug", "text": "You have 12 chicks. Then 4 wander off!", "style": "A"}, {"key": "1b9grv8", "text": "You have 6 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "18e90nx", "text": "You have 6 bees. Then you meet 5 more!", "style": "A"}, {"key": "1rnul6i", "text": "You have 6 turtles. Finn has 4 turtles. How many more do you have?", "style": "A"}, {"key": "3w70rk", "text": "You have 13 ladybugs. Then 1 flutter away!", "style": "A"}, {"key": "fvmaoj", "text": "You have 8 ducklings. Then 7 wander off!", "style": "A"}, {"key": "m8eqzk", "text": "You have 6 rabbits. Then 1 wander off!", "style": "A"}, {"key": "11f1blz", "text": "You have 6 butterflies. Then you meet 9 more!", "style": "A"}, {"key": "kkm5kx", "text": "You have 6 sharks. Then 5 swim away!", "style": "A"}, {"key": "3qishb", "text": "You have 8 bees. Bo has 5 bees. How many more do you have?", "style": "A"}, {"key": "d2d09e", "text": "You have 16 ladybugs. Then 11 flutter away!", "style": "A"}, {"key": "9xb250", "text": "You have 7 chicks. Then you spot 2 more!", "style": "A"}, {"key": "jw6hqp", "text": "You have 6 rabbits. Pat has 3 rabbits. How many more do you have?", "style": "A"}, {"key": "gz0uff", "text": "You have 5 butterflies. Then 1 flutter away!", "style": "A"}, {"key": "39324t", "text": "You have 12 sharks. Then 8 swim away!", "style": "A"}, {"key": "1mu84v1", "text": "You have 10 squirrels. Pat has 2 squirrels. How many more do you have?", "style": "A"}, {"key": "197vf1l", "text": "You have 5 bees. Then you meet 2 more!", "style": "A"}, {"key": "1pxfwps", "text": "You have 4 turtles. Then you meet 2 more!", "style": "A"}, {"key": "1a2sra7", "text": "You have 4 lambs. Pat has 3 lambs. How many more do you have?", "style": "A"}, {"key": "s2wkwy", "text": "You have 7 chicks. Then 4 wander off!", "style": "A"}, {"key": "1xj04wz", "text": "You have 12 ducklings. Pat has 1 duckling. How many more do you have?", "style": "A"}, {"key": "1w531ln", "text": "You have 11 butterflies. Then 6 flutter away!", "style": "A"}, {"key": "1vs5qa4", "text": "You have 10 sharks. Finn has 3 sharks. How many more do you have?", "style": "A"}, {"key": "1a2tzfe", "text": "You have 7 squirrels. Then 1 wander off!", "style": "A"}, {"key": "3j4q67", "text": "You have 10 bees. Then 3 flutter away!", "style": "A"}, {"key": "27o3ok", "text": "You have 13 turtles. Then 1 swim away!", "style": "A"}, {"key": "1kyfmbk", "text": "You have 4 lambs. Then you spot 5 more!", "style": "A"}, {"key": "6sx05d", "text": "You have 9 chicks. Then you spot 7 more!", "style": "A"}, {"key": "1xkddxb", "text": "You have 7 rabbits. Then you spot 5 more!", "style": "A"}, {"key": "hx97hc", "text": "You have 3 butterflies. Then you meet 12 more!", "style": "A"}, {"key": "eovydy", "text": "You have 2 sharks. Then you meet 3 more!", "style": "A"}, {"key": "1wrc9t7", "text": "You have 8 squirrels. Then you spot 1 more!", "style": "A"}, {"key": "mvlnre", "text": "You have 10 bees. Bo has 9 bees. How many more do you have?", "style": "A"}, {"key": "14p23oh", "text": "You have 4 turtles. Then you meet 5 more!", "style": "A"}, {"key": "1u83a", "text": "You have 13 lambs. Then 1 wander off!", "style": "A"}, {"key": "jgmxsd", "text": "You have 7 ladybugs. Bo has 2 ladybugs. How many more do you have?", "style": "A"}, {"key": "1gpuz8i", "text": "You have 5 chicks. Then you spot 2 more!", "style": "A"}, {"key": "175liey", "text": "You have 11 ducklings. Then 2 wander off!", "style": "A"}, {"key": "ucnqqi", "text": "You have 9 rabbits. Pat has 7 rabbits. How many more do you have?", "style": "A"}, {"key": "167ljkn", "text": "You have 8 squirrels. Pat has 5 squirrels. How many more do you have?", "style": "A"}, {"key": "xuc3q7", "text": "You have 5 bees. Then you meet 4 more!", "style": "A"}, {"key": "uw2whf", "text": "You have 8 turtles. Then 2 swim away!", "style": "A"}, {"key": "mn6nc", "text": "You have 7 ladybugs. Then 4 flutter away!", "style": "A"}, {"key": "enb46q", "text": "You have 13 chicks. Then 9 wander off!", "style": "A"}, {"key": "1q5b1st", "text": "You have 11 ducklings. Then 7 wander off!", "style": "A"}, {"key": "1qrxb5b", "text": "You have 9 butterflies. Then 1 flutter away!", "style": "A"}, {"key": "onebvv", "text": "You have 9 sharks. Finn has 2 sharks. How many more do you have?", "style": "A"}, {"key": "6a6770", "text": "You have 7 squirrels. Then you spot 1 more!", "style": "A"}, {"key": "xr4v5k", "text": "You have 10 bees. Then you meet 3 more!", "style": "A"}, {"key": "ja4hc1", "text": "You have 1 turtle. Then you meet 12 more!", "style": "A"}, {"key": "sv96oy", "text": "You have 6 lambs. Then 3 wander off!", "style": "A"}, {"key": "ao3rca", "text": "You have 10 ladybugs. Then you meet 3 more!", "style": "A"}, {"key": "1612b1c", "text": "You have 4 chicks. Pat has 2 chicks. How many more do you have?", "style": "A"}, {"key": "cvgdzg", "text": "You have 2 ducklings. Then you spot 4 more!", "style": "A"}, {"key": "1ukhl5e", "text": "You have 1 rabbit. Then you spot 12 more!", "style": "A"}, {"key": "7bswez", "text": "You have 8 butterflies. Then you meet 3 more!", "style": "A"}, {"key": "u4johh", "text": "You have 3 sharks. Then 2 swim away!", "style": "A"}, {"key": "1gubqgt", "text": "You have 10 squirrels. Then 8 wander off!", "style": "A"}, {"key": "160ufnh", "text": "You have 8 bees. Then you meet 3 more!", "style": "A"}, {"key": "65w20o", "text": "You have 3 turtles. Then you meet 3 more!", "style": "A"}, {"key": "z0og33", "text": "You have 7 lambs. Then you spot 1 more!", "style": "A"}, {"key": "t7sya1", "text": "You have 14 ladybugs. Then 3 flutter away!", "style": "A"}, {"key": "qrzmxt", "text": "You have 3 chicks. Then 1 wander off!", "style": "A"}, {"key": "fxhpif", "text": "You have 4 ducklings. Then you spot 3 more!", "style": "A"}, {"key": "19iuoz6", "text": "You have 12 rabbits. Pat has 7 rabbits. How many more do you have?", "style": "A"}, {"key": "p9597q", "text": "You have 6 butterflies. Then 5 flutter away!", "style": "A"}, {"key": "18q6xl1", "text": "You have 7 squirrels. Pat has 1 squirrel. How many more do you have?", "style": "A"}, {"key": "1mpx0dn", "text": "You have 4 bees. Then you meet 1 more!", "style": "A"}, {"key": "b8be7l", "text": "You have 16 lambs. Then 14 wander off!", "style": "A"}, {"key": "18b1pox", "text": "You have 4 ladybugs. Then you meet 5 more!", "style": "A"}, {"key": "9cu80l", "text": "You have 6 ducklings. Pat has 5 ducklings. How many more do you have?", "style": "A"}, {"key": "oz4ft5", "text": "You have 9 butterflies. Then 3 flutter away!", "style": "A"}, {"key": "186ay16", "text": "You have 4 squirrels. Then 2 wander off!", "style": "A"}, {"key": "k4khya", "text": "You have 4 lambs. Then 1 wander off!", "style": "A"}, {"key": "1ra57tn", "text": "You have 14 chicks. Then 12 wander off!", "style": "A"}, {"key": "g4x5ox", "text": "You have 4 ducklings. Then you spot 5 more!", "style": "A"}, {"key": "10c4hkl", "text": "You have 9 rabbits. Then 5 wander off!", "style": "A"}, {"key": "19cdy5s", "text": "You have 8 sharks. Then 6 swim away!", "style": "A"}, {"key": "122zdnx", "text": "You have 5 squirrels. Then 2 wander off!", "style": "A"}, {"key": "1i4eqmo", "text": "You have 14 bees. Then 2 flutter away!", "style": "A"}, {"key": "1pbknee", "text": "You have 8 turtles. Then 7 swim away!", "style": "A"}, {"key": "1p3e7w4", "text": "You have 9 lambs. Then 6 wander off!", "style": "A"}, {"key": "1qsysab", "text": "You have 12 ladybugs. Bo has 2 ladybugs. How many more do you have?", "style": "A"}, {"key": "jpmzn8", "text": "You have 5 chicks. Then 4 wander off!", "style": "A"}, {"key": "d7oeco", "text": "You have 8 ducklings. Then 2 wander off!", "style": "A"}, {"key": "1mxegly", "text": "You have 16 rabbits. Then 8 wander off!", "style": "A"}, {"key": "10j7drr", "text": "You have 3 sharks. Then you meet 9 more!", "style": "A"}, {"key": "1gpkxvw", "text": "You have 7 squirrels. Pat has 5 squirrels. How many more do you have?", "style": "A"}, {"key": "1le1iei", "text": "You have 2 bees. Then you meet 4 more!", "style": "A"}, {"key": "11pvgow", "text": "You have 13 turtles. Then 5 swim away!", "style": "A"}, {"key": "wplcwr", "text": "You have 12 lambs. Pat has 8 lambs. How many more do you have?", "style": "A"}, {"key": "s8wksv", "text": "You have 7 ladybugs. Then 1 flutter away!", "style": "A"}, {"key": "pj2h2q", "text": "You have 13 chicks. Then 12 wander off!", "style": "A"}, {"key": "5cg5kp", "text": "You have 11 ducklings. Pat has 10 ducklings. How many more do you have?", "style": "A"}, {"key": "1q08rff", "text": "You have 3 rabbits. Then 1 wander off!", "style": "A"}, {"key": "1nwa5o0", "text": "You have 12 butterflies. Then 4 flutter away!", "style": "A"}, {"key": "1hahr5j", "text": "You have 15 sharks. Then 7 swim away!", "style": "A"}, {"key": "1ax6fp0", "text": "You have 7 bees. Then you meet 3 more!", "style": "A"}, {"key": "1pep7xh", "text": "You have 5 turtles. Finn has 2 turtles. How many more do you have?", "style": "A"}, {"key": "1kgv4xd", "text": "You have 7 chicks. Then 5 wander off!", "style": "A"}, {"key": "116dovx", "text": "You have 5 ducklings. Then 4 wander off!", "style": "A"}, {"key": "t1fi19", "text": "You have 13 rabbits. Then 4 wander off!", "style": "A"}, {"key": "1ls8ygf", "text": "You have 4 butterflies. Bo has 3 butterflies. How many more do you have?", "style": "A"}, {"key": "161iddr", "text": "You have 6 squirrels. Then 3 wander off!", "style": "A"}, {"key": "102etrd", "text": "You have 9 bees. Then you meet 6 more!", "style": "A"}, {"key": "1axjfl3", "text": "You have 1 turtle. Then you meet 7 more!", "style": "A"}, {"key": "w42698", "text": "You have 6 lambs. Then 1 wander off!", "style": "A"}, {"key": "1vvxfd8", "text": "You have 9 ladybugs. Then 6 flutter away!", "style": "A"}, {"key": "cx7trj", "text": "You have 3 chicks. Then you spot 3 more!", "style": "A"}, {"key": "djugau", "text": "You have 3 ducklings. Then you spot 1 more!", "style": "A"}, {"key": "totvk5", "text": "You have 12 rabbits. Pat has 1 rabbit. How many more do you have?", "style": "A"}, {"key": "1iwwraz", "text": "You have 7 sharks. Then 4 swim away!", "style": "A"}, {"key": "1i6nstf", "text": "You have 7 squirrels. Pat has 4 squirrels. How many more do you have?", "style": "A"}, {"key": "1hfqrwu", "text": "You have 7 turtles. Then you meet 5 more!", "style": "A"}, {"key": "1lm9ep4", "text": "You have 9 lambs. Then you spot 6 more!", "style": "A"}, {"key": "snxx08", "text": "You have 3 ladybugs. Then you meet 5 more!", "style": "A"}, {"key": "1w9f2f0", "text": "You have 10 chicks. Then 2 wander off!", "style": "A"}, {"key": "18hq179", "text": "You have 8 rabbits. Then 4 wander off!", "style": "A"}, {"key": "o650pz", "text": "You have 7 butterflies. Then you meet 2 more!", "style": "A"}, {"key": "1a6q6ac", "text": "You have 16 sharks. Then 5 swim away!", "style": "A"}, {"key": "1i3lp7y", "text": "You have 8 bees. Then 5 flutter away!", "style": "A"}, {"key": "1m8y8pg", "text": "You have 11 turtles. Finn has 6 turtles. How many more do you have?", "style": "A"}, {"key": "1274oxa", "text": "You have 6 ladybugs. Then 5 flutter away!", "style": "A"}, {"key": "gzf3fm", "text": "You have 6 chicks. Pat has 1 chick. How many more do you have?", "style": "A"}, {"key": "gmf840", "text": "You have 4 ducklings. Then you spot 2 more!", "style": "A"}, {"key": "1dt83vo", "text": "You have 8 rabbits. Then you spot 1 more!", "style": "A"}, {"key": "1famvfz", "text": "You have 3 sharks. Then you meet 1 more!", "style": "A"}, {"key": "sf5m5e", "text": "You have 3 squirrels. Then you spot 7 more!", "style": "A"}, {"key": "fedd7t", "text": "You have 5 bees. Bo has 4 bees. How many more do you have?", "style": "A"}, {"key": "btz5ul", "text": "You have 5 turtles. Then you meet 2 more!", "style": "A"}, {"key": "11yiebe", "text": "You have 8 lambs. Then 5 wander off!", "style": "A"}, {"key": "152rj9g", "text": "You have 13 ladybugs. Then you meet 2 more!", "style": "A"}, {"key": "1gmjpmo", "text": "You have 11 rabbits. Then 5 wander off!", "style": "A"}, {"key": "r0rc48", "text": "You have 1 butterfly. Then you meet 1 more!", "style": "A"}, {"key": "1q2g8ir", "text": "You have 1 squirrel. Then you spot 10 more!", "style": "A"}, {"key": "1nkn5ir", "text": "You have 3 bees. Then you meet 6 more!", "style": "A"}, {"key": "1bjjovk", "text": "You have 11 turtles. Then 3 swim away!", "style": "A"}, {"key": "mxrwfq", "text": "You have 14 lambs. Then you spot 2 more!", "style": "A"}, {"key": "15cmdt3", "text": "You have 8 chicks. Then you spot 4 more!", "style": "A"}, {"key": "lrdals", "text": "You have 12 ducklings. Then you spot 1 more!", "style": "A"}, {"key": "1bmizt4", "text": "You have 9 butterflies. Then 4 flutter away!", "style": "A"}, {"key": "1bv6pbt", "text": "You have 8 sharks. Then you meet 8 more!", "style": "A"}, {"key": "1ruk5oz", "text": "You have 5 squirrels. Then 4 wander off!", "style": "A"}, {"key": "gdzelg", "text": "You have 6 ladybugs. Then you meet 4 more!", "style": "A"}, {"key": "ikmmqw", "text": "You have 6 rabbits. Then you spot 7 more!", "style": "A"}, {"key": "zz9bf3", "text": "You have 11 butterflies. Then you meet 5 more!", "style": "A"}, {"key": "su13vm", "text": "You have 7 sharks. Then you meet 2 more!", "style": "A"}, {"key": "zejr1c", "text": "You have 11 squirrels. Then 6 wander off!", "style": "A"}, {"key": "52tbvw", "text": "You have 8 bees. Bo has 6 bees. How many more do you have?", "style": "A"}, {"key": "o8kpwf", "text": "You have 13 lambs. Then 2 wander off!", "style": "A"}, {"key": "1akxvj1", "text": "You have 13 ducklings. Then 9 wander off!", "style": "A"}, {"key": "zwxsyc", "text": "You have 11 rabbits. Pat has 8 rabbits. How many more do you have?", "style": "A"}, {"key": "1ursvl8", "text": "You have 4 butterflies. Then 1 flutter away!", "style": "A"}, {"key": "12m0sgw", "text": "You have 2 sharks. Then you meet 9 more!", "style": "A"}, {"key": "5l8pi7", "text": "You have 11 squirrels. Then 7 wander off!", "style": "A"}, {"key": "gvm1fj", "text": "You have 13 lambs. Then 11 wander off!", "style": "A"}, {"key": "303gxt", "text": "You have 13 chicks. Then 8 wander off!", "style": "A"}, {"key": "3fe5ub", "text": "You have 11 ducklings. Then 10 wander off!", "style": "A"}, {"key": "jurr8a", "text": "You have 7 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "rcr2cy", "text": "You have 10 butterflies. Then you meet 1 more!", "style": "A"}, {"key": "5cg38j", "text": "You have 7 squirrels. Then 2 wander off!", "style": "A"}, {"key": "19qeq8i", "text": "You have 10 turtles. Finn has 9 turtles. How many more do you have?", "style": "A"}, {"key": "kdhdb9", "text": "You have 11 chicks. Then 2 wander off!", "style": "A"}, {"key": "1ra3j4u", "text": "You have 8 sharks. Then 4 swim away!", "style": "A"}, {"key": "s7hc99", "text": "You have 12 squirrels. Then 6 wander off!", "style": "A"}, {"key": "hp33kn", "text": "You have 4 turtles. Then 2 swim away!", "style": "A"}, {"key": "17n0yye", "text": "You have 5 lambs. Then 4 wander off!", "style": "A"}, {"key": "8wsxa3", "text": "You have 7 ladybugs. Bo has 4 ladybugs. How many more do you have?", "style": "A"}, {"key": "eee0t", "text": "You have 3 ducklings. Then you spot 8 more!", "style": "A"}, {"key": "rvjdy5", "text": "You have 12 rabbits. Pat has 6 rabbits. How many more do you have?", "style": "A"}, {"key": "14gbq4b", "text": "You have 7 squirrels. Then you spot 8 more!", "style": "A"}, {"key": "ui7rlu", "text": "You have 12 turtles. Then 2 swim away!", "style": "A"}, {"key": "bef8de", "text": "You have 5 lambs. Pat has 3 lambs. How many more do you have?", "style": "A"}, {"key": "pshoq2", "text": "You have 3 ladybugs. Then 2 flutter away!", "style": "A"}, {"key": "1laqx62", "text": "You have 6 chicks. Then 3 wander off!", "style": "A"}, {"key": "12b7ddb", "text": "You have 8 rabbits. Then 6 wander off!", "style": "A"}, {"key": "174woqn", "text": "You have 5 sharks. Finn has 2 sharks. How many more do you have?", "style": "A"}, {"key": "1y542q3", "text": "You have 5 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "18yeij0", "text": "You have 3 bees. Then you meet 7 more!", "style": "A"}, {"key": "b92ud5", "text": "You have 11 turtles. Finn has 5 turtles. How many more do you have?", "style": "A"}, {"key": "1f3l1en", "text": "You have 3 ducklings. Then you spot 2 more!", "style": "A"}, {"key": "10t564i", "text": "You have 5 rabbits. Then you spot 8 more!", "style": "A"}, {"key": "iwo6u7", "text": "You have 11 butterflies. Then 2 flutter away!", "style": "A"}, {"key": "gyc31h", "text": "You have 9 squirrels. Then 6 wander off!", "style": "A"}, {"key": "1bb1wkc", "text": "You have 9 lambs. Then you spot 2 more!", "style": "A"}, {"key": "wybkgl", "text": "You have 7 rabbits. Then you spot 7 more!", "style": "A"}, {"key": "9lik5z", "text": "You have 5 sharks. Then you meet 3 more!", "style": "A"}, {"key": "1gfm9o6", "text": "You have 11 squirrels. Then 4 wander off!", "style": "A"}, {"key": "n8rc9u", "text": "You have 6 bees. Then 3 flutter away!", "style": "A"}, {"key": "a5db65", "text": "You have 10 turtles. Then 7 swim away!", "style": "A"}, {"key": "16gmx28", "text": "You have 7 lambs. Then you spot 8 more!", "style": "A"}, {"key": "1ey5l0q", "text": "You have 8 ladybugs. Then 3 flutter away!", "style": "A"}, {"key": "f7lzzt", "text": "You have 6 chicks. Then 2 wander off!", "style": "A"}, {"key": "bds8tp", "text": "You have 8 ducklings. Then 1 wander off!", "style": "A"}, {"key": "18p1wyj", "text": "You have 8 rabbits. Then 2 wander off!", "style": "A"}, {"key": "pywo6h", "text": "You have 2 squirrels. Then you spot 5 more!", "style": "A"}, {"key": "n317jc", "text": "You have 9 bees. Then 4 flutter away!", "style": "A"}, {"key": "1tsr8ed", "text": "You have 1 lamb. Then you spot 2 more!", "style": "A"}, {"key": "16d6p8y", "text": "You have 11 ladybugs. Then you meet 2 more!", "style": "A"}, {"key": "i2sgmu", "text": "You have 4 chicks. Then you spot 12 more!", "style": "A"}, {"key": "p7pbys", "text": "You have 7 ducklings. Then 5 wander off!", "style": "A"}, {"key": "139h9me", "text": "You have 6 rabbits. Then 3 wander off!", "style": "A"}, {"key": "qj1inp", "text": "You have 9 butterflies. Bo has 8 butterflies. How many more do you have?", "style": "A"}, {"key": "18eod0r", "text": "You have 7 sharks. Then you meet 1 more!", "style": "A"}, {"key": "2f15io", "text": "You have 8 squirrels. Then you spot 4 more!", "style": "A"}, {"key": "1i1vrfk", "text": "You have 13 lambs. Then 3 wander off!", "style": "A"}, {"key": "1esu2x", "text": "You have 9 ladybugs. Then 5 flutter away!", "style": "A"}, {"key": "4c22rb", "text": "You have 3 butterflies. Then you meet 6 more!", "style": "A"}, {"key": "1yq3072", "text": "You have 8 squirrels. Then 2 wander off!", "style": "A"}, {"key": "4d24ez", "text": "You have 7 bees. Then you meet 2 more!", "style": "A"}, {"key": "114rguw", "text": "You have 10 turtles. Then you meet 3 more!", "style": "A"}, {"key": "15fccem", "text": "You have 6 lambs. Pat has 2 lambs. How many more do you have?", "style": "A"}, {"key": "1jcb9um", "text": "You have 12 chicks. Then 6 wander off!", "style": "A"}, {"key": "n2rtxj", "text": "You have 6 ducklings. Then 1 wander off!", "style": "A"}, {"key": "harywx", "text": "You have 2 rabbits. Then you spot 4 more!", "style": "A"}, {"key": "mmhlg", "text": "You have 8 sharks. Finn has 2 sharks. How many more do you have?", "style": "A"}, {"key": "9ba9wq", "text": "You have 13 bees. Then 12 flutter away!", "style": "A"}, {"key": "1cmalzx", "text": "You have 9 turtles. Then 1 swim away!", "style": "A"}, {"key": "aomj4h", "text": "You have 12 ladybugs. Then 10 flutter away!", "style": "A"}, {"key": "p6dmbi", "text": "You have 7 chicks. Then you spot 4 more!", "style": "A"}, {"key": "1y9kdpl", "text": "You have 1 rabbit. Then you spot 2 more!", "style": "A"}, {"key": "kai4t9", "text": "You have 14 butterflies. Then 10 flutter away!", "style": "A"}, {"key": "lle4zy", "text": "You have 5 squirrels. Then you spot 5 more!", "style": "A"}, {"key": "17luwp5", "text": "You have 1 bee. Then you meet 5 more!", "style": "A"}, {"key": "17623ub", "text": "You have 9 turtles. Then 3 swim away!", "style": "A"}, {"key": "ujw9u6", "text": "You have 7 lambs. Then 6 wander off!", "style": "A"}, {"key": "1eg47sv", "text": "You have 6 ladybugs. Bo has 3 ladybugs. How many more do you have?", "style": "A"}, {"key": "14jixlx", "text": "You have 7 chicks. Then 1 wander off!", "style": "A"}, {"key": "1krv4jn", "text": "You have 8 ducklings. Then you spot 3 more!", "style": "A"}, {"key": "2ir8my", "text": "You have 14 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "tgvz8s", "text": "You have 5 butterflies. Then 4 flutter away!", "style": "A"}, {"key": "1ruw6wv", "text": "You have 16 squirrels. Then 13 wander off!", "style": "A"}, {"key": "1repy28", "text": "You have 4 bees. Then you meet 4 more!", "style": "A"}, {"key": "1ib6vub", "text": "You have 7 lambs. Pat has 6 lambs. How many more do you have?", "style": "A"}, {"key": "t4ymde", "text": "You have 8 chicks. Then you spot 3 more!", "style": "A"}, {"key": "1xcmpxm", "text": "You have 12 ducklings. Pat has 5 ducklings. How many more do you have?", "style": "A"}, {"key": "txx8fw", "text": "You have 4 rabbits. Then you spot 5 more!", "style": "A"}, {"key": "skkzmt", "text": "You have 10 sharks. Then you meet 3 more!", "style": "A"}, {"key": "1oi0u3g", "text": "You have 5 bees. Then 4 flutter away!", "style": "A"}, {"key": "wd5s40", "text": "You have 9 turtles. Finn has 5 turtles. How many more do you have?", "style": "A"}, {"key": "q5iu8k", "text": "You have 5 ladybugs. Then 2 flutter away!", "style": "A"}, {"key": "vkojzw", "text": "You have 6 chicks. Then you spot 7 more!", "style": "A"}, {"key": "1dpdea5", "text": "You have 4 butterflies. Bo has 1 butterfly. How many more do you have?", "style": "A"}, {"key": "ietl03", "text": "You have 9 squirrels. Then 8 wander off!", "style": "A"}, {"key": "910kac", "text": "You have 14 bees. Then 6 flutter away!", "style": "A"}, {"key": "srxpbm", "text": "You have 3 lambs. Then you spot 2 more!", "style": "A"}, {"key": "1qss11s", "text": "You have 10 ladybugs. Then 8 flutter away!", "style": "A"}, {"key": "3h824m", "text": "You have 8 chicks. Then 5 wander off!", "style": "A"}, {"key": "mfbnuz", "text": "You have 8 rabbits. Pat has 3 rabbits. How many more do you have?", "style": "A"}, {"key": "1ssaai1", "text": "You have 4 butterflies. Then 2 flutter away!", "style": "A"}, {"key": "cy7l3v", "text": "You have 13 sharks. Then 9 swim away!", "style": "A"}, {"key": "1yactjm", "text": "You have 11 turtles. Then 5 swim away!", "style": "A"}, {"key": "d0tjzg", "text": "You have 8 lambs. Pat has 6 lambs. How many more do you have?", "style": "A"}, {"key": "7kz5qi", "text": "You have 7 ladybugs. Then 6 flutter away!", "style": "A"}, {"key": "1rxcgu5", "text": "You have 13 chicks. Then 4 wander off!", "style": "A"}, {"key": "4vpde9", "text": "You have 13 ducklings. Then you spot 1 more!", "style": "A"}, {"key": "iabszu", "text": "You have 10 butterflies. Then 8 flutter away!", "style": "A"}, {"key": "xfam85", "text": "You have 11 sharks. Finn has 10 sharks. How many more do you have?", "style": "A"}, {"key": "1qbmh8a", "text": "You have 10 bees. Then 4 flutter away!", "style": "A"}, {"key": "1wqkl58", "text": "You have 6 turtles. Then 3 swim away!", "style": "A"}, {"key": "rf6w7l", "text": "You have 5 lambs. Then 1 wander off!", "style": "A"}, {"key": "fqmoi8", "text": "You have 10 rabbits. Then 4 wander off!", "style": "A"}, {"key": "n5e4kt", "text": "You have 6 butterflies. Bo has 3 butterflies. How many more do you have?", "style": "A"}, {"key": "1kvny5n", "text": "You have 5 turtles. Then you meet 4 more!", "style": "A"}, {"key": "ia2gtz", "text": "You have 7 lambs. Then 5 wander off!", "style": "A"}, {"key": "qskg40", "text": "You have 6 butterflies. Then 3 flutter away!", "style": "A"}, {"key": "1q20bfb", "text": "You have 5 squirrels. Pat has 2 squirrels. How many more do you have?", "style": "A"}, {"key": "etdw9o", "text": "You have 8 bees. Then 7 flutter away!", "style": "A"}, {"key": "jl1wkr", "text": "You have 13 turtles. Then 2 swim away!", "style": "A"}, {"key": "usft7t", "text": "You have 10 chicks. Then 9 wander off!", "style": "A"}, {"key": "1savzo4", "text": "You have 11 ducklings. Pat has 6 ducklings. How many more do you have?", "style": "A"}, {"key": "g083t7", "text": "You have 1 rabbit. Then you spot 8 more!", "style": "A"}, {"key": "sdtnfp", "text": "You have 5 butterflies. Then you meet 6 more!", "style": "A"}, {"key": "1ye3mot", "text": "You have 7 sharks. Then you meet 7 more!", "style": "A"}, {"key": "1067qq2", "text": "You have 3 bees. Then you meet 10 more!", "style": "A"}, {"key": "x8kjz6", "text": "You have 11 turtles. Finn has 1 turtle. How many more do you have?", "style": "A"}, {"key": "1koqq5y", "text": "You have 8 ladybugs. Then you meet 4 more!", "style": "A"}, {"key": "13gd3ej", "text": "You have 5 chicks. Pat has 4 chicks. How many more do you have?", "style": "A"}, {"key": "jiy19n", "text": "You have 7 ducklings. Then you spot 2 more!", "style": "A"}, {"key": "lryca6", "text": "You have 12 butterflies. Then you meet 3 more!", "style": "A"}, {"key": "1p76la6", "text": "You have 7 sharks. Then 1 swim away!", "style": "A"}, {"key": "pm27d4", "text": "You have 13 squirrels. Then 11 wander off!", "style": "A"}, {"key": "d3z0ye", "text": "You have 10 bees. Bo has 5 bees. How many more do you have?", "style": "A"}, {"key": "pyg53w", "text": "You have 5 lambs. Then you spot 6 more!", "style": "A"}, {"key": "jpk7rc", "text": "You have 1 chick. Then you spot 3 more!", "style": "A"}, {"key": "sg1nq2", "text": "You have 13 rabbits. Then you spot 3 more!", "style": "A"}, {"key": "1fyp91w", "text": "You have 9 butterflies. Then 8 flutter away!", "style": "A"}, {"key": "1lywkwr", "text": "You have 6 sharks. Then 3 swim away!", "style": "A"}, {"key": "1ybatdn", "text": "You have 6 squirrels. Pat has 3 squirrels. How many more do you have?", "style": "A"}, {"key": "np17i", "text": "You have 5 turtles. Then 2 swim away!", "style": "A"}, {"key": "up34j7", "text": "You have 9 lambs. Pat has 8 lambs. How many more do you have?", "style": "A"}, {"key": "1rad4dt", "text": "You have 5 ladybugs. Then you meet 4 more!", "style": "A"}, {"key": "15q5wxy", "text": "You have 12 butterflies. Then 2 flutter away!", "style": "A"}, {"key": "2mmknj", "text": "You have 10 sharks. Then you meet 1 more!", "style": "A"}, {"key": "yu6ggj", "text": "You have 4 squirrels. Then 1 wander off!", "style": "A"}, {"key": "ldcpr0", "text": "You have 12 turtles. Finn has 9 turtles. How many more do you have?", "style": "A"}, {"key": "clv173", "text": "You have 10 ladybugs. Then 5 flutter away!", "style": "A"}, {"key": "rm6z9g", "text": "You have 4 chicks. Pat has 1 chick. How many more do you have?", "style": "A"}, {"key": "18hv5v7", "text": "You have 7 ducklings. Then 4 wander off!", "style": "A"}, {"key": "cpqtxh", "text": "You have 2 butterflies. Then you meet 7 more!", "style": "A"}, {"key": "vl1hqi", "text": "You have 3 sharks. Then you meet 6 more!", "style": "A"}, {"key": "z878t4", "text": "You have 13 squirrels. Then 8 wander off!", "style": "A"}, {"key": "1khcezg", "text": "You have 4 bees. Then you meet 8 more!", "style": "A"}, {"key": "1vfp5wu", "text": "You have 5 turtles. Then you meet 3 more!", "style": "A"}, {"key": "dokouq", "text": "You have 10 lambs. Then you spot 2 more!", "style": "A"}, {"key": "kkayzf", "text": "You have 13 ladybugs. Then 8 flutter away!", "style": "A"}, {"key": "y7yzsv", "text": "You have 7 chicks. Then 3 wander off!", "style": "A"}, {"key": "100vcwz", "text": "You have 11 sharks. Then 7 swim away!", "style": "A"}, {"key": "1o8k0a1", "text": "You have 12 squirrels. Then you spot 4 more!", "style": "A"}, {"key": "29apdp", "text": "You have 6 turtles. Then 2 swim away!", "style": "A"}, {"key": "ciwnpy", "text": "You have 8 lambs. Pat has 1 lamb. How many more do you have?", "style": "A"}, {"key": "1cr1jr4", "text": "You have 2 ladybugs. Then you meet 4 more!", "style": "A"}, {"key": "13c13oa", "text": "You have 13 chicks. Then 1 wander off!", "style": "A"}, {"key": "icy4gt", "text": "You have 16 ducklings. Then 4 wander off!", "style": "A"}, {"key": "e1itei", "text": "You have 6 butterflies. Then you meet 6 more!", "style": "A"}, {"key": "1cmv5sc", "text": "You have 13 sharks. Then 2 swim away!", "style": "A"}, {"key": "3djv20", "text": "You have 10 turtles. Finn has 3 turtles. How many more do you have?", "style": "A"}, {"key": "125m3ij", "text": "You have 7 ladybugs. Then 5 flutter away!", "style": "A"}, {"key": "10n2ama", "text": "You have 9 chicks. Then 2 wander off!", "style": "A"}, {"key": "3pty2q", "text": "You have 4 ducklings. Then you spot 4 more!", "style": "A"}, {"key": "syrp80", "text": "You have 8 rabbits. Then 7 wander off!", "style": "A"}, {"key": "9vh3a9", "text": "You have 1 shark. Then you meet 4 more!", "style": "A"}, {"key": "adbhf9", "text": "You have 12 bees. Bo has 4 bees. How many more do you have?", "style": "A"}, {"key": "eg8p0q", "text": "You have 3 turtles. Then you meet 5 more!", "style": "A"}, {"key": "mbn0zt", "text": "You have 5 lambs. Then you spot 5 more!", "style": "A"}, {"key": "9uz001", "text": "You have 12 ladybugs. Bo has 8 ladybugs. How many more do you have?", "style": "A"}, {"key": "1ksi4do", "text": "You have 11 rabbits. Then 1 wander off!", "style": "A"}, {"key": "tt2n9i", "text": "You have 8 butterflies. Then 7 flutter away!", "style": "A"}, {"key": "1imd3eg", "text": "You have 11 sharks. Then you meet 1 more!", "style": "A"}, {"key": "1azh0gr", "text": "You have 11 turtles. Then 4 swim away!", "style": "A"}, {"key": "bsujz3", "text": "You have 9 chicks. Then 5 wander off!", "style": "A"}, {"key": "1j1jc57", "text": "You have 2 rabbits. Then you spot 6 more!", "style": "A"}, {"key": "3rkamm", "text": "You have 12 sharks. Finn has 7 sharks. How many more do you have?", "style": "A"}, {"key": "1lmqpra", "text": "You have 4 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "1qov4d4", "text": "You have 3 bees. Then you meet 3 more!", "style": "A"}, {"key": "1eya9w9", "text": "You have 9 turtles. Then you meet 2 more!", "style": "A"}, {"key": "11kq4b7", "text": "You have 2 lambs. Then you spot 2 more!", "style": "A"}, {"key": "1wquc3d", "text": "You have 1 ladybug. Then you meet 7 more!", "style": "A"}, {"key": "pjsjne", "text": "You have 1 duckling. Then you spot 2 more!", "style": "A"}, {"key": "142wi2g", "text": "You have 7 butterflies. Bo has 5 butterflies. How many more do you have?", "style": "A"}, {"key": "18cuo7t", "text": "You have 4 sharks. Then 3 swim away!", "style": "A"}, {"key": "1nlf1ll", "text": "You have 8 squirrels. Then 7 wander off!", "style": "A"}, {"key": "1p304vk", "text": "You have 13 bees. Then 3 flutter away!", "style": "A"}, {"key": "1kkjjt0", "text": "You have 12 ladybugs. Then 6 flutter away!", "style": "A"}, {"key": "11vh6it", "text": "You have 4 chicks. Then you spot 2 more!", "style": "A"}, {"key": "12kqiu6", "text": "You have 7 ducklings. Then 3 wander off!", "style": "A"}, {"key": "187lui9", "text": "You have 6 rabbits. Then you spot 8 more!", "style": "A"}, {"key": "1ubjmlz", "text": "You have 5 sharks. Then 2 swim away!", "style": "A"}, {"key": "yll8a2", "text": "You have 10 squirrels. Pat has 7 squirrels. How many more do you have?", "style": "A"}, {"key": "7h4cpg", "text": "You have 7 bees. Then 6 flutter away!", "style": "A"}, {"key": "k8x5gx", "text": "You have 5 turtles. Then you meet 6 more!", "style": "A"}, {"key": "l2z5qn", "text": "You have 14 lambs. Then you spot 1 more!", "style": "A"}, {"key": "1hgd639", "text": "You have 8 ducklings. Then you spot 5 more!", "style": "A"}, {"key": "1crw8cf", "text": "You have 9 sharks. Finn has 6 sharks. How many more do you have?", "style": "A"}, {"key": "dbnrw2", "text": "You have 13 bees. Then 1 flutter away!", "style": "A"}, {"key": "3pmhwr", "text": "You have 14 turtles. Then you meet 2 more!", "style": "A"}, {"key": "1lg62ha", "text": "You have 11 ladybugs. Then 9 flutter away!", "style": "A"}, {"key": "bwj43x", "text": "You have 10 chicks. Pat has 4 chicks. How many more do you have?", "style": "A"}, {"key": "qgkyj8", "text": "You have 6 ducklings. Then 4 wander off!", "style": "A"}, {"key": "61tzbu", "text": "You have 8 butterflies. Bo has 4 butterflies. How many more do you have?", "style": "A"}, {"key": "juy8cf", "text": "You have 4 sharks. Then you meet 2 more!", "style": "A"}, {"key": "1f8vpro", "text": "You have 8 squirrels. Then 4 wander off!", "style": "A"}, {"key": "z2ao57", "text": "You have 14 bees. Then you meet 2 more!", "style": "A"}, {"key": "fbbbso", "text": "You have 3 turtles. Then 2 swim away!", "style": "A"}, {"key": "vmn9fn", "text": "You have 10 rabbits. Pat has 2 rabbits. How many more do you have?", "style": "A"}, {"key": "c2i2cy", "text": "You have 5 ladybugs. Then 4 flutter away!", "style": "A"}, {"key": "1wfqmjr", "text": "You have 11 chicks. Then 8 wander off!", "style": "A"}, {"key": "x5fdwl", "text": "You have 8 ducklings. Pat has 7 ducklings. How many more do you have?", "style": "A"}, {"key": "5oyqvi", "text": "You have 11 butterflies. Then 1 flutter away!", "style": "A"}, {"key": "1wj35rt", "text": "You have 9 sharks. Finn has 4 sharks. How many more do you have?", "style": "A"}, {"key": "hnljrt", "text": "You have 10 bees. Then 1 flutter away!", "style": "A"}, {"key": "396c1p", "text": "You have 6 turtles. Finn has 5 turtles. How many more do you have?", "style": "A"}, {"key": "5gdmpb", "text": "You have 8 ladybugs. Then 4 flutter away!", "style": "A"}, {"key": "3f7o7f", "text": "You have 6 ducklings. Then you spot 1 more!", "style": "A"}, {"key": "unzsmu", "text": "You have 7 rabbits. Then 2 wander off!", "style": "A"}, {"key": "1098aw8", "text": "You have 12 butterflies. Bo has 7 butterflies. How many more do you have?", "style": "A"}, {"key": "ktss4c", "text": "You have 4 squirrels. Then you spot 4 more!", "style": "A"}, {"key": "pvqzgk", "text": "You have 4 bees. Bo has 1 bee. How many more do you have?", "style": "A"}, {"key": "14hjmk7", "text": "You have 11 ladybugs. Then you meet 5 more!", "style": "A"}, {"key": "qakcp8", "text": "You have 3 chicks. Then you spot 6 more!", "style": "A"}, {"key": "1626tdv", "text": "You have 11 ducklings. Then 1 wander off!", "style": "A"}, {"key": "zflioz", "text": "You have 14 rabbits. Then you spot 1 more!", "style": "A"}, {"key": "2p20gp", "text": "You have 5 butterflies. Then you meet 2 more!", "style": "A"}, {"key": "sprtha", "text": "You have 6 sharks. Then you meet 7 more!", "style": "A"}, {"key": "1ynin5d", "text": "You have 7 bees. Then 5 flutter away!", "style": "A"}, {"key": "1gi9t2f", "text": "You have 6 ladybugs. Then you meet 1 more!", "style": "A"}, {"key": "1qhzfu4", "text": "You have 11 chicks. Then 5 wander off!", "style": "A"}, {"key": "1mw12e7", "text": "You have 1 rabbit. Then you spot 4 more!", "style": "A"}, {"key": "ebd9qq", "text": "You have 6 sharks. Finn has 2 sharks. How many more do you have?", "style": "A"}, {"key": "1epalov", "text": "You have 9 bees. Then 1 flutter away!", "style": "A"}, {"key": "bytc6y", "text": "You have 1 turtle. Then you meet 8 more!", "style": "A"}, {"key": "u2hx88", "text": "You have 2 lambs. Then you spot 7 more!", "style": "A"}, {"key": "pgjr32", "text": "You have 9 ladybugs. Then 4 flutter away!", "style": "A"}, {"key": "7he1tu", "text": "You have 6 ducklings. Then you spot 2 more!", "style": "A"}, {"key": "1drn91v", "text": "You have 11 butterflies. Bo has 5 butterflies. How many more do you have?", "style": "A"}, {"key": "reoq20", "text": "You have 11 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "1ltnm5d", "text": "You have 9 bees. Bo has 8 bees. How many more do you have?", "style": "A"}, {"key": "93a4bv", "text": "You have 2 turtles. Then you meet 1 more!", "style": "A"}, {"key": "1txg5b1", "text": "You have 10 ladybugs. Bo has 6 ladybugs. How many more do you have?", "style": "A"}, {"key": "1ckhrn5", "text": "You have 5 chicks. Then you spot 3 more!", "style": "A"}, {"key": "hj2q18", "text": "You have 13 rabbits. Then 10 wander off!", "style": "A"}, {"key": "1fn7rlf", "text": "You have 6 butterflies. Then 2 flutter away!", "style": "A"}, {"key": "18782fn", "text": "You have 9 sharks. Then 2 swim away!", "style": "A"}, {"key": "ezy9ol", "text": "You have 11 squirrels. Then 5 wander off!", "style": "A"}, {"key": "rhxm9q", "text": "You have 3 lambs. Then you spot 6 more!", "style": "A"}, {"key": "axhb64", "text": "You have 3 ladybugs. Then you meet 1 more!", "style": "A"}, {"key": "hlolgp", "text": "You have 1 chick. Then you spot 11 more!", "style": "A"}, {"key": "126uc8i", "text": "You have 2 rabbits. Then you spot 5 more!", "style": "A"}, {"key": "p4xf6d", "text": "You have 9 butterflies. Then you meet 2 more!", "style": "A"}, {"key": "ipilap", "text": "You have 12 sharks. Finn has 4 sharks. How many more do you have?", "style": "A"}, {"key": "nbz2y4", "text": "You have 9 squirrels. Then 1 wander off!", "style": "A"}, {"key": "7uehvf", "text": "You have 5 bees. Then 1 flutter away!", "style": "A"}, {"key": "19s8gdo", "text": "You have 2 lambs. Then you spot 3 more!", "style": "A"}, {"key": "17stq14", "text": "You have 9 ladybugs. Then 2 flutter away!", "style": "A"}, {"key": "x0phgk", "text": "You have 7 chicks. Pat has 5 chicks. How many more do you have?", "style": "A"}, {"key": "lm25mw", "text": "You have 5 rabbits. Then 2 wander off!", "style": "A"}, {"key": "z7qhsj", "text": "You have 12 butterflies. Then 5 flutter away!", "style": "A"}, {"key": "r27ru3", "text": "You have 7 bees. Bo has 1 bee. How many more do you have?", "style": "A"}, {"key": "1cqiss6", "text": "You have 1 lamb. Then you spot 12 more!", "style": "A"}, {"key": "1810yjc", "text": "You have 3 chicks. Then you spot 2 more!", "style": "A"}, {"key": "1m9q870", "text": "You have 7 rabbits. Pat has 3 rabbits. How many more do you have?", "style": "A"}, {"key": "12rexh5", "text": "You have 2 butterflies. Then you meet 3 more!", "style": "A"}, {"key": "auro8t", "text": "You have 10 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "1k0pvp5", "text": "You have 8 turtles. Then you meet 1 more!", "style": "A"}, {"key": "mp6etm", "text": "You have 14 lambs. Then 13 wander off!", "style": "A"}, {"key": "vo4oaj", "text": "You have 9 rabbits. Then 3 wander off!", "style": "A"}, {"key": "1461rtr", "text": "You have 13 butterflies. Then 4 flutter away!", "style": "A"}, {"key": "v55233", "text": "You have 10 bees. Then you meet 2 more!", "style": "A"}, {"key": "1fr2rvw", "text": "You have 3 turtles. Then you meet 7 more!", "style": "A"}, {"key": "10v3pab", "text": "You have 8 lambs. Then 6 wander off!", "style": "A"}, {"key": "156mjp1", "text": "You have 7 ladybugs. Then you meet 2 more!", "style": "A"}, {"key": "cmb1r0", "text": "You have 5 chicks. Then you spot 8 more!", "style": "A"}, {"key": "mcq203", "text": "You have 5 rabbits. Then you spot 3 more!", "style": "A"}, {"key": "13y5geu", "text": "You have 2 butterflies. Then you meet 6 more!", "style": "A"}, {"key": "1kydvby", "text": "You have 1 shark. Then you meet 1 more!", "style": "A"}, {"key": "dwh6ct", "text": "You have 8 squirrels. Then 3 wander off!", "style": "A"}, {"key": "1xqbj1x", "text": "You have 9 bees. Then you meet 2 more!", "style": "A"}, {"key": "1mbuh04", "text": "You have 5 turtles. Then 4 swim away!", "style": "A"}, {"key": "bx7rf1", "text": "You have 3 butterflies. Then you meet 4 more!", "style": "A"}, {"key": "1mimk6s", "text": "You have 9 squirrels. Pat has 3 squirrels. How many more do you have?", "style": "A"}, {"key": "1bski1g", "text": "You have 11 turtles. Then 7 swim away!", "style": "A"}, {"key": "i4k8df", "text": "You have 7 lambs. Then 1 wander off!", "style": "A"}, {"key": "ficrve", "text": "You have 10 chicks. Then 8 wander off!", "style": "A"}, {"key": "1ade6r", "text": "You have 11 ducklings. Then you spot 5 more!", "style": "A"}, {"key": "1106nax", "text": "You have 1 butterfly. Then you meet 6 more!", "style": "A"}, {"key": "1m767ck", "text": "You have 1 shark. Then you meet 7 more!", "style": "A"}, {"key": "1y920id", "text": "You have 1 bee. Then you meet 1 more!", "style": "A"}, {"key": "a52ikh", "text": "You have 10 rabbits. Then 3 wander off!", "style": "A"}, {"key": "107s6xd", "text": "You have 11 squirrels. Then 1 wander off!", "style": "A"}, {"key": "l1tq56", "text": "You have 7 bees. Bo has 5 bees. How many more do you have?", "style": "A"}, {"key": "33x3xl", "text": "You have 7 lambs. Then 3 wander off!", "style": "A"}, {"key": "1qp7c3d", "text": "You have 9 ladybugs. Bo has 8 ladybugs. How many more do you have?", "style": "A"}, {"key": "ua6efq", "text": "You have 4 chicks. Then you spot 3 more!", "style": "A"}, {"key": "17tagdt", "text": "You have 10 rabbits. Pat has 8 rabbits. How many more do you have?", "style": "A"}, {"key": "1pke3rq", "text": "You have 11 lambs. Then you spot 5 more!", "style": "A"}, {"key": "1cuvykr", "text": "You have 6 rabbits. Then 4 wander off!", "style": "A"}, {"key": "1g6mrnb", "text": "You have 1 butterfly. Then you meet 8 more!", "style": "A"}, {"key": "1hevzn9", "text": "You have 12 sharks. Finn has 8 sharks. How many more do you have?", "style": "A"}, {"key": "1u51o8e", "text": "You have 3 squirrels. Then you spot 3 more!", "style": "A"}, {"key": "5idtv", "text": "You have 11 chicks. Pat has 3 chicks. How many more do you have?", "style": "A"}, {"key": "1l05fro", "text": "You have 3 ducklings. Then 1 wander off!", "style": "A"}, {"key": "109yopu", "text": "You have 8 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "7a029d", "text": "You have 13 bees. Then 4 flutter away!", "style": "A"}, {"key": "c1bhdz", "text": "You have 10 ladybugs. Bo has 4 ladybugs. How many more do you have?", "style": "A"}, {"key": "jwh9g1", "text": "You have 6 ducklings. Then you spot 3 more!", "style": "A"}, {"key": "t8cdyj", "text": "You have 7 rabbits. Pat has 6 rabbits. How many more do you have?", "style": "A"}, {"key": "iqk1f5", "text": "You have 8 butterflies. Then 6 flutter away!", "style": "A"}, {"key": "1xf22zy", "text": "You have 12 squirrels. Pat has 9 squirrels. How many more do you have?", "style": "A"}, {"key": "leyimj", "text": "You have 11 turtles. Then you meet 1 more!", "style": "A"}, {"key": "1dvb8u8", "text": "You have 6 lambs. Pat has 1 lamb. How many more do you have?", "style": "A"}, {"key": "14f33vk", "text": "You have 1 ladybug. Then you meet 8 more!", "style": "A"}, {"key": "20bbdb", "text": "You have 10 chicks. Then you spot 3 more!", "style": "A"}, {"key": "1uoy8k2", "text": "You have 4 ducklings. Pat has 2 ducklings. How many more do you have?", "style": "A"}, {"key": "rxn8q", "text": "You have 2 lambs. Then you spot 1 more!", "style": "A"}, {"key": "y3a1", "text": "You have 10 ladybugs. Then you meet 2 more!", "style": "A"}, {"key": "1p5oz9j", "text": "You have 10 chicks. Pat has 6 chicks. How many more do you have?", "style": "A"}, {"key": "15x5st0", "text": "You have 4 ducklings. Then 2 wander off!", "style": "A"}, {"key": "qvj2bb", "text": "You have 11 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "zrun0p", "text": "You have 10 butterflies. Bo has 2 butterflies. How many more do you have?", "style": "A"}, {"key": "1yjtw33", "text": "You have 4 sharks. Then 1 swim away!", "style": "A"}, {"key": "1xldne0", "text": "You have 9 lambs. Then 2 wander off!", "style": "A"}, {"key": "1f30cla", "text": "You have 5 ladybugs. Bo has 3 ladybugs. How many more do you have?", "style": "A"}, {"key": "3kadte", "text": "You have 10 squirrels. Then 5 wander off!", "style": "A"}, {"key": "1mw9cl6", "text": "You have 14 lambs. Then 2 wander off!", "style": "A"}, {"key": "bz9a4o", "text": "You have 6 chicks. Then 5 wander off!", "style": "A"}, {"key": "ov2jbk", "text": "You have 7 butterflies. Then you meet 3 more!", "style": "A"}, {"key": "1s2irwk", "text": "You have 7 squirrels. Then 3 wander off!", "style": "A"}, {"key": "scvt68", "text": "You have 6 bees. Then you meet 6 more!", "style": "A"}, {"key": "stu14u", "text": "You have 9 turtles. Finn has 3 turtles. How many more do you have?", "style": "A"}, {"key": "l5ubpx", "text": "You have 5 lambs. Then you spot 1 more!", "style": "A"}, {"key": "1aav6ea", "text": "You have 11 ladybugs. Then 5 flutter away!", "style": "A"}, {"key": "h7gtyx", "text": "You have 7 bees. Then you meet 8 more!", "style": "A"}, {"key": "19o2xxm", "text": "You have 6 turtles. Then 1 swim away!", "style": "A"}, {"key": "g2ivr", "text": "You have 2 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "ietqzv", "text": "You have 6 bees. Then you meet 3 more!", "style": "A"}, {"key": "8o88n4", "text": "You have 10 ducklings. Pat has 5 ducklings. How many more do you have?", "style": "A"}, {"key": "10wu96m", "text": "You have 2 rabbits. Then you spot 1 more!", "style": "A"}, {"key": "5vf4y3", "text": "You have 14 sharks. Then you meet 1 more!", "style": "A"}, {"key": "1khlbh4", "text": "You have 11 bees. Then you meet 2 more!", "style": "A"}, {"key": "dqmmaa", "text": "You have 7 chicks. Pat has 3 chicks. How many more do you have?", "style": "A"}, {"key": "1q8se0b", "text": "You have 12 butterflies. Bo has 2 butterflies. How many more do you have?", "style": "A"}, {"key": "1g33sqy", "text": "You have 11 bees. Then you meet 4 more!", "style": "A"}, {"key": "yv05sh", "text": "You have 1 turtle. Then you meet 1 more!", "style": "A"}, {"key": "7vvc01", "text": "You have 3 lambs. Then you spot 3 more!", "style": "A"}, {"key": "11jwj4q", "text": "You have 15 ladybugs. Then 1 flutter away!", "style": "A"}, {"key": "1edup26", "text": "You have 9 rabbits. Pat has 3 rabbits. How many more do you have?", "style": "A"}, {"key": "d63326", "text": "You have 4 butterflies. Then 3 flutter away!", "style": "A"}, {"key": "nqfnre", "text": "You have 2 sharks. Then you meet 7 more!", "style": "A"}, {"key": "crwz0p", "text": "You have 11 squirrels. Then you spot 5 more!", "style": "A"}, {"key": "18pyvwr", "text": "You have 7 turtles. Then 1 swim away!", "style": "A"}, {"key": "vc8786", "text": "You have 16 lambs. Then 11 wander off!", "style": "A"}, {"key": "m95vvb", "text": "You have 2 ladybugs. Then you meet 5 more!", "style": "A"}, {"key": "15jk12n", "text": "You have 8 chicks. Then 6 wander off!", "style": "A"}, {"key": "iubwav", "text": "You have 4 rabbits. Then 2 wander off!", "style": "A"}, {"key": "1875ion", "text": "You have 8 butterflies. Then 4 flutter away!", "style": "A"}, {"key": "ac6lli", "text": "You have 9 sharks. Then 7 swim away!", "style": "A"}, {"key": "g57xrb", "text": "You have 1 bee. Then you meet 10 more!", "style": "A"}, {"key": "5j3a12", "text": "You have 6 turtles. Finn has 1 turtle. How many more do you have?", "style": "A"}, {"key": "q7fh3e", "text": "You have 2 ducklings. Then you spot 6 more!", "style": "A"}, {"key": "1d3wu4s", "text": "You have 2 sharks. Then you meet 5 more!", "style": "A"}, {"key": "roi220", "text": "You have 5 squirrels. Then 1 wander off!", "style": "A"}, {"key": "qr35hb", "text": "You have 8 bees. Then 6 flutter away!", "style": "A"}, {"key": "1aartb5", "text": "You have 11 lambs. Then 6 wander off!", "style": "A"}, {"key": "1qj190q", "text": "You have 9 ladybugs. Then you meet 1 more!", "style": "A"}, {"key": "l1w5h9", "text": "You have 1 chick. Then you spot 8 more!", "style": "A"}, {"key": "1qh4cq1", "text": "You have 3 ducklings. Then you spot 4 more!", "style": "A"}, {"key": "aq7rve", "text": "You have 10 rabbits. Pat has 5 rabbits. How many more do you have?", "style": "A"}, {"key": "dk59xw", "text": "You have 4 squirrels. Pat has 1 squirrel. How many more do you have?", "style": "A"}, {"key": "2jfwzn", "text": "You have 1 bee. Then you meet 7 more!", "style": "A"}, {"key": "80cvge", "text": "You have 6 ducklings. Pat has 1 duckling. How many more do you have?", "style": "A"}, {"key": "niegax", "text": "You have 1 squirrel. Then you spot 1 more!", "style": "A"}, {"key": "sassli", "text": "You have 9 bees. Then you meet 3 more!", "style": "A"}, {"key": "1evdubx", "text": "You have 11 ladybugs. Then 4 flutter away!", "style": "A"}, {"key": "1lzkt79", "text": "You have 6 bees. Bo has 5 bees. How many more do you have?", "style": "A"}, {"key": "e228b2", "text": "You have 4 chicks. Then 1 wander off!", "style": "A"}, {"key": "1w2zauu", "text": "You have 12 rabbits. Pat has 3 rabbits. How many more do you have?", "style": "A"}, {"key": "7s8sun", "text": "You have 2 bees. Then you meet 3 more!", "style": "A"}, {"key": "1gqgvqy", "text": "You have 4 lambs. Pat has 1 lamb. How many more do you have?", "style": "A"}, {"key": "372nro", "text": "You have 6 chicks. Then 1 wander off!", "style": "A"}, {"key": "180zq34", "text": "You have 12 ducklings. Pat has 7 ducklings. How many more do you have?", "style": "A"}, {"key": "ia56a9", "text": "You have 12 sharks. Then 4 swim away!", "style": "A"}, {"key": "1eantb8", "text": "You have 5 squirrels. Then you spot 3 more!", "style": "A"}, {"key": "11osnon", "text": "You have 11 turtles. Then you meet 5 more!", "style": "A"}, {"key": "o073ei", "text": "You have 5 chicks. Then you spot 11 more!", "style": "A"}, {"key": "1fy5k6t", "text": "You have 7 butterflies. Bo has 2 butterflies. How many more do you have?", "style": "A"}, {"key": "1czo8pu", "text": "You have 3 sharks. Then 1 swim away!", "style": "A"}, {"key": "eiguka", "text": "You have 8 bees. Then 1 flutter away!", "style": "A"}, {"key": "djrqku", "text": "You have 11 ladybugs. Bo has 6 ladybugs. How many more do you have?", "style": "A"}, {"key": "1jieopo", "text": "You have 3 chicks. Then 2 wander off!", "style": "A"}, {"key": "10c8v6d", "text": "You have 13 ducklings. Then 1 wander off!", "style": "A"}, {"key": "1fmerrx", "text": "You have 3 butterflies. Then 1 flutter away!", "style": "A"}, {"key": "xx09ga", "text": "You have 12 squirrels. Pat has 5 squirrels. How many more do you have?", "style": "A"}, {"key": "133vbwh", "text": "You have 2 ladybugs. Then you meet 3 more!", "style": "A"}, {"key": "14ku1vt", "text": "You have 6 butterflies. Then you meet 7 more!", "style": "A"}, {"key": "g9i3bx", "text": "You have 4 sharks. Then you meet 8 more!", "style": "A"}, {"key": "q6q0p9", "text": "You have 16 turtles. Then 14 swim away!", "style": "A"}, {"key": "1vrc75m", "text": "You have 6 chicks. Pat has 2 chicks. How many more do you have?", "style": "A"}, {"key": "girzmc", "text": "You have 12 squirrels. Then 1 wander off!", "style": "A"}, {"key": "1os1fng", "text": "You have 5 bees. Then you meet 1 more!", "style": "A"}, {"key": "1kdkzhj", "text": "You have 4 ladybugs. Then you meet 3 more!", "style": "A"}, {"key": "125ihpn", "text": "You have 10 ducklings. Then 8 wander off!", "style": "A"}, {"key": "1nq1n28", "text": "You have 11 sharks. Then 8 swim away!", "style": "A"}, {"key": "1ldck9f", "text": "You have 3 lambs. Then you spot 9 more!", "style": "A"}, {"key": "74ggix", "text": "You have 11 ducklings. Pat has 5 ducklings. How many more do you have?", "style": "A"}, {"key": "1hzhkgp", "text": "You have 7 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "vd89kc", "text": "You have 2 bees. Then you meet 6 more!", "style": "A"}, {"key": "1lzcn8t", "text": "You have 8 turtles. Finn has 7 turtles. How many more do you have?", "style": "A"}, {"key": "5tin5n", "text": "You have 2 ladybugs. Then you meet 1 more!", "style": "A"}, {"key": "1jft64p", "text": "You have 4 sharks. Then you meet 4 more!", "style": "A"}, {"key": "esmazv", "text": "You have 11 bees. Then 4 flutter away!", "style": "A"}, {"key": "rzbzcj", "text": "You have 11 lambs. Then you spot 2 more!", "style": "A"}, {"key": "kk5ugo", "text": "You have 4 chicks. Then 3 wander off!", "style": "A"}, {"key": "1acpoi2", "text": "You have 9 ducklings. Then 5 wander off!", "style": "A"}, {"key": "1bfd4yv", "text": "You have 4 rabbits. Then you spot 8 more!", "style": "A"}, {"key": "ql9syc", "text": "You have 8 butterflies. Then 5 flutter away!", "style": "A"}, {"key": "qbdp9q", "text": "You have 12 sharks. Then 7 swim away!", "style": "A"}, {"key": "wmvvo2", "text": "You have 14 squirrels. Then 12 wander off!", "style": "A"}, {"key": "1pkgvu8", "text": "You have 5 turtles. Then you meet 1 more!", "style": "A"}, {"key": "cs6pmh", "text": "You have 12 chicks. Then 3 wander off!", "style": "A"}, {"key": "8vefa", "text": "You have 8 rabbits. Then 5 wander off!", "style": "A"}, {"key": "ejxyzu", "text": "You have 11 butterflies. Then you meet 2 more!", "style": "A"}, {"key": "vl1zlb", "text": "You have 3 bees. Then you meet 2 more!", "style": "A"}, {"key": "sapo43", "text": "You have 9 ladybugs. Then you meet 2 more!", "style": "A"}, {"key": "1c7ru7u", "text": "You have 3 ducklings. Then you spot 5 more!", "style": "A"}, {"key": "14pfalw", "text": "You have 11 rabbits. Then 9 wander off!", "style": "A"}, {"key": "rgo0zy", "text": "You have 11 butterflies. Bo has 6 butterflies. How many more do you have?", "style": "A"}, {"key": "hrs4pa", "text": "You have 7 squirrels. Then 5 wander off!", "style": "A"}, {"key": "gf18xl", "text": "You have 12 bees. Bo has 11 bees. How many more do you have?", "style": "A"}, {"key": "hki2gh", "text": "You have 10 ladybugs. Bo has 2 ladybugs. How many more do you have?", "style": "A"}, {"key": "1yugau0", "text": "You have 4 chicks. Then you spot 1 more!", "style": "A"}, {"key": "1klayp7", "text": "You have 13 ducklings. Then 12 wander off!", "style": "A"}, {"key": "16pfwye", "text": "You have 6 rabbits. Then you spot 10 more!", "style": "A"}, {"key": "oug5wm", "text": "You have 4 sharks. Then you meet 1 more!", "style": "A"}, {"key": "yg1d34", "text": "You have 13 lambs. Then you spot 1 more!", "style": "A"}, {"key": "jbnav1", "text": "You have 4 ladybugs. Then you meet 1 more!", "style": "A"}, {"key": "13z1rx4", "text": "You have 11 ducklings. Then 4 wander off!", "style": "A"}, {"key": "14m6oag", "text": "You have 4 butterflies. Then you meet 2 more!", "style": "A"}, {"key": "1qs7dw9", "text": "You have 4 sharks. Finn has 3 sharks. How many more do you have?", "style": "A"}, {"key": "7rhc03", "text": "You have 4 squirrels. Then you spot 5 more!", "style": "A"}, {"key": "geghed", "text": "You have 11 bees. Then 6 flutter away!", "style": "A"}, {"key": "1h8fnwr", "text": "You have 5 lambs. Then 3 wander off!", "style": "A"}, {"key": "p3a9ga", "text": "You have 12 butterflies. Bo has 5 butterflies. How many more do you have?", "style": "A"}, {"key": "rmhh1r", "text": "You have 10 squirrels. Then 2 wander off!", "style": "A"}, {"key": "dxcgl7", "text": "You have 16 bees. Then 10 flutter away!", "style": "A"}, {"key": "1nqdqjz", "text": "You have 13 ducklings. Then 3 wander off!", "style": "A"}, {"key": "168i6ds", "text": "You have 7 sharks. Then 3 swim away!", "style": "A"}, {"key": "1g96nzk", "text": "You have 8 squirrels. Pat has 1 squirrel. How many more do you have?", "style": "A"}, {"key": "1u8ffmn", "text": "You have 10 turtles. Then 1 swim away!", "style": "A"}, {"key": "1lj51wb", "text": "You have 10 lambs. Pat has 2 lambs. How many more do you have?", "style": "A"}, {"key": "1mpts9a", "text": "You have 6 ladybugs. Then you meet 2 more!", "style": "A"}, {"key": "19eqqun", "text": "You have 11 ducklings. Pat has 7 ducklings. How many more do you have?", "style": "A"}, {"key": "mne3p1", "text": "You have 5 sharks. Finn has 4 sharks. How many more do you have?", "style": "A"}, {"key": "1mqurdx", "text": "You have 10 bees. Then 5 flutter away!", "style": "A"}, {"key": "1cqw0rs", "text": "You have 7 rabbits. Then you spot 4 more!", "style": "A"}, {"key": "7yibiv", "text": "You have 13 squirrels. Then 9 wander off!", "style": "A"}, {"key": "1e5yup7", "text": "You have 12 bees. Bo has 2 bees. How many more do you have?", "style": "A"}, {"key": "1bq94of", "text": "You have 5 ladybugs. Bo has 2 ladybugs. How many more do you have?", "style": "A"}, {"key": "emsb1i", "text": "You have 2 chicks. Then you spot 5 more!", "style": "A"}, {"key": "1tayiqv", "text": "You have 8 ducklings. Then 3 wander off!", "style": "A"}, {"key": "umb80a", "text": "You have 16 rabbits. Then 11 wander off!", "style": "A"}, {"key": "1v815p1", "text": "You have 6 butterflies. Then you meet 3 more!", "style": "A"}, {"key": "1f3jwtt", "text": "You have 1 shark. Then you meet 11 more!", "style": "A"}, {"key": "1jkfy6m", "text": "You have 7 lambs. Pat has 5 lambs. How many more do you have?", "style": "A"}, {"key": "8xdifx", "text": "You have 3 rabbits. Then you spot 3 more!", "style": "A"}, {"key": "17udf8t", "text": "You have 4 butterflies. Then you meet 9 more!", "style": "A"}, {"key": "ztkcq7", "text": "You have 8 sharks. Finn has 5 sharks. How many more do you have?", "style": "A"}, {"key": "1dysuh2", "text": "You have 10 turtles. Finn has 5 turtles. How many more do you have?", "style": "A"}, {"key": "10ydnwk", "text": "You have 11 ladybugs. Then 3 flutter away!", "style": "A"}, {"key": "1uzdyp5", "text": "You have 10 chicks. Pat has 1 chick. How many more do you have?", "style": "A"}, {"key": "3iq49k", "text": "You have 2 sharks. Then you meet 1 more!", "style": "A"}, {"key": "nvh5j2", "text": "You have 5 squirrels. Then 3 wander off!", "style": "A"}, {"key": "19l1ymf", "text": "You have 6 bees. Then you meet 7 more!", "style": "A"}, {"key": "1jlkyu6", "text": "You have 4 turtles. Then 3 swim away!", "style": "A"}, {"key": "1muy4ka", "text": "You have 7 lambs. Then 2 wander off!", "style": "A"}, {"key": "rhp0z7", "text": "You have 2 ducklings. Then you spot 5 more!", "style": "A"}, {"key": "g0lmiu", "text": "You have 11 rabbits. Pat has 6 rabbits. How many more do you have?", "style": "A"}, {"key": "803vv1", "text": "You have 5 squirrels. Pat has 4 squirrels. How many more do you have?", "style": "A"}, {"key": "12cf1ak", "text": "You have 8 ladybugs. Then 5 flutter away!", "style": "A"}, {"key": "1opitt", "text": "How many rabbits are left?", "style": "A"}, {"key": "t3kau3", "text": "How many butterflies altogether?", "style": "A"}, {"key": "sgorr6", "text": "How many more sharks do you have?", "style": "A"}, {"key": "jhppvo", "text": "How many squirrels altogether?", "style": "A"}, {"key": "1rg6zwt", "text": "How many bees are left?", "style": "A"}, {"key": "trccbj", "text": "How many turtles are left?", "style": "A"}, {"key": "1keezl1", "text": "How many lambs are left?", "style": "A"}, {"key": "1whnm0z", "text": "How many ladybugs altogether?", "style": "A"}, {"key": "5eyuot", "text": "How many chicks are left?", "style": "A"}, {"key": "1l5jona", "text": "How many ducklings are left?", "style": "A"}, {"key": "m1funb", "text": "How many butterflies are left?", "style": "A"}, {"key": "1xdjsd6", "text": "How many sharks are left?", "style": "A"}, {"key": "1jit8b4", "text": "How many squirrels are left?", "style": "A"}, {"key": "zenfbv", "text": "How many more bees do you have?", "style": "A"}, {"key": "1gny9jn", "text": "How many turtles altogether?", "style": "A"}, {"key": "gj3il5", "text": "How many rabbits altogether?", "style": "A"}, {"key": "qwtjst", "text": "How many lambs altogether?", "style": "A"}, {"key": "1ov53rp", "text": "How many chicks altogether?", "style": "A"}, {"key": "1yiu6a8", "text": "How many more ducklings do you have?", "style": "A"}, {"key": "1lze78v", "text": "How many ladybugs are left?", "style": "A"}, {"key": "53grxu", "text": "How many sharks altogether?", "style": "A"}, {"key": "10d8ihx", "text": "How many bees altogether?", "style": "A"}, {"key": "8jb6sh", "text": "How many more ladybugs do you have?", "style": "A"}, {"key": "ajmchr", "text": "How many more chicks do you have?", "style": "A"}, {"key": "79i51t", "text": "How many more rabbits do you have?", "style": "A"}, {"key": "gzxfua", "text": "How many more squirrels do you have?", "style": "A"}, {"key": "ml9dyl", "text": "How many more lambs do you have?", "style": "A"}, {"key": "sy9m9a", "text": "How many ducklings altogether?", "style": "A"}, {"key": "1qnug1b", "text": "How many more turtles do you have?", "style": "A"}, {"key": "tsw0qz", "text": "How many more butterflies do you have?", "style": "A"}, {"key": "61ktsv", "text": "How many crabs altogether?", "style": "A"}, {"key": "3a7h3i", "text": "It is time to wake up. What time is it now?", "style": "A"}, {"key": "1csberr", "text": "Time to have breakfast at half past 8. Move the hands!", "style": "A"}, {"key": "17uu9l5", "text": "It is time to catch the bus. What time is it now?", "style": "A"}, {"key": "c9g7t5", "text": "Time to get to school at 10 o'clock. Move the hands!", "style": "A"}, {"key": "rksunw", "text": "It is time to go out to play. What time is it now?", "style": "A"}, {"key": "3wqmmw", "text": "Time to eat lunch at ten to 1. Move the hands!", "style": "A"}, {"key": "jzurg2", "text": "It is time to do some painting. What time is it now?", "style": "A"}, {"key": "ipj10j", "text": "Time to go to the park at half past 3. Move the hands!", "style": "A"}, {"key": "m5dpyh", "text": "It is time to have dinner. What time is it now?", "style": "A"}, {"key": "7wfsvr", "text": "Time to look at the moon at 6 o'clock. Move the hands!", "style": "A"}, {"key": "1fz8e0l", "text": "Time to have breakfast at ten to 9. Move the hands!", "style": "A"}, {"key": "1ezv9v", "text": "Time to get to school at quarter past 10. Move the hands!", "style": "A"}, {"key": "1vrzcbg", "text": "Time to eat lunch at 12 o'clock. Move the hands!", "style": "A"}, {"key": "1gjwaix", "text": "Time to go to the park at ten to 4. Move the hands!", "style": "A"}, {"key": "eoxu12", "text": "Time to look at the moon at half past 6. Move the hands!", "style": "A"}, {"key": "13pwwha", "text": "Time to have breakfast at 8 o'clock. Move the hands!", "style": "A"}, {"key": "ggt8e2", "text": "Time to get to school at twenty to 11. Move the hands!", "style": "A"}, {"key": "1a11lfn", "text": "Time to eat lunch at half past 12. Move the hands!", "style": "A"}, {"key": "1jr96o2", "text": "Time to go to the park at 3 o'clock. Move the hands!", "style": "A"}, {"key": "89k94u", "text": "Time to eat lunch at twenty to 1. Move the hands!", "style": "A"}, {"key": "9l0qlq", "text": "Time to have breakfast at twenty-five to 9. Move the hands!", "style": "A"}, {"key": "d8zudb", "text": "Time to go to the park at twenty to 4. Move the hands!", "style": "A"}, {"key": "1r49tbr", "text": "Time to look at the moon at quarter past 6. Move the hands!", "style": "A"}, {"key": "95cswp", "text": "Time to get to school at five to 11. Move the hands!", "style": "A"}, {"key": "1mz36sx", "text": "Time to have breakfast at twenty to 9. Move the hands!", "style": "A"}, {"key": "9gfcsf", "text": "Time to get to school at quarter to 11. Move the hands!", "style": "A"}, {"key": "1s78wei", "text": "Time to go to the park at quarter to 4. Move the hands!", "style": "A"}, {"key": "10z79xz", "text": "Time to get to school at twenty-five to 11. Move the hands!", "style": "A"}, {"key": "153ils0", "text": "Time to look at the moon at ten past 6. Move the hands!", "style": "A"}, {"key": "1bgq6of", "text": "Time to eat lunch at five to 1. Move the hands!", "style": "A"}, {"key": "37xige", "text": "Time to get to school at half past 10. Move the hands!", "style": "A"}, {"key": "18a8mq6", "text": "Time to go to the park at five to 4. Move the hands!", "style": "A"}, {"key": "1u3fvd4", "text": "Time to look at the moon at twenty to 7. Move the hands!", "style": "A"}, {"key": "qsd3tv", "text": "Time to eat lunch at quarter to 1. Move the hands!", "style": "A"}, {"key": "2dwi2g", "text": "Time to have breakfast at five to 9. Move the hands!", "style": "A"}, {"key": "1pbq56z", "text": "Time to look at the moon at five past 6. Move the hands!", "style": "A"}, {"key": "h98ctj", "text": "Time to eat lunch at twenty-five to 1. Move the hands!", "style": "A"}, {"key": "qptkyu", "text": "Time to have breakfast at quarter to 9. Move the hands!", "style": "A"}, {"key": "lfu1wi", "text": "Time to look at the moon at twenty past 6. Move the hands!", "style": "A"}, {"key": "76rpt2", "text": "Time to go to the park at twenty-five to 4. Move the hands!", "style": "A"}, {"key": "18a5q7a", "text": "Time to get to school at ten to 11. Move the hands!", "style": "A"}, {"key": "1hoa2gm", "text": "Time to look at the moon at ten to 7. Move the hands!", "style": "A"}, {"key": "7vh01", "text": "Time to look at the moon at five to 7. Move the hands!", "style": "A"}, {"key": "ujlcjv", "text": "Time to look at the moon at twenty-five past 6. Move the hands!", "style": "A"}, {"key": "d4k8nl", "text": "Time to look at the moon at twenty-five to 7. Move the hands!", "style": "A"}, {"key": "17usc9x", "text": "Time to look at the moon at quarter to 7. Move the hands!", "style": "A"}, {"key": "1es3qkp", "text": "Yes — 7 o'clock. Time to wake up!", "style": "A"}, {"key": "wsgchb", "text": "Yes — half past 8. Time to have breakfast!", "style": "A"}, {"key": "73ma2g", "text": "Yes — ten to 10. Time to catch the bus!", "style": "A"}, {"key": "1o13bp3", "text": "Yes — 10 o'clock. Time to get to school!", "style": "A"}, {"key": "1oa5qf4", "text": "Yes — quarter past 11. Time to go out to play!", "style": "A"}, {"key": "rlz2o6", "text": "Yes — ten to 1. Time to eat lunch!", "style": "A"}, {"key": "1rkg0xh", "text": "Yes — 1 o'clock. Time to do some painting!", "style": "A"}, {"key": "dshmlt", "text": "Yes — half past 3. Time to go to the park!", "style": "A"}, {"key": "nq8i35", "text": "Yes — twenty to 6. Time to have dinner!", "style": "A"}, {"key": "rslrp5", "text": "Yes — 6 o'clock. Time to look at the moon!", "style": "A"}, {"key": "tz7p0q", "text": "Yes — half past 7. Time to wake up!", "style": "A"}, {"key": "1u9dok", "text": "Yes — quarter to 9. Time to have breakfast!", "style": "A"}, {"key": "8orcba", "text": "Yes — 9 o'clock. Time to catch the bus!", "style": "A"}, {"key": "1cw9dpu", "text": "Yes — half past 10. Time to get to school!", "style": "A"}, {"key": "1mj9vma", "text": "Yes — five to 12. Time to go out to play!", "style": "A"}, {"key": "7qo5du", "text": "Yes — 12 o'clock. Time to eat lunch!", "style": "A"}, {"key": "ixk01k", "text": "Yes — half past 1. Time to do some painting!", "style": "A"}, {"key": "kzfs30", "text": "Yes — twenty-five to 4. Time to go to the park!", "style": "A"}, {"key": "lrt5je", "text": "Yes — 5 o'clock. Time to have dinner!", "style": "A"}, {"key": "1swou8e", "text": "Yes — twenty to 8. Time to wake up!", "style": "A"}, {"key": "wujpwm", "text": "Yes — 8 o'clock. Time to have breakfast!", "style": "A"}, {"key": "19hhuvh", "text": "Yes — half past 9. Time to catch the bus!", "style": "A"}, {"key": "y9rc23", "text": "Yes — five to 11. Time to get to school!", "style": "A"}, {"key": "19hmuwo", "text": "Yes — 11 o'clock. Time to go out to play!", "style": "A"}, {"key": "1jdj96v", "text": "Yes — half past 12. Time to eat lunch!", "style": "A"}, {"key": "jdvxma", "text": "Yes — ten to 2. Time to do some painting!", "style": "A"}, {"key": "yq8gg", "text": "Yes — 3 o'clock. Time to go to the park!", "style": "A"}, {"key": "7zitpm", "text": "Yes — quarter past 5. Time to have dinner!", "style": "A"}, {"key": "1aqdtmp", "text": "Yes — quarter past 6. Time to look at the moon!", "style": "A"}, {"key": "1c44p97", "text": "Yes — five to 1. Time to eat lunch!", "style": "A"}, {"key": "wkjw1j", "text": "Yes — quarter past 10. Time to get to school!", "style": "A"}, {"key": "5d5kl2", "text": "Yes — quarter to 12. Time to go out to play!", "style": "A"}, {"key": "g2o28f", "text": "Yes — ten to 4. Time to go to the park!", "style": "A"}, {"key": "1d9i1wd", "text": "Yes — five to 8. Time to wake up!", "style": "A"}, {"key": "g62m0g", "text": "Yes — ten to 11. Time to get to school!", "style": "A"}, {"key": "28byi0", "text": "Yes — twenty to 2. Time to do some painting!", "style": "A"}, {"key": "rv33hd", "text": "Yes — half past 5. Time to have dinner!", "style": "A"}, {"key": "1qvq4e", "text": "Yes — ten past 6. Time to look at the moon!", "style": "A"}, {"key": "11la11b", "text": "Yes — half past 11. Time to go out to play!", "style": "A"}, {"key": "vqlz1o", "text": "Yes — twenty to 1. Time to eat lunch!", "style": "A"}, {"key": "3lil76", "text": "Yes — five to 6. Time to have dinner!", "style": "A"}, {"key": "1hsuz61", "text": "Yes — twenty to 9. Time to have breakfast!", "style": "A"}, {"key": "1vc9scn", "text": "Yes — ten to 12. Time to go out to play!", "style": "A"}, {"key": "ihl5iw", "text": "Yes — half past 6. Time to look at the moon!", "style": "A"}, {"key": "ra17gk", "text": "Yes — twenty past 6. Time to look at the moon!", "style": "A"}, {"key": "sv8q33", "text": "Yes — ten to 6. Time to have dinner!", "style": "A"}, {"key": "16mjz3x", "text": "Yes — ten past 11. Time to go out to play!", "style": "A"}, {"key": "jr4yo7", "text": "Yes — quarter to 11. Time to get to school!", "style": "A"}, {"key": "pdr6gj", "text": "Yes — twenty-five to 10. Time to catch the bus!", "style": "A"}, {"key": "1pqxoio", "text": "Yes — five to 9. Time to have breakfast!", "style": "A"}, {"key": "mitpx", "text": "Yes — twenty to 4. Time to go to the park!", "style": "A"}, {"key": "3ciurh", "text": "Yes — five to 2. Time to do some painting!", "style": "A"}, {"key": "1kyym47", "text": "Yes — quarter to 10. Time to catch the bus!", "style": "A"}, {"key": "17d6o9z", "text": "Yes — quarter to 1. Time to eat lunch!", "style": "A"}, {"key": "hdnrqy", "text": "Yes — twenty-five to 6. Time to have dinner!", "style": "A"}, {"key": "16go5yg", "text": "Yes — twenty-five to 9. Time to have breakfast!", "style": "A"}, {"key": "17wx5p7", "text": "Yes — twenty past 11. Time to go out to play!", "style": "A"}, {"key": "1lu0tx0", "text": "Yes — five to 4. Time to go to the park!", "style": "A"}, {"key": "1qcck6g", "text": "Yes — ten to 8. Time to wake up!", "style": "A"}, {"key": "137p9g3", "text": "Yes — twenty-five to 11. Time to get to school!", "style": "A"}, {"key": "y28xut", "text": "Yes — twenty-five to 2. Time to do some painting!", "style": "A"}, {"key": "1f5l19p", "text": "Yes — twenty-five past 6. Time to look at the moon!", "style": "A"}, {"key": "79hiqg", "text": "Yes — quarter to 4. Time to go to the park!", "style": "A"}, {"key": "vwfsfa", "text": "Yes — twenty to 7. Time to look at the moon!", "style": "A"}, {"key": "ut2mu4", "text": "Yes — twenty-five past 11. Time to go out to play!", "style": "A"}, {"key": "778py7", "text": "Yes — five to 7. Time to look at the moon!", "style": "A"}, {"key": "9wy8r2", "text": "Yes — quarter to 6. Time to have dinner!", "style": "A"}, {"key": "fp0llj", "text": "Yes — ten to 9. Time to have breakfast!", "style": "A"}, {"key": "vw477f", "text": "Yes — five to 10. Time to catch the bus!", "style": "A"}, {"key": "1p8ze1g", "text": "Yes — five past 11. Time to go out to play!", "style": "A"}, {"key": "thnr96", "text": "Yes — twenty to 11. Time to get to school!", "style": "A"}, {"key": "16c7hy1", "text": "Yes — twenty to 12. Time to go out to play!", "style": "A"}, {"key": "1ubhk1x", "text": "Yes — twenty-five to 8. Time to wake up!", "style": "A"}, {"key": "u53y01", "text": "Yes — quarter to 2. Time to do some painting!", "style": "A"}, {"key": "dvnkxu", "text": "Yes — twenty to 10. Time to catch the bus!", "style": "A"}, {"key": "5z694a", "text": "Yes — twenty-five to 12. Time to go out to play!", "style": "A"}, {"key": "liq6fd", "text": "Yes — quarter to 8. Time to wake up!", "style": "A"}, {"key": "1q93t5f", "text": "Yes — quarter to 7. Time to look at the moon!", "style": "A"}, {"key": "1m7ogzr", "text": "Yes — twenty-five to 7. Time to look at the moon!", "style": "A"}, {"key": "1oa59f7", "text": "Yes — twenty-five to 1. Time to eat lunch!", "style": "A"}, {"key": "1trz6mt", "text": "Yes — five past 6. Time to look at the moon!", "style": "A"}, {"key": "h8uxi5", "text": "Two bunnies are playing.", "style": "A"}, {"key": "xqy0e7", "text": "Another one comes to play!", "style": "A"}, {"key": "1vkdl79", "text": "Now count them all.", "style": "A"}, {"key": "1nqldu0", "text": "That makes 4. Tap the 4!", "style": "A"}, {"key": "18e5qba", "text": "That makes 3. Tap the 3!", "style": "A"}, {"key": "xsdu49", "text": "Five bunnies are playing.", "style": "A"}, {"key": "rn0yh8", "text": "One goes home.", "style": "A"}, {"key": "1kcd1gx", "text": "Now count who is left.", "style": "A"}, {"key": "1j8weq5", "text": "Some more come to play! Count them all, then tap how many.", "style": "A"}, {"key": "1vyts4u", "text": "Some go home! Count who is left, then tap how many.", "style": "A"}, {"key": "on9ez5", "text": "Not quite — count them all again, one by one.", "style": "A"}, {"key": "4fb6i7", "text": "Not quite — count who is still here.", "style": "A"}, {"key": "arbabi", "text": "Watch me build it!", "style": "A"}, {"key": "1gfy05w", "text": "ten", "style": "A"}, {"key": "13xydmo", "text": "eleven", "style": "A"}, {"key": "1w1b7hw", "text": "twelve", "style": "A"}, {"key": "rj1gs6", "text": "thirteen", "style": "A"}, {"key": "1vxseoo", "text": "1 ten and 3 ones make thirteen. That is thirteen!", "style": "A"}, {"key": "34g4o", "text": "twenty", "style": "A"}, {"key": "kbaeul", "text": "twenty-one", "style": "A"}, {"key": "8a4ctj", "text": "twenty-two", "style": "A"}, {"key": "18yadct", "text": "twenty-three", "style": "A"}, {"key": "y0d0ez", "text": "twenty-four", "style": "A"}, {"key": "1jdvnh7", "text": "2 tens and 4 ones make twenty-four. That is twenty-four!", "style": "A"}, {"key": "25vy22", "text": "fifteen", "style": "A"}, {"key": "7djbjp", "text": "thirty", "style": "A"}, {"key": "1066m1r", "text": "twenty-five", "style": "A"}, {"key": "d10ijz", "text": "Number Street", "style": "A"}, {"key": "1dgw3on", "text": "Yes! That is sixteen!", "style": "A"}, {"key": "oylytk", "text": "Locker Room", "style": "A"}, {"key": "l40d6l", "text": "Space Station", "style": "A"}, {"key": "tid1s9", "text": "The order says thirty-four. Let's build it.", "style": "A"}, {"key": "zb0wik", "text": "three tens go on the left.", "style": "A"}, {"key": "v10ryg", "text": "four ones go on the right. That is thirty-four.", "style": "A"}, {"key": "1wsqmh0", "text": "Now the order says forty-three — the same two digits, the other way round.", "style": "A"}, {"key": "o7izlr", "text": "four tens, and three ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "7gw9r6", "text": "Same digits, different sides, a different number. That is what the places mean.", "style": "A"}, {"key": "124twmj", "text": "The order says fifty-two. Let's build it.", "style": "A"}, {"key": "yxttdu", "text": "five tens go on the left.", "style": "A"}, {"key": "wsmly6", "text": "two ones go on the right. That is fifty-two.", "style": "A"}, {"key": "1ici16p", "text": "Now the order says twenty-five — the same two digits, the other way round.", "style": "A"}, {"key": "yhp94b", "text": "two tens, and five ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "spzo21", "text": "six on this side, and three on that side.", "style": "A"}, {"key": "ffj0a8", "text": "six is greater than three.", "style": "A"}, {"key": "1dk420j", "text": "So the sign is greater than!", "style": "A"}, {"key": "uya8p0", "text": "two on this side, and eight on that side.", "style": "A"}, {"key": "edgbxi", "text": "two is less than eight.", "style": "A"}, {"key": "wf3mai", "text": "So the sign is less than!", "style": "A"}, {"key": "nxdwrf", "text": "four on this side, and four on that side.", "style": "A"}, {"key": "9mjazf", "text": "They are the same — four equals four.", "style": "A"}, {"key": "37j717", "text": "So the sign is equal to!", "style": "A"}, {"key": "1hh8mgb", "text": "Yes! three is less than seven!", "style": "A"}, {"key": "1og54wz", "text": "Look again — which side is bigger? Try once more!", "style": "A"}, {"key": "1gra621", "text": "two", "style": "A"}, {"key": "d5lr51", "text": "four", "style": "A"}, {"key": "1k3lg2z", "text": "six", "style": "A"}, {"key": "1n3dt9s", "text": "eight", "style": "A"}, {"key": "11vp0w3", "text": "three", "style": "A"}, {"key": "1ch2k5x", "text": "five", "style": "A"}, {"key": "10tdh3", "text": "You have 3 fish.", "style": "A"}, {"key": "y3n91t", "text": "Here they come.", "style": "A"}, {"key": "1wapegp", "text": "Then you meet 2 fish more.", "style": "A"}, {"key": "15o87b4", "text": "Here comes another one!", "style": "A"}, {"key": "1df9mad", "text": "Let’s count them all!", "style": "A"}, {"key": "1fnfegf", "text": "one", "style": "A"}, {"key": "1qhsj0r", "text": "five fish altogether!", "style": "A"}, {"key": "1luc1r7", "text": "You have 5 ducks.", "style": "A"}, {"key": "y5y2a4", "text": "Then 2 ducks wander off.", "style": "A"}, {"key": "1j98tgo", "text": "There goes another one.", "style": "A"}, {"key": "1p26h2x", "text": "Let’s count what’s left!", "style": "A"}, {"key": "1726gd", "text": "three ducks left!", "style": "A"}, {"key": "1wpzsrw", "text": "You have 4 dragonflies.", "style": "A"}, {"key": "zdjpm", "text": "Bo has 2 dragonflies.", "style": "A"}, {"key": "1mjvhhv", "text": "And here are theirs.", "style": "A"}, {"key": "1lctrfx", "text": "You have more! How many more?", "style": "A"}, {"key": "bxs41g", "text": "You have two more!", "style": "A"}, {"key": "wq8m8m", "text": "You have 2 crabs. Then you meet 2 more!", "style": "A"}, {"key": "b1kte4", "text": "four!", "style": "A"}, {"key": "1ylw5su", "text": "Look — the long hand points straight up at the twelve. That means o'clock.", "style": "A"}, {"key": "1ftq3a4", "text": "It is time to have breakfast. What time is it now?", "style": "A"}, {"key": "xggz40", "text": "Time to catch the bus at 9 o'clock. Move the hands!", "style": "A"}, {"key": "1pt4ghf", "text": "Ten ones on the ground — you cannot leave ten there. Trade them up.", "style": "A"}, {"key": "1o01cvn", "text": "Ten ones on the ground — that is one ten. Tap them.", "style": "A"}, {"key": "d8ixnt", "text": "Ten again — trade them up.", "style": "A"}, {"key": "1k7l5dg", "text": "Ten ones make one ten. It goes on the left shelf.", "style": "A"}, {"key": "15eblm3", "text": "Not yet. Count the tens, then the ones.", "style": "A"}, {"key": "1bund2u", "text": "Not that one. Count the tens side, then the ones side.", "style": "A"}, {"key": "1kmjw98", "text": "Not that one. Count the tens on the left.", "style": "A"}, {"key": "105vnc0", "text": "Not that one. Count the loose ones on the right.", "style": "A"}, {"key": "w7e1dn", "text": "Not that one. Each one of those is worth ten — count them in tens.", "style": "A"}, {"key": "1dbpa9", "text": "Yes! Let’s count.", "style": "A"}, {"key": "1y0hwjf", "text": "Not quite — listen to the story again, then try!", "style": "A"}, {"key": "17mjg0q", "text": "The long hand is not there yet — count round the clock in fives.", "style": "A"}, {"key": "5q1zd1", "text": "Look at the short hand — that one shows the hour.", "style": "A"}, {"key": "15htvlu", "text": "Look at the long hand again. Which number is it pointing at?", "style": "A"}, {"key": "1u6eoxa", "text": "Careful — after half past we count to the next hour.", "style": "A"}, {"key": "1b8pscp", "text": "Look at the short hand — which hour has it just gone past?", "style": "A"}, {"key": "ae7up3", "text": "Every clock has two hands, and they are not the same.", "style": "A"}, {"key": "zxdtaj", "text": "This short fat one is the hour hand. It tells you the hour.", "style": "A"}, {"key": "11g5vz1", "text": "This long thin one is the minute hand. It counts the minutes.", "style": "A"}, {"key": "qxdv4f", "text": "When the long hand points straight up at the twelve, we say o'clock.", "style": "A"}, {"key": "1lmm8r7", "text": "The short hand tells us which one. Look — one o'clock, two o'clock, three o'clock.", "style": "A"}, {"key": "l4ha00", "text": "Four, five, six. all the way round to twelve.", "style": "A"}, {"key": "2ykwbn", "text": "Now the secret. This clock has another set of numbers hiding on it.", "style": "A"}, {"key": "15kb4he", "text": "The same six that means six hours also means thirty minutes.", "style": "A"}, {"key": "185dp68", "text": "They go up in fives all the way round — five, ten, fifteen, twenty, twenty-five, thirty.", "style": "A"}, {"key": "ocld1", "text": "So the long hand does not say six. It says thirty.", "style": "A"}, {"key": "w0j4qp", "text": "Long hand on the six is half past.", "style": "A"}, {"key": "153szpm", "text": "On the three it is quarter past.", "style": "A"}, {"key": "jvrboh", "text": "On the nine we count the other way — quarter to, and we say the next hour.", "style": "A"}, {"key": "1b819cm", "text": "Your turn. Put the long hand on the six to make half past three.", "style": "A"}, {"key": "1sqroh4", "text": "That is it — half past three. Now you can read a clock.", "style": "A"}, {"key": "42yy6y", "text": "That one is twenty-two. Listen again — find twelve!", "style": "A"}, {"key": "4g7cq1", "text": "That one is thirteen. Listen again — find twelve!", "style": "A"}, {"key": "1h5j9qf", "text": "That one is forty-five. Listen again — find forty-four!", "style": "A"}, {"key": "wkxzzx", "text": "That one is forty-three. Listen again — find forty-four!", "style": "A"}, {"key": "19wdobu", "text": "That one is sixty-five. Listen again — find fifty-five!", "style": "A"}, {"key": "1c5460x", "text": "That one is fifty-six. Listen again — find fifty-five!", "style": "A"}, {"key": "1rc6hgd", "text": "That one is twelve. Listen again — find thirteen!", "style": "A"}, {"key": "12dkvra", "text": "That one is twenty-three. Listen again — find thirteen!", "style": "A"}, {"key": "1yrki64", "text": "That one is eleven. Listen again — find twenty-one!", "style": "A"}, {"key": "1jpj4e5", "text": "That one is twenty-two. Listen again — find twenty-one!", "style": "A"}, {"key": "8eqp8a", "text": "That one is seventy-nine. Listen again — find sixty-nine!", "style": "A"}, {"key": "13zmg96", "text": "That one is sixty-eight. Listen again — find sixty-nine!", "style": "A"}, {"key": "1gjall8", "text": "That one is twenty-one. Listen again — find twenty!", "style": "A"}, {"key": "1o2bcnx", "text": "That one is ten. Listen again — find twenty!", "style": "A"}, {"key": "172dn3s", "text": "That one is fifty-eight. Listen again — find fifty-nine!", "style": "A"}, {"key": "vu4pg1", "text": "That one is sixty. Listen again — find fifty-nine!", "style": "A"}, {"key": "evy4t8", "text": "That one is ninety-three. Listen again — find eighty-three!", "style": "A"}, {"key": "1857bah", "text": "That one is eighty-two. Listen again — find eighty-three!", "style": "A"}, {"key": "1tue13o", "text": "That one is twenty-one. Listen again — find eleven!", "style": "A"}, {"key": "17zxa97", "text": "That one is twelve. Listen again — find eleven!", "style": "A"}, {"key": "jv6vrt", "text": "That one is forty. Listen again — find fifty!", "style": "A"}, {"key": "1pvl15m", "text": "That one is fifty-one. Listen again — find fifty!", "style": "A"}, {"key": "1ilvf4t", "text": "That one is ninety-two. Listen again — find ninety-three!", "style": "A"}, {"key": "1lav603", "text": "That one is ninety-four. Listen again — find ninety-three!", "style": "A"}, {"key": "ocmn6c", "text": "That one is one. Listen again — find eleven!", "style": "A"}, {"key": "e6nwri", "text": "That one is sixty-three. Listen again — find thirty-six!", "style": "A"}, {"key": "atvuo0", "text": "That one is thirty-seven. Listen again — find thirty-six!", "style": "A"}, {"key": "1qha71x", "text": "That one is ninety-eight. Listen again — find ninety-seven!", "style": "A"}, {"key": "1iskky0", "text": "That one is eighty-seven. Listen again — find ninety-seven!", "style": "A"}, {"key": "o7yy69", "text": "That one is eighteen. Listen again — find seventeen!", "style": "A"}, {"key": "16cuijh", "text": "That one is seven. Listen again — find seventeen!", "style": "A"}, {"key": "1gzub9d", "text": "That one is fifty-four. Listen again — find forty-five!", "style": "A"}, {"key": "798pdz", "text": "That one is forty-four. Listen again — find forty-five!", "style": "A"}, {"key": "1ox09la", "text": "That one is ninety-four. Listen again — find eighty-four!", "style": "A"}, {"key": "eqt62y", "text": "That one is forty-eight. Listen again — find eighty-four!", "style": "A"}, {"key": "6q08mc", "text": "That one is fifty. Listen again — find fifty-one!", "style": "A"}, {"key": "ukgpv3", "text": "That one is fifteen. Listen again — find fifty-one!", "style": "A"}, {"key": "muzrgw", "text": "That one is sixty-one. Listen again — find seventy-one!", "style": "A"}, {"key": "stvn1", "text": "That one is eighty-one. Listen again — find seventy-one!", "style": "A"}, {"key": "16projq", "text": "That one is fourteen. Listen again — find thirteen!", "style": "A"}, {"key": "zfkdnr", "text": "That one is forty-two. Listen again — find forty-one!", "style": "A"}, {"key": "17mgx80", "text": "That one is forty. Listen again — find forty-one!", "style": "A"}, {"key": "wpwqc3", "text": "That one is fifty-three. Listen again — find fifty-two!", "style": "A"}, {"key": "vpac6c", "text": "That one is sixty-two. Listen again — find fifty-two!", "style": "A"}, {"key": "1fyetdg", "text": "That one is fourteen. Listen again — find fifteen!", "style": "A"}, {"key": "1xiw9r0", "text": "That one is five. Listen again — find fifteen!", "style": "A"}, {"key": "jrl8gn", "text": "That one is thirty-seven. Listen again — find forty-seven!", "style": "A"}, {"key": "f3jnvp", "text": "That one is fifty-seven. Listen again — find forty-seven!", "style": "A"}, {"key": "1in543s", "text": "That one is thirty-nine. Listen again — find ninety-three!", "style": "A"}, {"key": "1jzzw5s", "text": "That one is twenty. Listen again — find nineteen!", "style": "A"}, {"key": "1y9my03", "text": "That one is nine. Listen again — find nineteen!", "style": "A"}, {"key": "8zrbk", "text": "That one is thirty-eight. Listen again — find twenty-eight!", "style": "A"}, {"key": "14m3k71", "text": "That one is eighteen. Listen again — find twenty-eight!", "style": "A"}, {"key": "1p6f03o", "text": "That one is eighty-two. Listen again — find ninety-two!", "style": "A"}, {"key": "ni1l5v", "text": "That one is twenty-nine. Listen again — find ninety-two!", "style": "A"}, {"key": "1yvzxbb", "text": "That one is eleven. Listen again — find twelve!", "style": "A"}, {"key": "1wkq6vm", "text": "That one is thirty-two. Listen again — find twenty-three!", "style": "A"}, {"key": "194hszv", "text": "That one is twenty-four. Listen again — find twenty-three!", "style": "A"}, {"key": "1g0kxad", "text": "That one is eighty-four. Listen again — find eighty-five!", "style": "A"}, {"key": "1g67enc", "text": "That one is fifty-eight. Listen again — find eighty-five!", "style": "A"}, {"key": "1mhkllm", "text": "That one is two. Listen again — find twelve!", "style": "A"}, {"key": "1ixpj0h", "text": "That one is fifty-nine. Listen again — find forty-nine!", "style": "A"}, {"key": "1nds7jf", "text": "That one is thirty-nine. Listen again — find forty-nine!", "style": "A"}, {"key": "1uualid", "text": "That one is eighty-four. Listen again — find eighty-three!", "style": "A"}, {"key": "1hemdul", "text": "That one is twenty-seven. Listen again — find seventeen!", "style": "A"}, {"key": "1bbu65k", "text": "That one is sixteen. Listen again — find seventeen!", "style": "A"}, {"key": "19scrm8", "text": "That one is ninety-four. Listen again — find forty-nine!", "style": "A"}, {"key": "1kzeqt9", "text": "That one is seventy-four. Listen again — find eighty-four!", "style": "A"}, {"key": "1d1mrrb", "text": "That one is eighty-three. Listen again — find eighty-four!", "style": "A"}, {"key": "14aotz7", "text": "That one is forty-six. Listen again — find thirty-six!", "style": "A"}, {"key": "1o0tyrh", "text": "That one is thirty-five. Listen again — find thirty-six!", "style": "A"}, {"key": "141c9a8", "text": "That one is eighty-eight. Listen again — find ninety-eight!", "style": "A"}, {"key": "1byo2pf", "text": "That one is eighty-nine. Listen again — find ninety-eight!", "style": "A"}, {"key": "4qmbz", "text": "That one is twenty. Listen again — find ten!", "style": "A"}, {"key": "bedzda", "text": "That one is nine. Listen again — find ten!", "style": "A"}, {"key": "13beiux", "text": "That one is twenty-seven. Listen again — find twenty-eight!", "style": "A"}, {"key": "1uits81", "text": "That one is eighty-two. Listen again — find twenty-eight!", "style": "A"}, {"key": "4m0ks2", "text": "That one is seventy-nine. Listen again — find seventy-eight!", "style": "A"}, {"key": "n8oh4n", "text": "That one is eighty-eight. Listen again — find seventy-eight!", "style": "A"}, {"key": "13ibxxs", "text": "That one is nineteen. Listen again — find eighteen!", "style": "A"}, {"key": "dpf1xj", "text": "That one is seventeen. Listen again — find eighteen!", "style": "A"}, {"key": "1vaqdsv", "text": "That one is forty-three. Listen again — find forty-two!", "style": "A"}, {"key": "1h3ofsv", "text": "That one is fifty-two. Listen again — find forty-two!", "style": "A"}, {"key": "100aqso", "text": "That one is eighty-nine. Listen again — find eighty-eight!", "style": "A"}, {"key": "1wki7hc", "text": "That one is ninety-eight. Listen again — find eighty-eight!", "style": "A"}, {"key": "23is6g", "text": "That one is sixteen. Listen again — find fifteen!", "style": "A"}, {"key": "8dyx8m", "text": "That one is forty. Listen again — find thirty-nine!", "style": "A"}, {"key": "1yrb9hg", "text": "That one is ninety-three. Listen again — find thirty-nine!", "style": "A"}, {"key": "dvw0lh", "text": "That one is seventy-five. Listen again — find eighty-five!", "style": "A"}, {"key": "1roham2", "text": "That one is fifteen. Listen again — find sixteen!", "style": "A"}, {"key": "34muqr", "text": "That one is twenty-six. Listen again — find sixteen!", "style": "A"}, {"key": "1rw2392", "text": "That one is fifty-nine. Listen again — find fifty-eight!", "style": "A"}, {"key": "lgiodi", "text": "That one is eighty-five. Listen again — find fifty-eight!", "style": "A"}, {"key": "1tlea1z", "text": "That one is ninety-three. Listen again — find ninety-four!", "style": "A"}, {"key": "iruwek", "text": "That one is eighty-four. Listen again — find ninety-four!", "style": "A"}, {"key": "3tc8of", "text": "That one is forty-one. Listen again — find forty-two!", "style": "A"}, {"key": "tn3cwi", "text": "That one is twenty-four. Listen again — find forty-two!", "style": "A"}, {"key": "lag0w7", "text": "That one is ninety-five. Listen again — find ninety-four!", "style": "A"}, {"key": "129i483", "text": "That one is six. Listen again — find sixteen!", "style": "A"}, {"key": "1jdv7wa", "text": "That one is seventeen. Listen again — find sixteen!", "style": "A"}, {"key": "zqxldt", "text": "That one is thirty-two. Listen again — find forty-two!", "style": "A"}, {"key": "h4ci6e", "text": "That one is sixty-eight. Listen again — find fifty-eight!", "style": "A"}, {"key": "13fegz1", "text": "That one is fifty-seven. Listen again — find fifty-eight!", "style": "A"}, {"key": "ckz8vn", "text": "That one is fourteen. Listen again — find twenty-four!", "style": "A"}, {"key": "9wdcm0", "text": "That one is forty-two. Listen again — find twenty-four!", "style": "A"}, {"key": "qy9j03", "text": "That one is fifty-four. Listen again — find fifty-five!", "style": "A"}, {"key": "1cwk9ek", "text": "That one is twenty-five. Listen again — find fifteen!", "style": "A"}, {"key": "1kxu8ru", "text": "That one is sixty-four. Listen again — find forty-six!", "style": "A"}, {"key": "1hpqyn9", "text": "That one is thirty-six. Listen again — find forty-six!", "style": "A"}, {"key": "yxdnos", "text": "That one is ninety-one. Listen again — find ninety!", "style": "A"}, {"key": "17btcla", "text": "That one is one hundred. Listen again — find ninety!", "style": "A"}, {"key": "1yq0bqj", "text": "That one is seventy-three. Listen again — find eighty-three!", "style": "A"}, {"key": "1arug24", "text": "That one is eighteen. Listen again — find nineteen!", "style": "A"}, {"key": "1pgjasq", "text": "That one is seventy-four. Listen again — find forty-seven!", "style": "A"}, {"key": "18p5kx1", "text": "That one is forty-eight. Listen again — find forty-seven!", "style": "A"}, {"key": "jks20h", "text": "That one is ninety-three. Listen again — find ninety-two!", "style": "A"}, {"key": "xsm3e1", "text": "That one is ninety-one. Listen again — find ninety-two!", "style": "A"}, {"key": "sjxsh6", "text": "That one is fifty-five. Listen again — find sixty-five!", "style": "A"}, {"key": "15unpre", "text": "That one is seventy-five. Listen again — find sixty-five!", "style": "A"}, {"key": "9m8s1v", "text": "That one is fifty-one. Listen again — find forty-one!", "style": "A"}, {"key": "6a21t9", "text": "That one is sixty-two. Listen again — find sixty-three!", "style": "A"}, {"key": "12eg6am", "text": "That one is seventy-three. Listen again — find sixty-three!", "style": "A"}, {"key": "51hlza", "text": "That one is three. Listen again — find thirteen!", "style": "A"}, {"key": "17kxpef", "text": "That one is seventy-eight. Listen again — find eighty-eight!", "style": "A"}, {"key": "11c6jjp", "text": "That one is eighty-seven. Listen again — find eighty-eight!", "style": "A"}, {"key": "1871imb", "text": "That one is seventy-two. Listen again — find twenty-seven!", "style": "A"}, {"key": "1iwscyw", "text": "That one is twenty-six. Listen again — find twenty-seven!", "style": "A"}, {"key": "19tt081", "text": "That one is five. Listen again — find fifty!", "style": "A"}, {"key": "g0ubbf", "text": "That one is twenty-four. Listen again — find fourteen!", "style": "A"}, {"key": "8ubrbg", "text": "That one is fifteen. Listen again — find fourteen!", "style": "A"}, {"key": "14x97ab", "text": "That one is nineteen. Listen again — find twenty-nine!", "style": "A"}, {"key": "n5rucr", "text": "That one is ninety-two. Listen again — find twenty-nine!", "style": "A"}, {"key": "aiwl3b", "text": "That one is eighty-five. Listen again — find seventy-five!", "style": "A"}, {"key": "evpq5i", "text": "That one is sixty-five. Listen again — find seventy-five!", "style": "A"}, {"key": "6w7ao9", "text": "That one is twenty-one. Listen again — find twenty-two!", "style": "A"}, {"key": "1kljjp1", "text": "That one is twenty-three. Listen again — find twenty-two!", "style": "A"}, {"key": "372rul", "text": "That one is eighteen. Listen again — find eighty-one!", "style": "A"}, {"key": "eqywas", "text": "That one is eighty. Listen again — find eighty-one!", "style": "A"}, {"key": "cycsuc", "text": "That one is nineteen. Listen again — find twenty!", "style": "A"}, {"key": "in0go0", "text": "That one is thirty. Listen again — find twenty!", "style": "A"}, {"key": "1c5vrtj", "text": "That one is forty-three. Listen again — find fifty-three!", "style": "A"}, {"key": "1wf68xj", "text": "That one is fifty-two. Listen again — find fifty-three!", "style": "A"}, {"key": "cyj7zx", "text": "That one is ninety-seven. Listen again — find seventy-nine!", "style": "A"}, {"key": "1jkt006", "text": "That one is eighty. Listen again — find seventy-nine!", "style": "A"}, {"key": "1mqq59z", "text": "That one is eleven. Listen again — find ten!", "style": "A"}, {"key": "1pqz30t", "text": "That one is forty-five. Listen again — find thirty-five!", "style": "A"}, {"key": "xabp1h", "text": "That one is fifty-three. Listen again — find thirty-five!", "style": "A"}, {"key": "3kn7jd", "text": "That one is eight. Listen again — find eighteen!", "style": "A"}, {"key": "1s94xlq", "text": "That one is twenty-nine. Listen again — find thirty-nine!", "style": "A"}, {"key": "1avvd1p", "text": "That one is forty-nine. Listen again — find thirty-nine!", "style": "A"}, {"key": "1gmed1", "text": "That one is sixty-two. Listen again — find sixty-one!", "style": "A"}, {"key": "ae5qr2", "text": "That one is seventy-one. Listen again — find sixty-one!", "style": "A"}, {"key": "l99pf0", "text": "That one is twenty-seven. Listen again — find twenty-six!", "style": "A"}, {"key": "1jjrj7f", "text": "That one is sixty-two. Listen again — find twenty-six!", "style": "A"}, {"key": "ngh14h", "text": "That one is eighty-two. Listen again — find eighty-one!", "style": "A"}, {"key": "y5oeyb", "text": "That one is forty-two. Listen again — find fifty-two!", "style": "A"}, {"key": "b5ydtg", "text": "That one is twenty-two. Listen again — find thirty-two!", "style": "A"}, {"key": "1z0ck6n", "text": "That one is forty-two. Listen again — find thirty-two!", "style": "A"}, {"key": "1levwzo", "text": "That one is ten. Listen again — find one hundred!", "style": "A"}, {"key": "1m0kw2x", "text": "That one is ninety-nine. Listen again — find one hundred!", "style": "A"}, {"key": "wwh6tt", "text": "That one is thirty-three. Listen again — find thirty-two!", "style": "A"}, {"key": "1upzinl", "text": "That one is thirty-one. Listen again — find thirty-two!", "style": "A"}, {"key": "11sva23", "text": "That one is sixty-five. Listen again — find sixty-six!", "style": "A"}, {"key": "4nx8ra", "text": "That one is seventy-six. Listen again — find sixty-six!", "style": "A"}, {"key": "1d9z3ac", "text": "That one is twenty-eight. Listen again — find twenty-nine!", "style": "A"}, {"key": "1hp7hlv", "text": "That one is twenty-nine. Listen again — find nineteen!", "style": "A"}, {"key": "8lke44", "text": "That one is sixty-three. Listen again — find fifty-three!", "style": "A"}, {"key": "1hxeqi0", "text": "That one is sixty-six. Listen again — find seventy-six!", "style": "A"}, {"key": "hiix6h", "text": "That one is eighty-six. Listen again — find seventy-six!", "style": "A"}, {"key": "xjjs3w", "text": "That one is sixty-one. Listen again — find fifty-one!", "style": "A"}, {"key": "1a97g9n", "text": "That one is forty-one. Listen again — find fifty-one!", "style": "A"}, {"key": "168rhce", "text": "That one is fifty-two. Listen again — find sixty-two!", "style": "A"}, {"key": "psc5fd", "text": "That one is sixty-one. Listen again — find sixty-two!", "style": "A"}, {"key": "1x7mswt", "text": "That one is thirteen. Listen again — find thirty-one!", "style": "A"}, {"key": "1gtzo2v", "text": "That one is forty-one. Listen again — find thirty-one!", "style": "A"}, {"key": "2nf7qa", "text": "That one is forty-nine. Listen again — find ninety-four!", "style": "A"}, {"key": "w3x2s2", "text": "That one is ninety-five. Listen again — find fifty-nine!", "style": "A"}, {"key": "1686czf", "text": "That one is seventy. Listen again — find eighty!", "style": "A"}, {"key": "1h58zyg", "text": "That one is eighty-one. Listen again — find eighty!", "style": "A"}, {"key": "hjkazf", "text": "That one is thirty-five. Listen again — find forty-five!", "style": "A"}, {"key": "gtbp2p", "text": "That one is fifty-five. Listen again — find forty-five!", "style": "A"}, {"key": "1s8r9tb", "text": "That one is eighty. Listen again — find seventy!", "style": "A"}, {"key": "o235lw", "text": "That one is seven. Listen again — find seventy!", "style": "A"}, {"key": "sthkf3", "text": "That one is twenty-five. Listen again — find twenty-six!", "style": "A"}, {"key": "1r6cio7", "text": "That one is seventy-four. Listen again — find seventy-five!", "style": "A"}, {"key": "tnl4l2", "text": "That one is forty-nine. Listen again — find fifty!", "style": "A"}, {"key": "1y1bely", "text": "That one is sixty-nine. Listen again — find seventy-nine!", "style": "A"}, {"key": "1paa6f3", "text": "That one is forty-eight. Listen again — find thirty-eight!", "style": "A"}, {"key": "1rch308", "text": "That one is thirty-nine. Listen again — find thirty-eight!", "style": "A"}, {"key": "1slah1r", "text": "That one is forty-six. Listen again — find fifty-six!", "style": "A"}, {"key": "r8vgys", "text": "That one is sixty-five. Listen again — find fifty-six!", "style": "A"}, {"key": "1uhcr63", "text": "That one is fifty-two. Listen again — find fifty-one!", "style": "A"}, {"key": "5y2ok6", "text": "That one is fifty-six. Listen again — find sixty-six!", "style": "A"}, {"key": "199y3zu", "text": "That one is sixty-seven. Listen again — find sixty-six!", "style": "A"}, {"key": "14mo74u", "text": "That one is twenty-five. Listen again — find thirty-five!", "style": "A"}, {"key": "i07ewu", "text": "That one is sixty. Listen again — find fifty!", "style": "A"}, {"key": "304nob", "text": "That one is fifty-four. Listen again — find fifty-three!", "style": "A"}, {"key": "1tebdpl", "text": "That one is twenty-eight. Listen again — find eighteen!", "style": "A"}, {"key": "10dcouj", "text": "That one is fifty-five. Listen again — find fifty-six!", "style": "A"}, {"key": "1s212a2", "text": "That one is seventy-nine. Listen again — find eighty!", "style": "A"}, {"key": "1wvjkm0", "text": "That one is eight. Listen again — find eighty!", "style": "A"}, {"key": "19punqt", "text": "That one is ten. Listen again — find eleven!", "style": "A"}, {"key": "1wpz5pr", "text": "That one is three. Listen again — find thirty!", "style": "A"}, {"key": "1yh4das", "text": "That one is thirty-one. Listen again — find thirty!", "style": "A"}, {"key": "1en6747", "text": "That one is sixty-three. Listen again — find sixty-four!", "style": "A"}, {"key": "1vsj2wn", "text": "That one is sixty-five. Listen again — find sixty-four!", "style": "A"}, {"key": "1fa3k5", "text": "That one is twenty-two. Listen again — find twenty-three!", "style": "A"}, {"key": "qnvbna", "text": "That one is ninety-nine. Listen again — find ninety-eight!", "style": "A"}, {"key": "lz8dv4", "text": "That one is ninety-seven. Listen again — find eighty-seven!", "style": "A"}, {"key": "tupe73", "text": "That one is seventy-seven. Listen again — find eighty-seven!", "style": "A"}, {"key": "oa4vsf", "text": "That one is forty. Listen again — find thirty!", "style": "A"}, {"key": "g93egn", "text": "That one is twenty-nine. Listen again — find thirty!", "style": "A"}, {"key": "hr5trg", "text": "That one is ninety. Listen again — find eighty!", "style": "A"}, {"key": "bn62zz", "text": "That one is forty-three. Listen again — find thirty-four!", "style": "A"}, {"key": "1lnjgnd", "text": "That one is forty-four. Listen again — find thirty-four!", "style": "A"}, {"key": "1t8lbca", "text": "That one is fifty-six. Listen again — find fifty-seven!", "style": "A"}, {"key": "aa5zfx", "text": "That one is forty-seven. Listen again — find fifty-seven!", "style": "A"}, {"key": "1ebce0e", "text": "That one is sixty-seven. Listen again — find fifty-seven!", "style": "A"}, {"key": "kyya9l", "text": "That one is fifty-eight. Listen again — find fifty-seven!", "style": "A"}, {"key": "14zsk2c", "text": "That one is fifty-six. Listen again — find sixty-five!", "style": "A"}, {"key": "1nkwi9m", "text": "That one is thirteen. Listen again — find fourteen!", "style": "A"}, {"key": "1cbrhcb", "text": "That one is four. Listen again — find fourteen!", "style": "A"}, {"key": "e9uor4", "text": "That one is fifty-seven. Listen again — find sixty-seven!", "style": "A"}, {"key": "1igfzps", "text": "That one is seventy-seven. Listen again — find sixty-seven!", "style": "A"}, {"key": "1svklpp", "text": "That one is seventy-nine. Listen again — find ninety-seven!", "style": "A"}, {"key": "18gfu0o", "text": "That one is fifty-seven. Listen again — find fifty-six!", "style": "A"}, {"key": "1824943", "text": "That one is twenty-six. Listen again — find sixty-two!", "style": "A"}, {"key": "1ocgksx", "text": "That one is sixty-three. Listen again — find sixty-two!", "style": "A"}, {"key": "1o8x1ns", "text": "That one is twenty-five. Listen again — find fifty-two!", "style": "A"}, {"key": "1t2mkn3", "text": "That one is fifty-one. Listen again — find fifty-two!", "style": "A"}, {"key": "1x10e0d", "text": "That one is forty-eight. Listen again — find fifty-eight!", "style": "A"}, {"key": "uc607v", "text": "That one is fifty-nine. Listen again — find sixty!", "style": "A"}, {"key": "1r16jr2", "text": "That one is six. Listen again — find sixty!", "style": "A"}, {"key": "evpjn6", "text": "That one is ninety-five. Listen again — find eighty-five!", "style": "A"}, {"key": "1jk3ja1", "text": "That one is fifty-three. Listen again — find fifty-four!", "style": "A"}, {"key": "hzumu9", "text": "That one is forty-five. Listen again — find fifty-four!", "style": "A"}, {"key": "vziynq", "text": "That one is twenty-four. Listen again — find thirty-four!", "style": "A"}, {"key": "13oi7fh", "text": "That one is eighty-five. Listen again — find eighty-six!", "style": "A"}, {"key": "1odiig0", "text": "That one is eighty-seven. Listen again — find eighty-six!", "style": "A"}, {"key": "grvxon", "text": "That one is seventy-two. Listen again — find seventy-one!", "style": "A"}, {"key": "1nwrovw", "text": "That one is thirty-six. Listen again — find twenty-six!", "style": "A"}, {"key": "lbown0", "text": "That one is thirty-one. Listen again — find twenty-one!", "style": "A"}, {"key": "1pubjjv", "text": "That one is sixty-six. Listen again — find sixty-five!", "style": "A"}, {"key": "1011a87", "text": "That one is thirty-three. Listen again — find thirty-four!", "style": "A"}, {"key": "bixpil", "text": "That one is thirty-two. Listen again — find thirty-three!", "style": "A"}, {"key": "17yov9k", "text": "That one is twenty-three. Listen again — find thirty-three!", "style": "A"}, {"key": "88xftm", "text": "That one is seventy-six. Listen again — find seventy-seven!", "style": "A"}, {"key": "1gl1ify", "text": "That one is sixty-seven. Listen again — find seventy-seven!", "style": "A"}, {"key": "n5pgue", "text": "That one is sixty-nine. Listen again — find sixty-eight!", "style": "A"}, {"key": "sspxqv", "text": "That one is sixty-seven. Listen again — find sixty-eight!", "style": "A"}, {"key": "1vclzmj", "text": "That one is twenty-five. Listen again — find twenty-four!", "style": "A"}, {"key": "1r4o0wx", "text": "That one is eighty-nine. Listen again — find ninety!", "style": "A"}, {"key": "re3uim", "text": "That one is nine. Listen again — find ninety!", "style": "A"}, {"key": "1qu05d6", "text": "That one is twelve. Listen again — find twenty-two!", "style": "A"}, {"key": "8occk4", "text": "That one is thirty-two. Listen again — find twenty-two!", "style": "A"}, {"key": "1hnsntk", "text": "That one is seventy-eight. Listen again — find sixty-eight!", "style": "A"}, {"key": "1d1pbxf", "text": "That one is thirty-six. Listen again — find thirty-five!", "style": "A"}, {"key": "idll90", "text": "That one is ninety-one. Listen again — find eighty-one!", "style": "A"}, {"key": "cr8fdd", "text": "That one is seventy-seven. Listen again — find seventy-eight!", "style": "A"}, {"key": "owe0n0", "text": "That one is thirty-nine. Listen again — find forty!", "style": "A"}, {"key": "5e3gct", "text": "That one is fifty. Listen again — find forty!", "style": "A"}, {"key": "qgdlfy", "text": "That one is seventy-four. Listen again — find sixty-four!", "style": "A"}, {"key": "191jp18", "text": "That one is twenty-seven. Listen again — find thirty-seven!", "style": "A"}, {"key": "4bse1", "text": "That one is thirty-eight. Listen again — find thirty-seven!", "style": "A"}, {"key": "dukjvw", "text": "That one is seventy-five. Listen again — find fifty-seven!", "style": "A"}, {"key": "19h3eko", "text": "That one is thirty-nine. Listen again — find twenty-nine!", "style": "A"}, {"key": "1nh915j", "text": "That one is thirty. Listen again — find twenty-nine!", "style": "A"}, {"key": "zqmjbi", "text": "That one is seventy-two. Listen again — find sixty-two!", "style": "A"}, {"key": "6f2gqd", "text": "That one is forty-seven. Listen again — find forty-eight!", "style": "A"}, {"key": "1g6yzf7", "text": "That one is thirty-eight. Listen again — find forty-eight!", "style": "A"}, {"key": "1ib8lrg", "text": "That one is sixty-six. Listen again — find fifty-six!", "style": "A"}, {"key": "1ig1g15", "text": "That one is fifty-eight. Listen again — find forty-eight!", "style": "A"}, {"key": "o4g4nq", "text": "That one is forty-nine. Listen again — find forty-eight!", "style": "A"}, {"key": "1dh9wcs", "text": "That one is twelve. Listen again — find twenty-one!", "style": "A"}, {"key": "ll5o45", "text": "That one is eighty-one. Listen again — find eighty-two!", "style": "A"}, {"key": "zcgw6d", "text": "That one is twenty-eight. Listen again — find eighty-two!", "style": "A"}, {"key": "1ea1rjf", "text": "That one is ninety-four. Listen again — find ninety-five!", "style": "A"}, {"key": "1xhvbss", "text": "That one is fifty-nine. Listen again — find ninety-five!", "style": "A"}, {"key": "aoorux", "text": "That one is thirty-four. Listen again — find thirty-five!", "style": "A"}, {"key": "1puo97o", "text": "That one is eighty-one. Listen again — find ninety-one!", "style": "A"}, {"key": "1af3tul", "text": "That one is nineteen. Listen again — find ninety-one!", "style": "A"}, {"key": "121mpg3", "text": "That one is sixty-four. Listen again — find sixty-three!", "style": "A"}, {"key": "24l9p5", "text": "That one is forty-nine. Listen again — find fifty-nine!", "style": "A"}, {"key": "eh4fl4", "text": "That one is eighty-three. Listen again — find thirty-eight!", "style": "A"}, {"key": "1m0la1h", "text": "That one is thirty-seven. Listen again — find thirty-eight!", "style": "A"}, {"key": "gdnix6", "text": "That one is two. Listen again — find twenty!", "style": "A"}, {"key": "106ly7g", "text": "That one is eighty-five. Listen again — find ninety-five!", "style": "A"}, {"key": "1v3fjf", "text": "That one is ninety-six. Listen again — find ninety-five!", "style": "A"}, {"key": "j3dgxa", "text": "That one is thirty-seven. Listen again — find seventy-three!", "style": "A"}, {"key": "1vdhmmf", "text": "That one is seventy-four. Listen again — find seventy-three!", "style": "A"}, {"key": "lzdzo", "text": "That one is twenty-eight. Listen again — find thirty-eight!", "style": "A"}, {"key": "2vlgys", "text": "That one is ninety. Listen again — find one hundred!", "style": "A"}, {"key": "fzateg", "text": "That one is thirty-five. Listen again — find twenty-five!", "style": "A"}, {"key": "1d1hrzy", "text": "That one is fifteen. Listen again — find twenty-five!", "style": "A"}, {"key": "19td93s", "text": "That one is eighty-three. Listen again — find ninety-three!", "style": "A"}, {"key": "llu4xp", "text": "That one is eighty-five. Listen again — find eighty-four!", "style": "A"}, {"key": "fqpzae", "text": "That one is sixty-four. Listen again — find fifty-four!", "style": "A"}, {"key": "8ppgwp", "text": "That one is eighty-eight. Listen again — find eighty-seven!", "style": "A"}, {"key": "1a4697t", "text": "That one is thirty-five. Listen again — find fifty-three!", "style": "A"}, {"key": "5d0zoj", "text": "That one is sixty-nine. Listen again — find ninety-six!", "style": "A"}, {"key": "181gpng", "text": "That one is ninety-seven. Listen again — find ninety-six!", "style": "A"}, {"key": "5gjjpw", "text": "That one is twenty-one. Listen again — find thirty-one!", "style": "A"}, {"key": "1ur9lv9", "text": "That one is thirty-two. Listen again — find thirty-one!", "style": "A"}, {"key": "14evkha", "text": "That one is sixty. Listen again — find seventy!", "style": "A"}, {"key": "1mxhi4f", "text": "That one is sixty-nine. Listen again — find seventy!", "style": "A"}, {"key": "1416bs3", "text": "That one is fifty-three. Listen again — find forty-three!", "style": "A"}, {"key": "b8ss59", "text": "That one is thirty-three. Listen again — find forty-three!", "style": "A"}, {"key": "18fa054", "text": "That one is thirty-eight. Listen again — find thirty-nine!", "style": "A"}, {"key": "m10zxe", "text": "That one is sixty. Listen again — find sixty-one!", "style": "A"}, {"key": "5wkbjv", "text": "That one is seventeen. Listen again — find seventy-one!", "style": "A"}, {"key": "1n5upir", "text": "That one is sixteen. Listen again — find twenty-six!", "style": "A"}, {"key": "9eqbdk", "text": "That one is sixty-three. Listen again — find seventy-three!", "style": "A"}, {"key": "1fbmncp", "text": "That one is eighty-three. Listen again — find seventy-three!", "style": "A"}, {"key": "fj6n3k", "text": "That one is thirty-eight. Listen again — find eighty-three!", "style": "A"}, {"key": "1oomef0", "text": "That one is thirty-three. Listen again — find twenty-three!", "style": "A"}, {"key": "tjc3p5", "text": "That one is seventy-eight. Listen again — find seventy-seven!", "style": "A"}, {"key": "kpc3zd", "text": "That one is eighty-two. Listen again — find seventy-two!", "style": "A"}, {"key": "177jq0z", "text": "That one is seventy-three. Listen again — find seventy-two!", "style": "A"}, {"key": "1m1j2yz", "text": "That one is four. Listen again — find forty!", "style": "A"}, {"key": "6ooz7u", "text": "That one is forty-one. Listen again — find forty!", "style": "A"}, {"key": "14s6v7", "text": "That one is eighty-six. Listen again — find eighty-five!", "style": "A"}, {"key": "1yl7qf7", "text": "That one is seventy-one. Listen again — find eighty-one!", "style": "A"}, {"key": "kb8zex", "text": "That one is ninety-seven. Listen again — find ninety-eight!", "style": "A"}, {"key": "161qwhz", "text": "That one is forty-seven. Listen again — find thirty-seven!", "style": "A"}, {"key": "1ikc8hs", "text": "That one is ninety. Listen again — find ninety-one!", "style": "A"}, {"key": "tpo9o7", "text": "That one is seventeen. Listen again — find twenty-seven!", "style": "A"}, {"key": "1anmqga", "text": "That one is fifty-seven. Listen again — find seventy-five!", "style": "A"}, {"key": "1hghh7u", "text": "That one is sixty-nine. Listen again — find fifty-nine!", "style": "A"}, {"key": "1rjg7sw", "text": "That one is fifty. Listen again — find forty-nine!", "style": "A"}, {"key": "131u8h1", "text": "That one is ninety-two. Listen again — find ninety-one!", "style": "A"}, {"key": "1hqwz20", "text": "That one is seventy-eight. Listen again — find seventy-nine!", "style": "A"}, {"key": "3mmemj", "text": "That one is eighty-six. Listen again — find sixty-eight!", "style": "A"}, {"key": "16zc0yg", "text": "That one is fifty-eight. Listen again — find sixty-eight!", "style": "A"}, {"key": "7l2fx3", "text": "That one is fifty-five. Listen again — find fifty-four!", "style": "A"}, {"key": "1cxwyxu", "text": "That one is twenty-nine. Listen again — find twenty-eight!", "style": "A"}, {"key": "1x97yin", "text": "That one is twenty-six. Listen again — find twenty-five!", "style": "A"}, {"key": "1pw3vz7", "text": "That one is twenty-four. Listen again — find twenty-five!", "style": "A"}, {"key": "1w3czzt", "text": "That one is forty-five. Listen again — find fifty-five!", "style": "A"}, {"key": "s0tiyy", "text": "That one is seventy-one. Listen again — find seventy!", "style": "A"}, {"key": "17vps7y", "text": "That one is fifty-three. Listen again — find sixty-three!", "style": "A"}, {"key": "h01b1k", "text": "That one is thirty-seven. Listen again — find twenty-seven!", "style": "A"}, {"key": "1k1pllo", "text": "That one is eighty. Listen again — find ninety!", "style": "A"}, {"key": "hwn3b8", "text": "That one is ninety-six. Listen again — find ninety-seven!", "style": "A"}, {"key": "9m1kfx", "text": "That one is sixty-eight. Listen again — find eighty-six!", "style": "A"}, {"key": "beeolw", "text": "That one is ninety-six. Listen again — find eighty-six!", "style": "A"}, {"key": "vwvap5", "text": "That one is seventy-eight. Listen again — find eighty-seven!", "style": "A"}, {"key": "kov4d1", "text": "That one is forty-four. Listen again — find fifty-four!", "style": "A"}, {"key": "1vx4zlx", "text": "That one is twenty-eight. Listen again — find twenty-seven!", "style": "A"}, {"key": "1cl8zov", "text": "That one is seventy-five. Listen again — find seventy-six!", "style": "A"}, {"key": "1jtpg8s", "text": "That one is sixty-one. Listen again — find sixty!", "style": "A"}, {"key": "pghoub", "text": "That one is forty-two. Listen again — find forty-three!", "style": "A"}, {"key": "1485knv", "text": "That one is sixty-four. Listen again — find sixty-five!", "style": "A"}, {"key": "rc77r7", "text": "That one is thirty-four. Listen again — find forty-four!", "style": "A"}, {"key": "bo0qwj", "text": "That one is forty-three. Listen again — find thirty-three!", "style": "A"}, {"key": "afyf35", "text": "That one is thirty-four. Listen again — find thirty-three!", "style": "A"}, {"key": "1nuq6wl", "text": "That one is seventy-six. Listen again — find sixty-seven!", "style": "A"}, {"key": "dkszro", "text": "That one is sixty-six. Listen again — find sixty-seven!", "style": "A"}, {"key": "19f4stw", "text": "That one is seventy. Listen again — find sixty!", "style": "A"}, {"key": "1b19d10", "text": "That one is fifty. Listen again — find sixty!", "style": "A"}, {"key": "e6ekzo", "text": "That one is twenty. Listen again — find twenty-one!", "style": "A"}, {"key": "1vbrhua", "text": "That one is forty-six. Listen again — find sixty-four!", "style": "A"}, {"key": "ow8j9s", "text": "That one is thirty. Listen again — find thirty-one!", "style": "A"}, {"key": "rt6klo", "text": "That one is ninety-two. Listen again — find eighty-two!", "style": "A"}, {"key": "9l5gwb", "text": "That one is eighty-four. Listen again — find seventy-four!", "style": "A"}, {"key": "kcd0si", "text": "That one is sixty-four. Listen again — find seventy-four!", "style": "A"}, {"key": "1dz2pe9", "text": "That one is one hundred. Listen again — find ninety-nine!", "style": "A"}, {"key": "1gydrlg", "text": "That one is ninety-eight. Listen again — find ninety-nine!", "style": "A"}, {"key": "1i5u4ge", "text": "That one is fifty-four. Listen again — find sixty-four!", "style": "A"}, {"key": "1pgdp4w", "text": "That one is twenty-six. Listen again — find thirty-six!", "style": "A"}, {"key": "u447v5", "text": "That one is eighty-three. Listen again — find eighty-two!", "style": "A"}, {"key": "4r3umz", "text": "That one is forty-five. Listen again — find forty-six!", "style": "A"}, {"key": "q5ykj", "text": "That one is fifty-six. Listen again — find forty-six!", "style": "A"}, {"key": "majvwt", "text": "That one is sixteen. Listen again — find sixty-one!", "style": "A"}, {"key": "tjiyl9", "text": "That one is thirty-five. Listen again — find thirty-four!", "style": "A"}, {"key": "10lzsh1", "text": "That one is thirty-one. Listen again — find forty-one!", "style": "A"}, {"key": "13mnu5g", "text": "That one is seventy-seven. Listen again — find seventy-six!", "style": "A"}, {"key": "1ppoden", "text": "That one is thirty-four. Listen again — find forty-three!", "style": "A"}, {"key": "xcns37", "text": "That one is twenty-three. Listen again — find twenty-four!", "style": "A"}, {"key": "fzqzkj", "text": "That one is seventy-two. Listen again — find eighty-two!", "style": "A"}, {"key": "4017ju", "text": "That one is fifty-nine. Listen again — find sixty-nine!", "style": "A"}, {"key": "12ak06r", "text": "That one is seventy. Listen again — find sixty-nine!", "style": "A"}, {"key": "3f2bjv", "text": "That one is seventy-six. Listen again — find eighty-six!", "style": "A"}, {"key": "1g4zkn6", "text": "That one is sixty-eight. Listen again — find seventy-eight!", "style": "A"}, {"key": "1cki7d3", "text": "That one is forty-four. Listen again — find forty-three!", "style": "A"}, {"key": "1xg96kh", "text": "That one is twenty-seven. Listen again — find seventy-two!", "style": "A"}, {"key": "lnmhgv", "text": "That one is seventy-one. Listen again — find seventy-two!", "style": "A"}, {"key": "1tvy17i", "text": "That one is seventy-three. Listen again — find thirty-seven!", "style": "A"}, {"key": "1cq5b5w", "text": "That one is forty-eight. Listen again — find forty-nine!", "style": "A"}, {"key": "l97dxn", "text": "That one is seventy-five. Listen again — find seventy-four!", "style": "A"}, {"key": "q1bqjn", "text": "That one is seventy-two. Listen again — find seventy-three!", "style": "A"}, {"key": "1ncd8j7", "text": "That one is sixty-eight. Listen again — find sixty-seven!", "style": "A"}, {"key": "njhew0", "text": "That one is eighty-six. Listen again — find ninety-six!", "style": "A"}, {"key": "8ac4t7", "text": "That one is ninety-five. Listen again — find ninety-six!", "style": "A"}, {"key": "p07lnb", "text": "That one is eighty-nine. Listen again — find seventy-nine!", "style": "A"}, {"key": "179s6gq", "text": "That one is thirteen. Listen again — find twenty-three!", "style": "A"}, {"key": "1rovuxy", "text": "That one is twenty-three. Listen again — find thirty-two!", "style": "A"}, {"key": "1u739o2", "text": "That one is ninety-nine. Listen again — find eighty-nine!", "style": "A"}, {"key": "ooz8u3", "text": "That one is ninety. Listen again — find eighty-nine!", "style": "A"}, {"key": "13jwyr2", "text": "That one is fifty-one. Listen again — find sixty-one!", "style": "A"}, {"key": "4y3n0", "text": "That one is forty-seven. Listen again — find seventy-four!", "style": "A"}, {"key": "1vshsb0", "text": "That one is eighty-nine. Listen again — find ninety-nine!", "style": "A"}, {"key": "1srl56g", "text": "That one is thirty-six. Listen again — find sixty-three!", "style": "A"}, {"key": "1fns0io", "text": "That one is forty-seven. Listen again — find forty-six!", "style": "A"}, {"key": "8jcivs", "text": "That one is eighty-eight. Listen again — find eighty-nine!", "style": "A"}, {"key": "z8ehdr", "text": "That one is thirty. Listen again — find forty!", "style": "A"}, {"key": "19v1ot0", "text": "That one is thirty-four. Listen again — find twenty-four!", "style": "A"}, {"key": "1gd3gts", "text": "That one is fourteen. Listen again — find forty-one!", "style": "A"}, {"key": "1y3ojs", "text": "That one is seventy. Listen again — find seventy-one!", "style": "A"}, {"key": "1rkmsay", "text": "That one is fifty-two. Listen again — find twenty-five!", "style": "A"}, {"key": "1bzxxpx", "text": "That one is forty-six. Listen again — find forty-five!", "style": "A"}, {"key": "ol4730", "text": "That one is twenty. Listen again — find thirty!", "style": "A"}, {"key": "85nkd", "text": "That one is sixty-seven. Listen again — find seventy-six!", "style": "A"}, {"key": "k02uu5", "text": "That one is ninety-eight. Listen again — find eighty-nine!", "style": "A"}, {"key": "9ch0gx", "text": "That one is eighty-seven. Listen again — find seventy-eight!", "style": "A"}, {"key": "13sen1l", "text": "That one is seventy-three. Listen again — find seventy-four!", "style": "A"}, {"key": "1o9wjnw", "text": "That one is thirty-six. Listen again — find thirty-seven!", "style": "A"}, {"key": "1ny1z66", "text": "That one is forty-six. Listen again — find forty-seven!", "style": "A"}, {"key": "131c1po", "text": "That one is eighty-six. Listen again — find eighty-seven!", "style": "A"}, {"key": "1bwt5hv", "text": "That one is eighty-seven. Listen again — find seventy-seven!", "style": "A"}, {"key": "1xtno58", "text": "That one is eighty-four. Listen again — find forty-eight!", "style": "A"}, {"key": "16pnxrl", "text": "That one is seventy-six. Listen again — find seventy-five!", "style": "A"}, {"key": "rl85zd", "text": "That one is fifty-four. Listen again — find forty-four!", "style": "A"}, {"key": "zhekmc", "text": "That one is sixty-two. Listen again — find seventy-two!", "style": "A"}, {"key": "1w5i0ut", "text": "That one is seventy-nine. Listen again — find eighty-nine!", "style": "A"}, {"key": "sjcd2b", "text": "That one is ninety-six. Listen again — find sixty-nine!", "style": "A"}, {"key": "1qms4ja", "text": "That one is twelve. Listen again — find sixteen!", "style": "A"}, {"key": "xn38ym", "text": "That one is twenty. Listen again — find sixteen!", "style": "A"}, {"key": "1dc2zt6", "text": "That is fifty-one, not fifteen. The tens side is on the left — look which one holds one.", "style": "A"}, {"key": "tww9zg", "text": "That is fifty-three, not thirty-five. The tens side is on the left — look which one holds three.", "style": "A"}, {"key": "19rlu5m", "text": "That is seventy-one, not seventeen. The tens side is on the left — look which one holds one.", "style": "A"}, {"key": "kxyjb7", "text": "That is forty-nine, not ninety-four. The tens side is on the left — look which one holds nine.", "style": "A"}, {"key": "1pg3jbt", "text": "That is forty-two, not twenty-four. The tens side is on the left — look which one holds two.", "style": "A"}, {"key": "130p4c8", "text": "That is sixteen, not sixty-one. The tens side is on the left — look which one holds six.", "style": "A"}, {"key": "1id4b26", "text": "That is sixty-two, not twenty-six. The tens side is on the left — look which one holds two.", "style": "A"}, {"key": "jbb8xl", "text": "That is eighty-four, not forty-eight. The tens side is on the left — look which one holds four.", "style": "A"}, {"key": "833yur", "text": "That is forty-six, not sixty-four. The tens side is on the left — look which one holds six.", "style": "A"}, {"key": "1fhalyx", "text": "That is twenty-one, not twelve. The tens side is on the left — look which one holds one.", "style": "A"}, {"key": "1m575el", "text": "That is fourteen, not forty-one. The tens side is on the left — look which one holds four.", "style": "A"}, {"key": "1tizz9s", "text": "That is ninety-two, not twenty-nine. The tens side is on the left — look which one holds two.", "style": "A"}, {"key": "17fkcyr", "text": "That is twenty-three, not thirty-two. The tens side is on the left — look which one holds three.", "style": "A"}, {"key": "lqpv96", "text": "That is twenty-six, not sixty-two. The tens side is on the left — look which one holds six.", "style": "A"}, {"key": "1ar5lwo", "text": "That is fifty-seven, not seventy-five. The tens side is on the left — look which one holds seven.", "style": "A"}, {"key": "1joxizr", "text": "That is thirty-six, not sixty-three. The tens side is on the left — look which one holds six.", "style": "A"}, {"key": "qef1up", "text": "That is fifty-six, not sixty-five. The tens side is on the left — look which one holds six.", "style": "A"}, {"key": "wtv18l", "text": "That is thirty-two, not twenty-three. The tens side is on the left — look which one holds two.", "style": "A"}, {"key": "f0khay", "text": "That is fifty-four, not forty-five. The tens side is on the left — look which one holds four.", "style": "A"}, {"key": "1vv29oi", "text": "That is eighty-six, not sixty-eight. The tens side is on the left — look which one holds six.", "style": "A"}, {"key": "1c0xh4s", "text": "That is thirty-five, not fifty-three. The tens side is on the left — look which one holds five.", "style": "A"}, {"key": "1fd18f2", "text": "That is forty-three, not thirty-four. The tens side is on the left — look which one holds three.", "style": "A"}, {"key": "40sjo7", "text": "That is fifty-two, not twenty-five. The tens side is on the left — look which one holds two.", "style": "A"}, {"key": "19o3kpe", "text": "That is seventy-two, not twenty-seven. The tens side is on the left — look which one holds two.", "style": "A"}, {"key": "1flp6ov", "text": "That is eighteen, not eighty-one. The tens side is on the left — look which one holds eight.", "style": "A"}, {"key": "1u9sd6o", "text": "That is twenty-nine, not ninety-two. The tens side is on the left — look which one holds nine.", "style": "A"}, {"key": "dqi8sq", "text": "That is eighty-one, not eighteen. The tens side is on the left — look which one holds one.", "style": "A"}, {"key": "fr4b3o", "text": "That is sixty-one, not sixteen. The tens side is on the left — look which one holds one.", "style": "A"}, {"key": "1g00z76", "text": "That is thirty-one, not thirteen. The tens side is on the left — look which one holds one.", "style": "A"}, {"key": "1rtoet1", "text": "That is seventy-five, not fifty-seven. The tens side is on the left — look which one holds five.", "style": "A"}, {"key": "ax3vzs", "text": "That is eighty-two, not twenty-eight. The tens side is on the left — look which one holds two.", "style": "A"}, {"key": "9k157n", "text": "That is sixty-four, not forty-six. The tens side is on the left — look which one holds four.", "style": "A"}, {"key": "1s71343", "text": "That is ninety-three, not thirty-nine. The tens side is on the left — look which one holds three.", "style": "A"}, {"key": "x2vqlb", "text": "That is seventy-four, not forty-seven. The tens side is on the left — look which one holds four.", "style": "A"}, {"key": "157vbv7", "text": "That is eighty-five, not fifty-eight. The tens side is on the left — look which one holds five.", "style": "A"}, {"key": "qmmqbl", "text": "That is twenty-five, not fifty-two. The tens side is on the left — look which one holds five.", "style": "A"}, {"key": "1xg3qkv", "text": "That is twenty-four, not forty-two. The tens side is on the left — look which one holds four.", "style": "A"}, {"key": "z6oli1", "text": "That is forty-one, not fourteen. The tens side is on the left — look which one holds one.", "style": "A"}, {"key": "139uk1f", "text": "That is thirty-nine, not ninety-three. The tens side is on the left — look which one holds nine.", "style": "A"}, {"key": "d6vuo6", "text": "That is thirteen, not thirty-one. The tens side is on the left — look which one holds three.", "style": "A"}, {"key": "kzpiv5", "text": "That is ninety-five, not fifty-nine. The tens side is on the left — look which one holds five.", "style": "A"}, {"key": "nhnwca", "text": "That is ninety-one, not nineteen. The tens side is on the left — look which one holds one.", "style": "A"}, {"key": "38j63l", "text": "That is sixty-five, not fifty-six. The tens side is on the left — look which one holds five.", "style": "A"}, {"key": "gd8qot", "text": "That is eighty-three, not thirty-eight. The tens side is on the left — look which one holds three.", "style": "A"}, {"key": "188gg98", "text": "That is ninety-six, not sixty-nine. The tens side is on the left — look which one holds six.", "style": "A"}, {"key": "2npayn", "text": "That is twelve, not twenty-one. The tens side is on the left — look which one holds two.", "style": "A"}, {"key": "6i9b4a", "text": "That is seventy-nine, not ninety-seven. The tens side is on the left — look which one holds nine.", "style": "A"}, {"key": "13ld9xf", "text": "That is ninety-four, not forty-nine. The tens side is on the left — look which one holds four.", "style": "A"}, {"key": "1pxkgra", "text": "That is thirty-four, not forty-three. The tens side is on the left — look which one holds four.", "style": "A"}, {"key": "13wdjk5", "text": "That is seventeen, not seventy-one. The tens side is on the left — look which one holds seven.", "style": "A"}, {"key": "11yammo", "text": "That is sixty-nine, not ninety-six. The tens side is on the left — look which one holds nine.", "style": "A"}, {"key": "mxoxo0", "text": "That is seventy-six, not sixty-seven. The tens side is on the left — look which one holds six.", "style": "A"}, {"key": "1cbxlan", "text": "That is seventy-three, not thirty-seven. The tens side is on the left — look which one holds three.", "style": "A"}, {"key": "qexxmd", "text": "That is ninety-eight, not eighty-nine. The tens side is on the left — look which one holds eight.", "style": "A"}, {"key": "1hiw0k7", "text": "That is sixty-eight, not eighty-six. The tens side is on the left — look which one holds eight.", "style": "A"}, {"key": "d7t38f", "text": "That is twenty-seven, not seventy-two. The tens side is on the left — look which one holds seven.", "style": "A"}, {"key": "12gnxdf", "text": "That is sixty-three, not thirty-six. The tens side is on the left — look which one holds three.", "style": "A"}, {"key": "1av2gcv", "text": "That is twenty-eight, not eighty-two. The tens side is on the left — look which one holds eight.", "style": "A"}, {"key": "xvmfwq", "text": "That is forty-five, not fifty-four. The tens side is on the left — look which one holds five.", "style": "A"}, {"key": "1pacdi4", "text": "That is eighty-nine, not ninety-eight. The tens side is on the left — look which one holds nine.", "style": "A"}, {"key": "1dq4iuo", "text": "That is forty-eight, not eighty-four. The tens side is on the left — look which one holds eight.", "style": "A"}, {"key": "1dnmmfx", "text": "That is fifty-nine, not ninety-five. The tens side is on the left — look which one holds nine.", "style": "A"}, {"key": "1ey62mt", "text": "That is ninety-seven, not seventy-nine. The tens side is on the left — look which one holds seven.", "style": "A"}, {"key": "1mua12v", "text": "That is eighty-seven, not seventy-eight. The tens side is on the left — look which one holds seven.", "style": "A"}, {"key": "317qq", "text": "That is fifteen, not fifty-one. The tens side is on the left — look which one holds five.", "style": "A"}]
todo = [r for r in LINES if not (REPO / 'public/audio' / VOICE / f"{r['key']}.mp3").exists()]
json.dump(todo, open(WORK / 'todo.json', 'w'))
print(len(todo), 'lines to render')
assert 0 < len(todo) <= 1500, 'nothing to render — every line already has a clip on main'

# %%
# Chatterbox pins torch 2.6, which breaks Kaggle's own torchvision — so it gets its own venv (uv: Kaggle's python has no ensurepip).
VENV = WORK / 'venv'; PY = VENV / 'bin' / 'python'; READY = VENV / '.ready'
if not READY.exists():
    shutil.rmtree(VENV, ignore_errors=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'uv'], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'venv', str(VENV), '--python', sys.executable], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'pip', 'install', '--python', str(PY), 'setuptools<81', 'chatterbox-tts', 'imageio-ffmpeg'], check=True)
    READY.touch()
print(subprocess.run([str(PY), '-c', "import torch; print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NONE — set the accelerator')"], capture_output=True, text=True).stdout)

# %%
OUT = WORK / 'out' / VOICE
cmd = [str(PY), str(REPO / 'scripts/chatterbox-render.py'), '--voice', VOICE, '--corpus', str(WORK / 'todo.json'), '--out', str(OUT)]
proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in proc.stdout:
    if 'it/s]' in line or not line.strip(): continue   # drop the progress bars
    print(line.rstrip()[:160], flush=True)
print('exit code', proc.wait())

# %%
keys = {r['key'] for r in todo}
clips = sorted(c for c in OUT.glob('*.mp3') if c.stem in keys)
missing = [k for k in keys if not (OUT / f'{k}.mp3').exists()]
stage = WORK / 'stage'; shutil.rmtree(stage, ignore_errors=True); (stage / VOICE).mkdir(parents=True)
for c in clips: shutil.copy2(c, stage / VOICE / c.name)
shutil.make_archive(str(WORK / 'radlic-voice-josh-chapters-g1-2'), 'zip', stage)
print(f'{len(clips)} of {len(todo)} clips in radlic-voice-josh-chapters-g1-2.zip' + (f' — MISSING {len(missing)}: {missing}' if missing else ' — complete'))
