# %% [markdown]
# # Radlic voice — Grade 1 (part 1 of 3) story chapters in Josh
#
# Renders every line the Grade 1 (part 1 of 3) story chapters can say that has no clip yet — **1500 lines, 66,647 characters** (the lines are
# written into this notebook). Style A (Chatterbox Turbo) for all of them. Rules: `docs/new-flow/voice.md`.
#
# **Before Run All:** Settings → Accelerator → **GPU T4 x2** (or P100), Internet **On**. At the end, download
# `radlic-voice-josh-chapters-g1-1.zip` from the Output panel and hand it back. If the session stops early, Run All
# again in the same session: lines already rendered are skipped.

# %%
import os, sys, subprocess, pathlib, shutil, json
VOICE = 'nzFihrBIvB34imQBuxub'   # Josh
WORK = pathlib.Path('/kaggle/working' if os.path.isdir('/kaggle/working') else '/content')
REPO = WORK / 'learn-main'
if not REPO.exists():
    subprocess.run(['git', 'clone', '--depth', '1', '--branch', 'main', 'https://github.com/RadlorInc/learn.git', str(REPO)], check=True)
LINES = [{"key": "hmxfkt", "text": "2 are playing. 1 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "1ytz3dy", "text": "2 are playing. 4 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "izieeb", "text": "6 are playing. 3 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "1vahqbh", "text": "3 are playing. 2 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "1akf06l", "text": "4 are playing. 3 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "w3aa4a", "text": "6 are playing. 4 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "w7i7pj", "text": "2 are playing. 3 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "1hm0wnb", "text": "1 are playing. 2 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "rxo7a4", "text": "2 are playing. 2 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "nd7923", "text": "3 are playing. 4 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "1gu54xo", "text": "3 are playing. 1 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "1yyfjte", "text": "3 are playing. 3 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "wxbn1x", "text": "5 are playing. 4 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "1y61cqo", "text": "4 are playing. 4 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "f0ubjm", "text": "1 are playing. 1 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "i8tmrm", "text": "4 are playing. 2 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "a0zzgo", "text": "5 are playing. 3 more come to play. Count them all, then tap how many.", "style": "A"}, {"key": "139wgn4", "text": "5 are playing. 2 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "6im3hx", "text": "6 are playing. 2 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "slhq5n", "text": "8 are playing. 6 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "1jufoxw", "text": "4 are playing. 1 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "lym573", "text": "7 are playing. 3 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "7cn2jl", "text": "10 are playing. 3 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "16jhz7w", "text": "7 are playing. 4 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "ap33mn", "text": "9 are playing. 5 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "3b7cwu", "text": "3 are playing. 2 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "6340rz", "text": "10 are playing. 5 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "rlwksv", "text": "5 are playing. 1 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "87usx1", "text": "5 are playing. 3 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "9dr4kq", "text": "9 are playing. 4 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "1ayb49", "text": "3 are playing. 1 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "1aiy92z", "text": "6 are playing. 4 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "1xobdyy", "text": "10 are playing. 4 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "c3zp7e", "text": "7 are playing. 2 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "1o9obi9", "text": "8 are playing. 4 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "suhqxc", "text": "9 are playing. 6 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "1dec10a", "text": "8 are playing. 3 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "wk1y9v", "text": "4 are playing. 2 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "w4x6rz", "text": "8 are playing. 2 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "zsnmz4", "text": "6 are playing. 3 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "19r8eao", "text": "10 are playing. 6 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "18xyj0x", "text": "9 are playing. 3 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "1324b4m", "text": "5 are playing. 4 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "mqe79o", "text": "8 are playing. 5 go home. Count who is left, then tap how many.", "style": "A"}, {"key": "j9kn9h", "text": "Find number fourteen. Tap the one that says 14.", "style": "A"}, {"key": "1xy3ccc", "text": "Find number thirty-seven. Tap the one that says 37.", "style": "A"}, {"key": "jjddrs", "text": "Find number seventy-seven. Tap the one that says 77.", "style": "A"}, {"key": "1vet018", "text": "Find number nineteen. Tap the one that says 19.", "style": "A"}, {"key": "ygwo5z", "text": "Find number sixty. Tap the one that says 60.", "style": "A"}, {"key": "qjx5rf", "text": "Find number fifty-one. Tap the one that says 51.", "style": "A"}, {"key": "gng0vi", "text": "Find number ten. Tap the one that says 10.", "style": "A"}, {"key": "1nqxfy9", "text": "Find number twenty-one. Tap the one that says 21.", "style": "A"}, {"key": "1d1bwiq", "text": "Find number ninety-one. Tap the one that says 91.", "style": "A"}, {"key": "1eg8n8y", "text": "Find number twenty-six. Tap the one that says 26.", "style": "A"}, {"key": "n6edk0", "text": "Find number ninety-five. Tap the one that says 95.", "style": "A"}, {"key": "xsx1m", "text": "Find number eighteen. Tap the one that says 18.", "style": "A"}, {"key": "1aexcrx", "text": "Find number thirty-five. Tap the one that says 35.", "style": "A"}, {"key": "1leagzb", "text": "Find number sixty-five. Tap the one that says 65.", "style": "A"}, {"key": "1lip7e9", "text": "Find number sixteen. Tap the one that says 16.", "style": "A"}, {"key": "40b0ij", "text": "Find number thirty-three. Tap the one that says 33.", "style": "A"}, {"key": "1jn4b80", "text": "Find number seventy-four. Tap the one that says 74.", "style": "A"}, {"key": "1v1n25i", "text": "Find number twenty-four. Tap the one that says 24.", "style": "A"}, {"key": "do22uu", "text": "Find number eighty-one. Tap the one that says 81.", "style": "A"}, {"key": "15l3v0j", "text": "Find number fifty-five. Tap the one that says 55.", "style": "A"}, {"key": "1xsmfli", "text": "Find number eighty-nine. Tap the one that says 89.", "style": "A"}, {"key": "1o2vktz", "text": "Find number twenty. Tap the one that says 20.", "style": "A"}, {"key": "hpegf0", "text": "Find number thirty-four. Tap the one that says 34.", "style": "A"}, {"key": "1dz2cbr", "text": "Find number ninety-two. Tap the one that says 92.", "style": "A"}, {"key": "139do27", "text": "Find number thirty. Tap the one that says 30.", "style": "A"}, {"key": "gjn958", "text": "Find number sixty-two. Tap the one that says 62.", "style": "A"}, {"key": "uzrv2s", "text": "Find number twenty-two. Tap the one that says 22.", "style": "A"}, {"key": "qdatvy", "text": "Find number fifty-seven. Tap the one that says 57.", "style": "A"}, {"key": "tcywbg", "text": "Find number twelve. Tap the one that says 12.", "style": "A"}, {"key": "y2cw22", "text": "Find number thirty-six. Tap the one that says 36.", "style": "A"}, {"key": "1fuuy6d", "text": "Find number fifty. Tap the one that says 50.", "style": "A"}, {"key": "1ofwj3l", "text": "Find number seventy-eight. Tap the one that says 78.", "style": "A"}, {"key": "1x866be", "text": "Find number fifty-four. Tap the one that says 54.", "style": "A"}, {"key": "d8fc98", "text": "Find number fifty-six. Tap the one that says 56.", "style": "A"}, {"key": "1keeg8g", "text": "Find number seventy-two. Tap the one that says 72.", "style": "A"}, {"key": "k2zz06", "text": "Find number forty-one. Tap the one that says 41.", "style": "A"}, {"key": "zg5ppu", "text": "Find number eighty-eight. Tap the one that says 88.", "style": "A"}, {"key": "12gzubz", "text": "Find number eleven. Tap the one that says 11.", "style": "A"}, {"key": "1r2r3nr", "text": "Find number fifty-eight. Tap the one that says 58.", "style": "A"}, {"key": "mvsit8", "text": "Find number ninety-three. Tap the one that says 93.", "style": "A"}, {"key": "uoiisf", "text": "Find number fifty-nine. Tap the one that says 59.", "style": "A"}, {"key": "5jkq49", "text": "Find number fifteen. Tap the one that says 15.", "style": "A"}, {"key": "troru2", "text": "Find number forty-five. Tap the one that says 45.", "style": "A"}, {"key": "wh9447", "text": "Find number seventeen. Tap the one that says 17.", "style": "A"}, {"key": "1m4uaf5", "text": "Find number thirty-nine. Tap the one that says 39.", "style": "A"}, {"key": "idyakz", "text": "Find number twenty-three. Tap the one that says 23.", "style": "A"}, {"key": "mo0ap9", "text": "Find number ninety-four. Tap the one that says 94.", "style": "A"}, {"key": "hylp0f", "text": "Find number forty-four. Tap the one that says 44.", "style": "A"}, {"key": "6o6xw", "text": "Find number ninety-nine. Tap the one that says 99.", "style": "A"}, {"key": "14tv9nh", "text": "Find number thirty-one. Tap the one that says 31.", "style": "A"}, {"key": "1sz67fx", "text": "Find number fifty-three. Tap the one that says 53.", "style": "A"}, {"key": "19ieapz", "text": "Find number forty-two. Tap the one that says 42.", "style": "A"}, {"key": "m80mfp", "text": "Find number seventy-nine. Tap the one that says 79.", "style": "A"}, {"key": "5irqqk", "text": "Find number ninety. Tap the one that says 90.", "style": "A"}, {"key": "13vfa77", "text": "Find number seventy. Tap the one that says 70.", "style": "A"}, {"key": "nln2rf", "text": "Find number forty-seven. Tap the one that says 47.", "style": "A"}, {"key": "qpd6g4", "text": "Find number twenty-seven. Tap the one that says 27.", "style": "A"}, {"key": "1i8v1zg", "text": "Find number forty-three. Tap the one that says 43.", "style": "A"}, {"key": "a3ho2d", "text": "Find number eighty-six. Tap the one that says 86.", "style": "A"}, {"key": "17q5ky5", "text": "Find number thirty-eight. Tap the one that says 38.", "style": "A"}, {"key": "wdmw75", "text": "Find number sixty-eight. Tap the one that says 68.", "style": "A"}, {"key": "1pltwmt", "text": "Find number one hundred. Tap the one that says 100.", "style": "A"}, {"key": "pcaw7u", "text": "Find number forty-eight. Tap the one that says 48.", "style": "A"}, {"key": "1l5fnu1", "text": "Find number seventy-one. Tap the one that says 71.", "style": "A"}, {"key": "1l40zo3", "text": "Find number thirteen. Tap the one that says 13.", "style": "A"}, {"key": "h2t1fv", "text": "Find number twenty-nine. Tap the one that says 29.", "style": "A"}, {"key": "3p2adv", "text": "Find number ninety-seven. Tap the one that says 97.", "style": "A"}, {"key": "131f69p", "text": "Find number forty-six. Tap the one that says 46.", "style": "A"}, {"key": "1qgnozn", "text": "Find number sixty-three. Tap the one that says 63.", "style": "A"}, {"key": "1pm57lh", "text": "Find number ninety-six. Tap the one that says 96.", "style": "A"}, {"key": "1p108z2", "text": "Find number sixty-four. Tap the one that says 64.", "style": "A"}, {"key": "qm4gsn", "text": "Find number eighty-four. Tap the one that says 84.", "style": "A"}, {"key": "1vk7ut8", "text": "Find number sixty-seven. Tap the one that says 67.", "style": "A"}, {"key": "1uokurb", "text": "Find number twenty-five. Tap the one that says 25.", "style": "A"}, {"key": "1003rgh", "text": "Find number sixty-one. Tap the one that says 61.", "style": "A"}, {"key": "14njyay", "text": "Find number fifty-two. Tap the one that says 52.", "style": "A"}, {"key": "1sbj5pr", "text": "Find number seventy-three. Tap the one that says 73.", "style": "A"}, {"key": "1wspn1o", "text": "Find number eighty-three. Tap the one that says 83.", "style": "A"}, {"key": "tlo1y7", "text": "Find number eighty-two. Tap the one that says 82.", "style": "A"}, {"key": "1d1wmg4", "text": "Find number eighty. Tap the one that says 80.", "style": "A"}, {"key": "15flugu", "text": "Find number ninety-eight. Tap the one that says 98.", "style": "A"}, {"key": "d0u70u", "text": "Find number forty-nine. Tap the one that says 49.", "style": "A"}, {"key": "1ono9d5", "text": "Find number twenty-eight. Tap the one that says 28.", "style": "A"}, {"key": "12w6noi", "text": "Find number eighty-five. Tap the one that says 85.", "style": "A"}, {"key": "12s9lzv", "text": "Find number sixty-nine. Tap the one that says 69.", "style": "A"}, {"key": "7rxyqh", "text": "Find number seventy-five. Tap the one that says 75.", "style": "A"}, {"key": "1itprqk", "text": "Find number forty. Tap the one that says 40.", "style": "A"}, {"key": "esb98z", "text": "Find number eighty-seven. Tap the one that says 87.", "style": "A"}, {"key": "qdenqu", "text": "Find number seventy-six. Tap the one that says 76.", "style": "A"}, {"key": "16mmz56", "text": "Find number sixty-six. Tap the one that says 66.", "style": "A"}, {"key": "o8en6s", "text": "Find number thirty-two. Tap the one that says 32.", "style": "A"}, {"key": "195aapo", "text": "Make fifteen. Tens on the left, ones on the right.", "style": "A"}, {"key": "16kscyi", "text": "Make thirty-five. Tens on the left, ones on the right.", "style": "A"}, {"key": "j30y9u", "text": "How many on the tens side?", "style": "A"}, {"key": "1kfs8y8", "text": "Make seventeen. Tens on the left, ones on the right.", "style": "A"}, {"key": "15sm96s", "text": "The tens side — how much is it worth?", "style": "A"}, {"key": "y0z3mv", "text": "Make ninety-four. Tens on the left, ones on the right.", "style": "A"}, {"key": "jguamx", "text": "Make twenty-four. Tens on the left, ones on the right.", "style": "A"}, {"key": "17emdrc", "text": "How many altogether?", "style": "A"}, {"key": "17yj2wn", "text": "Make sixty-one. Tens on the left, ones on the right.", "style": "A"}, {"key": "14aigjv", "text": "Make twenty-six. Tens on the left, ones on the right.", "style": "A"}, {"key": "391jq7", "text": "Make forty-eight. Tens on the left, ones on the right.", "style": "A"}, {"key": "ktsdvx", "text": "Make sixty-four. Tens on the left, ones on the right.", "style": "A"}, {"key": "18yrlxa", "text": "Make twelve. Tens on the left, ones on the right.", "style": "A"}, {"key": "1aws1so", "text": "Make forty-one. Tens on the left, ones on the right.", "style": "A"}, {"key": "1b83b91", "text": "Make twenty-nine. Tens on the left, ones on the right.", "style": "A"}, {"key": "ygh79g", "text": "Make thirty-two. Tens on the left, ones on the right.", "style": "A"}, {"key": "1meagqh", "text": "Make sixty-two. Tens on the left, ones on the right.", "style": "A"}, {"key": "1g59d9m", "text": "Make seventy-five. Tens on the left, ones on the right.", "style": "A"}, {"key": "1hfkt7b", "text": "How many on the ones side?", "style": "A"}, {"key": "8eb12f", "text": "Make sixty-three. Tens on the left, ones on the right.", "style": "A"}, {"key": "1o13ijd", "text": "Make sixty-five. Tens on the left, ones on the right.", "style": "A"}, {"key": "17ovjuj", "text": "Make twenty-three. Tens on the left, ones on the right.", "style": "A"}, {"key": "3zzy1s", "text": "Make forty-five. Tens on the left, ones on the right.", "style": "A"}, {"key": "14gswvc", "text": "Make sixty-eight. Tens on the left, ones on the right.", "style": "A"}, {"key": "1846yae", "text": "Make fifty-three. Tens on the left, ones on the right.", "style": "A"}, {"key": "1f1te2m", "text": "Make thirty-four. Tens on the left, ones on the right.", "style": "A"}, {"key": "18d1951", "text": "Make twenty-five. Tens on the left, ones on the right.", "style": "A"}, {"key": "1lrtxe", "text": "Make twenty-seven. Tens on the left, ones on the right.", "style": "A"}, {"key": "1mnfrd8", "text": "Make eighty-one. Tens on the left, ones on the right.", "style": "A"}, {"key": "gau1e3", "text": "Make ninety-two. Tens on the left, ones on the right.", "style": "A"}, {"key": "mpzdlu", "text": "Make eighteen. Tens on the left, ones on the right.", "style": "A"}, {"key": "5wwkm1", "text": "Make sixteen. Tens on the left, ones on the right.", "style": "A"}, {"key": "ct8868", "text": "Make thirteen. Tens on the left, ones on the right.", "style": "A"}, {"key": "1vtuiif", "text": "Make fifty-seven. Tens on the left, ones on the right.", "style": "A"}, {"key": "9fcld8", "text": "Make twenty-eight. Tens on the left, ones on the right.", "style": "A"}, {"key": "132uoi0", "text": "Make forty-six. Tens on the left, ones on the right.", "style": "A"}, {"key": "17yxgxm", "text": "Make thirty-nine. Tens on the left, ones on the right.", "style": "A"}, {"key": "dwsk89", "text": "Make forty-seven. Tens on the left, ones on the right.", "style": "A"}, {"key": "snjkn1", "text": "Make fifty-eight. Tens on the left, ones on the right.", "style": "A"}, {"key": "1dobddk", "text": "Make fifty-two. Tens on the left, ones on the right.", "style": "A"}, {"key": "qnzrby", "text": "Make forty-two. Tens on the left, ones on the right.", "style": "A"}, {"key": "1wm9akn", "text": "Make fourteen. Tens on the left, ones on the right.", "style": "A"}, {"key": "1pmgskd", "text": "Make ninety-three. Tens on the left, ones on the right.", "style": "A"}, {"key": "pu1lxi", "text": "Make thirty-one. Tens on the left, ones on the right.", "style": "A"}, {"key": "11unfyu", "text": "Make fifty-nine. Tens on the left, ones on the right.", "style": "A"}, {"key": "9obhhz", "text": "Make nineteen. Tens on the left, ones on the right.", "style": "A"}, {"key": "1opcy9q", "text": "Make fifty-six. Tens on the left, ones on the right.", "style": "A"}, {"key": "12r4pl", "text": "Make thirty-eight. Tens on the left, ones on the right.", "style": "A"}, {"key": "95lftl", "text": "Make sixty-nine. Tens on the left, ones on the right.", "style": "A"}, {"key": "13wv8t7", "text": "Make twenty-one. Tens on the left, ones on the right.", "style": "A"}, {"key": "nndy18", "text": "Make ninety-seven. Tens on the left, ones on the right.", "style": "A"}, {"key": "124x3cg", "text": "Make forty-nine. Tens on the left, ones on the right.", "style": "A"}, {"key": "1lgm1gw", "text": "Make forty-three. Tens on the left, ones on the right.", "style": "A"}, {"key": "12qhjfa", "text": "Make seventy-one. Tens on the left, ones on the right.", "style": "A"}, {"key": "vdnwnx", "text": "Make ninety-six. Tens on the left, ones on the right.", "style": "A"}, {"key": "hw1ufa", "text": "Make sixty-seven. Tens on the left, ones on the right.", "style": "A"}, {"key": "195hfln", "text": "Make thirty-seven. Tens on the left, ones on the right.", "style": "A"}, {"key": "sq9ky4", "text": "Make eighty-nine. Tens on the left, ones on the right.", "style": "A"}, {"key": "1o3mkfo", "text": "Make eighty-six. Tens on the left, ones on the right.", "style": "A"}, {"key": "1y8g02c", "text": "Make seventy-two. Tens on the left, ones on the right.", "style": "A"}, {"key": "srlgoy", "text": "Make thirty-six. Tens on the left, ones on the right.", "style": "A"}, {"key": "1r4ym1u", "text": "Make eighty-two. Tens on the left, ones on the right.", "style": "A"}, {"key": "11n4ld6", "text": "Make fifty-four. Tens on the left, ones on the right.", "style": "A"}, {"key": "12tz2se", "text": "Make ninety-eight. Tens on the left, ones on the right.", "style": "A"}, {"key": "xtre9w", "text": "Make eighty-four. Tens on the left, ones on the right.", "style": "A"}, {"key": "gxo8yf", "text": "Make ninety-five. Tens on the left, ones on the right.", "style": "A"}, {"key": "1ulv1gq", "text": "Make seventy-nine. Tens on the left, ones on the right.", "style": "A"}, {"key": "1x03ocp", "text": "Make seventy-eight. Tens on the left, ones on the right.", "style": "A"}, {"key": "3fgr2i", "text": "Make fifty-one. Tens on the left, ones on the right.", "style": "A"}, {"key": "c5jhlo", "text": "Make eighty-five. Tens on the left, ones on the right.", "style": "A"}, {"key": "1h789tg", "text": "Make eighty-three. Tens on the left, ones on the right.", "style": "A"}, {"key": "1d7yu51", "text": "Make eighty-seven. Tens on the left, ones on the right.", "style": "A"}, {"key": "1gr0toy", "text": "Make seventy-six. Tens on the left, ones on the right.", "style": "A"}, {"key": "1e2o0hd", "text": "Make ninety-one. Tens on the left, ones on the right.", "style": "A"}, {"key": "1j6wawi", "text": "Make seventy-three. Tens on the left, ones on the right.", "style": "A"}, {"key": "kdgsiy", "text": "Yes! one tens and five ones make fifteen.", "style": "A"}, {"key": "1as9z6c", "text": "Yes! three tens and five ones make thirty-five.", "style": "A"}, {"key": "nv06xt", "text": "Yes! 9 tens — worth 90", "style": "A"}, {"key": "lbazml", "text": "Yes! one tens and seven ones make seventeen.", "style": "A"}, {"key": "1n9j6jr", "text": "Yes! 3 tens are worth 30", "style": "A"}, {"key": "1e707zl", "text": "Yes! nine tens and four ones make ninety-four.", "style": "A"}, {"key": "1bz9jnb", "text": "Yes! two tens and four ones make twenty-four.", "style": "A"}, {"key": "obmhe1", "text": "Yes! 3 tens — worth 30", "style": "A"}, {"key": "8kwx1t", "text": "Yes! 2 tens and 5 ones make 25", "style": "A"}, {"key": "17vrp75", "text": "Yes! 5 tens — worth 50", "style": "A"}, {"key": "zad0o3", "text": "Yes! six tens and one ones make sixty-one.", "style": "A"}, {"key": "dffcap", "text": "Yes! two tens and six ones make twenty-six.", "style": "A"}, {"key": "cbfaw4", "text": "Yes! four tens and eight ones make forty-eight.", "style": "A"}, {"key": "y4nlyh", "text": "Yes! six tens and four ones make sixty-four.", "style": "A"}, {"key": "nh7ove", "text": "Yes! one tens and two ones make twelve.", "style": "A"}, {"key": "eevzw", "text": "Yes! four tens and one ones make forty-one.", "style": "A"}, {"key": "687mvp", "text": "Yes! 6 tens are worth 60", "style": "A"}, {"key": "ogey4z", "text": "Yes! two tens and nine ones make twenty-nine.", "style": "A"}, {"key": "s5qcjg", "text": "Yes! three tens and two ones make thirty-two.", "style": "A"}, {"key": "fctjpz", "text": "Yes! six tens and two ones make sixty-two.", "style": "A"}, {"key": "1ytjv19", "text": "Yes! 1 tens and 4 ones make 14", "style": "A"}, {"key": "1d0dj9d", "text": "Yes! seven tens and five ones make seventy-five.", "style": "A"}, {"key": "tlmdtw", "text": "Yes! 4 ones", "style": "A"}, {"key": "1xiyehv", "text": "Yes! 4 tens — worth 40", "style": "A"}, {"key": "1p6rt0x", "text": "Yes! 1 tens and 2 ones make 12", "style": "A"}, {"key": "xa6m9d", "text": "Yes! 2 tens and 7 ones make 27", "style": "A"}, {"key": "1xmurbd", "text": "Yes! 9 tens and 6 ones make 96", "style": "A"}, {"key": "dg5gyz", "text": "Yes! six tens and three ones make sixty-three.", "style": "A"}, {"key": "1rfaypx", "text": "Yes! six tens and five ones make sixty-five.", "style": "A"}, {"key": "vu57tt", "text": "Yes! two tens and three ones make twenty-three.", "style": "A"}, {"key": "13rzdnz", "text": "Yes! 2 tens — worth 20", "style": "A"}, {"key": "jwoktd", "text": "Yes! 4 tens are worth 40", "style": "A"}, {"key": "in1xy1", "text": "Yes! 2 tens and 3 ones make 23", "style": "A"}, {"key": "1dta981", "text": "Yes! 3 tens and 6 ones make 36", "style": "A"}, {"key": "kvui8p", "text": "Yes! 2 tens and 9 ones make 29", "style": "A"}, {"key": "1fntj1b", "text": "Yes! 5 tens are worth 50", "style": "A"}, {"key": "n8ygdz", "text": "Yes! 1 tens and 9 ones make 19", "style": "A"}, {"key": "1wipwz8", "text": "Yes! four tens and five ones make forty-five.", "style": "A"}, {"key": "5bwzix", "text": "Yes! 7 tens — worth 70", "style": "A"}, {"key": "60fctb", "text": "Yes! six tens and eight ones make sixty-eight.", "style": "A"}, {"key": "1gmfd9v", "text": "Yes! 8 tens — worth 80", "style": "A"}, {"key": "14w9ajd", "text": "Yes! 2 tens and 1 ones make 21", "style": "A"}, {"key": "1mliy3u", "text": "Yes! five tens and three ones make fifty-three.", "style": "A"}, {"key": "v5itcf", "text": "Yes! 7 tens are worth 70", "style": "A"}, {"key": "1u2nud1", "text": "Yes! 9 ones", "style": "A"}, {"key": "15aol7k", "text": "Yes! three tens and four ones make thirty-four.", "style": "A"}, {"key": "f7trv7", "text": "Yes! two tens and five ones make twenty-five.", "style": "A"}, {"key": "15pmqkn", "text": "Yes! two tens and seven ones make twenty-seven.", "style": "A"}, {"key": "7foetb", "text": "Yes! eight tens and one ones make eighty-one.", "style": "A"}, {"key": "1j7y2ev", "text": "Yes! 9 tens are worth 90", "style": "A"}, {"key": "1tro61t", "text": "Yes! 5 tens and 6 ones make 56", "style": "A"}, {"key": "2rw0n3", "text": "Yes! nine tens and two ones make ninety-two.", "style": "A"}, {"key": "1s7cntv", "text": "Yes! 3 ones", "style": "A"}, {"key": "1rpiq9z", "text": "Yes! 1 tens and 3 ones make 13", "style": "A"}, {"key": "nxe317", "text": "Yes! 2 tens and 2 ones make 22", "style": "A"}, {"key": "1qjt5i7", "text": "Yes! one tens and eight ones make eighteen.", "style": "A"}, {"key": "q5ym7l", "text": "Yes! one tens and six ones make sixteen.", "style": "A"}, {"key": "143wcs9", "text": "Yes! 5 ones", "style": "A"}, {"key": "1tal8nq", "text": "Yes! one tens and three ones make thirteen.", "style": "A"}, {"key": "1poqt33", "text": "Yes! 5 tens and 3 ones make 53", "style": "A"}, {"key": "77tj15", "text": "Yes! 6 tens and 1 ones make 61", "style": "A"}, {"key": "kh1dmi", "text": "Yes! five tens and seven ones make fifty-seven.", "style": "A"}, {"key": "1ndy7y3", "text": "Yes! two tens and eight ones make twenty-eight.", "style": "A"}, {"key": "1y4s9no", "text": "Yes! four tens and six ones make forty-six.", "style": "A"}, {"key": "1u9mc78", "text": "Yes! three tens and nine ones make thirty-nine.", "style": "A"}, {"key": "eyvqcr", "text": "Yes! 4 tens and 4 ones make 44", "style": "A"}, {"key": "17krhhh", "text": "Yes! 4 tens and 9 ones make 49", "style": "A"}, {"key": "1c7d04s", "text": "Yes! four tens and seven ones make forty-seven.", "style": "A"}, {"key": "n7471n", "text": "Yes! 6 tens and 6 ones make 66", "style": "A"}, {"key": "qp262e", "text": "Yes! five tens and eight ones make fifty-eight.", "style": "A"}, {"key": "8xo8lt", "text": "Yes! 8 tens are worth 80", "style": "A"}, {"key": "1yepfbx", "text": "Yes! 2 tens are worth 20", "style": "A"}, {"key": "17mlc02", "text": "Yes! five tens and two ones make fifty-two.", "style": "A"}, {"key": "1plkkf", "text": "Yes! 6 tens and 8 ones make 68", "style": "A"}, {"key": "1dmlg98", "text": "Yes! four tens and two ones make forty-two.", "style": "A"}, {"key": "1u648lz", "text": "Yes! one tens and four ones make fourteen.", "style": "A"}, {"key": "9qb1vj", "text": "Yes! nine tens and three ones make ninety-three.", "style": "A"}, {"key": "1m376vb", "text": "Yes! 6 tens — worth 60", "style": "A"}, {"key": "dp15g8", "text": "Yes! three tens and one ones make thirty-one.", "style": "A"}, {"key": "11byp1b", "text": "Yes! 2 tens and 8 ones make 28", "style": "A"}, {"key": "1xuxe02", "text": "Yes! five tens and nine ones make fifty-nine.", "style": "A"}, {"key": "1djtwgv", "text": "Yes! 2 tens and 4 ones make 24", "style": "A"}, {"key": "1xzc36n", "text": "Yes! 7 tens and 7 ones make 77", "style": "A"}, {"key": "ev0nl3", "text": "Yes! one tens and nine ones make nineteen.", "style": "A"}, {"key": "1ds1fhs", "text": "Yes! 8 ones", "style": "A"}, {"key": "yddv0z", "text": "Yes! 2 tens and 6 ones make 26", "style": "A"}, {"key": "1vsrkj7", "text": "Yes! 4 tens and 8 ones make 48", "style": "A"}, {"key": "1x5zi42", "text": "Yes! five tens and six ones make fifty-six.", "style": "A"}, {"key": "18mlv0n", "text": "Yes! 1 tens and 1 ones make 11", "style": "A"}, {"key": "1dkdzz9", "text": "Yes! 4 tens and 1 ones make 41", "style": "A"}, {"key": "1huciv3", "text": "Yes! 6 tens and 4 ones make 64", "style": "A"}, {"key": "wko2f6", "text": "Yes! three tens and eight ones make thirty-eight.", "style": "A"}, {"key": "1vecsxx", "text": "Yes! six tens and nine ones make sixty-nine.", "style": "A"}, {"key": "dm2xcp", "text": "Yes! two tens and one ones make twenty-one.", "style": "A"}, {"key": "1rlu7o9", "text": "Yes! nine tens and seven ones make ninety-seven.", "style": "A"}, {"key": "1mguyil", "text": "Yes! 1 tens and 8 ones make 18", "style": "A"}, {"key": "1a469qu", "text": "Yes! 2 ones", "style": "A"}, {"key": "1h3qz1w", "text": "Yes! four tens and nine ones make forty-nine.", "style": "A"}, {"key": "1dnco7g", "text": "Yes! four tens and three ones make forty-three.", "style": "A"}, {"key": "1jcjiup", "text": "Yes! seven tens and one ones make seventy-one.", "style": "A"}, {"key": "6c1tcv", "text": "Yes! nine tens and six ones make ninety-six.", "style": "A"}, {"key": "1qsvu6b", "text": "Yes! six tens and seven ones make sixty-seven.", "style": "A"}, {"key": "7g5869", "text": "Yes! 3 tens and 2 ones make 32", "style": "A"}, {"key": "gf1v1b", "text": "Yes! 7 ones", "style": "A"}, {"key": "mppraa", "text": "Yes! 6 ones", "style": "A"}, {"key": "10f3l7j", "text": "Yes! 3 tens and 3 ones make 33", "style": "A"}, {"key": "1r10fou", "text": "Yes! three tens and seven ones make thirty-seven.", "style": "A"}, {"key": "19hmg6z", "text": "Yes! eight tens and nine ones make eighty-nine.", "style": "A"}, {"key": "akznop", "text": "Yes! 1 tens and 6 ones make 16", "style": "A"}, {"key": "z0fqut", "text": "Yes! 4 tens and 5 ones make 45", "style": "A"}, {"key": "1v5rl33", "text": "Yes! 3 tens and 5 ones make 35", "style": "A"}, {"key": "9t72zf", "text": "Yes! eight tens and six ones make eighty-six.", "style": "A"}, {"key": "1dxxuzb", "text": "Yes! 5 tens and 1 ones make 51", "style": "A"}, {"key": "muv69p", "text": "Yes! 1 ones", "style": "A"}, {"key": "mxnoyx", "text": "Yes! seven tens and two ones make seventy-two.", "style": "A"}, {"key": "50abpg", "text": "Yes! three tens and six ones make thirty-six.", "style": "A"}, {"key": "1t1bjpv", "text": "Yes! eight tens and two ones make eighty-two.", "style": "A"}, {"key": "o26b39", "text": "Yes! 3 tens and 8 ones make 38", "style": "A"}, {"key": "1h6kh7f", "text": "Yes! 8 tens and 8 ones make 88", "style": "A"}, {"key": "1opk72e", "text": "Yes! five tens and four ones make fifty-four.", "style": "A"}, {"key": "1fx2dnb", "text": "Yes! 1 tens and 7 ones make 17", "style": "A"}, {"key": "9dkq5p", "text": "Yes! nine tens and eight ones make ninety-eight.", "style": "A"}, {"key": "yznsr7", "text": "Yes! eight tens and four ones make eighty-four.", "style": "A"}, {"key": "14iug07", "text": "Yes! 1 tens and 5 ones make 15", "style": "A"}, {"key": "14n5a7d", "text": "Yes! 5 tens and 2 ones make 52", "style": "A"}, {"key": "16lth4j", "text": "Yes! 6 tens and 2 ones make 62", "style": "A"}, {"key": "k93pk9", "text": "Yes! nine tens and five ones make ninety-five.", "style": "A"}, {"key": "163tzq9", "text": "Yes! seven tens and nine ones make seventy-nine.", "style": "A"}, {"key": "1a069o7", "text": "Yes! 9 tens and 9 ones make 99", "style": "A"}, {"key": "1lx90on", "text": "Yes! 3 tens and 7 ones make 37", "style": "A"}, {"key": "su336l", "text": "Yes! 8 tens and 1 ones make 81", "style": "A"}, {"key": "1tva1ct", "text": "Yes! seven tens and eight ones make seventy-eight.", "style": "A"}, {"key": "16ox20e", "text": "Yes! five tens and one ones make fifty-one.", "style": "A"}, {"key": "mvi6ln", "text": "Yes! eight tens and five ones make eighty-five.", "style": "A"}, {"key": "1rznq6p", "text": "Yes! 6 tens and 3 ones make 63", "style": "A"}, {"key": "1az9m7n", "text": "Yes! eight tens and three ones make eighty-three.", "style": "A"}, {"key": "g0vxi1", "text": "Yes! eight tens and seven ones make eighty-seven.", "style": "A"}, {"key": "e5ogat", "text": "Yes! 8 tens and 3 ones make 83", "style": "A"}, {"key": "1lc1689", "text": "Yes! 7 tens and 2 ones make 72", "style": "A"}, {"key": "12eiub9", "text": "Yes! seven tens and six ones make seventy-six.", "style": "A"}, {"key": "1ykpcdz", "text": "Yes! 5 tens and 9 ones make 59", "style": "A"}, {"key": "hg4zu7", "text": "Yes! 5 tens and 7 ones make 57", "style": "A"}, {"key": "174kerb", "text": "Yes! 3 tens and 1 ones make 31", "style": "A"}, {"key": "um7xqt", "text": "Yes! 4 tens and 3 ones make 43", "style": "A"}, {"key": "q3drnn", "text": "Yes! nine tens and one ones make ninety-one.", "style": "A"}, {"key": "1omnb9l", "text": "Yes! 6 tens and 9 ones make 69", "style": "A"}, {"key": "k8mzmd", "text": "Yes! 4 tens and 7 ones make 47", "style": "A"}, {"key": "ciw0xz", "text": "Yes! 5 tens and 5 ones make 55", "style": "A"}, {"key": "rk0ixj", "text": "Yes! 9 tens and 5 ones make 95", "style": "A"}, {"key": "zf1ikn", "text": "Yes! 7 tens and 9 ones make 79", "style": "A"}, {"key": "1k3ofgt", "text": "Yes! 5 tens and 8 ones make 58", "style": "A"}, {"key": "1vwm2gd", "text": "Yes! 8 tens and 5 ones make 85", "style": "A"}, {"key": "1fa0rd1", "text": "Yes! 8 tens and 7 ones make 87", "style": "A"}, {"key": "khy28v", "text": "Yes! 4 tens and 2 ones make 42", "style": "A"}, {"key": "1vsutux", "text": "Yes! 6 tens and 7 ones make 67", "style": "A"}, {"key": "h2ao2d", "text": "Yes! 7 tens and 8 ones make 78", "style": "A"}, {"key": "1s9vq9p", "text": "Yes! 8 tens and 9 ones make 89", "style": "A"}, {"key": "287wwd", "text": "Yes! 9 tens and 4 ones make 94", "style": "A"}, {"key": "vwmo9b", "text": "Yes! 8 tens and 6 ones make 86", "style": "A"}, {"key": "z4yiv1", "text": "Yes! 3 tens and 4 ones make 34", "style": "A"}, {"key": "jheeb9", "text": "Yes! seven tens and three ones make seventy-three.", "style": "A"}, {"key": "diehjf", "text": "two and five. Which sign is right?", "style": "A"}, {"key": "1ppfm5", "text": "thirty-nine and thirty-nine. Which sign is right?", "style": "A"}, {"key": "d0ep8r", "text": "ninety-four and twenty-three. Which sign is right?", "style": "A"}, {"key": "171ep30", "text": "two and eight. Which sign is right?", "style": "A"}, {"key": "15sc1r1", "text": "thirty-four and twelve. Which sign is right?", "style": "A"}, {"key": "14ibbm9", "text": "eighty-four and eighty-four. Which sign is right?", "style": "A"}, {"key": "1gwdomn", "text": "ten and seven. Which sign is right?", "style": "A"}, {"key": "qtee71", "text": "twenty and twenty. Which sign is right?", "style": "A"}, {"key": "lhoku6", "text": "eight and three. Which sign is right?", "style": "A"}, {"key": "xsknhg", "text": "twenty-eight and twenty-five. Which sign is right?", "style": "A"}, {"key": "1u49fcr", "text": "twenty-six and twenty-four. Which sign is right?", "style": "A"}, {"key": "1mfmndh", "text": "three and nine. Which sign is right?", "style": "A"}, {"key": "1qwisu1", "text": "eighteen and forty-two. Which sign is right?", "style": "A"}, {"key": "uecl6s", "text": "eighty-eight and fifty-three. Which sign is right?", "style": "A"}, {"key": "olmdu3", "text": "two and three. Which sign is right?", "style": "A"}, {"key": "1q6he42", "text": "thirty-eight and thirteen. Which sign is right?", "style": "A"}, {"key": "odhy4x", "text": "sixty-three and sixty-three. Which sign is right?", "style": "A"}, {"key": "1lpy5bj", "text": "five and nine. Which sign is right?", "style": "A"}, {"key": "kt1rq0", "text": "forty-four and twenty-five. Which sign is right?", "style": "A"}, {"key": "lrly7v", "text": "fifty-eight and sixty-nine. Which sign is right?", "style": "A"}, {"key": "h813yw", "text": "three and seven. Which sign is right?", "style": "A"}, {"key": "1obcb5u", "text": "twenty-seven and forty. Which sign is right?", "style": "A"}, {"key": "87jpo5", "text": "twenty-one and sixty-four. Which sign is right?", "style": "A"}, {"key": "xkz3b1", "text": "three and six. Which sign is right?", "style": "A"}, {"key": "1httm1b", "text": "eight and forty-five. Which sign is right?", "style": "A"}, {"key": "ib16it", "text": "eighty-four and forty-six. Which sign is right?", "style": "A"}, {"key": "gyswvy", "text": "seven and nine. Which sign is right?", "style": "A"}, {"key": "1trv7xz", "text": "twenty-two and two. Which sign is right?", "style": "A"}, {"key": "1cmizsp", "text": "seven and seven. Which sign is right?", "style": "A"}, {"key": "clcfb2", "text": "seven and five. Which sign is right?", "style": "A"}, {"key": "9kxldl", "text": "thirty-two and twenty-eight. Which sign is right?", "style": "A"}, {"key": "nz1nxf", "text": "ninety-one and ninety-one. Which sign is right?", "style": "A"}, {"key": "l39h0z", "text": "four and four. Which sign is right?", "style": "A"}, {"key": "8zzy2j", "text": "five and sixteen. Which sign is right?", "style": "A"}, {"key": "au5seb", "text": "eighty-five and twelve. Which sign is right?", "style": "A"}, {"key": "cidcrz", "text": "two and four. Which sign is right?", "style": "A"}, {"key": "5nzydt", "text": "forty-seven and forty-seven. Which sign is right?", "style": "A"}, {"key": "lfi68k", "text": "eighty-eight and eighty-six. Which sign is right?", "style": "A"}, {"key": "1th2x5i", "text": "three and thirty-two. Which sign is right?", "style": "A"}, {"key": "1tnnzkq", "text": "ninety-five and eighteen. Which sign is right?", "style": "A"}, {"key": "sc13zy", "text": "three and eight. Which sign is right?", "style": "A"}, {"key": "183qw54", "text": "eight and thirty-seven. Which sign is right?", "style": "A"}, {"key": "jj8mfh", "text": "sixteen and sixteen. Which sign is right?", "style": "A"}, {"key": "g3mzfw", "text": "ten and five. Which sign is right?", "style": "A"}, {"key": "ln7c3m", "text": "sixteen and thirty-nine. Which sign is right?", "style": "A"}, {"key": "s2le2l", "text": "thirty-five and thirty-five. Which sign is right?", "style": "A"}, {"key": "17197i3", "text": "five and one. Which sign is right?", "style": "A"}, {"key": "1idhq08", "text": "thirty-eight and eighty-four. Which sign is right?", "style": "A"}, {"key": "vk9yao", "text": "eight and nine. Which sign is right?", "style": "A"}, {"key": "7kxlgs", "text": "twenty-nine and seventeen. Which sign is right?", "style": "A"}, {"key": "1sb26sv", "text": "seventy-nine and forty-three. Which sign is right?", "style": "A"}, {"key": "jkkc68", "text": "six and seven. Which sign is right?", "style": "A"}, {"key": "1c7kfym", "text": "forty-one and nine. Which sign is right?", "style": "A"}, {"key": "1sjyezz", "text": "eighty and eighty. Which sign is right?", "style": "A"}, {"key": "19ys7fp", "text": "three and three. Which sign is right?", "style": "A"}, {"key": "oiqwdz", "text": "thirteen and thirty-one. Which sign is right?", "style": "A"}, {"key": "xpd2hx", "text": "thirty-three and thirty-three. Which sign is right?", "style": "A"}, {"key": "wzhxce", "text": "eight and one. Which sign is right?", "style": "A"}, {"key": "18iglx", "text": "six and six. Which sign is right?", "style": "A"}, {"key": "15ja8da", "text": "sixty and eighty. Which sign is right?", "style": "A"}, {"key": "1g15qjo", "text": "eight and four. Which sign is right?", "style": "A"}, {"key": "1apsu54", "text": "forty-six and one. Which sign is right?", "style": "A"}, {"key": "plixlb", "text": "thirty-five and eighty-nine. Which sign is right?", "style": "A"}, {"key": "12zdsh3", "text": "four and three. Which sign is right?", "style": "A"}, {"key": "hhto62", "text": "three and thirty-nine. Which sign is right?", "style": "A"}, {"key": "1ablvvn", "text": "ninety-three and ninety-three. Which sign is right?", "style": "A"}, {"key": "19vl6nd", "text": "one and five. Which sign is right?", "style": "A"}, {"key": "1pgnrwh", "text": "three and twenty-nine. Which sign is right?", "style": "A"}, {"key": "1g53ovo", "text": "eighty-seven and seventy-two. Which sign is right?", "style": "A"}, {"key": "ejck33", "text": "five and five. Which sign is right?", "style": "A"}, {"key": "p20tir", "text": "forty-eight and fourteen. Which sign is right?", "style": "A"}, {"key": "v994f5", "text": "thirty-six and eighty-two. Which sign is right?", "style": "A"}, {"key": "1i9p0qy", "text": "twenty-one and forty-one. Which sign is right?", "style": "A"}, {"key": "jr4wch", "text": "seventy-seven and seventy-seven. Which sign is right?", "style": "A"}, {"key": "q08e27", "text": "nine and nine. Which sign is right?", "style": "A"}, {"key": "2wsalz", "text": "forty-four and ten. Which sign is right?", "style": "A"}, {"key": "tdo9n2", "text": "eighty-three and fifty-seven. Which sign is right?", "style": "A"}, {"key": "15pgrq5", "text": "ten and ten. Which sign is right?", "style": "A"}, {"key": "1iqbmjf", "text": "forty-four and thirty-five. Which sign is right?", "style": "A"}, {"key": "1v64nti", "text": "sixty-six and fifty-two. Which sign is right?", "style": "A"}, {"key": "1o4z33i", "text": "forty-eight and forty-six. Which sign is right?", "style": "A"}, {"key": "v17irh", "text": "forty and eighty-eight. Which sign is right?", "style": "A"}, {"key": "z7u0w", "text": "fifty and forty-nine. Which sign is right?", "style": "A"}, {"key": "14bcf6o", "text": "forty-seven and twenty. Which sign is right?", "style": "A"}, {"key": "xiaq4f", "text": "four and five. Which sign is right?", "style": "A"}, {"key": "95fy0", "text": "thirty-five and two. Which sign is right?", "style": "A"}, {"key": "1kui5l9", "text": "two and two. Which sign is right?", "style": "A"}, {"key": "1jasgnp", "text": "six and nineteen. Which sign is right?", "style": "A"}, {"key": "5y0hfh", "text": "thirty-six and eighteen. Which sign is right?", "style": "A"}, {"key": "1rqpszz", "text": "two and one. Which sign is right?", "style": "A"}, {"key": "1xtkk45", "text": "forty-five and twenty-eight. Which sign is right?", "style": "A"}, {"key": "4uky5t", "text": "thirty-five and twelve. Which sign is right?", "style": "A"}, {"key": "v6auhv", "text": "two and thirty-seven. Which sign is right?", "style": "A"}, {"key": "mza3ir", "text": "forty-seven and seventy-seven. Which sign is right?", "style": "A"}, {"key": "12ilhd9", "text": "six and nine. Which sign is right?", "style": "A"}, {"key": "88mosr", "text": "four and twenty-one. Which sign is right?", "style": "A"}, {"key": "ff0b5d", "text": "ninety-five and ninety-five. Which sign is right?", "style": "A"}, {"key": "i5ubui", "text": "nine and thirty-three. Which sign is right?", "style": "A"}, {"key": "16afvoc", "text": "twenty-one and seventy-three. Which sign is right?", "style": "A"}, {"key": "3g36tp", "text": "thirty-five and thirty-three. Which sign is right?", "style": "A"}, {"key": "129hjjx", "text": "sixty-five and fourteen. Which sign is right?", "style": "A"}, {"key": "h561l1", "text": "three and five. Which sign is right?", "style": "A"}, {"key": "xy45a7", "text": "twenty-three and twenty-three. Which sign is right?", "style": "A"}, {"key": "13pb1ui", "text": "twenty-four and eighty-one. Which sign is right?", "style": "A"}, {"key": "36woez", "text": "forty-eight and twenty-six. Which sign is right?", "style": "A"}, {"key": "a3l7ep", "text": "forty-three and forty-three. Which sign is right?", "style": "A"}, {"key": "1fupw29", "text": "one and six. Which sign is right?", "style": "A"}, {"key": "psy3hd", "text": "forty-five and forty-three. Which sign is right?", "style": "A"}, {"key": "1wjwcg9", "text": "ninety-four and sixty-one. Which sign is right?", "style": "A"}, {"key": "jcmo9n", "text": "forty-one and twenty. Which sign is right?", "style": "A"}, {"key": "1agako5", "text": "sixty-four and one hundred. Which sign is right?", "style": "A"}, {"key": "1aygjgp", "text": "four and two. Which sign is right?", "style": "A"}, {"key": "kktu6e", "text": "forty-one and thirty. Which sign is right?", "style": "A"}, {"key": "bxapqb", "text": "sixty-one and nine. Which sign is right?", "style": "A"}, {"key": "13p9j25", "text": "twenty-nine and twenty-nine. Which sign is right?", "style": "A"}, {"key": "1sd86yh", "text": "seventy-three and twenty-seven. Which sign is right?", "style": "A"}, {"key": "x7xrjg", "text": "nine and ten. Which sign is right?", "style": "A"}, {"key": "vzqo2h", "text": "forty-one and forty-four. Which sign is right?", "style": "A"}, {"key": "29yzwu", "text": "two and forty-six. Which sign is right?", "style": "A"}, {"key": "ztnjj", "text": "nine and five. Which sign is right?", "style": "A"}, {"key": "1i3wj2p", "text": "fifty-four and twenty-seven. Which sign is right?", "style": "A"}, {"key": "1faqjvx", "text": "sixteen and nine. Which sign is right?", "style": "A"}, {"key": "1tmfwyh", "text": "eighty-eight and seventy-seven. Which sign is right?", "style": "A"}, {"key": "6bdb3n", "text": "two and six. Which sign is right?", "style": "A"}, {"key": "ejgyas", "text": "fifty and eight. Which sign is right?", "style": "A"}, {"key": "1vftmo6", "text": "sixty-five and seventy-six. Which sign is right?", "style": "A"}, {"key": "1jamad7", "text": "nine and one. Which sign is right?", "style": "A"}, {"key": "19oxlpd", "text": "thirty-four and thirty-nine. Which sign is right?", "style": "A"}, {"key": "1ujamjp", "text": "two and twenty-two. Which sign is right?", "style": "A"}, {"key": "13oy5pq", "text": "eighteen and one. Which sign is right?", "style": "A"}, {"key": "w7a0nl", "text": "sixty-three and sixty-six. Which sign is right?", "style": "A"}, {"key": "bfswr4", "text": "sixteen and seventeen. Which sign is right?", "style": "A"}, {"key": "pg3zv5", "text": "forty-one and forty-one. Which sign is right?", "style": "A"}, {"key": "1cx9xna", "text": "seventeen and nine. Which sign is right?", "style": "A"}, {"key": "1v5r4kt", "text": "thirty-six and thirty-six. Which sign is right?", "style": "A"}, {"key": "1myct6x", "text": "ten and eight. Which sign is right?", "style": "A"}, {"key": "1yg8cbw", "text": "twenty and thirty. Which sign is right?", "style": "A"}, {"key": "h084mc", "text": "ninety-six and seventy-nine. Which sign is right?", "style": "A"}, {"key": "4xwuwl", "text": "six and four. Which sign is right?", "style": "A"}, {"key": "1c767v6", "text": "ninety-seven and thirty. Which sign is right?", "style": "A"}, {"key": "16d07qa", "text": "twenty-one and twenty-seven. Which sign is right?", "style": "A"}, {"key": "qxsbt8", "text": "forty-six and seventy-eight. Which sign is right?", "style": "A"}, {"key": "o773gj", "text": "nine and four. Which sign is right?", "style": "A"}, {"key": "1o207u4", "text": "twenty-five and twenty. Which sign is right?", "style": "A"}, {"key": "1ogwp6m", "text": "eighty-seven and sixty. Which sign is right?", "style": "A"}, {"key": "14kx0t5", "text": "nine and twenty-two. Which sign is right?", "style": "A"}, {"key": "evfi3y", "text": "eighty-three and nineteen. Which sign is right?", "style": "A"}, {"key": "1eon5rv", "text": "twenty-three and four. Which sign is right?", "style": "A"}, {"key": "7e0zb0", "text": "ten and nine. Which sign is right?", "style": "A"}, {"key": "17ybp7g", "text": "twelve and nine. Which sign is right?", "style": "A"}, {"key": "1koschb", "text": "sixty-four and sixty-four. Which sign is right?", "style": "A"}, {"key": "17va7zi", "text": "fourteen and forty-one. Which sign is right?", "style": "A"}, {"key": "9war53", "text": "forty-two and thirty-two. Which sign is right?", "style": "A"}, {"key": "84yzky", "text": "thirty-eight and thirty-five. Which sign is right?", "style": "A"}, {"key": "nickat", "text": "eight and eight. Which sign is right?", "style": "A"}, {"key": "vesja3", "text": "twenty-six and four. Which sign is right?", "style": "A"}, {"key": "13h1hsd", "text": "fifty-seven and fifty-seven. Which sign is right?", "style": "A"}, {"key": "1ci436p", "text": "one and four. Which sign is right?", "style": "A"}, {"key": "gpa22m", "text": "twenty-seven and one. Which sign is right?", "style": "A"}, {"key": "10yuw2a", "text": "thirty-nine and forty-seven. Which sign is right?", "style": "A"}, {"key": "fhvojy", "text": "nineteen and forty-three. Which sign is right?", "style": "A"}, {"key": "1ipwvvy", "text": "seventeen and twenty-three. Which sign is right?", "style": "A"}, {"key": "jjww19", "text": "three and one. Which sign is right?", "style": "A"}, {"key": "gheuqt", "text": "sixty-four and eighty-eight. Which sign is right?", "style": "A"}, {"key": "16kquwc", "text": "five and ten. Which sign is right?", "style": "A"}, {"key": "h0pw5e", "text": "twenty-four and thirty-four. Which sign is right?", "style": "A"}, {"key": "1pzekpz", "text": "twenty-eight and eighty-two. Which sign is right?", "style": "A"}, {"key": "1pl67hy", "text": "fifty and twenty-seven. Which sign is right?", "style": "A"}, {"key": "fffaul", "text": "ninety-eight and seventy-three. Which sign is right?", "style": "A"}, {"key": "zzpxye", "text": "eight and six. Which sign is right?", "style": "A"}, {"key": "1butmyj", "text": "two and twenty-six. Which sign is right?", "style": "A"}, {"key": "n13hcq", "text": "eighty-six and thirty. Which sign is right?", "style": "A"}, {"key": "14qnosj", "text": "thirteen and eight. Which sign is right?", "style": "A"}, {"key": "1tnsevd", "text": "sixty-one and ninety-four. Which sign is right?", "style": "A"}, {"key": "1m3ivsu", "text": "two and twenty-seven. Which sign is right?", "style": "A"}, {"key": "cf5sfo", "text": "eighty-five and eighty-seven. Which sign is right?", "style": "A"}, {"key": "e8bes9", "text": "forty-nine and forty-nine. Which sign is right?", "style": "A"}, {"key": "1m0it40", "text": "seventy-three and ninety-five. Which sign is right?", "style": "A"}, {"key": "1wyrh1w", "text": "eleven and thirty. Which sign is right?", "style": "A"}, {"key": "17dci3d", "text": "eighteen and ten. Which sign is right?", "style": "A"}, {"key": "qhfiel", "text": "six and three. Which sign is right?", "style": "A"}, {"key": "nmxkpq", "text": "forty-two and twenty-two. Which sign is right?", "style": "A"}, {"key": "1g3hh2p", "text": "eighty-six and eighty-six. Which sign is right?", "style": "A"}, {"key": "56b7aq", "text": "thirty-four and three. Which sign is right?", "style": "A"}, {"key": "1f4qyqz", "text": "eighty-four and fifty-six. Which sign is right?", "style": "A"}, {"key": "emlst2", "text": "thirty-four and fifty-eight. Which sign is right?", "style": "A"}, {"key": "4zpozd", "text": "forty-five and forty-five. Which sign is right?", "style": "A"}, {"key": "zne0hl", "text": "twenty-seven and twenty-seven. Which sign is right?", "style": "A"}, {"key": "1te8f84", "text": "six and eighteen. Which sign is right?", "style": "A"}, {"key": "1i7kzk1", "text": "seventy-one and thirty-three. Which sign is right?", "style": "A"}, {"key": "m7mce1", "text": "nine and two. Which sign is right?", "style": "A"}, {"key": "11bizcn", "text": "nine and twenty-three. Which sign is right?", "style": "A"}, {"key": "16g0xo7", "text": "sixty-seven and ninety-seven. Which sign is right?", "style": "A"}, {"key": "1ay834x", "text": "forty-four and thirteen. Which sign is right?", "style": "A"}, {"key": "9g8hzo", "text": "nineteen and eight. Which sign is right?", "style": "A"}, {"key": "e8fk16", "text": "three and thirty-four. Which sign is right?", "style": "A"}, {"key": "1wvlq1j", "text": "thirteen and thirty-four. Which sign is right?", "style": "A"}, {"key": "11u9g85", "text": "six and one. Which sign is right?", "style": "A"}, {"key": "l3zao8", "text": "twenty-seven and thirty-seven. Which sign is right?", "style": "A"}, {"key": "96g30u", "text": "forty-four and ninety-two. Which sign is right?", "style": "A"}, {"key": "1r41rd", "text": "twenty-nine and sixteen. Which sign is right?", "style": "A"}, {"key": "1azfw2h", "text": "fifty-one and fifty-one. Which sign is right?", "style": "A"}, {"key": "1dg3i2r", "text": "fourteen and forty-seven. Which sign is right?", "style": "A"}, {"key": "1cj5drq", "text": "thirteen and four. Which sign is right?", "style": "A"}, {"key": "twunx9", "text": "six and five. Which sign is right?", "style": "A"}, {"key": "uh7g73", "text": "twenty-six and twenty-six. Which sign is right?", "style": "A"}, {"key": "1ieh2kt", "text": "sixty-four and twenty-one. Which sign is right?", "style": "A"}, {"key": "18w6e5k", "text": "thirty-four and twenty-six. Which sign is right?", "style": "A"}, {"key": "17isylf", "text": "eighty-three and sixty. Which sign is right?", "style": "A"}, {"key": "xk16fr", "text": "seventy-six and eighty-five. Which sign is right?", "style": "A"}, {"key": "a0u97o", "text": "ten and two. Which sign is right?", "style": "A"}, {"key": "spo9gn", "text": "nineteen and nineteen. Which sign is right?", "style": "A"}, {"key": "13w14zp", "text": "thirteen and thirty-two. Which sign is right?", "style": "A"}, {"key": "izkiwr", "text": "forty-one and eleven. Which sign is right?", "style": "A"}, {"key": "128njkx", "text": "sixty-two and twenty-four. Which sign is right?", "style": "A"}, {"key": "st2bhg", "text": "twelve and twenty-one. Which sign is right?", "style": "A"}, {"key": "ccbgxk", "text": "ninety-seven and thirty-eight. Which sign is right?", "style": "A"}, {"key": "16k1mc5", "text": "twenty-nine and thirty. Which sign is right?", "style": "A"}, {"key": "s0g0gn", "text": "nine and three. Which sign is right?", "style": "A"}, {"key": "1wef7pq", "text": "seventy and eighteen. Which sign is right?", "style": "A"}, {"key": "vsn1av", "text": "six and ninety-three. Which sign is right?", "style": "A"}, {"key": "gfgjj", "text": "forty-nine and fifty-five. Which sign is right?", "style": "A"}, {"key": "9gb7he", "text": "three and ten. Which sign is right?", "style": "A"}, {"key": "13l7zve", "text": "thirteen and forty-eight. Which sign is right?", "style": "A"}, {"key": "1d7fm7y", "text": "fifty-eight and eighty-three. Which sign is right?", "style": "A"}, {"key": "aha65s", "text": "two and ten. Which sign is right?", "style": "A"}, {"key": "14ieyys", "text": "ninety and forty-seven. Which sign is right?", "style": "A"}, {"key": "coqxop", "text": "thirty-three and twenty-seven. Which sign is right?", "style": "A"}, {"key": "1yr5zr", "text": "fifty-three and eighty-four. Which sign is right?", "style": "A"}, {"key": "nbagn4", "text": "eight and five. Which sign is right?", "style": "A"}, {"key": "1k7qovu", "text": "three and thirty-five. Which sign is right?", "style": "A"}, {"key": "grgyhw", "text": "sixteen and fifteen. Which sign is right?", "style": "A"}, {"key": "1y9wy6x", "text": "six and twenty-nine. Which sign is right?", "style": "A"}, {"key": "1uoh2fm", "text": "ten and six. Which sign is right?", "style": "A"}, {"key": "hmpkpu", "text": "one and thirty-two. Which sign is right?", "style": "A"}, {"key": "1r9k2ls", "text": "forty-two and twenty-three. Which sign is right?", "style": "A"}, {"key": "18w28nj", "text": "thirty and thirty. Which sign is right?", "style": "A"}, {"key": "1mlgp8j", "text": "fifty-four and thirteen. Which sign is right?", "style": "A"}, {"key": "2tn0lq", "text": "nineteen and thirty-six. Which sign is right?", "style": "A"}, {"key": "1lz0dx4", "text": "fifteen and six. Which sign is right?", "style": "A"}, {"key": "14ps6ex", "text": "five and two. Which sign is right?", "style": "A"}, {"key": "ffniyb", "text": "forty-five and eleven. Which sign is right?", "style": "A"}, {"key": "1de7y", "text": "twenty-eight and sixty-six. Which sign is right?", "style": "A"}, {"key": "1pbqdql", "text": "twelve and twelve. Which sign is right?", "style": "A"}, {"key": "1o7az6h", "text": "fifty-nine and sixty-seven. Which sign is right?", "style": "A"}, {"key": "105sjhw", "text": "forty-seven and eighteen. Which sign is right?", "style": "A"}, {"key": "146na0z", "text": "five and four. Which sign is right?", "style": "A"}, {"key": "yl5b9d", "text": "thirty-four and thirty-one. Which sign is right?", "style": "A"}, {"key": "1pyku1e", "text": "thirty-two and twenty-three. Which sign is right?", "style": "A"}, {"key": "1eveckf", "text": "sixteen and twenty-two. Which sign is right?", "style": "A"}, {"key": "vqg531", "text": "twenty-five and twenty-five. Which sign is right?", "style": "A"}, {"key": "w5s8bx", "text": "eighteen and eighteen. Which sign is right?", "style": "A"}, {"key": "kzwtbv", "text": "two and forty. Which sign is right?", "style": "A"}, {"key": "1txx0hx", "text": "twenty-eight and thirteen. Which sign is right?", "style": "A"}, {"key": "v1l88g", "text": "twenty-six and twenty-eight. Which sign is right?", "style": "A"}, {"key": "1lbalo1", "text": "nineteen and ninety-one. Which sign is right?", "style": "A"}, {"key": "a2icxb", "text": "thirty-seven and thirty-seven. Which sign is right?", "style": "A"}, {"key": "1fkx2r6", "text": "five and forty-one. Which sign is right?", "style": "A"}, {"key": "m01u9h", "text": "one hundred and six. Which sign is right?", "style": "A"}, {"key": "fqvupa", "text": "thirty-one and sixteen. Which sign is right?", "style": "A"}, {"key": "1pnvxh9", "text": "ninety-six and twenty-one. Which sign is right?", "style": "A"}, {"key": "vl3odf", "text": "twenty-eight and ten. Which sign is right?", "style": "A"}, {"key": "17yyncc", "text": "fifty-six and sixty-six. Which sign is right?", "style": "A"}, {"key": "rn935o", "text": "nine and forty-five. Which sign is right?", "style": "A"}, {"key": "1j3i2lb", "text": "twenty-seven and forty-five. Which sign is right?", "style": "A"}, {"key": "q0jg6c", "text": "forty and eleven. Which sign is right?", "style": "A"}, {"key": "sjoul6", "text": "eighty-eight and twelve. Which sign is right?", "style": "A"}, {"key": "15cksao", "text": "ten and four. Which sign is right?", "style": "A"}, {"key": "1iozmfw", "text": "thirty and forty-five. Which sign is right?", "style": "A"}, {"key": "qi22yt", "text": "ninety-six and twenty-nine. Which sign is right?", "style": "A"}, {"key": "i0xxm1", "text": "twelve and eight. Which sign is right?", "style": "A"}, {"key": "11pkd5p", "text": "twenty-four and three. Which sign is right?", "style": "A"}, {"key": "14xqx5q", "text": "ninety-nine and forty-three. Which sign is right?", "style": "A"}, {"key": "qnuuh4", "text": "twenty and nineteen. Which sign is right?", "style": "A"}, {"key": "8f18b5", "text": "fifty and fifty. Which sign is right?", "style": "A"}, {"key": "oywug0", "text": "eighty-four and thirty-eight. Which sign is right?", "style": "A"}, {"key": "rkpe6x", "text": "one and one. Which sign is right?", "style": "A"}, {"key": "184jh8m", "text": "twenty-six and seventeen. Which sign is right?", "style": "A"}, {"key": "dz5osl", "text": "eighty-eight and eighty. Which sign is right?", "style": "A"}, {"key": "hsl9ih", "text": "forty-four and forty-four. Which sign is right?", "style": "A"}, {"key": "mpjw9i", "text": "fifteen and fifty-seven. Which sign is right?", "style": "A"}, {"key": "bh3b87", "text": "eighteen and forty-three. Which sign is right?", "style": "A"}, {"key": "1j2b4ja", "text": "ninety-eight and sixty-nine. Which sign is right?", "style": "A"}, {"key": "1gdgru2", "text": "forty-one and sixty-three. Which sign is right?", "style": "A"}, {"key": "q23hei", "text": "thirty-six and sixteen. Which sign is right?", "style": "A"}, {"key": "vmufor", "text": "twenty-nine and ninety-nine. Which sign is right?", "style": "A"}, {"key": "7tljq2", "text": "six and twenty-eight. Which sign is right?", "style": "A"}, {"key": "4oy8tt", "text": "fifty-seven and sixty-three. Which sign is right?", "style": "A"}, {"key": "yb9izr", "text": "twenty-six and nine. Which sign is right?", "style": "A"}, {"key": "18j1nfn", "text": "twenty-two and twenty-two. Which sign is right?", "style": "A"}, {"key": "10yta4t", "text": "six and sixteen. Which sign is right?", "style": "A"}, {"key": "16cgn8r", "text": "fourteen and fourteen. Which sign is right?", "style": "A"}, {"key": "103yxu6", "text": "seven and four. Which sign is right?", "style": "A"}, {"key": "17zz0rc", "text": "forty-eight and forty-two. Which sign is right?", "style": "A"}, {"key": "ywdruv", "text": "seventy-six and fifty-two. Which sign is right?", "style": "A"}, {"key": "2fzdq5", "text": "eighteen and thirty-six. Which sign is right?", "style": "A"}, {"key": "119imz2", "text": "nine and seventeen. Which sign is right?", "style": "A"}, {"key": "1jexlyx", "text": "eighty-seven and thirty-seven. Which sign is right?", "style": "A"}, {"key": "s7bdsy", "text": "eleven and twenty-two. Which sign is right?", "style": "A"}, {"key": "g31uxl", "text": "thirty-one and thirty-one. Which sign is right?", "style": "A"}, {"key": "t8vuxh", "text": "fifty-five and fifty-five. Which sign is right?", "style": "A"}, {"key": "102b7va", "text": "eighty-two and ninety-six. Which sign is right?", "style": "A"}, {"key": "1qkvl9l", "text": "thirty-four and thirty-four. Which sign is right?", "style": "A"}, {"key": "16ey369", "text": "seventy-five and forty-two. Which sign is right?", "style": "A"}, {"key": "j9dzu1", "text": "thirteen and thirteen. Which sign is right?", "style": "A"}, {"key": "1ttrl6p", "text": "twenty-four and forty-seven. Which sign is right?", "style": "A"}, {"key": "39jn1d", "text": "fifteen and fifteen. Which sign is right?", "style": "A"}, {"key": "suzkwz", "text": "twenty-six and sixteen. Which sign is right?", "style": "A"}, {"key": "1xzkkm9", "text": "six and fifty-eight. Which sign is right?", "style": "A"}, {"key": "1jcumqy", "text": "five and seven. Which sign is right?", "style": "A"}, {"key": "n17z3d", "text": "twenty-five and fourteen. Which sign is right?", "style": "A"}, {"key": "iqjcqj", "text": "ten and forty-nine. Which sign is right?", "style": "A"}, {"key": "e15i99", "text": "seventy and sixty-one. Which sign is right?", "style": "A"}, {"key": "tyjt0r", "text": "fourteen and twenty-nine. Which sign is right?", "style": "A"}, {"key": "97pnbp", "text": "thirty and sixty-three. Which sign is right?", "style": "A"}, {"key": "1h78lnr", "text": "five and six. Which sign is right?", "style": "A"}, {"key": "15akma3", "text": "forty-three and thirty-six. Which sign is right?", "style": "A"}, {"key": "r7oox4", "text": "seventy-five and eighty-eight. Which sign is right?", "style": "A"}, {"key": "q2pneo", "text": "eighty-four and sixty-nine. Which sign is right?", "style": "A"}, {"key": "q2cvwz", "text": "twenty and thirteen. Which sign is right?", "style": "A"}, {"key": "jmgmpy", "text": "forty-eight and fifty-two. Which sign is right?", "style": "A"}, {"key": "asjyct", "text": "forty-eight and forty-eight. Which sign is right?", "style": "A"}, {"key": "c5yeah", "text": "seventy-five and seventy-five. Which sign is right?", "style": "A"}, {"key": "1hqo42c", "text": "twenty-six and forty-nine. Which sign is right?", "style": "A"}, {"key": "1927k2w", "text": "four and twenty-eight. Which sign is right?", "style": "A"}, {"key": "1nccm47", "text": "twenty-one and nine. Which sign is right?", "style": "A"}, {"key": "1y44p4y", "text": "ten and three. Which sign is right?", "style": "A"}, {"key": "w59yn4", "text": "fourteen and forty-five. Which sign is right?", "style": "A"}, {"key": "xzibho", "text": "fifty-five and thirty-seven. Which sign is right?", "style": "A"}, {"key": "1773owz", "text": "eight and seven. Which sign is right?", "style": "A"}, {"key": "m59zaj", "text": "forty and twenty-two. Which sign is right?", "style": "A"}, {"key": "1oql3ny", "text": "seventy-nine and ninety-six. Which sign is right?", "style": "A"}, {"key": "1hbw9f1", "text": "twenty-eight and forty-four. Which sign is right?", "style": "A"}, {"key": "wqhsdi", "text": "seventy-five and twenty-nine. Which sign is right?", "style": "A"}, {"key": "1o6n0qc", "text": "thirty and seventy-six. Which sign is right?", "style": "A"}, {"key": "1jekx54", "text": "sixty-six and forty-two. Which sign is right?", "style": "A"}, {"key": "es2m8k", "text": "nineteen and forty-four. Which sign is right?", "style": "A"}, {"key": "ey0qin", "text": "thirty-nine and seventy-two. Which sign is right?", "style": "A"}, {"key": "1nhumt4", "text": "twelve and twenty-six. Which sign is right?", "style": "A"}, {"key": "1k08epg", "text": "thirty-one and fifty. Which sign is right?", "style": "A"}, {"key": "sh96y7", "text": "thirteen and ten. Which sign is right?", "style": "A"}, {"key": "1g8fnif", "text": "thirty-eight and thirty-eight. Which sign is right?", "style": "A"}, {"key": "1p7q2qv", "text": "nine and six. Which sign is right?", "style": "A"}, {"key": "10uz0q2", "text": "twenty-three and forty-six. Which sign is right?", "style": "A"}, {"key": "14jxv3m", "text": "ninety-seven and nine. Which sign is right?", "style": "A"}, {"key": "1h2evwh", "text": "forty and four. Which sign is right?", "style": "A"}, {"key": "8hdryx", "text": "forty-six and forty-six. Which sign is right?", "style": "A"}, {"key": "1roe1yk", "text": "seventeen and ninety-one. Which sign is right?", "style": "A"}, {"key": "1idp7d8", "text": "thirty-four and forty-eight. Which sign is right?", "style": "A"}, {"key": "mwwyhb", "text": "ninety-three and forty-eight. Which sign is right?", "style": "A"}, {"key": "1hiu6ka", "text": "four and seven. Which sign is right?", "style": "A"}, {"key": "17jyf84", "text": "seven and sixteen. Which sign is right?", "style": "A"}, {"key": "5zewz1", "text": "sixty-three and seventy-seven. Which sign is right?", "style": "A"}, {"key": "1mxwqy3", "text": "eighteen and twenty-eight. Which sign is right?", "style": "A"}, {"key": "e14mic", "text": "thirty and seventy-three. Which sign is right?", "style": "A"}, {"key": "1nlmmhh", "text": "fifty-nine and fifty-nine. Which sign is right?", "style": "A"}, {"key": "1qkzip", "text": "one and three. Which sign is right?", "style": "A"}, {"key": "iawcr7", "text": "nineteen and twenty-six. Which sign is right?", "style": "A"}, {"key": "fysg0n", "text": "eight and seventeen. Which sign is right?", "style": "A"}, {"key": "9eg63f", "text": "two and nine. Which sign is right?", "style": "A"}, {"key": "15cf2dh", "text": "twenty-eight and forty-nine. Which sign is right?", "style": "A"}, {"key": "167mgay", "text": "fifty-eight and seventy-six. Which sign is right?", "style": "A"}, {"key": "1hoa0oy", "text": "forty and forty-five. Which sign is right?", "style": "A"}, {"key": "1p4qn2f", "text": "thirty-six and eighty-nine. Which sign is right?", "style": "A"}, {"key": "4s7ge7", "text": "fifty-five and thirteen. Which sign is right?", "style": "A"}, {"key": "1cjrptq", "text": "one and ten. Which sign is right?", "style": "A"}, {"key": "1vb7wxs", "text": "thirty-two and forty-seven. Which sign is right?", "style": "A"}, {"key": "18f94iy", "text": "thirty-three and forty-seven. Which sign is right?", "style": "A"}, {"key": "4h59ax", "text": "seventeen and seventeen. Which sign is right?", "style": "A"}, {"key": "qwh8dd", "text": "eighty and twenty-four. Which sign is right?", "style": "A"}, {"key": "t2dftr", "text": "four and nine. Which sign is right?", "style": "A"}, {"key": "1ngflu9", "text": "twenty-four and twenty-four. Which sign is right?", "style": "A"}, {"key": "r86iof", "text": "ninety-three and sixty-four. Which sign is right?", "style": "A"}, {"key": "p2hz0a", "text": "thirty-eight and forty-two. Which sign is right?", "style": "A"}, {"key": "1mzx7s5", "text": "forty-six and eighty-nine. Which sign is right?", "style": "A"}, {"key": "hixazd", "text": "thirty-one and eleven. Which sign is right?", "style": "A"}, {"key": "1f5eppt", "text": "forty-six and forty-five. Which sign is right?", "style": "A"}, {"key": "12ijhxz", "text": "fifty-five and forty-four. Which sign is right?", "style": "A"}, {"key": "803jyq", "text": "eighteen and fifty-eight. Which sign is right?", "style": "A"}, {"key": "l1mlf8", "text": "thirty-two and twenty-two. Which sign is right?", "style": "A"}, {"key": "fkzhf3", "text": "twenty-two and seventy. Which sign is right?", "style": "A"}, {"key": "kjxvfz", "text": "ninety-seven and thirty-five. Which sign is right?", "style": "A"}, {"key": "9f8y24", "text": "twenty-six and thirteen. Which sign is right?", "style": "A"}, {"key": "vohnya", "text": "seven and two. Which sign is right?", "style": "A"}, {"key": "1u2usup", "text": "sixty-two and sixty-two. Which sign is right?", "style": "A"}, {"key": "1ofhaot", "text": "forty-six and fifteen. Which sign is right?", "style": "A"}, {"key": "1cuhbzu", "text": "twenty and one hundred. Which sign is right?", "style": "A"}, {"key": "zo8pv8", "text": "thirty-six and four. Which sign is right?", "style": "A"}, {"key": "d28pnh", "text": "fifty-eight and fifty-eight. Which sign is right?", "style": "A"}, {"key": "13t2wuz", "text": "thirty-nine and thirty-two. Which sign is right?", "style": "A"}, {"key": "1j9y25s", "text": "ninety-four and forty-nine. Which sign is right?", "style": "A"}, {"key": "gr0jvm", "text": "thirty-five and sixteen. Which sign is right?", "style": "A"}, {"key": "16fvchh", "text": "eleven and eight. Which sign is right?", "style": "A"}, {"key": "ogvpu0", "text": "seventy-eight and fifty-four. Which sign is right?", "style": "A"}, {"key": "xv1aot", "text": "twenty-seven and eleven. Which sign is right?", "style": "A"}, {"key": "11szlrx", "text": "fifty-six and seventy-three. Which sign is right?", "style": "A"}, {"key": "1r4kvj9", "text": "sixty and eighty-two. Which sign is right?", "style": "A"}, {"key": "1p86uw", "text": "thirty-nine and two. Which sign is right?", "style": "A"}, {"key": "1gr9cmf", "text": "ninety-six and ninety-one. Which sign is right?", "style": "A"}, {"key": "1ofm61m", "text": "one and eight. Which sign is right?", "style": "A"}, {"key": "1u03yv9", "text": "twenty-four and nineteen. Which sign is right?", "style": "A"}, {"key": "ypzp1k", "text": "fifty-nine and fourteen. Which sign is right?", "style": "A"}, {"key": "14g1xco", "text": "seven and one. Which sign is right?", "style": "A"}, {"key": "7es78o", "text": "forty-one and twenty-five. Which sign is right?", "style": "A"}, {"key": "196vy0j", "text": "fifteen and twelve. Which sign is right?", "style": "A"}, {"key": "1m4b93t", "text": "three and forty-seven. Which sign is right?", "style": "A"}, {"key": "p91rud", "text": "seventy and seventy. Which sign is right?", "style": "A"}, {"key": "1auyc2i", "text": "sixty-five and fifty-six. Which sign is right?", "style": "A"}, {"key": "1lf4859", "text": "ninety-seven and seven. Which sign is right?", "style": "A"}, {"key": "1srr8pi", "text": "eighty-one and fourteen. Which sign is right?", "style": "A"}, {"key": "qw1huy", "text": "four and thirty-three. Which sign is right?", "style": "A"}, {"key": "5kwlc1", "text": "twenty-eight and twenty-eight. Which sign is right?", "style": "A"}, {"key": "1v6cdf5", "text": "thirty-five and seventy-six. Which sign is right?", "style": "A"}, {"key": "s0efiz", "text": "thirty-nine and seven. Which sign is right?", "style": "A"}, {"key": "wrq2yc", "text": "twenty-eight and twenty-nine. Which sign is right?", "style": "A"}, {"key": "6y58yf", "text": "five and three. Which sign is right?", "style": "A"}, {"key": "e3c0af", "text": "fifty-two and forty-two. Which sign is right?", "style": "A"}, {"key": "m027cz", "text": "twenty-eight and forty-two. Which sign is right?", "style": "A"}, {"key": "evsfvo", "text": "thirty-nine and sixty-one. Which sign is right?", "style": "A"}, {"key": "11x6dro", "text": "ten and thirty-seven. Which sign is right?", "style": "A"}, {"key": "8oarwv", "text": "eighty-six and seventy-three. Which sign is right?", "style": "A"}, {"key": "1v8zsnw", "text": "seventeen and sixteen. Which sign is right?", "style": "A"}, {"key": "1oy6uzc", "text": "forty and eighty-five. Which sign is right?", "style": "A"}, {"key": "1fbdeen", "text": "seventy-two and thirty-six. Which sign is right?", "style": "A"}, {"key": "1fgs6td", "text": "twenty-three and twenty-two. Which sign is right?", "style": "A"}, {"key": "15i7hlz", "text": "eighty and ninety-six. Which sign is right?", "style": "A"}, {"key": "x64mvf", "text": "eighteen and thirteen. Which sign is right?", "style": "A"}, {"key": "1qqicqr", "text": "sixty-seven and forty-three. Which sign is right?", "style": "A"}, {"key": "1dbfpq3", "text": "nine and sixteen. Which sign is right?", "style": "A"}, {"key": "a8nbci", "text": "forty-six and nineteen. Which sign is right?", "style": "A"}, {"key": "13ybmha", "text": "one and forty-two. Which sign is right?", "style": "A"}, {"key": "19e36zw", "text": "sixteen and fifty-two. Which sign is right?", "style": "A"}, {"key": "igdtls", "text": "eighteen and five. Which sign is right?", "style": "A"}, {"key": "1f8grs5", "text": "thirty-four and fifty-one. Which sign is right?", "style": "A"}, {"key": "dnloog", "text": "eighty and seventy-two. Which sign is right?", "style": "A"}, {"key": "q8ufnj", "text": "twenty-seven and forty-nine. Which sign is right?", "style": "A"}, {"key": "kuvdab", "text": "thirty-three and forty-four. Which sign is right?", "style": "A"}, {"key": "124or0m", "text": "two and seven. Which sign is right?", "style": "A"}, {"key": "131le75", "text": "eighty-five and eighty-five. Which sign is right?", "style": "A"}, {"key": "8873kl", "text": "twenty-nine and twenty-one. Which sign is right?", "style": "A"}, {"key": "7y3nyd", "text": "ninety-four and eighty-seven. Which sign is right?", "style": "A"}, {"key": "xfem65", "text": "three and four. Which sign is right?", "style": "A"}, {"key": "1b1hizf", "text": "twelve and forty-nine. Which sign is right?", "style": "A"}, {"key": "1f36pu4", "text": "thirty-nine and twenty-three. Which sign is right?", "style": "A"}, {"key": "jxh9vn", "text": "thirteen and thirty-nine. Which sign is right?", "style": "A"}, {"key": "1px34xy", "text": "seventy-seven and fifty-four. Which sign is right?", "style": "A"}, {"key": "1anwacp", "text": "forty-two and eight. Which sign is right?", "style": "A"}, {"key": "1rsiqpf", "text": "forty-five and thirty-nine. Which sign is right?", "style": "A"}, {"key": "5iclxi", "text": "twenty-seven and ninety-six. Which sign is right?", "style": "A"}, {"key": "pzpfh6", "text": "twenty-one and seventy-two. Which sign is right?", "style": "A"}, {"key": "1ipzski", "text": "ten and one. Which sign is right?", "style": "A"}, {"key": "106cr0z", "text": "one and fifty. Which sign is right?", "style": "A"}, {"key": "rxgavk", "text": "ten and twenty-three. Which sign is right?", "style": "A"}, {"key": "mo95mz", "text": "ninety-six and ninety-six. Which sign is right?", "style": "A"}, {"key": "sugk2o", "text": "eight and two. Which sign is right?", "style": "A"}, {"key": "hezid", "text": "eighteen and thirty-five. Which sign is right?", "style": "A"}, {"key": "1sj8n74", "text": "eighteen and nineteen. Which sign is right?", "style": "A"}, {"key": "17y01q4", "text": "thirty-seven and thirty-nine. Which sign is right?", "style": "A"}, {"key": "1gvc9wo", "text": "forty and eighteen. Which sign is right?", "style": "A"}, {"key": "r1d0b2", "text": "thirty and eighty-four. Which sign is right?", "style": "A"}, {"key": "18yvjf8", "text": "eight and twenty-six. Which sign is right?", "style": "A"}, {"key": "tea0ca", "text": "thirty-nine and seventy-eight. Which sign is right?", "style": "A"}, {"key": "1x73vny", "text": "forty-four and four. Which sign is right?", "style": "A"}, {"key": "kso569", "text": "seventy-seven and eighty-seven. Which sign is right?", "style": "A"}, {"key": "i54pr3", "text": "twenty-six and twenty-three. Which sign is right?", "style": "A"}, {"key": "1ywk0m4", "text": "seventy-eight and twenty-seven. Which sign is right?", "style": "A"}, {"key": "185231l", "text": "forty-eight and fifty. Which sign is right?", "style": "A"}, {"key": "l7hwse", "text": "eighteen and thirty-eight. Which sign is right?", "style": "A"}, {"key": "1qharnw", "text": "one and seven. Which sign is right?", "style": "A"}, {"key": "f45af9", "text": "thirty-one and twenty-seven. Which sign is right?", "style": "A"}, {"key": "xbsolo", "text": "twenty and twenty-three. Which sign is right?", "style": "A"}, {"key": "1au29ks", "text": "twelve and forty-eight. Which sign is right?", "style": "A"}, {"key": "w1d4r9", "text": "fifty-six and fifty-six. Which sign is right?", "style": "A"}, {"key": "ogqq48", "text": "eleven and twenty-one. Which sign is right?", "style": "A"}, {"key": "t5xn8e", "text": "forty-three and twenty-one. Which sign is right?", "style": "A"}, {"key": "396cje", "text": "sixty-three and eighty-five. Which sign is right?", "style": "A"}, {"key": "1hnmxui", "text": "thirty-six and forty-seven. Which sign is right?", "style": "A"}, {"key": "p29few", "text": "sixty-one and seventy-six. Which sign is right?", "style": "A"}, {"key": "1oootwn", "text": "nine and forty. Which sign is right?", "style": "A"}, {"key": "1frslxg", "text": "sixty-one and eight. Which sign is right?", "style": "A"}, {"key": "221div", "text": "four and six. Which sign is right?", "style": "A"}, {"key": "162jt13", "text": "eighty-two and eighty-nine. Which sign is right?", "style": "A"}, {"key": "hks6lf", "text": "thirty-one and forty-three. Which sign is right?", "style": "A"}, {"key": "1mwiyql", "text": "thirty-six and thirty-one. Which sign is right?", "style": "A"}, {"key": "15tepzh", "text": "twenty-eight and forty-six. Which sign is right?", "style": "A"}, {"key": "yozxti", "text": "fourteen and twenty-seven. Which sign is right?", "style": "A"}, {"key": "8t8xis", "text": "ninety-six and seventeen. Which sign is right?", "style": "A"}, {"key": "16q5rs2", "text": "seven and forty-eight. Which sign is right?", "style": "A"}, {"key": "1bv87u9", "text": "thirty-nine and twelve. Which sign is right?", "style": "A"}, {"key": "14obd1k", "text": "fifty and thirty-two. Which sign is right?", "style": "A"}, {"key": "1qel265", "text": "eleven and eleven. Which sign is right?", "style": "A"}, {"key": "1isgyt8", "text": "eighty-eight and ninety. Which sign is right?", "style": "A"}, {"key": "qvqyo3", "text": "forty-six and thirty-six. Which sign is right?", "style": "A"}, {"key": "1e27o9o", "text": "four and ten. Which sign is right?", "style": "A"}, {"key": "9hjixe", "text": "thirty-five and forty-seven. Which sign is right?", "style": "A"}, {"key": "olnyti", "text": "ninety-four and twelve. Which sign is right?", "style": "A"}, {"key": "k11jip", "text": "thirty-eight and thirty. Which sign is right?", "style": "A"}, {"key": "1yqmpjo", "text": "six and eighty-five. Which sign is right?", "style": "A"}, {"key": "1ude1vp", "text": "nine and fifty. Which sign is right?", "style": "A"}, {"key": "17jdhtr", "text": "four and one hundred. Which sign is right?", "style": "A"}, {"key": "16skml2", "text": "twenty-six and eighteen. Which sign is right?", "style": "A"}, {"key": "6jn538", "text": "eighteen and four. Which sign is right?", "style": "A"}, {"key": "1q1rieb", "text": "twenty-one and twenty-one. Which sign is right?", "style": "A"}, {"key": "1fzzurb", "text": "seven and ten. Which sign is right?", "style": "A"}, {"key": "1qdoht3", "text": "eleven and forty-three. Which sign is right?", "style": "A"}, {"key": "epvxeg", "text": "five and twenty-eight. Which sign is right?", "style": "A"}, {"key": "1fscd2c", "text": "nineteen and seventy-one. Which sign is right?", "style": "A"}, {"key": "1ozvg2v", "text": "thirty-three and forty-six. Which sign is right?", "style": "A"}, {"key": "iyvxn3", "text": "thirty-nine and eighty-five. Which sign is right?", "style": "A"}, {"key": "rgao35", "text": "forty and forty. Which sign is right?", "style": "A"}, {"key": "uy32vw", "text": "eighty-four and eighty-seven. Which sign is right?", "style": "A"}, {"key": "1pqepjh", "text": "forty-seven and thirty-seven. Which sign is right?", "style": "A"}, {"key": "1jzsd9h", "text": "thirty and sixty-nine. Which sign is right?", "style": "A"}, {"key": "1s4wkr5", "text": "forty-nine and seven. Which sign is right?", "style": "A"}, {"key": "1waf8im", "text": "fifty-nine and sixty-five. Which sign is right?", "style": "A"}, {"key": "1dqtgit", "text": "forty-eight and thirty-eight. Which sign is right?", "style": "A"}, {"key": "1ey2swp", "text": "seventy-six and seventy-six. Which sign is right?", "style": "A"}, {"key": "if0pcb", "text": "thirty-three and thirteen. Which sign is right?", "style": "A"}, {"key": "1xykejc", "text": "eighty-two and seventy. Which sign is right?", "style": "A"}, {"key": "13akj94", "text": "twenty-two and fifteen. Which sign is right?", "style": "A"}, {"key": "16l216v", "text": "forty-nine and sixty. Which sign is right?", "style": "A"}, {"key": "13y6hr4", "text": "fifty-one and sixty-three. Which sign is right?", "style": "A"}, {"key": "1jhl4h4", "text": "four and eight. Which sign is right?", "style": "A"}, {"key": "w4v8ja", "text": "thirty-nine and three. Which sign is right?", "style": "A"}, {"key": "gprudf", "text": "forty-nine and thirty-three. Which sign is right?", "style": "A"}, {"key": "1yotji6", "text": "thirty and eighteen. Which sign is right?", "style": "A"}, {"key": "jl2pj1", "text": "thirty-nine and thirty-five. Which sign is right?", "style": "A"}, {"key": "1190nmr", "text": "thirty-eight and forty-eight. Which sign is right?", "style": "A"}, {"key": "1phjhrk", "text": "thirty-six and nine. Which sign is right?", "style": "A"}, {"key": "y8ugrt", "text": "ninety-eight and eight. Which sign is right?", "style": "A"}, {"key": "1h83v2w", "text": "sixty-nine and eighty-four. Which sign is right?", "style": "A"}, {"key": "14kgd60", "text": "twenty-one and forty-four. Which sign is right?", "style": "A"}, {"key": "12sk48t", "text": "twenty-one and eighty. Which sign is right?", "style": "A"}, {"key": "13rpii9", "text": "forty-seven and sixty-two. Which sign is right?", "style": "A"}, {"key": "zlahjn", "text": "seventeen and eighteen. Which sign is right?", "style": "A"}, {"key": "9va5cc", "text": "six and twenty-seven. Which sign is right?", "style": "A"}, {"key": "la3y8a", "text": "thirty-five and twenty-two. Which sign is right?", "style": "A"}, {"key": "3b4j2b", "text": "forty-nine and thirty-nine. Which sign is right?", "style": "A"}, {"key": "1asr1tp", "text": "twenty and thirty-five. Which sign is right?", "style": "A"}, {"key": "1t21c6h", "text": "two and sixty-six. Which sign is right?", "style": "A"}, {"key": "1cz7qj2", "text": "seventeen and thirty. Which sign is right?", "style": "A"}, {"key": "1agt3ow", "text": "ten and fourteen. Which sign is right?", "style": "A"}, {"key": "16z8wqh", "text": "eight and ten. Which sign is right?", "style": "A"}, {"key": "pzn27m", "text": "twenty-five and thirty-two. Which sign is right?", "style": "A"}, {"key": "15eora", "text": "six and eight. Which sign is right?", "style": "A"}, {"key": "18wv6m4", "text": "five and thirty-two. Which sign is right?", "style": "A"}, {"key": "1thz6f6", "text": "thirty and forty-six. Which sign is right?", "style": "A"}, {"key": "czx45g", "text": "twenty-two and twelve. Which sign is right?", "style": "A"}, {"key": "1itox93", "text": "fifty-three and forty-four. Which sign is right?", "style": "A"}, {"key": "qo5yuu", "text": "twenty and three. Which sign is right?", "style": "A"}, {"key": "8mse4w", "text": "forty-nine and sixty-four. Which sign is right?", "style": "A"}, {"key": "1090z4l", "text": "thirty-six and eight. Which sign is right?", "style": "A"}, {"key": "1bmehwf", "text": "forty-nine and fifty-nine. Which sign is right?", "style": "A"}, {"key": "1ymz53h", "text": "thirty-eight and forty. Which sign is right?", "style": "A"}, {"key": "t1mbb3", "text": "thirty-two and eleven. Which sign is right?", "style": "A"}, {"key": "1vn63et", "text": "seventy-eight and six. Which sign is right?", "style": "A"}, {"key": "smyu41", "text": "ninety and forty-five. Which sign is right?", "style": "A"}, {"key": "mz6v6e", "text": "thirty-eight and forty-four. Which sign is right?", "style": "A"}, {"key": "1vza4qx", "text": "forty-seven and twenty-five. Which sign is right?", "style": "A"}, {"key": "19djskx", "text": "thirty-two and seventy-two. Which sign is right?", "style": "A"}, {"key": "2wl8if", "text": "ten and twenty-eight. Which sign is right?", "style": "A"}, {"key": "bwpbjf", "text": "twenty-nine and twenty-two. Which sign is right?", "style": "A"}, {"key": "1n5z8lc", "text": "thirty-three and nine. Which sign is right?", "style": "A"}, {"key": "1r3pr7h", "text": "seventy-nine and thirty-nine. Which sign is right?", "style": "A"}, {"key": "1i9uwnm", "text": "forty-two and thirty-eight. Which sign is right?", "style": "A"}, {"key": "1fk1yx6", "text": "twenty and fifty-eight. Which sign is right?", "style": "A"}, {"key": "lbnmdf", "text": "fifty and forty. Which sign is right?", "style": "A"}, {"key": "dmgyg2", "text": "twelve and three. Which sign is right?", "style": "A"}, {"key": "10jnlsc", "text": "thirteen and six. Which sign is right?", "style": "A"}, {"key": "1nqwi6q", "text": "ten and twenty-nine. Which sign is right?", "style": "A"}, {"key": "1k2amwc", "text": "four and forty-five. Which sign is right?", "style": "A"}, {"key": "zmx71t", "text": "thirty-nine and ten. Which sign is right?", "style": "A"}, {"key": "ipg4my", "text": "sixteen and forty-two. Which sign is right?", "style": "A"}, {"key": "197bp01", "text": "ninety and ninety. Which sign is right?", "style": "A"}, {"key": "1rbg7r1", "text": "nineteen and fifty-seven. Which sign is right?", "style": "A"}, {"key": "mo9eob", "text": "four and one. Which sign is right?", "style": "A"}, {"key": "9gvqf2", "text": "two and thirty-three. Which sign is right?", "style": "A"}, {"key": "o71thr", "text": "forty-eight and four. Which sign is right?", "style": "A"}, {"key": "1wdx5a4", "text": "forty-two and forty-eight. Which sign is right?", "style": "A"}, {"key": "dphvyj", "text": "seven and thirty-nine. Which sign is right?", "style": "A"}, {"key": "1pg1l55", "text": "eighty-two and seventy-four. Which sign is right?", "style": "A"}, {"key": "hkfm9k", "text": "four and thirty-four. Which sign is right?", "style": "A"}, {"key": "kalcuh", "text": "seventy-nine and seventy-nine. Which sign is right?", "style": "A"}, {"key": "1028az7", "text": "thirty-two and sixty-seven. Which sign is right?", "style": "A"}, {"key": "9hf0sx", "text": "thirty-eight and twenty-three. Which sign is right?", "style": "A"}, {"key": "wg44wn", "text": "thirty-seven and twenty-nine. Which sign is right?", "style": "A"}, {"key": "ldlk0k", "text": "thirteen and sixty-two. Which sign is right?", "style": "A"}, {"key": "psww4", "text": "forty-nine and twenty-four. Which sign is right?", "style": "A"}, {"key": "71d4rh", "text": "ninety and thirty-two. Which sign is right?", "style": "A"}, {"key": "2h82hg", "text": "fifty-three and fifty. Which sign is right?", "style": "A"}, {"key": "pjqspw", "text": "thirty-six and twenty-six. Which sign is right?", "style": "A"}, {"key": "1luzcpr", "text": "thirty-eight and twenty-two. Which sign is right?", "style": "A"}, {"key": "9lxc49", "text": "eighty-two and fifty-four. Which sign is right?", "style": "A"}, {"key": "pwz19b", "text": "one and two. Which sign is right?", "style": "A"}, {"key": "1ddvy7k", "text": "one and fifteen. Which sign is right?", "style": "A"}, {"key": "tyk39h", "text": "seventy-eight and seventy-eight. Which sign is right?", "style": "A"}, {"key": "1510gtm", "text": "forty-three and forty-eight. Which sign is right?", "style": "A"}, {"key": "1z0i9w9", "text": "sixty-six and seventy. Which sign is right?", "style": "A"}, {"key": "1bcomrg", "text": "four and forty-nine. Which sign is right?", "style": "A"}, {"key": "1tg66sx", "text": "ninety-six and five. Which sign is right?", "style": "A"}, {"key": "g1bmuj", "text": "eight and thirteen. Which sign is right?", "style": "A"}, {"key": "96plsw", "text": "seventy-eight and seventy-nine. Which sign is right?", "style": "A"}, {"key": "9mo00r", "text": "nine and ninety-two. Which sign is right?", "style": "A"}, {"key": "j62ipn", "text": "six and two. Which sign is right?", "style": "A"}, {"key": "rd4yc3", "text": "forty-five and thirty-three. Which sign is right?", "style": "A"}, {"key": "1fhjkav", "text": "forty-four and ninety-eight. Which sign is right?", "style": "A"}, {"key": "1j8q0lm", "text": "twenty-four and twenty-eight. Which sign is right?", "style": "A"}, {"key": "1h35dmx", "text": "two and fifty. Which sign is right?", "style": "A"}, {"key": "qypnrd", "text": "eighteen and twelve. Which sign is right?", "style": "A"}, {"key": "niyjyj", "text": "sixty-eight and seventy-three. Which sign is right?", "style": "A"}, {"key": "wu8m82", "text": "seventy-three and fifty-eight. Which sign is right?", "style": "A"}, {"key": "h544h5", "text": "thirty-one and thirty-five. Which sign is right?", "style": "A"}, {"key": "o1fgme", "text": "forty-four and twenty-one. Which sign is right?", "style": "A"}, {"key": "7fkme", "text": "fifty and thirty-one. Which sign is right?", "style": "A"}, {"key": "16zzbpd", "text": "eighty-three and eighty-three. Which sign is right?", "style": "A"}, {"key": "1n64fah", "text": "forty-two and thirty-six. Which sign is right?", "style": "A"}, {"key": "1wkavjd", "text": "fifty-nine and thirty-nine. Which sign is right?", "style": "A"}, {"key": "1u5zp4z", "text": "forty-nine and eight. Which sign is right?", "style": "A"}, {"key": "wcvrr", "text": "eighty-one and seventy-six. Which sign is right?", "style": "A"}, {"key": "1g7wemn", "text": "thirty-seven and fourteen. Which sign is right?", "style": "A"}, {"key": "1c0y4kr", "text": "sixty-five and ninety-one. Which sign is right?", "style": "A"}, {"key": "1wynmaz", "text": "nineteen and twenty-three. Which sign is right?", "style": "A"}, {"key": "43gw55", "text": "eleven and twelve. Which sign is right?", "style": "A"}, {"key": "6il0ty", "text": "thirty-nine and thirty-eight. Which sign is right?", "style": "A"}, {"key": "1r6rwy6", "text": "ninety-seven and sixty-six. Which sign is right?", "style": "A"}, {"key": "145lwv6", "text": "forty-seven and thirty-nine. Which sign is right?", "style": "A"}, {"key": "17sgptk", "text": "five and eight. Which sign is right?", "style": "A"}, {"key": "1y3z45g", "text": "twenty-two and seventy-nine. Which sign is right?", "style": "A"}, {"key": "163e11e", "text": "twenty and sixty-four. Which sign is right?", "style": "A"}, {"key": "18z1c6j", "text": "sixty-six and one hundred. Which sign is right?", "style": "A"}, {"key": "3xt3zk", "text": "sixty-five and seven. Which sign is right?", "style": "A"}, {"key": "1waudyo", "text": "twenty-seven and five. Which sign is right?", "style": "A"}, {"key": "1f80egt", "text": "fifty-one and thirty-nine. Which sign is right?", "style": "A"}, {"key": "8p7vyi", "text": "forty-eight and seventeen. Which sign is right?", "style": "A"}, {"key": "1pi96s8", "text": "eighteen and seventy. Which sign is right?", "style": "A"}, {"key": "1ctdo0j", "text": "twenty-seven and forty-four. Which sign is right?", "style": "A"}, {"key": "gk0fnx", "text": "ninety-seven and sixty-eight. Which sign is right?", "style": "A"}, {"key": "1og0o5c", "text": "thirty-nine and thirty-seven. Which sign is right?", "style": "A"}, {"key": "s69rsg", "text": "thirty-nine and sixty-three. Which sign is right?", "style": "A"}, {"key": "6id8ww", "text": "twelve and four. Which sign is right?", "style": "A"}, {"key": "6s1w5j", "text": "twenty-six and one hundred. Which sign is right?", "style": "A"}, {"key": "5571te", "text": "forty-four and nineteen. Which sign is right?", "style": "A"}, {"key": "1limlob", "text": "seven and eight. Which sign is right?", "style": "A"}, {"key": "a8s3ko", "text": "thirty-one and seventy-seven. Which sign is right?", "style": "A"}, {"key": "1xfizca", "text": "nine and seven. Which sign is right?", "style": "A"}, {"key": "1u6p66p", "text": "six and twenty-six. Which sign is right?", "style": "A"}, {"key": "1nubx3b", "text": "thirty-five and eighty-six. Which sign is right?", "style": "A"}, {"key": "7g1dr8", "text": "seven and six. Which sign is right?", "style": "A"}, {"key": "1rcgwoc", "text": "thirty-two and one. Which sign is right?", "style": "A"}, {"key": "1eq6hec", "text": "forty-three and twenty-four. Which sign is right?", "style": "A"}, {"key": "dv2v65", "text": "twenty-five and twenty-nine. Which sign is right?", "style": "A"}, {"key": "zfahj9", "text": "five and sixty-nine. Which sign is right?", "style": "A"}, {"key": "ekl3zs", "text": "nine and eight. Which sign is right?", "style": "A"}, {"key": "1q1xtzy", "text": "seventy and seventy-nine. Which sign is right?", "style": "A"}, {"key": "1n9bi56", "text": "twenty-three and forty-one. Which sign is right?", "style": "A"}, {"key": "1u0w8g1", "text": "forty-four and seventeen. Which sign is right?", "style": "A"}, {"key": "kujdc7", "text": "twenty-three and thirty. Which sign is right?", "style": "A"}, {"key": "lkzfas", "text": "fifty-five and nine. Which sign is right?", "style": "A"}, {"key": "r272ea", "text": "four and forty-one. Which sign is right?", "style": "A"}, {"key": "1onedbc", "text": "twenty-four and ninety-eight. Which sign is right?", "style": "A"}, {"key": "1lhs0uz", "text": "forty-two and forty-nine. Which sign is right?", "style": "A"}, {"key": "117bww9", "text": "ninety-eight and ninety-eight. Which sign is right?", "style": "A"}, {"key": "wdic60", "text": "three and twenty. Which sign is right?", "style": "A"}, {"key": "1j5zs7k", "text": "eighty-three and one hundred. Which sign is right?", "style": "A"}, {"key": "mheu0l", "text": "forty-seven and nineteen. Which sign is right?", "style": "A"}, {"key": "nxqx7l", "text": "twenty-two and one. Which sign is right?", "style": "A"}, {"key": "1lsd3a9", "text": "eighty-nine and eighty-nine. Which sign is right?", "style": "A"}, {"key": "f0ysmd", "text": "eight and thirty-five. Which sign is right?", "style": "A"}, {"key": "14zgrbi", "text": "sixty-three and seventy-two. Which sign is right?", "style": "A"}, {"key": "enm9sw", "text": "sixty-one and eighty-six. Which sign is right?", "style": "A"}, {"key": "1yc1hu8", "text": "forty-two and fourteen. Which sign is right?", "style": "A"}, {"key": "ym7a7b", "text": "twenty-nine and forty-eight. Which sign is right?", "style": "A"}, {"key": "1dgyakj", "text": "ninety-nine and forty. Which sign is right?", "style": "A"}, {"key": "1x0podi", "text": "forty and twenty-eight. Which sign is right?", "style": "A"}, {"key": "1clbb7l", "text": "sixty-eight and sixty-eight. Which sign is right?", "style": "A"}, {"key": "1bo32ft", "text": "one and nine. Which sign is right?", "style": "A"}, {"key": "zm4mwi", "text": "twenty-nine and forty-four. Which sign is right?", "style": "A"}, {"key": "afztcr", "text": "seventeen and eighty-two. Which sign is right?", "style": "A"}, {"key": "gobe7y", "text": "forty-four and nine. Which sign is right?", "style": "A"}, {"key": "a1o5rk", "text": "five and forty-four. Which sign is right?", "style": "A"}, {"key": "sbumxy", "text": "thirty-one and twenty-two. Which sign is right?", "style": "A"}, {"key": "1pclccl", "text": "twenty and thirty-one. Which sign is right?", "style": "A"}, {"key": "jpus", "text": "twenty-five and forty-one. Which sign is right?", "style": "A"}, {"key": "1ex71cq", "text": "seventy-seven and forty-one. Which sign is right?", "style": "A"}, {"key": "1y8zsgk", "text": "five and thirty-five. Which sign is right?", "style": "A"}, {"key": "1nmuhbp", "text": "seventy-four and seventy-four. Which sign is right?", "style": "A"}, {"key": "1jznghk", "text": "twenty-six and forty-four. Which sign is right?", "style": "A"}, {"key": "7kbw4i", "text": "ninety-four and fifty-four. Which sign is right?", "style": "A"}, {"key": "amw8zp", "text": "fifty-eight and one hundred. Which sign is right?", "style": "A"}, {"key": "13ubgf3", "text": "thirty-five and forty-three. Which sign is right?", "style": "A"}, {"key": "kbu4o", "text": "forty-six and twenty-two. Which sign is right?", "style": "A"}, {"key": "4zabw7", "text": "ninety and ten. Which sign is right?", "style": "A"}, {"key": "1h20f7y", "text": "twenty-seven and twenty-four. Which sign is right?", "style": "A"}, {"key": "m96azt", "text": "eighty-two and sixty. Which sign is right?", "style": "A"}, {"key": "18snv9v", "text": "thirty-five and thirteen. Which sign is right?", "style": "A"}, {"key": "15yrrts", "text": "fifty-eight and eighty-nine. Which sign is right?", "style": "A"}, {"key": "5kgbdn", "text": "ninety-four and thirty. Which sign is right?", "style": "A"}, {"key": "vejdwm", "text": "eighty-one and nineteen. Which sign is right?", "style": "A"}, {"key": "1b9w4us", "text": "twenty-eight and one. Which sign is right?", "style": "A"}, {"key": "1d39be9", "text": "fifty-five and thirty-three. Which sign is right?", "style": "A"}, {"key": "uw8tre", "text": "nine and twelve. Which sign is right?", "style": "A"}, {"key": "18zgnho", "text": "eighty-seven and seventeen. Which sign is right?", "style": "A"}, {"key": "1d7eqnu", "text": "four and thirty-one. Which sign is right?", "style": "A"}, {"key": "1aqruff", "text": "fifty and thirty. Which sign is right?", "style": "A"}, {"key": "4c98dh", "text": "thirty-one and forty-two. Which sign is right?", "style": "A"}, {"key": "wlkupj", "text": "eleven and forty-six. Which sign is right?", "style": "A"}, {"key": "g3c3s0", "text": "ninety-nine and forty-five. Which sign is right?", "style": "A"}, {"key": "1afikxw", "text": "eighteen and thirty. Which sign is right?", "style": "A"}, {"key": "1wjr0cj", "text": "fifty-three and forty-three. Which sign is right?", "style": "A"}, {"key": "19wlnr8", "text": "thirteen and thirty-eight. Which sign is right?", "style": "A"}, {"key": "137kied", "text": "sixty and sixty. Which sign is right?", "style": "A"}, {"key": "4eptzo", "text": "forty-six and sixteen. Which sign is right?", "style": "A"}, {"key": "16vp68n", "text": "seventy-four and ninety. Which sign is right?", "style": "A"}, {"key": "16w7yfr", "text": "eighty-three and twenty. Which sign is right?", "style": "A"}, {"key": "hofa37", "text": "forty-nine and thirty-five. Which sign is right?", "style": "A"}, {"key": "8x3b78", "text": "eighteen and twenty-six. Which sign is right?", "style": "A"}, {"key": "18wgmmy", "text": "thirty-one and twenty-four. Which sign is right?", "style": "A"}, {"key": "1osu1uq", "text": "forty and forty-nine. Which sign is right?", "style": "A"}, {"key": "1lz0y89", "text": "sixty-one and sixty-five. Which sign is right?", "style": "A"}, {"key": "ihr468", "text": "thirty-eight and forty-one. Which sign is right?", "style": "A"}, {"key": "10qqosi", "text": "seventy-three and twenty-two. Which sign is right?", "style": "A"}, {"key": "1guu49n", "text": "seven and eighteen. Which sign is right?", "style": "A"}, {"key": "13iaxpi", "text": "fifty-seven and thirty-three. Which sign is right?", "style": "A"}, {"key": "qc67gs", "text": "twenty-eight and twenty-two. Which sign is right?", "style": "A"}, {"key": "na8a5x", "text": "twenty and thirty-six. Which sign is right?", "style": "A"}, {"key": "19vyfak", "text": "thirty-eight and forty-six. Which sign is right?", "style": "A"}, {"key": "1euh24v", "text": "nineteen and sixteen. Which sign is right?", "style": "A"}, {"key": "1ciwmf9", "text": "thirty-one and ten. Which sign is right?", "style": "A"}, {"key": "8fdbuh", "text": "seventeen and forty-five. Which sign is right?", "style": "A"}, {"key": "1xcaj4e", "text": "eighty-four and fifty. Which sign is right?", "style": "A"}, {"key": "17ttcaj", "text": "twenty-seven and twenty-eight. Which sign is right?", "style": "A"}, {"key": "wqc40d", "text": "forty-two and forty-two. Which sign is right?", "style": "A"}, {"key": "vcrz1t", "text": "sixty-five and one hundred. Which sign is right?", "style": "A"}, {"key": "whtt26", "text": "eight and thirty-eight. Which sign is right?", "style": "A"}, {"key": "ayufmy", "text": "forty-two and sixty-two. Which sign is right?", "style": "A"}, {"key": "1ua22qa", "text": "sixteen and thirty-four. Which sign is right?", "style": "A"}, {"key": "1em86mo", "text": "thirty-one and twenty-six. Which sign is right?", "style": "A"}, {"key": "al1jj1", "text": "eight and thirty-four. Which sign is right?", "style": "A"}, {"key": "zhz96f", "text": "one hundred and ninety-three. Which sign is right?", "style": "A"}, {"key": "7c8i62", "text": "thirteen and fourteen. Which sign is right?", "style": "A"}, {"key": "9ebcjl", "text": "forty-three and forty-six. Which sign is right?", "style": "A"}, {"key": "4ry8ep", "text": "sixty-two and eighty-eight. Which sign is right?", "style": "A"}, {"key": "fqj20t", "text": "fifty-three and fifty-one. Which sign is right?", "style": "A"}, {"key": "uj8at7", "text": "thirty-four and forty-five. Which sign is right?", "style": "A"}, {"key": "1r02oyn", "text": "forty-six and thirty-four. Which sign is right?", "style": "A"}, {"key": "1d0r0bv", "text": "sixty-eight and eight. Which sign is right?", "style": "A"}, {"key": "i9r5x3", "text": "twenty-one and one hundred. Which sign is right?", "style": "A"}, {"key": "1d8tg26", "text": "thirty-three and twenty-five. Which sign is right?", "style": "A"}, {"key": "gv1ns6", "text": "forty-two and sixty-four. Which sign is right?", "style": "A"}, {"key": "1m25dp2", "text": "forty-four and thirty-seven. Which sign is right?", "style": "A"}, {"key": "73bt6i", "text": "sixty-five and ten. Which sign is right?", "style": "A"}, {"key": "s2f0gb", "text": "forty-four and twenty. Which sign is right?", "style": "A"}, {"key": "1e8p5gh", "text": "fifty-two and fifty-two. Which sign is right?", "style": "A"}, {"key": "1aa5m24", "text": "sixty and ninety-two. Which sign is right?", "style": "A"}, {"key": "44q1qj", "text": "eighty-three and forty-two. Which sign is right?", "style": "A"}, {"key": "a5fc5o", "text": "twenty and fourteen. Which sign is right?", "style": "A"}, {"key": "irva31", "text": "twenty-nine and forty-seven. Which sign is right?", "style": "A"}, {"key": "11h1noh", "text": "seventeen and forty-six. Which sign is right?", "style": "A"}, {"key": "1jcw7fm", "text": "one and forty-five. Which sign is right?", "style": "A"}, {"key": "gyzdke", "text": "eighty-two and one. Which sign is right?", "style": "A"}, {"key": "tvuanq", "text": "forty-seven and eight. Which sign is right?", "style": "A"}, {"key": "mn6u9", "text": "fifteen and ninety-seven. Which sign is right?", "style": "A"}, {"key": "1rj7b8h", "text": "ninety-nine and ninety-nine. Which sign is right?", "style": "A"}, {"key": "1cvzi6k", "text": "thirty-nine and four. Which sign is right?", "style": "A"}, {"key": "1telruk", "text": "forty-six and sixty-two. Which sign is right?", "style": "A"}, {"key": "1120x52", "text": "sixty-eight and seventy-seven. Which sign is right?", "style": "A"}, {"key": "1gmdn6", "text": "twenty-one and twelve. Which sign is right?", "style": "A"}, {"key": "1uz6zq2", "text": "fifteen and twenty-six. Which sign is right?", "style": "A"}, {"key": "1k6yn4d", "text": "thirty-eight and sixteen. Which sign is right?", "style": "A"}, {"key": "z2qubs", "text": "twenty-eight and sixteen. Which sign is right?", "style": "A"}, {"key": "r4zrk", "text": "seventeen and twenty-two. Which sign is right?", "style": "A"}, {"key": "1wxn6r1", "text": "one hundred and forty. Which sign is right?", "style": "A"}, {"key": "2rxtqo", "text": "six and seventeen. Which sign is right?", "style": "A"}, {"key": "sjlty5", "text": "seven and fifteen. Which sign is right?", "style": "A"}, {"key": "ty2wq7", "text": "twenty-one and forty. Which sign is right?", "style": "A"}, {"key": "d0q707", "text": "fifteen and eight. Which sign is right?", "style": "A"}, {"key": "6xw90x", "text": "twenty-one and two. Which sign is right?", "style": "A"}, {"key": "12cj2hq", "text": "twenty-one and ninety-eight. Which sign is right?", "style": "A"}, {"key": "u6tud3", "text": "forty-seven and fifty-seven. Which sign is right?", "style": "A"}, {"key": "10jmlfu", "text": "twenty-six and forty-six. Which sign is right?", "style": "A"}, {"key": "1osvfsz", "text": "seventy-nine and twenty-eight. Which sign is right?", "style": "A"}, {"key": "10b1z0a", "text": "four and eleven. Which sign is right?", "style": "A"}, {"key": "1veywex", "text": "thirty-five and eighty-two. Which sign is right?", "style": "A"}, {"key": "1i2wqqs", "text": "seven and three. Which sign is right?", "style": "A"}, {"key": "1x5dx6e", "text": "one and ninety. Which sign is right?", "style": "A"}, {"key": "163zcpk", "text": "fifty-three and ninety-four. Which sign is right?", "style": "A"}, {"key": "1gee1qi", "text": "fifteen and twenty-one. Which sign is right?", "style": "A"}, {"key": "kat2wp", "text": "sixty-six and fifty. Which sign is right?", "style": "A"}, {"key": "orvlj9", "text": "forty-nine and thirty-two. Which sign is right?", "style": "A"}, {"key": "oo2lj4", "text": "three and thirty-six. Which sign is right?", "style": "A"}, {"key": "70z7qt", "text": "eighty-three and fifty-two. Which sign is right?", "style": "A"}, {"key": "16v4eoz", "text": "fifty and nine. Which sign is right?", "style": "A"}, {"key": "1104tgz", "text": "forty and fifty. Which sign is right?", "style": "A"}, {"key": "y7ufkp", "text": "sixty-six and sixty-six. Which sign is right?", "style": "A"}, {"key": "pxe98w", "text": "twenty-four and seven. Which sign is right?", "style": "A"}, {"key": "sk082v", "text": "four and twenty-three. Which sign is right?", "style": "A"}, {"key": "1u2rahl", "text": "ninety-four and ninety-four. Which sign is right?", "style": "A"}, {"key": "c9wija", "text": "twenty-four and forty-five. Which sign is right?", "style": "A"}, {"key": "1mw5sog", "text": "fifty-eight and forty-six. Which sign is right?", "style": "A"}, {"key": "se9ybv", "text": "twelve and forty-three. Which sign is right?", "style": "A"}, {"key": "4o18m4", "text": "fifty-six and ninety-five. Which sign is right?", "style": "A"}, {"key": "sxmjx0", "text": "forty-four and ninety-one. Which sign is right?", "style": "A"}, {"key": "1mve93s", "text": "sixty-one and ninety. Which sign is right?", "style": "A"}, {"key": "vqoh67", "text": "twenty-one and three. Which sign is right?", "style": "A"}, {"key": "t7heid", "text": "sixty-three and eighty-seven. Which sign is right?", "style": "A"}, {"key": "1k9yi6i", "text": "six and ten. Which sign is right?", "style": "A"}, {"key": "1ronx4h", "text": "forty-three and forty-four. Which sign is right?", "style": "A"}, {"key": "znnk6d", "text": "forty-one and eighty-three. Which sign is right?", "style": "A"}, {"key": "1h51yex", "text": "twenty-two and six. Which sign is right?", "style": "A"}, {"key": "mo3vy2", "text": "twenty-four and fifty-six. Which sign is right?", "style": "A"}, {"key": "rpvezs", "text": "twenty and nine. Which sign is right?", "style": "A"}, {"key": "72re99", "text": "six and fourteen. Which sign is right?", "style": "A"}, {"key": "1auc53q", "text": "fifty and twelve. Which sign is right?", "style": "A"}, {"key": "1y31o5h", "text": "ninety-two and sixty-one. Which sign is right?", "style": "A"}, {"key": "8r7kjt", "text": "eighty-three and eighty-one. Which sign is right?", "style": "A"}, {"key": "xzqbf", "text": "nineteen and twenty-nine. Which sign is right?", "style": "A"}, {"key": "1rwckab", "text": "thirty and nineteen. Which sign is right?", "style": "A"}, {"key": "1juxs9d", "text": "three and twenty-five. Which sign is right?", "style": "A"}, {"key": "1ad3lg6", "text": "fifty-seven and twenty-seven. Which sign is right?", "style": "A"}, {"key": "jy7kkz", "text": "twenty-eight and thirty-four. Which sign is right?", "style": "A"}, {"key": "1d67m67", "text": "thirty-six and sixty-eight. Which sign is right?", "style": "A"}, {"key": "y6zd0v", "text": "seventy-six and sixty-eight. Which sign is right?", "style": "A"}, {"key": "l56bt2", "text": "thirteen and twenty-six. Which sign is right?", "style": "A"}, {"key": "19sbj8x", "text": "twenty-nine and six. Which sign is right?", "style": "A"}, {"key": "181yn5v", "text": "sixty-four and eighty-seven. Which sign is right?", "style": "A"}, {"key": "1gnbrlc", "text": "nine and forty-four. Which sign is right?", "style": "A"}, {"key": "oh4zwn", "text": "eighty-four and fifty-one. Which sign is right?", "style": "A"}, {"key": "szchyb", "text": "thirty and four. Which sign is right?", "style": "A"}, {"key": "1jb6e7w", "text": "six and forty-three. Which sign is right?", "style": "A"}, {"key": "e3690z", "text": "three and two. Which sign is right?", "style": "A"}, {"key": "149fw1m", "text": "thirty-two and thirty. Which sign is right?", "style": "A"}, {"key": "3z47c3", "text": "thirty-seven and fifty-eight. Which sign is right?", "style": "A"}, {"key": "10t6fke", "text": "nine and fifteen. Which sign is right?", "style": "A"}, {"key": "12pvx9n", "text": "forty-five and thirty-six. Which sign is right?", "style": "A"}, {"key": "1hthbnw", "text": "twenty-one and fifty-six. Which sign is right?", "style": "A"}, {"key": "9jdb2y", "text": "fourteen and eighteen. Which sign is right?", "style": "A"}, {"key": "1lvhno", "text": "sixty and eighty-eight. Which sign is right?", "style": "A"}, {"key": "1rwmp6y", "text": "seventy-six and sixty-nine. Which sign is right?", "style": "A"}, {"key": "rpkh5a", "text": "fifty-one and sixty-two. Which sign is right?", "style": "A"}, {"key": "1ck7yed", "text": "thirteen and twenty-eight. Which sign is right?", "style": "A"}, {"key": "7ci9ai", "text": "seventeen and two. Which sign is right?", "style": "A"}, {"key": "1fzu6m3", "text": "three and seventy-seven. Which sign is right?", "style": "A"}, {"key": "14520l", "text": "thirty-two and forty-six. Which sign is right?", "style": "A"}, {"key": "p32gtm", "text": "fifty-five and twenty-five. Which sign is right?", "style": "A"}, {"key": "p629go", "text": "sixty-four and fifteen. Which sign is right?", "style": "A"}, {"key": "9m2fwm", "text": "eighty-five and sixty-three. Which sign is right?", "style": "A"}, {"key": "1f8wd5b", "text": "forty-three and forty-two. Which sign is right?", "style": "A"}, {"key": "ggr0je", "text": "ninety-three and forty-four. Which sign is right?", "style": "A"}, {"key": "1fdyrep", "text": "thirty-five and twenty-seven. Which sign is right?", "style": "A"}, {"key": "15y8irg", "text": "ninety-eight and nineteen. Which sign is right?", "style": "A"}, {"key": "zc6cy", "text": "twenty-six and seven. Which sign is right?", "style": "A"}, {"key": "1ayr5xf", "text": "ninety-six and sixty-six. Which sign is right?", "style": "A"}, {"key": "11vz5dv", "text": "eighty-seven and sixty-nine. Which sign is right?", "style": "A"}, {"key": "4iqlg6", "text": "thirty-four and forty. Which sign is right?", "style": "A"}, {"key": "1bbjdak", "text": "forty-nine and forty-seven. Which sign is right?", "style": "A"}, {"key": "14mhwfj", "text": "fifteen and thirty-five. Which sign is right?", "style": "A"}, {"key": "s7p6oi", "text": "twenty and forty-seven. Which sign is right?", "style": "A"}, {"key": "d6pc7m", "text": "You have 3 rabbits. Then 2 wander off!", "style": "A"}, {"key": "odkgwh", "text": "You have 7 butterflies. Then you meet 4 more!", "style": "A"}, {"key": "zf4s2e", "text": "You have 5 sharks. Finn has 3 sharks. How many more do you have?", "style": "A"}, {"key": "1cd2b6t", "text": "You have 6 squirrels. Then 1 wander off!", "style": "A"}, {"key": "1pzn74b", "text": "You have 5 bees. Then you meet 8 more!", "style": "A"}, {"key": "3o7asx", "text": "You have 13 turtles. Then you meet 1 more!", "style": "A"}, {"key": "f1cyjv", "text": "You have 4 lambs. Then 2 wander off!", "style": "A"}, {"key": "teo0gw", "text": "You have 11 ladybugs. Then 7 flutter away!", "style": "A"}, {"key": "1ksr9rp", "text": "You have 7 chicks. Pat has 1 chick. How many more do you have?", "style": "A"}, {"key": "1w2m8qm", "text": "You have 9 ducklings. Then 1 wander off!", "style": "A"}, {"key": "s1pu3y", "text": "You have 12 rabbits. Then 11 wander off!", "style": "A"}, {"key": "c4xsoi", "text": "You have 12 butterflies. Then 6 flutter away!", "style": "A"}, {"key": "1carx6t", "text": "You have 5 sharks. Then 4 swim away!", "style": "A"}, {"key": "qqiqjb", "text": "You have 6 squirrels. Then you spot 7 more!", "style": "A"}, {"key": "1ng6mra", "text": "You have 5 bees. Bo has 3 bees. How many more do you have?", "style": "A"}, {"key": "fzlw2y", "text": "You have 8 turtles. Then 3 swim away!", "style": "A"}, {"key": "bgh6b0", "text": "You have 3 lambs. Then you spot 8 more!", "style": "A"}, {"key": "guzqd2", "text": "You have 14 ladybugs. Then 13 flutter away!", "style": "A"}, {"key": "n53qpm", "text": "You have 1 chick. Then you spot 5 more!", "style": "A"}, {"key": "96510", "text": "You have 10 ducklings. Then 1 wander off!", "style": "A"}, {"key": "1pqxsfa", "text": "You have 6 rabbits. Pat has 2 rabbits. How many more do you have?", "style": "A"}, {"key": "1wuntdc", "text": "You have 8 butterflies. Then 1 flutter away!", "style": "A"}, {"key": "1baezaf", "text": "You have 12 sharks. Then 6 swim away!", "style": "A"}, {"key": "28exgr", "text": "You have 9 squirrels. Pat has 2 squirrels. How many more do you have?", "style": "A"}, {"key": "58w3d0", "text": "You have 6 bees. Then 5 flutter away!", "style": "A"}, {"key": "j1c6i8", "text": "You have 2 turtles. Then you meet 4 more!", "style": "A"}, {"key": "1b1li12", "text": "You have 11 lambs. Then 3 wander off!", "style": "A"}, {"key": "cv2xi", "text": "You have 4 ladybugs. Then 3 flutter away!", "style": "A"}, {"key": "bmwy5o", "text": "You have 7 chicks. Then 6 wander off!", "style": "A"}, {"key": "sohm3k", "text": "You have 4 ducklings. Pat has 1 duckling. How many more do you have?", "style": "A"}, {"key": "13sspu7", "text": "You have 9 rabbits. Then 7 wander off!", "style": "A"}, {"key": "u2gyy0", "text": "You have 13 butterflies. Then 12 flutter away!", "style": "A"}, {"key": "ft7niz", "text": "You have 10 sharks. Finn has 8 sharks. How many more do you have?", "style": "A"}, {"key": "1nhp6rq", "text": "You have 3 squirrels. Then 1 wander off!", "style": "A"}, {"key": "aox70m", "text": "You have 7 bees. Then 4 flutter away!", "style": "A"}, {"key": "1wckk3z", "text": "You have 7 turtles. Finn has 2 turtles. How many more do you have?", "style": "A"}, {"key": "82aihm", "text": "You have 5 lambs. Then you spot 4 more!", "style": "A"}, {"key": "1ys7v7q", "text": "You have 7 ladybugs. Then you meet 3 more!", "style": "A"}, {"key": "24gmi4", "text": "You have 6 chicks. Pat has 4 chicks. How many more do you have?", "style": "A"}, {"key": "1a8zum1", "text": "You have 4 ducklings. Then 1 wander off!", "style": "A"}, {"key": "1h789fn", "text": "You have 6 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "iejfrx", "text": "You have 14 butterflies. Then 5 flutter away!", "style": "A"}, {"key": "1bcadiq", "text": "You have 5 sharks. Then you meet 4 more!", "style": "A"}, {"key": "1vp18yy", "text": "You have 11 squirrels. Then 8 wander off!", "style": "A"}, {"key": "10rq5tf", "text": "You have 3 bees. Then you meet 13 more!", "style": "A"}, {"key": "1t8n2tr", "text": "You have 6 turtles. Then 4 swim away!", "style": "A"}, {"key": "12r1y9a", "text": "You have 5 lambs. Then you spot 8 more!", "style": "A"}, {"key": "1v0i1py", "text": "You have 13 ladybugs. Then 7 flutter away!", "style": "A"}, {"key": "11vz4jl", "text": "You have 7 chicks. Then you spot 1 more!", "style": "A"}, {"key": "1cleyb8", "text": "You have 9 ducklings. Then 7 wander off!", "style": "A"}, {"key": "1lkcp9s", "text": "You have 8 rabbits. Pat has 2 rabbits. How many more do you have?", "style": "A"}, {"key": "5p9g3h", "text": "You have 7 butterflies. Then 5 flutter away!", "style": "A"}, {"key": "3bf6x1", "text": "You have 7 sharks. Then 6 swim away!", "style": "A"}, {"key": "9gz93h", "text": "You have 11 squirrels. Pat has 5 squirrels. How many more do you have?", "style": "A"}, {"key": "1xpxc8h", "text": "You have 6 bees. Then you meet 1 more!", "style": "A"}, {"key": "xmcpfw", "text": "You have 8 turtles. Then you meet 2 more!", "style": "A"}, {"key": "hxefts", "text": "You have 6 lambs. Then you spot 3 more!", "style": "A"}, {"key": "13g12um", "text": "You have 5 ladybugs. Then you meet 1 more!", "style": "A"}, {"key": "154zw00", "text": "You have 7 chicks. Then 2 wander off!", "style": "A"}, {"key": "1cg4iyp", "text": "You have 5 ducklings. Pat has 4 ducklings. How many more do you have?", "style": "A"}, {"key": "19vs38f", "text": "You have 7 rabbits. Then 1 wander off!", "style": "A"}, {"key": "j8btm", "text": "You have 13 butterflies. Then 3 flutter away!", "style": "A"}, {"key": "1i2n1fm", "text": "You have 11 sharks. Finn has 6 sharks. How many more do you have?", "style": "A"}, {"key": "o07hnz", "text": "You have 3 squirrels. Then 2 wander off!", "style": "A"}, {"key": "1qmjixo", "text": "You have 10 bees. Then 2 flutter away!", "style": "A"}, {"key": "k906i7", "text": "You have 8 turtles. Then you meet 7 more!", "style": "A"}, {"key": "3okv70", "text": "You have 4 lambs. Then 3 wander off!", "style": "A"}, {"key": "1kpl1rm", "text": "You have 9 ladybugs. Then 8 flutter away!", "style": "A"}, {"key": "1lu8u8s", "text": "You have 8 chicks. Then 3 wander off!", "style": "A"}, {"key": "19qqsfn", "text": "You have 6 ducklings. Then 5 wander off!", "style": "A"}, {"key": "z91k17", "text": "You have 9 butterflies. Then 5 flutter away!", "style": "A"}, {"key": "i17904", "text": "You have 6 sharks. Then you meet 1 more!", "style": "A"}, {"key": "s56y5t", "text": "You have 9 squirrels. Then 2 wander off!", "style": "A"}, {"key": "1nwtnq8", "text": "You have 7 bees. Then you meet 7 more!", "style": "A"}, {"key": "s9l3fu", "text": "You have 9 turtles. Then 2 swim away!", "style": "A"}, {"key": "iu3be4", "text": "You have 8 lambs. Then you spot 5 more!", "style": "A"}, {"key": "1m1diqt", "text": "You have 10 ladybugs. Then you meet 6 more!", "style": "A"}, {"key": "ra4cpe", "text": "You have 8 chicks. Then 1 wander off!", "style": "A"}, {"key": "1e3hb1j", "text": "You have 9 ducklings. Then 2 wander off!", "style": "A"}, {"key": "1kgfkbr", "text": "You have 4 rabbits. Pat has 3 rabbits. How many more do you have?", "style": "A"}, {"key": "10uvqfp", "text": "You have 9 butterflies. Then 7 flutter away!", "style": "A"}, {"key": "5ec4rp", "text": "You have 8 sharks. Then 3 swim away!", "style": "A"}, {"key": "mcdydp", "text": "You have 16 squirrels. Then 2 wander off!", "style": "A"}, {"key": "lvqrif", "text": "You have 4 bees. Then you meet 5 more!", "style": "A"}, {"key": "eqh1qc", "text": "You have 7 turtles. Then 2 swim away!", "style": "A"}, {"key": "cn8tuz", "text": "You have 12 lambs. Pat has 11 lambs. How many more do you have?", "style": "A"}, {"key": "7wv0ma", "text": "You have 11 chicks. Then 7 wander off!", "style": "A"}, {"key": "17b3rkr", "text": "You have 5 ducklings. Pat has 2 ducklings. How many more do you have?", "style": "A"}, {"key": "oolxqb", "text": "You have 7 rabbits. Then you spot 1 more!", "style": "A"}, {"key": "1n2eokc", "text": "You have 12 butterflies. Then 11 flutter away!", "style": "A"}, {"key": "1439j1h", "text": "You have 5 sharks. Then you meet 9 more!", "style": "A"}, {"key": "reojro", "text": "You have 13 bees. Then 7 flutter away!", "style": "A"}, {"key": "1ecrupz", "text": "You have 5 turtles. Finn has 4 turtles. How many more do you have?", "style": "A"}, {"key": "14dyxh5", "text": "You have 11 ladybugs. Then 8 flutter away!", "style": "A"}, {"key": "1b3fehe", "text": "You have 12 chicks. Pat has 5 chicks. How many more do you have?", "style": "A"}, {"key": "3yas4i", "text": "You have 7 ducklings. Then you spot 1 more!", "style": "A"}, {"key": "1adsaze", "text": "You have 9 rabbits. Then 8 wander off!", "style": "A"}, {"key": "1o6q0e1", "text": "You have 3 butterflies. Then you meet 8 more!", "style": "A"}, {"key": "z5f9ku", "text": "You have 5 sharks. Then 3 swim away!", "style": "A"}, {"key": "o5hdh3", "text": "You have 9 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "1glgs3h", "text": "You have 9 bees. Bo has 4 bees. How many more do you have?", "style": "A"}, {"key": "fbude5", "text": "You have 6 turtles. Then you meet 3 more!", "style": "A"}, {"key": "mikcfp", "text": "You have 12 lambs. Then 1 wander off!", "style": "A"}, {"key": "io7ndo", "text": "You have 12 ladybugs. Bo has 10 ladybugs. How many more do you have?", "style": "A"}, {"key": "qdq9m5", "text": "You have 5 chicks. Then 3 wander off!", "style": "A"}, {"key": "c0tin7", "text": "You have 5 ducklings. Then 2 wander off!", "style": "A"}, {"key": "1eev4h1", "text": "You have 11 rabbits. Then 6 wander off!", "style": "A"}, {"key": "x04iqh", "text": "You have 4 butterflies. Then you meet 5 more!", "style": "A"}, {"key": "11sr32f", "text": "You have 10 sharks. Then 4 swim away!", "style": "A"}, {"key": "eqjq8r", "text": "You have 9 squirrels. Then you spot 6 more!", "style": "A"}, {"key": "1yuf7p8", "text": "You have 3 bees. Then 2 flutter away!", "style": "A"}, {"key": "yw4bsx", "text": "You have 5 turtles. Then 1 swim away!", "style": "A"}, {"key": "7zz75j", "text": "You have 6 lambs. Then you spot 2 more!", "style": "A"}, {"key": "1r3zgfh", "text": "You have 7 chicks. Then you spot 5 more!", "style": "A"}, {"key": "qtdl1b", "text": "You have 5 ducklings. Pat has 1 duckling. How many more do you have?", "style": "A"}, {"key": "vjd118", "text": "You have 5 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "opa4up", "text": "You have 7 butterflies. Then 1 flutter away!", "style": "A"}, {"key": "h97s3f", "text": "You have 7 sharks. Finn has 4 sharks. How many more do you have?", "style": "A"}, {"key": "o9sek1", "text": "You have 3 squirrels. Then you spot 6 more!", "style": "A"}, {"key": "11xq4cn", "text": "You have 6 bees. Then 4 flutter away!", "style": "A"}, {"key": "h8czwc", "text": "You have 12 turtles. Then 8 swim away!", "style": "A"}, {"key": "17jjkmm", "text": "You have 3 lambs. Then 2 wander off!", "style": "A"}, {"key": "1gpp98x", "text": "You have 6 ladybugs. Then you meet 7 more!", "style": "A"}, {"key": "g9c999", "text": "You have 5 chicks. Pat has 2 chicks. How many more do you have?", "style": "A"}, {"key": "62s1s8", "text": "You have 3 ducklings. Then you spot 3 more!", "style": "A"}, {"key": "qciouj", "text": "You have 13 rabbits. Then 11 wander off!", "style": "A"}, {"key": "ybo067", "text": "You have 12 butterflies. Bo has 6 butterflies. How many more do you have?", "style": "A"}, {"key": "1x59l9s", "text": "You have 6 sharks. Then 4 swim away!", "style": "A"}, {"key": "j60o74", "text": "You have 9 squirrels. Then 5 wander off!", "style": "A"}, {"key": "bf4is", "text": "You have 10 bees. Bo has 7 bees. How many more do you have?", "style": "A"}, {"key": "1anm327", "text": "You have 3 turtles. Then 1 swim away!", "style": "A"}, {"key": "10xa1gx", "text": "You have 6 lambs. Then 2 wander off!", "style": "A"}, {"key": "2dr4c8", "text": "You have 10 ladybugs. Then you meet 5 more!", "style": "A"}, {"key": "7k5dfq", "text": "You have 6 chicks. Then you spot 1 more!", "style": "A"}, {"key": "1360xk6", "text": "You have 10 ducklings. Then you spot 1 more!", "style": "A"}, {"key": "1oi5tgs", "text": "You have 4 rabbits. Pat has 2 rabbits. How many more do you have?", "style": "A"}, {"key": "1mow5ph", "text": "You have 4 butterflies. Then you meet 1 more!", "style": "A"}, {"key": "1oxklg9", "text": "You have 9 sharks. Then you meet 1 more!", "style": "A"}, {"key": "5d2yp2", "text": "You have 4 bees. Then 1 flutter away!", "style": "A"}, {"key": "qmu3v7", "text": "You have 3 turtles. Then you meet 6 more!", "style": "A"}, {"key": "758rtj", "text": "You have 10 lambs. Pat has 6 lambs. How many more do you have?", "style": "A"}, {"key": "13l3kpw", "text": "You have 13 ducklings. Then you spot 2 more!", "style": "A"}, {"key": "5371pq", "text": "You have 3 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "6j37w4", "text": "You have 3 butterflies. Then you meet 3 more!", "style": "A"}, {"key": "1oh14lb", "text": "You have 11 sharks. Finn has 3 sharks. How many more do you have?", "style": "A"}, {"key": "1bfhzen", "text": "You have 9 squirrels. Then 4 wander off!", "style": "A"}, {"key": "cftwer", "text": "You have 7 bees. Then 3 flutter away!", "style": "A"}, {"key": "1hb3ayg", "text": "You have 9 turtles. Then you meet 5 more!", "style": "A"}, {"key": "1bb9egx", "text": "You have 4 lambs. Then you spot 2 more!", "style": "A"}, {"key": "1tegays", "text": "You have 3 ladybugs. Then you meet 10 more!", "style": "A"}, {"key": "4h8ta1", "text": "You have 4 chicks. Then you spot 6 more!", "style": "A"}, {"key": "1v3us5g", "text": "You have 5 ducklings. Then 3 wander off!", "style": "A"}, {"key": "a46gef", "text": "You have 3 rabbits. Then you spot 1 more!", "style": "A"}, {"key": "obw8b1", "text": "You have 8 butterflies. Then you meet 5 more!", "style": "A"}, {"key": "19ojj47", "text": "You have 13 squirrels. Then 10 wander off!", "style": "A"}, {"key": "16hl5gg", "text": "You have 16 bees. Then 8 flutter away!", "style": "A"}, {"key": "1vdjn5c", "text": "You have 4 turtles. Then 1 swim away!", "style": "A"}, {"key": "weiv5l", "text": "You have 1 lamb. Then you spot 6 more!", "style": "A"}, {"key": "1kmohxi", "text": "You have 9 ladybugs. Bo has 7 ladybugs. How many more do you have?", "style": "A"}, {"key": "1t4ypo7", "text": "You have 4 chicks. Then 2 wander off!", "style": "A"}, {"key": "1f3cbxy", "text": "You have 11 ducklings. Then you spot 2 more!", "style": "A"}, {"key": "h6mgek", "text": "You have 7 rabbits. Then 4 wander off!", "style": "A"}, {"key": "tma52o", "text": "You have 3 butterflies. Then 2 flutter away!", "style": "A"}, {"key": "cq7mdv", "text": "You have 9 sharks. Then you meet 3 more!", "style": "A"}, {"key": "1hh3ikj", "text": "You have 1 squirrel. Then you spot 3 more!", "style": "A"}, {"key": "1nki80i", "text": "You have 7 bees. Then you meet 1 more!", "style": "A"}, {"key": "ph4w8y", "text": "You have 11 turtles. Then you meet 2 more!", "style": "A"}, {"key": "e9r4fl", "text": "You have 12 lambs. Then you spot 1 more!", "style": "A"}, {"key": "wz4mwf", "text": "You have 1 ladybug. Then you meet 1 more!", "style": "A"}, {"key": "qr5kvu", "text": "You have 11 chicks. Then you spot 1 more!", "style": "A"}, {"key": "18hluyy", "text": "You have 10 ducklings. Then 3 wander off!", "style": "A"}, {"key": "1vqc0nu", "text": "You have 6 rabbits. Then you spot 1 more!", "style": "A"}, {"key": "1ar2kw5", "text": "You have 11 butterflies. Then 4 flutter away!", "style": "A"}, {"key": "fpmp63", "text": "You have 11 sharks. Finn has 7 sharks. How many more do you have?", "style": "A"}, {"key": "470sap", "text": "You have 6 squirrels. Then you spot 1 more!", "style": "A"}, {"key": "een7dk", "text": "You have 10 bees. Then 6 flutter away!", "style": "A"}, {"key": "nfn04l", "text": "You have 5 turtles. Finn has 1 turtle. How many more do you have?", "style": "A"}, {"key": "1olygjb", "text": "You have 1 lamb. Then you spot 8 more!", "style": "A"}, {"key": "11r5dj2", "text": "You have 7 ladybugs. Then 2 flutter away!", "style": "A"}, {"key": "1pbzhkp", "text": "You have 3 ducklings. Then 2 wander off!", "style": "A"}, {"key": "1hax1md", "text": "You have 4 rabbits. Then you spot 2 more!", "style": "A"}, {"key": "gte4n1", "text": "You have 5 butterflies. Bo has 4 butterflies. How many more do you have?", "style": "A"}, {"key": "29k78h", "text": "You have 7 sharks. Then 2 swim away!", "style": "A"}, {"key": "1sw2hyt", "text": "You have 2 squirrels. Then you spot 1 more!", "style": "A"}, {"key": "dt0slk", "text": "You have 9 bees. Then you meet 1 more!", "style": "A"}, {"key": "uycnnv", "text": "You have 7 turtles. Then you meet 2 more!", "style": "A"}, {"key": "11648hp", "text": "You have 12 lambs. Then 9 wander off!", "style": "A"}, {"key": "qj1gz3", "text": "You have 10 ladybugs. Bo has 1 ladybug. How many more do you have?", "style": "A"}, {"key": "18dn1ux", "text": "You have 1 duckling. Then you spot 3 more!", "style": "A"}, {"key": "dg2bwo", "text": "You have 10 rabbits. Pat has 3 rabbits. How many more do you have?", "style": "A"}, {"key": "1g1ny0a", "text": "You have 5 butterflies. Then you meet 3 more!", "style": "A"}, {"key": "di5fg9", "text": "You have 2 sharks. Then you meet 6 more!", "style": "A"}, {"key": "ox5v7d", "text": "You have 14 squirrels. Then you spot 2 more!", "style": "A"}, {"key": "hu5hed", "text": "You have 7 turtles. Then 3 swim away!", "style": "A"}, {"key": "ry3ri8", "text": "You have 6 lambs. Then 5 wander off!", "style": "A"}, {"key": "12ootc9", "text": "You have 8 ladybugs. Then 6 flutter away!", "style": "A"}, {"key": "1wai8dn", "text": "You have 5 chicks. Then you spot 1 more!", "style": "A"}, {"key": "ds4nne", "text": "You have 10 ducklings. Pat has 7 ducklings. How many more do you have?", "style": "A"}, {"key": "141fzrg", "text": "You have 6 rabbits. Then 5 wander off!", "style": "A"}, {"key": "eum53l", "text": "You have 10 butterflies. Then 5 flutter away!", "style": "A"}, {"key": "1nyiud", "text": "You have 11 sharks. Then you meet 2 more!", "style": "A"}, {"key": "17zsvaj", "text": "You have 3 squirrels. Then you spot 4 more!", "style": "A"}, {"key": "1om04ej", "text": "You have 9 bees. Then 5 flutter away!", "style": "A"}, {"key": "6dodej", "text": "You have 4 turtles. Then you meet 7 more!", "style": "A"}, {"key": "pk7ogm", "text": "You have 7 lambs. Then you spot 2 more!", "style": "A"}, {"key": "ninv9y", "text": "You have 1 ladybug. Then you meet 2 more!", "style": "A"}, {"key": "3q0ovi", "text": "You have 10 chicks. Pat has 3 chicks. How many more do you have?", "style": "A"}, {"key": "1qvdxml", "text": "You have 4 ducklings. Then you spot 1 more!", "style": "A"}, {"key": "1plpzld", "text": "You have 11 rabbits. Then 2 wander off!", "style": "A"}, {"key": "12np5x4", "text": "You have 11 butterflies. Then 7 flutter away!", "style": "A"}, {"key": "1mhldvp", "text": "You have 2 sharks. Then you meet 2 more!", "style": "A"}, {"key": "bm49qt", "text": "You have 11 squirrels. Then you spot 1 more!", "style": "A"}, {"key": "xb4k2m", "text": "You have 6 turtles. Then you meet 2 more!", "style": "A"}, {"key": "omebw3", "text": "You have 1 lamb. Then you spot 4 more!", "style": "A"}, {"key": "b21u85", "text": "You have 3 chicks. Then you spot 1 more!", "style": "A"}, {"key": "1o87ijq", "text": "You have 8 ducklings. Then you spot 4 more!", "style": "A"}, {"key": "1wcsbij", "text": "You have 10 rabbits. Then you spot 5 more!", "style": "A"}, {"key": "1few3un", "text": "You have 6 butterflies. Then you meet 1 more!", "style": "A"}, {"key": "1do51u", "text": "You have 6 squirrels. Pat has 4 squirrels. How many more do you have?", "style": "A"}, {"key": "skffed", "text": "You have 9 bees. Then 7 flutter away!", "style": "A"}, {"key": "10brtee", "text": "You have 6 turtles. Then 5 swim away!", "style": "A"}, {"key": "187hqr", "text": "You have 9 lambs. Then 7 wander off!", "style": "A"}, {"key": "1kafv7s", "text": "You have 7 ladybugs. Then you meet 1 more!", "style": "A"}, {"key": "jemzce", "text": "You have 5 chicks. Then you spot 6 more!", "style": "A"}, {"key": "evmgex", "text": "You have 5 ducklings. Then you spot 2 more!", "style": "A"}, {"key": "10nr79p", "text": "You have 5 rabbits. Then 1 wander off!", "style": "A"}, {"key": "1yf0m6o", "text": "You have 7 butterflies. Then 6 flutter away!", "style": "A"}, {"key": "h2pxd0", "text": "You have 12 sharks. Finn has 9 sharks. How many more do you have?", "style": "A"}, {"key": "g16yqd", "text": "You have 4 squirrels. Then you spot 3 more!", "style": "A"}, {"key": "11mlmoo", "text": "You have 8 bees. Then 3 flutter away!", "style": "A"}, {"key": "nnclzt", "text": "You have 8 turtles. Then 4 swim away!", "style": "A"}, {"key": "1lrw56n", "text": "You have 5 lambs. Then you spot 3 more!", "style": "A"}, {"key": "h41f35", "text": "You have 13 ladybugs. Then 6 flutter away!", "style": "A"}, {"key": "1cua71l", "text": "You have 12 chicks. Pat has 2 chicks. How many more do you have?", "style": "A"}, {"key": "cl2bq2", "text": "You have 5 ducklings. Then 1 wander off!", "style": "A"}, {"key": "1553n1t", "text": "You have 12 rabbits. Then 9 wander off!", "style": "A"}, {"key": "1exx82a", "text": "You have 5 butterflies. Bo has 1 butterfly. How many more do you have?", "style": "A"}, {"key": "97digi", "text": "You have 7 sharks. Then 5 swim away!", "style": "A"}, {"key": "13z2mz1", "text": "You have 7 bees. Then you meet 4 more!", "style": "A"}, {"key": "1clulwu", "text": "You have 11 lambs. Then 10 wander off!", "style": "A"}, {"key": "9lro9", "text": "You have 5 ladybugs. Bo has 4 ladybugs. How many more do you have?", "style": "A"}, {"key": "1h3zozw", "text": "You have 4 chicks. Then you spot 5 more!", "style": "A"}, {"key": "e252j5", "text": "You have 1 duckling. Then you spot 10 more!", "style": "A"}, {"key": "o21zn5", "text": "You have 14 rabbits. Then 7 wander off!", "style": "A"}, {"key": "2mg4be", "text": "You have 7 squirrels. Pat has 3 squirrels. How many more do you have?", "style": "A"}, {"key": "18lkeex", "text": "You have 3 bees. Then 1 flutter away!", "style": "A"}, {"key": "1ugtt0n", "text": "You have 13 turtles. Then 6 swim away!", "style": "A"}, {"key": "rqmaqg", "text": "You have 1 lamb. Then you spot 1 more!", "style": "A"}, {"key": "1preosi", "text": "You have 4 ladybugs. Then you meet 4 more!", "style": "A"}, {"key": "4mb4fs", "text": "You have 10 chicks. Then you spot 2 more!", "style": "A"}, {"key": "5evd9d", "text": "You have 10 ducklings. Pat has 2 ducklings. How many more do you have?", "style": "A"}, {"key": "t0iyvc", "text": "You have 4 rabbits. Then you spot 1 more!", "style": "A"}, {"key": "1a6rqet", "text": "You have 10 butterflies. Then 9 flutter away!", "style": "A"}, {"key": "1e470i6", "text": "You have 14 sharks. Then 12 swim away!", "style": "A"}, {"key": "1gn8s73", "text": "You have 4 squirrels. Then you spot 1 more!", "style": "A"}, {"key": "4ip6rt", "text": "You have 11 bees. Then 2 flutter away!", "style": "A"}, {"key": "1is22dj", "text": "You have 7 turtles. Then 5 swim away!", "style": "A"}, {"key": "1k8r49g", "text": "You have 4 lambs. Then you spot 1 more!", "style": "A"}, {"key": "16hj6gy", "text": "You have 13 ladybugs. Then 10 flutter away!", "style": "A"}, {"key": "1lk46kj", "text": "You have 5 chicks. Then you spot 9 more!", "style": "A"}, {"key": "emfoen", "text": "You have 5 ducklings. Then you spot 4 more!", "style": "A"}, {"key": "1up72gr", "text": "You have 10 rabbits. Then 1 wander off!", "style": "A"}, {"key": "1toc2tt", "text": "You have 6 butterflies. Then 4 flutter away!", "style": "A"}, {"key": "1al7ezf", "text": "You have 1 shark. Then you meet 6 more!", "style": "A"}, {"key": "1b65w4t", "text": "You have 12 bees. Then 7 flutter away!", "style": "A"}, {"key": "kro5rr", "text": "You have 6 turtles. Then you meet 1 more!", "style": "A"}, {"key": "18ezp3g", "text": "You have 5 lambs. Then 2 wander off!", "style": "A"}, {"key": "1izm4ar", "text": "You have 12 ladybugs. Then 3 flutter away!", "style": "A"}, {"key": "99shk7", "text": "You have 5 chicks. Then 1 wander off!", "style": "A"}, {"key": "xzvybs", "text": "You have 7 ducklings. Then 1 wander off!", "style": "A"}, {"key": "xzulf3", "text": "You have 10 rabbits. Pat has 6 rabbits. How many more do you have?", "style": "A"}, {"key": "1bwc5ge", "text": "You have 9 butterflies. Then 2 flutter away!", "style": "A"}]
todo = [r for r in LINES if not (REPO / 'public/audio' / VOICE / f"{r['key']}.mp3").exists()]
json.dump(todo, open(WORK / 'todo.json', 'w'))
print(len(todo), 'lines to render')
assert 0 < len(todo) <= 1500, 'nothing to render — every line already has a clip on main'

# %%
# Chatterbox pins torch 2.6, which breaks Kaggle's own torchvision — so it gets its own venv (uv: Kaggle's python has no ensurepip).
VENV = WORK / 'venv'; PY = VENV / 'bin' / 'python'; READY = VENV / '.ready'
if not READY.exists():
    shutil.rmtree(VENV, ignore_errors=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'uv'], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'venv', str(VENV), '--python', sys.executable], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'pip', 'install', '--python', str(PY), 'setuptools<81', 'chatterbox-tts', 'imageio-ffmpeg'], check=True)
    READY.touch()
print(subprocess.run([str(PY), '-c', "import torch; print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NONE — set the accelerator')"], capture_output=True, text=True).stdout)

# %%
OUT = WORK / 'out' / VOICE
cmd = [str(PY), str(REPO / 'scripts/chatterbox-render.py'), '--voice', VOICE, '--corpus', str(WORK / 'todo.json'), '--out', str(OUT)]
proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in proc.stdout:
    if 'it/s]' in line or not line.strip(): continue   # drop the progress bars
    print(line.rstrip()[:160], flush=True)
print('exit code', proc.wait())

# %%
keys = {r['key'] for r in todo}
clips = sorted(c for c in OUT.glob('*.mp3') if c.stem in keys)
missing = [k for k in keys if not (OUT / f'{k}.mp3').exists()]
stage = WORK / 'stage'; shutil.rmtree(stage, ignore_errors=True); (stage / VOICE).mkdir(parents=True)
for c in clips: shutil.copy2(c, stage / VOICE / c.name)
shutil.make_archive(str(WORK / 'radlic-voice-josh-chapters-g1-1'), 'zip', stage)
print(f'{len(clips)} of {len(todo)} clips in radlic-voice-josh-chapters-g1-1.zip' + (f' — MISSING {len(missing)}: {missing}' if missing else ' — complete'))
