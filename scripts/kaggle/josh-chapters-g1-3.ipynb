# %% [markdown]
# # Radlic voice — Grade 1 (part 3 of 3) story chapters in Josh
#
# Renders every line the Grade 1 (part 3 of 3) story chapters can say that has no clip yet — **1170 lines, 45,431 characters** (the lines are
# written into this notebook). Style A (Chatterbox Turbo) for all of them. Rules: `docs/new-flow/voice.md`.
#
# **Before Run All:** Settings → Accelerator → **GPU T4 x2** (or P100), Internet **On**. At the end, download
# `radlic-voice-josh-chapters-g1-3.zip` from the Output panel and hand it back. If the session stops early, Run All
# again in the same session: lines already rendered are skipped.

# %%
import os, sys, subprocess, pathlib, shutil, json
VOICE = 'nzFihrBIvB34imQBuxub'   # Josh
WORK = pathlib.Path('/kaggle/working' if os.path.isdir('/kaggle/working') else '/content')
REPO = WORK / 'learn-main'
if not REPO.exists():
    subprocess.run(['git', 'clone', '--depth', '1', '--branch', 'main', 'https://github.com/RadlorInc/learn.git', str(REPO)], check=True)
LINES = [{"key": "1xfsk4m", "text": "That is fifty-eight, not eighty-five. The tens side is on the left — look which one holds eight.", "style": "A"}, {"key": "qjkhg8", "text": "That is thirty-eight, not eighty-three. The tens side is on the left — look which one holds eight.", "style": "A"}, {"key": "1ajs3xb", "text": "That is seventy-eight, not eighty-seven. The tens side is on the left — look which one holds eight.", "style": "A"}, {"key": "8lfqif", "text": "That is sixty-seven, not seventy-six. The tens side is on the left — look which one holds seven.", "style": "A"}, {"key": "1qvml1y", "text": "That is nineteen, not ninety-one. The tens side is on the left — look which one holds nine.", "style": "A"}, {"key": "9im24e", "text": "That is thirty-seven, not seventy-three. The tens side is on the left — look which one holds seven.", "style": "A"}, {"key": "1bwpyi4", "text": "Not yet — that is zero. Count the tens, then the ones.", "style": "A"}, {"key": "1wvr8nc", "text": "Not yet — that is one. Count the tens, then the ones.", "style": "A"}, {"key": "ugpgcm", "text": "Not yet — that is two. Count the tens, then the ones.", "style": "A"}, {"key": "1ietd8", "text": "Not yet — that is three. Count the tens, then the ones.", "style": "A"}, {"key": "qgn66q", "text": "Not yet — that is four. Count the tens, then the ones.", "style": "A"}, {"key": "vi3nz6", "text": "Not yet — that is five. Count the tens, then the ones.", "style": "A"}, {"key": "1cf2zgk", "text": "Not yet — that is six. Count the tens, then the ones.", "style": "A"}, {"key": "r5cm4p", "text": "Not yet — that is seven. Count the tens, then the ones.", "style": "A"}, {"key": "kpa9uv", "text": "Not yet — that is eight. Count the tens, then the ones.", "style": "A"}, {"key": "1so6gci", "text": "Not yet — that is nine. Count the tens, then the ones.", "style": "A"}, {"key": "3znzob", "text": "Not yet — that is ten. Count the tens, then the ones.", "style": "A"}, {"key": "b1rwmf", "text": "Not yet — that is eleven. Count the tens, then the ones.", "style": "A"}, {"key": "6k30dn", "text": "Not yet — that is twelve. Count the tens, then the ones.", "style": "A"}, {"key": "1y2ja5t", "text": "Not yet — that is thirteen. Count the tens, then the ones.", "style": "A"}, {"key": "1ar608u", "text": "Not yet — that is fourteen. Count the tens, then the ones.", "style": "A"}, {"key": "updr45", "text": "Not yet — that is fifteen. Count the tens, then the ones.", "style": "A"}, {"key": "1kdgues", "text": "Not yet — that is sixteen. Count the tens, then the ones.", "style": "A"}, {"key": "1tu7qn5", "text": "Not yet — that is seventeen. Count the tens, then the ones.", "style": "A"}, {"key": "70ta9z", "text": "Not yet — that is eighteen. Count the tens, then the ones.", "style": "A"}, {"key": "16k1rim", "text": "Not yet — that is nineteen. Count the tens, then the ones.", "style": "A"}, {"key": "12y72en", "text": "Not yet — that is twenty. Count the tens, then the ones.", "style": "A"}, {"key": "1jnsa8q", "text": "Not yet — that is twenty-one. Count the tens, then the ones.", "style": "A"}, {"key": "1kgdl80", "text": "Not yet — that is twenty-two. Count the tens, then the ones.", "style": "A"}, {"key": "18be916", "text": "Not yet — that is twenty-three. Count the tens, then the ones.", "style": "A"}, {"key": "km42k4", "text": "Not yet — that is twenty-four. Count the tens, then the ones.", "style": "A"}, {"key": "tgi4k8", "text": "Not yet — that is twenty-five. Count the tens, then the ones.", "style": "A"}, {"key": "1fhusui", "text": "Not yet — that is twenty-six. Count the tens, then the ones.", "style": "A"}, {"key": "1bup887", "text": "Not yet — that is twenty-seven. Count the tens, then the ones.", "style": "A"}, {"key": "fnb9rp", "text": "Not yet — that is twenty-eight. Count the tens, then the ones.", "style": "A"}, {"key": "12grcug", "text": "Not yet — that is twenty-nine. Count the tens, then the ones.", "style": "A"}, {"key": "16xcpwi", "text": "Not yet — that is thirty. Count the tens, then the ones.", "style": "A"}, {"key": "1of3yyr", "text": "Not yet — that is thirty-one. Count the tens, then the ones.", "style": "A"}, {"key": "1hxd7j1", "text": "Not yet — that is thirty-two. Count the tens, then the ones.", "style": "A"}, {"key": "1o3jkzr", "text": "Not yet — that is thirty-three. Count the tens, then the ones.", "style": "A"}, {"key": "1ye4dpn", "text": "Not yet — that is thirty-four. Count the tens, then the ones.", "style": "A"}, {"key": "16t5k4v", "text": "Not yet — that is thirty-five. Count the tens, then the ones.", "style": "A"}, {"key": "193136v", "text": "Not yet — that is thirty-six. Count the tens, then the ones.", "style": "A"}, {"key": "1wo8lru", "text": "Not yet — that is thirty-seven. Count the tens, then the ones.", "style": "A"}, {"key": "x0cac", "text": "Not yet — that is thirty-eight. Count the tens, then the ones.", "style": "A"}, {"key": "1c2scnj", "text": "Not yet — that is thirty-nine. Count the tens, then the ones.", "style": "A"}, {"key": "1c46zyg", "text": "Not yet — that is forty. Count the tens, then the ones.", "style": "A"}, {"key": "1kbxsp", "text": "Not yet — that is forty-one. Count the tens, then the ones.", "style": "A"}, {"key": "o2rv", "text": "Not yet — that is forty-two. Count the tens, then the ones.", "style": "A"}, {"key": "h7z58h", "text": "Not yet — that is forty-three. Count the tens, then the ones.", "style": "A"}, {"key": "wcltih", "text": "Not yet — that is forty-four. Count the tens, then the ones.", "style": "A"}, {"key": "1h9wik1", "text": "Not yet — that is forty-five. Count the tens, then the ones.", "style": "A"}, {"key": "1kaxzux", "text": "Not yet — that is forty-six. Count the tens, then the ones.", "style": "A"}, {"key": "11rg0lg", "text": "Not yet — that is forty-seven. Count the tens, then the ones.", "style": "A"}, {"key": "pzg86", "text": "Not yet — that is forty-eight. Count the tens, then the ones.", "style": "A"}, {"key": "178283l", "text": "Not yet — that is forty-nine. Count the tens, then the ones.", "style": "A"}, {"key": "10qalou", "text": "Not yet — that is fifty. Count the tens, then the ones.", "style": "A"}, {"key": "1m3qj8f", "text": "Not yet — that is fifty-one. Count the tens, then the ones.", "style": "A"}, {"key": "7kedh5", "text": "Not yet — that is fifty-two. Count the tens, then the ones.", "style": "A"}, {"key": "1tn6psj", "text": "Not yet — that is fifty-three. Count the tens, then the ones.", "style": "A"}, {"key": "pvnmv3", "text": "Not yet — that is fifty-four. Count the tens, then the ones.", "style": "A"}, {"key": "gczqhv", "text": "Not yet — that is fifty-five. Count the tens, then the ones.", "style": "A"}, {"key": "83u4bv", "text": "Not yet — that is fifty-six. Count the tens, then the ones.", "style": "A"}, {"key": "15ippm6", "text": "Not yet — that is fifty-seven. Count the tens, then the ones.", "style": "A"}, {"key": "6ur940", "text": "Not yet — that is fifty-eight. Count the tens, then the ones.", "style": "A"}, {"key": "1exx3f7", "text": "Not yet — that is fifty-nine. Count the tens, then the ones.", "style": "A"}, {"key": "132znsz", "text": "Not yet — that is sixty. Count the tens, then the ones.", "style": "A"}, {"key": "1duj60e", "text": "Not yet — that is sixty-one. Count the tens, then the ones.", "style": "A"}, {"key": "ckvxlg", "text": "Not yet — that is sixty-two. Count the tens, then the ones.", "style": "A"}, {"key": "1a77rxa", "text": "Not yet — that is sixty-three. Count the tens, then the ones.", "style": "A"}, {"key": "17pld0w", "text": "Not yet — that is sixty-four. Count the tens, then the ones.", "style": "A"}, {"key": "1hz7h9w", "text": "Not yet — that is sixty-five. Count the tens, then the ones.", "style": "A"}, {"key": "17vxwqu", "text": "Not yet — that is sixty-six. Count the tens, then the ones.", "style": "A"}, {"key": "1wxiklf", "text": "Not yet — that is sixty-seven. Count the tens, then the ones.", "style": "A"}, {"key": "6x7jqh", "text": "Not yet — that is sixty-eight. Count the tens, then the ones.", "style": "A"}, {"key": "itgu0k", "text": "Not yet — that is sixty-nine. Count the tens, then the ones.", "style": "A"}, {"key": "1vx31wy", "text": "Not yet — that is seventy. Count the tens, then the ones.", "style": "A"}, {"key": "q4wsyb", "text": "Not yet — that is seventy-one. Count the tens, then the ones.", "style": "A"}, {"key": "k5rrsd", "text": "Not yet — that is seventy-two. Count the tens, then the ones.", "style": "A"}, {"key": "15l7lav", "text": "Not yet — that is seventy-three. Count the tens, then the ones.", "style": "A"}, {"key": "1dwv82j", "text": "Not yet — that is seventy-four. Count the tens, then the ones.", "style": "A"}, {"key": "9s36wv", "text": "Not yet — that is seventy-five. Count the tens, then the ones.", "style": "A"}, {"key": "1ujdo3b", "text": "Not yet — that is seventy-six. Count the tens, then the ones.", "style": "A"}, {"key": "12xy4lm", "text": "Not yet — that is seventy-seven. Count the tens, then the ones.", "style": "A"}, {"key": "wvhe3o", "text": "Not yet — that is seventy-eight. Count the tens, then the ones.", "style": "A"}, {"key": "1tubou7", "text": "Not yet — that is seventy-nine. Count the tens, then the ones.", "style": "A"}, {"key": "se8vgk", "text": "Not yet — that is eighty. Count the tens, then the ones.", "style": "A"}, {"key": "lefd5h", "text": "Not yet — that is eighty-one. Count the tens, then the ones.", "style": "A"}, {"key": "a0cekn", "text": "Not yet — that is eighty-two. Count the tens, then the ones.", "style": "A"}, {"key": "1433glp", "text": "Not yet — that is eighty-three. Count the tens, then the ones.", "style": "A"}, {"key": "jedwt9", "text": "Not yet — that is eighty-four. Count the tens, then the ones.", "style": "A"}, {"key": "njpnol", "text": "Not yet — that is eighty-five. Count the tens, then the ones.", "style": "A"}, {"key": "9o5b7x", "text": "Not yet — that is eighty-six. Count the tens, then the ones.", "style": "A"}, {"key": "1xpqtk8", "text": "Not yet — that is eighty-seven. Count the tens, then the ones.", "style": "A"}, {"key": "1n6gj7m", "text": "Not yet — that is eighty-eight. Count the tens, then the ones.", "style": "A"}, {"key": "1kaevkl", "text": "Not yet — that is eighty-nine. Count the tens, then the ones.", "style": "A"}, {"key": "185iq6h", "text": "Not yet — that is ninety. Count the tens, then the ones.", "style": "A"}, {"key": "k9l1vg", "text": "Not yet — that is ninety-one. Count the tens, then the ones.", "style": "A"}, {"key": "1n72zt6", "text": "Not yet — that is ninety-two. Count the tens, then the ones.", "style": "A"}, {"key": "16y5680", "text": "Not yet — that is ninety-three. Count the tens, then the ones.", "style": "A"}, {"key": "1igp4wu", "text": "Not yet — that is ninety-four. Count the tens, then the ones.", "style": "A"}, {"key": "1in9jm6", "text": "Not yet — that is ninety-five. Count the tens, then the ones.", "style": "A"}, {"key": "a2a3wg", "text": "Not yet — that is ninety-six. Count the tens, then the ones.", "style": "A"}, {"key": "12s2ob9", "text": "Not yet — that is ninety-seven. Count the tens, then the ones.", "style": "A"}, {"key": "8c5ux7", "text": "Not yet — that is ninety-eight. Count the tens, then the ones.", "style": "A"}, {"key": "1859kem", "text": "Not yet — that is ninety-nine. Count the tens, then the ones.", "style": "A"}, {"key": "1r6ksjv", "text": "Three bunnies are playing.", "style": "A"}, {"key": "1a5xti", "text": "That makes 5. Tap the 5!", "style": "A"}, {"key": "1vowxnr", "text": "Three fish are playing.", "style": "A"}, {"key": "n4buk6", "text": "That makes 7. Tap the 7!", "style": "A"}, {"key": "4yherw", "text": "Five butterflies are playing.", "style": "A"}, {"key": "4x2xei", "text": "Eight.", "style": "A"}, {"key": "6c6lmg", "text": "That makes 8. Tap the 8!", "style": "A"}, {"key": "vpzp0t", "text": "Two squirrels are playing.", "style": "A"}, {"key": "1w1z4tu", "text": "Three turtles are playing.", "style": "A"}, {"key": "15pivno", "text": "Three ladybugs are playing.", "style": "A"}, {"key": "1mxf6dl", "text": "Two ants are playing.", "style": "A"}, {"key": "16zr8o", "text": "Two crabs are playing.", "style": "A"}, {"key": "uhheeg", "text": "Three fireflies are playing.", "style": "A"}, {"key": "1p1ddsc", "text": "That makes 6. Tap the 6!", "style": "A"}, {"key": "1idp92n", "text": "Three sharks are playing.", "style": "A"}, {"key": "1eevmfd", "text": "Four bunnies are playing.", "style": "A"}, {"key": "yxounl", "text": "Four fish are playing.", "style": "A"}, {"key": "6gjynm", "text": "One butterflies are playing.", "style": "A"}, {"key": "1q4rcv8", "text": "That makes 2. Tap the 2!", "style": "A"}, {"key": "83ab5f", "text": "Three squirrels are playing.", "style": "A"}, {"key": "v3oha3", "text": "Three ants are playing.", "style": "A"}, {"key": "dt8uo4", "text": "Four crabs are playing.", "style": "A"}, {"key": "658ww2", "text": "Two fireflies are playing.", "style": "A"}, {"key": "x8mstd", "text": "Four sharks are playing.", "style": "A"}, {"key": "15fb14s", "text": "Four butterflies are playing.", "style": "A"}, {"key": "1csfp35", "text": "Five squirrels are playing.", "style": "A"}, {"key": "1yti24h", "text": "Nine.", "style": "A"}, {"key": "cttli", "text": "That makes 9. Tap the 9!", "style": "A"}, {"key": "wjdvjy", "text": "Two ladybugs are playing.", "style": "A"}, {"key": "g8zrul", "text": "Four ants are playing.", "style": "A"}, {"key": "1ekbz87", "text": "One bunnies are playing.", "style": "A"}, {"key": "1fugpt3", "text": "One squirrels are playing.", "style": "A"}, {"key": "m22ixi", "text": "Four fireflies are playing.", "style": "A"}, {"key": "1nyy1lf", "text": "One sharks are playing.", "style": "A"}, {"key": "pyu9wf", "text": "Six fish are playing.", "style": "A"}, {"key": "mwln0o", "text": "Two butterflies are playing.", "style": "A"}, {"key": "1fhlsay", "text": "Six turtles are playing.", "style": "A"}, {"key": "10p0isu", "text": "Ten.", "style": "A"}, {"key": "qrhb68", "text": "That makes 10. Tap the 10!", "style": "A"}, {"key": "1kokgqg", "text": "One ladybugs are playing.", "style": "A"}, {"key": "kht4ct", "text": "Two sharks are playing.", "style": "A"}, {"key": "1qqmw0z", "text": "One fish are playing.", "style": "A"}, {"key": "kgkij2", "text": "Three butterflies are playing.", "style": "A"}, {"key": "1r8bi9n", "text": "Six squirrels are playing.", "style": "A"}, {"key": "yffplo", "text": "Two turtles are playing.", "style": "A"}, {"key": "q6m9jw", "text": "Six ladybugs are playing.", "style": "A"}, {"key": "fafw3k", "text": "Six fireflies are playing.", "style": "A"}, {"key": "152huox", "text": "Five fish are playing.", "style": "A"}, {"key": "1mvtopd", "text": "Four squirrels are playing.", "style": "A"}, {"key": "1405yw0", "text": "Five turtles are playing.", "style": "A"}, {"key": "hblg1y", "text": "Three crabs are playing.", "style": "A"}, {"key": "l3dyvh", "text": "Five ants are playing.", "style": "A"}, {"key": "1fftb69", "text": "Five sharks are playing.", "style": "A"}, {"key": "66rpdy", "text": "Five fireflies are playing.", "style": "A"}, {"key": "rbl4fb", "text": "Six sharks are playing.", "style": "A"}, {"key": "5ks18v", "text": "Ten butterflies are playing.", "style": "A"}, {"key": "1rerq4m", "text": "That makes 1. Tap the 1!", "style": "A"}, {"key": "1bqy0i", "text": "Nine ladybugs are playing.", "style": "A"}, {"key": "9202jy", "text": "Six crabs are playing.", "style": "A"}, {"key": "i1yyo1", "text": "Ten fireflies are playing.", "style": "A"}, {"key": "4hk1r0", "text": "Ten fish are playing.", "style": "A"}, {"key": "z5dga3", "text": "Eight turtles are playing.", "style": "A"}, {"key": "1pyiprm", "text": "Five ladybugs are playing.", "style": "A"}, {"key": "1ed76zn", "text": "Six ants are playing.", "style": "A"}, {"key": "8krjw4", "text": "Nine crabs are playing.", "style": "A"}, {"key": "1ii5fjk", "text": "Eight sharks are playing.", "style": "A"}, {"key": "1a3wamy", "text": "Ten bunnies are playing.", "style": "A"}, {"key": "1trsop2", "text": "Eight squirrels are playing.", "style": "A"}, {"key": "1mjas5s", "text": "Four turtles are playing.", "style": "A"}, {"key": "17mnvg8", "text": "Ten ants are playing.", "style": "A"}, {"key": "13me65w", "text": "Five crabs are playing.", "style": "A"}, {"key": "1jpvcpb", "text": "Seven fireflies are playing.", "style": "A"}, {"key": "se429o", "text": "Ten sharks are playing.", "style": "A"}, {"key": "1hfykg5", "text": "Seven turtles are playing.", "style": "A"}, {"key": "1250x7f", "text": "Eight ladybugs are playing.", "style": "A"}, {"key": "noz49j", "text": "Eight crabs are playing.", "style": "A"}, {"key": "1be0clx", "text": "Eight fireflies are playing.", "style": "A"}, {"key": "lcaun4", "text": "Seven bunnies are playing.", "style": "A"}, {"key": "19f6sbs", "text": "Eight fish are playing.", "style": "A"}, {"key": "ecvezk", "text": "Nine turtles are playing.", "style": "A"}, {"key": "1ecj75u", "text": "Four ladybugs are playing.", "style": "A"}, {"key": "1krrxj0", "text": "Eight ants are playing.", "style": "A"}, {"key": "3yhwse", "text": "Seven sharks are playing.", "style": "A"}, {"key": "8xfp89", "text": "Nine bunnies are playing.", "style": "A"}, {"key": "1rmosz", "text": "Eight butterflies are playing.", "style": "A"}, {"key": "knq4ct", "text": "Nine ants are playing.", "style": "A"}, {"key": "11np65y", "text": "Seven fish are playing.", "style": "A"}, {"key": "kp7pos", "text": "Nine butterflies are playing.", "style": "A"}, {"key": "12kal86", "text": "Eight bunnies are playing.", "style": "A"}, {"key": "1ohljs1", "text": "Nine fish are playing.", "style": "A"}, {"key": "lt0v9z", "text": "Ten turtles are playing.", "style": "A"}, {"key": "jq6vsl", "text": "Seven ladybugs are playing.", "style": "A"}, {"key": "1j27ma9", "text": "Nine sharks are playing.", "style": "A"}, {"key": "cogkw7", "text": "Ten ladybugs are playing.", "style": "A"}, {"key": "ixa7sm", "text": "One turtles are playing.", "style": "A"}, {"key": "shzp67", "text": "One ants are playing.", "style": "A"}, {"key": "bv9f9u", "text": "One crabs are playing.", "style": "A"}, {"key": "1e64at8", "text": "One fireflies are playing.", "style": "A"}, {"key": "ep6jut", "text": "Two fish are playing.", "style": "A"}, {"key": "q1ig83", "text": "Six bunnies are playing.", "style": "A"}, {"key": "15vekie", "text": "Six butterflies are playing.", "style": "A"}, {"key": "5xnknh", "text": "Seven butterflies are playing.", "style": "A"}, {"key": "1i6qvy0", "text": "Seven squirrels are playing.", "style": "A"}, {"key": "1wmltky", "text": "Seven ants are playing.", "style": "A"}, {"key": "1luxrsx", "text": "Seven crabs are playing.", "style": "A"}, {"key": "qsm269", "text": "Nine squirrels are playing.", "style": "A"}, {"key": "hpyneu", "text": "Nine fireflies are playing.", "style": "A"}, {"key": "1lw32wy", "text": "Ten squirrels are playing.", "style": "A"}, {"key": "sle2vv", "text": "Ten crabs are playing.", "style": "A"}, {"key": "gfom9", "text": "fourteen", "style": "A"}, {"key": "1ivxxnv", "text": "sixteen", "style": "A"}, {"key": "19pwxnq", "text": "seventeen", "style": "A"}, {"key": "19x2uj4", "text": "eighteen", "style": "A"}, {"key": "1qqnn01", "text": "nineteen", "style": "A"}, {"key": "1qh5wlu", "text": "1 ten and 9 ones make nineteen. That is nineteen!", "style": "A"}, {"key": "111mb9r", "text": "forty", "style": "A"}, {"key": "9gl5ta", "text": "forty-one", "style": "A"}, {"key": "1tbskok", "text": "forty-two", "style": "A"}, {"key": "vavcjq", "text": "forty-three", "style": "A"}, {"key": "867ozi", "text": "forty-four", "style": "A"}, {"key": "6oxtcj", "text": "4 tens and 4 ones make forty-four. That is forty-four!", "style": "A"}, {"key": "1gln1sx", "text": "fifty", "style": "A"}, {"key": "r8umqk", "text": "sixty", "style": "A"}, {"key": "wwolmp", "text": "sixty-one", "style": "A"}, {"key": "1x3k92j", "text": "sixty-two", "style": "A"}, {"key": "16ozu75", "text": "sixty-three", "style": "A"}, {"key": "1vmk7jr", "text": "sixty-four", "style": "A"}, {"key": "12em56j", "text": "sixty-five", "style": "A"}, {"key": "3vtiqh", "text": "sixty-six", "style": "A"}, {"key": "1rmhhks", "text": "sixty-seven", "style": "A"}, {"key": "1p5hu8e", "text": "sixty-eight", "style": "A"}, {"key": "kboudx", "text": "6 tens and 8 ones make sixty-eight. That is sixty-eight!", "style": "A"}, {"key": "1nrhygd", "text": "1 ten and 4 ones make fourteen. That is fourteen!", "style": "A"}, {"key": "9lr4m0", "text": "fifty-one", "style": "A"}, {"key": "gdrt5q", "text": "fifty-two", "style": "A"}, {"key": "1x9lwak", "text": "fifty-three", "style": "A"}, {"key": "10u3r57", "text": "5 tens and 3 ones make fifty-three. That is fifty-three!", "style": "A"}, {"key": "pqlco", "text": "fifty-four", "style": "A"}, {"key": "14usnss", "text": "fifty-five", "style": "A"}, {"key": "jk9rb8", "text": "fifty-six", "style": "A"}, {"key": "1qqia2p", "text": "fifty-seven", "style": "A"}, {"key": "1pneo5z", "text": "fifty-eight", "style": "A"}, {"key": "1b95vzk", "text": "5 tens and 8 ones make fifty-eight. That is fifty-eight!", "style": "A"}, {"key": "9x6c8k", "text": "1 ten and 7 ones make seventeen. That is seventeen!", "style": "A"}, {"key": "j9h4p1", "text": "6 tens make sixty. That is sixty!", "style": "A"}, {"key": "14bgx51", "text": "seventy", "style": "A"}, {"key": "m0rr57", "text": "eighty", "style": "A"}, {"key": "1htlq9q", "text": "ninety", "style": "A"}, {"key": "1n8bi3n", "text": "ninety-one", "style": "A"}, {"key": "1b0c6kt", "text": "ninety-two", "style": "A"}, {"key": "10d67dj", "text": "ninety-three", "style": "A"}, {"key": "ws67wx", "text": "ninety-four", "style": "A"}, {"key": "sj1f4x", "text": "ninety-five", "style": "A"}, {"key": "neddjb", "text": "ninety-six", "style": "A"}, {"key": "1bmy3ai", "text": "ninety-seven", "style": "A"}, {"key": "vabpkn", "text": "9 tens and 7 ones make ninety-seven. That is ninety-seven!", "style": "A"}, {"key": "6m7wox", "text": "2 tens make twenty. That is twenty!", "style": "A"}, {"key": "mkhtki", "text": "5 tens and 4 ones make fifty-four. That is fifty-four!", "style": "A"}, {"key": "mko3tx", "text": "5 tens and 7 ones make fifty-seven. That is fifty-seven!", "style": "A"}, {"key": "tjt75t", "text": "1 ten and 6 ones make sixteen. That is sixteen!", "style": "A"}, {"key": "wowrzg", "text": "fifty-nine", "style": "A"}, {"key": "3vg4zt", "text": "5 tens and 9 ones make fifty-nine. That is fifty-nine!", "style": "A"}, {"key": "sz7c7z", "text": "1 ten and 1 one make eleven. That is eleven!", "style": "A"}, {"key": "hnv46k", "text": "5 tens and 6 ones make fifty-six. That is fifty-six!", "style": "A"}, {"key": "1n6lotp", "text": "1 ten make ten. That is ten!", "style": "A"}, {"key": "maqpnw", "text": "seventy-one", "style": "A"}, {"key": "1c7sysy", "text": "seventy-two", "style": "A"}, {"key": "1r7rcva", "text": "7 tens and 2 ones make seventy-two. That is seventy-two!", "style": "A"}, {"key": "10iyqdm", "text": "eighty-one", "style": "A"}, {"key": "4v099l", "text": "8 tens and 1 one make eighty-one. That is eighty-one!", "style": "A"}, {"key": "1ll09ao", "text": "eighty-two", "style": "A"}, {"key": "1xbr14i", "text": "eighty-three", "style": "A"}, {"key": "2kbo2", "text": "eighty-four", "style": "A"}, {"key": "1xlfnlm", "text": "eighty-five", "style": "A"}, {"key": "1a2z32a", "text": "eighty-six", "style": "A"}, {"key": "nalakv", "text": "eighty-seven", "style": "A"}, {"key": "1bxwkcl", "text": "eighty-eight", "style": "A"}, {"key": "kaa2wf", "text": "8 tens and 8 ones make eighty-eight. That is eighty-eight!", "style": "A"}, {"key": "wyqxuu", "text": "forty-five", "style": "A"}, {"key": "kyu8j0", "text": "4 tens and 5 ones make forty-five. That is forty-five!", "style": "A"}, {"key": "1agbnq6", "text": "4 tens and 3 ones make forty-three. That is forty-three!", "style": "A"}, {"key": "18afphv", "text": "2 tens and 1 one make twenty-one. That is twenty-one!", "style": "A"}, {"key": "1g78akn", "text": "9 tens and 5 ones make ninety-five. That is ninety-five!", "style": "A"}, {"key": "zvqc1p", "text": "twenty-six", "style": "A"}, {"key": "fbfgww", "text": "twenty-seven", "style": "A"}, {"key": "6qxqfu", "text": "twenty-eight", "style": "A"}, {"key": "1ii7sq1", "text": "2 tens and 8 ones make twenty-eight. That is twenty-eight!", "style": "A"}, {"key": "2wu3vs", "text": "7 tens and 1 one make seventy-one. That is seventy-one!", "style": "A"}, {"key": "1cph2l8", "text": "thirty-one", "style": "A"}, {"key": "1aol942", "text": "thirty-two", "style": "A"}, {"key": "1yvyd1s", "text": "thirty-three", "style": "A"}, {"key": "1ujzg1w", "text": "thirty-four", "style": "A"}, {"key": "1jq9fsk", "text": "3 tens and 4 ones make thirty-four. That is thirty-four!", "style": "A"}, {"key": "lcimjo", "text": "9 tens make ninety. That is ninety!", "style": "A"}, {"key": "8fyc37", "text": "1 ten and 2 ones make twelve. That is twelve!", "style": "A"}, {"key": "9dinfs", "text": "thirty-five", "style": "A"}, {"key": "a5eaw0", "text": "thirty-six", "style": "A"}, {"key": "1ex9rf1", "text": "thirty-seven", "style": "A"}, {"key": "106o895", "text": "3 tens and 7 ones make thirty-seven. That is thirty-seven!", "style": "A"}, {"key": "iefoqy", "text": "3 tens make thirty. That is thirty!", "style": "A"}, {"key": "1jtt1k0", "text": "seventy-three", "style": "A"}, {"key": "2vz35g", "text": "seventy-four", "style": "A"}, {"key": "767xiw", "text": "seventy-five", "style": "A"}, {"key": "1ddg61j", "text": "7 tens and 5 ones make seventy-five. That is seventy-five!", "style": "A"}, {"key": "12lh50e", "text": "1 ten and 5 ones make fifteen. That is fifteen!", "style": "A"}, {"key": "1saz6xd", "text": "6 tens and 4 ones make sixty-four. That is sixty-four!", "style": "A"}, {"key": "1lhbpq0", "text": "2 tens and 5 ones make twenty-five. That is twenty-five!", "style": "A"}, {"key": "13frnid", "text": "5 tens and 5 ones make fifty-five. That is fifty-five!", "style": "A"}, {"key": "90nfjy", "text": "forty-six", "style": "A"}, {"key": "188i35l", "text": "4 tens and 6 ones make forty-six. That is forty-six!", "style": "A"}, {"key": "1ji2fms", "text": "9 tens and 4 ones make ninety-four. That is ninety-four!", "style": "A"}, {"key": "m6nsbq", "text": "5 tens make fifty. That is fifty!", "style": "A"}, {"key": "1u6drd1", "text": "4 tens and 1 one make forty-one. That is forty-one!", "style": "A"}, {"key": "1816fah", "text": "6 tens and 1 one make sixty-one. That is sixty-one!", "style": "A"}, {"key": "r67u6j", "text": "forty-seven", "style": "A"}, {"key": "sejmdl", "text": "forty-eight", "style": "A"}, {"key": "175st86", "text": "forty-nine", "style": "A"}, {"key": "1jwjpdc", "text": "4 tens and 9 ones make forty-nine. That is forty-nine!", "style": "A"}, {"key": "do4t11", "text": "8 tens and 6 ones make eighty-six. That is eighty-six!", "style": "A"}, {"key": "1e68w1y", "text": "3 tens and 6 ones make thirty-six. That is thirty-six!", "style": "A"}, {"key": "mrqckc", "text": "7 tens make seventy. That is seventy!", "style": "A"}, {"key": "n2vu4p", "text": "1 ten and 8 ones make eighteen. That is eighteen!", "style": "A"}, {"key": "crdr5i", "text": "3 tens and 2 ones make thirty-two. That is thirty-two!", "style": "A"}, {"key": "c3xwi3", "text": "one hundred", "style": "A"}, {"key": "1yntvwy", "text": "10 tens make one hundred. That is one hundred!", "style": "A"}, {"key": "1ph0i25", "text": "4 tens and 8 ones make forty-eight. That is forty-eight!", "style": "A"}, {"key": "1vrb273", "text": "3 tens and 5 ones make thirty-five. That is thirty-five!", "style": "A"}, {"key": "ldfoxd", "text": "3 tens and 3 ones make thirty-three. That is thirty-three!", "style": "A"}, {"key": "42bvax", "text": "8 tens and 2 ones make eighty-two. That is eighty-two!", "style": "A"}, {"key": "1rq73qj", "text": "thirty-eight", "style": "A"}, {"key": "114t574", "text": "3 tens and 8 ones make thirty-eight. That is thirty-eight!", "style": "A"}, {"key": "120j5pw", "text": "ninety-eight", "style": "A"}, {"key": "1k17plm", "text": "9 tens and 8 ones make ninety-eight. That is ninety-eight!", "style": "A"}, {"key": "rqqzoy", "text": "8 tens and 7 ones make eighty-seven. That is eighty-seven!", "style": "A"}, {"key": "hbpkg0", "text": "9 tens and 2 ones make ninety-two. That is ninety-two!", "style": "A"}, {"key": "knb168", "text": "seventy-six", "style": "A"}, {"key": "zxrgnx", "text": "seventy-seven", "style": "A"}, {"key": "rhhqor", "text": "seventy-eight", "style": "A"}, {"key": "6i1ly0", "text": "seventy-nine", "style": "A"}, {"key": "13w3pv", "text": "7 tens and 9 ones make seventy-nine. That is seventy-nine!", "style": "A"}, {"key": "nvhc90", "text": "3 tens and 1 one make thirty-one. That is thirty-one!", "style": "A"}, {"key": "zmtxpq", "text": "6 tens and 3 ones make sixty-three. That is sixty-three!", "style": "A"}, {"key": "17qfb2n", "text": "twenty-nine", "style": "A"}, {"key": "tn7v2c", "text": "2 tens and 9 ones make twenty-nine. That is twenty-nine!", "style": "A"}, {"key": "hdux18", "text": "6 tens and 7 ones make sixty-seven. That is sixty-seven!", "style": "A"}, {"key": "1l15vls", "text": "5 tens and 2 ones make fifty-two. That is fifty-two!", "style": "A"}, {"key": "whw4og", "text": "9 tens and 6 ones make ninety-six. That is ninety-six!", "style": "A"}, {"key": "l44vb4", "text": "4 tens and 7 ones make forty-seven. That is forty-seven!", "style": "A"}, {"key": "1oizomm", "text": "7 tens and 8 ones make seventy-eight. That is seventy-eight!", "style": "A"}, {"key": "1ui7al7", "text": "sixty-nine", "style": "A"}, {"key": "1vx0szu", "text": "6 tens and 9 ones make sixty-nine. That is sixty-nine!", "style": "A"}, {"key": "10o2lj0", "text": "7 tens and 4 ones make seventy-four. That is seventy-four!", "style": "A"}, {"key": "o9zje0", "text": "thirty-nine", "style": "A"}, {"key": "39bp4j", "text": "3 tens and 9 ones make thirty-nine. That is thirty-nine!", "style": "A"}, {"key": "exa5fj", "text": "2 tens and 2 ones make twenty-two. That is twenty-two!", "style": "A"}, {"key": "1wqoj9i", "text": "7 tens and 6 ones make seventy-six. That is seventy-six!", "style": "A"}, {"key": "1h387n7", "text": "9 tens and 3 ones make ninety-three. That is ninety-three!", "style": "A"}, {"key": "amz9re", "text": "eighty-nine", "style": "A"}, {"key": "1l97js8", "text": "8 tens and 9 ones make eighty-nine. That is eighty-nine!", "style": "A"}, {"key": "1f0xvg8", "text": "2 tens and 3 ones make twenty-three. That is twenty-three!", "style": "A"}, {"key": "riz7zg", "text": "8 tens and 5 ones make eighty-five. That is eighty-five!", "style": "A"}, {"key": "amzzv9", "text": "4 tens make forty. That is forty!", "style": "A"}, {"key": "71x796", "text": "9 tens and 1 one make ninety-one. That is ninety-one!", "style": "A"}, {"key": "16thax2", "text": "6 tens and 5 ones make sixty-five. That is sixty-five!", "style": "A"}, {"key": "1dnpyj6", "text": "5 tens and 1 one make fifty-one. That is fifty-one!", "style": "A"}, {"key": "rrr5k1", "text": "ninety-nine", "style": "A"}, {"key": "1ep9co3", "text": "9 tens and 9 ones make ninety-nine. That is ninety-nine!", "style": "A"}, {"key": "1ijgmwv", "text": "8 tens make eighty. That is eighty!", "style": "A"}, {"key": "16jy8l", "text": "6 tens and 2 ones make sixty-two. That is sixty-two!", "style": "A"}, {"key": "1exski7", "text": "8 tens and 4 ones make eighty-four. That is eighty-four!", "style": "A"}, {"key": "m5pbcp", "text": "4 tens and 2 ones make forty-two. That is forty-two!", "style": "A"}, {"key": "1rnkyds", "text": "2 tens and 7 ones make twenty-seven. That is twenty-seven!", "style": "A"}, {"key": "d6znxb", "text": "The order says fifteen. Let's build it.", "style": "A"}, {"key": "j0r2ps", "text": "one tens go on the left.", "style": "A"}, {"key": "h1cw4i", "text": "five ones go on the right. That is fifteen.", "style": "A"}, {"key": "b27mvu", "text": "Now the order says fifty-one — the same two digits, the other way round.", "style": "A"}, {"key": "16snf1f", "text": "five tens, and one ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "r47xuc", "text": "The order says twenty-nine. Let's build it.", "style": "A"}, {"key": "c4mroe", "text": "two tens go on the left.", "style": "A"}, {"key": "14jdjzh", "text": "nine ones go on the right. That is twenty-nine.", "style": "A"}, {"key": "m12rwt", "text": "Now the order says ninety-two — the same two digits, the other way round.", "style": "A"}, {"key": "1c5suip", "text": "nine tens, and two ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "18sdw7h", "text": "The order says forty-five. Let's build it.", "style": "A"}, {"key": "17vdlrm", "text": "four tens go on the left.", "style": "A"}, {"key": "15uzuhm", "text": "five ones go on the right. That is forty-five.", "style": "A"}, {"key": "5tjw1k", "text": "Now the order says fifty-four — the same two digits, the other way round.", "style": "A"}, {"key": "1et5083", "text": "five tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "13br1fn", "text": "The order says twelve. Let's build it.", "style": "A"}, {"key": "q50o3c", "text": "two ones go on the right. That is twelve.", "style": "A"}, {"key": "t8subp", "text": "Now the order says twenty-one — the same two digits, the other way round.", "style": "A"}, {"key": "1yvavjb", "text": "two tens, and one ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1h0pqhs", "text": "The order says seventy-eight. Let's build it.", "style": "A"}, {"key": "15dvu9f", "text": "seven tens go on the left.", "style": "A"}, {"key": "ombroa", "text": "eight ones go on the right. That is seventy-eight.", "style": "A"}, {"key": "m10kkj", "text": "Now the order says eighty-seven — the same two digits, the other way round.", "style": "A"}, {"key": "181qnsv", "text": "eight tens, and seven ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "15l8l90", "text": "The order says fourteen. Let's build it.", "style": "A"}, {"key": "1mwlsbf", "text": "four ones go on the right. That is fourteen.", "style": "A"}, {"key": "119vg7o", "text": "Now the order says forty-one — the same two digits, the other way round.", "style": "A"}, {"key": "1b12xgz", "text": "four tens, and one ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1h15d4y", "text": "The order says sixty-six. Let's build it.", "style": "A"}, {"key": "4bw2ro", "text": "six tens go on the left.", "style": "A"}, {"key": "1sxyott", "text": "six ones go on the right. That is sixty-six.", "style": "A"}, {"key": "1m1shin", "text": "Now the order says sixty-six — the same two digits, the other way round.", "style": "A"}, {"key": "137o0ad", "text": "six tens, and six ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "df7s26", "text": "The order says seventy-seven. Let's build it.", "style": "A"}, {"key": "10z6kmi", "text": "seven ones go on the right. That is seventy-seven.", "style": "A"}, {"key": "1qeaxez", "text": "Now the order says seventy-seven — the same two digits, the other way round.", "style": "A"}, {"key": "2hhd91", "text": "seven tens, and seven ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "16tpcvt", "text": "The order says twenty-eight. Let's build it.", "style": "A"}, {"key": "p1w3cb", "text": "eight ones go on the right. That is twenty-eight.", "style": "A"}, {"key": "1dt5b8s", "text": "Now the order says eighty-two — the same two digits, the other way round.", "style": "A"}, {"key": "1qvh3tm", "text": "eight tens, and two ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1l2rtyd", "text": "The order says thirty-two. Let's build it.", "style": "A"}, {"key": "17w8y3m", "text": "two ones go on the right. That is thirty-two.", "style": "A"}, {"key": "nrpfb5", "text": "Now the order says twenty-three — the same two digits, the other way round.", "style": "A"}, {"key": "18cafkz", "text": "two tens, and three ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "ukni49", "text": "The order says sixty-seven. Let's build it.", "style": "A"}, {"key": "1rpf0e5", "text": "seven ones go on the right. That is sixty-seven.", "style": "A"}, {"key": "1kccrb2", "text": "Now the order says seventy-six — the same two digits, the other way round.", "style": "A"}, {"key": "8hsai6", "text": "seven tens, and six ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "awkg7u", "text": "The order says sixty-one. Let's build it.", "style": "A"}, {"key": "1lrig3x", "text": "one ones go on the right. That is sixty-one.", "style": "A"}, {"key": "pf0zmt", "text": "Now the order says sixteen — the same two digits, the other way round.", "style": "A"}, {"key": "1it73rl", "text": "one tens, and six ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "18p4ca3", "text": "The order says seventy-two. Let's build it.", "style": "A"}, {"key": "y87j66", "text": "two ones go on the right. That is seventy-two.", "style": "A"}, {"key": "1anl8gc", "text": "Now the order says twenty-seven — the same two digits, the other way round.", "style": "A"}, {"key": "1c1wo5o", "text": "two tens, and seven ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1yfx8ul", "text": "The order says fifty-three. Let's build it.", "style": "A"}, {"key": "jnnj2q", "text": "three ones go on the right. That is fifty-three.", "style": "A"}, {"key": "1qdyuj2", "text": "Now the order says thirty-five — the same two digits, the other way round.", "style": "A"}, {"key": "1kpt9kl", "text": "three tens, and five ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1lx7dei", "text": "The order says ninety-six. Let's build it.", "style": "A"}, {"key": "kawtdu", "text": "nine tens go on the left.", "style": "A"}, {"key": "cyxjqv", "text": "six ones go on the right. That is ninety-six.", "style": "A"}, {"key": "e4yeef", "text": "Now the order says sixty-nine — the same two digits, the other way round.", "style": "A"}, {"key": "148j13x", "text": "six tens, and nine ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "ftewfc", "text": "The order says sixteen. Let's build it.", "style": "A"}, {"key": "1bf7iwr", "text": "six ones go on the right. That is sixteen.", "style": "A"}, {"key": "uj7687", "text": "Now the order says sixty-one — the same two digits, the other way round.", "style": "A"}, {"key": "9ih071", "text": "six tens, and one ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "wsnvpd", "text": "The order says forty-four. Let's build it.", "style": "A"}, {"key": "1akwyt2", "text": "four ones go on the right. That is forty-four.", "style": "A"}, {"key": "1w2jnre", "text": "Now the order says forty-four — the same two digits, the other way round.", "style": "A"}, {"key": "1yg0n6b", "text": "four tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "yk320n", "text": "The order says eighteen. Let's build it.", "style": "A"}, {"key": "1t7c3cp", "text": "eight ones go on the right. That is eighteen.", "style": "A"}, {"key": "7quf1e", "text": "Now the order says eighty-one — the same two digits, the other way round.", "style": "A"}, {"key": "q2gdkg", "text": "eight tens, and one ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1uct1zv", "text": "The order says forty-three. Let's build it.", "style": "A"}, {"key": "uxkr38", "text": "three ones go on the right. That is forty-three.", "style": "A"}, {"key": "synx3m", "text": "Now the order says thirty-four — the same two digits, the other way round.", "style": "A"}, {"key": "yt5ebx", "text": "three tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "mfcqoz", "text": "The order says twenty-seven. Let's build it.", "style": "A"}, {"key": "hbfjvz", "text": "seven ones go on the right. That is twenty-seven.", "style": "A"}, {"key": "17ulfdg", "text": "Now the order says seventy-two — the same two digits, the other way round.", "style": "A"}, {"key": "1ao8u10", "text": "seven tens, and two ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "6dysrs", "text": "The order says sixty-two. Let's build it.", "style": "A"}, {"key": "ovo5lt", "text": "two ones go on the right. That is sixty-two.", "style": "A"}, {"key": "nco6ah", "text": "Now the order says twenty-six — the same two digits, the other way round.", "style": "A"}, {"key": "1ob7z5v", "text": "two tens, and six ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "10gyx8l", "text": "The order says fifty-six. Let's build it.", "style": "A"}, {"key": "ac5nx6", "text": "six ones go on the right. That is fifty-six.", "style": "A"}, {"key": "1p08umv", "text": "Now the order says sixty-five — the same two digits, the other way round.", "style": "A"}, {"key": "p7zex9", "text": "six tens, and five ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1uo7fz4", "text": "The order says fifty-eight. Let's build it.", "style": "A"}, {"key": "26uxga", "text": "eight ones go on the right. That is fifty-eight.", "style": "A"}, {"key": "1nmx580", "text": "Now the order says eighty-five — the same two digits, the other way round.", "style": "A"}, {"key": "vsgk2y", "text": "eight tens, and five ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1vztivn", "text": "The order says forty-six. Let's build it.", "style": "A"}, {"key": "zttdh8", "text": "six ones go on the right. That is forty-six.", "style": "A"}, {"key": "hm99en", "text": "Now the order says sixty-four — the same two digits, the other way round.", "style": "A"}, {"key": "pi6o6d", "text": "six tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1akr4ja", "text": "The order says forty-eight. Let's build it.", "style": "A"}, {"key": "fbjua0", "text": "eight ones go on the right. That is forty-eight.", "style": "A"}, {"key": "1na5lmo", "text": "Now the order says eighty-four — the same two digits, the other way round.", "style": "A"}, {"key": "1wcwmz2", "text": "eight tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "tc9w4y", "text": "The order says sixty-four. Let's build it.", "style": "A"}, {"key": "1oygj69", "text": "four ones go on the right. That is sixty-four.", "style": "A"}, {"key": "16j7kf0", "text": "Now the order says forty-six — the same two digits, the other way round.", "style": "A"}, {"key": "1p3pgkn", "text": "four tens, and six ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "r5re32", "text": "The order says fifty-seven. Let's build it.", "style": "A"}, {"key": "1wf3tdi", "text": "seven ones go on the right. That is fifty-seven.", "style": "A"}, {"key": "i8hoq0", "text": "Now the order says seventy-five — the same two digits, the other way round.", "style": "A"}, {"key": "17t277k", "text": "seven tens, and five ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "mh17d1", "text": "The order says seventy-six. Let's build it.", "style": "A"}, {"key": "1neb9sm", "text": "six ones go on the right. That is seventy-six.", "style": "A"}, {"key": "1muo3s2", "text": "Now the order says sixty-seven — the same two digits, the other way round.", "style": "A"}, {"key": "1p4ehxq", "text": "six tens, and seven ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "4ax2f0", "text": "The order says twenty-six. Let's build it.", "style": "A"}, {"key": "1kjscvh", "text": "six ones go on the right. That is twenty-six.", "style": "A"}, {"key": "60mxtx", "text": "Now the order says sixty-two — the same two digits, the other way round.", "style": "A"}, {"key": "127vxw3", "text": "six tens, and two ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "bwzsuz", "text": "The order says thirty-six. Let's build it.", "style": "A"}, {"key": "9aq81i", "text": "six ones go on the right. That is thirty-six.", "style": "A"}, {"key": "13kze3z", "text": "Now the order says sixty-three — the same two digits, the other way round.", "style": "A"}, {"key": "qicxdh", "text": "six tens, and three ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "13q7eh4", "text": "The order says twenty-one. Let's build it.", "style": "A"}, {"key": "1vwbx9l", "text": "one ones go on the right. That is twenty-one.", "style": "A"}, {"key": "1ke6umk", "text": "Now the order says twelve — the same two digits, the other way round.", "style": "A"}, {"key": "x2ivuf", "text": "one tens, and two ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "p3mhip", "text": "The order says fifty-one. Let's build it.", "style": "A"}, {"key": "1p5qqc2", "text": "one ones go on the right. That is fifty-one.", "style": "A"}, {"key": "1cmwg60", "text": "Now the order says fifteen — the same two digits, the other way round.", "style": "A"}, {"key": "wnl3rt", "text": "one tens, and five ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "jh83ut", "text": "The order says eighty-three. Let's build it.", "style": "A"}, {"key": "1rj7jc1", "text": "eight tens go on the left.", "style": "A"}, {"key": "1dnqzbs", "text": "three ones go on the right. That is eighty-three.", "style": "A"}, {"key": "c6hn7f", "text": "Now the order says thirty-eight — the same two digits, the other way round.", "style": "A"}, {"key": "b2p558", "text": "three tens, and eight ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1tlijuz", "text": "The order says forty-one. Let's build it.", "style": "A"}, {"key": "3msc0", "text": "one ones go on the right. That is forty-one.", "style": "A"}, {"key": "3eqmc1", "text": "Now the order says fourteen — the same two digits, the other way round.", "style": "A"}, {"key": "104gv3l", "text": "one tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1c0l66g", "text": "The order says twenty-four. Let's build it.", "style": "A"}, {"key": "1fmj5l9", "text": "four ones go on the right. That is twenty-four.", "style": "A"}, {"key": "1q14xuu", "text": "Now the order says forty-two — the same two digits, the other way round.", "style": "A"}, {"key": "s633pt", "text": "four tens, and two ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "ep69tx", "text": "The order says thirteen. Let's build it.", "style": "A"}, {"key": "1wjaw3g", "text": "three ones go on the right. That is thirteen.", "style": "A"}, {"key": "191w3r0", "text": "Now the order says thirty-one — the same two digits, the other way round.", "style": "A"}, {"key": "h985dx", "text": "three tens, and one ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1pj2zsn", "text": "The order says sixty-eight. Let's build it.", "style": "A"}, {"key": "q4o1jt", "text": "eight ones go on the right. That is sixty-eight.", "style": "A"}, {"key": "4ubhra", "text": "Now the order says eighty-six — the same two digits, the other way round.", "style": "A"}, {"key": "1gxska0", "text": "eight tens, and six ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "s8jyg7", "text": "The order says eighty-four. Let's build it.", "style": "A"}, {"key": "d8bni", "text": "four ones go on the right. That is eighty-four.", "style": "A"}, {"key": "u6bb8z", "text": "Now the order says forty-eight — the same two digits, the other way round.", "style": "A"}, {"key": "wrsmr2", "text": "four tens, and eight ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1oyl7sf", "text": "The order says fifty-five. Let's build it.", "style": "A"}, {"key": "eb4ul0", "text": "five ones go on the right. That is fifty-five.", "style": "A"}, {"key": "kcnbl4", "text": "Now the order says fifty-five — the same two digits, the other way round.", "style": "A"}, {"key": "13n4ve7", "text": "five tens, and five ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "e3c44z", "text": "The order says thirty-one. Let's build it.", "style": "A"}, {"key": "143wh7q", "text": "one ones go on the right. That is thirty-one.", "style": "A"}, {"key": "15qm29q", "text": "Now the order says thirteen — the same two digits, the other way round.", "style": "A"}, {"key": "1fyjrcp", "text": "one tens, and three ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1tjdoux", "text": "The order says eighty-one. Let's build it.", "style": "A"}, {"key": "my15uk", "text": "one ones go on the right. That is eighty-one.", "style": "A"}, {"key": "1tf8d4g", "text": "Now the order says eighteen — the same two digits, the other way round.", "style": "A"}, {"key": "1jtb3rs", "text": "one tens, and eight ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "rrkrvx", "text": "The order says forty-two. Let's build it.", "style": "A"}, {"key": "6wjgwo", "text": "two ones go on the right. That is forty-two.", "style": "A"}, {"key": "1ir9085", "text": "Now the order says twenty-four — the same two digits, the other way round.", "style": "A"}, {"key": "1pdya4v", "text": "two tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1c6j02k", "text": "The order says forty-seven. Let's build it.", "style": "A"}, {"key": "51lalk", "text": "seven ones go on the right. That is forty-seven.", "style": "A"}, {"key": "j0upyw", "text": "Now the order says seventy-four — the same two digits, the other way round.", "style": "A"}, {"key": "1yhmyb4", "text": "seven tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "10sflao", "text": "The order says nineteen. Let's build it.", "style": "A"}, {"key": "15ut0hr", "text": "nine ones go on the right. That is nineteen.", "style": "A"}, {"key": "jcz8vz", "text": "Now the order says ninety-one — the same two digits, the other way round.", "style": "A"}, {"key": "jk0sv7", "text": "nine tens, and one ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "r222db", "text": "The order says fifty-four. Let's build it.", "style": "A"}, {"key": "cj6qos", "text": "four ones go on the right. That is fifty-four.", "style": "A"}, {"key": "7ty98m", "text": "Now the order says forty-five — the same two digits, the other way round.", "style": "A"}, {"key": "s89ssf", "text": "four tens, and five ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "icp9e2", "text": "The order says sixty-five. Let's build it.", "style": "A"}, {"key": "aic9g1", "text": "five ones go on the right. That is sixty-five.", "style": "A"}, {"key": "uefjge", "text": "Now the order says fifty-six — the same two digits, the other way round.", "style": "A"}, {"key": "rq5lqv", "text": "five tens, and six ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1a55isy", "text": "The order says ninety-nine. Let's build it.", "style": "A"}, {"key": "xhpkpb", "text": "nine ones go on the right. That is ninety-nine.", "style": "A"}, {"key": "1rrnwlb", "text": "Now the order says ninety-nine — the same two digits, the other way round.", "style": "A"}, {"key": "1wombtr", "text": "nine tens, and nine ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1rt4f16", "text": "The order says sixty-nine. Let's build it.", "style": "A"}, {"key": "kjga7l", "text": "nine ones go on the right. That is sixty-nine.", "style": "A"}, {"key": "w7kgh3", "text": "Now the order says ninety-six — the same two digits, the other way round.", "style": "A"}, {"key": "166vvrr", "text": "nine tens, and six ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1avmft0", "text": "The order says twenty-three. Let's build it.", "style": "A"}, {"key": "5nqe59", "text": "three ones go on the right. That is twenty-three.", "style": "A"}, {"key": "14rfuf2", "text": "Now the order says thirty-two — the same two digits, the other way round.", "style": "A"}, {"key": "7et0vf", "text": "three tens, and two ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1r7j0b9", "text": "The order says thirty-nine. Let's build it.", "style": "A"}, {"key": "qhvgsw", "text": "nine ones go on the right. That is thirty-nine.", "style": "A"}, {"key": "1m7dpcn", "text": "Now the order says ninety-three — the same two digits, the other way round.", "style": "A"}, {"key": "1yyfxf3", "text": "nine tens, and three ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "19fb5j5", "text": "The order says ninety-seven. Let's build it.", "style": "A"}, {"key": "d6kgk5", "text": "seven ones go on the right. That is ninety-seven.", "style": "A"}, {"key": "hn3ajs", "text": "Now the order says seventy-nine — the same two digits, the other way round.", "style": "A"}, {"key": "ld296o", "text": "seven tens, and nine ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "gq26kq", "text": "The order says ninety-four. Let's build it.", "style": "A"}, {"key": "1nir96z", "text": "four ones go on the right. That is ninety-four.", "style": "A"}, {"key": "14d2w7a", "text": "Now the order says forty-nine — the same two digits, the other way round.", "style": "A"}, {"key": "n7mvnz", "text": "four tens, and nine ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1j6z09u", "text": "The order says ninety-five. Let's build it.", "style": "A"}, {"key": "118qa3z", "text": "five ones go on the right. That is ninety-five.", "style": "A"}, {"key": "1o5g1t4", "text": "Now the order says fifty-nine — the same two digits, the other way round.", "style": "A"}, {"key": "1m83yn3", "text": "five tens, and nine ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "qwj2s", "text": "The order says thirty-seven. Let's build it.", "style": "A"}, {"key": "j9owgc", "text": "seven ones go on the right. That is thirty-seven.", "style": "A"}, {"key": "1trw8rq", "text": "Now the order says seventy-three — the same two digits, the other way round.", "style": "A"}, {"key": "lk6s8u", "text": "seven tens, and three ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "ah5pj2", "text": "The order says thirty-eight. Let's build it.", "style": "A"}, {"key": "3u4u9s", "text": "eight ones go on the right. That is thirty-eight.", "style": "A"}, {"key": "18bpwpq", "text": "Now the order says eighty-three — the same two digits, the other way round.", "style": "A"}, {"key": "10e8qfk", "text": "eight tens, and three ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "151p4od", "text": "The order says forty-nine. Let's build it.", "style": "A"}, {"key": "1uuwc2i", "text": "nine ones go on the right. That is forty-nine.", "style": "A"}, {"key": "177dajb", "text": "Now the order says ninety-four — the same two digits, the other way round.", "style": "A"}, {"key": "74nicj", "text": "nine tens, and four ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "cjsv2c", "text": "The order says twenty-five. Let's build it.", "style": "A"}, {"key": "1ifa3yl", "text": "five ones go on the right. That is twenty-five.", "style": "A"}, {"key": "hwo7is", "text": "Now the order says fifty-two — the same two digits, the other way round.", "style": "A"}, {"key": "1bym5oh", "text": "five tens, and two ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "u927e2", "text": "The order says ninety-three. Let's build it.", "style": "A"}, {"key": "1v01rxz", "text": "three ones go on the right. That is ninety-three.", "style": "A"}, {"key": "sdipke", "text": "Now the order says thirty-nine — the same two digits, the other way round.", "style": "A"}, {"key": "r6guyt", "text": "three tens, and nine ones. Look how much bigger the tens side is.", "style": "A"}, {"key": "1j9xnfk", "text": "eight on this side, and five on that side.", "style": "A"}, {"key": "1ilp1jj", "text": "eight is greater than five.", "style": "A"}, {"key": "hy8imu", "text": "thirty-two on this side, and twenty-six on that side.", "style": "A"}, {"key": "1w4gy3d", "text": "thirty-two is greater than twenty-six.", "style": "A"}, {"key": "dc85fc", "text": "forty-three on this side, and eighty-seven on that side.", "style": "A"}, {"key": "1qfgaby", "text": "forty-three is less than eighty-seven.", "style": "A"}, {"key": "1o0lbiz", "text": "five on this side, and six on that side.", "style": "A"}, {"key": "18k5n53", "text": "five is less than six.", "style": "A"}, {"key": "4jfa5l", "text": "thirty-six on this side, and thirty-six on that side.", "style": "A"}, {"key": "2e5n23", "text": "They are the same — thirty-six equals thirty-six.", "style": "A"}, {"key": "i8zud3", "text": "sixty-five on this side, and sixty-five on that side.", "style": "A"}, {"key": "18978wz", "text": "They are the same — sixty-five equals sixty-five.", "style": "A"}, {"key": "9wz23v", "text": "four on this side, and six on that side.", "style": "A"}, {"key": "ystdpz", "text": "four is less than six.", "style": "A"}, {"key": "8tg7yq", "text": "forty-four on this side, and twenty-six on that side.", "style": "A"}, {"key": "17wj4p9", "text": "forty-four is greater than twenty-six.", "style": "A"}, {"key": "1yz6xjr", "text": "fourteen on this side, and five on that side.", "style": "A"}, {"key": "ohz2nq", "text": "fourteen is greater than five.", "style": "A"}, {"key": "n5pj4s", "text": "seven on this side, and three on that side.", "style": "A"}, {"key": "bnn7ez", "text": "seven is greater than three.", "style": "A"}, {"key": "1jhzfmk", "text": "thirty-two on this side, and twenty-two on that side.", "style": "A"}, {"key": "wr1syj", "text": "thirty-two is greater than twenty-two.", "style": "A"}, {"key": "iaqt2v", "text": "eighty-nine on this side, and eighty-two on that side.", "style": "A"}, {"key": "476rk2", "text": "eighty-nine is greater than eighty-two.", "style": "A"}, {"key": "t7wl8b", "text": "four on this side, and three on that side.", "style": "A"}, {"key": "1dp88mq", "text": "four is greater than three.", "style": "A"}, {"key": "12p450s", "text": "fifty on this side, and forty-four on that side.", "style": "A"}, {"key": "1ifvnvv", "text": "fifty is greater than forty-four.", "style": "A"}, {"key": "1gbpc8l", "text": "nine on this side, and eighty on that side.", "style": "A"}, {"key": "1fjzy7b", "text": "nine is less than eighty.", "style": "A"}, {"key": "1a50uor", "text": "nine on this side, and six on that side.", "style": "A"}, {"key": "1vb2gn6", "text": "nine is greater than six.", "style": "A"}, {"key": "o2n5kh", "text": "twenty-three on this side, and two on that side.", "style": "A"}, {"key": "dg8f1w", "text": "twenty-three is greater than two.", "style": "A"}, {"key": "124onv2", "text": "seventy-two on this side, and twenty-three on that side.", "style": "A"}, {"key": "1x11p0p", "text": "seventy-two is greater than twenty-three.", "style": "A"}, {"key": "774dup", "text": "one on this side, and one on that side.", "style": "A"}, {"key": "q5tce5", "text": "They are the same — one equals one.", "style": "A"}, {"key": "198ab7f", "text": "twenty-one on this side, and sixteen on that side.", "style": "A"}, {"key": "1icgq52", "text": "twenty-one is greater than sixteen.", "style": "A"}, {"key": "1ng9s8p", "text": "six on this side, and six on that side.", "style": "A"}, {"key": "m6bl7l", "text": "They are the same — six equals six.", "style": "A"}, {"key": "17j0ld7", "text": "nine on this side, and three on that side.", "style": "A"}, {"key": "1dlwnmq", "text": "nine is greater than three.", "style": "A"}, {"key": "16dsyix", "text": "thirty-three on this side, and thirty-three on that side.", "style": "A"}, {"key": "501r2r", "text": "They are the same — thirty-three equals thirty-three.", "style": "A"}, {"key": "38x2g6", "text": "fifty-seven on this side, and seventy-five on that side.", "style": "A"}, {"key": "xwfjem", "text": "fifty-seven is less than seventy-five.", "style": "A"}, {"key": "1p44mt9", "text": "two on this side, and two on that side.", "style": "A"}, {"key": "m920b1", "text": "They are the same — two equals two.", "style": "A"}, {"key": "193dg3w", "text": "forty-four on this side, and one on that side.", "style": "A"}, {"key": "12bj4xz", "text": "forty-four is greater than one.", "style": "A"}, {"key": "1rkduq8", "text": "twenty-four on this side, and forty-one on that side.", "style": "A"}, {"key": "jxgu5i", "text": "twenty-four is less than forty-one.", "style": "A"}, {"key": "1mo4hvg", "text": "eight on this side, and two on that side.", "style": "A"}, {"key": "z04ujj", "text": "eight is greater than two.", "style": "A"}, {"key": "526zcl", "text": "seven on this side, and seven on that side.", "style": "A"}, {"key": "6h2tmr", "text": "They are the same — seven equals seven.", "style": "A"}, {"key": "c0x72i", "text": "eighty-three on this side, and ninety-five on that side.", "style": "A"}, {"key": "xiccgy", "text": "eighty-three is less than ninety-five.", "style": "A"}, {"key": "wzc5bg", "text": "ten on this side, and nine on that side.", "style": "A"}, {"key": "tcqsdf", "text": "ten is greater than nine.", "style": "A"}, {"key": "1pbdckf", "text": "nineteen on this side, and one on that side.", "style": "A"}, {"key": "1aptgy", "text": "nineteen is greater than one.", "style": "A"}, {"key": "33mz7i", "text": "seventy-nine on this side, and seventy-eight on that side.", "style": "A"}, {"key": "1vpf01d", "text": "seventy-nine is greater than seventy-eight.", "style": "A"}, {"key": "mvwm6f", "text": "two on this side, and six on that side.", "style": "A"}, {"key": "1oe7vc3", "text": "two is less than six.", "style": "A"}, {"key": "1kpnzzo", "text": "thirty on this side, and ten on that side.", "style": "A"}, {"key": "o4oppf", "text": "thirty is greater than ten.", "style": "A"}, {"key": "90ydhz", "text": "four on this side, and twenty-nine on that side.", "style": "A"}, {"key": "yrgip7", "text": "four is less than twenty-nine.", "style": "A"}, {"key": "2uw4mu", "text": "eight on this side, and six on that side.", "style": "A"}, {"key": "1uean85", "text": "eight is greater than six.", "style": "A"}, {"key": "4lsyzi", "text": "thirty-nine on this side, and twenty-four on that side.", "style": "A"}, {"key": "kiyyol", "text": "thirty-nine is greater than twenty-four.", "style": "A"}, {"key": "1gyrzeq", "text": "ninety-six on this side, and fifty-one on that side.", "style": "A"}, {"key": "5xfcjx", "text": "ninety-six is greater than fifty-one.", "style": "A"}, {"key": "p56si5", "text": "three on this side, and four on that side.", "style": "A"}, {"key": "1iew13v", "text": "three is less than four.", "style": "A"}, {"key": "1ctxm0a", "text": "fourteen on this side, and eighteen on that side.", "style": "A"}, {"key": "fs82em", "text": "fourteen is less than eighteen.", "style": "A"}, {"key": "1g4yn0o", "text": "sixty-one on this side, and thirty-four on that side.", "style": "A"}, {"key": "vmguf7", "text": "sixty-one is greater than thirty-four.", "style": "A"}, {"key": "pt62wg", "text": "three on this side, and seven on that side.", "style": "A"}, {"key": "16gvzx2", "text": "three is less than seven.", "style": "A"}, {"key": "bnxp2v", "text": "nine on this side, and twenty-three on that side.", "style": "A"}, {"key": "1bgrgdd", "text": "nine is less than twenty-three.", "style": "A"}, {"key": "19rjwel", "text": "sixty-one on this side, and sixty-one on that side.", "style": "A"}, {"key": "3yd0y1", "text": "They are the same — sixty-one equals sixty-one.", "style": "A"}, {"key": "5rtdvn", "text": "five on this side, and five on that side.", "style": "A"}, {"key": "rs04oj", "text": "They are the same — five equals five.", "style": "A"}, {"key": "1e9e9pl", "text": "forty-five on this side, and forty-five on that side.", "style": "A"}, {"key": "bnu8f7", "text": "They are the same — forty-five equals forty-five.", "style": "A"}, {"key": "13ds6n6", "text": "forty-six on this side, and seventy-seven on that side.", "style": "A"}, {"key": "18zw6pe", "text": "forty-six is less than seventy-seven.", "style": "A"}, {"key": "1jrbezl", "text": "forty-seven on this side, and forty-seven on that side.", "style": "A"}, {"key": "d9atx", "text": "They are the same — forty-seven equals forty-seven.", "style": "A"}, {"key": "1qddub1", "text": "one on this side, and forty on that side.", "style": "A"}, {"key": "1aey1c5", "text": "one is less than forty.", "style": "A"}, {"key": "l4m32h", "text": "eight on this side, and eight on that side.", "style": "A"}, {"key": "vm2omz", "text": "They are the same — eight equals eight.", "style": "A"}, {"key": "10nkm9m", "text": "four on this side, and thirty-three on that side.", "style": "A"}, {"key": "12wdcpe", "text": "four is less than thirty-three.", "style": "A"}, {"key": "178t0id", "text": "two on this side, and ninety-four on that side.", "style": "A"}, {"key": "ru1b2p", "text": "two is less than ninety-four.", "style": "A"}, {"key": "yknwf8", "text": "one on this side, and seven on that side.", "style": "A"}, {"key": "15vzw9m", "text": "one is less than seven.", "style": "A"}, {"key": "lfzwmc", "text": "eight on this side, and fifty on that side.", "style": "A"}, {"key": "1puhufw", "text": "eight is less than fifty.", "style": "A"}, {"key": "uuuqtq", "text": "twenty on this side, and one hundred on that side.", "style": "A"}, {"key": "st2rd2", "text": "twenty is less than one hundred.", "style": "A"}, {"key": "kzju4e", "text": "eight on this side, and three on that side.", "style": "A"}, {"key": "1x8ao4d", "text": "eight is greater than three.", "style": "A"}, {"key": "frf5bt", "text": "twenty on this side, and twenty on that side.", "style": "A"}, {"key": "1xsg1h7", "text": "They are the same — twenty equals twenty.", "style": "A"}, {"key": "mabdxe", "text": "sixteen on this side, and eighty-three on that side.", "style": "A"}, {"key": "1jzn7ki", "text": "sixteen is less than eighty-three.", "style": "A"}, {"key": "1wos2a1", "text": "three on this side, and nine on that side.", "style": "A"}, {"key": "1j0pnjj", "text": "three is less than nine.", "style": "A"}, {"key": "bdbjbb", "text": "twenty-three on this side, and twenty-six on that side.", "style": "A"}, {"key": "fx7zvt", "text": "twenty-three is less than twenty-six.", "style": "A"}, {"key": "t04u49", "text": "fifty-one on this side, and fifty-one on that side.", "style": "A"}, {"key": "eoymtn", "text": "They are the same — fifty-one equals fifty-one.", "style": "A"}, {"key": "vmr28h", "text": "six on this side, and five on that side.", "style": "A"}, {"key": "19isr0g", "text": "six is greater than five.", "style": "A"}, {"key": "13a4m10", "text": "two on this side, and forty-four on that side.", "style": "A"}, {"key": "1autcec", "text": "two is less than forty-four.", "style": "A"}, {"key": "3e4dl", "text": "ninety-seven on this side, and ninety-seven on that side.", "style": "A"}, {"key": "1omge97", "text": "They are the same — ninety-seven equals ninety-seven.", "style": "A"}, {"key": "1bh4kll", "text": "three on this side, and five on that side.", "style": "A"}, {"key": "xnharz", "text": "three is less than five.", "style": "A"}, {"key": "1fw7sd9", "text": "thirty-nine on this side, and thirty-four on that side.", "style": "A"}, {"key": "qugalc", "text": "thirty-nine is greater than thirty-four.", "style": "A"}, {"key": "1yc430f", "text": "ninety-three on this side, and thirty-eight on that side.", "style": "A"}, {"key": "amoa3y", "text": "ninety-three is greater than thirty-eight.", "style": "A"}, {"key": "1hlfzq9", "text": "twenty-eight on this side, and twenty-eight on that side.", "style": "A"}, {"key": "f7etyj", "text": "They are the same — twenty-eight equals twenty-eight.", "style": "A"}, {"key": "11fhgox", "text": "seventy on this side, and forty-eight on that side.", "style": "A"}, {"key": "1v68wos", "text": "seventy is greater than forty-eight.", "style": "A"}, {"key": "1b8kgte", "text": "three on this side, and ten on that side.", "style": "A"}, {"key": "67xrzw", "text": "three is less than ten.", "style": "A"}, {"key": "1qh8uwb", "text": "two on this side, and twenty-one on that side.", "style": "A"}, {"key": "l5zxlp", "text": "two is less than twenty-one.", "style": "A"}, {"key": "7zqrh0", "text": "nine on this side, and forty-two on that side.", "style": "A"}, {"key": "19jxg3a", "text": "nine is less than forty-two.", "style": "A"}, {"key": "10z9tdu", "text": "sixteen on this side, and thirty-nine on that side.", "style": "A"}, {"key": "kzuf6w", "text": "sixteen is less than thirty-nine.", "style": "A"}, {"key": "1keqqt", "text": "twenty-five on this side, and twenty-five on that side.", "style": "A"}, {"key": "ahzla9", "text": "They are the same — twenty-five equals twenty-five.", "style": "A"}, {"key": "12irg38", "text": "seven on this side, and six on that side.", "style": "A"}, {"key": "17v907v", "text": "seven is greater than six.", "style": "A"}, {"key": "pnziky", "text": "one on this side, and thirty-four on that side.", "style": "A"}, {"key": "1ho4uvg", "text": "one is less than thirty-four.", "style": "A"}, {"key": "1y6owi3", "text": "thirty-seven on this side, and thirty-seven on that side.", "style": "A"}, {"key": "siqwtv", "text": "They are the same — thirty-seven equals thirty-seven.", "style": "A"}, {"key": "pcqz3x", "text": "twenty-five on this side, and twenty-six on that side.", "style": "A"}, {"key": "oxpjrb", "text": "twenty-five is less than twenty-six.", "style": "A"}, {"key": "1l907x5", "text": "seventy-one on this side, and seventy-one on that side.", "style": "A"}, {"key": "1bmypd7", "text": "They are the same — seventy-one equals seventy-one.", "style": "A"}, {"key": "1l1bm30", "text": "ten on this side, and five on that side.", "style": "A"}, {"key": "kh50ab", "text": "ten is greater than five.", "style": "A"}, {"key": "y77vmm", "text": "six on this side, and forty-four on that side.", "style": "A"}, {"key": "1m1s7jy", "text": "six is less than forty-four.", "style": "A"}, {"key": "1gpmmfy", "text": "eighty-six on this side, and fourteen on that side.", "style": "A"}, {"key": "168u4nh", "text": "eighty-six is greater than fourteen.", "style": "A"}, {"key": "6gd0pg", "text": "five on this side, and ten on that side.", "style": "A"}, {"key": "rjb6zq", "text": "five is less than ten.", "style": "A"}, {"key": "1r1fuxk", "text": "four on this side, and forty-five on that side.", "style": "A"}, {"key": "kojy4g", "text": "four is less than forty-five.", "style": "A"}, {"key": "eekklx", "text": "eighty-five on this side, and eighty-five on that side.", "style": "A"}, {"key": "1cci33n", "text": "They are the same — eighty-five equals eighty-five.", "style": "A"}, {"key": "1kvv4td", "text": "fifty-six on this side, and fifty-six on that side.", "style": "A"}, {"key": "z6s5tf", "text": "They are the same — fifty-six equals fifty-six.", "style": "A"}, {"key": "18b5qp", "text": "six on this side, and nine on that side.", "style": "A"}, {"key": "b06i1z", "text": "six is less than nine.", "style": "A"}, {"key": "ke8xxh", "text": "seventy on this side, and ninety-three on that side.", "style": "A"}, {"key": "13ytlpf", "text": "seventy is less than ninety-three.", "style": "A"}, {"key": "15064r8", "text": "nine on this side, and ten on that side.", "style": "A"}, {"key": "4bmtt2", "text": "nine is less than ten.", "style": "A"}, {"key": "1jhae7p", "text": "thirty-four on this side, and thirty-six on that side.", "style": "A"}, {"key": "d8x81d", "text": "thirty-four is less than thirty-six.", "style": "A"}, {"key": "nnpwz3", "text": "ninety-one on this side, and sixty-three on that side.", "style": "A"}, {"key": "wok9m", "text": "ninety-one is greater than sixty-three.", "style": "A"}, {"key": "z3b6dq", "text": "three on this side, and eight on that side.", "style": "A"}, {"key": "swc5eo", "text": "three is less than eight.", "style": "A"}, {"key": "e5lpw4", "text": "seventeen on this side, and three on that side.", "style": "A"}, {"key": "vpym1f", "text": "seventeen is greater than three.", "style": "A"}, {"key": "11ay6ot", "text": "six on this side, and one on that side.", "style": "A"}, {"key": "1ww8wa0", "text": "six is greater than one.", "style": "A"}, {"key": "ue13xo", "text": "forty-one on this side, and thirty-eight on that side.", "style": "A"}, {"key": "15cymar", "text": "forty-one is greater than thirty-eight.", "style": "A"}, {"key": "8jk89e", "text": "fifty-four on this side, and ninety-six on that side.", "style": "A"}, {"key": "1fmte4c", "text": "fifty-four is less than ninety-six.", "style": "A"}, {"key": "1j7yl3h", "text": "forty on this side, and forty on that side.", "style": "A"}, {"key": "12cz7g5", "text": "They are the same — forty equals forty.", "style": "A"}, {"key": "1s66kpy", "text": "six on this side, and thirty-four on that side.", "style": "A"}, {"key": "1275qc0", "text": "six is less than thirty-four.", "style": "A"}, {"key": "wsmuy9", "text": "three on this side, and three on that side.", "style": "A"}, {"key": "12yor8p", "text": "They are the same — three equals three.", "style": "A"}, {"key": "1dnwued", "text": "forty on this side, and twenty-nine on that side.", "style": "A"}, {"key": "mzxp1c", "text": "forty is greater than twenty-nine.", "style": "A"}, {"key": "1l6fhx", "text": "forty-four on this side, and forty-four on that side.", "style": "A"}, {"key": "nww28b", "text": "They are the same — forty-four equals forty-four.", "style": "A"}, {"key": "mqu4rx", "text": "twenty-nine on this side, and nine on that side.", "style": "A"}, {"key": "mnr4d0", "text": "twenty-nine is greater than nine.", "style": "A"}, {"key": "k919lo", "text": "ten on this side, and four on that side.", "style": "A"}, {"key": "dfjf1b", "text": "ten is greater than four.", "style": "A"}, {"key": "1mz29na", "text": "six on this side, and eight on that side.", "style": "A"}, {"key": "1auv2l4", "text": "six is less than eight.", "style": "A"}, {"key": "1qaozt2", "text": "ten on this side, and twenty-nine on that side.", "style": "A"}, {"key": "8hyoje", "text": "ten is less than twenty-nine.", "style": "A"}, {"key": "ulbn76", "text": "ten on this side, and six on that side.", "style": "A"}, {"key": "7aemgp", "text": "ten is greater than six.", "style": "A"}, {"key": "vzwty3", "text": "twenty on this side, and fifteen on that side.", "style": "A"}, {"key": "1sb6y62", "text": "twenty is greater than fifteen.", "style": "A"}, {"key": "1qpujth", "text": "twenty-one on this side, and ninety-six on that side.", "style": "A"}, {"key": "18tjx4r", "text": "twenty-one is less than ninety-six.", "style": "A"}, {"key": "6591zp", "text": "nine", "style": "A"}, {"key": "dg7kv3", "text": "You have 8 rabbits.", "style": "A"}, {"key": "oede39", "text": "Then 1 rabbit wander off.", "style": "A"}, {"key": "eujfum", "text": "seven", "style": "A"}, {"key": "1qjkx2z", "text": "seven rabbits left!", "style": "A"}, {"key": "1b6w3ve", "text": "You have 10 butterflies.", "style": "A"}, {"key": "145a1ni", "text": "Then 3 butterflies flutter away.", "style": "A"}, {"key": "13op3kh", "text": "seven butterflies left!", "style": "A"}, {"key": "1r2yyh3", "text": "You have 10 sharks.", "style": "A"}, {"key": "sw4omk", "text": "Finn has 4 sharks.", "style": "A"}, {"key": "2sx1y6", "text": "You have six more!", "style": "A"}, {"key": "jeirem", "text": "You have 6 squirrels.", "style": "A"}, {"key": "10yadk4", "text": "Then 4 squirrels wander off.", "style": "A"}, {"key": "12y71td", "text": "two squirrels left!", "style": "A"}, {"key": "qd3sfh", "text": "You have 11 bees.", "style": "A"}, {"key": "plx52y", "text": "Then 10 bees flutter away.", "style": "A"}, {"key": "ryrjr0", "text": "one bees left!", "style": "A"}, {"key": "12zoh2w", "text": "You have 5 turtles.", "style": "A"}, {"key": "bfr4nj", "text": "Finn has 4 turtles.", "style": "A"}, {"key": "1utzbri", "text": "You have one more!", "style": "A"}, {"key": "bp5xte", "text": "You have 5 lambs.", "style": "A"}, {"key": "1j6dqhh", "text": "Then 4 lambs wander off.", "style": "A"}, {"key": "46zjea", "text": "one lambs left!", "style": "A"}, {"key": "1ygnvnm", "text": "You have 9 ladybugs.", "style": "A"}, {"key": "13t3qq1", "text": "Then 1 ladybug flutter away.", "style": "A"}, {"key": "1kfqxcv", "text": "eight ladybugs left!", "style": "A"}, {"key": "wcwbj3", "text": "You have 8 chicks.", "style": "A"}, {"key": "1h6tgtl", "text": "Pat has 2 chicks.", "style": "A"}, {"key": "114sxib", "text": "You have 9 ducklings.", "style": "A"}, {"key": "1i13mgs", "text": "Then 2 ducklings wander off.", "style": "A"}, {"key": "7e3wsw", "text": "seven ducklings left!", "style": "A"}, {"key": "iiz3er", "text": "You have 4 rabbits.", "style": "A"}, {"key": "1wi8sxu", "text": "Then you spot 7 rabbits more.", "style": "A"}, {"key": "1wtw71z", "text": "eleven rabbits altogether!", "style": "A"}, {"key": "17o7xpu", "text": "Then 7 butterflies flutter away.", "style": "A"}, {"key": "gjfjxg", "text": "three butterflies left!", "style": "A"}, {"key": "1ytyok6", "text": "You have 1 shark.", "style": "A"}, {"key": "nkjfys", "text": "Then you meet 7 sharks more.", "style": "A"}, {"key": "9r54yw", "text": "eight sharks altogether!", "style": "A"}, {"key": "d3fnzv", "text": "You have 3 squirrels.", "style": "A"}, {"key": "7qt29j", "text": "Then you spot 3 squirrels more.", "style": "A"}, {"key": "1i32jj1", "text": "six squirrels altogether!", "style": "A"}, {"key": "1bg3c9q", "text": "You have 10 bees.", "style": "A"}, {"key": "tqa3p1", "text": "Bo has 2 bees.", "style": "A"}, {"key": "mkbrz9", "text": "You have eight more!", "style": "A"}, {"key": "za4k10", "text": "You have 9 turtles.", "style": "A"}, {"key": "1v889q1", "text": "Then 2 turtles swim away.", "style": "A"}, {"key": "9wgw0p", "text": "seven turtles left!", "style": "A"}, {"key": "d4bhcz", "text": "Then you spot 4 lambs more.", "style": "A"}, {"key": "18wh9c6", "text": "nine lambs altogether!", "style": "A"}, {"key": "s554p4", "text": "Bo has 7 ladybugs.", "style": "A"}, {"key": "13luuus", "text": "You have 9 chicks.", "style": "A"}, {"key": "jub9bp", "text": "Then 8 chicks wander off.", "style": "A"}, {"key": "14lebsw", "text": "one chicks left!", "style": "A"}, {"key": "6cugbs", "text": "You have 6 ducklings.", "style": "A"}, {"key": "k0vafq", "text": "Then you spot 6 ducklings more.", "style": "A"}, {"key": "ioxxvk", "text": "twelve ducklings altogether!", "style": "A"}, {"key": "b4v53x", "text": "You have 6 rabbits.", "style": "A"}, {"key": "7km9dl", "text": "thirteen rabbits altogether!", "style": "A"}, {"key": "1hgflk0", "text": "You have 9 butterflies.", "style": "A"}, {"key": "amn678", "text": "Then 1 butterfly flutter away.", "style": "A"}, {"key": "95hphj", "text": "eight butterflies left!", "style": "A"}, {"key": "tzm6xy", "text": "Then 2 sharks swim away.", "style": "A"}, {"key": "cury52", "text": "eight sharks left!", "style": "A"}, {"key": "yv9732", "text": "Pat has 2 squirrels.", "style": "A"}, {"key": "1lyl4n2", "text": "You have four more!", "style": "A"}, {"key": "1fhbotv", "text": "You have 4 bees.", "style": "A"}, {"key": "1owdhuv", "text": "Then 2 bees flutter away.", "style": "A"}, {"key": "1mt9bby", "text": "two bees left!", "style": "A"}, {"key": "zjplqr", "text": "You have 11 turtles.", "style": "A"}, {"key": "1udar0s", "text": "Then 7 turtles swim away.", "style": "A"}, {"key": "pf3id2", "text": "four turtles left!", "style": "A"}, {"key": "1x76d86", "text": "You have 9 lambs.", "style": "A"}, {"key": "svxp5d", "text": "Then 8 lambs wander off.", "style": "A"}, {"key": "bpin2f", "text": "Then 4 ladybugs flutter away.", "style": "A"}, {"key": "w4vj48", "text": "five ladybugs left!", "style": "A"}, {"key": "188rhrg", "text": "You have 12 chicks.", "style": "A"}, {"key": "uvad0a", "text": "Then 7 chicks wander off.", "style": "A"}, {"key": "d3dnzq", "text": "five chicks left!", "style": "A"}, {"key": "1brayrf", "text": "Pat has 5 ducklings.", "style": "A"}, {"key": "1verm0", "text": "Then you spot 5 rabbits more.", "style": "A"}, {"key": "f4ixpm", "text": "nine rabbits altogether!", "style": "A"}, {"key": "3ajpkb", "text": "You have 11 butterflies.", "style": "A"}, {"key": "1s8vbbp", "text": "Then 2 butterflies flutter away.", "style": "A"}, {"key": "17bpbgy", "text": "nine butterflies left!", "style": "A"}, {"key": "aj1vgi", "text": "You have 13 sharks.", "style": "A"}, {"key": "13qkvao", "text": "Then 1 shark swim away.", "style": "A"}, {"key": "xdd51e", "text": "twelve sharks left!", "style": "A"}, {"key": "16h2qp0", "text": "Then you spot 2 squirrels more.", "style": "A"}, {"key": "10y7r9y", "text": "eight squirrels altogether!", "style": "A"}, {"key": "x4as33", "text": "You have 8 bees.", "style": "A"}, {"key": "1ncc76t", "text": "Then 4 bees flutter away.", "style": "A"}, {"key": "19etpe", "text": "four bees left!", "style": "A"}, {"key": "1aw2t4u", "text": "You have 10 turtles.", "style": "A"}, {"key": "1qbc3h2", "text": "Then 5 turtles swim away.", "style": "A"}, {"key": "1840352", "text": "five turtles left!", "style": "A"}, {"key": "wky68h", "text": "You have 6 lambs.", "style": "A"}, {"key": "8utlkg", "text": "Then 3 lambs wander off.", "style": "A"}, {"key": "sfzyhy", "text": "three lambs left!", "style": "A"}, {"key": "1wv5ir6", "text": "Then 5 ladybugs flutter away.", "style": "A"}, {"key": "1dqpxdk", "text": "four ladybugs left!", "style": "A"}, {"key": "7w2z6w", "text": "You have 16 chicks.", "style": "A"}, {"key": "oaolia", "text": "Then 14 chicks wander off.", "style": "A"}, {"key": "1moxo82", "text": "two chicks left!", "style": "A"}, {"key": "1q6rixh", "text": "You have 7 ducklings.", "style": "A"}, {"key": "4c5r3k", "text": "Then 6 ducklings wander off.", "style": "A"}, {"key": "5cwnpx", "text": "one ducklings left!", "style": "A"}, {"key": "191eyxc", "text": "You have 7 rabbits.", "style": "A"}, {"key": "if0653", "text": "Then 6 rabbits wander off.", "style": "A"}, {"key": "10rifm6", "text": "one rabbits left!", "style": "A"}, {"key": "16yerz8", "text": "You have 5 butterflies.", "style": "A"}, {"key": "19muy3n", "text": "Bo has 2 butterflies.", "style": "A"}, {"key": "bpup12", "text": "You have three more!", "style": "A"}, {"key": "jlnjxv", "text": "You have 7 sharks.", "style": "A"}, {"key": "1i65s91", "text": "Then 3 sharks swim away.", "style": "A"}, {"key": "zb6l6d", "text": "four sharks left!", "style": "A"}, {"key": "13m4loo", "text": "You have 8 squirrels.", "style": "A"}, {"key": "151bzph", "text": "four squirrels left!", "style": "A"}, {"key": "118xzju", "text": "You have 7 bees.", "style": "A"}, {"key": "y4l5b3", "text": "Then you meet 7 bees more.", "style": "A"}, {"key": "18bonyg", "text": "fourteen bees altogether!", "style": "A"}, {"key": "15gilpa", "text": "You have 3 turtles.", "style": "A"}, {"key": "21sgos", "text": "one turtles left!", "style": "A"}, {"key": "1hwcgmd", "text": "Then you spot 1 lamb more.", "style": "A"}, {"key": "1pnqk34", "text": "six lambs altogether!", "style": "A"}, {"key": "17v7d8h", "text": "You have 8 ladybugs.", "style": "A"}, {"key": "1d3lfwa", "text": "three ladybugs left!", "style": "A"}, {"key": "16zdewu", "text": "You have 7 chicks.", "style": "A"}, {"key": "9jp52t", "text": "Then you spot 1 chick more.", "style": "A"}, {"key": "1uedyzv", "text": "eight chicks altogether!", "style": "A"}, {"key": "19ragz4", "text": "You have 1 duckling.", "style": "A"}, {"key": "bvu6oa", "text": "Then you spot 2 ducklings more.", "style": "A"}, {"key": "d4f6lb", "text": "three ducklings altogether!", "style": "A"}, {"key": "7c7iu", "text": "You have 5 rabbits.", "style": "A"}, {"key": "14umtdz", "text": "Pat has 4 rabbits.", "style": "A"}, {"key": "1gzpn68", "text": "You have 2 sharks.", "style": "A"}, {"key": "14hm8k1", "text": "Then you meet 2 sharks more.", "style": "A"}, {"key": "1gh8lxn", "text": "four sharks altogether!", "style": "A"}, {"key": "15b4u0i", "text": "You have 11 squirrels.", "style": "A"}, {"key": "11val1r", "text": "Then 5 squirrels wander off.", "style": "A"}, {"key": "17gb85b", "text": "six squirrels left!", "style": "A"}, {"key": "ewr34d", "text": "You have 2 bees.", "style": "A"}, {"key": "1juf2xo", "text": "nine bees altogether!", "style": "A"}, {"key": "1f2sca1", "text": "You have 13 turtles.", "style": "A"}, {"key": "10tqvgb", "text": "Then 8 turtles swim away.", "style": "A"}, {"key": "16oesdv", "text": "You have 8 lambs.", "style": "A"}, {"key": "orp90x", "text": "Pat has 2 lambs.", "style": "A"}, {"key": "14tsuqx", "text": "seven ladybugs left!", "style": "A"}, {"key": "1m4d66c", "text": "Then you spot 5 chicks more.", "style": "A"}, {"key": "13hnaf3", "text": "twelve chicks altogether!", "style": "A"}, {"key": "1q6qrft", "text": "You have 10 ducklings.", "style": "A"}, {"key": "1g49aeo", "text": "Then you spot 4 ducklings more.", "style": "A"}, {"key": "1yvbmkt", "text": "fourteen ducklings altogether!", "style": "A"}, {"key": "14dhrap", "text": "You have 2 rabbits.", "style": "A"}, {"key": "1c1rn3x", "text": "Then you spot 2 rabbits more.", "style": "A"}, {"key": "1efsp6i", "text": "four rabbits altogether!", "style": "A"}, {"key": "ui2j4p", "text": "You have 8 butterflies.", "style": "A"}, {"key": "13c4atk", "text": "one butterflies left!", "style": "A"}, {"key": "ff0mt8", "text": "You have 6 sharks.", "style": "A"}, {"key": "1jex756", "text": "Then you meet 9 sharks more.", "style": "A"}, {"key": "8jvtfe", "text": "fifteen sharks altogether!", "style": "A"}, {"key": "5xiwep", "text": "You have 9 squirrels.", "style": "A"}, {"key": "1l8du3s", "text": "Then 8 squirrels wander off.", "style": "A"}, {"key": "6npadn", "text": "one squirrels left!", "style": "A"}, {"key": "f0g6bf", "text": "Then 6 bees flutter away.", "style": "A"}, {"key": "1u1x718", "text": "Finn has 3 turtles.", "style": "A"}, {"key": "160r194", "text": "You have 3 lambs.", "style": "A"}, {"key": "sb7bvt", "text": "Then 1 lamb wander off.", "style": "A"}, {"key": "1ycn4c0", "text": "two lambs left!", "style": "A"}, {"key": "1vbu7qe", "text": "You have 5 ladybugs.", "style": "A"}, {"key": "1efzgha", "text": "one ladybugs left!", "style": "A"}, {"key": "ixvrex", "text": "You have 1 chick.", "style": "A"}, {"key": "1qpx3df", "text": "Then you spot 2 chicks more.", "style": "A"}, {"key": "1xmdj3q", "text": "three chicks altogether!", "style": "A"}, {"key": "187fzk9", "text": "You have 3 ducklings.", "style": "A"}, {"key": "kudc7s", "text": "four rabbits left!", "style": "A"}, {"key": "1qzhhu0", "text": "Bo has 9 butterflies.", "style": "A"}, {"key": "1osv5l1", "text": "five sharks left!", "style": "A"}, {"key": "1aj4xf9", "text": "You have 5 squirrels.", "style": "A"}, {"key": "117kegw", "text": "You have 9 bees.", "style": "A"}, {"key": "ezvl6q", "text": "Bo has 7 bees.", "style": "A"}, {"key": "1tdpzr3", "text": "You have 6 turtles.", "style": "A"}, {"key": "1tsm823", "text": "Then 1 turtle swim away.", "style": "A"}, {"key": "1vmb8zc", "text": "You have 10 lambs.", "style": "A"}, {"key": "z5t0ce", "text": "six lambs left!", "style": "A"}, {"key": "fb68wz", "text": "You have 11 ladybugs.", "style": "A"}, {"key": "1ll889y", "text": "Then 9 ladybugs flutter away.", "style": "A"}, {"key": "1odi06s", "text": "two ladybugs left!", "style": "A"}, {"key": "1p2viq0", "text": "You have 5 chicks.", "style": "A"}, {"key": "ps9ucx", "text": "seven chicks altogether!", "style": "A"}, {"key": "6urguw", "text": "Then 1 duckling wander off.", "style": "A"}, {"key": "1y86o3m", "text": "eight ducklings left!", "style": "A"}, {"key": "p3pqil", "text": "Pat has 2 rabbits.", "style": "A"}, {"key": "898uwq", "text": "You have 3 butterflies.", "style": "A"}, {"key": "epthr2", "text": "two butterflies left!", "style": "A"}, {"key": "mu5jgj", "text": "three sharks left!", "style": "A"}, {"key": "1xymrye", "text": "Then 2 squirrels wander off.", "style": "A"}, {"key": "e8i74", "text": "six bees left!", "style": "A"}, {"key": "1y81ez3", "text": "You have 4 lambs.", "style": "A"}, {"key": "19mefvj", "text": "Pat has 1 lamb.", "style": "A"}, {"key": "og30hs", "text": "You have 7 ladybugs.", "style": "A"}, {"key": "zldtg1", "text": "Then 6 ladybugs flutter away.", "style": "A"}, {"key": "1yjdnsy", "text": "You have 10 chicks.", "style": "A"}, {"key": "35ed44", "text": "Then 9 chicks wander off.", "style": "A"}, {"key": "1pzcjnf", "text": "Then 3 ducklings wander off.", "style": "A"}, {"key": "5xt6y1", "text": "six ducklings left!", "style": "A"}, {"key": "17iz88z", "text": "Then 2 rabbits wander off.", "style": "A"}, {"key": "gu57ea", "text": "six rabbits left!", "style": "A"}, {"key": "1ph36ug", "text": "Then you meet 2 butterflies more.", "style": "A"}, {"key": "1tlmlmv", "text": "thirteen butterflies altogether!", "style": "A"}, {"key": "1pjsm6r", "text": "You have 14 sharks.", "style": "A"}, {"key": "ktx1rj", "text": "Then you meet 1 shark more.", "style": "A"}, {"key": "rl1kj2", "text": "Then you spot 1 squirrel more.", "style": "A"}, {"key": "lw68o0", "text": "seven squirrels altogether!", "style": "A"}, {"key": "13eimp5", "text": "You have 6 bees.", "style": "A"}, {"key": "i68ch3", "text": "You have 1 ladybug.", "style": "A"}, {"key": "6vq2jx", "text": "Then you meet 7 ladybugs more.", "style": "A"}, {"key": "9yao1p", "text": "eight ladybugs altogether!", "style": "A"}, {"key": "kc5hya", "text": "You have 3 chicks.", "style": "A"}, {"key": "16fl2ra", "text": "Then you spot 3 chicks more.", "style": "A"}, {"key": "7pfmdq", "text": "six chicks altogether!", "style": "A"}, {"key": "1167b1n", "text": "five ducklings left!", "style": "A"}, {"key": "bvljf4", "text": "You have 1 butterfly.", "style": "A"}, {"key": "9b1fgd", "text": "Then you meet 5 butterflies more.", "style": "A"}, {"key": "97e8xy", "text": "six butterflies altogether!", "style": "A"}, {"key": "1ann4wj", "text": "Then you spot 7 squirrels more.", "style": "A"}, {"key": "16hjsx4", "text": "thirteen squirrels altogether!", "style": "A"}, {"key": "h1o4zi", "text": "You have 3 bees.", "style": "A"}, {"key": "kkmxrm", "text": "Then you meet 11 bees more.", "style": "A"}, {"key": "16er7ze", "text": "You have 7 turtles.", "style": "A"}, {"key": "o2ss8w", "text": "Then 3 turtles swim away.", "style": "A"}, {"key": "1jx93wc", "text": "You have 7 lambs.", "style": "A"}, {"key": "13qmu3w", "text": "four lambs left!", "style": "A"}, {"key": "imuahh", "text": "You have 4 ladybugs.", "style": "A"}, {"key": "qinfxu", "text": "Then you meet 4 ladybugs more.", "style": "A"}, {"key": "2p2l4z", "text": "Then 1 chick wander off.", "style": "A"}, {"key": "dw6jxg", "text": "six chicks left!", "style": "A"}, {"key": "ruo2sc", "text": "You have 11 ducklings.", "style": "A"}, {"key": "m5k6jp", "text": "Then 5 ducklings wander off.", "style": "A"}, {"key": "16obdxg", "text": "You have 10 rabbits.", "style": "A"}, {"key": "1o0287f", "text": "twelve rabbits altogether!", "style": "A"}, {"key": "6jpt6u", "text": "You have 7 butterflies.", "style": "A"}, {"key": "1cc5pn6", "text": "five butterflies left!", "style": "A"}, {"key": "twdkjl", "text": "You have 9 sharks.", "style": "A"}, {"key": "xzwu4x", "text": "Then 7 sharks swim away.", "style": "A"}, {"key": "1pdm7kh", "text": "two sharks left!", "style": "A"}, {"key": "1wjx1fw", "text": "You have 4 squirrels.", "style": "A"}, {"key": "cj1mcf", "text": "Then 1 bee flutter away.", "style": "A"}, {"key": "186lb06", "text": "Then you meet 1 turtle more.", "style": "A"}, {"key": "we7x9d", "text": "ten turtles altogether!", "style": "A"}, {"key": "1j4ps64", "text": "Pat has 3 lambs.", "style": "A"}, {"key": "1fsbdv3", "text": "You have 6 ladybugs.", "style": "A"}, {"key": "187iztf", "text": "You have 4 chicks.", "style": "A"}, {"key": "14fc0eg", "text": "five chicks altogether!", "style": "A"}, {"key": "120nfnj", "text": "And the short hand is on the 7.", "style": "A"}, {"key": "1anji0h", "text": "So it is 7 o'clock.", "style": "A"}, {"key": "1l5bvld", "text": "The long hand is on the 6. On the outside ring, the 6 means 30 minutes.", "style": "A"}, {"key": "12lreg6", "text": "The short hand is just past the 8.", "style": "A"}, {"key": "1ox8xwi", "text": "So it is half past 8 — time to have breakfast.", "style": "A"}, {"key": "1em2lb5", "text": "The long hand is on the 9. On the outside ring, the 9 means 45 minutes.", "style": "A"}, {"key": "1c1h1j7", "text": "The short hand is just past the 9.", "style": "A"}, {"key": "19akqc0", "text": "So it is quarter to 10 — time to catch the bus.", "style": "A"}, {"key": "4luqaj", "text": "And the short hand is on the 10.", "style": "A"}, {"key": "1o5b02d", "text": "So it is 10 o'clock.", "style": "A"}, {"key": "1u7956m", "text": "And the short hand is on the 11.", "style": "A"}, {"key": "1kqp53k", "text": "So it is 11 o'clock.", "style": "A"}, {"key": "icao6l", "text": "The long hand is on the 10. On the outside ring, the 10 means 50 minutes.", "style": "A"}, {"key": "j7vupv", "text": "The short hand is just past the 12.", "style": "A"}, {"key": "b1erln", "text": "So it is ten to 1 — time to eat lunch.", "style": "A"}, {"key": "beapnt", "text": "And the short hand is on the 1.", "style": "A"}, {"key": "14o608n", "text": "So it is 1 o'clock.", "style": "A"}, {"key": "cjvuy1", "text": "The short hand is just past the 3.", "style": "A"}, {"key": "1xmkna6", "text": "So it is half past 3 — time to go to the park.", "style": "A"}, {"key": "1368kxr", "text": "The short hand is just past the 5.", "style": "A"}, {"key": "j1pfpn", "text": "So it is quarter to 6 — time to have dinner.", "style": "A"}, {"key": "atn86a", "text": "And the short hand is on the 6.", "style": "A"}, {"key": "rtiqvg", "text": "So it is 6 o'clock.", "style": "A"}, {"key": "1c2264t", "text": "The short hand is just past the 7.", "style": "A"}, {"key": "3gacat", "text": "So it is half past 7 — time to wake up.", "style": "A"}, {"key": "rxczjm", "text": "So it is ten to 9 — time to have breakfast.", "style": "A"}, {"key": "2hvzv5", "text": "And the short hand is on the 9.", "style": "A"}, {"key": "68gezj", "text": "So it is 9 o'clock.", "style": "A"}, {"key": "8veine", "text": "The long hand is on the 4. On the outside ring, the 4 means 20 minutes.", "style": "A"}, {"key": "1i6kxmc", "text": "The short hand is just past the 11.", "style": "A"}, {"key": "55qvli", "text": "So it is twenty past 11 — time to go out to play.", "style": "A"}, {"key": "144m62x", "text": "And the short hand is on the 12.", "style": "A"}, {"key": "i1mlqf", "text": "So it is 12 o'clock.", "style": "A"}, {"key": "cjpjy3", "text": "The short hand is just past the 1.", "style": "A"}, {"key": "1oxx6g3", "text": "So it is half past 1 — time to do some painting.", "style": "A"}, {"key": "1ndmsvl", "text": "So it is quarter to 4 — time to go to the park.", "style": "A"}, {"key": "1awh0ul", "text": "And the short hand is on the 5.", "style": "A"}, {"key": "jad83", "text": "So it is 5 o'clock.", "style": "A"}, {"key": "1bhzt8w", "text": "The short hand is just past the 6.", "style": "A"}, {"key": "1hzbr15", "text": "So it is half past 6 — time to look at the moon.", "style": "A"}, {"key": "j7p6oa", "text": "The long hand is on the 11. On the outside ring, the 11 means 55 minutes.", "style": "A"}, {"key": "12szgx8", "text": "So it is five to 8 — time to wake up.", "style": "A"}, {"key": "atgx6c", "text": "And the short hand is on the 8.", "style": "A"}, {"key": "1bzn8q", "text": "So it is 8 o'clock.", "style": "A"}, {"key": "15g6tzu", "text": "So it is half past 9 — time to catch the bus.", "style": "A"}, {"key": "19v00b5", "text": "The short hand is just past the 10.", "style": "A"}, {"key": "1k1gali", "text": "So it is five to 11 — time to get to school.", "style": "A"}, {"key": "z9b0o", "text": "So it is half past 12 — time to eat lunch.", "style": "A"}, {"key": "1hoj7rg", "text": "So it is five to 2 — time to do some painting.", "style": "A"}, {"key": "be4env", "text": "And the short hand is on the 3.", "style": "A"}, {"key": "114td6t", "text": "So it is 3 o'clock.", "style": "A"}, {"key": "1jh5dl7", "text": "The long hand is on the 1. On the outside ring, the 1 means 5 minutes.", "style": "A"}, {"key": "blgnm6", "text": "So it is five past 6 — time to look at the moon.", "style": "A"}, {"key": "qk5kgw", "text": "The long hand is on the 8. On the outside ring, the 8 means 40 minutes.", "style": "A"}, {"key": "1bx098n", "text": "So it is twenty to 10 — time to catch the bus.", "style": "A"}, {"key": "1ax8wzm", "text": "The long hand is on the 3. On the outside ring, the 3 means 15 minutes.", "style": "A"}, {"key": "1jxfoq3", "text": "So it is quarter past 11 — time to go out to play.", "style": "A"}, {"key": "49a3k8", "text": "So it is quarter to 1 — time to eat lunch.", "style": "A"}, {"key": "z1ia7b", "text": "So it is quarter to 9 — time to have breakfast.", "style": "A"}, {"key": "wwpe9p", "text": "So it is half past 10 — time to get to school.", "style": "A"}, {"key": "50c555", "text": "So it is five to 12 — time to go out to play.", "style": "A"}, {"key": "16yfjhe", "text": "So it is quarter past 6 — time to look at the moon.", "style": "A"}, {"key": "1m8d2zz", "text": "So it is ten to 8 — time to wake up.", "style": "A"}, {"key": "195hk4a", "text": "So it is quarter to 11 — time to get to school.", "style": "A"}, {"key": "s54zp2", "text": "So it is half past 5 — time to have dinner.", "style": "A"}, {"key": "1pxxogz", "text": "So it is twenty to 7 — time to look at the moon.", "style": "A"}, {"key": "17bs1tn", "text": "So it is five to 9 — time to have breakfast.", "style": "A"}, {"key": "12dlsm3", "text": "The long hand is on the 2. On the outside ring, the 2 means 10 minutes.", "style": "A"}, {"key": "1dpe21g", "text": "So it is ten past 11 — time to go out to play.", "style": "A"}, {"key": "15yr0ns", "text": "The long hand is on the 7. On the outside ring, the 7 means 35 minutes.", "style": "A"}, {"key": "1eo58mk", "text": "So it is twenty-five to 8 — time to wake up.", "style": "A"}, {"key": "hdk651", "text": "So it is twenty to 11 — time to get to school.", "style": "A"}, {"key": "13emqep", "text": "So it is ten to 2 — time to do some painting.", "style": "A"}, {"key": "1ibn76k", "text": "So it is five to 10 — time to catch the bus.", "style": "A"}, {"key": "1yb6nb6", "text": "So it is half past 11 — time to go out to play.", "style": "A"}, {"key": "1ywj6as", "text": "So it is twenty-five to 1 — time to eat lunch.", "style": "A"}, {"key": "1pgqo7b", "text": "So it is twenty-five to 6 — time to have dinner.", "style": "A"}, {"key": "107q782", "text": "So it is quarter past 10 — time to get to school.", "style": "A"}, {"key": "6ostt6", "text": "So it is twenty to 4 — time to go to the park.", "style": "A"}, {"key": "c63sxs", "text": "So it is quarter to 8 — time to wake up.", "style": "A"}, {"key": "1op6x2n", "text": "So it is quarter past 5 — time to have dinner.", "style": "A"}]
todo = [r for r in LINES if not (REPO / 'public/audio' / VOICE / f"{r['key']}.mp3").exists()]
json.dump(todo, open(WORK / 'todo.json', 'w'))
print(len(todo), 'lines to render')
assert 0 < len(todo) <= 1170, 'nothing to render — every line already has a clip on main'

# %%
# Chatterbox pins torch 2.6, which breaks Kaggle's own torchvision — so it gets its own venv (uv: Kaggle's python has no ensurepip).
VENV = WORK / 'venv'; PY = VENV / 'bin' / 'python'; READY = VENV / '.ready'
if not READY.exists():
    shutil.rmtree(VENV, ignore_errors=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'uv'], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'venv', str(VENV), '--python', sys.executable], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'pip', 'install', '--python', str(PY), 'setuptools<81', 'chatterbox-tts', 'imageio-ffmpeg'], check=True)
    READY.touch()
print(subprocess.run([str(PY), '-c', "import torch; print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NONE — set the accelerator')"], capture_output=True, text=True).stdout)

# %%
OUT = WORK / 'out' / VOICE
cmd = [str(PY), str(REPO / 'scripts/chatterbox-render.py'), '--voice', VOICE, '--corpus', str(WORK / 'todo.json'), '--out', str(OUT)]
proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in proc.stdout:
    if 'it/s]' in line or not line.strip(): continue   # drop the progress bars
    print(line.rstrip()[:160], flush=True)
print('exit code', proc.wait())

# %%
keys = {r['key'] for r in todo}
clips = sorted(c for c in OUT.glob('*.mp3') if c.stem in keys)
missing = [k for k in keys if not (OUT / f'{k}.mp3').exists()]
stage = WORK / 'stage'; shutil.rmtree(stage, ignore_errors=True); (stage / VOICE).mkdir(parents=True)
for c in clips: shutil.copy2(c, stage / VOICE / c.name)
shutil.make_archive(str(WORK / 'radlic-voice-josh-chapters-g1-3'), 'zip', stage)
print(f'{len(clips)} of {len(todo)} clips in radlic-voice-josh-chapters-g1-3.zip' + (f' — MISSING {len(missing)}: {missing}' if missing else ' — complete'))
