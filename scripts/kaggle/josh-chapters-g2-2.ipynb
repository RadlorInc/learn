# %% [markdown]
# # Radlic voice — Grade 2 (part 2 of 4) story chapters in Josh
#
# Renders every line the Grade 2 (part 2 of 4) story chapters can say that has no clip yet — **1500 lines, 71,651 characters** (the lines are
# written into this notebook). Style A (Chatterbox Turbo) for all of them. Rules: `docs/new-flow/voice.md`.
#
# **Before Run All:** Settings → Accelerator → **GPU T4 x2** (or P100), Internet **On**. At the end, download
# `radlic-voice-josh-chapters-g2-2.zip` from the Output panel and hand it back. If the session stops early, Run All
# again in the same session: lines already rendered are skipped.

# %%
import os, sys, subprocess, pathlib, shutil, json
VOICE = 'nzFihrBIvB34imQBuxub'   # Josh
WORK = pathlib.Path('/kaggle/working' if os.path.isdir('/kaggle/working') else '/content')
REPO = WORK / 'learn-main'
if not REPO.exists():
    subprocess.run(['git', 'clone', '--depth', '1', '--branch', 'main', 'https://github.com/RadlorInc/learn.git', str(REPO)], check=True)
LINES = [{"key": "80gcas", "text": "Yes! fifty-seven minus thirty-one is twenty-six.", "style": "A"}, {"key": "1xpn1fu", "text": "Yes! ninety minus fifty-six is thirty-four.", "style": "A"}, {"key": "v6t0re", "text": "Yes! forty-one minus ten is thirty-one.", "style": "A"}, {"key": "7lmmxh", "text": "Yes! eighty-three minus thirty-five is forty-eight.", "style": "A"}, {"key": "1a2pkhu", "text": "Yes! ninety-three minus thirty-five is fifty-eight.", "style": "A"}, {"key": "12xang5", "text": "Yes! eighty-one minus sixty-seven is fourteen.", "style": "A"}, {"key": "10a2mut", "text": "Yes! thirty-two minus thirteen is nineteen.", "style": "A"}, {"key": "900ifc", "text": "Yes! eighty-two minus sixty-three is nineteen.", "style": "A"}, {"key": "ufhyw8", "text": "Yes! sixty-seven minus eighteen is forty-nine.", "style": "A"}, {"key": "no1jo5", "text": "Yes! eighty-six minus forty-nine is thirty-seven.", "style": "A"}, {"key": "vnqwa9", "text": "Yes! thirty-six minus sixteen is twenty.", "style": "A"}, {"key": "8t8hik", "text": "Yes! seventy-six minus forty-nine is twenty-seven.", "style": "A"}, {"key": "ib5gak", "text": "Yes! seventeen minus seven is ten.", "style": "A"}, {"key": "ckydpm", "text": "Yes! sixty-one minus thirty-two is twenty-nine.", "style": "A"}, {"key": "14zemt1", "text": "Yes! fifty-eight minus thirteen is forty-five.", "style": "A"}, {"key": "axwq4y", "text": "Yes! seventy-three minus fifty-six is seventeen.", "style": "A"}, {"key": "3zwlod", "text": "Yes! thirteen minus three is ten.", "style": "A"}, {"key": "hf6qat", "text": "Yes! twenty-five minus one is twenty-four.", "style": "A"}, {"key": "1xj62sw", "text": "Yes! sixty-one minus twenty-nine is thirty-two.", "style": "A"}, {"key": "xsh1rl", "text": "Yes! ninety-three minus seventy-five is eighteen.", "style": "A"}, {"key": "3udj5c", "text": "Yes! seventy-two minus twenty-five is forty-seven.", "style": "A"}, {"key": "dfnnez", "text": "Yes! sixty-six minus thirty-nine is twenty-seven.", "style": "A"}, {"key": "1u8nxf8", "text": "Yes! twenty-eight minus four is twenty-four.", "style": "A"}, {"key": "vo8ig9", "text": "Yes! ninety-three minus eighteen is seventy-five.", "style": "A"}, {"key": "1tfxxoz", "text": "Yes! thirty-two minus ten is twenty-two.", "style": "A"}, {"key": "swm376", "text": "Yes! seventy-seven minus thirty-eight is thirty-nine.", "style": "A"}, {"key": "ipaoi6", "text": "Yes! seventy minus sixteen is fifty-four.", "style": "A"}, {"key": "129lvvy", "text": "Yes! ninety minus sixty-nine is twenty-one.", "style": "A"}, {"key": "s2c9f4", "text": "Yes! forty-one minus thirteen is twenty-eight.", "style": "A"}, {"key": "1kbytn", "text": "Yes! thirty-three minus ten is twenty-three.", "style": "A"}, {"key": "erbbu5", "text": "Yes! fifty-five minus thirty-seven is eighteen.", "style": "A"}, {"key": "p2atdj", "text": "Yes! seventy-one minus fifty-eight is thirteen.", "style": "A"}, {"key": "s6arec", "text": "Yes! seventy minus nineteen is fifty-one.", "style": "A"}, {"key": "1enlful", "text": "Yes! eighty minus twenty-two is fifty-eight.", "style": "A"}, {"key": "6au5t", "text": "Yes! eighty minus thirty-nine is forty-one.", "style": "A"}, {"key": "bxgxlj", "text": "Yes! twenty-six minus thirteen is thirteen.", "style": "A"}, {"key": "19abcx3", "text": "Yes! ninety-three minus sixteen is seventy-seven.", "style": "A"}, {"key": "oj2qvz", "text": "Yes! twenty-four minus three is twenty-one.", "style": "A"}, {"key": "kxv54m", "text": "Yes! ninety-one minus seventy-five is sixteen.", "style": "A"}, {"key": "qit8ok", "text": "Yes! ninety-six minus twenty-seven is sixty-nine.", "style": "A"}, {"key": "r1ujxy", "text": "Yes! eighty-seven minus forty-eight is thirty-nine.", "style": "A"}, {"key": "130f2f1", "text": "Yes! ninety-two minus thirty-nine is fifty-three.", "style": "A"}, {"key": "14zhrzk", "text": "Yes! twenty-six minus fourteen is twelve.", "style": "A"}, {"key": "33r61n", "text": "Yes! fifty-one minus eleven is forty.", "style": "A"}, {"key": "11pcjut", "text": "Yes! fifty-nine minus thirty-six is twenty-three.", "style": "A"}, {"key": "kwhiw4", "text": "Yes! sixty-two minus forty-three is nineteen.", "style": "A"}, {"key": "1svakvz", "text": "Yes! sixty minus thirty-one is twenty-nine.", "style": "A"}, {"key": "o7w0ax", "text": "Yes! eighty-two minus thirteen is sixty-nine.", "style": "A"}, {"key": "1gd8bau", "text": "Yes! fifty-three minus thirty-three is twenty.", "style": "A"}, {"key": "1ql6bhz", "text": "Yes! fifty minus thirty-nine is eleven.", "style": "A"}, {"key": "1xpqzfi", "text": "Yes! forty-two minus sixteen is twenty-six.", "style": "A"}, {"key": "2917d2", "text": "Yes! fifty-nine minus thirteen is forty-six.", "style": "A"}, {"key": "t58eqf", "text": "Yes! seventy-two minus thirty-four is thirty-eight.", "style": "A"}, {"key": "5sf84f", "text": "Yes! seventy-six minus eighteen is fifty-eight.", "style": "A"}, {"key": "47v7ne", "text": "Yes! forty-two minus ten is thirty-two.", "style": "A"}, {"key": "ootidv", "text": "Yes! ninety minus twenty-eight is sixty-two.", "style": "A"}, {"key": "r1f3jr", "text": "Yes! thirty-five minus twenty-five is ten.", "style": "A"}, {"key": "hekgs", "text": "Yes! fifty-three minus thirty-six is seventeen.", "style": "A"}, {"key": "4vcox6", "text": "Yes! forty-three minus fifteen is twenty-eight.", "style": "A"}, {"key": "1lsx15w", "text": "two pens of four ducklings. How many in all?", "style": "A"}, {"key": "1g6y1lp", "text": "two patches of four ladybugs. How many in all?", "style": "A"}, {"key": "n39edt", "text": "five rows of six squirrels. How many in all?", "style": "A"}, {"key": "122hqzz", "text": "two pens of four lambs. How many in all?", "style": "A"}, {"key": "1w00j0v", "text": "four rows of four ants. How many in all?", "style": "A"}, {"key": "znd3qe", "text": "three nests of two eagles. How many in all?", "style": "A"}, {"key": "c2bsym", "text": "two pens of two ducks. How many in all?", "style": "A"}, {"key": "rj0jcw", "text": "four rows of four butterflies. How many in all?", "style": "A"}, {"key": "wkpetk", "text": "three rows of five fireflies. How many in all?", "style": "A"}, {"key": "a9c1ot", "text": "three pens of three rabbits. How many in all?", "style": "A"}, {"key": "9cc5jt", "text": "four rows of two ducklings. How many in all?", "style": "A"}, {"key": "1407yp5", "text": "two patches of six ladybugs. How many in all?", "style": "A"}, {"key": "5o4nsz", "text": "two nests of two squirrels. How many in all?", "style": "A"}, {"key": "133m7xd", "text": "three pens of five lambs. How many in all?", "style": "A"}, {"key": "183b6xf", "text": "four rows of two ants. How many in all?", "style": "A"}, {"key": "yydoey", "text": "three nests of four eagles. How many in all?", "style": "A"}, {"key": "3y7b7h", "text": "two rows of five ducks. How many in all?", "style": "A"}, {"key": "3wzfnf", "text": "two patches of two butterflies. How many in all?", "style": "A"}, {"key": "69z9gi", "text": "two nests of four fireflies. How many in all?", "style": "A"}, {"key": "1xgek0n", "text": "five pens of four rabbits. How many in all?", "style": "A"}, {"key": "fvzzxs", "text": "four pens of four ducklings. How many in all?", "style": "A"}, {"key": "m7f4zd", "text": "three patches of two ladybugs. How many in all?", "style": "A"}, {"key": "1oia9iz", "text": "three rows of three squirrels. How many in all?", "style": "A"}, {"key": "1id4vv3", "text": "five pens of five lambs. How many in all?", "style": "A"}, {"key": "18yar4m", "text": "two patches of two ants. How many in all?", "style": "A"}, {"key": "g2w57o", "text": "four rows of two eagles. How many in all?", "style": "A"}, {"key": "1jy6zu4", "text": "five pens of three ducks. How many in all?", "style": "A"}, {"key": "12g98zl", "text": "three patches of two butterflies. How many in all?", "style": "A"}, {"key": "2qri4u", "text": "five nests of four fireflies. How many in all?", "style": "A"}, {"key": "12c5qby", "text": "two rows of five rabbits. How many in all?", "style": "A"}, {"key": "ty91ae", "text": "two pens of two ducklings. How many in all?", "style": "A"}, {"key": "jbtaxv", "text": "three patches of three ladybugs. How many in all?", "style": "A"}, {"key": "1175a7l", "text": "six nests of four squirrels. How many in all?", "style": "A"}, {"key": "118rfh4", "text": "two patches of three ants. How many in all?", "style": "A"}, {"key": "1obgyl8", "text": "five nests of two eagles. How many in all?", "style": "A"}, {"key": "uc5j9o", "text": "two pens of four ducks. How many in all?", "style": "A"}, {"key": "clgal6", "text": "three rows of two butterflies. How many in all?", "style": "A"}, {"key": "142yxzk", "text": "two rows of three fireflies. How many in all?", "style": "A"}, {"key": "17j8115", "text": "two pens of two rabbits. How many in all?", "style": "A"}, {"key": "15om7wp", "text": "five rows of two ducklings. How many in all?", "style": "A"}, {"key": "13hvs2z", "text": "six patches of six ladybugs. How many in all?", "style": "A"}, {"key": "aueid9", "text": "two nests of three squirrels. How many in all?", "style": "A"}, {"key": "1wmg37a", "text": "two rows of two lambs. How many in all?", "style": "A"}, {"key": "kynamf", "text": "six rows of six ants. How many in all?", "style": "A"}, {"key": "1320dal", "text": "two rows of four ducks. How many in all?", "style": "A"}, {"key": "yqzb9n", "text": "three patches of four butterflies. How many in all?", "style": "A"}, {"key": "q1vsl2", "text": "three nests of three fireflies. How many in all?", "style": "A"}, {"key": "bo25rv", "text": "two pens of four rabbits. How many in all?", "style": "A"}, {"key": "ycvqgk", "text": "three pens of two ducklings. How many in all?", "style": "A"}, {"key": "qzr3i1", "text": "two patches of three ladybugs. How many in all?", "style": "A"}, {"key": "8rrwzt", "text": "five rows of three squirrels. How many in all?", "style": "A"}, {"key": "1bppnu4", "text": "two patches of four ants. How many in all?", "style": "A"}, {"key": "1luj56s", "text": "two rows of five eagles. How many in all?", "style": "A"}, {"key": "1d8ubfk", "text": "two pens of six ducks. How many in all?", "style": "A"}, {"key": "a4g9wj", "text": "six pens of two rabbits. How many in all?", "style": "A"}, {"key": "10htptu", "text": "three pens of four ducklings. How many in all?", "style": "A"}, {"key": "1jol38u", "text": "two rows of four ladybugs. How many in all?", "style": "A"}, {"key": "qb9g67", "text": "three pens of two lambs. How many in all?", "style": "A"}, {"key": "1m6obdy", "text": "three patches of four ants. How many in all?", "style": "A"}, {"key": "1gsi5ae", "text": "two rows of three eagles. How many in all?", "style": "A"}, {"key": "b6xgws", "text": "three pens of two ducks. How many in all?", "style": "A"}, {"key": "rxbz8a", "text": "two rows of three butterflies. How many in all?", "style": "A"}, {"key": "1bmpcd2", "text": "four rows of four fireflies. How many in all?", "style": "A"}, {"key": "1r9yfk5", "text": "two rows of two ducklings. How many in all?", "style": "A"}, {"key": "1ik3nou", "text": "five rows of two ladybugs. How many in all?", "style": "A"}, {"key": "117085d", "text": "four pens of two lambs. How many in all?", "style": "A"}, {"key": "nk05zh", "text": "five rows of two ducks. How many in all?", "style": "A"}, {"key": "pbmnus", "text": "four rows of two butterflies. How many in all?", "style": "A"}, {"key": "a4jmk0", "text": "three nests of two fireflies. How many in all?", "style": "A"}, {"key": "10uxqrh", "text": "three pens of five rabbits. How many in all?", "style": "A"}, {"key": "yqyoq4", "text": "four pens of six ducklings. How many in all?", "style": "A"}, {"key": "1gr0otf", "text": "three patches of four ladybugs. How many in all?", "style": "A"}, {"key": "12gf3kj", "text": "five nests of five squirrels. How many in all?", "style": "A"}, {"key": "1mdfb1u", "text": "two rows of five lambs. How many in all?", "style": "A"}, {"key": "1ei2xq2", "text": "five rows of three eagles. How many in all?", "style": "A"}, {"key": "k333if", "text": "three rows of two ducks. How many in all?", "style": "A"}, {"key": "1ua6jdm", "text": "three rows of three rabbits. How many in all?", "style": "A"}, {"key": "12fa19c", "text": "two pens of three ducklings. How many in all?", "style": "A"}, {"key": "16zg6s", "text": "three rows of two ladybugs. How many in all?", "style": "A"}, {"key": "rjbdgp", "text": "five nests of six squirrels. How many in all?", "style": "A"}, {"key": "1j1w6rt", "text": "three pens of four lambs. How many in all?", "style": "A"}, {"key": "a0bzjh", "text": "three rows of two ants. How many in all?", "style": "A"}, {"key": "1topqs4", "text": "two rows of four eagles. How many in all?", "style": "A"}, {"key": "19sq3rm", "text": "three pens of four ducks. How many in all?", "style": "A"}, {"key": "1m55eod", "text": "five patches of three butterflies. How many in all?", "style": "A"}, {"key": "1pmmp1o", "text": "four rows of six fireflies. How many in all?", "style": "A"}, {"key": "1kedkui", "text": "three pens of three ducklings. How many in all?", "style": "A"}, {"key": "ik5pkj", "text": "two patches of two ladybugs. How many in all?", "style": "A"}, {"key": "jritgb", "text": "three nests of three squirrels. How many in all?", "style": "A"}, {"key": "1rizl7g", "text": "five rows of three lambs. How many in all?", "style": "A"}, {"key": "1991c7t", "text": "six rows of four ants. How many in all?", "style": "A"}, {"key": "17uwcww", "text": "three nests of three eagles. How many in all?", "style": "A"}, {"key": "rwngm9", "text": "four rows of five ducks. How many in all?", "style": "A"}, {"key": "1j2z3k3", "text": "three patches of five butterflies. How many in all?", "style": "A"}, {"key": "e9jl1a", "text": "two rows of four rabbits. How many in all?", "style": "A"}, {"key": "8tf42d", "text": "five rows of four ducklings. How many in all?", "style": "A"}, {"key": "vypv4m", "text": "three rows of six lambs. How many in all?", "style": "A"}, {"key": "1vyiljs", "text": "three patches of two ants. How many in all?", "style": "A"}, {"key": "1vzco4j", "text": "four rows of three ducks. How many in all?", "style": "A"}, {"key": "spyu1m", "text": "five rows of two fireflies. How many in all?", "style": "A"}, {"key": "5z28a0", "text": "four rows of three rabbits. How many in all?", "style": "A"}, {"key": "1hdvsj0", "text": "three rows of five ladybugs. How many in all?", "style": "A"}, {"key": "1ey20lf", "text": "five nests of four squirrels. How many in all?", "style": "A"}, {"key": "1jjoa8w", "text": "five rows of five butterflies. How many in all?", "style": "A"}, {"key": "1upxsi8", "text": "six rows of five fireflies. How many in all?", "style": "A"}, {"key": "15udcc5", "text": "three pens of four rabbits. How many in all?", "style": "A"}, {"key": "1ptp1t1", "text": "five rows of five ducklings. How many in all?", "style": "A"}, {"key": "pwd29n", "text": "six patches of four ladybugs. How many in all?", "style": "A"}, {"key": "1kj4m5z", "text": "two nests of four squirrels. How many in all?", "style": "A"}, {"key": "qndhgd", "text": "two rows of six ants. How many in all?", "style": "A"}, {"key": "1ssvy8", "text": "three rows of three butterflies. How many in all?", "style": "A"}, {"key": "dne9b8", "text": "three nests of four fireflies. How many in all?", "style": "A"}, {"key": "zmvjx3", "text": "two pens of three rabbits. How many in all?", "style": "A"}, {"key": "n4ce0k", "text": "four pens of five ducklings. How many in all?", "style": "A"}, {"key": "lt1rer", "text": "four nests of five squirrels. How many in all?", "style": "A"}, {"key": "1rky2c6", "text": "five rows of five lambs. How many in all?", "style": "A"}, {"key": "1tdmwo8", "text": "five nests of four eagles. How many in all?", "style": "A"}, {"key": "ei069m", "text": "three pens of five ducks. How many in all?", "style": "A"}, {"key": "nel0id", "text": "two patches of four butterflies. How many in all?", "style": "A"}, {"key": "caauoa", "text": "two rows of five fireflies. How many in all?", "style": "A"}, {"key": "1r9hn0q", "text": "five rows of four rabbits. How many in all?", "style": "A"}, {"key": "7ui3ha", "text": "two rows of five ladybugs. How many in all?", "style": "A"}, {"key": "aua43f", "text": "two rows of two squirrels. How many in all?", "style": "A"}, {"key": "17sfrld", "text": "three pens of three lambs. How many in all?", "style": "A"}, {"key": "18mzpxc", "text": "two pens of three ducks. How many in all?", "style": "A"}, {"key": "1jigivk", "text": "four rows of five butterflies. How many in all?", "style": "A"}, {"key": "repyr8", "text": "six rows of five ladybugs. How many in all?", "style": "A"}, {"key": "1cyt580", "text": "three rows of two lambs. How many in all?", "style": "A"}, {"key": "1bl00mn", "text": "five rows of five ants. How many in all?", "style": "A"}, {"key": "18xibvq", "text": "six rows of four butterflies. How many in all?", "style": "A"}, {"key": "ttmp5n", "text": "five rows of five squirrels. How many in all?", "style": "A"}, {"key": "16abeds", "text": "five rows of four eagles. How many in all?", "style": "A"}, {"key": "1cc7heb", "text": "four pens of six rabbits. How many in all?", "style": "A"}, {"key": "7i0ov9", "text": "five patches of three ladybugs. How many in all?", "style": "A"}, {"key": "14o54cj", "text": "two pens of three lambs. How many in all?", "style": "A"}, {"key": "cx50x", "text": "four rows of three ants. How many in all?", "style": "A"}, {"key": "q0ud1q", "text": "three nests of five eagles. How many in all?", "style": "A"}, {"key": "1wdgkd4", "text": "six nests of two fireflies. How many in all?", "style": "A"}, {"key": "lrv06x", "text": "two rows of five ducklings. How many in all?", "style": "A"}, {"key": "1v4t5cx", "text": "four patches of four ladybugs. How many in all?", "style": "A"}, {"key": "1etcs5", "text": "three rows of five ants. How many in all?", "style": "A"}, {"key": "55uay0", "text": "two nests of two eagles. How many in all?", "style": "A"}, {"key": "8e3jkj", "text": "five rows of three ducks. How many in all?", "style": "A"}, {"key": "241wc8", "text": "six rows of six butterflies. How many in all?", "style": "A"}, {"key": "1jokapq", "text": "five rows of two rabbits. How many in all?", "style": "A"}, {"key": "c8j28w", "text": "five pens of four ducklings. How many in all?", "style": "A"}, {"key": "nvudfr", "text": "two nests of five squirrels. How many in all?", "style": "A"}, {"key": "8mdpk6", "text": "three patches of three ants. How many in all?", "style": "A"}, {"key": "1gqkfwq", "text": "four rows of three eagles. How many in all?", "style": "A"}, {"key": "eo0snn", "text": "three rows of four ducks. How many in all?", "style": "A"}, {"key": "1lsl1xi", "text": "four rows of five fireflies. How many in all?", "style": "A"}, {"key": "1vhm9zk", "text": "five rows of six rabbits. How many in all?", "style": "A"}, {"key": "11zcwfz", "text": "five patches of two ladybugs. How many in all?", "style": "A"}, {"key": "1o6y2vx", "text": "three nests of five squirrels. How many in all?", "style": "A"}, {"key": "11o8lrz", "text": "five rows of four ants. How many in all?", "style": "A"}, {"key": "1xucr84", "text": "five rows of two eagles. How many in all?", "style": "A"}, {"key": "1ndsh7u", "text": "three pens of three ducks. How many in all?", "style": "A"}, {"key": "hlzpog", "text": "six nests of five fireflies. How many in all?", "style": "A"}, {"key": "jptgzz", "text": "four rows of three ducklings. How many in all?", "style": "A"}, {"key": "h56i3e", "text": "three rows of three ladybugs. How many in all?", "style": "A"}, {"key": "1ektuw3", "text": "five rows of two ants. How many in all?", "style": "A"}, {"key": "1adamao", "text": "three rows of six butterflies. How many in all?", "style": "A"}, {"key": "16wucjs", "text": "two nests of three fireflies. How many in all?", "style": "A"}, {"key": "1296gs", "text": "five pens of six ducklings. How many in all?", "style": "A"}, {"key": "1josxpn", "text": "four rows of five squirrels. How many in all?", "style": "A"}, {"key": "izyrj6", "text": "five nests of three eagles. How many in all?", "style": "A"}, {"key": "1akj3n5", "text": "three rows of three ducks. How many in all?", "style": "A"}, {"key": "zl0e2p", "text": "two patches of three butterflies. How many in all?", "style": "A"}, {"key": "x7g2ac", "text": "four rows of three fireflies. How many in all?", "style": "A"}, {"key": "2wtusb", "text": "five pens of five rabbits. How many in all?", "style": "A"}, {"key": "ihg7qi", "text": "five rows of four ladybugs. How many in all?", "style": "A"}, {"key": "jxgsih", "text": "four nests of six squirrels. How many in all?", "style": "A"}, {"key": "1bsy2as", "text": "five patches of three ants. How many in all?", "style": "A"}, {"key": "1gilomh", "text": "two patches of five butterflies. How many in all?", "style": "A"}, {"key": "qqqqdb", "text": "five rows of three ducklings. How many in all?", "style": "A"}, {"key": "1nv0usp", "text": "three nests of four squirrels. How many in all?", "style": "A"}, {"key": "odjn6n", "text": "four pens of three lambs. How many in all?", "style": "A"}, {"key": "17mhvuf", "text": "six rows of three ants. How many in all?", "style": "A"}, {"key": "1r12cf1", "text": "four rows of two ducks. How many in all?", "style": "A"}, {"key": "12mldib", "text": "six patches of six butterflies. How many in all?", "style": "A"}, {"key": "36v2oc", "text": "three rows of five rabbits. How many in all?", "style": "A"}, {"key": "b62odc", "text": "two rows of six lambs. How many in all?", "style": "A"}, {"key": "8o50ra", "text": "two rows of two fireflies. How many in all?", "style": "A"}, {"key": "yf5xno", "text": "two rows of six rabbits. How many in all?", "style": "A"}, {"key": "iexeq7", "text": "two rows of five squirrels. How many in all?", "style": "A"}, {"key": "w120xg", "text": "four patches of three ants. How many in all?", "style": "A"}, {"key": "1qn5agg", "text": "four rows of five eagles. How many in all?", "style": "A"}, {"key": "s3elq", "text": "three rows of four butterflies. How many in all?", "style": "A"}, {"key": "183m8j8", "text": "four pens of three ducklings. How many in all?", "style": "A"}, {"key": "3r97z6", "text": "six rows of six ladybugs. How many in all?", "style": "A"}, {"key": "117ij8z", "text": "four pens of four lambs. How many in all?", "style": "A"}, {"key": "14vh8f4", "text": "two patches of five ants. How many in all?", "style": "A"}, {"key": "160kzzc", "text": "six rows of three butterflies. How many in all?", "style": "A"}, {"key": "7zd390", "text": "three rows of two rabbits. How many in all?", "style": "A"}, {"key": "7cleen", "text": "four rows of two squirrels. How many in all?", "style": "A"}, {"key": "3n38ja", "text": "four rows of four lambs. How many in all?", "style": "A"}, {"key": "fbki4c", "text": "two nests of five eagles. How many in all?", "style": "A"}, {"key": "rh103e", "text": "six pens of four ducks. How many in all?", "style": "A"}, {"key": "a0dakr", "text": "three patches of three butterflies. How many in all?", "style": "A"}, {"key": "5qiym4", "text": "five nests of three fireflies. How many in all?", "style": "A"}, {"key": "1utqai", "text": "four rows of four ladybugs. How many in all?", "style": "A"}, {"key": "1fqarxa", "text": "four nests of four fireflies. How many in all?", "style": "A"}, {"key": "1dbcm70", "text": "three rows of four lambs. How many in all?", "style": "A"}, {"key": "1mygage", "text": "two nests of three eagles. How many in all?", "style": "A"}, {"key": "a9bugg", "text": "five rows of four butterflies. How many in all?", "style": "A"}, {"key": "1hlzrsb", "text": "four pens of three rabbits. How many in all?", "style": "A"}, {"key": "1js0iwb", "text": "six rows of five ducklings. How many in all?", "style": "A"}, {"key": "1yco867", "text": "five rows of two squirrels. How many in all?", "style": "A"}, {"key": "1ocmfiq", "text": "four rows of two lambs. How many in all?", "style": "A"}, {"key": "rac1m", "text": "three rows of four eagles. How many in all?", "style": "A"}, {"key": "1l0jkup", "text": "two patches of five ladybugs. How many in all?", "style": "A"}, {"key": "1pff53", "text": "five nests of two squirrels. How many in all?", "style": "A"}, {"key": "9x275e", "text": "five patches of two ants. How many in all?", "style": "A"}, {"key": "1gcstyc", "text": "five nests of six fireflies. How many in all?", "style": "A"}, {"key": "iv6qyt", "text": "four rows of four ducklings. How many in all?", "style": "A"}, {"key": "bi2qey", "text": "five rows of five ladybugs. How many in all?", "style": "A"}, {"key": "10ryfin", "text": "five pens of three lambs. How many in all?", "style": "A"}, {"key": "1wthfb", "text": "four patches of two butterflies. How many in all?", "style": "A"}, {"key": "xuloag", "text": "five rows of three rabbits. How many in all?", "style": "A"}, {"key": "fegwje", "text": "four pens of two ducklings. How many in all?", "style": "A"}, {"key": "5qdrn8", "text": "six rows of four lambs. How many in all?", "style": "A"}, {"key": "kpv0wh", "text": "three rows of six ducks. How many in all?", "style": "A"}, {"key": "t5bd9h", "text": "two pens of two lambs. How many in all?", "style": "A"}, {"key": "tvvifk", "text": "four patches of four ants. How many in all?", "style": "A"}, {"key": "1e2vxzi", "text": "six rows of two eagles. How many in all?", "style": "A"}, {"key": "7b2xo2", "text": "two nests of five fireflies. How many in all?", "style": "A"}, {"key": "jahdzu", "text": "three pens of five ducklings. How many in all?", "style": "A"}, {"key": "1yckh10", "text": "two rows of three ladybugs. How many in all?", "style": "A"}, {"key": "1n59yso", "text": "two pens of five ducks. How many in all?", "style": "A"}, {"key": "k7eb6c", "text": "five rows of two butterflies. How many in all?", "style": "A"}, {"key": "jq8sez", "text": "five pens of three rabbits. How many in all?", "style": "A"}, {"key": "1qyazif", "text": "five pens of six lambs. How many in all?", "style": "A"}, {"key": "1caelkx", "text": "five rows of four ducks. How many in all?", "style": "A"}, {"key": "54jz8l", "text": "five patches of five ladybugs. How many in all?", "style": "A"}, {"key": "1esigzw", "text": "six rows of four fireflies. How many in all?", "style": "A"}, {"key": "vokqpk", "text": "two pens of five ducklings. How many in all?", "style": "A"}, {"key": "1gnqajl", "text": "six patches of two ladybugs. How many in all?", "style": "A"}, {"key": "1eqzp10", "text": "four patches of five ants. How many in all?", "style": "A"}, {"key": "8geilt", "text": "two rows of two ducks. How many in all?", "style": "A"}, {"key": "1xekuec", "text": "two rows of five butterflies. How many in all?", "style": "A"}, {"key": "y7ex2i", "text": "four rows of five rabbits. How many in all?", "style": "A"}, {"key": "10394nn", "text": "four nests of four squirrels. How many in all?", "style": "A"}, {"key": "4zt2f2", "text": "six rows of three lambs. How many in all?", "style": "A"}, {"key": "18w0fc0", "text": "five rows of five eagles. How many in all?", "style": "A"}, {"key": "1fpf0x5", "text": "six rows of three ducks. How many in all?", "style": "A"}, {"key": "1qrbkii", "text": "two rows of two ladybugs. How many in all?", "style": "A"}, {"key": "1otgsch", "text": "three rows of four ants. How many in all?", "style": "A"}, {"key": "1agvl2j", "text": "three pens of two rabbits. How many in all?", "style": "A"}, {"key": "13joeio", "text": "five rows of six ladybugs. How many in all?", "style": "A"}, {"key": "c2jlcy", "text": "two rows of four lambs. How many in all?", "style": "A"}, {"key": "r6qu7g", "text": "two nests of four eagles. How many in all?", "style": "A"}, {"key": "187oi6f", "text": "two rows of three ducks. How many in all?", "style": "A"}, {"key": "sqyi5l", "text": "five patches of four butterflies. How many in all?", "style": "A"}, {"key": "shy7bi", "text": "two nests of two fireflies. How many in all?", "style": "A"}, {"key": "qeefh6", "text": "four rows of four rabbits. How many in all?", "style": "A"}, {"key": "1p8ukz7", "text": "six rows of two ducklings. How many in all?", "style": "A"}, {"key": "b2uv99", "text": "three rows of five squirrels. How many in all?", "style": "A"}, {"key": "1bh2927", "text": "four pens of five lambs. How many in all?", "style": "A"}, {"key": "6ogacx", "text": "four rows of four ducks. How many in all?", "style": "A"}, {"key": "2e7dp9", "text": "six pens of six rabbits. How many in all?", "style": "A"}, {"key": "sjt554", "text": "five rows of three ladybugs. How many in all?", "style": "A"}, {"key": "1m3jx2l", "text": "two rows of three ants. How many in all?", "style": "A"}, {"key": "1i3pew", "text": "four nests of five eagles. How many in all?", "style": "A"}, {"key": "1gp05w9", "text": "four patches of four butterflies. How many in all?", "style": "A"}, {"key": "10psub2", "text": "six rows of three fireflies. How many in all?", "style": "A"}, {"key": "1szfuiy", "text": "four rows of five ladybugs. How many in all?", "style": "A"}, {"key": "1w8x3h4", "text": "three rows of five lambs. How many in all?", "style": "A"}, {"key": "8042j1", "text": "five pens of two rabbits. How many in all?", "style": "A"}, {"key": "15vx0ju", "text": "five pens of two ducklings. How many in all?", "style": "A"}, {"key": "1xqm02d", "text": "three nests of two squirrels. How many in all?", "style": "A"}, {"key": "n86bly", "text": "four rows of five lambs. How many in all?", "style": "A"}, {"key": "d3t2e3", "text": "six rows of four ducks. How many in all?", "style": "A"}, {"key": "8l57ee", "text": "five rows of five fireflies. How many in all?", "style": "A"}, {"key": "ify8sb", "text": "four rows of four squirrels. How many in all?", "style": "A"}, {"key": "mxzsrk", "text": "five patches of four ants. How many in all?", "style": "A"}, {"key": "rk0pyf", "text": "five patches of two butterflies. How many in all?", "style": "A"}, {"key": "1vlng0y", "text": "five rows of two lambs. How many in all?", "style": "A"}, {"key": "1hqmqf2", "text": "six patches of three ants. How many in all?", "style": "A"}, {"key": "yralga", "text": "two rows of two rabbits. How many in all?", "style": "A"}, {"key": "14ife42", "text": "six pens of three ducklings. How many in all?", "style": "A"}, {"key": "10dbb0h", "text": "four nests of three squirrels. How many in all?", "style": "A"}, {"key": "19fj9if", "text": "six pens of two lambs. How many in all?", "style": "A"}, {"key": "997nx8", "text": "four pens of three ducks. How many in all?", "style": "A"}, {"key": "yvfhhu", "text": "five nests of two fireflies. How many in all?", "style": "A"}, {"key": "1bqdog4", "text": "five pens of five ducklings. How many in all?", "style": "A"}, {"key": "c7pnhl", "text": "five rows of six ants. How many in all?", "style": "A"}, {"key": "1k57ifw", "text": "four pens of five ducks. How many in all?", "style": "A"}, {"key": "j7z0hc", "text": "six rows of five lambs. How many in all?", "style": "A"}, {"key": "1bunc4l", "text": "six pens of five rabbits. How many in all?", "style": "A"}, {"key": "dtim6", "text": "four rows of two ladybugs. How many in all?", "style": "A"}, {"key": "10l9y8f", "text": "two rows of two ants. How many in all?", "style": "A"}, {"key": "1x143k0", "text": "three rows of three eagles. How many in all?", "style": "A"}, {"key": "8b87rx", "text": "four patches of three butterflies. How many in all?", "style": "A"}, {"key": "r97ojz", "text": "three rows of three ants. How many in all?", "style": "A"}, {"key": "kjvwg", "text": "five pens of four ducks. How many in all?", "style": "A"}, {"key": "j9pvrf", "text": "five rows of four squirrels. How many in all?", "style": "A"}, {"key": "1kpmho4", "text": "four rows of six lambs. How many in all?", "style": "A"}, {"key": "1os8cw0", "text": "four rows of four eagles. How many in all?", "style": "A"}, {"key": "1vgmgqq", "text": "four patches of two ants. How many in all?", "style": "A"}, {"key": "yiql2m", "text": "three rows of five eagles. How many in all?", "style": "A"}, {"key": "1o0lx9a", "text": "four rows of three butterflies. How many in all?", "style": "A"}, {"key": "1nmbsg4", "text": "five pens of three ducklings. How many in all?", "style": "A"}, {"key": "qn2hen", "text": "three rows of five ducks. How many in all?", "style": "A"}, {"key": "14xsw1u", "text": "six rows of two butterflies. How many in all?", "style": "A"}, {"key": "siel2y", "text": "five rows of five rabbits. How many in all?", "style": "A"}, {"key": "1b1tiqi", "text": "six pens of four ducklings. How many in all?", "style": "A"}, {"key": "11zaf8f", "text": "two pens of five rabbits. How many in all?", "style": "A"}, {"key": "1i0q4l4", "text": "four nests of four eagles. How many in all?", "style": "A"}, {"key": "1mc566u", "text": "three rows of three fireflies. How many in all?", "style": "A"}, {"key": "1wp30y1", "text": "two rows of four ducklings. How many in all?", "style": "A"}, {"key": "1g88pxs", "text": "six rows of four ladybugs. How many in all?", "style": "A"}, {"key": "1ki4r6z", "text": "four pens of five rabbits. How many in all?", "style": "A"}, {"key": "1tr3loj", "text": "five pens of four lambs. How many in all?", "style": "A"}, {"key": "p2qg92", "text": "three rows of two eagles. How many in all?", "style": "A"}, {"key": "1u4nyw6", "text": "five rows of four fireflies. How many in all?", "style": "A"}, {"key": "1stz5n", "text": "three nests of six squirrels. How many in all?", "style": "A"}, {"key": "qc0z8f", "text": "two rows of four squirrels. How many in all?", "style": "A"}, {"key": "1ps0ct3", "text": "four nests of two squirrels. How many in all?", "style": "A"}, {"key": "1wz0nr5", "text": "five rows of three ants. How many in all?", "style": "A"}, {"key": "e1aczg", "text": "five rows of six fireflies. How many in all?", "style": "A"}, {"key": "1qbp4yz", "text": "six patches of three ladybugs. How many in all?", "style": "A"}, {"key": "13p9t2w", "text": "three rows of four rabbits. How many in all?", "style": "A"}, {"key": "nlss7m", "text": "six pens of five ducklings. How many in all?", "style": "A"}, {"key": "104l8ch", "text": "six pens of six lambs. How many in all?", "style": "A"}, {"key": "jykqxt", "text": "six rows of four squirrels. How many in all?", "style": "A"}, {"key": "1whxole", "text": "six nests of four eagles. How many in all?", "style": "A"}, {"key": "1p49s1g", "text": "two rows of three rabbits. How many in all?", "style": "A"}, {"key": "l1mf49", "text": "three rows of four squirrels. How many in all?", "style": "A"}, {"key": "etzfnv", "text": "five rows of six ducks. How many in all?", "style": "A"}, {"key": "14v7ufg", "text": "six rows of two ladybugs. How many in all?", "style": "A"}, {"key": "9moome", "text": "five rows of four lambs. How many in all?", "style": "A"}, {"key": "arruqk", "text": "five patches of six ants. How many in all?", "style": "A"}, {"key": "13pyy8t", "text": "four pens of two rabbits. How many in all?", "style": "A"}, {"key": "i0fg49", "text": "four rows of three squirrels. How many in all?", "style": "A"}, {"key": "1iupv76", "text": "four rows of six eagles. How many in all?", "style": "A"}, {"key": "1q90uz5", "text": "five patches of four ladybugs. How many in all?", "style": "A"}, {"key": "zpgm9i", "text": "three rows of three lambs. How many in all?", "style": "A"}, {"key": "pv1tlh", "text": "six rows of two ants. How many in all?", "style": "A"}, {"key": "6s9fa4", "text": "six pens of two ducklings. How many in all?", "style": "A"}, {"key": "1k75k2i", "text": "four pens of two ducks. How many in all?", "style": "A"}, {"key": "1wlphcx", "text": "four rows of six squirrels. How many in all?", "style": "A"}, {"key": "16jupk", "text": "six nests of three eagles. How many in all?", "style": "A"}, {"key": "4n9dia", "text": "three rows of five butterflies. How many in all?", "style": "A"}, {"key": "1qihsny", "text": "six nests of three fireflies. How many in all?", "style": "A"}, {"key": "eko965", "text": "six rows of three ducklings. How many in all?", "style": "A"}, {"key": "n3enrh", "text": "six nests of two squirrels. How many in all?", "style": "A"}, {"key": "isggoa", "text": "five pens of two ducks. How many in all?", "style": "A"}, {"key": "139d7ob", "text": "four rows of six ducks. How many in all?", "style": "A"}, {"key": "rptc1u", "text": "four nests of two fireflies. How many in all?", "style": "A"}, {"key": "1nfh1ur", "text": "two rows of four ants. How many in all?", "style": "A"}, {"key": "166dm15", "text": "three pens of six lambs. How many in all?", "style": "A"}, {"key": "1fo2jrp", "text": "four patches of five ladybugs. How many in all?", "style": "A"}, {"key": "luy7xr", "text": "three rows of six ants. How many in all?", "style": "A"}, {"key": "a01s8w", "text": "two rows of two butterflies. How many in all?", "style": "A"}, {"key": "bpjzam", "text": "four rows of two rabbits. How many in all?", "style": "A"}, {"key": "1jqfn2y", "text": "two rows of four fireflies. How many in all?", "style": "A"}, {"key": "aiw4tg", "text": "five patches of five ants. How many in all?", "style": "A"}, {"key": "10i65su", "text": "six rows of six fireflies. How many in all?", "style": "A"}, {"key": "16fmjou", "text": "six patches of four ants. How many in all?", "style": "A"}, {"key": "9h4leb", "text": "six patches of four butterflies. How many in all?", "style": "A"}, {"key": "1snxvqd", "text": "three rows of six ducklings. How many in all?", "style": "A"}, {"key": "smzrbu", "text": "six pens of six ducks. How many in all?", "style": "A"}, {"key": "rkragt", "text": "six pens of four rabbits. How many in all?", "style": "A"}, {"key": "pqwess", "text": "four patches of six ants. How many in all?", "style": "A"}, {"key": "y9ynlz", "text": "four pens of four rabbits. How many in all?", "style": "A"}, {"key": "zaoisd", "text": "six rows of six ducklings. How many in all?", "style": "A"}, {"key": "ca0hwx", "text": "five pens of two lambs. How many in all?", "style": "A"}, {"key": "wmlohh", "text": "three pens of six rabbits. How many in all?", "style": "A"}, {"key": "3xhhmw", "text": "two nests of six fireflies. How many in all?", "style": "A"}, {"key": "ckztzf", "text": "three patches of five ladybugs. How many in all?", "style": "A"}, {"key": "1vb9hfc", "text": "six rows of two lambs. How many in all?", "style": "A"}, {"key": "d4sj31", "text": "four patches of five butterflies. How many in all?", "style": "A"}, {"key": "1hxhtsg", "text": "four rows of six ladybugs. How many in all?", "style": "A"}, {"key": "1s1ii1h", "text": "four patches of six butterflies. How many in all?", "style": "A"}, {"key": "bo91dr", "text": "three rows of four ducklings. How many in all?", "style": "A"}, {"key": "20biwp", "text": "six pens of five lambs. How many in all?", "style": "A"}, {"key": "1cepaan", "text": "four rows of five ants. How many in all?", "style": "A"}, {"key": "1cc3bzi", "text": "two nests of six eagles. How many in all?", "style": "A"}, {"key": "1lw311q", "text": "six nests of six fireflies. How many in all?", "style": "A"}, {"key": "13qz9x2", "text": "five rows of six butterflies. How many in all?", "style": "A"}, {"key": "9l3wc5", "text": "two rows of three squirrels. How many in all?", "style": "A"}, {"key": "1q7xp50", "text": "five rows of six lambs. How many in all?", "style": "A"}, {"key": "msaim0", "text": "five nests of five eagles. How many in all?", "style": "A"}, {"key": "1e7c2z4", "text": "three rows of two fireflies. How many in all?", "style": "A"}, {"key": "1avg5eb", "text": "six nests of three squirrels. How many in all?", "style": "A"}, {"key": "1f0weye", "text": "six nests of five eagles. How many in all?", "style": "A"}, {"key": "1akdcrz", "text": "four patches of two ladybugs. How many in all?", "style": "A"}, {"key": "1u1gtl8", "text": "four rows of three lambs. How many in all?", "style": "A"}, {"key": "18ynw05", "text": "five patches of six butterflies. How many in all?", "style": "A"}, {"key": "16fauxe", "text": "four nests of three eagles. How many in all?", "style": "A"}, {"key": "1tf78z0", "text": "four nests of three fireflies. How many in all?", "style": "A"}, {"key": "kv4ij7", "text": "six rows of six squirrels. How many in all?", "style": "A"}, {"key": "ibp78o", "text": "six rows of two fireflies. How many in all?", "style": "A"}, {"key": "esi00h", "text": "five nests of three squirrels. How many in all?", "style": "A"}, {"key": "138p7sa", "text": "four rows of two fireflies. How many in all?", "style": "A"}, {"key": "fzgc7y", "text": "three patches of five ants. How many in all?", "style": "A"}, {"key": "16y9mya", "text": "six rows of four eagles. How many in all?", "style": "A"}, {"key": "1m4fhpn", "text": "six patches of five butterflies. How many in all?", "style": "A"}, {"key": "jph1bp", "text": "three rows of two squirrels. How many in all?", "style": "A"}, {"key": "18f2qgy", "text": "six pens of three ducks. How many in all?", "style": "A"}, {"key": "gf5wd0", "text": "two rows of four butterflies. How many in all?", "style": "A"}, {"key": "lqp52k", "text": "six rows of two rabbits. How many in all?", "style": "A"}, {"key": "4jwjmd", "text": "four patches of three ladybugs. How many in all?", "style": "A"}, {"key": "1qiio8z", "text": "six patches of five ladybugs. How many in all?", "style": "A"}, {"key": "dl8ya8", "text": "six patches of two ants. How many in all?", "style": "A"}, {"key": "k1n3lm", "text": "six pens of six ducklings. How many in all?", "style": "A"}, {"key": "1nt6t76", "text": "six rows of three rabbits. How many in all?", "style": "A"}, {"key": "179g9j3", "text": "six rows of two ducks. How many in all?", "style": "A"}, {"key": "fzkfb4", "text": "two rows of two eagles. How many in all?", "style": "A"}, {"key": "104ctes", "text": "four pens of six ducks. How many in all?", "style": "A"}, {"key": "1wl6pbs", "text": "six rows of six eagles. How many in all?", "style": "A"}, {"key": "4dvtm0", "text": "three nests of five fireflies. How many in all?", "style": "A"}, {"key": "hujwck", "text": "five rows of three fireflies. How many in all?", "style": "A"}, {"key": "9h8x4", "text": "six nests of six eagles. How many in all?", "style": "A"}, {"key": "1qllvic", "text": "three rows of four fireflies. How many in all?", "style": "A"}, {"key": "18foxdn", "text": "two rows of six ducklings. How many in all?", "style": "A"}, {"key": "18mvaxa", "text": "four nests of five fireflies. How many in all?", "style": "A"}, {"key": "1b0u7yv", "text": "six rows of four ducklings. How many in all?", "style": "A"}, {"key": "cd3w9j", "text": "two rows of six ducks. How many in all?", "style": "A"}, {"key": "1ly5o8z", "text": "five pens of six rabbits. How many in all?", "style": "A"}, {"key": "z29hj7", "text": "six nests of six squirrels. How many in all?", "style": "A"}, {"key": "1ly1j2l", "text": "five patches of five butterflies. How many in all?", "style": "A"}, {"key": "rnw57q", "text": "four rows of six butterflies. How many in all?", "style": "A"}, {"key": "1fuvff2", "text": "Here is a piece of pizza this big. How many friends can get one? Lay them in!", "style": "A"}, {"key": "1id0fnq", "text": "Three friends are waiting, and there are six cherries. Share them out so everyone gets the same!", "style": "A"}, {"key": "w8vccs", "text": "Here is a piece of orange this big. How many friends can get one? Lay them in!", "style": "A"}, {"key": "1wpjg8m", "text": "Two friends want some flapjack, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "1mt95b0", "text": "Here is a piece of cheese wheel this big. How many friends can get one? Lay them in!", "style": "A"}, {"key": "ijyezq", "text": "Three friends are waiting, and there are six pears. Share them out so everyone gets the same!", "style": "A"}, {"key": "yljo7u", "text": "Here is a piece of big cookie this big. How many friends can get one? Lay them in!", "style": "A"}, {"key": "9czwn5", "text": "Four friends want some nougat bar, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "1wcmc3m", "text": "Here is a piece of party cake this big. How many friends can get one? Lay them in!", "style": "A"}, {"key": "7e53ts", "text": "Four friends want some watermelon, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "16hjstp", "text": "Four friends are waiting, and there are twelve cherries. Share them out so everyone gets the same!", "style": "A"}, {"key": "xumcn0", "text": "Three friends want some flapjack, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "1f98cuo", "text": "Two friends want some mint slice, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "wzyovr", "text": "Three friends want some nougat bar, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "18ou85i", "text": "Two friends are waiting, and there are six oranges. Share them out so everyone gets the same!", "style": "A"}, {"key": "g6ngz9", "text": "Four friends want some chocolate bar, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "ycv82l", "text": "Three friends are waiting, and there are twelve pears. Share them out so everyone gets the same!", "style": "A"}, {"key": "kr9at9", "text": "Two friends want some nougat bar, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "a0wddb", "text": "Three friends are waiting, and there are twelve oranges. Share them out so everyone gets the same!", "style": "A"}, {"key": "16xdvck", "text": "Two friends are waiting, and there are four cherries. Share them out so everyone gets the same!", "style": "A"}, {"key": "b4y03m", "text": "Four friends want some flapjack, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "nh3vck", "text": "Two friends want some watermelon, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "38afck", "text": "Four friends want some mint slice, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "1e20h0o", "text": "Three friends are waiting, and there are six oranges. Share them out so everyone gets the same!", "style": "A"}, {"key": "1kvkpv", "text": "Four friends are waiting, and there are eight oranges. Share them out so everyone gets the same!", "style": "A"}, {"key": "8o07mz", "text": "Three friends are waiting, and there are twelve cherries. Share them out so everyone gets the same!", "style": "A"}, {"key": "170td5", "text": "Four friends are waiting, and there are eight pears. Share them out so everyone gets the same!", "style": "A"}, {"key": "dgirbd", "text": "Two friends want some chocolate bar, and they must all get the same. Which piece is fair?", "style": "A"}, {"key": "h7x5na", "text": "Two friends are waiting, and there are four oranges. Share them out so everyone gets the same!", "style": "A"}, {"key": "12bcy0v", "text": "Two friends are waiting, and there are eight oranges. Share them out so everyone gets the same!", "style": "A"}, {"key": "1dx2gdc", "text": "Two friends are waiting, and there are four pears. Share them out so everyone gets the same!", "style": "A"}, {"key": "11ft4ez", "text": "Four friends are waiting, and there are twelve pears. Share them out so everyone gets the same!", "style": "A"}, {"key": "by22vt", "text": "Four friends are waiting, and there are twelve oranges. Share them out so everyone gets the same!", "style": "A"}, {"key": "1p95hrv", "text": "Two friends are waiting, and there are eight cherries. Share them out so everyone gets the same!", "style": "A"}, {"key": "18ltaaf", "text": "Four friends are waiting, and there are eight cherries. Share them out so everyone gets the same!", "style": "A"}, {"key": "1trqxyc", "text": "Two friends are waiting, and there are six cherries. Share them out so everyone gets the same!", "style": "A"}, {"key": "1kqdawg", "text": "Two friends are waiting, and there are six pears. Share them out so everyone gets the same!", "style": "A"}, {"key": "umxzt9", "text": "Two friends are waiting, and there are eight pears. Share them out so everyone gets the same!", "style": "A"}, {"key": "12vsish", "text": "Four friends, four equal pieces. Each one gets a quarter!", "style": "A"}, {"key": "i8iarq", "text": "Three friends, three equal piles — two cherries each. One third of six is two!", "style": "A"}, {"key": "12rx6po", "text": "Two equal pieces — a half each. Nobody got more than anybody else!", "style": "A"}, {"key": "ky00bk", "text": "Three friends, three equal pieces. Each one gets a third!", "style": "A"}, {"key": "kzt5uh", "text": "Three friends, three equal piles — four pears each. One third of twelve is four!", "style": "A"}, {"key": "1kd0z15", "text": "Four equal pieces — a quarter each. Nobody got more than anybody else!", "style": "A"}, {"key": "1o2a0pb", "text": "Three friends, three equal piles — four cherries each. One third of twelve is four!", "style": "A"}, {"key": "5cuols", "text": "Three equal pieces — a third each. Nobody got more than anybody else!", "style": "A"}, {"key": "plrnuq", "text": "Four friends, four equal piles — three oranges each. One quarter of twelve is three!", "style": "A"}, {"key": "1fkfzns", "text": "Three friends, three equal piles — two pears each. One third of six is two!", "style": "A"}, {"key": "aqgw0r", "text": "Three friends, three equal piles — four oranges each. One third of twelve is four!", "style": "A"}, {"key": "ks4c1q", "text": "Four friends, four equal piles — three cherries each. One quarter of twelve is three!", "style": "A"}, {"key": "clgx96", "text": "Three friends, three equal piles — two oranges each. One third of six is two!", "style": "A"}, {"key": "1t7lwst", "text": "Two friends, two equal piles — four cherries each. One half of eight is four!", "style": "A"}, {"key": "wbhlcg", "text": "Two friends, two equal piles — three oranges each. One half of six is three!", "style": "A"}, {"key": "13hpbj0", "text": "Four friends, four equal piles — two cherries each. One quarter of eight is two!", "style": "A"}, {"key": "z6vkny", "text": "Two friends, two equal piles — two oranges each. One half of four is two!", "style": "A"}, {"key": "8gwhpo", "text": "Two friends, two equal piles — two pears each. One half of four is two!", "style": "A"}, {"key": "1kp74aq", "text": "Two friends, two equal piles — two cherries each. One half of four is two!", "style": "A"}, {"key": "xefvyo", "text": "Four friends, four equal piles — two oranges each. One quarter of eight is two!", "style": "A"}, {"key": "1fhls10", "text": "Two friends, two equal piles — three cherries each. One half of six is three!", "style": "A"}, {"key": "3qhnls", "text": "Four friends, four equal piles — three pears each. One quarter of twelve is three!", "style": "A"}, {"key": "1rpl9k1", "text": "Two friends, two equal piles — four oranges each. One half of eight is four!", "style": "A"}, {"key": "jdmdhy", "text": "Four friends, four equal piles — two pears each. One quarter of eight is two!", "style": "A"}, {"key": "b0wnpm", "text": "Two friends, two equal piles — three pears each. One half of six is three!", "style": "A"}, {"key": "s264ir", "text": "Two friends, two equal piles — four pears each. One half of eight is four!", "style": "A"}, {"key": "1wicbhs", "text": "Otter has a fish, seven. Count that out for me.", "style": "A"}, {"key": "dhb2v3", "text": "Hedgehog has a tulip, eleven. Count that out for me.", "style": "A"}, {"key": "rvcafp", "text": "Yes! That is eleven. The tulip is yours!", "style": "A"}, {"key": "1lyd944", "text": "Goat has a pot. This is what it costs. Count my coins, then pay me the same.", "style": "A"}, {"key": "12hs1sg", "text": "Yes! That is thirteen. The pot is yours!", "style": "A"}, {"key": "19lqox5", "text": "Badger has an egg, seventy-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "hrq32s", "text": "Yes! seventy-five in just three coins!", "style": "A"}, {"key": "kw8xa3", "text": "Fox has an apple. This is what it costs. Count my coins, then pay me the same.", "style": "A"}, {"key": "tvietv", "text": "Yes! That is ten. The apple is yours!", "style": "A"}, {"key": "1kuj40o", "text": "Otter has a fish, twenty. Count that out for me.", "style": "A"}, {"key": "1crko07", "text": "Yes! That is twenty. The fish is yours!", "style": "A"}, {"key": "zvds6b", "text": "Bear has a bun. This is what it costs. Count my coins — now pay me the same with as few as you can.", "style": "A"}, {"key": "jb0mbc", "text": "Yes! forty-six in just four coins!", "style": "A"}, {"key": "1iuhj5e", "text": "Goat has a pot, fifteen. Count that out for me.", "style": "A"}, {"key": "1rf65dq", "text": "Yes! That is fifteen. The pot is yours!", "style": "A"}, {"key": "pver1d", "text": "Hedgehog has a tulip. This is what it costs. Count my coins, then pay me the same.", "style": "A"}, {"key": "5yy5h5", "text": "Yes! That is seventeen. The tulip is yours!", "style": "A"}, {"key": "jejrh", "text": "Badger has an egg, twenty. Try again — with as few coins as you can.", "style": "A"}, {"key": "1b1yf1a", "text": "Yes! twenty in just two coins!", "style": "A"}, {"key": "15hqw7y", "text": "Otter has a fish. This is what it costs. Count my coins, then pay me the same.", "style": "A"}, {"key": "v9ts5r", "text": "Yes! That is seven. The fish is yours!", "style": "A"}, {"key": "1vps05r", "text": "Hedgehog has a tulip, thirty-five. Count that out for me.", "style": "A"}, {"key": "18t6own", "text": "Yes! That is thirty-five. The tulip is yours!", "style": "A"}, {"key": "1t2d9xy", "text": "Goat has a pot. This is what it costs. Count my coins — now pay me the same with as few as you can.", "style": "A"}, {"key": "gqfq69", "text": "Yes! twenty-five in just one coins!", "style": "A"}, {"key": "1s1eu5h", "text": "Badger has an egg, six. Count that out for me.", "style": "A"}, {"key": "q4a9l3", "text": "Yes! That is six. The egg is yours!", "style": "A"}, {"key": "13btxll", "text": "Yes! That is twelve. The apple is yours!", "style": "A"}, {"key": "1t3k535", "text": "Otter has a fish, thirty. Count that out for me.", "style": "A"}, {"key": "1g7hylm", "text": "Yes! That is thirty. The fish is yours!", "style": "A"}, {"key": "1qqzs6r", "text": "Bear has a bun. This is what it costs. Count my coins, then pay me the same.", "style": "A"}, {"key": "1rpjjqj", "text": "Yes! That is six. The bun is yours!", "style": "A"}, {"key": "1dlc4v8", "text": "Goat has a pot, thirteen. Count that out for me.", "style": "A"}, {"key": "183r176", "text": "Yes! That is twenty-one. The tulip is yours!", "style": "A"}, {"key": "4e3u7x", "text": "Badger has an egg, three. Count that out for me.", "style": "A"}, {"key": "zs1xlj", "text": "Yes! That is three. The egg is yours!", "style": "A"}, {"key": "1cd4eb3", "text": "Yes! That is thirty-one. The fish is yours!", "style": "A"}, {"key": "1qy0um2", "text": "Hedgehog has a tulip, forty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "1ki4ttk", "text": "Yes! That is ten. The pot is yours!", "style": "A"}, {"key": "my0u2o", "text": "Badger has an egg, seventeen. Count that out for me.", "style": "A"}, {"key": "wqdju4", "text": "Yes! That is seventeen. The egg is yours!", "style": "A"}, {"key": "1oxk0ic", "text": "Yes! That is twenty-two. The apple is yours!", "style": "A"}, {"key": "128f7ow", "text": "Otter has a fish, eleven. Count that out for me.", "style": "A"}, {"key": "140cy4v", "text": "Yes! That is eleven. The fish is yours!", "style": "A"}, {"key": "1hko34z", "text": "Yes! That is twenty-five. The bun is yours!", "style": "A"}, {"key": "1tzir0n", "text": "Goat has a pot, four. Count that out for me.", "style": "A"}, {"key": "80kp5x", "text": "Yes! That is four. The pot is yours!", "style": "A"}, {"key": "1a6unsf", "text": "Yes! That is ten. The tulip is yours!", "style": "A"}, {"key": "1o7h984", "text": "Badger has an egg, twelve. Count that out for me.", "style": "A"}, {"key": "1de4fbs", "text": "Yes! That is twelve. The egg is yours!", "style": "A"}, {"key": "1nr3n7k", "text": "Hedgehog has a tulip, six. Count that out for me.", "style": "A"}, {"key": "ciyq6", "text": "Yes! That is six. The tulip is yours!", "style": "A"}, {"key": "1qyx0ay", "text": "Yes! That is twenty. The pot is yours!", "style": "A"}, {"key": "1wpnv09", "text": "Badger has an egg, twenty-one. Count that out for me.", "style": "A"}, {"key": "1k2ebl7", "text": "Yes! That is twenty-one. The egg is yours!", "style": "A"}, {"key": "1dnapwh", "text": "Otter has a fish, twenty-five. Count that out for me.", "style": "A"}, {"key": "19p2z7u", "text": "Yes! That is twenty-five. The fish is yours!", "style": "A"}, {"key": "1mhn29g", "text": "Yes! That is fifteen. The bun is yours!", "style": "A"}, {"key": "1n32i9j", "text": "Goat has a pot, six. Count that out for me.", "style": "A"}, {"key": "vi2rkx", "text": "Yes! That is six. The pot is yours!", "style": "A"}, {"key": "1o1z62d", "text": "Yes! That is thirty-one. The tulip is yours!", "style": "A"}, {"key": "32kkke", "text": "Badger has an egg, seventy-one. Count that out for me.", "style": "A"}, {"key": "g4gfwm", "text": "Yes! That is seventy-one. The egg is yours!", "style": "A"}, {"key": "1sp8uac", "text": "Hedgehog has a tulip, sixteen. Count that out for me.", "style": "A"}, {"key": "1itv73m", "text": "Yes! That is sixteen. The tulip is yours!", "style": "A"}, {"key": "bzfi68", "text": "Yes! thirteen in just four coins!", "style": "A"}, {"key": "1ruc603", "text": "Badger has an egg, two. Count that out for me.", "style": "A"}, {"key": "1i69rd5", "text": "Yes! That is two. The egg is yours!", "style": "A"}, {"key": "3x8rxq", "text": "Yes! That is sixteen. The apple is yours!", "style": "A"}, {"key": "25370w", "text": "Otter has a fish, thirty-one. Count that out for me.", "style": "A"}, {"key": "teusod", "text": "Yes! That is two. The bun is yours!", "style": "A"}, {"key": "147vjwv", "text": "Goat has a pot, sixteen. Count that out for me.", "style": "A"}, {"key": "pvmrm5", "text": "Yes! That is sixteen. The pot is yours!", "style": "A"}, {"key": "72lwtq", "text": "Yes! That is twenty-six. The tulip is yours!", "style": "A"}, {"key": "jzs3g4", "text": "Badger has an egg, eleven. Count that out for me.", "style": "A"}, {"key": "19sa4ig", "text": "Yes! That is eleven. The egg is yours!", "style": "A"}, {"key": "zbyk6q", "text": "Yes! That is forty. The fish is yours!", "style": "A"}, {"key": "1tbt52b", "text": "Hedgehog has a tulip, thirty-seven. Try again — with as few coins as you can.", "style": "A"}, {"key": "c65d2f", "text": "Yes! thirty-seven in just four coins!", "style": "A"}, {"key": "ywapl5", "text": "Badger has an egg, sixteen. Count that out for me.", "style": "A"}, {"key": "9srb0r", "text": "Yes! That is sixteen. The egg is yours!", "style": "A"}, {"key": "wqd3ej", "text": "Fox has an apple. This is what it costs. Count my coins — now pay me the same with as few as you can.", "style": "A"}, {"key": "1pduw6o", "text": "Yes! forty-one in just four coins!", "style": "A"}, {"key": "u6n1nt", "text": "Otter has a fish, three. Count that out for me.", "style": "A"}, {"key": "aeeybm", "text": "Yes! That is three. The fish is yours!", "style": "A"}, {"key": "1sakoqv", "text": "Yes! That is sixteen. The bun is yours!", "style": "A"}, {"key": "1vytvk7", "text": "Goat has a pot, twenty-seven. Try again — with as few coins as you can.", "style": "A"}, {"key": "13kow4", "text": "Yes! twenty-seven in just three coins!", "style": "A"}, {"key": "556vsg", "text": "Yes! That is two. The tulip is yours!", "style": "A"}, {"key": "16e4hrj", "text": "Yes! That is twenty-seven. The fish is yours!", "style": "A"}, {"key": "1niwk49", "text": "Yes! That is thirty. The pot is yours!", "style": "A"}, {"key": "12kc56s", "text": "Badger has an egg, twenty-seven. Count that out for me.", "style": "A"}, {"key": "6fy4fs", "text": "Yes! That is twenty-seven. The egg is yours!", "style": "A"}, {"key": "qcdpmc", "text": "Yes! That is two. The apple is yours!", "style": "A"}, {"key": "1ayc0va", "text": "Yes! That is fifty-one. The bun is yours!", "style": "A"}, {"key": "1quliw6", "text": "Goat has a pot, eleven. Count that out for me.", "style": "A"}, {"key": "1chp782", "text": "Yes! That is eleven. The pot is yours!", "style": "A"}, {"key": "1tieatn", "text": "Yes! That is eight. The tulip is yours!", "style": "A"}, {"key": "148lcsg", "text": "Badger has an egg, fifty-five. Count that out for me.", "style": "A"}, {"key": "jjegng", "text": "Yes! That is fifty-five. The egg is yours!", "style": "A"}, {"key": "y5nbku", "text": "Hedgehog has a tulip, twenty-one. Count that out for me.", "style": "A"}, {"key": "1n6btnl", "text": "Yes! twenty-two in just four coins!", "style": "A"}, {"key": "jdpyh8", "text": "Badger has an egg, seven. Count that out for me.", "style": "A"}, {"key": "w6x5js", "text": "Yes! That is seven. The egg is yours!", "style": "A"}, {"key": "1wx601u", "text": "Yes! That is three. The apple is yours!", "style": "A"}, {"key": "thffac", "text": "Otter has a fish, seventeen. Count that out for me.", "style": "A"}, {"key": "18xk263", "text": "Yes! That is seventeen. The fish is yours!", "style": "A"}, {"key": "pnaisb", "text": "Yes! That is three. The bun is yours!", "style": "A"}, {"key": "1jzvsff", "text": "Goat has a pot, twenty-one. Count that out for me.", "style": "A"}, {"key": "mejjal", "text": "Yes! That is twenty-one. The pot is yours!", "style": "A"}, {"key": "1qqy4p", "text": "Yes! That is eighty-five. The tulip is yours!", "style": "A"}, {"key": "12hwk7v", "text": "Hedgehog has a tulip, twelve. Count that out for me.", "style": "A"}, {"key": "gve2ol", "text": "Yes! That is twelve. The tulip is yours!", "style": "A"}, {"key": "vt8h9g", "text": "Badger has an egg, twenty. Count that out for me.", "style": "A"}, {"key": "1amkgps", "text": "Yes! That is twenty. The egg is yours!", "style": "A"}, {"key": "1q9xc9m", "text": "Yes! That is forty-seven. The apple is yours!", "style": "A"}, {"key": "lpyr2x", "text": "Otter has a fish, six. Count that out for me.", "style": "A"}, {"key": "1kq5ar6", "text": "Yes! That is six. The fish is yours!", "style": "A"}, {"key": "1mef55h", "text": "Yes! That is seven. The tulip is yours!", "style": "A"}, {"key": "15akc8y", "text": "Badger has an egg, thirty-five. Count that out for me.", "style": "A"}, {"key": "16zkf9u", "text": "Yes! That is thirty-five. The egg is yours!", "style": "A"}, {"key": "1yz5slp", "text": "Yes! That is thirty-five. The fish is yours!", "style": "A"}, {"key": "hi8bpu", "text": "Badger has an egg, fifty-six. Count that out for me.", "style": "A"}, {"key": "uu1uky", "text": "Yes! That is fifty-six. The egg is yours!", "style": "A"}, {"key": "14p9776", "text": "Yes! That is six. The apple is yours!", "style": "A"}, {"key": "sddbv5", "text": "Yes! That is fifty. The bun is yours!", "style": "A"}, {"key": "zw7phq", "text": "Goat has a pot, seven. Count that out for me.", "style": "A"}, {"key": "ywc89e", "text": "Yes! That is seven. The pot is yours!", "style": "A"}, {"key": "t10ezq", "text": "Badger has an egg, sixteen. Try again — with as few coins as you can.", "style": "A"}, {"key": "1ncl0x5", "text": "Yes! sixteen in just three coins!", "style": "A"}, {"key": "1xpai6", "text": "Yes! forty-five in just three coins!", "style": "A"}, {"key": "1pzcob6", "text": "Badger has an egg, ten. Count that out for me.", "style": "A"}, {"key": "k0ex3e", "text": "Yes! That is ten. The egg is yours!", "style": "A"}, {"key": "14r47e", "text": "Yes! That is twenty-five. The apple is yours!", "style": "A"}, {"key": "18z8upy", "text": "Otter has a fish, seventy-six. Count that out for me.", "style": "A"}, {"key": "q9phsd", "text": "Yes! That is seventy-six. The fish is yours!", "style": "A"}, {"key": "jboaf2", "text": "Goat has a pot, twelve. Count that out for me.", "style": "A"}, {"key": "k25z4i", "text": "Yes! That is twelve. The pot is yours!", "style": "A"}, {"key": "pptpy", "text": "Yes! That is twenty-five. The tulip is yours!", "style": "A"}, {"key": "e1eprt", "text": "Hedgehog has a tulip, forty-one. Count that out for me.", "style": "A"}, {"key": "fgh7od", "text": "Yes! That is forty-one. The tulip is yours!", "style": "A"}, {"key": "15jqv45", "text": "Badger has an egg, twenty-five. Count that out for me.", "style": "A"}, {"key": "13xt5hr", "text": "Yes! That is twenty-five. The egg is yours!", "style": "A"}, {"key": "5v0sjn", "text": "Yes! sixty-one in just four coins!", "style": "A"}, {"key": "1ul6upm", "text": "Yes! That is thirteen. The bun is yours!", "style": "A"}, {"key": "1px0uu9", "text": "Goat has a pot, seventy-seven. Count that out for me.", "style": "A"}, {"key": "1lk706v", "text": "Yes! That is seventy-seven. The pot is yours!", "style": "A"}, {"key": "wz6dy3", "text": "Badger has an egg, twenty-two. Count that out for me.", "style": "A"}, {"key": "q77m5l", "text": "Yes! That is twenty-two. The egg is yours!", "style": "A"}, {"key": "jpnm2j", "text": "Yes! That is fifteen. The fish is yours!", "style": "A"}, {"key": "12jropl", "text": "Hedgehog has a tulip, seven. Count that out for me.", "style": "A"}, {"key": "3rdrr5", "text": "Yes! That is twenty-six. The pot is yours!", "style": "A"}, {"key": "byziit", "text": "Badger has an egg, forty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "11iy4e1", "text": "Otter has a fish, twenty-six. Count that out for me.", "style": "A"}, {"key": "vnee6q", "text": "Yes! That is twenty-six. The fish is yours!", "style": "A"}, {"key": "1f1m9q0", "text": "Yes! That is thirty-six. The bun is yours!", "style": "A"}, {"key": "1fjdtr8", "text": "Goat has a pot, ten. Count that out for me.", "style": "A"}, {"key": "1z10y3h", "text": "Yes! That is twenty. The tulip is yours!", "style": "A"}, {"key": "1kd8xb6", "text": "Badger has an egg, thirty. Try again — with as few coins as you can.", "style": "A"}, {"key": "kd6qdl", "text": "Yes! thirty in just two coins!", "style": "A"}, {"key": "19r6hwd", "text": "Hedgehog has a tulip, seventeen. Count that out for me.", "style": "A"}, {"key": "m8bsx3", "text": "Yes! twenty-one in just three coins!", "style": "A"}, {"key": "1pw0qoe", "text": "Yes! That is twenty-one. The apple is yours!", "style": "A"}, {"key": "c4vk3k", "text": "Otter has a fish, thirty-six. Count that out for me.", "style": "A"}, {"key": "4fhezj", "text": "Yes! That is thirty-six. The fish is yours!", "style": "A"}, {"key": "pj1r23", "text": "Goat has a pot, twenty-six. Count that out for me.", "style": "A"}, {"key": "1k6g0d9", "text": "Hedgehog has a tulip. This is what it costs. Count my coins — now pay me the same with as few as you can.", "style": "A"}, {"key": "1mag5nw", "text": "Yes! fifty-one in just three coins!", "style": "A"}, {"key": "8cu28w", "text": "Hedgehog has a tulip, eleven. Try again — with as few coins as you can.", "style": "A"}, {"key": "60ylwe", "text": "Yes! eleven in just two coins!", "style": "A"}, {"key": "zxw99i", "text": "Yes! fifty-six in just four coins!", "style": "A"}, {"key": "1u3zev4", "text": "Yes! That is twenty. The bun is yours!", "style": "A"}, {"key": "1ug64ae", "text": "Goat has a pot, forty-one. Count that out for me.", "style": "A"}, {"key": "514pxm", "text": "Yes! That is forty-one. The pot is yours!", "style": "A"}, {"key": "1uoe49b", "text": "Yes! That is twelve. The fish is yours!", "style": "A"}, {"key": "1o0avzy", "text": "Badger has an egg, fifty-one. Count that out for me.", "style": "A"}, {"key": "19lw3k6", "text": "Yes! That is fifty-one. The egg is yours!", "style": "A"}, {"key": "pzkgvp", "text": "Yes! That is fifteen. The apple is yours!", "style": "A"}, {"key": "42eyc2", "text": "Yes! That is forty-five. The bun is yours!", "style": "A"}, {"key": "oo1j07", "text": "Goat has a pot, three. Count that out for me.", "style": "A"}, {"key": "1i0s59t", "text": "Yes! That is three. The pot is yours!", "style": "A"}, {"key": "18au8um", "text": "Yes! That is forty. The tulip is yours!", "style": "A"}, {"key": "zmjgg9", "text": "Badger has an egg, fifty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "17elxc0", "text": "Yes! fifty-five in just three coins!", "style": "A"}, {"key": "1qq33dn", "text": "Otter has a fish, sixty-five. Count that out for me.", "style": "A"}, {"key": "1spnb58", "text": "Yes! That is sixty-five. The fish is yours!", "style": "A"}, {"key": "1lrq8dq", "text": "Goat has a pot, seventeen. Count that out for me.", "style": "A"}, {"key": "1pmsrpa", "text": "Yes! That is seventeen. The pot is yours!", "style": "A"}, {"key": "10q95xp", "text": "Hedgehog has a tulip, forty. Try again — with as few coins as you can.", "style": "A"}, {"key": "n0o6xp", "text": "Yes! forty in just three coins!", "style": "A"}, {"key": "1i7swiz", "text": "Yes! That is fifty-six. The apple is yours!", "style": "A"}, {"key": "z51rj", "text": "Otter has a fish, two. Count that out for me.", "style": "A"}, {"key": "1lirt48", "text": "Yes! That is two. The fish is yours!", "style": "A"}, {"key": "4fvqbn", "text": "Goat has a pot, twenty-five. Count that out for me.", "style": "A"}, {"key": "110aibd", "text": "Yes! That is twenty-five. The pot is yours!", "style": "A"}, {"key": "n02h3t", "text": "Yes! That is seven. The apple is yours!", "style": "A"}, {"key": "16iiomg", "text": "Yes! That is twenty-seven. The bun is yours!", "style": "A"}, {"key": "2jvzay", "text": "Yes! That is four. The tulip is yours!", "style": "A"}, {"key": "184xcox", "text": "Badger has an egg, eighty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "5dkpvg", "text": "Yes! eighty-five in just four coins!", "style": "A"}, {"key": "1nbspvy", "text": "Yes! thirty-five in just two coins!", "style": "A"}, {"key": "1dsk3h5", "text": "Otter has a fish, forty. Count that out for me.", "style": "A"}, {"key": "m88kau", "text": "Yes! That is four. The fish is yours!", "style": "A"}, {"key": "kwo96j", "text": "Hedgehog has a tulip, sixty. Count that out for me.", "style": "A"}, {"key": "9debmf", "text": "Yes! That is sixty. The tulip is yours!", "style": "A"}, {"key": "1remfx1", "text": "Yes! That is fifty-five. The apple is yours!", "style": "A"}, {"key": "1b7fzgf", "text": "Yes! That is four. The bun is yours!", "style": "A"}, {"key": "1mmrv3t", "text": "Goat has a pot, sixty-one. Count that out for me.", "style": "A"}, {"key": "aav2s3", "text": "Yes! That is sixty-one. The pot is yours!", "style": "A"}, {"key": "1wojm8s", "text": "Otter has a fish. This is what it costs. Count my coins — now pay me the same with as few as you can.", "style": "A"}, {"key": "17ov6q9", "text": "Yes! That is seventy. The bun is yours!", "style": "A"}, {"key": "7nuaz9", "text": "Badger has an egg, twenty-three. Count that out for me.", "style": "A"}, {"key": "o1gdfb", "text": "Yes! That is twenty-three. The egg is yours!", "style": "A"}, {"key": "10eefr7", "text": "Yes! That is sixty-six. The pot is yours!", "style": "A"}, {"key": "or6v56", "text": "Yes! That is thirty. The apple is yours!", "style": "A"}, {"key": "ztnl36", "text": "Yes! That is ten. The bun is yours!", "style": "A"}, {"key": "pv7oaf", "text": "Hedgehog has a tulip, thirty-six. Count that out for me.", "style": "A"}, {"key": "a6rk5h", "text": "Yes! That is thirty-six. The tulip is yours!", "style": "A"}, {"key": "1dzlj53", "text": "Yes! That is two. The pot is yours!", "style": "A"}, {"key": "1gddvs7", "text": "Yes! That is fifty-one. The apple is yours!", "style": "A"}, {"key": "ux4nsg", "text": "Otter has a fish, twelve. Count that out for me.", "style": "A"}, {"key": "kn1fbf", "text": "Yes! That is twenty-six. The bun is yours!", "style": "A"}, {"key": "t79vsb", "text": "Yes! That is thirteen. The apple is yours!", "style": "A"}, {"key": "1p7tsw3", "text": "Otter has a fish, sixty-one. Count that out for me.", "style": "A"}, {"key": "16kcsn8", "text": "Yes! That is sixty-one. The fish is yours!", "style": "A"}, {"key": "1crqpst", "text": "Yes! That is fifty-two. The tulip is yours!", "style": "A"}, {"key": "zxh382", "text": "Hedgehog has a tulip, forty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "4arpbb", "text": "Yes! That is twenty-one. The bun is yours!", "style": "A"}, {"key": "1uwsqoc", "text": "Goat has a pot, eighty-one. Count that out for me.", "style": "A"}, {"key": "m1y5u4", "text": "Yes! That is eighty-one. The pot is yours!", "style": "A"}, {"key": "5x010c", "text": "Badger has an egg, forty-one. Count that out for me.", "style": "A"}, {"key": "1npw8bk", "text": "Yes! That is forty-one. The egg is yours!", "style": "A"}, {"key": "etjs6m", "text": "Yes! That is twenty-one. The fish is yours!", "style": "A"}, {"key": "mat97r", "text": "Hedgehog has a tulip, eight. Count that out for me.", "style": "A"}, {"key": "1ojmpni", "text": "Badger has an egg, eight. Count that out for me.", "style": "A"}, {"key": "nfgg2e", "text": "Yes! That is eight. The egg is yours!", "style": "A"}, {"key": "hq1k0e", "text": "Hedgehog has a tulip, two. Count that out for me.", "style": "A"}, {"key": "evbziv", "text": "Badger has an egg, thirty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "15cyu0t", "text": "Otter has a fish, twenty-one. Count that out for me.", "style": "A"}, {"key": "4iry5c", "text": "Hedgehog has a tulip, three. Count that out for me.", "style": "A"}, {"key": "hqci66", "text": "Yes! That is three. The tulip is yours!", "style": "A"}, {"key": "1vivkv2", "text": "Yes! That is fifty-five. The pot is yours!", "style": "A"}, {"key": "1ufwyjw", "text": "Otter has a fish, fifty. Try again — with as few coins as you can.", "style": "A"}, {"key": "7ncswt", "text": "Yes! fifty in just two coins!", "style": "A"}, {"key": "1fef8ys", "text": "Hedgehog has a tulip, forty. Count that out for me.", "style": "A"}, {"key": "zxsf71", "text": "Badger has an egg, twenty-six. Count that out for me.", "style": "A"}, {"key": "16f0vc7", "text": "Yes! That is twenty-six. The egg is yours!", "style": "A"}, {"key": "8znzr0", "text": "Yes! That is fifty. The fish is yours!", "style": "A"}, {"key": "1tz9s6l", "text": "Badger has an egg, twenty-seven. Try again — with as few coins as you can.", "style": "A"}, {"key": "17oanxk", "text": "Yes! That is thirty-one. The bun is yours!", "style": "A"}, {"key": "b54gqs", "text": "Badger has an egg, thirty-three. Count that out for me.", "style": "A"}, {"key": "nb377s", "text": "Yes! That is thirty-three. The egg is yours!", "style": "A"}, {"key": "lgizhc", "text": "Badger has an egg, fifteen. Count that out for me.", "style": "A"}, {"key": "yiqxik", "text": "Yes! That is fifteen. The egg is yours!", "style": "A"}, {"key": "1b30jt4", "text": "Yes! That is twenty-two. The fish is yours!", "style": "A"}, {"key": "1ihc0ig", "text": "Hedgehog has a tulip, thirty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "57y42k", "text": "Yes! thirty-six in just three coins!", "style": "A"}, {"key": "8p0ic5", "text": "Badger has an egg, thirty. Count that out for me.", "style": "A"}, {"key": "3quai7", "text": "Yes! That is thirty. The egg is yours!", "style": "A"}, {"key": "15d3zcb", "text": "Yes! That is sixty. The apple is yours!", "style": "A"}, {"key": "1ccmwbi", "text": "Otter has a fish, ten. Count that out for me.", "style": "A"}, {"key": "qrpe1h", "text": "Yes! That is ten. The fish is yours!", "style": "A"}, {"key": "ga3lwe", "text": "Goat has a pot, twenty. Count that out for me.", "style": "A"}, {"key": "1wswclh", "text": "Yes! That is forty-five. The fish is yours!", "style": "A"}, {"key": "jdv3zv", "text": "Hedgehog has a tulip, ten. Count that out for me.", "style": "A"}, {"key": "anahf9", "text": "Badger has an egg, thirty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "c3zyoc", "text": "Badger has an egg, thirty-six. Count that out for me.", "style": "A"}, {"key": "5i5i7c", "text": "Yes! That is thirty-six. The egg is yours!", "style": "A"}, {"key": "yr2thw", "text": "Otter has a fish, eighteen. Count that out for me.", "style": "A"}, {"key": "17bhxbf", "text": "Yes! That is eighteen. The fish is yours!", "style": "A"}, {"key": "m838t3", "text": "Yes! That is fifty-six. The tulip is yours!", "style": "A"}, {"key": "8und5s", "text": "Hedgehog has a tulip, twenty-five. Count that out for me.", "style": "A"}, {"key": "s5qzw", "text": "Goat has a pot, twenty-eight. Count that out for me.", "style": "A"}, {"key": "1gp0fqk", "text": "Yes! That is twenty-eight. The pot is yours!", "style": "A"}, {"key": "rwvbb9", "text": "Yes! That is thirty-two. The fish is yours!", "style": "A"}, {"key": "txkkng", "text": "Yes! That is eight. The pot is yours!", "style": "A"}, {"key": "ql9w4t", "text": "Badger has an egg, forty. Count that out for me.", "style": "A"}, {"key": "1wjkcuf", "text": "Yes! That is forty. The egg is yours!", "style": "A"}, {"key": "139pdzk", "text": "Yes! That is twenty-two. The tulip is yours!", "style": "A"}, {"key": "15yvjy2", "text": "Badger has an egg, twenty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "14qdvyp", "text": "Yes! twenty-six in just two coins!", "style": "A"}, {"key": "4v7o20", "text": "Yes! sixty in just three coins!", "style": "A"}, {"key": "a8cw2h", "text": "Otter has a fish, twenty-seven. Try again — with as few coins as you can.", "style": "A"}, {"key": "pitq4o", "text": "Yes! That is eleven. The bun is yours!", "style": "A"}, {"key": "37xtwr", "text": "Hedgehog has a tulip, fifty-five. Count that out for me.", "style": "A"}, {"key": "v15h7d", "text": "Yes! That is fifty-five. The tulip is yours!", "style": "A"}, {"key": "64jj1w", "text": "Badger has an egg, thirty-one. Count that out for me.", "style": "A"}, {"key": "7lq3qw", "text": "Yes! That is thirty-one. The egg is yours!", "style": "A"}, {"key": "1hli5cq", "text": "Yes! That is forty-seven. The fish is yours!", "style": "A"}, {"key": "1qcqtot", "text": "Hedgehog has a tulip, fifteen. Count that out for me.", "style": "A"}, {"key": "zgdt4p", "text": "Yes! That is fifteen. The tulip is yours!", "style": "A"}, {"key": "8674hs", "text": "Yes! That is forty-one. The bun is yours!", "style": "A"}, {"key": "3c1msy", "text": "Hedgehog has a tulip, twenty-six. Count that out for me.", "style": "A"}, {"key": "1bx3sli", "text": "Otter has a fish, sixty. Count that out for me.", "style": "A"}, {"key": "1u9793h", "text": "Yes! That is sixty. The fish is yours!", "style": "A"}, {"key": "1144k7v", "text": "Hedgehog has a tulip, forty-two. Count that out for me.", "style": "A"}, {"key": "p53xh3", "text": "Yes! That is forty-two. The tulip is yours!", "style": "A"}, {"key": "pmq3x0", "text": "Goat has a pot, fifty-three. Count that out for me.", "style": "A"}, {"key": "13j1lao", "text": "Yes! That is fifty-three. The pot is yours!", "style": "A"}, {"key": "1ri3od5", "text": "Yes! That is eleven. The apple is yours!", "style": "A"}, {"key": "1ehmapc", "text": "Yes! That is forty-six. The bun is yours!", "style": "A"}, {"key": "q3e0wr", "text": "Otter has a fish, thirty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "bxgr60", "text": "Yes! That is seven. The bun is yours!", "style": "A"}, {"key": "qnq2wb", "text": "Goat has a pot, thirty. Count that out for me.", "style": "A"}, {"key": "zl1wvo", "text": "Hedgehog has a tulip, fifty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "bqpbl7", "text": "Yes! That is thirty-five. The apple is yours!", "style": "A"}, {"key": "1kp9ol0", "text": "Yes! That is seventeen. The bun is yours!", "style": "A"}, {"key": "arm3m5", "text": "Yes! That is fifty-six. The fish is yours!", "style": "A"}, {"key": "1eg94ve", "text": "Badger has an egg, forty-five. Count that out for me.", "style": "A"}, {"key": "5jm8hm", "text": "Yes! That is forty-five. The egg is yours!", "style": "A"}, {"key": "vlmokg", "text": "Yes! seventeen in just four coins!", "style": "A"}, {"key": "1amd7vv", "text": "Hedgehog has a tulip, fifty. Try again — with as few coins as you can.", "style": "A"}, {"key": "1ir9d0q", "text": "Goat has a pot, eighty. Try again — with as few coins as you can.", "style": "A"}, {"key": "1m2jvxh", "text": "Yes! eighty in just four coins!", "style": "A"}, {"key": "3nh972", "text": "Yes! That is sixteen. The fish is yours!", "style": "A"}, {"key": "1eh9mxh", "text": "Badger has an egg, thirty-seven. Count that out for me.", "style": "A"}, {"key": "1s33mo7", "text": "Yes! That is thirty-seven. The egg is yours!", "style": "A"}, {"key": "17vp9p0", "text": "Yes! That is fifty-five. The bun is yours!", "style": "A"}, {"key": "8gkf6e", "text": "Yes! That is thirty. The tulip is yours!", "style": "A"}, {"key": "1c79jk4", "text": "Otter has a fish, fifty-five. Count that out for me.", "style": "A"}, {"key": "19x2s63", "text": "Yes! That is fifty-five. The fish is yours!", "style": "A"}, {"key": "h3b7oq", "text": "Hedgehog has a tulip, sixty-one. Count that out for me.", "style": "A"}, {"key": "xgcgfo", "text": "Yes! That is sixty-one. The tulip is yours!", "style": "A"}, {"key": "h4auv", "text": "Yes! That is eighty-one. The apple is yours!", "style": "A"}, {"key": "1qkv5xk", "text": "Yes! That is twelve. The bun is yours!", "style": "A"}, {"key": "1yo5lxu", "text": "Goat has a pot, fifty-five. Count that out for me.", "style": "A"}, {"key": "s6ozs7", "text": "Yes! seventy in just four coins!", "style": "A"}, {"key": "1e8soan", "text": "Yes! That is sixty-two. The bun is yours!", "style": "A"}, {"key": "1l4hejl", "text": "Goat has a pot, two. Count that out for me.", "style": "A"}, {"key": "114aux6", "text": "Badger has an egg, sixty. Count that out for me.", "style": "A"}, {"key": "10bpqq", "text": "Yes! That is sixty. The egg is yours!", "style": "A"}, {"key": "10el6t8", "text": "Yes! That is seventy-one. The pot is yours!", "style": "A"}, {"key": "15bzdhi", "text": "Otter has a fish, fifty-six. Count that out for me.", "style": "A"}, {"key": "130gi10", "text": "Goat has a pot, thirty-five. Count that out for me.", "style": "A"}, {"key": "c3t0pc", "text": "Yes! That is thirty-five. The pot is yours!", "style": "A"}, {"key": "gw4477", "text": "Hedgehog has a tulip, seventy-one. Count that out for me.", "style": "A"}, {"key": "76ufq3", "text": "Yes! That is seventy-one. The tulip is yours!", "style": "A"}, {"key": "1u3zvnx", "text": "Goat has a pot, sixty. Try again — with as few coins as you can.", "style": "A"}, {"key": "1wvhafr", "text": "Yes! That is forty-six. The fish is yours!", "style": "A"}, {"key": "1h3fgax", "text": "Badger has an egg, seventeen. Try again — with as few coins as you can.", "style": "A"}, {"key": "ugq0fj", "text": "Hedgehog has a tulip, twenty. Count that out for me.", "style": "A"}, {"key": "uvb9zu", "text": "Yes! That is forty-six. The pot is yours!", "style": "A"}, {"key": "1kt8oqv", "text": "Hedgehog has a tulip, twenty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "uspgpe", "text": "Yes! That is twenty-six. The apple is yours!", "style": "A"}, {"key": "11xqvpc", "text": "Yes! twelve in just three coins!", "style": "A"}, {"key": "1obkjec", "text": "Badger has an egg, forty-six. Count that out for me.", "style": "A"}, {"key": "1umoz00", "text": "Yes! That is forty-six. The egg is yours!", "style": "A"}, {"key": "6c2aj2", "text": "Yes! That is thirty-seven. The tulip is yours!", "style": "A"}, {"key": "r51wwv", "text": "Hedgehog has a tulip, thirty-one. Count that out for me.", "style": "A"}, {"key": "1o8i477", "text": "Yes! That is thirty-two. The apple is yours!", "style": "A"}, {"key": "13u4zn3", "text": "Goat has a pot, thirty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "9nyva0", "text": "Yes! thirty-one in just three coins!", "style": "A"}, {"key": "vgo1ct", "text": "Otter has a fish, sixteen. Count that out for me.", "style": "A"}, {"key": "1g8wr2a", "text": "Hedgehog has a tulip, thirty. Count that out for me.", "style": "A"}, {"key": "1qxu4ai", "text": "Yes! That is sixty-two. The tulip is yours!", "style": "A"}, {"key": "i3o04k", "text": "Otter has a fish, fifteen. Count that out for me.", "style": "A"}, {"key": "1y7ru9y", "text": "Goat has a pot, thirty-six. Count that out for me.", "style": "A"}, {"key": "1fetxya", "text": "Yes! That is thirty-six. The pot is yours!", "style": "A"}, {"key": "1qj1ehz", "text": "Badger has an egg, sixty-five. Count that out for me.", "style": "A"}, {"key": "171exqt", "text": "Yes! That is sixty-five. The egg is yours!", "style": "A"}, {"key": "brogr7", "text": "Goat has a pot, twelve. Try again — with as few coins as you can.", "style": "A"}, {"key": "1y0lkkr", "text": "Yes! That is eighty-five. The fish is yours!", "style": "A"}, {"key": "f8jidj", "text": "Yes! That is twenty-two. The pot is yours!", "style": "A"}, {"key": "1vl08tz", "text": "Badger has an egg, thirty-two. Try again — with as few coins as you can.", "style": "A"}, {"key": "m0vkuc", "text": "Yes! thirty-two in just four coins!", "style": "A"}, {"key": "1aubecy", "text": "Badger has an egg, seventy-six. Count that out for me.", "style": "A"}, {"key": "1cm6xe", "text": "Yes! That is seventy-six. The egg is yours!", "style": "A"}, {"key": "1tw0ugs", "text": "Yes! That is fifty-one. The pot is yours!", "style": "A"}, {"key": "1vj8v79", "text": "Yes! That is seventeen. The apple is yours!", "style": "A"}, {"key": "okp4su", "text": "Hedgehog has a tulip, thirty-seven. Count that out for me.", "style": "A"}, {"key": "x3o9be", "text": "Goat has a pot, eighteen. Count that out for me.", "style": "A"}, {"key": "1kium26", "text": "Yes! That is eighteen. The pot is yours!", "style": "A"}, {"key": "x7elmv", "text": "Yes! That is forty-one. The fish is yours!", "style": "A"}, {"key": "1hpy036", "text": "Yes! That is thirty-one. The pot is yours!", "style": "A"}, {"key": "362c5q", "text": "Otter has a fish, forty-five. Count that out for me.", "style": "A"}, {"key": "19tuetf", "text": "Goat has a pot, forty-seven. Count that out for me.", "style": "A"}, {"key": "p1snbd", "text": "Yes! That is forty-seven. The pot is yours!", "style": "A"}, {"key": "1x4h6fr", "text": "Badger has an egg, sixty-one. Count that out for me.", "style": "A"}, {"key": "1hqcgal", "text": "Yes! That is sixty-one. The egg is yours!", "style": "A"}, {"key": "q9kezf", "text": "Otter has a fish, sixty. Try again — with as few coins as you can.", "style": "A"}, {"key": "16zn171", "text": "Hedgehog has a tulip, eighty. Try again — with as few coins as you can.", "style": "A"}, {"key": "1w8oa1j", "text": "Yes! That is thirteen. The tulip is yours!", "style": "A"}, {"key": "gbi3ko", "text": "Otter has a fish, forty-one. Count that out for me.", "style": "A"}, {"key": "1yb6m31", "text": "Yes! That is forty-six. The tulip is yours!", "style": "A"}, {"key": "fmuybz", "text": "Otter has a fish, twenty-two. Count that out for me.", "style": "A"}, {"key": "16o7zu", "text": "Yes! That is fifty-six. The bun is yours!", "style": "A"}, {"key": "puwfal", "text": "Goat has a pot, sixty-six. Count that out for me.", "style": "A"}, {"key": "4qb43k", "text": "Yes! That is fifty-two. The bun is yours!", "style": "A"}, {"key": "6bk2kw", "text": "Hedgehog has a tulip, twenty. Try again — with as few coins as you can.", "style": "A"}, {"key": "1aosj02", "text": "Yes! That is thirty-seven. The apple is yours!", "style": "A"}, {"key": "15dqnsd", "text": "Goat has a pot, thirty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "t1t8qx", "text": "Otter has a fish, thirty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "m0len5", "text": "Yes! That is forty-six. The apple is yours!", "style": "A"}, {"key": "18wp9j7", "text": "Yes! That is thirty. The bun is yours!", "style": "A"}, {"key": "1jhll2", "text": "Goat has a pot, thirty-three. Count that out for me.", "style": "A"}, {"key": "1k8bgg2", "text": "Yes! That is thirty-three. The pot is yours!", "style": "A"}, {"key": "127fwgm", "text": "Yes! That is eight. The bun is yours!", "style": "A"}, {"key": "d3q8z3", "text": "Badger has an egg, seventy. Count that out for me.", "style": "A"}, {"key": "y4pbc5", "text": "Yes! That is seventy. The egg is yours!", "style": "A"}, {"key": "1hax7k6", "text": "Otter has a fish, thirteen. Count that out for me.", "style": "A"}, {"key": "1fby2bx", "text": "Yes! That is thirteen. The fish is yours!", "style": "A"}, {"key": "12egzx6", "text": "Yes! That is forty-two. The bun is yours!", "style": "A"}, {"key": "136zlsq", "text": "Otter has a fish, seventy-one. Count that out for me.", "style": "A"}, {"key": "t41e3t", "text": "Yes! That is seventy-one. The fish is yours!", "style": "A"}, {"key": "13irbf5", "text": "Yes! That is forty-one. The apple is yours!", "style": "A"}, {"key": "19gjgpe", "text": "Badger has an egg, twenty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "17k8kic", "text": "Otter has a fish, eighty-five. Count that out for me.", "style": "A"}, {"key": "q54os", "text": "Hedgehog has a tulip, sixty. Try again — with as few coins as you can.", "style": "A"}, {"key": "dmgfci", "text": "Yes! That is forty. The apple is yours!", "style": "A"}, {"key": "lrreaf", "text": "Goat has a pot, forty. Count that out for me.", "style": "A"}, {"key": "2w8sv5", "text": "Yes! That is forty. The pot is yours!", "style": "A"}, {"key": "1qww7sc", "text": "Badger has an egg, fifty-two. Count that out for me.", "style": "A"}, {"key": "1ka07xc", "text": "Yes! That is fifty-two. The egg is yours!", "style": "A"}, {"key": "1wn79sz", "text": "Otter has a fish, forty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "atdljw", "text": "Yes! That is fifty. The tulip is yours!", "style": "A"}, {"key": "umq071", "text": "Hedgehog has a tulip, sixteen. Try again — with as few coins as you can.", "style": "A"}, {"key": "t01vgo", "text": "Yes! That is fifty. The apple is yours!", "style": "A"}, {"key": "1ehgaey", "text": "Yes! That is thirty-five. The bun is yours!", "style": "A"}, {"key": "n79w2b", "text": "Badger has an egg, fifty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "126sink", "text": "Yes! That is forty-two. The pot is yours!", "style": "A"}, {"key": "4ppwss", "text": "Hedgehog has a tulip, twenty-two. Count that out for me.", "style": "A"}, {"key": "19c223g", "text": "Yes! That is thirty-eight. The apple is yours!", "style": "A"}, {"key": "1sot8t9", "text": "Badger has an egg, forty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "1rhj4hx", "text": "Goat has a pot, sixty-five. Count that out for me.", "style": "A"}, {"key": "1davguz", "text": "Yes! That is sixty-five. The pot is yours!", "style": "A"}, {"key": "15il6qj", "text": "Badger has an egg, thirty-eight. Count that out for me.", "style": "A"}, {"key": "jcvj1d", "text": "Yes! That is thirty-eight. The egg is yours!", "style": "A"}, {"key": "r3f4h9", "text": "Otter has a fish, seventy-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "wtbpbp", "text": "Yes! That is twenty-seven. The tulip is yours!", "style": "A"}, {"key": "g6j9av", "text": "Badger has an egg, thirteen. Try again — with as few coins as you can.", "style": "A"}, {"key": "1ibaobz", "text": "Badger has an egg, sixty-six. Count that out for me.", "style": "A"}, {"key": "deadyl", "text": "Yes! That is sixty-six. The egg is yours!", "style": "A"}, {"key": "eanc7k", "text": "Yes! That is sixty. The pot is yours!", "style": "A"}, {"key": "ia5c0p", "text": "Otter has a fish, thirty-seven. Count that out for me.", "style": "A"}, {"key": "1eb2ywi", "text": "Yes! That is thirty-seven. The fish is yours!", "style": "A"}, {"key": "1859xrw", "text": "Hedgehog has a tulip, twenty-seven. Try again — with as few coins as you can.", "style": "A"}, {"key": "fjbpd7", "text": "Yes! That is seventy-six. The apple is yours!", "style": "A"}, {"key": "h4cfis", "text": "Goat has a pot, forty-two. Count that out for me.", "style": "A"}, {"key": "fpm8aw", "text": "Badger has an egg, sixty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "1bqkbvp", "text": "Yes! sixty-five in just four coins!", "style": "A"}, {"key": "1hmqc7l", "text": "Yes! That is fourteen. The pot is yours!", "style": "A"}, {"key": "1r8s6a9", "text": "Otter has a fish, forty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "1d4jkzk", "text": "Hedgehog has a tulip, thirty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "q0zzg9", "text": "Yes! That is twenty-seven. The apple is yours!", "style": "A"}, {"key": "1bupn7x", "text": "Yes! That is twenty-two. The bun is yours!", "style": "A"}, {"key": "12ibr5o", "text": "Yes! That is seventy. The fish is yours!", "style": "A"}, {"key": "36g7gm", "text": "Otter has a fish, thirty-five. Count that out for me.", "style": "A"}, {"key": "1w0mnvd", "text": "Otter has a fish, thirty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "1a0vepj", "text": "Hedgehog has a tulip, thirty-three. Count that out for me.", "style": "A"}, {"key": "1jfa4yt", "text": "Yes! That is thirty-three. The tulip is yours!", "style": "A"}, {"key": "ikt6y4", "text": "Goat has a pot, twenty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "1cvjkfy", "text": "Otter has a fish, twenty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "11hjcop", "text": "Yes! That is eight. The fish is yours!", "style": "A"}, {"key": "14z8k1e", "text": "Goat has a pot, twenty-seven. Count that out for me.", "style": "A"}, {"key": "1gk60s2", "text": "Yes! That is twenty-seven. The pot is yours!", "style": "A"}, {"key": "1ceg9m1", "text": "Badger has an egg, fifteen. Try again — with as few coins as you can.", "style": "A"}, {"key": "plc2pc", "text": "Yes! fifteen in just two coins!", "style": "A"}, {"key": "1qz02r1", "text": "Otter has a fish, fifty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "19vbmvv", "text": "Yes! That is fifty-one. The tulip is yours!", "style": "A"}, {"key": "rm1bs1", "text": "Hedgehog has a tulip, ninety. Count that out for me.", "style": "A"}, {"key": "st5lf3", "text": "Yes! That is ninety. The tulip is yours!", "style": "A"}, {"key": "dowomf", "text": "Yes! That is seventy-one. The apple is yours!", "style": "A"}, {"key": "1rdopcr", "text": "Goat has a pot, thirty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "78ll0b", "text": "Yes! That is seventy-five. The fish is yours!", "style": "A"}, {"key": "1hrqvfm", "text": "Badger has an egg, thirty-two. Count that out for me.", "style": "A"}, {"key": "1ki5e4a", "text": "Yes! That is thirty-two. The egg is yours!", "style": "A"}, {"key": "bb1e7t", "text": "Yes! That is sixty-one. The bun is yours!", "style": "A"}, {"key": "1a3nytl", "text": "Badger has an egg, sixty-two. Count that out for me.", "style": "A"}, {"key": "1mlgrbn", "text": "Yes! That is sixty-two. The egg is yours!", "style": "A"}, {"key": "s25697", "text": "Yes! That is seventy. The pot is yours!", "style": "A"}, {"key": "1n17cf", "text": "Otter has a fish, fifty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "1mzlpys", "text": "Yes! That is sixty-six. The fish is yours!", "style": "A"}, {"key": "i0r09s", "text": "Yes! That is fifty-seven. The tulip is yours!", "style": "A"}, {"key": "1dcb8tg", "text": "Goat has a pot, twenty-five. Try again — with as few coins as you can.", "style": "A"}, {"key": "z3pl0r", "text": "Yes! That is forty. The bun is yours!", "style": "A"}, {"key": "177k7vk", "text": "Goat has a pot, thirty-seven. Try again — with as few coins as you can.", "style": "A"}, {"key": "9107vg", "text": "Yes! That is seventy. The tulip is yours!", "style": "A"}, {"key": "1otjel8", "text": "Goat has a pot, ninety. Count that out for me.", "style": "A"}, {"key": "l9aym0", "text": "Yes! That is ninety. The pot is yours!", "style": "A"}, {"key": "xtl92a", "text": "Badger has an egg, thirty-seven. Try again — with as few coins as you can.", "style": "A"}, {"key": "dy9sda", "text": "Otter has a fish, thirty. Try again — with as few coins as you can.", "style": "A"}, {"key": "1grsa04", "text": "Hedgehog has a tulip, fifty-six. Try again — with as few coins as you can.", "style": "A"}, {"key": "1yx5gbx", "text": "Goat has a pot, fifty-one. Try again — with as few coins as you can.", "style": "A"}, {"key": "wpgm9a", "text": "Yes! That is eighty-five. The pot is yours!", "style": "A"}, {"key": "g0h0z3", "text": "Find the rectangle. Tap it!", "style": "A"}, {"key": "mpu0de", "text": "Find the circle. Tap it!", "style": "A"}, {"key": "bgmk66", "text": "Find the pentagon. Tap it!", "style": "A"}, {"key": "1awppmm", "text": "Find the triangle. Tap it!", "style": "A"}, {"key": "1bn4uyi", "text": "How many sides does this triangle have?", "style": "A"}, {"key": "byny5n", "text": "Find the square. Tap it!", "style": "A"}, {"key": "16rgp25", "text": "Find the cube. Tap it!", "style": "A"}, {"key": "1h2rtza", "text": "How many sides does this pentagon have?", "style": "A"}, {"key": "xyj8v9", "text": "Find the sphere. Tap it!", "style": "A"}, {"key": "gphs2w", "text": "Find the hexagon. Tap it!", "style": "A"}, {"key": "1udxhzy", "text": "Find the star. Tap it!", "style": "A"}, {"key": "18ftcw8", "text": "How many sides does this hexagon have?", "style": "A"}, {"key": "1ac7m9l", "text": "How many sides does this square have?", "style": "A"}, {"key": "lbuwap", "text": "How many sides does this rectangle have?", "style": "A"}, {"key": "omu45c", "text": "Find the cylinder. Tap it!", "style": "A"}, {"key": "1opgusr", "text": "Find the cone. Tap it!", "style": "A"}, {"key": "34m4ww", "text": "We have to count all the butterflies.", "style": "A"}, {"key": "4wqasu", "text": "Oh no — they keep moving. We lost count!", "style": "A"}, {"key": "1pfdo38", "text": "But look — they sit in familys of 2.", "style": "A"}, {"key": "1i4i6jh", "text": "So we can count the familys instead — much faster!", "style": "A"}, {"key": "m6p9pw", "text": "6! 3 familys of 2 makes 6.", "style": "A"}, {"key": "1u806te", "text": "We have to count all the ladybugs.", "style": "A"}, {"key": "1sric6t", "text": "But look — they sit in bunchs of 5.", "style": "A"}, {"key": "1kysod9", "text": "So we can count the bunchs instead — much faster!", "style": "A"}, {"key": "5zxlcb", "text": "15! 3 bunchs of 5 makes 15.", "style": "A"}, {"key": "1lep49x", "text": "We need 6 squirrels. They come in groups of 2. Tap a group to fetch it!", "style": "A"}, {"key": "1w1zwg3", "text": "We need 8 squirrels. They come in groups of 2. Tap a group to fetch it!", "style": "A"}, {"key": "up0dp9", "text": "We need 10 squirrels. They come in groups of 5. Tap a group to fetch it!", "style": "A"}, {"key": "1kd003y", "text": "We need 15 squirrels. They come in groups of 5. Tap a group to fetch it!", "style": "A"}, {"key": "d3z3fy", "text": "We have these blocks in the yard.", "style": "A"}, {"key": "pvwpm", "text": "More arrive — the rods join the row, the ones go on the ground.", "style": "A"}, {"key": "gpym9j", "text": "That is ten ones on the ground, and some still waiting.", "style": "A"}, {"key": "lh3334", "text": "Ten ones make one rod. It goes up to the row.", "style": "A"}, {"key": "n23yna", "text": "Now the waiting ones come in. Count the rods, then the ones.", "style": "A"}, {"key": "vws7xl", "text": "We have these blocks, and an order to send out.", "style": "A"}, {"key": "1oi3lp0", "text": "The ones go first — and we run out of them.", "style": "A"}, {"key": "q4y0st", "text": "So we fetch a rod back and break it open into ten ones.", "style": "A"}, {"key": "jfl4cw", "text": "Now we can finish the ones, and send the rods.", "style": "A"}, {"key": "1ghxlsi", "text": "Count the rods, then the ones.", "style": "A"}, {"key": "g075po", "text": "three pens of two chicks. Let’s skip-count!", "style": "A"}, {"key": "1n4k7gj", "text": "three times two is six! six chicks in all.", "style": "A"}, {"key": "1vkpchv", "text": "three rows of four bees. Let’s skip-count!", "style": "A"}, {"key": "1b8sk91", "text": "three times four is twelve! twelve bees in all.", "style": "A"}, {"key": "n5hm41", "text": "two nests of three birds. How many in all?", "style": "A"}, {"key": "1yi2f9g", "text": "two times three is six!", "style": "A"}, {"key": "1ut7ry0", "text": "Not yet — somebody else is still waiting for a piece. Keep going!", "style": "A"}, {"key": "1tibw66", "text": "Those pieces are too small — everyone would need more than one. Try a bigger piece.", "style": "A"}, {"key": "u3hicf", "text": "An apple — that is thirty.", "style": "A"}, {"key": "1wnc4mc", "text": "That is thirty. Just right.", "style": "A"}, {"key": "kf836g", "text": "A bun — that is thirty.", "style": "A"}, {"key": "1hqee1x", "text": "The same thirty — in only two coins.", "style": "A"}, {"key": "1j1t9ey", "text": "This is a triangle.", "style": "A"}, {"key": "9ze5ct", "text": "A triangle has 3 sides.", "style": "A"}, {"key": "1xncxk5", "text": "This is a cube.", "style": "A"}, {"key": "h09fw2", "text": "A cube is a solid shape you can hold.", "style": "A"}, {"key": "16beu8c", "text": "Art Studio", "style": "A"}, {"key": "1qug4aq", "text": "Build Site", "style": "A"}, {"key": "1nehl9w", "text": "Playroom", "style": "A"}, {"key": "n6tyki", "text": "Yes! A square!", "style": "A"}, {"key": "oiope4", "text": "Not quite — try again!", "style": "A"}, {"key": "1tgz31r", "text": "Ten ones on the ground, and more still waiting. Tap them — ten ones make one rod.", "style": "A"}, {"key": "7k7cfs", "text": "All in. How many altogether?", "style": "A"}, {"key": "116vh2o", "text": "Not enough ones left. Tap a rod to fetch it and break it open.", "style": "A"}, {"key": "1adk75l", "text": "All sent. How many are left?", "style": "A"}, {"key": "1qn0ykw", "text": "Not ten yet — count them.", "style": "A"}, {"key": "cgcefj", "text": "Ten ones make one rod. Now — how many altogether?", "style": "A"}, {"key": "eziepn", "text": "One rod opens back into ten ones. Now — how many are left?", "style": "A"}, {"key": "71f08m", "text": "Not that one. Count the rods, then the ones.", "style": "A"}, {"key": "4hn9zd", "text": "How many in all?", "style": "A"}, {"key": "7ed9vn", "text": "Yes! Let’s skip-count.", "style": "A"}, {"key": "1g5xhsy", "text": "Bunny and Duck both want some pizza. Just two friends, and one pizza.", "style": "A"}, {"key": "11psp6h", "text": "We cut it into two pieces — but look. Bunny got a big piece and Duck got a little one.", "style": "A"}, {"key": "157efb3", "text": "That is not fair, and it is not a half. A half means both pieces are the same.", "style": "A"}, {"key": "1jylx62", "text": "So we cut again. One piece for Bunny.", "style": "A"}, {"key": "1hbxuz4", "text": "and one for Duck, exactly the same size. Two friends, two equal pieces.", "style": "A"}, {"key": "1sk3rt9", "text": "They each get one half. Nobody got more than anybody else.", "style": "A"}, {"key": "1wmlb0r", "text": "Now watch. two more friends come along — that is four friends now.", "style": "A"}, {"key": "1smjvkq", "text": "Same pizza. But now we cut it into four pieces so everyone gets one.", "style": "A"}, {"key": "103x35o", "text": "Four friends, four equal pieces. Each one gets a quarter.", "style": "A"}, {"key": "z7ntgw", "text": "More friends means a smaller piece each. That is why a quarter is smaller than a half.", "style": "A"}, {"key": "1ajk5qn", "text": "Two friends share into halves. Three into thirds. Four into quarters.", "style": "A"}, {"key": "9cwljl", "text": "Your turn. three friends are waiting — fill the pizza so everybody gets one.", "style": "A"}, {"key": "xt5fb6", "text": "That is it — three equal pieces. Thirds! Now you can find a fraction.", "style": "A"}, {"key": "1sta3ye", "text": "Not enough yet — we need 8. Fetch another family!", "style": "A"}, {"key": "1r0ksty", "text": "That's too many — we only need 8. Tap the ones behind the frog to send a family back.", "style": "A"}, {"key": "14ts8sg", "text": "Not enough yet — we need 20. Fetch another bunch!", "style": "A"}, {"key": "133g3y", "text": "That's too many — we only need 20. Tap the ones behind the frog to send a bunch back.", "style": "A"}, {"key": "1khmpkf", "text": "Not enough yet — we need 20. Fetch another group!", "style": "A"}, {"key": "1vp3k5f", "text": "That's too many — we only need 20. Tap the ones behind the frog to send a group back.", "style": "A"}, {"key": "18xw8hs", "text": "Not enough yet — we need 10. Fetch another group!", "style": "A"}, {"key": "s6le1g", "text": "That's too many — we only need 10. Tap the ones behind the frog to send a group back.", "style": "A"}, {"key": "1mb3wls", "text": "Not enough yet — we need 20. Fetch another family!", "style": "A"}, {"key": "15vy8pa", "text": "That's too many — we only need 20. Tap the ones behind the frog to send a family back.", "style": "A"}, {"key": "tnrlb3", "text": "Not enough yet — we need 15. Fetch another group!", "style": "A"}, {"key": "aadiv3", "text": "That's too many — we only need 15. Tap the ones behind the frog to send a group back.", "style": "A"}, {"key": "3np140", "text": "Not enough yet — we need 15. Fetch another family!", "style": "A"}, {"key": "1ouag02", "text": "That's too many — we only need 15. Tap the ones behind the frog to send a family back.", "style": "A"}, {"key": "91ajk7", "text": "Not enough yet — we need 10. Fetch another bunch!", "style": "A"}, {"key": "to9mvt", "text": "That's too many — we only need 10. Tap the ones behind the frog to send a bunch back.", "style": "A"}, {"key": "1h55qy7", "text": "Not enough yet — we need 6. Fetch another group!", "style": "A"}, {"key": "18tg4sl", "text": "That's too many — we only need 6. Tap the ones behind the frog to send a group back.", "style": "A"}, {"key": "gpf35h", "text": "Not enough yet — we need 12. Fetch another bunch!", "style": "A"}, {"key": "10vyjmv", "text": "That's too many — we only need 12. Tap the ones behind the frog to send a bunch back.", "style": "A"}, {"key": "ue8q7f", "text": "Not enough yet — we need 12. Fetch another family!", "style": "A"}, {"key": "1vxfkel", "text": "That's too many — we only need 12. Tap the ones behind the frog to send a family back.", "style": "A"}, {"key": "aekvki", "text": "Not enough yet — we need 8. Fetch another bunch!", "style": "A"}, {"key": "hg8ap2", "text": "That's too many — we only need 8. Tap the ones behind the frog to send a bunch back.", "style": "A"}, {"key": "trujwg", "text": "Not enough yet — we need 6. Fetch another bunch!", "style": "A"}, {"key": "r2xtjc", "text": "That's too many — we only need 6. Tap the ones behind the frog to send a bunch back.", "style": "A"}, {"key": "556d37", "text": "Not enough yet — we need 30. Fetch another family!", "style": "A"}, {"key": "1se1y2p", "text": "That's too many — we only need 30. Tap the ones behind the frog to send a family back.", "style": "A"}, {"key": "6z1g9c", "text": "Not enough yet — we need 6. Fetch another family!", "style": "A"}, {"key": "18dmprg", "text": "That's too many — we only need 6. Tap the ones behind the frog to send a family back.", "style": "A"}, {"key": "13tqqr2", "text": "Not enough yet — we need 12. Fetch another group!", "style": "A"}, {"key": "172lmea", "text": "That's too many — we only need 12. Tap the ones behind the frog to send a group back.", "style": "A"}, {"key": "1yweol9", "text": "Not enough yet — we need 30. Fetch another bunch!", "style": "A"}, {"key": "2v6y8r", "text": "That's too many — we only need 30. Tap the ones behind the frog to send a bunch back.", "style": "A"}, {"key": "hrihb5", "text": "Not enough yet — we need 10. Fetch another family!", "style": "A"}, {"key": "8ark8j", "text": "That's too many — we only need 10. Tap the ones behind the frog to send a family back.", "style": "A"}, {"key": "wa2ejl", "text": "Not enough yet — we need 8. Fetch another group!", "style": "A"}, {"key": "xjt6a3", "text": "That's too many — we only need 8. Tap the ones behind the frog to send a group back.", "style": "A"}, {"key": "1t6yvpi", "text": "Not enough yet — we need 30. Fetch another group!", "style": "A"}, {"key": "wtzila", "text": "That's too many — we only need 30. Tap the ones behind the frog to send a group back.", "style": "A"}, {"key": "wx4ugg", "text": "Not enough yet — we need 15. Fetch another bunch!", "style": "A"}, {"key": "1mbtky", "text": "That's too many — we only need 15. Tap the ones behind the frog to send a bunch back.", "style": "A"}, {"key": "1jibhah", "text": "Not quite — count the pens of two. Try again!", "style": "A"}, {"key": "5qzxj3", "text": "Not quite — count the patches of five. Try again!", "style": "A"}, {"key": "o304ri", "text": "Not quite — count the nests of five. Try again!", "style": "A"}, {"key": "1qf6c7z", "text": "Not quite — count the pens of three. Try again!", "style": "A"}, {"key": "16kpntk", "text": "Not quite — count the rows of three. Try again!", "style": "A"}, {"key": "5dddtc", "text": "Not quite — count the rows of four. Try again!", "style": "A"}, {"key": "1tocjrk", "text": "Not quite — count the rows of six. Try again!", "style": "A"}, {"key": "u1yput", "text": "Not quite — count the pens of four. Try again!", "style": "A"}, {"key": "1e675fd", "text": "Not quite — count the pens of five. Try again!", "style": "A"}, {"key": "3ciibp", "text": "Not quite — count the patches of three. Try again!", "style": "A"}, {"key": "7y13la", "text": "Not quite — count the nests of three. Try again!", "style": "A"}, {"key": "179fi8u", "text": "Not quite — count the rows of two. Try again!", "style": "A"}, {"key": "1e5l5ca", "text": "Not quite — count the nests of four. Try again!", "style": "A"}, {"key": "1ci7qzz", "text": "Not quite — count the patches of four. Try again!", "style": "A"}, {"key": "4emx3r", "text": "Not quite — count the pens of six. Try again!", "style": "A"}, {"key": "4uiidn", "text": "Not quite — count the patches of two. Try again!", "style": "A"}, {"key": "mtznnc", "text": "Not quite — count the rows of five. Try again!", "style": "A"}, {"key": "10dcmvs", "text": "Not quite — count the nests of two. Try again!", "style": "A"}, {"key": "oc6wfa", "text": "Not quite — count the nests of six. Try again!", "style": "A"}, {"key": "9exuol", "text": "Not quite — count the patches of six. Try again!", "style": "A"}, {"key": "s81za2", "text": "Those pieces are too big — only two would fit and four friends are waiting. Try a smaller piece.", "style": "A"}, {"key": "qvuzpg", "text": "Those pieces are too big — only three would fit and four friends are waiting. Try a smaller piece.", "style": "A"}, {"key": "15e0e0k", "text": "That is one too many — there are only four friends.", "style": "A"}, {"key": "1pcgz16", "text": "Those pieces are too big — only two would fit and three friends are waiting. Try a smaller piece.", "style": "A"}, {"key": "1l3x4py", "text": "Not yet — Duck has nothing! Keep sharing.", "style": "A"}, {"key": "1w35gfg", "text": "Not yet — Squirrel has nothing! Keep sharing.", "style": "A"}, {"key": "1ni7yxq", "text": "That is one too many — there are only three friends.", "style": "A"}, {"key": "11ijyzs", "text": "That is one too many — there are only two friends.", "style": "A"}, {"key": "1ukyvg1", "text": "Not yet — Lamb has nothing! Keep sharing.", "style": "A"}, {"key": "18kw56", "text": "That makes one. I asked for eleven.", "style": "A"}, {"key": "186erzo", "text": "That makes two. I asked for eleven.", "style": "A"}, {"key": "tc9b5y", "text": "That makes three. I asked for eleven.", "style": "A"}, {"key": "11sf26w", "text": "That makes four. I asked for eleven.", "style": "A"}, {"key": "1y6odns", "text": "That makes five. I asked for eleven.", "style": "A"}, {"key": "c564vi", "text": "That makes six. I asked for eleven.", "style": "A"}, {"key": "1prs78x", "text": "That makes seven. I asked for eleven.", "style": "A"}, {"key": "z3virv", "text": "That makes eight. I asked for eleven.", "style": "A"}, {"key": "1fa4494", "text": "That makes nine. I asked for eleven.", "style": "A"}, {"key": "8nf7yv", "text": "That makes ten. I asked for eleven.", "style": "A"}, {"key": "13uubrr", "text": "That makes twelve. I asked for eleven.", "style": "A"}, {"key": "br9ft5", "text": "That makes thirteen. I asked for eleven.", "style": "A"}, {"key": "lhg5t8", "text": "That makes fourteen. I asked for eleven.", "style": "A"}, {"key": "ywuuj9", "text": "That makes fifteen. I asked for eleven.", "style": "A"}, {"key": "12q04b2", "text": "That makes sixteen. I asked for eleven.", "style": "A"}, {"key": "1ytbzh5", "text": "That makes seventeen. I asked for eleven.", "style": "A"}, {"key": "51tlxn", "text": "That makes eighteen. I asked for eleven.", "style": "A"}, {"key": "3133ss", "text": "That makes nineteen. I asked for eleven.", "style": "A"}, {"key": "z1o6cj", "text": "That makes twenty. I asked for eleven.", "style": "A"}, {"key": "i3b82o", "text": "That makes twenty-one. I asked for eleven.", "style": "A"}, {"key": "1ct8vxu", "text": "That makes twenty-two. I asked for eleven.", "style": "A"}, {"key": "12rjvdc", "text": "That makes twenty-three. I asked for eleven.", "style": "A"}, {"key": "dad3z2", "text": "That makes twenty-four. I asked for eleven.", "style": "A"}, {"key": "15dujii", "text": "That makes twenty-five. I asked for eleven.", "style": "A"}, {"key": "q3ho0", "text": "That makes twenty-six. I asked for eleven.", "style": "A"}, {"key": "1lrgvya", "text": "That makes one. Count my coins again.", "style": "A"}, {"key": "1734c6c", "text": "That makes two. Count my coins again.", "style": "A"}, {"key": "19es5bq", "text": "That makes three. Count my coins again.", "style": "A"}, {"key": "1a2o15s", "text": "That makes four. Count my coins again.", "style": "A"}, {"key": "w0u9qo", "text": "That makes five. Count my coins again.", "style": "A"}, {"key": "52wda6", "text": "That makes six. Count my coins again.", "style": "A"}, {"key": "1v9d1et", "text": "That makes seven. Count my coins again.", "style": "A"}, {"key": "1azlixr", "text": "That makes eight. Count my coins again.", "style": "A"}, {"key": "etuieo", "text": "That makes nine. Count my coins again.", "style": "A"}, {"key": "1orubgz", "text": "That makes ten. Count my coins again.", "style": "A"}, {"key": "fvkapb", "text": "That makes eleven. Count my coins again.", "style": "A"}, {"key": "f10kgj", "text": "That makes twelve. Count my coins again.", "style": "A"}, {"key": "a8jz0c", "text": "That makes fourteen. Count my coins again.", "style": "A"}, {"key": "13nrvgh", "text": "That makes fifteen. Count my coins again.", "style": "A"}, {"key": "14mwme6", "text": "That makes sixteen. Count my coins again.", "style": "A"}, {"key": "1ifogel", "text": "That makes seventeen. Count my coins again.", "style": "A"}, {"key": "16noiov", "text": "That makes eighteen. Count my coins again.", "style": "A"}, {"key": "es797w", "text": "That makes nineteen. Count my coins again.", "style": "A"}, {"key": "1qcpcmv", "text": "That makes twenty. Count my coins again.", "style": "A"}, {"key": "1h5s5jc", "text": "That makes twenty-one. Count my coins again.", "style": "A"}, {"key": "rrvtei", "text": "That makes twenty-two. Count my coins again.", "style": "A"}, {"key": "f31moo", "text": "That makes twenty-three. Count my coins again.", "style": "A"}, {"key": "1w46efi", "text": "That makes twenty-four. Count my coins again.", "style": "A"}, {"key": "1x3cz1u", "text": "That makes twenty-five. Count my coins again.", "style": "A"}, {"key": "12lv7p4", "text": "That makes twenty-six. Count my coins again.", "style": "A"}, {"key": "1e2a9rj", "text": "That makes twenty-seven. Count my coins again.", "style": "A"}, {"key": "dyebzl", "text": "That makes twenty-eight. Count my coins again.", "style": "A"}, {"key": "lmpnm7", "text": "That makes sixty. I asked for seventy-five.", "style": "A"}, {"key": "1mq23i8", "text": "That makes sixty-one. I asked for seventy-five.", "style": "A"}, {"key": "10ku48u", "text": "That makes sixty-two. I asked for seventy-five.", "style": "A"}, {"key": "fcvaao", "text": "That makes sixty-three. I asked for seventy-five.", "style": "A"}, {"key": "10bpfx6", "text": "That makes sixty-four. I asked for seventy-five.", "style": "A"}, {"key": "sz33m6", "text": "That makes sixty-five. I asked for seventy-five.", "style": "A"}, {"key": "1ku94xk", "text": "That makes sixty-six. I asked for seventy-five.", "style": "A"}, {"key": "l5c6y7", "text": "That makes sixty-seven. I asked for seventy-five.", "style": "A"}, {"key": "yu4prx", "text": "That makes sixty-eight. I asked for seventy-five.", "style": "A"}, {"key": "1cvr5fy", "text": "That makes sixty-nine. I asked for seventy-five.", "style": "A"}, {"key": "rfl790", "text": "That makes seventy. I asked for seventy-five.", "style": "A"}, {"key": "clwie7", "text": "That makes seventy-one. I asked for seventy-five.", "style": "A"}, {"key": "fr8n1d", "text": "That makes seventy-two. I asked for seventy-five.", "style": "A"}, {"key": "19m4ng3", "text": "That makes seventy-three. I asked for seventy-five.", "style": "A"}, {"key": "qo0ns7", "text": "That makes seventy-four. I asked for seventy-five.", "style": "A"}, {"key": "1u7czur", "text": "That makes seventy-six. I asked for seventy-five.", "style": "A"}, {"key": "zlwoa4", "text": "That makes seventy-seven. I asked for seventy-five.", "style": "A"}, {"key": "g6rya6", "text": "That makes seventy-eight. I asked for seventy-five.", "style": "A"}, {"key": "1dddxt7", "text": "That makes seventy-nine. I asked for seventy-five.", "style": "A"}, {"key": "6b3hpa", "text": "That makes eighty. I asked for seventy-five.", "style": "A"}, {"key": "128v3x5", "text": "That makes eighty-one. I asked for seventy-five.", "style": "A"}, {"key": "xzo3k3", "text": "That makes eighty-two. I asked for seventy-five.", "style": "A"}, {"key": "xfjiwx", "text": "That makes eighty-three. I asked for seventy-five.", "style": "A"}, {"key": "3rptvl", "text": "That makes eighty-four. I asked for seventy-five.", "style": "A"}, {"key": "6epsqx", "text": "That makes eighty-five. I asked for seventy-five.", "style": "A"}, {"key": "1d7leq9", "text": "That makes eighty-six. I asked for seventy-five.", "style": "A"}, {"key": "140onn6", "text": "That makes eighty-seven. I asked for seventy-five.", "style": "A"}, {"key": "wbqj5g", "text": "That makes eighty-eight. I asked for seventy-five.", "style": "A"}, {"key": "k7giop", "text": "That makes eighty-nine. I asked for seventy-five.", "style": "A"}, {"key": "llvv1p", "text": "That makes ninety. I asked for seventy-five.", "style": "A"}, {"key": "1rqf7da", "text": "That is seventy-five, but with four coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "cmzh6y", "text": "That is seventy-five, but with five coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1ojniki", "text": "That is seventy-five, but with six coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "isygxz", "text": "That is seventy-five, but with seven coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1bako5t", "text": "That is seventy-five, but with eight coins. Try bigger coins — can you do it in three?", "style": "A"}, {"key": "1nzprh9", "text": "That makes thirteen. Count my coins again.", "style": "A"}, {"key": "1r9b7z4", "text": "That makes five. I asked for twenty.", "style": "A"}, {"key": "18xbqdq", "text": "That makes six. I asked for twenty.", "style": "A"}, {"key": "cwe8ex", "text": "That makes seven. I asked for twenty.", "style": "A"}, {"key": "109j1fn", "text": "That makes eight. I asked for twenty.", "style": "A"}, {"key": "1w7grk0", "text": "That makes nine. I asked for twenty.", "style": "A"}, {"key": "16y0fhz", "text": "That makes ten. I asked for twenty.", "style": "A"}, {"key": "10n7eqb", "text": "That makes eleven. I asked for twenty.", "style": "A"}, {"key": "34bhbr", "text": "That makes twelve. I asked for twenty.", "style": "A"}, {"key": "1qem8mp", "text": "That makes thirteen. I asked for twenty.", "style": "A"}, {"key": "1ygtfjw", "text": "That makes fourteen. I asked for twenty.", "style": "A"}, {"key": "1ovhtph", "text": "That makes fifteen. I asked for twenty.", "style": "A"}, {"key": "oeczu6", "text": "That makes sixteen. I asked for twenty.", "style": "A"}, {"key": "1w92co1", "text": "That makes seventeen. I asked for twenty.", "style": "A"}, {"key": "67h4lf", "text": "That makes eighteen. I asked for twenty.", "style": "A"}, {"key": "1gjgzjg", "text": "That makes nineteen. I asked for twenty.", "style": "A"}, {"key": "11a7k54", "text": "That makes twenty-one. I asked for twenty.", "style": "A"}, {"key": "p7a0xm", "text": "That makes twenty-two. I asked for twenty.", "style": "A"}, {"key": "15zp7uw", "text": "That makes twenty-three. I asked for twenty.", "style": "A"}, {"key": "1ay7zq6", "text": "That makes twenty-four. I asked for twenty.", "style": "A"}, {"key": "1kn9m1e", "text": "That makes twenty-five. I asked for twenty.", "style": "A"}, {"key": "fm45yg", "text": "That makes twenty-six. I asked for twenty.", "style": "A"}, {"key": "u81z4j", "text": "That makes twenty-seven. I asked for twenty.", "style": "A"}, {"key": "1mdrg7p", "text": "That makes twenty-eight. I asked for twenty.", "style": "A"}, {"key": "69oegy", "text": "That makes twenty-nine. I asked for twenty.", "style": "A"}, {"key": "9lb82o", "text": "That makes thirty. I asked for twenty.", "style": "A"}, {"key": "12hl6f3", "text": "That makes thirty-one. I asked for twenty.", "style": "A"}, {"key": "q8eq9p", "text": "That makes thirty-two. I asked for twenty.", "style": "A"}, {"key": "fphaub", "text": "That makes thirty-three. I asked for twenty.", "style": "A"}, {"key": "ax3i1z", "text": "That makes thirty-four. I asked for twenty.", "style": "A"}, {"key": "1uv0kt7", "text": "That makes thirty-five. I asked for twenty.", "style": "A"}, {"key": "11es5ln", "text": "That makes thirty-one. Count my coins again.", "style": "A"}, {"key": "1qwd989", "text": "That makes thirty-two. Count my coins again.", "style": "A"}, {"key": "jqa6gv", "text": "That makes thirty-three. Count my coins again.", "style": "A"}, {"key": "o7sqir", "text": "That makes thirty-four. Count my coins again.", "style": "A"}, {"key": "1dlqqif", "text": "That makes thirty-five. Count my coins again.", "style": "A"}, {"key": "1sefeen", "text": "That makes thirty-six. Count my coins again.", "style": "A"}, {"key": "16js7mw", "text": "That makes thirty-seven. Count my coins again.", "style": "A"}, {"key": "hts5vi", "text": "That makes thirty-eight. Count my coins again.", "style": "A"}, {"key": "1oh951z", "text": "That makes thirty-nine. Count my coins again.", "style": "A"}, {"key": "bww66a", "text": "That makes forty. Count my coins again.", "style": "A"}, {"key": "shk905", "text": "That makes forty-one. Count my coins again.", "style": "A"}, {"key": "v9nwoj", "text": "That makes forty-two. Count my coins again.", "style": "A"}, {"key": "4uyfjh", "text": "That makes forty-three. Count my coins again.", "style": "A"}, {"key": "572g6d", "text": "That makes forty-four. Count my coins again.", "style": "A"}, {"key": "wfz1l9", "text": "That makes forty-five. Count my coins again.", "style": "A"}, {"key": "1k22z5q", "text": "That makes forty-seven. Count my coins again.", "style": "A"}, {"key": "1db1jr8", "text": "That makes forty-eight. Count my coins again.", "style": "A"}, {"key": "ui5g0t", "text": "That makes forty-nine. Count my coins again.", "style": "A"}, {"key": "1gjr67w", "text": "That makes fifty. Count my coins again.", "style": "A"}, {"key": "tswlpj", "text": "That makes fifty-one. Count my coins again.", "style": "A"}, {"key": "1cjxnid", "text": "That makes fifty-two. Count my coins again.", "style": "A"}, {"key": "hwi3yz", "text": "That makes fifty-three. Count my coins again.", "style": "A"}, {"key": "wav6fb", "text": "That makes fifty-four. Count my coins again.", "style": "A"}, {"key": "1d0cx23", "text": "That makes fifty-five. Count my coins again.", "style": "A"}, {"key": "174wv43", "text": "That makes fifty-six. Count my coins again.", "style": "A"}, {"key": "1x728gs", "text": "That makes fifty-seven. Count my coins again.", "style": "A"}, {"key": "4jnr3e", "text": "That makes fifty-eight. Count my coins again.", "style": "A"}, {"key": "awacqz", "text": "That makes fifty-nine. Count my coins again.", "style": "A"}, {"key": "1v13hbv", "text": "That makes sixty. Count my coins again.", "style": "A"}, {"key": "pa1hlo", "text": "That makes sixty-one. Count my coins again.", "style": "A"}, {"key": "1dk3ckc", "text": "That is forty-six, but with five coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1mx040k", "text": "That is forty-six, but with six coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1uyrb6j", "text": "That is forty-six, but with seven coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "iazea1", "text": "That is forty-six, but with eight coins. Try bigger coins — can you do it in four?", "style": "A"}, {"key": "1qaeqnw", "text": "That makes one. I asked for fifteen.", "style": "A"}, {"key": "1okruna", "text": "That makes two. I asked for fifteen.", "style": "A"}, {"key": "1u54zao", "text": "That makes three. I asked for fifteen.", "style": "A"}, {"key": "1l3ncoi", "text": "That makes four. I asked for fifteen.", "style": "A"}, {"key": "1ag42le", "text": "That makes five. I asked for fifteen.", "style": "A"}, {"key": "1m0dimg", "text": "That makes six. I asked for fifteen.", "style": "A"}, {"key": "1jed3ml", "text": "That makes seven. I asked for fifteen.", "style": "A"}, {"key": "cqzbmn", "text": "That makes eight. I asked for fifteen.", "style": "A"}, {"key": "cnrywy", "text": "That makes nine. I asked for fifteen.", "style": "A"}, {"key": "e20qtf", "text": "That makes ten. I asked for fifteen.", "style": "A"}, {"key": "1q2y8z3", "text": "That makes eleven. I asked for fifteen.", "style": "A"}, {"key": "hn6lkz", "text": "That makes twelve. I asked for fifteen.", "style": "A"}, {"key": "1tf871h", "text": "That makes thirteen. I asked for fifteen.", "style": "A"}, {"key": "t02c26", "text": "That makes fourteen. I asked for fifteen.", "style": "A"}, {"key": "1my7wyw", "text": "That makes sixteen. I asked for fifteen.", "style": "A"}, {"key": "llaqad", "text": "That makes seventeen. I asked for fifteen.", "style": "A"}, {"key": "aja23j", "text": "That makes eighteen. I asked for fifteen.", "style": "A"}, {"key": "1tzxdha", "text": "That makes nineteen. I asked for fifteen.", "style": "A"}, {"key": "1sk3elj", "text": "That makes twenty. I asked for fifteen.", "style": "A"}, {"key": "4evoiy", "text": "That makes twenty-one. I asked for fifteen.", "style": "A"}, {"key": "1jz9kg4", "text": "That makes twenty-two. I asked for fifteen.", "style": "A"}, {"key": "tfx8qi", "text": "That makes twenty-three. I asked for fifteen.", "style": "A"}, {"key": "1eleu3c", "text": "That makes twenty-four. I asked for fifteen.", "style": "A"}, {"key": "9al0oc", "text": "That makes twenty-five. I asked for fifteen.", "style": "A"}, {"key": "pxjmze", "text": "That makes twenty-six. I asked for fifteen.", "style": "A"}, {"key": "ki8jvz", "text": "That makes twenty-seven. I asked for fifteen.", "style": "A"}, {"key": "1kx0emh", "text": "That makes twenty-eight. I asked for fifteen.", "style": "A"}, {"key": "idrh8", "text": "That makes twenty-nine. I asked for fifteen.", "style": "A"}, {"key": "1boxvvm", "text": "That makes thirty. I asked for fifteen.", "style": "A"}, {"key": "16ilr8i", "text": "That makes twenty-nine. Count my coins again.", "style": "A"}, {"key": "148ocw", "text": "That makes thirty. Count my coins again.", "style": "A"}, {"key": "1mqtdjs", "text": "That is twenty, but with three coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1ekt6ws", "text": "That is twenty, but with four coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "diqr7s", "text": "That is twenty, but with five coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1xqxehc", "text": "That is twenty, but with six coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "19chyx", "text": "That is twenty, but with seven coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1k3rylr", "text": "That is twenty, but with eight coins. Try bigger coins — can you do it in two?", "style": "A"}, {"key": "1toorkl", "text": "That makes twenty. I asked for thirty-five.", "style": "A"}, {"key": "1hp909k", "text": "That makes twenty-one. I asked for thirty-five.", "style": "A"}, {"key": "1kt20u2", "text": "That makes twenty-two. I asked for thirty-five.", "style": "A"}, {"key": "q6hijs", "text": "That makes twenty-three. I asked for thirty-five.", "style": "A"}, {"key": "1s34x8u", "text": "That makes twenty-four. I asked for thirty-five.", "style": "A"}, {"key": "1nan6xe", "text": "That makes twenty-five. I asked for thirty-five.", "style": "A"}, {"key": "1hz42q0", "text": "That makes twenty-six. I asked for thirty-five.", "style": "A"}, {"key": "d3vjrh", "text": "That makes twenty-seven. I asked for thirty-five.", "style": "A"}, {"key": "1ydesyf", "text": "That makes twenty-eight. I asked for thirty-five.", "style": "A"}, {"key": "d78i0y", "text": "That makes twenty-nine. I asked for thirty-five.", "style": "A"}, {"key": "1m9vj5s", "text": "That makes thirty. I asked for thirty-five.", "style": "A"}, {"key": "hmmq1", "text": "That makes thirty-one. I asked for thirty-five.", "style": "A"}, {"key": "1eryl1b", "text": "That makes thirty-two. I asked for thirty-five.", "style": "A"}, {"key": "1ffk3dp", "text": "That makes thirty-three. I asked for thirty-five.", "style": "A"}, {"key": "1luvwcx", "text": "That makes thirty-four. I asked for thirty-five.", "style": "A"}, {"key": "xdmj2l", "text": "That makes thirty-six. I asked for thirty-five.", "style": "A"}, {"key": "1d5dozc", "text": "That makes thirty-seven. I asked for thirty-five.", "style": "A"}, {"key": "hvz6gu", "text": "That makes thirty-eight. I asked for thirty-five.", "style": "A"}, {"key": "1f2c5kl", "text": "That makes thirty-nine. I asked for thirty-five.", "style": "A"}, {"key": "be3ioy", "text": "That makes forty. I asked for thirty-five.", "style": "A"}, {"key": "1j4it4b", "text": "That makes forty-one. I asked for thirty-five.", "style": "A"}, {"key": "j3vkxt", "text": "That makes forty-two. I asked for thirty-five.", "style": "A"}, {"key": "1wfeqtf", "text": "That makes forty-three. I asked for thirty-five.", "style": "A"}, {"key": "qjp0u3", "text": "That makes forty-four. I asked for thirty-five.", "style": "A"}, {"key": "1i4c5lv", "text": "That makes forty-five. I asked for thirty-five.", "style": "A"}, {"key": "q4tbh7", "text": "That makes forty-six. I asked for thirty-five.", "style": "A"}, {"key": "3mr6wu", "text": "That makes forty-seven. I asked for thirty-five.", "style": "A"}, {"key": "hpnxyc", "text": "That makes forty-eight. I asked for thirty-five.", "style": "A"}, {"key": "nu54kz", "text": "That makes forty-nine. I asked for thirty-five.", "style": "A"}, {"key": "elquu4", "text": "That makes fifty. I asked for thirty-five.", "style": "A"}, {"key": "1rw51hx", "text": "That is twenty-five, but with two coins. Try bigger coins — can you do it in one?", "style": "A"}, {"key": "1dz64hf", "text": "That is twenty-five, but with three coins. Try bigger coins — can you do it in one?", "style": "A"}, {"key": "111v1kp", "text": "That is twenty-five, but with four coins. Try bigger coins — can you do it in one?", "style": "A"}, {"key": "vh28ud", "text": "That is twenty-five, but with five coins. Try bigger coins — can you do it in one?", "style": "A"}, {"key": "abnhrv", "text": "That is twenty-five, but with six coins. Try bigger coins — can you do it in one?", "style": "A"}, {"key": "1a4kyim", "text": "That is twenty-five, but with seven coins. Try bigger coins — can you do it in one?", "style": "A"}, {"key": "mv6a8g", "text": "That is twenty-five, but with eight coins. Try bigger coins — can you do it in one?", "style": "A"}, {"key": "10zo71r", "text": "That makes one. I asked for six.", "style": "A"}, {"key": "16gecdl", "text": "That makes two. I asked for six.", "style": "A"}, {"key": "51n2b7", "text": "That makes three. I asked for six.", "style": "A"}, {"key": "7mdqwl", "text": "That makes four. I asked for six.", "style": "A"}, {"key": "1yj3uo5", "text": "That makes five. I asked for six.", "style": "A"}, {"key": "ifcbci", "text": "That makes seven. I asked for six.", "style": "A"}, {"key": "n1mysk", "text": "That makes eight. I asked for six.", "style": "A"}, {"key": "1bz0ep1", "text": "That makes nine. I asked for six.", "style": "A"}, {"key": "1ebn0ig", "text": "That makes ten. I asked for six.", "style": "A"}, {"key": "1bj5wgk", "text": "That makes eleven. I asked for six.", "style": "A"}, {"key": "p6gzfc", "text": "That makes twelve. I asked for six.", "style": "A"}, {"key": "rsdjay", "text": "That makes thirteen. I asked for six.", "style": "A"}, {"key": "3ffsmp", "text": "That makes fourteen. I asked for six.", "style": "A"}, {"key": "yxd93i", "text": "That makes fifteen. I asked for six.", "style": "A"}, {"key": "1hv30uj", "text": "That makes sixteen. I asked for six.", "style": "A"}, {"key": "1hdg7yi", "text": "That makes seventeen. I asked for six.", "style": "A"}, {"key": "19ri71g", "text": "That makes eighteen. I asked for six.", "style": "A"}, {"key": "1l8kx35", "text": "That makes nineteen. I asked for six.", "style": "A"}, {"key": "xavkek", "text": "That makes twenty. I asked for six.", "style": "A"}, {"key": "1w8vil", "text": "That makes twenty-one. I asked for six.", "style": "A"}, {"key": "1cl121q", "text": "That makes fifteen. I asked for thirty.", "style": "A"}, {"key": "de8jp1", "text": "That makes sixteen. I asked for thirty.", "style": "A"}, {"key": "z5slpu", "text": "That makes seventeen. I asked for thirty.", "style": "A"}, {"key": "1ap2mkw", "text": "That makes eighteen. I asked for thirty.", "style": "A"}, {"key": "2vzze7", "text": "That makes nineteen. I asked for thirty.", "style": "A"}, {"key": "1owlvco", "text": "That makes twenty. I asked for thirty.", "style": "A"}, {"key": "1jf8jhv", "text": "That makes twenty-one. I asked for thirty.", "style": "A"}, {"key": "zestkp", "text": "That makes twenty-two. I asked for thirty.", "style": "A"}, {"key": "vdsav7", "text": "That makes twenty-three. I asked for thirty.", "style": "A"}, {"key": "dcylet", "text": "That makes twenty-four. I asked for thirty.", "style": "A"}, {"key": "i4eb1d", "text": "That makes twenty-five. I asked for thirty.", "style": "A"}, {"key": "1rp2yoz", "text": "That makes twenty-six. I asked for thirty.", "style": "A"}, {"key": "1fchizk", "text": "That makes twenty-seven. I asked for thirty.", "style": "A"}, {"key": "1291mha", "text": "That makes twenty-eight. I asked for thirty.", "style": "A"}, {"key": "1iwbip", "text": "That makes twenty-nine. I asked for thirty.", "style": "A"}, {"key": "v5c9ic", "text": "That makes thirty-one. I asked for thirty.", "style": "A"}, {"key": "1u1ss6e", "text": "That makes thirty-two. I asked for thirty.", "style": "A"}, {"key": "q00esw", "text": "That makes thirty-three. I asked for thirty.", "style": "A"}, {"key": "1yv60s", "text": "That makes thirty-four. I asked for thirty.", "style": "A"}, {"key": "rb3iig", "text": "That makes thirty-five. I asked for thirty.", "style": "A"}, {"key": "1fr280w", "text": "That makes thirty-six. I asked for thirty.", "style": "A"}, {"key": "15z4iqb", "text": "That makes thirty-seven. I asked for thirty.", "style": "A"}, {"key": "97fr4l", "text": "That makes thirty-eight. I asked for thirty.", "style": "A"}, {"key": "1npt63c", "text": "That makes thirty-nine. I asked for thirty.", "style": "A"}, {"key": "o04p9t", "text": "That makes forty. I asked for thirty.", "style": "A"}, {"key": "zofvuy", "text": "That makes forty-one. I asked for thirty.", "style": "A"}, {"key": "bjzvxo", "text": "That makes forty-two. I asked for thirty.", "style": "A"}, {"key": "1lhjouq", "text": "That makes forty-three. I asked for thirty.", "style": "A"}, {"key": "1pxucbe", "text": "That makes forty-four. I asked for thirty.", "style": "A"}, {"key": "t7pvhu", "text": "That makes forty-five. I asked for thirty.", "style": "A"}, {"key": "167zd94", "text": "That makes one. I asked for thirteen.", "style": "A"}, {"key": "1f65waa", "text": "That makes two. I asked for thirteen.", "style": "A"}, {"key": "i8g5f0", "text": "That makes three. I asked for thirteen.", "style": "A"}, {"key": "1a9mr2", "text": "That makes four. I asked for thirteen.", "style": "A"}, {"key": "48hm7y", "text": "That makes five. I asked for thirteen.", "style": "A"}, {"key": "146cl6s", "text": "That makes six. I asked for thirteen.", "style": "A"}, {"key": "1q65wx7", "text": "That makes seven. I asked for thirteen.", "style": "A"}, {"key": "1onpt65", "text": "That makes eight. I asked for thirteen.", "style": "A"}, {"key": "12pxw9q", "text": "That makes nine. I asked for thirteen.", "style": "A"}, {"key": "19mrd0x", "text": "That makes ten. I asked for thirteen.", "style": "A"}, {"key": "1li042l", "text": "That makes eleven. I asked for thirteen.", "style": "A"}, {"key": "1yx1nzl", "text": "That makes twelve. I asked for thirteen.", "style": "A"}, {"key": "1u4q0oq", "text": "That makes fourteen. I asked for thirteen.", "style": "A"}, {"key": "3znuh3", "text": "That makes fifteen. I asked for thirteen.", "style": "A"}, {"key": "v6bmg4", "text": "That makes sixteen. I asked for thirteen.", "style": "A"}, {"key": "22kycj", "text": "That makes seventeen. I asked for thirteen.", "style": "A"}, {"key": "1kbssx9", "text": "That makes eighteen. I asked for thirteen.", "style": "A"}, {"key": "14tfmru", "text": "That makes nineteen. I asked for thirteen.", "style": "A"}, {"key": "ylicdx", "text": "That makes twenty. I asked for thirteen.", "style": "A"}, {"key": "12m3z6u", "text": "That makes twenty-one. I asked for thirteen.", "style": "A"}, {"key": "1i8ajk0", "text": "That makes twenty-two. I asked for thirteen.", "style": "A"}, {"key": "14hnady", "text": "That makes twenty-three. I asked for thirteen.", "style": "A"}, {"key": "g8kub8", "text": "That makes twenty-four. I asked for thirteen.", "style": "A"}, {"key": "1k5pm08", "text": "That makes twenty-five. I asked for thirteen.", "style": "A"}, {"key": "12dp6ye", "text": "That makes twenty-six. I asked for thirteen.", "style": "A"}, {"key": "1h8khnh", "text": "That makes twenty-seven. I asked for thirteen.", "style": "A"}, {"key": "1w6kj87", "text": "That makes twenty-eight. I asked for thirteen.", "style": "A"}, {"key": "3195lz", "text": "That makes one. I asked for three.", "style": "A"}, {"key": "1o4e215", "text": "That makes two. I asked for three.", "style": "A"}, {"key": "8ro67x", "text": "That makes four. I asked for three.", "style": "A"}, {"key": "12vfya5", "text": "That makes five. I asked for three.", "style": "A"}, {"key": "5fsk63", "text": "That makes six. I asked for three.", "style": "A"}, {"key": "1jhni1e", "text": "That makes seven. I asked for three.", "style": "A"}, {"key": "2d5y44", "text": "That makes eight. I asked for three.", "style": "A"}, {"key": "ed3yy5", "text": "That makes nine. I asked for three.", "style": "A"}, {"key": "b70lxs", "text": "That makes ten. I asked for three.", "style": "A"}, {"key": "1cg7oys", "text": "That makes eleven. I asked for three.", "style": "A"}, {"key": "14j3u34", "text": "That makes twelve. I asked for three.", "style": "A"}, {"key": "gn1xze", "text": "That makes thirteen. I asked for three.", "style": "A"}, {"key": "12kqmkh", "text": "That makes fourteen. I asked for three.", "style": "A"}]
todo = [r for r in LINES if not (REPO / 'public/audio' / VOICE / f"{r['key']}.mp3").exists()]
json.dump(todo, open(WORK / 'todo.json', 'w'))
print(len(todo), 'lines to render')
assert 0 < len(todo) <= 1500, 'nothing to render — every line already has a clip on main'

# %%
# Chatterbox pins torch 2.6, which breaks Kaggle's own torchvision — so it gets its own venv (uv: Kaggle's python has no ensurepip).
VENV = WORK / 'venv'; PY = VENV / 'bin' / 'python'; READY = VENV / '.ready'
if not READY.exists():
    shutil.rmtree(VENV, ignore_errors=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'uv'], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'venv', str(VENV), '--python', sys.executable], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'pip', 'install', '--python', str(PY), 'setuptools<81', 'chatterbox-tts', 'imageio-ffmpeg'], check=True)
    READY.touch()
print(subprocess.run([str(PY), '-c', "import torch; print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NONE — set the accelerator')"], capture_output=True, text=True).stdout)

# %%
OUT = WORK / 'out' / VOICE
cmd = [str(PY), str(REPO / 'scripts/chatterbox-render.py'), '--voice', VOICE, '--corpus', str(WORK / 'todo.json'), '--out', str(OUT)]
proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in proc.stdout:
    if 'it/s]' in line or not line.strip(): continue   # drop the progress bars
    print(line.rstrip()[:160], flush=True)
print('exit code', proc.wait())

# %%
keys = {r['key'] for r in todo}
clips = sorted(c for c in OUT.glob('*.mp3') if c.stem in keys)
missing = [k for k in keys if not (OUT / f'{k}.mp3').exists()]
stage = WORK / 'stage'; shutil.rmtree(stage, ignore_errors=True); (stage / VOICE).mkdir(parents=True)
for c in clips: shutil.copy2(c, stage / VOICE / c.name)
shutil.make_archive(str(WORK / 'radlic-voice-josh-chapters-g2-2'), 'zip', stage)
print(f'{len(clips)} of {len(todo)} clips in radlic-voice-josh-chapters-g2-2.zip' + (f' — MISSING {len(missing)}: {missing}' if missing else ' — complete'))
