# %% [markdown]
# # Radlic voice — Grade 2 (part 4 of 4) story chapters in Josh
#
# Renders every line the Grade 2 (part 4 of 4) story chapters can say that has no clip yet — **453 lines, 17,427 characters** (the lines are
# written into this notebook). Style A (Chatterbox Turbo) for all of them. Rules: `docs/new-flow/voice.md`.
#
# **Before Run All:** Settings → Accelerator → **GPU T4 x2** (or P100), Internet **On**. At the end, download
# `radlic-voice-josh-chapters-g2-4.zip` from the Output panel and hand it back. If the session stops early, Run All
# again in the same session: lines already rendered are skipped.

# %%
import os, sys, subprocess, pathlib, shutil, json
VOICE = 'nzFihrBIvB34imQBuxub'   # Josh
WORK = pathlib.Path('/kaggle/working' if os.path.isdir('/kaggle/working') else '/content')
REPO = WORK / 'learn-main'
if not REPO.exists():
    subprocess.run(['git', 'clone', '--depth', '1', '--branch', 'main', 'https://github.com/RadlorInc/learn.git', str(REPO)], check=True)
LINES = [{"key": "yqw6rc", "text": "That makes ninety-six. I asked for ninety.", "style": "A"}, {"key": "vppj5z", "text": "That makes ninety-seven. I asked for ninety.", "style": "A"}, {"key": "1cusd69", "text": "That makes ninety-eight. I asked for ninety.", "style": "A"}, {"key": "1c4jhmy", "text": "That makes ninety-nine. I asked for ninety.", "style": "A"}, {"key": "155j6dg", "text": "That makes one hundred. I asked for ninety.", "style": "A"}, {"key": "yjmu80", "text": "That makes 101. I asked for ninety.", "style": "A"}, {"key": "1mrb1z3", "text": "That makes 102. I asked for ninety.", "style": "A"}, {"key": "1iqefzq", "text": "That makes 103. I asked for ninety.", "style": "A"}, {"key": "6ho5x1", "text": "That makes 104. I asked for ninety.", "style": "A"}, {"key": "1456zuk", "text": "That makes 105. I asked for ninety.", "style": "A"}, {"key": "1lw4c6r", "text": "That makes forty-seven. I asked for sixty-two.", "style": "A"}, {"key": "m80o29", "text": "That makes forty-eight. I asked for sixty-two.", "style": "A"}, {"key": "1vf0g26", "text": "That makes forty-nine. I asked for sixty-two.", "style": "A"}, {"key": "vz2ii1", "text": "That makes fifty. I asked for sixty-two.", "style": "A"}, {"key": "eona0o", "text": "That makes fifty-one. I asked for sixty-two.", "style": "A"}, {"key": "yda9km", "text": "That makes fifty-two. I asked for sixty-two.", "style": "A"}, {"key": "wfxlhw", "text": "That makes fifty-three. I asked for sixty-two.", "style": "A"}, {"key": "19da4pk", "text": "That makes fifty-four. I asked for sixty-two.", "style": "A"}, {"key": "1wxr238", "text": "That makes fifty-five. I asked for sixty-two.", "style": "A"}, {"key": "gwc1mk", "text": "That makes fifty-six. I asked for sixty-two.", "style": "A"}, {"key": "5eqgcp", "text": "That makes fifty-seven. I asked for sixty-two.", "style": "A"}, {"key": "157iut3", "text": "That makes fifty-eight. I asked for sixty-two.", "style": "A"}, {"key": "9xgx7o", "text": "That makes fifty-nine. I asked for sixty-two.", "style": "A"}, {"key": "a297n8", "text": "That makes sixty. I asked for sixty-two.", "style": "A"}, {"key": "1shjfwp", "text": "That makes sixty-one. I asked for sixty-two.", "style": "A"}, {"key": "1nqago9", "text": "That makes sixty-three. I asked for sixty-two.", "style": "A"}, {"key": "uz39qv", "text": "That makes sixty-four. I asked for sixty-two.", "style": "A"}, {"key": "imct1f", "text": "That makes sixty-five. I asked for sixty-two.", "style": "A"}, {"key": "1dy1cdd", "text": "That makes sixty-six. I asked for sixty-two.", "style": "A"}, {"key": "3s6h90", "text": "That makes sixty-seven. I asked for sixty-two.", "style": "A"}, {"key": "rs6cna", "text": "That makes sixty-eight. I asked for sixty-two.", "style": "A"}, {"key": "qx2w5f", "text": "That makes sixty-nine. I asked for sixty-two.", "style": "A"}, {"key": "2p3ehx", "text": "That makes seventy. I asked for sixty-two.", "style": "A"}, {"key": "1omke10", "text": "That makes seventy-one. I asked for sixty-two.", "style": "A"}, {"key": "9z6rle", "text": "That makes seventy-two. I asked for sixty-two.", "style": "A"}, {"key": "10f4shs", "text": "That makes seventy-three. I asked for sixty-two.", "style": "A"}, {"key": "tethe4", "text": "That makes seventy-four. I asked for sixty-two.", "style": "A"}, {"key": "wdfsig", "text": "That makes seventy-five. I asked for sixty-two.", "style": "A"}, {"key": "1l86nrk", "text": "That makes seventy-six. I asked for sixty-two.", "style": "A"}, {"key": "1bp4qvx", "text": "That makes seventy-seven. I asked for sixty-two.", "style": "A"}, {"key": "1apipq8", "text": "We have to count all the bees.", "style": "A"}, {"key": "6qz8fx", "text": "We have to count all the ants.", "style": "A"}, {"key": "18re4er", "text": "But look — they sit in bunchs of 10.", "style": "A"}, {"key": "uxngd5", "text": "30! 3 bunchs of 10 makes 30.", "style": "A"}, {"key": "jbbh01", "text": "We have to count all the birds.", "style": "A"}, {"key": "19ptwc5", "text": "But look — they sit in groups of 2.", "style": "A"}, {"key": "huopeo", "text": "So we can count the groups instead — much faster!", "style": "A"}, {"key": "q14dkt", "text": "10! 5 groups of 2 makes 10.", "style": "A"}, {"key": "19229h5", "text": "We have to count all the dragonflies.", "style": "A"}, {"key": "1pyuwdj", "text": "But look — they sit in familys of 5.", "style": "A"}, {"key": "1f981dg", "text": "10! 2 familys of 5 makes 10.", "style": "A"}, {"key": "1sfvs50", "text": "We have to count all the chicks.", "style": "A"}, {"key": "b0qumm", "text": "20! 4 bunchs of 5 makes 20.", "style": "A"}, {"key": "5osk3m", "text": "We have to count all the rabbits.", "style": "A"}, {"key": "nikiiu", "text": "We have to count all the fireflies.", "style": "A"}, {"key": "1wr8i19", "text": "8! 4 familys of 2 makes 8.", "style": "A"}, {"key": "1wgv7kz", "text": "We have to count all the ducklings.", "style": "A"}, {"key": "15k3tnb", "text": "We have to count all the ducks.", "style": "A"}, {"key": "pznf1y", "text": "We have to count all the lambs.", "style": "A"}, {"key": "1x9ocez", "text": "15! 3 familys of 5 makes 15.", "style": "A"}, {"key": "dq0wg9", "text": "But look — they sit in familys of 10.", "style": "A"}, {"key": "1k5o583", "text": "30! 3 familys of 10 makes 30.", "style": "A"}, {"key": "jtg2x2", "text": "But look — they sit in bunchs of 2.", "style": "A"}, {"key": "10avd31", "text": "12! 6 bunchs of 2 makes 12.", "style": "A"}, {"key": "g24w3o", "text": "8! 4 groups of 2 makes 8.", "style": "A"}, {"key": "1pe8qw0", "text": "20! 4 familys of 5 makes 20.", "style": "A"}, {"key": "dbv6qc", "text": "10! 5 bunchs of 2 makes 10.", "style": "A"}, {"key": "zobbof", "text": "6! 3 groups of 2 makes 6.", "style": "A"}, {"key": "1vyrye2", "text": "But look — they sit in groups of 10.", "style": "A"}, {"key": "1jwqgud", "text": "20! 2 groups of 10 makes 20.", "style": "A"}, {"key": "fbkw5s", "text": "6! 3 bunchs of 2 makes 6.", "style": "A"}, {"key": "rrn2e", "text": "But look — they sit in groups of 5.", "style": "A"}, {"key": "5qfleq", "text": "15! 3 groups of 5 makes 15.", "style": "A"}, {"key": "26cqhm", "text": "10! 5 familys of 2 makes 10.", "style": "A"}, {"key": "1irvmbg", "text": "12! 6 groups of 2 makes 12.", "style": "A"}, {"key": "1fnwc8a", "text": "30! 3 groups of 10 makes 30.", "style": "A"}, {"key": "1962tap", "text": "10! 2 groups of 5 makes 10.", "style": "A"}, {"key": "34ca25", "text": "12! 6 familys of 2 makes 12.", "style": "A"}, {"key": "c30a1z", "text": "20! 4 groups of 5 makes 20.", "style": "A"}, {"key": "1c0n0qm", "text": "20! 2 bunchs of 10 makes 20.", "style": "A"}, {"key": "15w6nyw", "text": "20! 2 familys of 10 makes 20.", "style": "A"}, {"key": "12rwuhb", "text": "8! 4 bunchs of 2 makes 8.", "style": "A"}, {"key": "wdk6e0", "text": "10! 2 bunchs of 5 makes 10.", "style": "A"}, {"key": "1f4cpih", "text": "two pens of three ducklings. Let’s skip-count!", "style": "A"}, {"key": "f1ukf4", "text": "two times three is six! six ducklings in all.", "style": "A"}, {"key": "x97hwv", "text": "two rows of four ladybugs. Let’s skip-count!", "style": "A"}, {"key": "t9cnrp", "text": "two times four is eight! eight ladybugs in all.", "style": "A"}, {"key": "luzn3u", "text": "three nests of five squirrels. Let’s skip-count!", "style": "A"}, {"key": "1sglam8", "text": "three times five is fifteen! fifteen squirrels in all.", "style": "A"}, {"key": "8ku5q", "text": "three pens of four lambs. Let’s skip-count!", "style": "A"}, {"key": "1ai9fk1", "text": "three times four is twelve! twelve lambs in all.", "style": "A"}, {"key": "gfydj0", "text": "four rows of five ants. Let’s skip-count!", "style": "A"}, {"key": "1oam9b0", "text": "four times five is twenty! twenty ants in all.", "style": "A"}, {"key": "q015ij", "text": "five nests of three eagles. Let’s skip-count!", "style": "A"}, {"key": "1ll5cqd", "text": "five times three is fifteen! fifteen eagles in all.", "style": "A"}, {"key": "8q2ha7", "text": "two pens of two ducks. Let’s skip-count!", "style": "A"}, {"key": "15hue80", "text": "two times two is four! four ducks in all.", "style": "A"}, {"key": "1womfim", "text": "two patches of five butterflies. Let’s skip-count!", "style": "A"}, {"key": "vsfdkl", "text": "two times five is ten! ten butterflies in all.", "style": "A"}, {"key": "1o3wor9", "text": "three rows of four fireflies. Let’s skip-count!", "style": "A"}, {"key": "4toxb1", "text": "three times four is twelve! twelve fireflies in all.", "style": "A"}, {"key": "18qqt6y", "text": "three pens of three rabbits. Let’s skip-count!", "style": "A"}, {"key": "h22zor", "text": "three times three is nine! nine rabbits in all.", "style": "A"}, {"key": "1gv80sr", "text": "three pens of four ducklings. Let’s skip-count!", "style": "A"}, {"key": "24rw92", "text": "three times four is twelve! twelve ducklings in all.", "style": "A"}, {"key": "1omumzv", "text": "six rows of six ladybugs. Let’s skip-count!", "style": "A"}, {"key": "1a9v8l1", "text": "six times six is thirty-six! thirty-six ladybugs in all.", "style": "A"}, {"key": "nakvru", "text": "two nests of three squirrels. Let’s skip-count!", "style": "A"}, {"key": "pxpxom", "text": "two times three is six! six squirrels in all.", "style": "A"}, {"key": "h2xkrr", "text": "four rows of five lambs. Let’s skip-count!", "style": "A"}, {"key": "1u5a9j7", "text": "four times five is twenty! twenty lambs in all.", "style": "A"}, {"key": "ru4fc9", "text": "five patches of four ants. Let’s skip-count!", "style": "A"}, {"key": "1is0fjw", "text": "five times four is twenty! twenty ants in all.", "style": "A"}, {"key": "i07nxt", "text": "two nests of two eagles. Let’s skip-count!", "style": "A"}, {"key": "1cw6i4f", "text": "two times two is four! four eagles in all.", "style": "A"}, {"key": "ip6y43", "text": "five pens of two ducks. Let’s skip-count!", "style": "A"}, {"key": "1irr30g", "text": "five times two is ten! ten ducks in all.", "style": "A"}, {"key": "ikqnsq", "text": "four patches of three butterflies. Let’s skip-count!", "style": "A"}, {"key": "1gxbkoj", "text": "four times three is twelve! twelve butterflies in all.", "style": "A"}, {"key": "muwad", "text": "three nests of four fireflies. Let’s skip-count!", "style": "A"}, {"key": "j1w3n", "text": "two rows of two rabbits. Let’s skip-count!", "style": "A"}, {"key": "24zqaj", "text": "two times two is four! four rabbits in all.", "style": "A"}, {"key": "44utgl", "text": "four pens of three ducklings. Let’s skip-count!", "style": "A"}, {"key": "ri4wc2", "text": "four times three is twelve! twelve ducklings in all.", "style": "A"}, {"key": "142thy0", "text": "two patches of two ladybugs. Let’s skip-count!", "style": "A"}, {"key": "13v4zqd", "text": "two times two is four! four ladybugs in all.", "style": "A"}, {"key": "y7fg9a", "text": "three nests of four squirrels. Let’s skip-count!", "style": "A"}, {"key": "1ym7tag", "text": "three times four is twelve! twelve squirrels in all.", "style": "A"}, {"key": "11nged8", "text": "three pens of two lambs. Let’s skip-count!", "style": "A"}, {"key": "8qocgr", "text": "three times two is six! six lambs in all.", "style": "A"}, {"key": "hmd18h", "text": "two patches of three ants. Let’s skip-count!", "style": "A"}, {"key": "p8cmrk", "text": "two times three is six! six ants in all.", "style": "A"}, {"key": "19t7rm1", "text": "three rows of three eagles. Let’s skip-count!", "style": "A"}, {"key": "xwygfj", "text": "three times three is nine! nine eagles in all.", "style": "A"}, {"key": "1siw4l1", "text": "four pens of six ducks. Let’s skip-count!", "style": "A"}, {"key": "197cfug", "text": "four times six is twenty-four! twenty-four ducks in all.", "style": "A"}, {"key": "giqjmu", "text": "three patches of two butterflies. Let’s skip-count!", "style": "A"}, {"key": "19thofd", "text": "three times two is six! six butterflies in all.", "style": "A"}, {"key": "1e1oz5", "text": "three nests of five fireflies. Let’s skip-count!", "style": "A"}, {"key": "y50zph", "text": "three times five is fifteen! fifteen fireflies in all.", "style": "A"}, {"key": "xqs3k0", "text": "five pens of three rabbits. Let’s skip-count!", "style": "A"}, {"key": "xoprwt", "text": "five times three is fifteen! fifteen rabbits in all.", "style": "A"}, {"key": "cflppx", "text": "two pens of four ducklings. Let’s skip-count!", "style": "A"}, {"key": "1mjl4oo", "text": "two times four is eight! eight ducklings in all.", "style": "A"}, {"key": "18arrsy", "text": "six nests of five squirrels. Let’s skip-count!", "style": "A"}, {"key": "1g222s", "text": "six times five is thirty! thirty squirrels in all.", "style": "A"}, {"key": "12eicmu", "text": "three pens of three lambs. Let’s skip-count!", "style": "A"}, {"key": "1f2kllz", "text": "three times three is nine! nine lambs in all.", "style": "A"}, {"key": "ka9s39", "text": "five patches of three ants. Let’s skip-count!", "style": "A"}, {"key": "1fcj1x2", "text": "five times three is fifteen! fifteen ants in all.", "style": "A"}, {"key": "1xcxfu5", "text": "three pens of two ducks. Let’s skip-count!", "style": "A"}, {"key": "1pp88yc", "text": "three times two is six! six ducks in all.", "style": "A"}, {"key": "jj26l0", "text": "four patches of two butterflies. Let’s skip-count!", "style": "A"}, {"key": "o57kph", "text": "four times two is eight! eight butterflies in all.", "style": "A"}, {"key": "1bmrjwf", "text": "four nests of four fireflies. Let’s skip-count!", "style": "A"}, {"key": "6ppl51", "text": "four times four is sixteen! sixteen fireflies in all.", "style": "A"}, {"key": "5qu4du", "text": "three pens of four rabbits. Let’s skip-count!", "style": "A"}, {"key": "14beu1h", "text": "three times four is twelve! twelve rabbits in all.", "style": "A"}, {"key": "52hscj", "text": "three rows of three ladybugs. Let’s skip-count!", "style": "A"}, {"key": "1ur8pg5", "text": "three times three is nine! nine ladybugs in all.", "style": "A"}, {"key": "i0xhp3", "text": "five rows of five lambs. Let’s skip-count!", "style": "A"}, {"key": "1pru9g9", "text": "five times five is twenty-five! twenty-five lambs in all.", "style": "A"}, {"key": "1ou5qf5", "text": "three patches of two ants. Let’s skip-count!", "style": "A"}, {"key": "1fgclw", "text": "three times two is six! six ants in all.", "style": "A"}, {"key": "smgkqs", "text": "two rows of three ducks. Let’s skip-count!", "style": "A"}, {"key": "czlrd4", "text": "two times three is six! six ducks in all.", "style": "A"}, {"key": "1b3ban5", "text": "six rows of six butterflies. Let’s skip-count!", "style": "A"}, {"key": "13qjirx", "text": "six times six is thirty-six! thirty-six butterflies in all.", "style": "A"}, {"key": "1ykhoff", "text": "two nests of four fireflies. Let’s skip-count!", "style": "A"}, {"key": "oq2mrv", "text": "two times four is eight! eight fireflies in all.", "style": "A"}, {"key": "1kkpz7", "text": "four rows of four rabbits. Let’s skip-count!", "style": "A"}, {"key": "1oiujml", "text": "four times four is sixteen! sixteen rabbits in all.", "style": "A"}, {"key": "1fpsggs", "text": "five rows of three ducklings. Let’s skip-count!", "style": "A"}, {"key": "1th33qm", "text": "five times three is fifteen! fifteen ducklings in all.", "style": "A"}, {"key": "iiwzlm", "text": "two patches of four ladybugs. Let’s skip-count!", "style": "A"}, {"key": "1ma19l8", "text": "two rows of five squirrels. Let’s skip-count!", "style": "A"}, {"key": "1p6385i", "text": "two times five is ten! ten squirrels in all.", "style": "A"}, {"key": "14y4g0l", "text": "five rows of six lambs. Let’s skip-count!", "style": "A"}, {"key": "q2nxp1", "text": "five times six is thirty! thirty lambs in all.", "style": "A"}, {"key": "19qyz5z", "text": "three patches of three ants. Let’s skip-count!", "style": "A"}, {"key": "14j2u3c", "text": "three times three is nine! nine ants in all.", "style": "A"}, {"key": "1dboakv", "text": "three nests of five eagles. Let’s skip-count!", "style": "A"}, {"key": "1at8351", "text": "three times five is fifteen! fifteen eagles in all.", "style": "A"}, {"key": "11fbhs9", "text": "five pens of four ducks. Let’s skip-count!", "style": "A"}, {"key": "13ht47g", "text": "five times four is twenty! twenty ducks in all.", "style": "A"}, {"key": "1lgu36j", "text": "two nests of five fireflies. Let’s skip-count!", "style": "A"}, {"key": "uaty8z", "text": "two times five is ten! ten fireflies in all.", "style": "A"}, {"key": "1wj7poz", "text": "five rows of four rabbits. Let’s skip-count!", "style": "A"}, {"key": "eml7rz", "text": "five times four is twenty! twenty rabbits in all.", "style": "A"}, {"key": "1g3a7dz", "text": "two pens of two ducklings. Let’s skip-count!", "style": "A"}, {"key": "1o26qx4", "text": "two times two is four! four ducklings in all.", "style": "A"}, {"key": "y8vr51", "text": "two rows of three ladybugs. Let’s skip-count!", "style": "A"}, {"key": "qdbojx", "text": "two times three is six! six ladybugs in all.", "style": "A"}, {"key": "mxigg8", "text": "two nests of two squirrels. Let’s skip-count!", "style": "A"}, {"key": "15ln8oe", "text": "two times two is four! four squirrels in all.", "style": "A"}, {"key": "1kfk3mh", "text": "four rows of five eagles. Let’s skip-count!", "style": "A"}, {"key": "1mesybn", "text": "four times five is twenty! twenty eagles in all.", "style": "A"}, {"key": "4szu63", "text": "three pens of four ducks. Let’s skip-count!", "style": "A"}, {"key": "5t3412", "text": "three times four is twelve! twelve ducks in all.", "style": "A"}, {"key": "1wc07pz", "text": "three rows of three fireflies. Let’s skip-count!", "style": "A"}, {"key": "15xdrnv", "text": "three times three is nine! nine fireflies in all.", "style": "A"}, {"key": "1gcdfsk", "text": "two pens of three rabbits. Let’s skip-count!", "style": "A"}, {"key": "1x1skoz", "text": "two times three is six! six rabbits in all.", "style": "A"}, {"key": "f6i9fc", "text": "three rows of five ducklings. Let’s skip-count!", "style": "A"}, {"key": "1b2vdcu", "text": "three times five is fifteen! fifteen ducklings in all.", "style": "A"}, {"key": "fvvfbk", "text": "three patches of five ladybugs. Let’s skip-count!", "style": "A"}, {"key": "1x6al7r", "text": "three times five is fifteen! fifteen ladybugs in all.", "style": "A"}, {"key": "327xs0", "text": "three nests of three squirrels. Let’s skip-count!", "style": "A"}, {"key": "1pbwin2", "text": "three times three is nine! nine squirrels in all.", "style": "A"}, {"key": "mhzo01", "text": "three rows of five lambs. Let’s skip-count!", "style": "A"}, {"key": "1vr44ft", "text": "three times five is fifteen! fifteen lambs in all.", "style": "A"}, {"key": "u6cp9o", "text": "five rows of five ants. Let’s skip-count!", "style": "A"}, {"key": "1bpb6xy", "text": "five times five is twenty-five! twenty-five ants in all.", "style": "A"}, {"key": "na3fnr", "text": "three nests of two eagles. Let’s skip-count!", "style": "A"}, {"key": "14u77p7", "text": "three times two is six! six eagles in all.", "style": "A"}, {"key": "1lymo4d", "text": "five pens of five ducks. Let’s skip-count!", "style": "A"}, {"key": "of6svi", "text": "five times five is twenty-five! twenty-five ducks in all.", "style": "A"}, {"key": "ghpvt7", "text": "six rows of two butterflies. Let’s skip-count!", "style": "A"}, {"key": "2k0l3f", "text": "six times two is twelve! twelve butterflies in all.", "style": "A"}, {"key": "1ge3edr", "text": "two nests of two fireflies. Let’s skip-count!", "style": "A"}, {"key": "suaj", "text": "two times two is four! four fireflies in all.", "style": "A"}, {"key": "1le8gai", "text": "four pens of two rabbits. Let’s skip-count!", "style": "A"}, {"key": "pc7foj", "text": "four times two is eight! eight rabbits in all.", "style": "A"}, {"key": "1xr9wh", "text": "two pens of five ducklings. Let’s skip-count!", "style": "A"}, {"key": "1af5q8w", "text": "two times five is ten! ten ducklings in all.", "style": "A"}, {"key": "1i81vs8", "text": "three patches of three ladybugs. Let’s skip-count!", "style": "A"}, {"key": "4jmaf8", "text": "five pens of six lambs. Let’s skip-count!", "style": "A"}, {"key": "1d0r4hz", "text": "three patches of four ants. Let’s skip-count!", "style": "A"}, {"key": "z3fv5a", "text": "three times four is twelve! twelve ants in all.", "style": "A"}, {"key": "1io74f7", "text": "five rows of three eagles. Let’s skip-count!", "style": "A"}, {"key": "1t6whle", "text": "two patches of four butterflies. Let’s skip-count!", "style": "A"}, {"key": "103x2i5", "text": "two times four is eight! eight butterflies in all.", "style": "A"}, {"key": "1mx0zdh", "text": "five rows of three fireflies. Let’s skip-count!", "style": "A"}, {"key": "9yw66t", "text": "five times three is fifteen! fifteen fireflies in all.", "style": "A"}, {"key": "7z0vtx", "text": "two rows of three rabbits. Let’s skip-count!", "style": "A"}, {"key": "wjh9qq", "text": "four patches of three ladybugs. Let’s skip-count!", "style": "A"}, {"key": "1o5q7sb", "text": "four times three is twelve! twelve ladybugs in all.", "style": "A"}, {"key": "1axw0tc", "text": "two rows of two squirrels. Let’s skip-count!", "style": "A"}, {"key": "p6wmng", "text": "two pens of four lambs. Let’s skip-count!", "style": "A"}, {"key": "1svwvs7", "text": "two times four is eight! eight lambs in all.", "style": "A"}, {"key": "1reanvl", "text": "five nests of five eagles. Let’s skip-count!", "style": "A"}, {"key": "1ekcix1", "text": "five times five is twenty-five! twenty-five eagles in all.", "style": "A"}, {"key": "hzqrgp", "text": "two pens of three ducks. Let’s skip-count!", "style": "A"}, {"key": "lhs9xm", "text": "five patches of three butterflies. Let’s skip-count!", "style": "A"}, {"key": "7ci8z3", "text": "five times three is fifteen! fifteen butterflies in all.", "style": "A"}, {"key": "hzzoev", "text": "four rows of four fireflies. Let’s skip-count!", "style": "A"}, {"key": "1v9cpya", "text": "four rows of four ducklings. Let’s skip-count!", "style": "A"}, {"key": "jnjyse", "text": "four times four is sixteen! sixteen ducklings in all.", "style": "A"}, {"key": "9sfa0c", "text": "three rows of six ants. Let’s skip-count!", "style": "A"}, {"key": "3qbz7c", "text": "three times six is eighteen! eighteen ants in all.", "style": "A"}, {"key": "1c68mot", "text": "two nests of four eagles. Let’s skip-count!", "style": "A"}, {"key": "pg410v", "text": "two times four is eight! eight eagles in all.", "style": "A"}, {"key": "ub9n7a", "text": "two rows of two ducks. Let’s skip-count!", "style": "A"}, {"key": "1wj38at", "text": "two rows of four butterflies. Let’s skip-count!", "style": "A"}, {"key": "a5uv1z", "text": "three nests of three fireflies. Let’s skip-count!", "style": "A"}, {"key": "1pk3f3y", "text": "two pens of two rabbits. Let’s skip-count!", "style": "A"}, {"key": "1uoxcgl", "text": "five pens of three ducklings. Let’s skip-count!", "style": "A"}, {"key": "mcp818", "text": "four rows of two squirrels. Let’s skip-count!", "style": "A"}, {"key": "9i65d2", "text": "four times two is eight! eight squirrels in all.", "style": "A"}, {"key": "ofuw3p", "text": "six pens of two ducks. Let’s skip-count!", "style": "A"}, {"key": "1nsm536", "text": "six times two is twelve! twelve ducks in all.", "style": "A"}, {"key": "nk9xg0", "text": "three patches of three butterflies. Let’s skip-count!", "style": "A"}, {"key": "yg5d9p", "text": "three times three is nine! nine butterflies in all.", "style": "A"}, {"key": "15ag18b", "text": "five nests of two fireflies. Let’s skip-count!", "style": "A"}, {"key": "1mrobff", "text": "five times two is ten! ten fireflies in all.", "style": "A"}, {"key": "1tn0x7s", "text": "Look — four friends are waiting, and they must all get the same.", "style": "A"}, {"key": "tyxmsv", "text": "So I share the pizza out, one piece at a time.", "style": "A"}, {"key": "1pp7zcp", "text": ".until everybody has one. Four equal pieces.", "style": "A"}, {"key": "1j0osm2", "text": "Each friend gets one piece out of four — one quarter.", "style": "A"}, {"key": "bm55c", "text": "Look — three friends are waiting, and they must all get the same.", "style": "A"}, {"key": "1mjvek0", "text": "So I share twelve cherries out, one piece at a time.", "style": "A"}, {"key": "t61rsv", "text": ".until everybody has one. Three equal piles.", "style": "A"}, {"key": "10qgwsm", "text": "Each friend gets four. One third of twelve is four.", "style": "A"}, {"key": "3qfy83", "text": "So I share the orange out, one piece at a time.", "style": "A"}, {"key": "yp1izy", "text": "Look — two friends are waiting, and they must all get the same.", "style": "A"}, {"key": "1p974zl", "text": "So I share the flapjack out, one piece at a time.", "style": "A"}, {"key": "8it6b", "text": ".until everybody has one. Two equal pieces.", "style": "A"}, {"key": "1sapw1j", "text": "Each friend gets one piece out of two — one half.", "style": "A"}, {"key": "v0o8zb", "text": "So I share the cheese wheel out, one piece at a time.", "style": "A"}, {"key": "1nsxnpd", "text": ".until everybody has one. Three equal pieces.", "style": "A"}, {"key": "shs9ut", "text": "Each friend gets one piece out of three — one third.", "style": "A"}, {"key": "ukvc97", "text": "So I share six pears out, one piece at a time.", "style": "A"}, {"key": "ibhh87", "text": "Each friend gets two. One third of six is two.", "style": "A"}, {"key": "17u30ud", "text": "So I share the big cookie out, one piece at a time.", "style": "A"}, {"key": "1qpaoz2", "text": "So I share the nougat bar out, one piece at a time.", "style": "A"}, {"key": "13253mt", "text": "So I share the party cake out, one piece at a time.", "style": "A"}, {"key": "4glbxv", "text": "So I share the watermelon out, one piece at a time.", "style": "A"}, {"key": "29x4i3", "text": "So I share the mint slice out, one piece at a time.", "style": "A"}, {"key": "13gyp2a", "text": "So I share eight oranges out, one piece at a time.", "style": "A"}, {"key": "1hvk6k7", "text": ".until everybody has one. Four equal piles.", "style": "A"}, {"key": "1c5k52b", "text": "Each friend gets two. One quarter of eight is two.", "style": "A"}, {"key": "c49356", "text": "So I share the chocolate bar out, one piece at a time.", "style": "A"}, {"key": "v1ei6o", "text": "So I share twelve pears out, one piece at a time.", "style": "A"}, {"key": "34l7g5", "text": "So I share six oranges out, one piece at a time.", "style": "A"}, {"key": "1a4y9lg", "text": "So I share eight pears out, one piece at a time.", "style": "A"}, {"key": "se0t01", "text": "So I share six cherries out, one piece at a time.", "style": "A"}, {"key": "2duqyx", "text": "Each friend gets three. One quarter of twelve is three.", "style": "A"}, {"key": "4ycibq", "text": "So I share twelve oranges out, one piece at a time.", "style": "A"}, {"key": "1o7kjgx", "text": ".until everybody has one. Two equal piles.", "style": "A"}, {"key": "q67tyh", "text": "Each friend gets three. One half of six is three.", "style": "A"}, {"key": "w2y5k0", "text": "Each friend gets four. One half of eight is four.", "style": "A"}, {"key": "4s151y", "text": "A tulip — that is eleven.", "style": "A"}, {"key": "1exftvn", "text": "That is eleven. Just right.", "style": "A"}, {"key": "17dr976", "text": "A pot — that is thirty.", "style": "A"}, {"key": "19jq8bb", "text": "An egg — that is fifty-six.", "style": "A"}, {"key": "1pa0zft", "text": "That is fifty-six. Just right.", "style": "A"}, {"key": "2yxl9f", "text": "An apple — that is two.", "style": "A"}, {"key": "wrklcq", "text": "That is two. Just right.", "style": "A"}, {"key": "7k7o5e", "text": "A fish — that is seven.", "style": "A"}, {"key": "10bzv5n", "text": "That is seven. Just right.", "style": "A"}, {"key": "gp14c4", "text": "A bun — that is thirty-seven.", "style": "A"}, {"key": "7c3xhp", "text": "The same thirty-seven — in only four coins.", "style": "A"}, {"key": "inhdm2", "text": "A pot — that is six.", "style": "A"}, {"key": "84pg4", "text": "That is six. Just right.", "style": "A"}, {"key": "bckw3q", "text": "A tulip — that is eight.", "style": "A"}, {"key": "19kr3yt", "text": "That is eight. Just right.", "style": "A"}, {"key": "156snqf", "text": "An egg — that is thirty-five.", "style": "A"}, {"key": "1jrnjeg", "text": "The same thirty-five — in only two coins.", "style": "A"}, {"key": "9iglxo", "text": "A fish — that is eleven.", "style": "A"}, {"key": "jd45cl", "text": "A tulip — that is twenty-six.", "style": "A"}, {"key": "13igvdo", "text": "That is twenty-six. Just right.", "style": "A"}, {"key": "feibn3", "text": "A pot — that is fifty-one.", "style": "A"}, {"key": "vlla0l", "text": "That is fifty-one. Just right.", "style": "A"}, {"key": "1t5a3ri", "text": "An egg — that is six.", "style": "A"}, {"key": "34clhe", "text": "An apple — that is seven.", "style": "A"}, {"key": "1k9na0u", "text": "A fish — that is forty-six.", "style": "A"}, {"key": "1bvpykj", "text": "That is forty-six. Just right.", "style": "A"}, {"key": "1ue52nf", "text": "A bun — that is seven.", "style": "A"}, {"key": "m588v", "text": "A pot — that is eight.", "style": "A"}, {"key": "pkye8q", "text": "A tulip — that is fifty-five.", "style": "A"}, {"key": "114dez0", "text": "The same fifty-five — in only three coins.", "style": "A"}, {"key": "151vxat", "text": "An egg — that is eleven.", "style": "A"}, {"key": "15oinld", "text": "A fish — that is twenty-five.", "style": "A"}, {"key": "1h2ocl0", "text": "That is twenty-five. Just right.", "style": "A"}, {"key": "siw44", "text": "A tulip — that is forty-six.", "style": "A"}, {"key": "1p3vi4o", "text": "The same forty-six — in only four coins.", "style": "A"}, {"key": "1l5f920", "text": "An egg — that is twenty-two.", "style": "A"}, {"key": "vgenpu", "text": "That is twenty-two. Just right.", "style": "A"}, {"key": "1xsoxqp", "text": "A fish — that is six.", "style": "A"}, {"key": "vhbtrv", "text": "A bun — that is twenty.", "style": "A"}, {"key": "z24ggj", "text": "That is twenty. Just right.", "style": "A"}, {"key": "1gtg4ox", "text": "A tulip — that is two.", "style": "A"}, {"key": "17r2j8e", "text": "An egg — that is thirty.", "style": "A"}, {"key": "1bv25vk", "text": "A fish — that is twenty-seven.", "style": "A"}, {"key": "1hc7xkj", "text": "That is twenty-seven. Just right.", "style": "A"}, {"key": "1ioit1m", "text": "A tulip — that is ten.", "style": "A"}, {"key": "119t295", "text": "That is ten. Just right.", "style": "A"}, {"key": "1baec1t", "text": "A pot — that is twenty.", "style": "A"}, {"key": "1glil79", "text": "An egg — that is twelve.", "style": "A"}, {"key": "kmf1x4", "text": "The same twelve — in only three coins.", "style": "A"}, {"key": "9xfc98", "text": "An apple — that is eleven.", "style": "A"}, {"key": "z8t6ak", "text": "A fish — that is twenty.", "style": "A"}, {"key": "xea3qy", "text": "A bun — that is seventy.", "style": "A"}, {"key": "1b143c6", "text": "That is seventy. Just right.", "style": "A"}, {"key": "92td15", "text": "A pot — that is seven.", "style": "A"}, {"key": "91nmwj", "text": "A tulip — that is sixteen.", "style": "A"}, {"key": "1u38uco", "text": "That is sixteen. Just right.", "style": "A"}, {"key": "dw75gd", "text": "An egg — that is forty-one.", "style": "A"}, {"key": "11ctn6z", "text": "That is forty-one. Just right.", "style": "A"}, {"key": "t83x19", "text": "A tulip — that is twenty-one.", "style": "A"}, {"key": "hd5rjs", "text": "That is twenty-one. Just right.", "style": "A"}, {"key": "r1agkf", "text": "A pot — that is twenty-eight.", "style": "A"}, {"key": "yygv31", "text": "That is twenty-eight. Just right.", "style": "A"}, {"key": "1rpckyr", "text": "An apple — that is twenty-one.", "style": "A"}, {"key": "1g5c1uo", "text": "A fish — that is sixty.", "style": "A"}, {"key": "13eu3cy", "text": "The same sixty — in only three coins.", "style": "A"}, {"key": "1tleg5f", "text": "A bun — that is eleven.", "style": "A"}, {"key": "1vegeia", "text": "A pot — that is twenty-five.", "style": "A"}, {"key": "hcds52", "text": "A tulip — that is twenty.", "style": "A"}, {"key": "1vv16cd", "text": "A fish — that is sixteen.", "style": "A"}, {"key": "13w8l95", "text": "A tulip — that is sixty-six.", "style": "A"}, {"key": "104qdk6", "text": "That is sixty-six. Just right.", "style": "A"}, {"key": "7phdqc", "text": "An apple — that is thirty-six.", "style": "A"}, {"key": "1dpmu4b", "text": "That is thirty-six. Just right.", "style": "A"}, {"key": "fgmymc", "text": "A bun — that is sixteen.", "style": "A"}, {"key": "1nxcltq", "text": "A pot — that is sixty-two.", "style": "A"}, {"key": "84b3qg", "text": "That is sixty-two. Just right.", "style": "A"}, {"key": "58aj9w", "text": "A tulip — that is seven.", "style": "A"}, {"key": "1rr015x", "text": "An egg — that is twenty.", "style": "A"}, {"key": "bfxe5f", "text": "A fish — that is twenty-one.", "style": "A"}, {"key": "zj1w5f", "text": "A tulip — that is six.", "style": "A"}, {"key": "ih0n05", "text": "A pot — that is seventeen.", "style": "A"}, {"key": "byo9un", "text": "That is seventeen. Just right.", "style": "A"}, {"key": "15t8z0n", "text": "An egg — that is thirty-two.", "style": "A"}, {"key": "hypw9l", "text": "That is thirty-two. Just right.", "style": "A"}, {"key": "8o2kk1", "text": "An apple — that is six.", "style": "A"}, {"key": "19qurrq", "text": "A bun — that is twenty-two.", "style": "A"}, {"key": "78kep9", "text": "A tulip — that is thirty.", "style": "A"}, {"key": "1feohq3", "text": "The same twenty-two — in only four coins.", "style": "A"}, {"key": "15410tm", "text": "A tulip — that is twelve.", "style": "A"}, {"key": "1t2rcsj", "text": "That is twelve. Just right.", "style": "A"}, {"key": "1nnrg23", "text": "A pot — that is forty-five.", "style": "A"}, {"key": "oonx6p", "text": "That is forty-five. Just right.", "style": "A"}, {"key": "9q3567", "text": "An apple — that is twenty-six.", "style": "A"}, {"key": "19diy2k", "text": "A fish — that is thirty-five.", "style": "A"}, {"key": "1068h05", "text": "A bun — that is ten.", "style": "A"}, {"key": "1si9rhy", "text": "A pot — that is twenty-one.", "style": "A"}, {"key": "jawkbp", "text": "The same twenty-six — in only two coins.", "style": "A"}, {"key": "l6l18m", "text": "An egg — that is three.", "style": "A"}, {"key": "m8uyh8", "text": "That is three. Just right.", "style": "A"}, {"key": "1oy6hna", "text": "A tulip — that is twenty-seven.", "style": "A"}, {"key": "jspwec", "text": "A pot — that is two.", "style": "A"}, {"key": "1oif3wa", "text": "An egg — that is twenty-one.", "style": "A"}, {"key": "lhqdn0", "text": "An apple — that is eighteen.", "style": "A"}, {"key": "wsycbr", "text": "That is eighteen. Just right.", "style": "A"}, {"key": "enq17y", "text": "A fish — that is fifteen.", "style": "A"}, {"key": "1i751of", "text": "That is fifteen. Just right.", "style": "A"}, {"key": "cu5255", "text": "A bun — that is eight.", "style": "A"}, {"key": "1r1tfaq", "text": "The same fifty-one — in only three coins.", "style": "A"}, {"key": "1b7nhyt", "text": "An egg — that is thirty-one.", "style": "A"}, {"key": "myaypv", "text": "That is thirty-one. Just right.", "style": "A"}, {"key": "1xka3im", "text": "An egg — that is twenty-five.", "style": "A"}, {"key": "4wu7bn", "text": "The same twenty-five — in only one coins.", "style": "A"}, {"key": "1qj4mjw", "text": "A fish — that is thirty-one.", "style": "A"}, {"key": "1xi8qb9", "text": "A bun — that is thirty-five.", "style": "A"}, {"key": "1pg8i6z", "text": "A pot — that is ten.", "style": "A"}, {"key": "1tgjobp", "text": "A tulip — that is four.", "style": "A"}, {"key": "k046og", "text": "That is four. Just right.", "style": "A"}, {"key": "1nb5hbt", "text": "An egg — that is seventy-five.", "style": "A"}, {"key": "17p1pkv", "text": "That is seventy-five. Just right.", "style": "A"}, {"key": "1ovvo8z", "text": "A pot — that is thirty-five.", "style": "A"}, {"key": "1xspaex", "text": "That is thirty-five. Just right.", "style": "A"}, {"key": "rnhqnh", "text": "An egg — that is seven.", "style": "A"}, {"key": "1489wbg", "text": "An apple — that is twenty.", "style": "A"}, {"key": "f2va56", "text": "A fish — that is thirteen.", "style": "A"}, {"key": "1veqnqx", "text": "That is thirteen. Just right.", "style": "A"}, {"key": "1rsz9oj", "text": "A pot — that is thirteen.", "style": "A"}, {"key": "w5k3jd", "text": "A tulip — that is sixty-one.", "style": "A"}, {"key": "1ge53lb", "text": "The same sixty-one — in only four coins.", "style": "A"}, {"key": "1p1tsjb", "text": "An egg — that is ten.", "style": "A"}, {"key": "1yuqla2", "text": "A pot — that is three.", "style": "A"}, {"key": "alimm5", "text": "An apple — that is forty.", "style": "A"}, {"key": "7nsuzg", "text": "That is forty. Just right.", "style": "A"}, {"key": "1fja1a8", "text": "A fish — that is ten.", "style": "A"}, {"key": "1tfvm8r", "text": "A bun — that is twelve.", "style": "A"}, {"key": "1rfoqql", "text": "This is a rectangle.", "style": "A"}, {"key": "zqi1qx", "text": "A rectangle has 4 sides.", "style": "A"}, {"key": "1pg1cev", "text": "This is a square.", "style": "A"}, {"key": "3ix5fj", "text": "A square has 4 sides.", "style": "A"}, {"key": "160rio2", "text": "This is a circle.", "style": "A"}, {"key": "19pqaft", "text": "A circle has null sides.", "style": "A"}, {"key": "1vcxfcl", "text": "This is a sphere.", "style": "A"}, {"key": "1eznlz6", "text": "A sphere is a solid shape you can hold.", "style": "A"}, {"key": "9u74ne", "text": "This is a hexagon.", "style": "A"}, {"key": "1e4n2ss", "text": "A hexagon has 6 sides.", "style": "A"}, {"key": "1f1nrga", "text": "This is a pentagon.", "style": "A"}, {"key": "jatsgb", "text": "A pentagon has 5 sides.", "style": "A"}, {"key": "14muoo6", "text": "This is a star.", "style": "A"}, {"key": "dv2cid", "text": "A star has null sides.", "style": "A"}, {"key": "e91zis", "text": "This is a cylinder.", "style": "A"}, {"key": "bhggyr", "text": "A cylinder is a solid shape you can hold.", "style": "A"}, {"key": "1l3hvub", "text": "This is a cone.", "style": "A"}, {"key": "1x97hkg", "text": "A cone is a solid shape you can hold.", "style": "A"}]
todo = [r for r in LINES if not (REPO / 'public/audio' / VOICE / f"{r['key']}.mp3").exists()]
json.dump(todo, open(WORK / 'todo.json', 'w'))
print(len(todo), 'lines to render')
assert 0 < len(todo) <= 453, 'nothing to render — every line already has a clip on main'

# %%
# Chatterbox pins torch 2.6, which breaks Kaggle's own torchvision — so it gets its own venv (uv: Kaggle's python has no ensurepip).
VENV = WORK / 'venv'; PY = VENV / 'bin' / 'python'; READY = VENV / '.ready'
if not READY.exists():
    shutil.rmtree(VENV, ignore_errors=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'uv'], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'venv', str(VENV), '--python', sys.executable], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'pip', 'install', '--python', str(PY), 'setuptools<81', 'chatterbox-tts', 'imageio-ffmpeg'], check=True)
    READY.touch()
print(subprocess.run([str(PY), '-c', "import torch; print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NONE — set the accelerator')"], capture_output=True, text=True).stdout)

# %%
OUT = WORK / 'out' / VOICE
cmd = [str(PY), str(REPO / 'scripts/chatterbox-render.py'), '--voice', VOICE, '--corpus', str(WORK / 'todo.json'), '--out', str(OUT)]
proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in proc.stdout:
    if 'it/s]' in line or not line.strip(): continue   # drop the progress bars
    print(line.rstrip()[:160], flush=True)
print('exit code', proc.wait())

# %%
keys = {r['key'] for r in todo}
clips = sorted(c for c in OUT.glob('*.mp3') if c.stem in keys)
missing = [k for k in keys if not (OUT / f'{k}.mp3').exists()]
stage = WORK / 'stage'; shutil.rmtree(stage, ignore_errors=True); (stage / VOICE).mkdir(parents=True)
for c in clips: shutil.copy2(c, stage / VOICE / c.name)
shutil.make_archive(str(WORK / 'radlic-voice-josh-chapters-g2-4'), 'zip', stage)
print(f'{len(clips)} of {len(todo)} clips in radlic-voice-josh-chapters-g2-4.zip' + (f' — MISSING {len(missing)}: {missing}' if missing else ' — complete'))
