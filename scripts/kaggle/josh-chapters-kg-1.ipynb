# %% [markdown]
# # Radlic voice — KG (part 1 of 1) story chapters in Josh
#
# Renders every line the KG (part 1 of 1) story chapters can say that has no clip yet — **1224 lines, 53,175 characters** (the lines are
# written into this notebook). Style A (Chatterbox Turbo) for all of them. Rules: `docs/new-flow/voice.md`.
#
# **Before Run All:** Settings → Accelerator → **GPU T4 x2** (or P100), Internet **On**. At the end, download
# `radlic-voice-josh-chapters-kg-1.zip` from the Output panel and hand it back. If the session stops early, Run All
# again in the same session: lines already rendered are skipped.

# %%
import os, sys, subprocess, pathlib, shutil, json
VOICE = 'nzFihrBIvB34imQBuxub'   # Josh
WORK = pathlib.Path('/kaggle/working' if os.path.isdir('/kaggle/working') else '/content')
REPO = WORK / 'learn-main'
if not REPO.exists():
    subprocess.run(['git', 'clone', '--depth', '1', '--branch', 'main', 'https://github.com/RadlorInc/learn.git', str(REPO)], check=True)
LINES = [{"key": "163yjlw", "text": "Great job!", "style": "A"}, {"key": "1grv0yo", "text": "Nice work!", "style": "A"}, {"key": "tr918i", "text": "Well done!", "style": "A"}, {"key": "12ueh7y", "text": "You got it!", "style": "A"}, {"key": "12du2td", "text": "Lovely!", "style": "A"}, {"key": "3p7ngw", "text": "Good try!", "style": "A"}, {"key": "dlno41", "text": "Nearly there!", "style": "A"}, {"key": "t2osf7", "text": "Let's look again.", "style": "A"}, {"key": "16mdgx6", "text": "Almost!", "style": "A"}, {"key": "vsg0l8", "text": "Not quite — but you're getting it!", "style": "A"}, {"key": "1gpqno1", "text": "Keep going!", "style": "A"}, {"key": "152q4ho", "text": "Try again — you can do it!", "style": "A"}, {"key": "1wsq33r", "text": "Oops! No worries — let's try another!", "style": "A"}, {"key": "tyw155", "text": "Keep practicing!", "style": "A"}, {"key": "10ik6t6", "text": "Don't give up!", "style": "A"}, {"key": "epw9f3", "text": "0", "style": "A"}, {"key": "efwnq4", "text": "1", "style": "A"}, {"key": "f9vgt1", "text": "2", "style": "A"}, {"key": "ezvv42", "text": "3", "style": "A"}, {"key": "dlxun7", "text": "4", "style": "A"}, {"key": "dby8y8", "text": "5", "style": "A"}, {"key": "e5x215", "text": "6", "style": "A"}, {"key": "dvxgc6", "text": "7", "style": "A"}, {"key": "gxt2yv", "text": "8", "style": "A"}, {"key": "gnth9w", "text": "9", "style": "A"}, {"key": "7qvd50", "text": "10", "style": "A"}, {"key": "80uytz", "text": "11", "style": "A"}, {"key": "8aukiy", "text": "12", "style": "A"}, {"key": "8ku67x", "text": "13", "style": "A"}, {"key": "6mwyd4", "text": "14", "style": "A"}, {"key": "6wwk23", "text": "15", "style": "A"}, {"key": "76w5r2", "text": "16", "style": "A"}, {"key": "7gvrg1", "text": "17", "style": "A"}, {"key": "5iyjl8", "text": "18", "style": "A"}, {"key": "5sy5a7", "text": "19", "style": "A"}, {"key": "13dvipr", "text": "20", "style": "A"}, {"key": "16qxqjp", "text": "Here come the ladybugs! Tap each one to count it.", "style": "A"}, {"key": "va1fm6", "text": "Here come the fish! Tap each one to count it.", "style": "A"}, {"key": "pcrfv6", "text": "Here come the ants! Tap each one to count it.", "style": "A"}, {"key": "ect55x", "text": "Here come the turtles! Tap each one to count it.", "style": "A"}, {"key": "z2n1vb", "text": "Here come the eagles! Tap each one to count it.", "style": "A"}, {"key": "1y6fa3k", "text": "Here come the squirrels! Tap each one to count it.", "style": "A"}, {"key": "1n14tg9", "text": "Here come the crabs! Tap each one to count it.", "style": "A"}, {"key": "jkv2fj", "text": "Here come the rabbits! Tap each one to count it.", "style": "A"}, {"key": "15gzmfy", "text": "Here come the sharks! Tap each one to count it.", "style": "A"}, {"key": "1n19pwj", "text": "Here come the lambs! Tap each one to count it.", "style": "A"}, {"key": "1ewop5h", "text": "Here come the frogs! Tap each one to count it.", "style": "A"}, {"key": "1821in3", "text": "Here come the bees! Tap each one to count it.", "style": "A"}, {"key": "1idmbsi", "text": "Here come the ducks! Tap each one to count it.", "style": "A"}, {"key": "124cat9", "text": "Here come the butterflies! Tap each one to count it.", "style": "A"}, {"key": "uq6ds0", "text": "Here come the dragonflies! Tap each one to count it.", "style": "A"}, {"key": "t68d1o", "text": "Here come the aliens! Tap each one to count it.", "style": "A"}, {"key": "1r5zmi6", "text": "Here come the clouds! Tap each one to count it.", "style": "A"}, {"key": "11sn9ed", "text": "Here come the planets! Tap each one to count it.", "style": "A"}, {"key": "1ojnh3s", "text": "Here come the astronauts! Tap each one to count it.", "style": "A"}, {"key": "26y1u2", "text": "Here come the satellites! Tap each one to count it.", "style": "A"}, {"key": "1jzehop", "text": "Mommy Rabbit is ready! Tap the smallest bunny first.", "style": "A"}, {"key": "o7xy9j", "text": "Mommy Fish is ready! Tap the smallest fish first.", "style": "A"}, {"key": "h8aqbz", "text": "Mommy Butterfly is ready! Tap the smallest butterfly first.", "style": "A"}, {"key": "1wm7ajz", "text": "Mommy Squirrel is ready! Tap the smallest squirrel first.", "style": "A"}, {"key": "ip502r", "text": "Mommy Turtle is ready! Tap the smallest turtle first.", "style": "A"}, {"key": "3gter9", "text": "Mommy Ladybug is ready! Tap the smallest ladybug first.", "style": "A"}, {"key": "383mvf", "text": "Mommy Ant is ready! Tap the smallest ant first.", "style": "A"}, {"key": "168xmoj", "text": "Mommy Crab is ready! Tap the smallest crab first.", "style": "A"}, {"key": "12w475v", "text": "Mommy Firefly is ready! Tap the smallest firefly first.", "style": "A"}, {"key": "ljrqb7", "text": "Mommy Shark is ready! Tap the smallest shark first.", "style": "A"}, {"key": "1sfbta", "text": "Feed the chick in nest number 1. Tap the nest that says 1!", "style": "A"}, {"key": "16ztppq", "text": "Feed the chick in nest number 5. Tap the nest that says 5!", "style": "A"}, {"key": "z1zhni", "text": "Feed the chick in nest number 4. Tap the nest that says 4!", "style": "A"}, {"key": "145btly", "text": "Feed the chick in nest number 3. Tap the nest that says 3!", "style": "A"}, {"key": "1inl01y", "text": "Feed the chick in nest number 6. Tap the nest that says 6!", "style": "A"}, {"key": "skf5t2", "text": "Feed the chick in nest number 2. Tap the nest that says 2!", "style": "A"}, {"key": "1huolam", "text": "Feed the chick in nest number 10. Tap the nest that says 10!", "style": "A"}, {"key": "d6vkf2", "text": "Feed the chick in nest number 9. Tap the nest that says 9!", "style": "A"}, {"key": "macbye", "text": "Feed the chick in nest number 7. Tap the nest that says 7!", "style": "A"}, {"key": "1r64mni", "text": "Feed the chick in nest number 8. Tap the nest that says 8!", "style": "A"}, {"key": "1nxm457", "text": "Feed the duckling in nest number 5. Tap the nest that says 5!", "style": "A"}, {"key": "mlem83", "text": "Feed the duckling in nest number 2. Tap the nest that says 2!", "style": "A"}, {"key": "zhzqsj", "text": "Feed the duckling in nest number 6. Tap the nest that says 6!", "style": "A"}, {"key": "z899fb", "text": "Feed the duckling in nest number 10. Tap the nest that says 10!", "style": "A"}, {"key": "haolbv", "text": "Feed the duckling in nest number 8. Tap the nest that says 8!", "style": "A"}, {"key": "1xn0ryj", "text": "Feed the duckling in nest number 4. Tap the nest that says 4!", "style": "A"}, {"key": "g0563f", "text": "Feed the duckling in nest number 1. Tap the nest that says 1!", "style": "A"}, {"key": "f0cygz", "text": "Feed the duckling in nest number 3. Tap the nest that says 3!", "style": "A"}, {"key": "t4ep5v", "text": "Feed the duckling in nest number 7. Tap the nest that says 7!", "style": "A"}, {"key": "1cnmfuz", "text": "Feed the duckling in nest number 9. Tap the nest that says 9!", "style": "A"}, {"key": "qqmaec", "text": "Send exactly 3 bunnies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "dy7tnp", "text": "Send exactly 6 fish home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "knpisd", "text": "Send exactly 7 butterflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "uk5c09", "text": "Send exactly 2 squirrels home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1ahmnwa", "text": "Send exactly 4 turtles home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1770g5x", "text": "Send exactly 7 ladybugs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "87ozjx", "text": "Send exactly 2 ants home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "y0dwgu", "text": "Send exactly 4 crabs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "o5uw1j", "text": "Send exactly 7 fireflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1n8y1dh", "text": "Send exactly 1 shark home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "157d8ba", "text": "Send exactly 7 fish home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "3ft6dr", "text": "Send exactly 1 butterfly home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "c5690m", "text": "Send exactly 5 squirrels home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "14cdr85", "text": "Send exactly 7 turtles home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "g7isah", "text": "Send exactly 3 ladybugs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1h5abtv", "text": "Send exactly 4 ants home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "vyjhvl", "text": "Send exactly 7 crabs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1lbwomt", "text": "Send exactly 1 firefly home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "ggjoag", "text": "Send exactly 5 sharks home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "102k1ag", "text": "Send exactly 7 bunnies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1e7zuc1", "text": "Send exactly 2 fish home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "hkoyjf", "text": "Send exactly 5 butterflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "19zb7ug", "text": "Send exactly 7 squirrels home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "uh9sz0", "text": "Send exactly 1 turtle home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "ihtita", "text": "Send exactly 6 ladybugs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "vco6ll", "text": "Send exactly 6 ants home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "17ou1j8", "text": "Send exactly 2 crabs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "q01j1m", "text": "Send exactly 6 fireflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "105ef9x", "text": "Send exactly 6 sharks home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1q34n72", "text": "Send exactly 1 bunny home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "g70vaq", "text": "Send exactly 3 fish home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "hswo0s", "text": "Send exactly 3 squirrels home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "jkz8mk", "text": "Send exactly 6 turtles home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "xcfv14", "text": "Send exactly 6 crabs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1qkz698", "text": "Send exactly 5 ants home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1fuz9ke", "text": "Send exactly 2 fireflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "qsrlyn", "text": "Send exactly 4 sharks home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1vg0wec", "text": "Send exactly 1 fish home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "j83rs0", "text": "Send exactly 6 butterflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "tjvndc", "text": "Send exactly 2 turtles home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "3u9xu", "text": "Send exactly 7 ants home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "gc6mi0", "text": "Send exactly 1 crab home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "16hs0fk", "text": "Send exactly 4 fireflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "vs48li", "text": "Send exactly 7 sharks home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "11dyem1", "text": "Send exactly 2 bunnies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1gcbjb3", "text": "Send exactly 4 fish home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "n5adah", "text": "Send exactly 3 turtles home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1j80fp2", "text": "Send exactly 3 ants home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1eur5xp", "text": "Send exactly 3 crabs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1ttwfl5", "text": "Send exactly 2 sharks home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1dwfrxp", "text": "Send exactly 6 bunnies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "961dqc", "text": "Send exactly 2 butterflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1ua1sy9", "text": "Send exactly 3 butterflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "12jeomr", "text": "Send exactly 5 ladybugs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "isiwwr", "text": "Send exactly 3 fireflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "121qke0", "text": "Send exactly 5 fish home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1xmhl4z", "text": "Send exactly 5 turtles home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1sowqfz", "text": "Send exactly 5 crabs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1fhsj2i", "text": "Send exactly 3 sharks home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "125qj3f", "text": "Send exactly 4 squirrels home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "9y9w1o", "text": "Send exactly 1 ladybug home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "r8lb0t", "text": "Send exactly 5 fireflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "ytxxeb", "text": "Send exactly 1 squirrel home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1rqmeke", "text": "Send exactly 5 bunnies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1pd36e6", "text": "Send exactly 4 butterflies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "ux34at", "text": "Send exactly 6 squirrels home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "9zq4pn", "text": "Send exactly 4 bunnies home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1bka98y", "text": "Send exactly 2 ladybugs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "x8q80h", "text": "Send exactly 1 ant home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "ekeg6s", "text": "Send exactly 4 ladybugs home. Tap them one by one, then tap Ready.", "style": "A"}, {"key": "1y1ljhm", "text": "Count each bunch. Tap the one with more.", "style": "A"}, {"key": "mp96db", "text": "Count each bunch. Tap the one with the most.", "style": "A"}, {"key": "1jywo44", "text": "Count each bunch. Tap the one with fewer.", "style": "A"}, {"key": "tfxo2e", "text": "Look at the two numbers. Tap the bigger one.", "style": "A"}, {"key": "sj4tgy", "text": "Look at the two numbers. Tap the smaller one.", "style": "A"}, {"key": "1wxtjtj", "text": "The door needs a rectangle. Find the rectangle!", "style": "A"}, {"key": "dgi9lr", "text": "The window needs a circle. Find the circle!", "style": "A"}, {"key": "tc2vw7", "text": "The star on the roof needs a star. Find the star!", "style": "A"}, {"key": "76tw9h", "text": "The heart on the wall needs a heart. Find the heart!", "style": "A"}, {"key": "1yjkai6", "text": "The hull needs a rectangle. Find the rectangle!", "style": "A"}, {"key": "1ihwx3s", "text": "The sail needs a triangle. Find the triangle!", "style": "A"}, {"key": "cl00v4", "text": "The porthole needs a circle. Find the circle!", "style": "A"}, {"key": "zhlkzd", "text": "The flag needs a star. Find the star!", "style": "A"}, {"key": "52rri4", "text": "Color the balloon red. See it glowing? Find the red paint, then tap it!", "style": "A"}, {"key": "74ynbx", "text": "Color the car blue. See it glowing? Find the blue paint, then tap it!", "style": "A"}, {"key": "1j23fal", "text": "Color the star yellow. See it glowing? Find the yellow paint, then tap it!", "style": "A"}, {"key": "1ki68d5", "text": "Color the wall green. See it glowing? Find the green paint, then tap it!", "style": "A"}, {"key": "s573vj", "text": "Color the teddy's head purple. See it glowing? Find the purple paint, then tap it!", "style": "A"}, {"key": "14qbnyp", "text": "Color the rug orange. See it glowing? Find the orange paint, then tap it!", "style": "A"}, {"key": "14w6jck", "text": "Color the ball red. See it glowing? Find the red paint, then tap it!", "style": "A"}, {"key": "domos7", "text": "Color the car window blue. See it glowing? Find the blue paint, then tap it!", "style": "A"}, {"key": "lqn2qu", "text": "Color the cat's face orange. See it glowing? Find the orange paint, then tap it!", "style": "A"}, {"key": "1jod803", "text": "Color the teddy's tummy yellow. See it glowing? Find the yellow paint, then tap it!", "style": "A"}, {"key": "x8vveh", "text": "red! The roof is red.", "style": "A"}, {"key": "2evtk9", "text": "yellow! The sun is yellow.", "style": "A"}, {"key": "1sy6kl8", "text": "blue! The sky is blue.", "style": "A"}, {"key": "3z0piz", "text": "green! The tree is green.", "style": "A"}, {"key": "1fwt3k9", "text": "orange! The rabbit is orange.", "style": "A"}, {"key": "ujkgwj", "text": "purple! The tulip is purple.", "style": "A"}, {"key": "vnbfus", "text": "red! The balloon is red.", "style": "A"}, {"key": "q9ecpd", "text": "blue! The car is blue.", "style": "A"}, {"key": "6odyqx", "text": "yellow! The star is yellow.", "style": "A"}, {"key": "5qnc2n", "text": "green! The wall is green.", "style": "A"}, {"key": "1cvb0qr", "text": "purple! The teddy's head is purple.", "style": "A"}, {"key": "8q1i69", "text": "orange! The rug is orange.", "style": "A"}, {"key": "1tklapa", "text": "red! The ball is red.", "style": "A"}, {"key": "su8so3", "text": "blue! The car window is blue.", "style": "A"}, {"key": "1muasq8", "text": "orange! The cat's face is orange.", "style": "A"}, {"key": "12mnr2j", "text": "yellow! The teddy's tummy is yellow.", "style": "A"}, {"key": "ryhlcf", "text": "red, blue, red, blue. what bead comes next? Tap it!", "style": "A"}, {"key": "x40qzf", "text": "green, orange, green, orange. what bead comes next? Tap it!", "style": "A"}, {"key": "krudn7", "text": "pink, red, pink, red. what bead comes next? Tap it!", "style": "A"}, {"key": "k8z8gv", "text": "yellow, green, yellow, green. what bead comes next? Tap it!", "style": "A"}, {"key": "jt6xu5", "text": "purple, pink, purple, pink. what bead comes next? Tap it!", "style": "A"}, {"key": "13gh6d", "text": "blue, yellow, blue, yellow. what bead comes next? Tap it!", "style": "A"}, {"key": "2qri8t", "text": "orange, purple, orange, purple. what bead comes next? Tap it!", "style": "A"}, {"key": "1c0jyoj", "text": "red, blue, yellow, red, blue, yellow. what bead comes next? Tap it!", "style": "A"}, {"key": "x86f83", "text": "green, orange, purple, green, orange, purple. what bead comes next? Tap it!", "style": "A"}, {"key": "j1u3pv", "text": "pink, red, blue, pink, red, blue. what bead comes next? Tap it!", "style": "A"}, {"key": "1qwlk87", "text": "yellow, green, orange, yellow, green, orange. what bead comes next? Tap it!", "style": "A"}, {"key": "hczycr", "text": "purple, pink, red, purple, pink, red. what bead comes next? Tap it!", "style": "A"}, {"key": "3m4f9f", "text": "blue, yellow, green, blue, yellow, green. what bead comes next? Tap it!", "style": "A"}, {"key": "1ojl999", "text": "orange, purple, pink, orange, purple, pink. what bead comes next? Tap it!", "style": "A"}, {"key": "1nchq5h", "text": "red, blue, yellow, green, red, blue, yellow, green. what bead comes next? Tap it!", "style": "A"}, {"key": "eps3nr", "text": "green, orange, purple, pink, green, orange, purple, pink. what bead comes next? Tap it!", "style": "A"}, {"key": "17fbctz", "text": "pink, red, blue, yellow, pink, red, blue, yellow. what bead comes next? Tap it!", "style": "A"}, {"key": "v99ix3", "text": "yellow, green, orange, purple, yellow, green, orange, purple. what bead comes next? Tap it!", "style": "A"}, {"key": "hiqkrr", "text": "purple, pink, red, blue, purple, pink, red, blue. what bead comes next? Tap it!", "style": "A"}, {"key": "4t38e7", "text": "blue, yellow, green, orange, blue, yellow, green, orange. what bead comes next? Tap it!", "style": "A"}, {"key": "m4437b", "text": "orange, purple, pink, red, orange, purple, pink, red. what bead comes next? Tap it!", "style": "A"}, {"key": "5os0ql", "text": "red, blue, red, blue. what flag comes next? Tap it!", "style": "A"}, {"key": "es7zox", "text": "green, orange, green, orange. what flag comes next? Tap it!", "style": "A"}, {"key": "1kskt09", "text": "pink, red, pink, red. what flag comes next? Tap it!", "style": "A"}, {"key": "wy36a5", "text": "yellow, green, yellow, green. what flag comes next? Tap it!", "style": "A"}, {"key": "1lsll3", "text": "purple, pink, purple, pink. what flag comes next? Tap it!", "style": "A"}, {"key": "usfman", "text": "blue, yellow, blue, yellow. what flag comes next? Tap it!", "style": "A"}, {"key": "ooq1lj", "text": "orange, purple, orange, purple. what flag comes next? Tap it!", "style": "A"}, {"key": "1m0uzrt", "text": "red, blue, yellow, red, blue, yellow. what flag comes next? Tap it!", "style": "A"}, {"key": "1x8wul5", "text": "green, orange, purple, green, orange, purple. what flag comes next? Tap it!", "style": "A"}, {"key": "t254t5", "text": "pink, red, blue, pink, red, blue. what flag comes next? Tap it!", "style": "A"}, {"key": "1mwacdh", "text": "yellow, green, orange, yellow, green, orange. what flag comes next? Tap it!", "style": "A"}, {"key": "1wur98h", "text": "purple, pink, red, purple, pink, red. what flag comes next? Tap it!", "style": "A"}, {"key": "1p5othl", "text": "blue, yellow, green, blue, yellow, green. what flag comes next? Tap it!", "style": "A"}, {"key": "bgfqmv", "text": "orange, purple, pink, orange, purple, pink. what flag comes next? Tap it!", "style": "A"}, {"key": "1fo70jz", "text": "red, blue, yellow, green, red, blue, yellow, green. what flag comes next? Tap it!", "style": "A"}, {"key": "1sb4745", "text": "green, orange, purple, pink, green, orange, purple, pink. what flag comes next? Tap it!", "style": "A"}, {"key": "1dd6rn9", "text": "pink, red, blue, yellow, pink, red, blue, yellow. what flag comes next? Tap it!", "style": "A"}, {"key": "9thked", "text": "yellow, green, orange, purple, yellow, green, orange, purple. what flag comes next? Tap it!", "style": "A"}, {"key": "difcx1", "text": "purple, pink, red, blue, purple, pink, red, blue. what flag comes next? Tap it!", "style": "A"}, {"key": "a43c4t", "text": "blue, yellow, green, orange, blue, yellow, green, orange. what flag comes next? Tap it!", "style": "A"}, {"key": "s1zi0l", "text": "orange, purple, pink, red, orange, purple, pink, red. what flag comes next? Tap it!", "style": "A"}, {"key": "2tmkft", "text": "red, blue, red, blue. what train car comes next? Tap it!", "style": "A"}, {"key": "ijmyod", "text": "green, orange, green, orange. what train car comes next? Tap it!", "style": "A"}, {"key": "a5i31x", "text": "pink, red, pink, red. what train car comes next? Tap it!", "style": "A"}, {"key": "1owqle1", "text": "yellow, green, yellow, green. what train car comes next? Tap it!", "style": "A"}, {"key": "1q9bazr", "text": "purple, pink, purple, pink. what train car comes next? Tap it!", "style": "A"}, {"key": "1cipicf", "text": "blue, yellow, blue, yellow. what train car comes next? Tap it!", "style": "A"}, {"key": "hxeynr", "text": "orange, purple, orange, purple. what train car comes next? Tap it!", "style": "A"}, {"key": "14w0shh", "text": "red, blue, yellow, red, blue, yellow. what train car comes next? Tap it!", "style": "A"}, {"key": "hhcqgl", "text": "green, orange, purple, green, orange, purple. what train car comes next? Tap it!", "style": "A"}, {"key": "ta712t", "text": "pink, red, blue, pink, red, blue. what train car comes next? Tap it!", "style": "A"}, {"key": "324eo1", "text": "yellow, green, orange, yellow, green, orange. what train car comes next? Tap it!", "style": "A"}, {"key": "1p792vx", "text": "purple, pink, red, purple, pink, red. what train car comes next? Tap it!", "style": "A"}, {"key": "11e8md", "text": "blue, yellow, green, blue, yellow, green. what train car comes next? Tap it!", "style": "A"}, {"key": "puqg3b", "text": "orange, purple, pink, orange, purple, pink. what train car comes next? Tap it!", "style": "A"}, {"key": "187gemn", "text": "red, blue, yellow, green, red, blue, yellow, green. what train car comes next? Tap it!", "style": "A"}, {"key": "1us8ntt", "text": "green, orange, purple, pink, green, orange, purple, pink. what train car comes next? Tap it!", "style": "A"}, {"key": "1s8gh5d", "text": "pink, red, blue, yellow, pink, red, blue, yellow. what train car comes next? Tap it!", "style": "A"}, {"key": "1o8hxy9", "text": "yellow, green, orange, purple, yellow, green, orange, purple. what train car comes next? Tap it!", "style": "A"}, {"key": "zlu79d", "text": "purple, pink, red, blue, purple, pink, red, blue. what train car comes next? Tap it!", "style": "A"}, {"key": "160rujt", "text": "blue, yellow, green, orange, blue, yellow, green, orange. what train car comes next? Tap it!", "style": "A"}, {"key": "81k0gh", "text": "orange, purple, pink, red, orange, purple, pink, red. what train car comes next? Tap it!", "style": "A"}, {"key": "1461d9c", "text": "How tall is the tulip? Lay the blocks!", "style": "A"}, {"key": "bjxqgm", "text": "How tall is the apple tree? Lay the blocks!", "style": "A"}, {"key": "1g2xq78", "text": "How tall is the giraffe? Lay the blocks!", "style": "A"}, {"key": "1k6trnu", "text": "How tall is the pine tree? Lay the blocks!", "style": "A"}, {"key": "hw025b", "text": "How tall is the sunflower? Lay the blocks!", "style": "A"}, {"key": "1xdz58y", "text": "How tall is the daisy? Lay the blocks!", "style": "A"}, {"key": "1evaq19", "text": "3. The tulip is 3 blocks tall.", "style": "A"}, {"key": "173tcry", "text": "3 blocks! The tulip is 3 blocks tall.", "style": "A"}, {"key": "1wya88b", "text": "3. The daisy is 3 blocks tall.", "style": "A"}, {"key": "hgml1c", "text": "3 blocks! The daisy is 3 blocks tall.", "style": "A"}, {"key": "hsjnug", "text": "4. The sunflower is 4 blocks tall.", "style": "A"}, {"key": "1lv5555", "text": "4 blocks! The sunflower is 4 blocks tall.", "style": "A"}, {"key": "1l4hobx", "text": "4. The apple tree is 4 blocks tall.", "style": "A"}, {"key": "t91wva", "text": "4 blocks! The apple tree is 4 blocks tall.", "style": "A"}, {"key": "nvj3ox", "text": "5. The giraffe is 5 blocks tall.", "style": "A"}, {"key": "1vkbdim", "text": "5 blocks! The giraffe is 5 blocks tall.", "style": "A"}, {"key": "okkih7", "text": "6. The pine tree is 6 blocks tall.", "style": "A"}, {"key": "yrl6z6", "text": "6 blocks! The pine tree is 6 blocks tall.", "style": "A"}, {"key": "1t26pif", "text": "How long is the fish? Lay the blocks!", "style": "A"}, {"key": "13psoy9", "text": "How long is the train car? Lay the blocks!", "style": "A"}, {"key": "nrrg5n", "text": "How long is the bus? Lay the blocks!", "style": "A"}, {"key": "1vg2ak9", "text": "How long is the snake? Lay the blocks!", "style": "A"}, {"key": "1akpz2w", "text": "How long is the caterpillar? Lay the blocks!", "style": "A"}, {"key": "tvxf8l", "text": "How long is the train engine? Lay the blocks!", "style": "A"}, {"key": "1hd0gae", "text": "3. The fish is 3 blocks long.", "style": "A"}, {"key": "hy2wnf", "text": "3 blocks! The fish is 3 blocks long.", "style": "A"}, {"key": "nwpz3o", "text": "3. The train engine is 3 blocks long.", "style": "A"}, {"key": "13hkv0x", "text": "3 blocks! The train engine is 3 blocks long.", "style": "A"}, {"key": "1stl2l", "text": "4. The caterpillar is 4 blocks long.", "style": "A"}, {"key": "8tmzng", "text": "4 blocks! The caterpillar is 4 blocks long.", "style": "A"}, {"key": "jdi4by", "text": "4. The train car is 4 blocks long.", "style": "A"}, {"key": "gp8mvz", "text": "4 blocks! The train car is 4 blocks long.", "style": "A"}, {"key": "bfns84", "text": "5. The bus is 5 blocks long.", "style": "A"}, {"key": "1gjyvkb", "text": "5 blocks! The bus is 5 blocks long.", "style": "A"}, {"key": "q5h1oq", "text": "6. The snake is 6 blocks long.", "style": "A"}, {"key": "1cw45r7", "text": "6 blocks! The snake is 6 blocks long.", "style": "A"}, {"key": "441d0t", "text": "All done! Nice work.", "style": "A"}, {"key": "1tgxb52", "text": "Great work, 5 questions done! Your spot is saved.", "style": "A"}, {"key": "1jvz1u6", "text": "Let's count together!", "style": "A"}, {"key": "14uu8l8", "text": "Let's learn to count in the forest!", "style": "A"}, {"key": "9t4db6", "text": "You counted everywhere! You are a counting star!", "style": "A"}, {"key": "q1racr", "text": "Welcome to the farm! Let's count the animals together!", "style": "A"}, {"key": "j54e6o", "text": "You counted the whole farm! Wonderful counting!", "style": "A"}, {"key": "1lyvw6s", "text": "Blast off! Let's count our way through space!", "style": "A"}, {"key": "1hp4agw", "text": "You counted across the whole galaxy! You're a counting astronaut!", "style": "A"}, {"key": "13wq00w", "text": "Counting Journey", "style": "A"}, {"key": "1l2oulj", "text": "Farm Day", "style": "A"}, {"key": "8wegfp", "text": "Space Adventure", "style": "A"}, {"key": "jvo7r2", "text": "Now you count! Tap each one you see.", "style": "A"}, {"key": "16eaq3c", "text": "So how many did you count? Tap the number!", "style": "A"}, {"key": "2caerh", "text": "Mommy Rabbit is waiting. The smallest one goes first.", "style": "A"}, {"key": "1azbogd", "text": "The smallest is 1. Come along, 1!", "style": "A"}, {"key": "t220m2", "text": "Then 2.", "style": "A"}, {"key": "kqh3av", "text": "Then 3.", "style": "A"}, {"key": "1vs43h6", "text": "Everybody in line!", "style": "A"}, {"key": "1fgknlg", "text": "Off we go! Smallest first.", "style": "A"}, {"key": "1n4opek", "text": "Now you! Tap the smallest fish first.", "style": "A"}, {"key": "yoz7mn", "text": "This chick is hungry. Listen, nest number 3.", "style": "A"}, {"key": "1wlkxzd", "text": "3! Find the nest that says 3.", "style": "A"}, {"key": "1pq8rry", "text": "There it is! Mommy bird feeds nest number 3.", "style": "A"}, {"key": "17l7mfd", "text": "This chick is hungry. Listen, nest number 5.", "style": "A"}, {"key": "1yvmi5l", "text": "5! Find the nest that says 5.", "style": "A"}, {"key": "z34m6o", "text": "There it is! Mommy bird feeds nest number 5.", "style": "A"}, {"key": "1eidi23", "text": "Forest Nests", "style": "A"}, {"key": "1fgm793", "text": "Now you! Feed the chick in nest number 2. Tap it!", "style": "A"}, {"key": "1jolf7w", "text": "This duckling is hungry. Listen, nest number 3.", "style": "A"}, {"key": "1sjnkte", "text": "This duckling is hungry. Listen, nest number 5.", "style": "A"}, {"key": "1c869zf", "text": "Meadow Nests", "style": "A"}, {"key": "50cmr6", "text": "Now you! Feed the duckling in nest number 2. Tap it!", "style": "A"}, {"key": "vnpxfk", "text": "Evening Nests", "style": "A"}, {"key": "klkqvm", "text": "Yes! Nest number 2! Great job!", "style": "A"}, {"key": "1lkllb3", "text": "We need exactly 3 bunnies to walk home.", "style": "A"}, {"key": "1kszbeb", "text": "One.", "style": "A"}, {"key": "p5tl0l", "text": "Two.", "style": "A"}, {"key": "90vbqv", "text": "Three.", "style": "A"}, {"key": "mxjt9x", "text": "That is 3. We have enough — so we stop, even though there are more.", "style": "A"}, {"key": "zih132", "text": "Ready! Off we go.", "style": "A"}, {"key": "ngfeup", "text": "Four.", "style": "A"}, {"key": "liau7h", "text": "Back you go.", "style": "A"}, {"key": "no4jfj", "text": "3! Just right. Off we go!", "style": "A"}, {"key": "14z5n5u", "text": "Now you! Send exactly 2 fish home.", "style": "A"}, {"key": "1adcu3k", "text": "2! Just right. Off we go!", "style": "A"}, {"key": "1cvqgov", "text": "Let's count this bunch. 4.", "style": "A"}, {"key": "1ylw0f6", "text": "And this bunch. 2.", "style": "A"}, {"key": "ep0vsv", "text": "4 is more — that is the one we pick.", "style": "A"}, {"key": "4ajkus", "text": "Now you! Tap the bunch with more.", "style": "A"}, {"key": "1kfnbhw", "text": "Not that one — look at the numbers again.", "style": "A"}, {"key": "2dse0", "text": "Not quite — count each bunch again.", "style": "A"}, {"key": "o3uh5s", "text": "These are the shapes!", "style": "A"}, {"key": "b4uqa1", "text": "circle", "style": "A"}, {"key": "1e52nuu", "text": "square", "style": "A"}, {"key": "1e17yd", "text": "triangle", "style": "A"}, {"key": "1v9n34e", "text": "rectangle", "style": "A"}, {"key": "1m1y9v5", "text": "star", "style": "A"}, {"key": "42hbdv", "text": "heart", "style": "A"}, {"key": "vwbb8e", "text": "Let's build a house!", "style": "A"}, {"key": "b5z3ke", "text": "Now let's build a boat!", "style": "A"}, {"key": "1wnzhvj", "text": "Look — the wall is missing. It needs a square.", "style": "A"}, {"key": "518391", "text": "This one is a square. Watch it fit!", "style": "A"}, {"key": "s6lgew", "text": "Now you! The wall needs a square. Tap it!", "style": "A"}, {"key": "2fqrzh", "text": "Great job! The square fits!", "style": "A"}, {"key": "1q21zgk", "text": "Look — the roof is missing. It needs a triangle.", "style": "A"}, {"key": "1jgylos", "text": "This one is a triangle. Watch it fit!", "style": "A"}, {"key": "15ky4ub", "text": "Now you! The roof needs a triangle. Tap it!", "style": "A"}, {"key": "1fpt5qq", "text": "Great job! The triangle fits!", "style": "A"}, {"key": "12kqfz0", "text": "This color is red. The roof is red! Pick up the red paint — it is jumping up and down — then tap the roof.", "style": "A"}, {"key": "ctkcsj", "text": "This color is yellow. The sun is yellow! Pick up the yellow paint — it is jumping up and down — then tap the sun.", "style": "A"}, {"key": "14nwr6p", "text": "This color is blue. The sky is blue! Pick up the blue paint — it is jumping up and down — then tap the sky.", "style": "A"}, {"key": "fwgmn8", "text": "This color is green. The tree is green! Pick up the green paint — it is jumping up and down — then tap the tree.", "style": "A"}, {"key": "946iz5", "text": "This color is orange. The rabbit is orange! Pick up the orange paint — it is jumping up and down — then tap the rabbit.", "style": "A"}, {"key": "t33d9t", "text": "This color is purple. The tulip is purple! Pick up the purple paint — it is jumping up and down — then tap the tulip.", "style": "A"}, {"key": "1ywfgev", "text": "Color the roof red. See it glowing? Find the red paint, then tap it!", "style": "A"}, {"key": "62tgx9", "text": "Color the sun yellow. See it glowing? Find the yellow paint, then tap it!", "style": "A"}, {"key": "gdwmoe", "text": "Color the sky blue. See it glowing? Find the blue paint, then tap it!", "style": "A"}, {"key": "163381l", "text": "Color the tree green. See it glowing? Find the green paint, then tap it!", "style": "A"}, {"key": "3i80n5", "text": "Color the rabbit orange. See it glowing? Find the orange paint, then tap it!", "style": "A"}, {"key": "aykxl7", "text": "Color the tulip purple. See it glowing? Find the purple paint, then tap it!", "style": "A"}, {"key": "16sepjo", "text": "A necklace", "style": "A"}, {"key": "1vc72rq", "text": "Party bunting", "style": "A"}, {"key": "1soxu0c", "text": "A long train", "style": "A"}, {"key": "qvxdqm", "text": "Look at the pattern. It goes red, blue, red, blue, over and over.", "style": "A"}, {"key": "tvk0s3", "text": "Yes! The blue one!", "style": "A"}, {"key": "117ctya", "text": "Yes! The red one!", "style": "A"}, {"key": "vdzf65", "text": "So the next bead is blue. Watch it go on!", "style": "A"}, {"key": "1xk6xvf", "text": "Now you! What bead comes next? Tap it!", "style": "A"}, {"key": "i7igs3", "text": "So the next flag is blue. Watch it go on!", "style": "A"}, {"key": "1uqnydt", "text": "Now you! What flag comes next? Tap it!", "style": "A"}, {"key": "1ctl0fn", "text": "So the next train car is blue. Watch it go on!", "style": "A"}, {"key": "g1fa7h", "text": "Now you! What train car comes next? Tap it!", "style": "A"}, {"key": "1drag3n", "text": "How tall is the tulip? Let's lay the blocks!", "style": "A"}, {"key": "17srs4p", "text": "We reached the very top! So the tulip is 3 blocks tall.", "style": "A"}, {"key": "1ks4pnc", "text": "How tall is the sunflower? Let's lay the blocks!", "style": "A"}, {"key": "yctrc3", "text": "We reached the very top! So the sunflower is 4 blocks tall.", "style": "A"}, {"key": "desrxn", "text": "Tall Forest", "style": "A"}, {"key": "7t5jkl", "text": "Your turn! Lay the blocks until you reach the end of the daisy.", "style": "A"}, {"key": "863j4g", "text": "How long is the fish? Let's lay the blocks!", "style": "A"}, {"key": "1t6r3ac", "text": "We reached the very end! So the fish is 3 blocks long.", "style": "A"}, {"key": "n42yvf", "text": "How long is the caterpillar? Let's lay the blocks!", "style": "A"}, {"key": "culv7g", "text": "We reached the very end! So the caterpillar is 4 blocks long.", "style": "A"}, {"key": "1l01w4v", "text": "Long Trail", "style": "A"}, {"key": "ejewyp", "text": "Your turn! Lay the blocks until you reach the end of the train engine.", "style": "A"}, {"key": "1strfby", "text": "Oops — that went past the end. Watch.", "style": "A"}, {"key": "y75eml", "text": "Not quite there yet. Watch.", "style": "A"}, {"key": "1glem4s", "text": "Not yet! Find the smallest bunny.", "style": "A"}, {"key": "j3bhf2", "text": "Not yet! Find the smallest fish.", "style": "A"}, {"key": "18lv8sh", "text": "Not yet! Find the smallest butterfly.", "style": "A"}, {"key": "eq48ep", "text": "Not yet! Find the smallest squirrel.", "style": "A"}, {"key": "a407uq", "text": "Not yet! Find the smallest turtle.", "style": "A"}, {"key": "207lci", "text": "Not yet! Find the smallest ladybug.", "style": "A"}, {"key": "1vdpqv", "text": "Not yet! Find the smallest ant.", "style": "A"}, {"key": "hdf8h2", "text": "Not yet! Find the smallest crab.", "style": "A"}, {"key": "7zyw97", "text": "Not yet! Find the smallest firefly.", "style": "A"}, {"key": "1i5n0p7", "text": "Not yet! Find the smallest shark.", "style": "A"}, {"key": "1aaewur", "text": "Yes! Nest number 1! Great job!", "style": "A"}, {"key": "1xu9wro", "text": "That's 2. Find nest number 1!", "style": "A"}, {"key": "1wt2twl", "text": "That's 3. Find nest number 1!", "style": "A"}, {"key": "1mwkdr6", "text": "That's 4. Find nest number 1!", "style": "A"}, {"key": "1ata3ab", "text": "That's 5. Find nest number 1!", "style": "A"}, {"key": "179ni2o", "text": "That's 6. Find nest number 1!", "style": "A"}, {"key": "1qv7lz5", "text": "That's 7. Find nest number 1!", "style": "A"}, {"key": "1qx4rb2", "text": "That's 8. Find nest number 1!", "style": "A"}, {"key": "15iun6n", "text": "That's 9. Find nest number 1!", "style": "A"}, {"key": "1es8w5p", "text": "That's 10. Find nest number 1!", "style": "A"}, {"key": "p7zlik", "text": "That's 1. Find nest number 2!", "style": "A"}, {"key": "13y509i", "text": "That's 3. Find nest number 2!", "style": "A"}, {"key": "gqe5f5", "text": "That's 4. Find nest number 2!", "style": "A"}, {"key": "6v6zi0", "text": "That's 5. Find nest number 2!", "style": "A"}, {"key": "c6mjvv", "text": "That's 6. Find nest number 2!", "style": "A"}, {"key": "1frkcqa", "text": "That's 7. Find nest number 2!", "style": "A"}, {"key": "2znykt", "text": "That's 8. Find nest number 2!", "style": "A"}, {"key": "jc23sk", "text": "That's 9. Find nest number 2!", "style": "A"}, {"key": "13olmwu", "text": "That's 10. Find nest number 2!", "style": "A"}, {"key": "4ekw7h", "text": "Yes! Nest number 3! Great job!", "style": "A"}, {"key": "1wi48mh", "text": "That's 1. Find nest number 3!", "style": "A"}, {"key": "1ui8dg2", "text": "That's 2. Find nest number 3!", "style": "A"}, {"key": "qq2zw4", "text": "That's 4. Find nest number 3!", "style": "A"}, {"key": "1e5bmlx", "text": "That's 5. Find nest number 3!", "style": "A"}, {"key": "m6becu", "text": "That's 6. Find nest number 3!", "style": "A"}, {"key": "1nj62nj", "text": "That's 7. Find nest number 3!", "style": "A"}, {"key": "uqndg0", "text": "That's 8. Find nest number 3!", "style": "A"}, {"key": "9cd9bl", "text": "That's 9. Find nest number 3!", "style": "A"}, {"key": "1bg7cu3", "text": "That's 10. Find nest number 3!", "style": "A"}, {"key": "1jazn78", "text": "Yes! Nest number 4! Great job!", "style": "A"}, {"key": "wz3cc6", "text": "That's 1. Find nest number 4!", "style": "A"}, {"key": "zf7f99", "text": "That's 2. Find nest number 4!", "style": "A"}, {"key": "w719fw", "text": "That's 3. Find nest number 4!", "style": "A"}, {"key": "a78itm", "text": "That's 5. Find nest number 4!", "style": "A"}, {"key": "m6tdgh", "text": "That's 6. Find nest number 4!", "style": "A"}, {"key": "1cfiteo", "text": "That's 7. Find nest number 4!", "style": "A"}, {"key": "o302an", "text": "That's 8. Find nest number 4!", "style": "A"}, {"key": "9bva7y", "text": "That's 9. Find nest number 4!", "style": "A"}, {"key": "1dosghg", "text": "That's 10. Find nest number 4!", "style": "A"}, {"key": "wuu2nz", "text": "Yes! Nest number 5! Great job!", "style": "A"}, {"key": "mzehv7", "text": "That's 1. Find nest number 5!", "style": "A"}, {"key": "rnlpc0", "text": "That's 2. Find nest number 5!", "style": "A"}, {"key": "13ymzd5", "text": "That's 3. Find nest number 5!", "style": "A"}, {"key": "gpw6bi", "text": "That's 4. Find nest number 5!", "style": "A"}, {"key": "ef7nj8", "text": "That's 6. Find nest number 5!", "style": "A"}, {"key": "kojejh", "text": "That's 7. Find nest number 5!", "style": "A"}, {"key": "y2owrm", "text": "That's 8. Find nest number 5!", "style": "A"}, {"key": "h3h057", "text": "That's 9. Find nest number 5!", "style": "A"}, {"key": "13p3m0h", "text": "That's 10. Find nest number 5!", "style": "A"}, {"key": "1pujtn2", "text": "Yes! Nest number 6! Great job!", "style": "A"}, {"key": "10b4vns", "text": "That's 1. Find nest number 6!", "style": "A"}, {"key": "1vlot4b", "text": "That's 2. Find nest number 6!", "style": "A"}, {"key": "b3p5q2", "text": "That's 3. Find nest number 6!", "style": "A"}, {"key": "rtjfkd", "text": "That's 4. Find nest number 6!", "style": "A"}, {"key": "1d1v6xo", "text": "That's 5. Find nest number 6!", "style": "A"}, {"key": "rc6pou", "text": "That's 7. Find nest number 6!", "style": "A"}, {"key": "1qxmqep", "text": "That's 8. Find nest number 6!", "style": "A"}, {"key": "1c6hyc0", "text": "That's 9. Find nest number 6!", "style": "A"}, {"key": "au5sde", "text": "That's 10. Find nest number 6!", "style": "A"}, {"key": "139vrtl", "text": "Yes! Nest number 7! Great job!", "style": "A"}, {"key": "qbg16t", "text": "That's 1. Find nest number 7!", "style": "A"}, {"key": "6k9lm6", "text": "That's 2. Find nest number 7!", "style": "A"}, {"key": "140b93", "text": "That's 3. Find nest number 7!", "style": "A"}, {"key": "1jkiufk", "text": "That's 4. Find nest number 7!", "style": "A"}, {"key": "1326cgp", "text": "That's 5. Find nest number 7!", "style": "A"}, {"key": "b3647m", "text": "That's 6. Find nest number 7!", "style": "A"}, {"key": "1w7iwk", "text": "That's 8. Find nest number 7!", "style": "A"}, {"key": "kfijgt", "text": "That's 9. Find nest number 7!", "style": "A"}, {"key": "ugxwf", "text": "That's 10. Find nest number 7!", "style": "A"}, {"key": "1ipx2s0", "text": "Yes! Nest number 8! Great job!", "style": "A"}, {"key": "1yqpc9u", "text": "That's 1. Find nest number 8!", "style": "A"}, {"key": "1s9n9sp", "text": "That's 2. Find nest number 8!", "style": "A"}, {"key": "3clewg", "text": "That's 3. Find nest number 8!", "style": "A"}, {"key": "1hbxqs7", "text": "That's 4. Find nest number 8!", "style": "A"}, {"key": "1gdwq9a", "text": "That's 5. Find nest number 8!", "style": "A"}, {"key": "jxqaph", "text": "That's 6. Find nest number 8!", "style": "A"}, {"key": "1nio3jw", "text": "That's 7. Find nest number 8!", "style": "A"}, {"key": "1jxlp5m", "text": "That's 9. Find nest number 8!", "style": "A"}, {"key": "1bfpdqg", "text": "That's 10. Find nest number 8!", "style": "A"}, {"key": "p0yvjf", "text": "Yes! Nest number 9! Great job!", "style": "A"}, {"key": "1or0hsv", "text": "That's 1. Find nest number 9!", "style": "A"}, {"key": "3882ak", "text": "That's 2. Find nest number 9!", "style": "A"}, {"key": "b474tp", "text": "That's 3. Find nest number 9!", "style": "A"}, {"key": "1rbml96", "text": "That's 4. Find nest number 9!", "style": "A"}, {"key": "16e7vsb", "text": "That's 5. Find nest number 9!", "style": "A"}, {"key": "1boppko", "text": "That's 6. Find nest number 9!", "style": "A"}, {"key": "1diz92x", "text": "That's 7. Find nest number 9!", "style": "A"}, {"key": "1vc6yt2", "text": "That's 8. Find nest number 9!", "style": "A"}, {"key": "11g0j9h", "text": "That's 10. Find nest number 9!", "style": "A"}, {"key": "m1fd4d", "text": "Yes! Nest number 10! Great job!", "style": "A"}, {"key": "v00lxr", "text": "That's 1. Find nest number 10!", "style": "A"}, {"key": "1jqfd0y", "text": "That's 2. Find nest number 10!", "style": "A"}, {"key": "199hvvd", "text": "That's 3. Find nest number 10!", "style": "A"}, {"key": "1fnkvxo", "text": "That's 4. Find nest number 10!", "style": "A"}, {"key": "6gxl5f", "text": "That's 5. Find nest number 10!", "style": "A"}, {"key": "r1gakm", "text": "That's 6. Find nest number 10!", "style": "A"}, {"key": "2uamdp", "text": "That's 7. Find nest number 10!", "style": "A"}, {"key": "1pw5dgg", "text": "That's 8. Find nest number 10!", "style": "A"}, {"key": "14530x3", "text": "That's 9. Find nest number 10!", "style": "A"}, {"key": "1eikn21", "text": "Tap the bunnies to send them home.", "style": "A"}, {"key": "84z00h", "text": "Tap the fish to send them home.", "style": "A"}, {"key": "1fj8rs4", "text": "Tap the butterflies to send them home.", "style": "A"}, {"key": "lw3rk1", "text": "Tap the squirrels to send them home.", "style": "A"}, {"key": "1jzw6gg", "text": "Tap the turtles to send them home.", "style": "A"}, {"key": "jc429i", "text": "Tap the ladybugs to send them home.", "style": "A"}, {"key": "1o4ywmt", "text": "Tap the ants to send them home.", "style": "A"}, {"key": "10jy7q4", "text": "Tap the crabs to send them home.", "style": "A"}, {"key": "pzaude", "text": "Tap the fireflies to send them home.", "style": "A"}, {"key": "1spa8m9", "text": "Tap the sharks to send them home.", "style": "A"}, {"key": "1sqiszp", "text": "That is 2 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "sz56vm", "text": "That is 3 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "15ujf9r", "text": "That is 4 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "1ts9ab0", "text": "That is 5 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "1rlcld5", "text": "That is 6 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "1r5azue", "text": "That is 7 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "1ipvehf", "text": "That is 8 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "1smgbgw", "text": "That is 9 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "ixpb62", "text": "That is 10 — too many! We need 1. Tap one to send it back.", "style": "A"}, {"key": "1uxyn29", "text": "That is only 1. We need 2 — send some more!", "style": "A"}, {"key": "1stj8sr", "text": "That is 3 — too many! We need 2. Tap one to send it back.", "style": "A"}, {"key": "9zrq86", "text": "That is 4 — too many! We need 2. Tap one to send it back.", "style": "A"}, {"key": "1ja1ow1", "text": "That is 5 — too many! We need 2. Tap one to send it back.", "style": "A"}, {"key": "srhes4", "text": "That is 6 — too many! We need 2. Tap one to send it back.", "style": "A"}, {"key": "1bd7t33", "text": "That is 7 — too many! We need 2. Tap one to send it back.", "style": "A"}, {"key": "zqdc2i", "text": "That is 8 — too many! We need 2. Tap one to send it back.", "style": "A"}, {"key": "yxdts5", "text": "That is 9 — too many! We need 2. Tap one to send it back.", "style": "A"}, {"key": "ipbnnn", "text": "That is 10 — too many! We need 2. Tap one to send it back.", "style": "A"}, {"key": "zwvh6i", "text": "That is only 1. We need 3 — send some more!", "style": "A"}, {"key": "d1fjq5", "text": "That is only 2. We need 3 — send some more!", "style": "A"}, {"key": "gxsssd", "text": "That is 4 — too many! We need 3. Tap one to send it back.", "style": "A"}, {"key": "chiaui", "text": "That is 5 — too many! We need 3. Tap one to send it back.", "style": "A"}, {"key": "1bdbtm3", "text": "That is 6 — too many! We need 3. Tap one to send it back.", "style": "A"}, {"key": "1ofqlq0", "text": "That is 7 — too many! We need 3. Tap one to send it back.", "style": "A"}, {"key": "1gpu0c1", "text": "That is 8 — too many! We need 3. Tap one to send it back.", "style": "A"}, {"key": "5scvri", "text": "That is 9 — too many! We need 3. Tap one to send it back.", "style": "A"}, {"key": "1hx5424", "text": "That is 10 — too many! We need 3. Tap one to send it back.", "style": "A"}, {"key": "o6tpub", "text": "That is only 1. We need 4 — send some more!", "style": "A"}, {"key": "1b95opk", "text": "That is only 2. We need 4 — send some more!", "style": "A"}, {"key": "1lxym6l", "text": "That is only 3. We need 4 — send some more!", "style": "A"}, {"key": "1gvgqif", "text": "That is 5 — too many! We need 4. Tap one to send it back.", "style": "A"}, {"key": "jcik3a", "text": "That is 6 — too many! We need 4. Tap one to send it back.", "style": "A"}, {"key": "147arjd", "text": "That is 7 — too many! We need 4. Tap one to send it back.", "style": "A"}, {"key": "1onpfnk", "text": "That is 8 — too many! We need 4. Tap one to send it back.", "style": "A"}, {"key": "1vsffqb", "text": "That is 9 — too many! We need 4. Tap one to send it back.", "style": "A"}, {"key": "jbzk11", "text": "That is 10 — too many! We need 4. Tap one to send it back.", "style": "A"}, {"key": "1h4ph04", "text": "That is only 1. We need 5 — send some more!", "style": "A"}, {"key": "z0g3hz", "text": "That is only 2. We need 5 — send some more!", "style": "A"}, {"key": "yt9brq", "text": "That is only 3. We need 5 — send some more!", "style": "A"}, {"key": "drd4u1", "text": "That is only 4. We need 5 — send some more!", "style": "A"}, {"key": "18u4p0t", "text": "That is 6 — too many! We need 5. Tap one to send it back.", "style": "A"}, {"key": "zmm46q", "text": "That is 7 — too many! We need 5. Tap one to send it back.", "style": "A"}, {"key": "1f4qq5j", "text": "That is 8 — too many! We need 5. Tap one to send it back.", "style": "A"}, {"key": "1bgdqng", "text": "That is 9 — too many! We need 5. Tap one to send it back.", "style": "A"}, {"key": "1d9w1v2", "text": "That is 10 — too many! We need 5. Tap one to send it back.", "style": "A"}, {"key": "1wshj05", "text": "That is only 1. We need 6 — send some more!", "style": "A"}, {"key": "dn1yde", "text": "That is only 2. We need 6 — send some more!", "style": "A"}, {"key": "1utyanf", "text": "That is only 3. We need 6 — send some more!", "style": "A"}, {"key": "1lno27c", "text": "That is only 4. We need 6 — send some more!", "style": "A"}, {"key": "zgqs89", "text": "That is only 5. We need 6 — send some more!", "style": "A"}, {"key": "1s82rmz", "text": "That is 7 — too many! We need 6. Tap one to send it back.", "style": "A"}, {"key": "5g1a66", "text": "That is 8 — too many! We need 6. Tap one to send it back.", "style": "A"}, {"key": "1j6uwap", "text": "That is 9 — too many! We need 6. Tap one to send it back.", "style": "A"}, {"key": "1wlkniv", "text": "That is 10 — too many! We need 6. Tap one to send it back.", "style": "A"}, {"key": "vyxxwe", "text": "That is only 1. We need 7 — send some more!", "style": "A"}, {"key": "i326uh", "text": "That is only 2. We need 7 — send some more!", "style": "A"}, {"key": "1u4ul9o", "text": "That is only 3. We need 7 — send some more!", "style": "A"}, {"key": "2shpxj", "text": "That is only 4. We need 7 — send some more!", "style": "A"}, {"key": "18c2phe", "text": "That is only 5. We need 7 — send some more!", "style": "A"}, {"key": "xw6dl9", "text": "That is only 6. We need 7 — send some more!", "style": "A"}, {"key": "1t4uy7p", "text": "That is 8 — too many! We need 7. Tap one to send it back.", "style": "A"}, {"key": "l1999m", "text": "That is 9 — too many! We need 7. Tap one to send it back.", "style": "A"}, {"key": "6cyfn4", "text": "That is 10 — too many! We need 7. Tap one to send it back.", "style": "A"}, {"key": "1o41fq6", "text": "Now you! Tap the bunch with fewer.", "style": "A"}, {"key": "xu5p5l", "text": "Now you! Tap the bunch with the most.", "style": "A"}, {"key": "g0y2ki", "text": "Now you! Tap the bunch with the fewest.", "style": "A"}, {"key": "qvuejz", "text": "That's a circle. It doesn't fit. Look at the hole!", "style": "A"}, {"key": "18aeca", "text": "That's a square. It doesn't fit. Look at the hole!", "style": "A"}, {"key": "1nyzckb", "text": "That's a triangle. It doesn't fit. Look at the hole!", "style": "A"}, {"key": "1k8twge", "text": "That's a rectangle. It doesn't fit. Look at the hole!", "style": "A"}, {"key": "79z4qz", "text": "That's a star. It doesn't fit. Look at the hole!", "style": "A"}, {"key": "1153mlh", "text": "That's a heart. It doesn't fit. Look at the hole!", "style": "A"}, {"key": "a4hi5y", "text": "Pick up a paint first! We need red.", "style": "A"}, {"key": "1fz7811", "text": "Pick up a paint first! We need yellow.", "style": "A"}, {"key": "1tj5f2x", "text": "Pick up a paint first! We need blue.", "style": "A"}, {"key": "1ag7f9y", "text": "Pick up a paint first! We need green.", "style": "A"}, {"key": "1jlk9r3", "text": "Pick up a paint first! We need orange.", "style": "A"}, {"key": "1ivz9f", "text": "Pick up a paint first! We need purple.", "style": "A"}, {"key": "1oc31oq", "text": "That one is red. We want yellow — the paint that is jumping!", "style": "A"}, {"key": "1q7tna", "text": "That's red paint. We need yellow!", "style": "A"}, {"key": "igole2", "text": "That one is red. We want blue — the paint that is jumping!", "style": "A"}, {"key": "7rtpcm", "text": "That's red paint. We need blue!", "style": "A"}, {"key": "19v3ty1", "text": "That one is red. We want green — the paint that is jumping!", "style": "A"}, {"key": "1yy33ct", "text": "That's red paint. We need green!", "style": "A"}, {"key": "1kypk4k", "text": "That one is red. We want orange — the paint that is jumping!", "style": "A"}, {"key": "1w8qxzo", "text": "That's red paint. We need orange!", "style": "A"}, {"key": "hyij18", "text": "That one is red. We want purple — the paint that is jumping!", "style": "A"}, {"key": "58znn8", "text": "That's red paint. We need purple!", "style": "A"}, {"key": "1ugeim6", "text": "That one is yellow. We want red — the paint that is jumping!", "style": "A"}, {"key": "156znw2", "text": "That's yellow paint. We need red!", "style": "A"}, {"key": "1e7jhrz", "text": "That one is yellow. We want blue — the paint that is jumping!", "style": "A"}, {"key": "ma3qaf", "text": "That's yellow paint. We need blue!", "style": "A"}, {"key": "jafo6i", "text": "That one is yellow. We want green — the paint that is jumping!", "style": "A"}, {"key": "fsbuue", "text": "That's yellow paint. We need green!", "style": "A"}, {"key": "1qq0031", "text": "That one is yellow. We want orange — the paint that is jumping!", "style": "A"}, {"key": "w04boh", "text": "That's yellow paint. We need orange!", "style": "A"}, {"key": "tmoaf9", "text": "That one is yellow. We want purple — the paint that is jumping!", "style": "A"}, {"key": "15z9lt", "text": "That's yellow paint. We need purple!", "style": "A"}, {"key": "orjqh6", "text": "That one is blue. We want red — the paint that is jumping!", "style": "A"}, {"key": "2tdocy", "text": "That's blue paint. We need red!", "style": "A"}, {"key": "kcz66v", "text": "That one is blue. We want yellow — the paint that is jumping!", "style": "A"}, {"key": "fukd9n", "text": "That's blue paint. We need yellow!", "style": "A"}, {"key": "mv0a86", "text": "That one is blue. We want green — the paint that is jumping!", "style": "A"}, {"key": "k1eldy", "text": "That's blue paint. We need green!", "style": "A"}, {"key": "19p7fkx", "text": "That one is blue. We want orange — the paint that is jumping!", "style": "A"}, {"key": "t2v11d", "text": "That's blue paint. We need orange!", "style": "A"}, {"key": "v86q8x", "text": "That one is blue. We want purple — the paint that is jumping!", "style": "A"}, {"key": "ms6wqp", "text": "That's blue paint. We need purple!", "style": "A"}, {"key": "1yxiuel", "text": "That one is green. We want red — the paint that is jumping!", "style": "A"}, {"key": "1wo2hrt", "text": "That's green paint. We need red!", "style": "A"}, {"key": "lsfyfy", "text": "That one is green. We want yellow — the paint that is jumping!", "style": "A"}, {"key": "1k4f7nm", "text": "That's green paint. We need yellow!", "style": "A"}, {"key": "pz8mby", "text": "That one is green. We want blue — the paint that is jumping!", "style": "A"}, {"key": "oqhxuq", "text": "That's green paint. We need blue!", "style": "A"}, {"key": "18nyx6o", "text": "That one is green. We want orange — the paint that is jumping!", "style": "A"}, {"key": "1bav8wo", "text": "That's green paint. We need orange!", "style": "A"}, {"key": "13p2nf4", "text": "That one is green. We want purple — the paint that is jumping!", "style": "A"}, {"key": "1io6lls", "text": "That's green paint. We need purple!", "style": "A"}, {"key": "1kdq9ls", "text": "That one is orange. We want red — the paint that is jumping!", "style": "A"}, {"key": "27dd5c", "text": "That's orange paint. We need red!", "style": "A"}, {"key": "i90971", "text": "That one is orange. We want yellow — the paint that is jumping!", "style": "A"}, {"key": "hu97pl", "text": "That's orange paint. We need yellow!", "style": "A"}, {"key": "p3g1e5", "text": "That one is orange. We want blue — the paint that is jumping!", "style": "A"}, {"key": "1ylbjgp", "text": "That's orange paint. We need blue!", "style": "A"}, {"key": "151s7no", "text": "That one is orange. We want green — the paint that is jumping!", "style": "A"}, {"key": "rxfdak", "text": "That's orange paint. We need green!", "style": "A"}, {"key": "1vk3my3", "text": "That one is orange. We want purple — the paint that is jumping!", "style": "A"}, {"key": "ykf2zf", "text": "That's orange paint. We need purple!", "style": "A"}, {"key": "rzh3ls", "text": "That one is purple. We want red — the paint that is jumping!", "style": "A"}, {"key": "1roj82s", "text": "That's purple paint. We need red!", "style": "A"}, {"key": "12qts31", "text": "That one is purple. We want yellow — the paint that is jumping!", "style": "A"}, {"key": "byl2d9", "text": "That's purple paint. We need yellow!", "style": "A"}, {"key": "136byel", "text": "That one is purple. We want blue — the paint that is jumping!", "style": "A"}, {"key": "1ggv50t", "text": "That's purple paint. We need blue!", "style": "A"}, {"key": "uq1hd0", "text": "That one is purple. We want green — the paint that is jumping!", "style": "A"}, {"key": "yttkfk", "text": "That's purple paint. We need green!", "style": "A"}, {"key": "y7w5z", "text": "That one is purple. We want orange — the paint that is jumping!", "style": "A"}, {"key": "1hwfhjn", "text": "That's purple paint. We need orange!", "style": "A"}, {"key": "5s7fsm", "text": "Now, where is the roof? Look for the glowing part!", "style": "A"}, {"key": "1p7qa9a", "text": "That's the other roof! Tap the one that is glowing.", "style": "A"}, {"key": "6k8hgz", "text": "That's the roof! Tap the part that is glowing.", "style": "A"}, {"key": "15igx0g", "text": "Now, where is the sun? Look for the glowing part!", "style": "A"}, {"key": "cv4vks", "text": "That's the other sun! Tap the one that is glowing.", "style": "A"}, {"key": "m15i0d", "text": "That's the sun! Tap the part that is glowing.", "style": "A"}, {"key": "jqcr4z", "text": "Now, where is the sky? Look for the glowing part!", "style": "A"}, {"key": "sd73or", "text": "That's the other sky! Tap the one that is glowing.", "style": "A"}, {"key": "8uatv8", "text": "That's the sky! Tap the part that is glowing.", "style": "A"}, {"key": "7o1sg4", "text": "Now, where is the tree? Look for the glowing part!", "style": "A"}, {"key": "5zaiko", "text": "That's the other tree! Tap the one that is glowing.", "style": "A"}, {"key": "1e1qjyh", "text": "That's the tree! Tap the part that is glowing.", "style": "A"}, {"key": "1ohmtd8", "text": "Now, where is the rabbit? Look for the glowing part!", "style": "A"}, {"key": "1nf96mg", "text": "That's the other rabbit! Tap the one that is glowing.", "style": "A"}, {"key": "15tc9gx", "text": "That's the rabbit! Tap the part that is glowing.", "style": "A"}, {"key": "oc5jzy", "text": "Now, where is the tulip? Look for the glowing part!", "style": "A"}, {"key": "1h6vc42", "text": "That's the other tulip! Tap the one that is glowing.", "style": "A"}, {"key": "1x04vlv", "text": "That's the tulip! Tap the part that is glowing.", "style": "A"}, {"key": "1wk7hzx", "text": "Now, where is the balloon? Look for the glowing part!", "style": "A"}, {"key": "1v6e3o5", "text": "That's the other balloon! Tap the one that is glowing.", "style": "A"}, {"key": "cjuyt2", "text": "That's the balloon! Tap the part that is glowing.", "style": "A"}, {"key": "1atnbc0", "text": "Now, where is the car? Look for the glowing part!", "style": "A"}, {"key": "tuzqr0", "text": "That's the other car! Tap the one that is glowing.", "style": "A"}, {"key": "1q9jlrx", "text": "That's the car! Tap the part that is glowing.", "style": "A"}, {"key": "lxybfo", "text": "Now, where is the star? Look for the glowing part!", "style": "A"}, {"key": "dextv0", "text": "That's the other star! Tap the one that is glowing.", "style": "A"}, {"key": "1wx9asp", "text": "That's the star! Tap the part that is glowing.", "style": "A"}, {"key": "3x1pn0", "text": "Now, where is the wall? Look for the glowing part!", "style": "A"}, {"key": "m5qkso", "text": "That's the other wall! Tap the one that is glowing.", "style": "A"}, {"key": "e8g48x", "text": "That's the wall! Tap the part that is glowing.", "style": "A"}, {"key": "1pviqm", "text": "Now, where is the teddy's head? Look for the glowing part!", "style": "A"}, {"key": "1c75xau", "text": "That's the other teddy's head! Tap the one that is glowing.", "style": "A"}, {"key": "1aads0r", "text": "That's the teddy's head! Tap the part that is glowing.", "style": "A"}, {"key": "wvso5g", "text": "Now, where is the rug? Look for the glowing part!", "style": "A"}, {"key": "93tuko", "text": "That's the other rug! Tap the one that is glowing.", "style": "A"}, {"key": "1jreep5", "text": "That's the rug! Tap the part that is glowing.", "style": "A"}, {"key": "v25tkd", "text": "Now, where is the ball? Look for the glowing part!", "style": "A"}, {"key": "lajt6l", "text": "That's the other ball! Tap the one that is glowing.", "style": "A"}, {"key": "18rhv6e", "text": "That's the ball! Tap the part that is glowing.", "style": "A"}, {"key": "7f9k3m", "text": "Now, where is the car window? Look for the glowing part!", "style": "A"}, {"key": "1synumq", "text": "That's the other car window! Tap the one that is glowing.", "style": "A"}, {"key": "nooryv", "text": "That's the car window! Tap the part that is glowing.", "style": "A"}, {"key": "1cncy7", "text": "Now, where is the cat's face? Look for the glowing part!", "style": "A"}, {"key": "jjxxkv", "text": "That's the other cat's face! Tap the one that is glowing.", "style": "A"}, {"key": "1u759lc", "text": "That's the cat's face! Tap the part that is glowing.", "style": "A"}, {"key": "1eoex36", "text": "Now, where is the teddy's tummy? Look for the glowing part!", "style": "A"}, {"key": "atp2sm", "text": "That's the other teddy's tummy! Tap the one that is glowing.", "style": "A"}, {"key": "rmr9wf", "text": "That's the teddy's tummy! Tap the part that is glowing.", "style": "A"}, {"key": "1cb0uwz", "text": "That one is red. Look at the pattern again — what comes next?", "style": "A"}, {"key": "12twed4", "text": "That one is blue. Look at the pattern again — what comes next?", "style": "A"}, {"key": "1shg9fj", "text": "Yes! The yellow one!", "style": "A"}, {"key": "c3une4", "text": "That one is yellow. Look at the pattern again — what comes next?", "style": "A"}, {"key": "13qgev2", "text": "Yes! The green one!", "style": "A"}, {"key": "1fuxqyv", "text": "That one is green. Look at the pattern again — what comes next?", "style": "A"}, {"key": "5be04t", "text": "Yes! The orange one!", "style": "A"}, {"key": "17pntue", "text": "That one is orange. Look at the pattern again — what comes next?", "style": "A"}, {"key": "urro2l", "text": "Yes! The purple one!", "style": "A"}, {"key": "19rdxva", "text": "That one is purple. Look at the pattern again — what comes next?", "style": "A"}, {"key": "fjdpz7", "text": "Yes! The pink one!", "style": "A"}, {"key": "igmslk", "text": "That one is pink. Look at the pattern again — what comes next?", "style": "A"}, {"key": "1vxgnrj", "text": "Mommy Fish is waiting. The smallest one goes first.", "style": "A"}, {"key": "rvub8t", "text": "The smallest is 3. Come along, 3!", "style": "A"}, {"key": "tmpi3l", "text": "Then 5.", "style": "A"}, {"key": "1jpxlsw", "text": "Then 8.", "style": "A"}, {"key": "oit2kv", "text": "Then 10.", "style": "A"}, {"key": "mv959c", "text": "Mommy Butterfly is waiting. The smallest one goes first.", "style": "A"}, {"key": "k6zv0k", "text": "Then 4.", "style": "A"}, {"key": "1skzree", "text": "Then 6.", "style": "A"}, {"key": "ziehio", "text": "Mommy Squirrel is waiting. The smallest one goes first.", "style": "A"}, {"key": "1873yxv", "text": "Mommy Turtle is waiting. The smallest one goes first.", "style": "A"}, {"key": "1eslgsb", "text": "The smallest is 6. Come along, 6!", "style": "A"}, {"key": "1k9eu37", "text": "Then 7.", "style": "A"}, {"key": "1k9zyot", "text": "Then 9.", "style": "A"}, {"key": "i5wxcz", "text": "Mommy Ladybug is waiting. The smallest one goes first.", "style": "A"}, {"key": "hqlgju", "text": "Mommy Ant is waiting. The smallest one goes first.", "style": "A"}, {"key": "17nocgb", "text": "The smallest is 2. Come along, 2!", "style": "A"}, {"key": "14dlsxb", "text": "Mommy Crab is waiting. The smallest one goes first.", "style": "A"}, {"key": "wt7yjy", "text": "Mommy Firefly is waiting. The smallest one goes first.", "style": "A"}, {"key": "1ybgrv2", "text": "Mommy Shark is waiting. The smallest one goes first.", "style": "A"}, {"key": "ulk4iv", "text": "The smallest is 4. Come along, 4!", "style": "A"}, {"key": "1ccpb3h", "text": "The smallest is 7. Come along, 7!", "style": "A"}, {"key": "1uc9thp", "text": "The smallest is 5. Come along, 5!", "style": "A"}, {"key": "172od32", "text": "Now you! Tap the smallest bunny first.", "style": "A"}, {"key": "1hd6n2v", "text": "Now you! Tap the smallest butterfly first.", "style": "A"}, {"key": "4ja47", "text": "Now you! Tap the smallest squirrel first.", "style": "A"}, {"key": "16oerwg", "text": "Now you! Tap the smallest turtle first.", "style": "A"}, {"key": "1wlkouo", "text": "Now you! Tap the smallest ladybug first.", "style": "A"}, {"key": "12u2mrl", "text": "Now you! Tap the smallest ant first.", "style": "A"}, {"key": "102nkas", "text": "Now you! Tap the smallest crab first.", "style": "A"}, {"key": "3h2eyt", "text": "Now you! Tap the smallest firefly first.", "style": "A"}, {"key": "mlhn1x", "text": "Now you! Tap the smallest shark first.", "style": "A"}, {"key": "1k98j39", "text": "Then 1.", "style": "A"}, {"key": "8zfktb", "text": "The smallest is 8. Come along, 8!", "style": "A"}, {"key": "81toal", "text": "The smallest is 9. Come along, 9!", "style": "A"}, {"key": "i13bvl", "text": "The smallest is 10. Come along, 10!", "style": "A"}, {"key": "y4bq54", "text": "This chick is hungry. Listen, nest number 8.", "style": "A"}, {"key": "emv4dr", "text": "8! Find the nest that says 8.", "style": "A"}, {"key": "1q9q029", "text": "There it is! Mommy bird feeds nest number 8.", "style": "A"}, {"key": "82g6mz", "text": "This chick is hungry. Listen, nest number 7.", "style": "A"}, {"key": "wcgj29", "text": "7! Find the nest that says 7.", "style": "A"}, {"key": "1ylh8de", "text": "There it is! Mommy bird feeds nest number 7.", "style": "A"}, {"key": "17k1d85", "text": "This chick is hungry. Listen, nest number 9.", "style": "A"}, {"key": "1cxqsy9", "text": "9! Find the nest that says 9.", "style": "A"}, {"key": "1ylaxdg", "text": "There it is! Mommy bird feeds nest number 9.", "style": "A"}, {"key": "y5hzcc", "text": "This chick is hungry. Listen, nest number 4.", "style": "A"}, {"key": "17wcilr", "text": "4! Find the nest that says 4.", "style": "A"}, {"key": "zn6z2l", "text": "There it is! Mommy bird feeds nest number 4.", "style": "A"}, {"key": "829vn1", "text": "This chick is hungry. Listen, nest number 1.", "style": "A"}, {"key": "1lfanq9", "text": "1! Find the nest that says 1.", "style": "A"}, {"key": "1pqf2rw", "text": "There it is! Mommy bird feeds nest number 1.", "style": "A"}, {"key": "1xnulj2", "text": "This chick is hungry. Listen, nest number 6.", "style": "A"}, {"key": "me825f", "text": "6! Find the nest that says 6.", "style": "A"}, {"key": "qrddvj", "text": "There it is! Mommy bird feeds nest number 6.", "style": "A"}, {"key": "170k4xu", "text": "This chick is hungry. Listen, nest number 2.", "style": "A"}, {"key": "z9mvl7", "text": "2! Find the nest that says 2.", "style": "A"}, {"key": "4ucvv", "text": "There it is! Mommy bird feeds nest number 2.", "style": "A"}, {"key": "18xxvhj", "text": "This chick is hungry. Listen, nest number 10.", "style": "A"}, {"key": "1ca7znv", "text": "10! Find the nest that says 10.", "style": "A"}, {"key": "9nt800", "text": "There it is! Mommy bird feeds nest number 10.", "style": "A"}, {"key": "ybgx3c", "text": "Now you! Feed the chick in nest number 1. Tap it!", "style": "A"}, {"key": "1nuwogi", "text": "Now you! Feed the chick in nest number 3. Tap it!", "style": "A"}, {"key": "1eg1bmx", "text": "Now you! Feed the chick in nest number 4. Tap it!", "style": "A"}, {"key": "1bruf4c", "text": "Now you! Feed the chick in nest number 5. Tap it!", "style": "A"}, {"key": "1vqj77f", "text": "Now you! Feed the chick in nest number 6. Tap it!", "style": "A"}, {"key": "o5tgpi", "text": "Now you! Feed the chick in nest number 7. Tap it!", "style": "A"}, {"key": "s4ox4t", "text": "Now you! Feed the chick in nest number 8. Tap it!", "style": "A"}, {"key": "l6l0w0", "text": "Now you! Feed the chick in nest number 9. Tap it!", "style": "A"}, {"key": "18h1waa", "text": "Now you! Feed the chick in nest number 10. Tap it!", "style": "A"}, {"key": "kpjqbj", "text": "This duckling is hungry. Listen, nest number 4.", "style": "A"}, {"key": "1t4b2ax", "text": "This duckling is hungry. Listen, nest number 2.", "style": "A"}, {"key": "15gmg3a", "text": "This duckling is hungry. Listen, nest number 10.", "style": "A"}, {"key": "1jof47y", "text": "This duckling is hungry. Listen, nest number 1.", "style": "A"}, {"key": "tldbil", "text": "This duckling is hungry. Listen, nest number 6.", "style": "A"}, {"key": "t1aymo", "text": "This duckling is hungry. Listen, nest number 7.", "style": "A"}, {"key": "tks6wz", "text": "This duckling is hungry. Listen, nest number 8.", "style": "A"}, {"key": "k52jty", "text": "This duckling is hungry. Listen, nest number 9.", "style": "A"}, {"key": "w3nkv9", "text": "Now you! Feed the duckling in nest number 1. Tap it!", "style": "A"}, {"key": "16et313", "text": "Now you! Feed the duckling in nest number 3. Tap it!", "style": "A"}, {"key": "1537mcs", "text": "Now you! Feed the duckling in nest number 4. Tap it!", "style": "A"}, {"key": "1ru6gi1", "text": "Now you! Feed the duckling in nest number 5. Tap it!", "style": "A"}, {"key": "4y3hh2", "text": "Now you! Feed the duckling in nest number 6. Tap it!", "style": "A"}, {"key": "nuw2zf", "text": "Now you! Feed the duckling in nest number 7. Tap it!", "style": "A"}, {"key": "h7zd40", "text": "Now you! Feed the duckling in nest number 8. Tap it!", "style": "A"}, {"key": "1zbf6l", "text": "Now you! Feed the duckling in nest number 9. Tap it!", "style": "A"}, {"key": "tkcduh", "text": "Now you! Feed the duckling in nest number 10. Tap it!", "style": "A"}, {"key": "y7kvz0", "text": "We need exactly 2 bunnies to walk home.", "style": "A"}, {"key": "1an09se", "text": "That is 2. We have enough — so we stop, even though there are more.", "style": "A"}, {"key": "1yvxhkq", "text": "We need exactly 4 fish to walk home.", "style": "A"}, {"key": "d3vvr8", "text": "That is 4. We have enough — so we stop, even though there are more.", "style": "A"}, {"key": "1lyatvc", "text": "We need exactly 7 butterflies to walk home.", "style": "A"}, {"key": "sfxa81", "text": "Five.", "style": "A"}, {"key": "1m29ptr", "text": "Six.", "style": "A"}, {"key": "1mx8zkg", "text": "Seven.", "style": "A"}, {"key": "kn8tvl", "text": "That is 7. We have enough — so we stop, even though there are more.", "style": "A"}, {"key": "ibc5x3", "text": "We need exactly 3 squirrels to walk home.", "style": "A"}, {"key": "oy35di", "text": "We need exactly 5 turtles to walk home.", "style": "A"}, {"key": "1nmlcir", "text": "That is 5. We have enough — so we stop, even though there are more.", "style": "A"}, {"key": "w8jf0w", "text": "We need exactly 7 ladybugs to walk home.", "style": "A"}, {"key": "zyxhv8", "text": "We need exactly 1 ant to walk home.", "style": "A"}, {"key": "1ysz9t3", "text": "That is 1. We have enough — so we stop, even though there are more.", "style": "A"}, {"key": "1f1wykr", "text": "We need exactly 6 crabs to walk home.", "style": "A"}, {"key": "135pobe", "text": "That is 6. We have enough — so we stop, even though there are more.", "style": "A"}, {"key": "1uw8cwi", "text": "We need exactly 7 fireflies to walk home.", "style": "A"}, {"key": "20fii8", "text": "We need exactly 1 shark to walk home.", "style": "A"}, {"key": "1vqioih", "text": "We need exactly 7 fish to walk home.", "style": "A"}, {"key": "1mvr8hr", "text": "We need exactly 2 butterflies to walk home.", "style": "A"}, {"key": "nq2gao", "text": "We need exactly 6 squirrels to walk home.", "style": "A"}, {"key": "7jzhtz", "text": "We need exactly 6 turtles to walk home.", "style": "A"}, {"key": "dwkmlp", "text": "We need exactly 2 ladybugs to walk home.", "style": "A"}, {"key": "1ulergn", "text": "We need exactly 5 ants to walk home.", "style": "A"}, {"key": "93rq0h", "text": "We need exactly 2 fireflies to walk home.", "style": "A"}, {"key": "1m0xzoq", "text": "We need exactly 4 sharks to walk home.", "style": "A"}, {"key": "mlmm9n", "text": "We need exactly 7 bunnies to walk home.", "style": "A"}, {"key": "10pfu2c", "text": "We need exactly 2 fish to walk home.", "style": "A"}, {"key": "jut3vl", "text": "We need exactly 4 butterflies to walk home.", "style": "A"}, {"key": "1ud3fvv", "text": "We need exactly 7 squirrels to walk home.", "style": "A"}, {"key": "abemzw", "text": "We need exactly 3 turtles to walk home.", "style": "A"}, {"key": "1i4dj3j", "text": "We need exactly 4 ladybugs to walk home.", "style": "A"}, {"key": "86o831", "text": "We need exactly 7 ants to walk home.", "style": "A"}, {"key": "1qb62sb", "text": "We need exactly 1 crab to walk home.", "style": "A"}, {"key": "1ljyfb9", "text": "We need exactly 6 fireflies to walk home.", "style": "A"}, {"key": "1dzan7t", "text": "We need exactly 7 sharks to walk home.", "style": "A"}, {"key": "98ejv1", "text": "We need exactly 3 fish to walk home.", "style": "A"}, {"key": "jq6ysz", "text": "We need exactly 6 butterflies to walk home.", "style": "A"}, {"key": "vfbefs", "text": "We need exactly 2 ants to walk home.", "style": "A"}, {"key": "js9tzg", "text": "We need exactly 2 sharks to walk home.", "style": "A"}, {"key": "16sxeyy", "text": "We need exactly 1 butterfly to walk home.", "style": "A"}, {"key": "fndvah", "text": "We need exactly 5 squirrels to walk home.", "style": "A"}, {"key": "1shekr4", "text": "We need exactly 7 turtles to walk home.", "style": "A"}, {"key": "88p21o", "text": "We need exactly 3 ladybugs to walk home.", "style": "A"}, {"key": "10lquw4", "text": "We need exactly 7 crabs to walk home.", "style": "A"}, {"key": "pywcwg", "text": "We need exactly 6 sharks to walk home.", "style": "A"}, {"key": "1skz7jo", "text": "We need exactly 3 butterflies to walk home.", "style": "A"}, {"key": "ayr01z", "text": "We need exactly 1 turtle to walk home.", "style": "A"}, {"key": "r7kn5r", "text": "We need exactly 2 crabs to walk home.", "style": "A"}, {"key": "lwfngj", "text": "We need exactly 4 fireflies to walk home.", "style": "A"}, {"key": "dnu73f", "text": "We need exactly 5 fish to walk home.", "style": "A"}, {"key": "9fp830", "text": "We need exactly 2 squirrels to walk home.", "style": "A"}, {"key": "19e9yzl", "text": "We need exactly 4 crabs to walk home.", "style": "A"}, {"key": "1lbp7d4", "text": "We need exactly 6 bunnies to walk home.", "style": "A"}, {"key": "f58rz2", "text": "We need exactly 4 squirrels to walk home.", "style": "A"}, {"key": "16788ly", "text": "We need exactly 4 ants to walk home.", "style": "A"}, {"key": "dqvflc", "text": "We need exactly 1 firefly to walk home.", "style": "A"}, {"key": "n9vy08", "text": "We need exactly 5 fireflies to walk home.", "style": "A"}, {"key": "eii51i", "text": "We need exactly 1 squirrel to walk home.", "style": "A"}, {"key": "1wehwcs", "text": "We need exactly 6 ants to walk home.", "style": "A"}, {"key": "zkk6zp", "text": "We need exactly 3 sharks to walk home.", "style": "A"}, {"key": "17gvvwh", "text": "We need exactly 6 ladybugs to walk home.", "style": "A"}, {"key": "dev0h4", "text": "We need exactly 3 crabs to walk home.", "style": "A"}, {"key": "140mm91", "text": "1! Just right. Off we go!", "style": "A"}, {"key": "zm7y29", "text": "We need exactly 1 bunny to walk home.", "style": "A"}, {"key": "kl9bs3", "text": "Now you! Send exactly 1 bunny home.", "style": "A"}, {"key": "jzg9hb", "text": "We need exactly 1 fish to walk home.", "style": "A"}, {"key": "1waar3h", "text": "Now you! Send exactly 1 fish home.", "style": "A"}, {"key": "726dh0", "text": "Now you! Send exactly 1 butterfly home.", "style": "A"}, {"key": "1x9n58w", "text": "Now you! Send exactly 1 squirrel home.", "style": "A"}, {"key": "1m0x8it", "text": "Now you! Send exactly 1 turtle home.", "style": "A"}, {"key": "g73eqf", "text": "We need exactly 1 ladybug to walk home.", "style": "A"}, {"key": "fw6a1h", "text": "Now you! Send exactly 1 ladybug home.", "style": "A"}, {"key": "ealdpe", "text": "Now you! Send exactly 1 ant home.", "style": "A"}, {"key": "g8q92x", "text": "Now you! Send exactly 1 crab home.", "style": "A"}, {"key": "s9vwta", "text": "Now you! Send exactly 1 firefly home.", "style": "A"}, {"key": "13zzgwu", "text": "Now you! Send exactly 1 shark home.", "style": "A"}, {"key": "lxzw3e", "text": "Now you! Send exactly 2 bunnies home.", "style": "A"}, {"key": "1h05jil", "text": "Now you! Send exactly 2 butterflies home.", "style": "A"}, {"key": "82k4zu", "text": "Now you! Send exactly 2 squirrels home.", "style": "A"}, {"key": "1wqtdgj", "text": "We need exactly 2 turtles to walk home.", "style": "A"}, {"key": "xdn71t", "text": "Now you! Send exactly 2 turtles home.", "style": "A"}, {"key": "15knpf3", "text": "Now you! Send exactly 2 ladybugs home.", "style": "A"}, {"key": "1us386", "text": "Now you! Send exactly 2 ants home.", "style": "A"}, {"key": "psd6r1", "text": "Now you! Send exactly 2 crabs home.", "style": "A"}, {"key": "5yza77", "text": "Now you! Send exactly 2 fireflies home.", "style": "A"}, {"key": "1gyypii", "text": "Now you! Send exactly 2 sharks home.", "style": "A"}, {"key": "1uh2y19", "text": "Now you! Send exactly 3 bunnies home.", "style": "A"}, {"key": "a04oun", "text": "Now you! Send exactly 3 fish home.", "style": "A"}, {"key": "2154f6", "text": "Now you! Send exactly 3 butterflies home.", "style": "A"}, {"key": "9ghstx", "text": "Now you! Send exactly 3 squirrels home.", "style": "A"}, {"key": "1u63nje", "text": "Now you! Send exactly 3 turtles home.", "style": "A"}, {"key": "1ukdw8q", "text": "Now you! Send exactly 3 ladybugs home.", "style": "A"}, {"key": "ah61ix", "text": "We need exactly 3 ants to walk home.", "style": "A"}, {"key": "159582j", "text": "Now you! Send exactly 3 ants home.", "style": "A"}, {"key": "1q3kafa", "text": "Now you! Send exactly 3 crabs home.", "style": "A"}, {"key": "kh305q", "text": "We need exactly 3 fireflies to walk home.", "style": "A"}, {"key": "130k8g8", "text": "Now you! Send exactly 3 fireflies home.", "style": "A"}, {"key": "1xgadqv", "text": "Now you! Send exactly 3 sharks home.", "style": "A"}, {"key": "g8va4a", "text": "4! Just right. Off we go!", "style": "A"}, {"key": "elms7i", "text": "We need exactly 4 bunnies to walk home.", "style": "A"}, {"key": "137ktl4", "text": "Now you! Send exactly 4 bunnies home.", "style": "A"}, {"key": "2kgitg", "text": "Now you! Send exactly 4 fish home.", "style": "A"}, {"key": "pvxa2b", "text": "Now you! Send exactly 4 butterflies home.", "style": "A"}, {"key": "1ofhd08", "text": "Now you! Send exactly 4 squirrels home.", "style": "A"}, {"key": "1l6fhn9", "text": "We need exactly 4 turtles to walk home.", "style": "A"}, {"key": "1qjncdj", "text": "Now you! Send exactly 4 turtles home.", "style": "A"}, {"key": "1g2u1b1", "text": "Now you! Send exactly 4 ladybugs home.", "style": "A"}, {"key": "1syilc0", "text": "Now you! Send exactly 4 ants home.", "style": "A"}, {"key": "wir6dv", "text": "Now you! Send exactly 4 crabs home.", "style": "A"}, {"key": "d880xd", "text": "Now you! Send exactly 4 fireflies home.", "style": "A"}, {"key": "18vpt84", "text": "Now you! Send exactly 4 sharks home.", "style": "A"}, {"key": "omuz2h", "text": "5! Just right. Off we go!", "style": "A"}, {"key": "hdzwqp", "text": "We need exactly 5 bunnies to walk home.", "style": "A"}, {"key": "ypmqyb", "text": "Now you! Send exactly 5 bunnies home.", "style": "A"}, {"key": "1m5jtop", "text": "Now you! Send exactly 5 fish home.", "style": "A"}, {"key": "i4mmz2", "text": "We need exactly 5 butterflies to walk home.", "style": "A"}, {"key": "179fu20", "text": "Now you! Send exactly 5 butterflies home.", "style": "A"}, {"key": "1pezf8r", "text": "Now you! Send exactly 5 squirrels home.", "style": "A"}, {"key": "1smi3s0", "text": "Now you! Send exactly 5 turtles home.", "style": "A"}, {"key": "168jg12", "text": "We need exactly 5 ladybugs to walk home.", "style": "A"}, {"key": "1gzjpkg", "text": "Now you! Send exactly 5 ladybugs home.", "style": "A"}, {"key": "li6tt1", "text": "Now you! Send exactly 5 ants home.", "style": "A"}, {"key": "1y2dh96", "text": "We need exactly 5 crabs to walk home.", "style": "A"}, {"key": "uy7i78", "text": "Now you! Send exactly 5 crabs home.", "style": "A"}, {"key": "1dsh492", "text": "Now you! Send exactly 5 fireflies home.", "style": "A"}, {"key": "1j7cnl7", "text": "We need exactly 5 sharks to walk home.", "style": "A"}, {"key": "hxjqkp", "text": "Now you! Send exactly 5 sharks home.", "style": "A"}, {"key": "17hqgyc", "text": "6! Just right. Off we go!", "style": "A"}, {"key": "hi13s6", "text": "Now you! Send exactly 6 bunnies home.", "style": "A"}, {"key": "1yld468", "text": "We need exactly 6 fish to walk home.", "style": "A"}, {"key": "1kzssu", "text": "Now you! Send exactly 6 fish home.", "style": "A"}, {"key": "1ysep4x", "text": "Now you! Send exactly 6 butterflies home.", "style": "A"}, {"key": "riqzou", "text": "Now you! Send exactly 6 squirrels home.", "style": "A"}, {"key": "1nkbwrp", "text": "Now you! Send exactly 6 turtles home.", "style": "A"}, {"key": "1c0objn", "text": "Now you! Send exactly 6 ladybugs home.", "style": "A"}, {"key": "1kk2r9m", "text": "Now you! Send exactly 6 ants home.", "style": "A"}, {"key": "1gvjhl", "text": "Now you! Send exactly 6 crabs home.", "style": "A"}, {"key": "6jl81j", "text": "Now you! Send exactly 6 fireflies home.", "style": "A"}, {"key": "u2e29q", "text": "Now you! Send exactly 6 sharks home.", "style": "A"}, {"key": "14f99jn", "text": "7! Just right. Off we go!", "style": "A"}, {"key": "1te76op", "text": "Now you! Send exactly 7 bunnies home.", "style": "A"}, {"key": "4he5gb", "text": "Now you! Send exactly 7 fish home.", "style": "A"}, {"key": "1pl6sxi", "text": "Now you! Send exactly 7 butterflies home.", "style": "A"}, {"key": "1vsb85l", "text": "Now you! Send exactly 7 squirrels home.", "style": "A"}, {"key": "59vyzi", "text": "Now you! Send exactly 7 turtles home.", "style": "A"}, {"key": "1gd7uda", "text": "Now you! Send exactly 7 ladybugs home.", "style": "A"}, {"key": "qff9lb", "text": "Now you! Send exactly 7 ants home.", "style": "A"}, {"key": "2sllo2", "text": "Now you! Send exactly 7 crabs home.", "style": "A"}, {"key": "cj93bg", "text": "Now you! Send exactly 7 fireflies home.", "style": "A"}, {"key": "8lbfpn", "text": "Now you! Send exactly 7 sharks home.", "style": "A"}, {"key": "cto3m4", "text": "Let's count this bunch. 3.", "style": "A"}, {"key": "5ffxl", "text": "And this bunch. 5.", "style": "A"}, {"key": "118ea0u", "text": "5 is more — that is the one we pick.", "style": "A"}, {"key": "znlr4d", "text": "And this bunch. 1.", "style": "A"}, {"key": "1r2bus4", "text": "3 is more — that is the one we pick.", "style": "A"}, {"key": "cthsm6", "text": "Let's count this bunch. 1.", "style": "A"}, {"key": "qrs5xb", "text": "And this bunch. 3.", "style": "A"}, {"key": "1lrk1vx", "text": "Let's count this bunch. 6.", "style": "A"}, {"key": "174xqnj", "text": "2 is fewer — that is the one we pick.", "style": "A"}, {"key": "1sk3u3h", "text": "This one has 3. This one has 9.", "style": "A"}, {"key": "4rgz7d", "text": "3 is smaller. Tap that one!", "style": "A"}, {"key": "sp1i2k", "text": "3 is fewer — that is the one we pick.", "style": "A"}, {"key": "1xnpk2t", "text": "2 is more — that is the one we pick.", "style": "A"}, {"key": "loq97m", "text": "Let's count this bunch. 5.", "style": "A"}, {"key": "1fowliq", "text": "1 is fewer — that is the one we pick.", "style": "A"}, {"key": "ak4di8", "text": "This one has 7. This one has 4.", "style": "A"}, {"key": "ztma8t", "text": "7 is bigger. Tap that one!", "style": "A"}, {"key": "1pqtuto", "text": "And this bunch. 4.", "style": "A"}, {"key": "m9dqp5", "text": "Let's count this bunch. 2.", "style": "A"}, {"key": "1d3aqpp", "text": "This one has 1. This one has 10.", "style": "A"}, {"key": "1mskopv", "text": "1 is smaller. Tap that one!", "style": "A"}, {"key": "1an4h6h", "text": "This one has 7. This one has 1.", "style": "A"}, {"key": "dp93qq", "text": "This one has 8. This one has 10.", "style": "A"}, {"key": "h3tm0", "text": "8 is smaller. Tap that one!", "style": "A"}, {"key": "1pqnjtq", "text": "And this bunch. 6.", "style": "A"}, {"key": "1iwltu9", "text": "6 is more — that is the one we pick.", "style": "A"}, {"key": "1hk6dl3", "text": "This one has 1. This one has 9.", "style": "A"}, {"key": "1khq6dx", "text": "This one has 9. This one has 3.", "style": "A"}, {"key": "yooc5z", "text": "9 is bigger. Tap that one!", "style": "A"}, {"key": "1lowwqc", "text": "This one has 6. This one has 9.", "style": "A"}, {"key": "1a2gzoy", "text": "This one has 7. This one has 6.", "style": "A"}, {"key": "140wp38", "text": "This one has 5. This one has 2.", "style": "A"}, {"key": "kf4l8m", "text": "2 is smaller. Tap that one!", "style": "A"}, {"key": "1ji0bs1", "text": "This one has 7. This one has 9.", "style": "A"}, {"key": "1wjli4l", "text": "7 is smaller. Tap that one!", "style": "A"}, {"key": "kyyqlj", "text": "This one has 9. This one has 1.", "style": "A"}, {"key": "1tzkty", "text": "This one has 3. This one has 6.", "style": "A"}, {"key": "ni4no9", "text": "This one has 5. This one has 10.", "style": "A"}, {"key": "urjux3", "text": "10 is bigger. Tap that one!", "style": "A"}, {"key": "3tqnqn", "text": "5 is smaller. Tap that one!", "style": "A"}, {"key": "b46qe5", "text": "This one has 7. This one has 5.", "style": "A"}, {"key": "1a2aop0", "text": "This one has 7. This one has 8.", "style": "A"}, {"key": "17m3l8m", "text": "8 is bigger. Tap that one!", "style": "A"}, {"key": "521b6t", "text": "This one has 5. This one has 7.", "style": "A"}, {"key": "5995mx", "text": "4 is fewer — that is the one we pick.", "style": "A"}, {"key": "1i2sfzo", "text": "6 is bigger. Tap that one!", "style": "A"}, {"key": "1iuoerm", "text": "1 is more — that is the one we pick.", "style": "A"}, {"key": "1d64ipa", "text": "5 is fewer — that is the one we pick.", "style": "A"}, {"key": "1aoolfv", "text": "6 is fewer — that is the one we pick.", "style": "A"}, {"key": "1l7hp00", "text": "Let's count this bunch. 7.", "style": "A"}, {"key": "594xn", "text": "And this bunch. 7.", "style": "A"}, {"key": "13p10lc", "text": "7 is more — that is the one we pick.", "style": "A"}, {"key": "1saqtk", "text": "7 is fewer — that is the one we pick.", "style": "A"}, {"key": "1lqyxab", "text": "Let's count this bunch. 8.", "style": "A"}, {"key": "q74ofs", "text": "And this bunch. 8.", "style": "A"}, {"key": "16daq0b", "text": "8 is more — that is the one we pick.", "style": "A"}, {"key": "1ja3uit", "text": "8 is fewer — that is the one we pick.", "style": "A"}, {"key": "1cb9a7a", "text": "Let's count this bunch. 9.", "style": "A"}, {"key": "zmubit", "text": "And this bunch. 9.", "style": "A"}, {"key": "1d2pgey", "text": "9 is more — that is the one we pick.", "style": "A"}, {"key": "1tekjtm", "text": "9 is fewer — that is the one we pick.", "style": "A"}, {"key": "9wdkq7", "text": "1 is bigger. Tap that one!", "style": "A"}, {"key": "1h11rao", "text": "This one has 1. This one has 2.", "style": "A"}, {"key": "i2l6zx", "text": "This one has 1. This one has 3.", "style": "A"}, {"key": "8n1uwu", "text": "This one has 1. This one has 4.", "style": "A"}, {"key": "i2rhzv", "text": "This one has 1. This one has 5.", "style": "A"}, {"key": "185tap8", "text": "This one has 1. This one has 6.", "style": "A"}, {"key": "1hlixs9", "text": "This one has 1. This one has 7.", "style": "A"}, {"key": "184gqi2", "text": "This one has 1. This one has 8.", "style": "A"}, {"key": "t2auyg", "text": "2 is bigger. Tap that one!", "style": "A"}, {"key": "hxlv6w", "text": "This one has 2. This one has 1.", "style": "A"}, {"key": "1hfyhdm", "text": "This one has 2. This one has 3.", "style": "A"}, {"key": "1i0lyv5", "text": "This one has 2. This one has 4.", "style": "A"}, {"key": "18kwbs4", "text": "This one has 2. This one has 5.", "style": "A"}, {"key": "194sdo3", "text": "This one has 2. This one has 6.", "style": "A"}, {"key": "hxs66u", "text": "This one has 2. This one has 7.", "style": "A"}, {"key": "195di9p", "text": "This one has 2. This one has 8.", "style": "A"}, {"key": "92q0lc", "text": "This one has 2. This one has 9.", "style": "A"}, {"key": "s2ovjo", "text": "This one has 2. This one has 10.", "style": "A"}, {"key": "1bry2mp", "text": "3 is bigger. Tap that one!", "style": "A"}, {"key": "1sjcehx", "text": "This one has 3. This one has 1.", "style": "A"}, {"key": "11c5w0q", "text": "This one has 3. This one has 2.", "style": "A"}, {"key": "sh3qf8", "text": "This one has 3. This one has 4.", "style": "A"}, {"key": "11wtdi9", "text": "This one has 3. This one has 5.", "style": "A"}, {"key": "1sjiphv", "text": "This one has 3. This one has 7.", "style": "A"}, {"key": "1s01h7k", "text": "This one has 3. This one has 8.", "style": "A"}, {"key": "5gl2fj", "text": "This one has 3. This one has 10.", "style": "A"}, {"key": "1ctdtmi", "text": "4 is bigger. Tap that one!", "style": "A"}, {"key": "1hi52t8", "text": "4 is smaller. Tap that one!", "style": "A"}, {"key": "4eemtq", "text": "This one has 4. This one has 1.", "style": "A"}, {"key": "vll5ax", "text": "This one has 4. This one has 2.", "style": "A"}, {"key": "4ekxto", "text": "This one has 4. This one has 3.", "style": "A"}, {"key": "v0xnte", "text": "This one has 4. This one has 5.", "style": "A"}, {"key": "1v3rghp", "text": "This one has 4. This one has 6.", "style": "A"}, {"key": "v13ytc", "text": "This one has 4. This one has 7.", "style": "A"}, {"key": "1v36bw3", "text": "This one has 4. This one has 8.", "style": "A"}, {"key": "13w64eu", "text": "This one has 4. This one has 9.", "style": "A"}, {"key": "15u28km", "text": "This one has 4. This one has 10.", "style": "A"}, {"key": "1qsjzej", "text": "5 is bigger. Tap that one!", "style": "A"}, {"key": "527m6r", "text": "This one has 5. This one has 1.", "style": "A"}, {"key": "1dgmc69", "text": "This one has 5. This one has 3.", "style": "A"}, {"key": "1cvyuoq", "text": "This one has 5. This one has 4.", "style": "A"}, {"key": "1cw55oo", "text": "This one has 5. This one has 6.", "style": "A"}, {"key": "dejz3i", "text": "This one has 5. This one has 8.", "style": "A"}, {"key": "14lk6kr", "text": "This one has 5. This one has 9.", "style": "A"}, {"key": "tzw2ci", "text": "6 is smaller. Tap that one!", "style": "A"}, {"key": "1cu124s", "text": "This one has 6. This one has 1.", "style": "A"}, {"key": "1m9ke7v", "text": "This one has 6. This one has 2.", "style": "A"}, {"key": "1ctur4u", "text": "This one has 6. This one has 3.", "style": "A"}, {"key": "mqsyfh", "text": "This one has 6. This one has 4.", "style": "A"}, {"key": "m6qljk", "text": "This one has 6. This one has 5.", "style": "A"}, {"key": "1lp37qa", "text": "This one has 6. This one has 7.", "style": "A"}, {"key": "1ddbzf5", "text": "This one has 6. This one has 8.", "style": "A"}, {"key": "e3e1z4", "text": "This one has 6. This one has 10.", "style": "A"}, {"key": "jfxypa", "text": "This one has 7. This one has 2.", "style": "A"}, {"key": "1amy66j", "text": "This one has 7. This one has 3.", "style": "A"}, {"key": "oippwr", "text": "This one has 7. This one has 10.", "style": "A"}, {"key": "5qqsr6", "text": "This one has 8. This one has 1.", "style": "A"}, {"key": "15tklfh", "text": "This one has 8. This one has 2.", "style": "A"}, {"key": "5qx3r4", "text": "This one has 8. This one has 3.", "style": "A"}, {"key": "15tqwff", "text": "This one has 8. This one has 4.", "style": "A"}, {"key": "1e5btqm", "text": "This one has 8. This one has 5.", "style": "A"}, {"key": "6bea8p", "text": "This one has 8. This one has 6.", "style": "A"}, {"key": "1e5i4qk", "text": "This one has 8. This one has 7.", "style": "A"}, {"key": "1e45kje", "text": "This one has 8. This one has 9.", "style": "A"}, {"key": "nxvy4b", "text": "9 is smaller. Tap that one!", "style": "A"}, {"key": "1b20jaw", "text": "This one has 9. This one has 2.", "style": "A"}, {"key": "1b26uau", "text": "This one has 9. This one has 4.", "style": "A"}, {"key": "1khwhdv", "text": "This one has 9. This one has 5.", "style": "A"}, {"key": "kfhib8", "text": "This one has 9. This one has 6.", "style": "A"}, {"key": "c3wl01", "text": "This one has 9. This one has 7.", "style": "A"}, {"key": "kfntb6", "text": "This one has 9. This one has 8.", "style": "A"}, {"key": "a1hrud", "text": "This one has 9. This one has 10.", "style": "A"}, {"key": "1mi0c4r", "text": "10 is smaller. Tap that one!", "style": "A"}, {"key": "v91d3n", "text": "This one has 10. This one has 1.", "style": "A"}, {"key": "1u7qg04", "text": "This one has 10. This one has 2.", "style": "A"}, {"key": "4mc141", "text": "This one has 10. This one has 3.", "style": "A"}, {"key": "41ojmi", "text": "This one has 10. This one has 4.", "style": "A"}, {"key": "1ur7oaf", "text": "This one has 10. This one has 5.", "style": "A"}, {"key": "41uumg", "text": "This one has 10. This one has 6.", "style": "A"}, {"key": "v8v23p", "text": "This one has 10. This one has 7.", "style": "A"}, {"key": "13ldq0e", "text": "This one has 10. This one has 8.", "style": "A"}, {"key": "1usdxhn", "text": "This one has 10. This one has 9.", "style": "A"}, {"key": "apkb7l", "text": "Look — the door is missing. It needs a rectangle.", "style": "A"}, {"key": "10a5o6f", "text": "This one is a rectangle. Watch it fit!", "style": "A"}, {"key": "ola71a", "text": "Now you! The door needs a rectangle. Tap it!", "style": "A"}, {"key": "rwssph", "text": "Great job! The rectangle fits!", "style": "A"}, {"key": "1ko5nuu", "text": "Look — the window is missing. It needs a circle.", "style": "A"}, {"key": "vj2y8k", "text": "This one is a circle. Watch it fit!", "style": "A"}, {"key": "l2ru49", "text": "Now you! The window needs a circle. Tap it!", "style": "A"}, {"key": "1qmd25i", "text": "Great job! The circle fits!", "style": "A"}, {"key": "1auipze", "text": "Look — the star on the roof is missing. It needs a star.", "style": "A"}, {"key": "1cxffow", "text": "This one is a star. Watch it fit!", "style": "A"}, {"key": "174djyd", "text": "Now you! The star on the roof needs a star. Tap it!", "style": "A"}, {"key": "1l3hvj2", "text": "Great job! The star fits!", "style": "A"}, {"key": "1gjikcq", "text": "Look — the heart on the wall is missing. It needs a heart.", "style": "A"}, {"key": "1ja8okk", "text": "This one is a heart. Watch it fit!", "style": "A"}, {"key": "4s36nf", "text": "Now you! The heart on the wall needs a heart. Tap it!", "style": "A"}, {"key": "1uuj5tk", "text": "Great job! The heart fits!", "style": "A"}, {"key": "jhvwr6", "text": "Look — the hull is missing. It needs a rectangle.", "style": "A"}, {"key": "xougxv", "text": "Now you! The hull needs a rectangle. Tap it!", "style": "A"}, {"key": "xtjxxl", "text": "Look — the sail is missing. It needs a triangle.", "style": "A"}, {"key": "1p7ki1s", "text": "Now you! The sail needs a triangle. Tap it!", "style": "A"}, {"key": "1wwryvp", "text": "Look — the porthole is missing. It needs a circle.", "style": "A"}, {"key": "2l53pg", "text": "Now you! The porthole needs a circle. Tap it!", "style": "A"}, {"key": "18uokek", "text": "Look — the flag is missing. It needs a star.", "style": "A"}, {"key": "17j95qr", "text": "Now you! The flag needs a star. Tap it!", "style": "A"}, {"key": "sxep5", "text": "Let's do this one together. The roof is glowing — that is the bit we color.", "style": "A"}, {"key": "13f8ngr", "text": "We want red. Remember the red in the garden? This is the red paint.", "style": "A"}, {"key": "1j0nyvs", "text": "Watch the roof turn red!", "style": "A"}, {"key": "nr7m4p", "text": "Let's do this one together. The sun is glowing — that is the bit we color.", "style": "A"}, {"key": "1khp49u", "text": "We want yellow. Remember the yellow in the garden? This is the yellow paint.", "style": "A"}, {"key": "1eehrev", "text": "Watch the sun turn yellow!", "style": "A"}, {"key": "1ka8m1s", "text": "Let's do this one together. The sky is glowing — that is the bit we color.", "style": "A"}, {"key": "1vilg6u", "text": "We want blue. Remember the blue in the garden? This is the blue paint.", "style": "A"}, {"key": "evzxt2", "text": "Watch the sky turn blue!", "style": "A"}, {"key": "1v6chlz", "text": "Let's do this one together. The tree is glowing — that is the bit we color.", "style": "A"}, {"key": "z9jk77", "text": "We want green. Remember the green in the garden? This is the green paint.", "style": "A"}, {"key": "16yi1ce", "text": "Watch the tree turn green!", "style": "A"}, {"key": "jdx1z3", "text": "Let's do this one together. The rabbit is glowing — that is the bit we color.", "style": "A"}, {"key": "ye0p5c", "text": "We want orange. Remember the orange in the garden? This is the orange paint.", "style": "A"}, {"key": "fjhr21", "text": "Watch the rabbit turn orange!", "style": "A"}, {"key": "6kwjg3", "text": "Let's do this one together. The tulip is glowing — that is the bit we color.", "style": "A"}, {"key": "phuugs", "text": "We want purple. Remember the purple in the garden? This is the purple paint.", "style": "A"}, {"key": "aj8373", "text": "Watch the tulip turn purple!", "style": "A"}, {"key": "1tfpge6", "text": "Let's do this one together. The balloon is glowing — that is the bit we color.", "style": "A"}, {"key": "lx5vbj", "text": "Watch the balloon turn red!", "style": "A"}, {"key": "17um2x", "text": "Let's do this one together. The car is glowing — that is the bit we color.", "style": "A"}, {"key": "gw275f", "text": "Watch the car turn blue!", "style": "A"}, {"key": "1k6du7z", "text": "Let's do this one together. The star is glowing — that is the bit we color.", "style": "A"}, {"key": "1lbi1on", "text": "Watch the star turn yellow!", "style": "A"}, {"key": "1da6ngr", "text": "Let's do this one together. The wall is glowing — that is the bit we color.", "style": "A"}, {"key": "p6daxa", "text": "Watch the wall turn green!", "style": "A"}, {"key": "aunslh", "text": "Let's do this one together. The teddy's head is glowing — that is the bit we color.", "style": "A"}, {"key": "6h3bu3", "text": "Watch the teddy's head turn purple!", "style": "A"}, {"key": "1mstgod", "text": "Let's do this one together. The rug is glowing — that is the bit we color.", "style": "A"}, {"key": "1osgjmx", "text": "Watch the rug turn orange!", "style": "A"}, {"key": "ty90ig", "text": "Let's do this one together. The ball is glowing — that is the bit we color.", "style": "A"}, {"key": "24jmwn", "text": "Watch the ball turn red!", "style": "A"}, {"key": "1dsvhs1", "text": "Let's do this one together. The car window is glowing — that is the bit we color.", "style": "A"}, {"key": "1tcoij9", "text": "Watch the car window turn blue!", "style": "A"}, {"key": "1kuw9ea", "text": "Let's do this one together. The cat's face is glowing — that is the bit we color.", "style": "A"}, {"key": "11qukrc", "text": "Watch the cat's face turn orange!", "style": "A"}, {"key": "sfaizn", "text": "Let's do this one together. The teddy's tummy is glowing — that is the bit we color.", "style": "A"}, {"key": "1rpxzxd", "text": "Watch the teddy's tummy turn yellow!", "style": "A"}, {"key": "1nmbbqy", "text": "Look at the pattern. It goes green, orange, green, orange, over and over.", "style": "A"}, {"key": "1001q4i", "text": "Look at the pattern. It goes pink, red, pink, red, over and over.", "style": "A"}, {"key": "quz312", "text": "Look at the pattern. It goes yellow, green, yellow, green, over and over.", "style": "A"}, {"key": "c7b5s8", "text": "Look at the pattern. It goes purple, pink, purple, pink, over and over.", "style": "A"}, {"key": "1a60xg8", "text": "Look at the pattern. It goes blue, yellow, blue, yellow, over and over.", "style": "A"}, {"key": "fu7biw", "text": "Look at the pattern. It goes orange, purple, orange, purple, over and over.", "style": "A"}, {"key": "vqshxm", "text": "Look at the pattern. It goes red, blue, yellow, red, blue, yellow, over and over.", "style": "A"}, {"key": "1ddvn6a", "text": "Look at the pattern. It goes green, orange, purple, green, orange, purple, over and over.", "style": "A"}, {"key": "buaqqa", "text": "Look at the pattern. It goes pink, red, blue, pink, red, blue, over and over.", "style": "A"}, {"key": "16hkh9q", "text": "Look at the pattern. It goes yellow, green, orange, yellow, green, orange, over and over.", "style": "A"}, {"key": "u89a8q", "text": "Look at the pattern. It goes purple, pink, red, purple, pink, red, over and over.", "style": "A"}, {"key": "1tr3tze", "text": "Look at the pattern. It goes blue, yellow, green, blue, yellow, green, over and over.", "style": "A"}, {"key": "1ht4fy0", "text": "Look at the pattern. It goes orange, purple, pink, orange, purple, pink, over and over.", "style": "A"}, {"key": "1danbsg", "text": "Look at the pattern. It goes red, blue, yellow, green, red, blue, yellow, green, over and over.", "style": "A"}, {"key": "xq99yu", "text": "Look at the pattern. It goes green, orange, purple, pink, green, orange, purple, pink, over and over.", "style": "A"}, {"key": "1p0kpry", "text": "Look at the pattern. It goes pink, red, blue, yellow, pink, red, blue, yellow, over and over.", "style": "A"}, {"key": "y04sri", "text": "Look at the pattern. It goes yellow, green, orange, purple, yellow, green, orange, purple, over and over.", "style": "A"}, {"key": "1ta00fq", "text": "Look at the pattern. It goes purple, pink, red, blue, purple, pink, red, blue, over and over.", "style": "A"}, {"key": "8q6kny", "text": "Look at the pattern. It goes blue, yellow, green, orange, blue, yellow, green, orange, over and over.", "style": "A"}, {"key": "1ryep5q", "text": "Look at the pattern. It goes orange, purple, pink, red, orange, purple, pink, red, over and over.", "style": "A"}, {"key": "1gvomce", "text": "So the next bead is red. Watch it go on!", "style": "A"}, {"key": "1dbsyst", "text": "So the next bead is yellow. Watch it go on!", "style": "A"}, {"key": "1gfsrj2", "text": "So the next bead is green. Watch it go on!", "style": "A"}, {"key": "1x1qlbz", "text": "So the next bead is orange. Watch it go on!", "style": "A"}, {"key": "jut2xz", "text": "So the next bead is purple. Watch it go on!", "style": "A"}, {"key": "1qeg0sx", "text": "So the next bead is pink. Watch it go on!", "style": "A"}, {"key": "1rjsrxs", "text": "So the next flag is red. Watch it go on!", "style": "A"}, {"key": "118yqwn", "text": "So the next flag is yellow. Watch it go on!", "style": "A"}, {"key": "61ud0g", "text": "So the next flag is green. Watch it go on!", "style": "A"}, {"key": "1llvltd", "text": "So the next flag is orange. Watch it go on!", "style": "A"}, {"key": "dacf0t", "text": "So the next flag is purple. Watch it go on!", "style": "A"}, {"key": "1p8777", "text": "So the next flag is pink. Watch it go on!", "style": "A"}, {"key": "110er8w", "text": "So the next train car is red. Watch it go on!", "style": "A"}, {"key": "1vxrvsn", "text": "So the next train car is yellow. Watch it go on!", "style": "A"}, {"key": "1iruvz4", "text": "So the next train car is green. Watch it go on!", "style": "A"}, {"key": "h9koq9", "text": "So the next train car is orange. Watch it go on!", "style": "A"}, {"key": "17z5jwt", "text": "So the next train car is purple. Watch it go on!", "style": "A"}, {"key": "wbaqur", "text": "So the next train car is pink. Watch it go on!", "style": "A"}, {"key": "1pt9un5", "text": "How tall is the apple tree? Let's lay the blocks!", "style": "A"}, {"key": "v09d74", "text": "We reached the very top! So the apple tree is 4 blocks tall.", "style": "A"}, {"key": "gy80t3", "text": "How tall is the giraffe? Let's lay the blocks!", "style": "A"}, {"key": "y307m3", "text": "We reached the very top! So the giraffe is 5 blocks tall.", "style": "A"}, {"key": "1idwos5", "text": "How tall is the pine tree? Let's lay the blocks!", "style": "A"}, {"key": "thnfhq", "text": "We reached the very top! So the pine tree is 6 blocks tall.", "style": "A"}, {"key": "1dejg99", "text": "How tall is the daisy? Let's lay the blocks!", "style": "A"}, {"key": "t0wppz", "text": "We reached the very top! So the daisy is 3 blocks tall.", "style": "A"}, {"key": "gwdm5b", "text": "Your turn! Lay the blocks until you reach the end of the tulip.", "style": "A"}, {"key": "vo10bg", "text": "Your turn! Lay the blocks until you reach the end of the sunflower.", "style": "A"}, {"key": "1rh4mtl", "text": "Your turn! Lay the blocks until you reach the end of the apple tree.", "style": "A"}, {"key": "iytbxv", "text": "Your turn! Lay the blocks until you reach the end of the giraffe.", "style": "A"}, {"key": "73819", "text": "Your turn! Lay the blocks until you reach the end of the pine tree.", "style": "A"}, {"key": "j5ir56", "text": "How long is the train car? Let's lay the blocks!", "style": "A"}, {"key": "1njvyxr", "text": "We reached the very end! So the train car is 4 blocks long.", "style": "A"}, {"key": "19s0jo", "text": "How long is the bus? Let's lay the blocks!", "style": "A"}, {"key": "1w4u8b0", "text": "We reached the very end! So the bus is 5 blocks long.", "style": "A"}, {"key": "ie0nj6", "text": "How long is the snake? Let's lay the blocks!", "style": "A"}, {"key": "1g45w35", "text": "We reached the very end! So the snake is 6 blocks long.", "style": "A"}, {"key": "29rjji", "text": "How long is the train engine? Let's lay the blocks!", "style": "A"}, {"key": "fv92fy", "text": "We reached the very end! So the train engine is 3 blocks long.", "style": "A"}, {"key": "mmd047", "text": "Your turn! Lay the blocks until you reach the end of the fish.", "style": "A"}, {"key": "tx0tcq", "text": "Your turn! Lay the blocks until you reach the end of the caterpillar.", "style": "A"}, {"key": "16dvatb", "text": "Your turn! Lay the blocks until you reach the end of the train car.", "style": "A"}, {"key": "p4thud", "text": "Your turn! Lay the blocks until you reach the end of the bus.", "style": "A"}, {"key": "2o24zz", "text": "Your turn! Lay the blocks until you reach the end of the snake.", "style": "A"}]
todo = [r for r in LINES if not (REPO / 'public/audio' / VOICE / f"{r['key']}.mp3").exists()]
json.dump(todo, open(WORK / 'todo.json', 'w'))
print(len(todo), 'lines to render')
assert 0 < len(todo) <= 1224, 'nothing to render — every line already has a clip on main'

# %%
# Chatterbox pins torch 2.6, which breaks Kaggle's own torchvision — so it gets its own venv (uv: Kaggle's python has no ensurepip).
VENV = WORK / 'venv'; PY = VENV / 'bin' / 'python'; READY = VENV / '.ready'
if not READY.exists():
    shutil.rmtree(VENV, ignore_errors=True)
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'uv'], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'venv', str(VENV), '--python', sys.executable], check=True)
    subprocess.run([sys.executable, '-m', 'uv', 'pip', 'install', '--python', str(PY), 'setuptools<81', 'chatterbox-tts', 'imageio-ffmpeg'], check=True)
    READY.touch()
print(subprocess.run([str(PY), '-c', "import torch; print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'NONE — set the accelerator')"], capture_output=True, text=True).stdout)

# %%
OUT = WORK / 'out' / VOICE
cmd = [str(PY), str(REPO / 'scripts/chatterbox-render.py'), '--voice', VOICE, '--corpus', str(WORK / 'todo.json'), '--out', str(OUT)]
proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
for line in proc.stdout:
    if 'it/s]' in line or not line.strip(): continue   # drop the progress bars
    print(line.rstrip()[:160], flush=True)
print('exit code', proc.wait())

# %%
keys = {r['key'] for r in todo}
clips = sorted(c for c in OUT.glob('*.mp3') if c.stem in keys)
missing = [k for k in keys if not (OUT / f'{k}.mp3').exists()]
stage = WORK / 'stage'; shutil.rmtree(stage, ignore_errors=True); (stage / VOICE).mkdir(parents=True)
for c in clips: shutil.copy2(c, stage / VOICE / c.name)
shutil.make_archive(str(WORK / 'radlic-voice-josh-chapters-kg-1'), 'zip', stage)
print(f'{len(clips)} of {len(todo)} clips in radlic-voice-josh-chapters-kg-1.zip' + (f' — MISSING {len(missing)}: {missing}' if missing else ' — complete'))
